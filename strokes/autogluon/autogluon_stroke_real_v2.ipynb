# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-real.csv')

# %%
df.drop(columns='id', inplace=True)
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((3066, 11), (2044, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/real/v2',
    learner_kwargs = {'positive_class':1}
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/strokes/real/v2"

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 900
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       9.85 GB / 15.94 GB (61.8%)
# Disk Space Avail:   121.14 GB / 446.36 GB (27.1%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-08 16:19:58,768	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/strokes/real/v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=27764) Running DyStack sub-fit ...
# (_dystack pid=27764) Beginning AutoGluon training ... Time limit = 219s
# (_dystack pid=27764) AutoGluon will save models to "AutogluonModels/strokes/real/v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=27764) Train Data Rows:    2725
# (_dystack pid=27764) Train Data Columns: 10
# (_dystack pid=27764) Label Column:       stroke
# (_dystack pid=27764) Problem Type:       binary
# (_dystack pid=27764) Preprocessing data ...
# (_dystack pid=27764) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=27764) Using Feature Generators to preprocess the data ...
# (_dystack pid=27764) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=27764) 	Available Memory:                    9565.45 MB
# (_dystack pid=27764) 	Train Data (Original)  Memory Usage: 0.93 MB (0.0% of available memory)
# (_dystack pid=27764) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=27764) 	Stage 1 Generators:
# (_dystack pid=27764) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=27764) 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=27764) 	Stage 2 Generators:
# (_dystack pid=27764) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=27764) 	Stage 3 Generators:
# (_dystack pid=27764) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=27764) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=27764) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=27764) 	Stage 4 Generators:
# (_dystack pid=27764) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=27764) 	Stage 5 Generators:
# (_dystack pid=27764) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=27764) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=27764) 		('float', [])  : 3 | ['age', 'avg_glucose_level', 'bmi']
# (_dystack pid=27764) 		('int', [])    : 2 | ['hypertension', 'heart_disease']
# (_dystack pid=27764) 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# (_dystack pid=27764) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=27764) 		('category', [])  : 2 | ['work_type', 'smoking_status']
# (_dystack pid=27764) 		('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# (_dystack pid=27764) 		('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# (_dystack pid=27764) 	0.0s = Fit runtime
# (_dystack pid=27764) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=27764) 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=27764) Data preprocessing and feature engineering runtime = 0.06s ...
# (_dystack pid=27764) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=27764) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=27764) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=27764) User-specified model hyperparameters to be fit:
# (_dystack pid=27764) {
# (_dystack pid=27764) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=27764) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=27764) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=27764) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=27764) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=27764) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=27764) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=27764) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=27764) }
# (_dystack pid=27764) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=27764) Fitting 110 L1 models ...
# (_dystack pid=27764) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 146.21s of the 219.36s of remaining time.
# (_dystack pid=27764) 	0.9516	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.0s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 143.96s of the 217.1s of remaining time.
# (_dystack pid=27764) 	0.9512	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.0s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 143.9s of the 217.04s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_dystack pid=27764) 	0.9578	 = Validation score   (accuracy)
# (_dystack pid=27764) 	1.36s	 = Training   runtime
# (_dystack pid=27764) 	0.04s	 = Validation runtime
# (_dystack pid=27764) Fitting model: LightGBM_BAG_L1 ... Training model for up to 139.04s of the 212.19s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_dystack pid=27764) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=27764) 	1.13s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 134.23s of the 207.38s of remaining time.
# (_dystack pid=27764) 	0.956	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.9s	 = Training   runtime
# (_dystack pid=27764) 	0.11s	 = Validation runtime
# (_dystack pid=27764) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 133.17s of the 206.32s of remaining time.
# (_dystack pid=27764) 	0.9556	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.64s	 = Training   runtime
# (_dystack pid=27764) 	0.11s	 = Validation runtime
# (_dystack pid=27764) Fitting model: CatBoost_BAG_L1 ... Training model for up to 132.36s of the 205.51s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	23.42s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 105.56s of the 178.71s of remaining time.
# (_dystack pid=27764) 	0.9541	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.73s	 = Training   runtime
# (_dystack pid=27764) 	0.14s	 = Validation runtime
# (_dystack pid=27764) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 104.64s of the 177.78s of remaining time.
# (_dystack pid=27764) 	0.9556	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.66s	 = Training   runtime
# (_dystack pid=27764) 	0.12s	 = Validation runtime
# (_dystack pid=27764) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 103.81s of the 176.96s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=27764) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=27764) 	9.94s	 = Training   runtime
# (_dystack pid=27764) 	0.23s	 = Validation runtime
# (_dystack pid=27764) Fitting model: XGBoost_BAG_L1 ... Training model for up to 89.96s of the 163.11s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_dystack pid=27764) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=27764) 	1.42s	 = Training   runtime
# (_dystack pid=27764) 	0.08s	 = Validation runtime
# (_dystack pid=27764) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 83.98s of the 157.13s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=17152) Stack (most recent call first):
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17152)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=17152)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=27764) 	0.956	 = Validation score   (accuracy)
# (_dystack pid=27764) 	33.63s	 = Training   runtime
# (_dystack pid=27764) 	0.09s	 = Validation runtime
# (_dystack pid=27764) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 46.4s of the 119.55s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=7128) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=7128)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	3.12s	 = Training   runtime
# (_dystack pid=27764) 	0.04s	 = Validation runtime
# (_dystack pid=27764) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 39.37s of the 112.52s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	2.51s	 = Training   runtime
# (_dystack pid=27764) 	0.02s	 = Validation runtime
# (_dystack pid=27764) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 33.14s of the 106.29s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=27536) Stack (most recent call first):
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27536)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=27536)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=27764) 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# (_ray_fit pid=7268) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=7268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=27764) Fitting model: WeightedEnsemble_L2 ... Training model for up to 219.37s of the 69.43s of remaining time.
# (_dystack pid=27764) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=27764) 	0.9578	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.17s	 = Training   runtime
# (_dystack pid=27764) 	0.0s	 = Validation runtime
# (_dystack pid=27764) Fitting 108 L2 models ...
# (_dystack pid=27764) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 69.26s of the 69.2s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=27764) 	0.9582	 = Validation score   (accuracy)
# (_dystack pid=27764) 	1.55s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: LightGBM_BAG_L2 ... Training model for up to 64.22s of the 64.15s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_dystack pid=27764) 	0.9574	 = Validation score   (accuracy)
# (_dystack pid=27764) 	1.78s	 = Training   runtime
# (_dystack pid=27764) 	0.04s	 = Validation runtime
# (_dystack pid=27764) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 58.7s of the 58.64s of remaining time.
# (_dystack pid=27764) 	0.9563	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.94s	 = Training   runtime
# (_dystack pid=27764) 	0.13s	 = Validation runtime
# (_dystack pid=27764) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 57.6s of the 57.53s of remaining time.
# (_dystack pid=27764) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.65s	 = Training   runtime
# (_dystack pid=27764) 	0.13s	 = Validation runtime
# (_dystack pid=27764) Fitting model: CatBoost_BAG_L2 ... Training model for up to 56.78s of the 56.72s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=27764) 	0.9563	 = Validation score   (accuracy)
# (_dystack pid=27764) 	21.31s	 = Training   runtime
# (_dystack pid=27764) 	0.03s	 = Validation runtime
# (_dystack pid=27764) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 31.71s of the 31.65s of remaining time.
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.63s	 = Training   runtime
# (_dystack pid=27764) 	0.13s	 = Validation runtime
# (_dystack pid=27764) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 30.92s of the 30.86s of remaining time.
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	0.62s	 = Training   runtime
# (_dystack pid=27764) 	0.13s	 = Validation runtime
# (_dystack pid=27764) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 30.14s of the 30.08s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=27764) 	0.9574	 = Validation score   (accuracy)
# (_dystack pid=27764) 	9.04s	 = Training   runtime
# (_dystack pid=27764) 	0.1s	 = Validation runtime
# (_dystack pid=27764) Fitting model: XGBoost_BAG_L2 ... Training model for up to 17.67s of the 17.61s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_dystack pid=27764) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=27764) 	2.2s	 = Training   runtime
# (_dystack pid=27764) 	0.06s	 = Validation runtime
# (_dystack pid=27764) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 11.22s of the 11.15s of remaining time.
# (_dystack pid=27764) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=26508) Stack (most recent call first):
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26508)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=26508)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# ...
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 641.85s of the 641.85s of remaining time.
# 	0.953	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 639.45s of the 639.45s of remaining time.
# 	0.9517	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 639.4s of the 639.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.9573	 = Validation score   (accuracy)
# 	1.84s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 633.88s of the 633.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.9566	 = Validation score   (accuracy)
# 	2.48s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 628.75s of the 628.75s of remaining time.
# 	0.9547	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 627.68s of the 627.68s of remaining time.
# 	0.9553	 = Validation score   (accuracy)
# 	0.63s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 626.9s of the 626.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.9569	 = Validation score   (accuracy)
# 	23.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 600.95s of the 600.94s of remaining time.
# 	0.954	 = Validation score   (accuracy)
# 	0.64s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 600.12s of the 600.12s of remaining time.
# 	0.9543	 = Validation score   (accuracy)
# 	0.61s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 599.34s of the 599.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9553	 = Validation score   (accuracy)
# 	10.39s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 586.27s of the 586.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.9573	 = Validation score   (accuracy)
# 	1.8s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 580.32s of the 580.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.956	 = Validation score   (accuracy)
# 	34.41s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 543.02s of the 543.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9566	 = Validation score   (accuracy)
# 	2.38s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 536.75s of the 536.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.9569	 = Validation score   (accuracy)
# 	4.05s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 529.52s of the 529.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9566	 = Validation score   (accuracy)
# 	35.22s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 491.19s of the 491.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.956	 = Validation score   (accuracy)
# 	2.12s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 486.04s of the 486.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	20.75s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 462.3s of the 462.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	0.9566	 = Validation score   (accuracy)
# 	31.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 428.18s of the 428.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.956	 = Validation score   (accuracy)
# 	2.14s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 423.46s of the 423.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9569	 = Validation score   (accuracy)
# 	41.26s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 379.08s of the 379.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.9569	 = Validation score   (accuracy)
# 	2.26s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 373.57s of the 373.57s of remaining time.
# 	0.9537	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 372.52s of the 372.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9563	 = Validation score   (accuracy)
# 	16.43s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 353.49s of the 353.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	7.38s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 343.15s of the 343.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.9566	 = Validation score   (accuracy)
# 	5.44s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 333.65s of the 333.65s of remaining time.
# 	0.9524	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 332.54s of the 332.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.9569	 = Validation score   (accuracy)
# 	2.39s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 327.15s of the 327.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	18.79s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 305.36s of the 305.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.9573	 = Validation score   (accuracy)
# 	1.96s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 299.72s of the 299.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9563	 = Validation score   (accuracy)
# 	53.88s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 242.53s of the 242.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.9576	 = Validation score   (accuracy)
# 	2.48s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 236.62s of the 236.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9563	 = Validation score   (accuracy)
# 	34.29s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 199.28s of the 199.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9573	 = Validation score   (accuracy)
# 	14.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 182.09s of the 182.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9569	 = Validation score   (accuracy)
# 	21.73s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 157.82s of the 157.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.9573	 = Validation score   (accuracy)
# 	1.92s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 152.81s of the 152.81s of remaining time.
# 	0.956	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 151.87s of the 151.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9569	 = Validation score   (accuracy)
# 	21.21s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 128.07s of the 128.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	13.05s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 112.5s of the 112.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9563	 = Validation score   (accuracy)
# 	31.37s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 78.4s of the 78.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.956	 = Validation score   (accuracy)
# 	3.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 71.15s of the 71.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	7.47s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 61.03s of the 61.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.9573	 = Validation score   (accuracy)
# 	25.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 32.29s of the 32.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9563	 = Validation score   (accuracy)
# 	7.99s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 21.69s of the 21.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.956	 = Validation score   (accuracy)
# 	1.58s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 16.65s of the 16.65s of remaining time.
# 	0.9543	 = Validation score   (accuracy)
# 	0.9s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 15.53s of the 15.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.9573	 = Validation score   (accuracy)
# 	13.45s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -0.97s of remaining time.
# 	Ensemble Weights: {'LightGBM_r130_BAG_L1': 1.0}
# 	0.9576	 = Validation score   (accuracy)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 643.34s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 8026.4 rows/s (384 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/real/v2")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L2   0.957599    accuracy       0.047842   2.815633                0.000000           0.333111            2       True         47
# 1          LightGBM_r130_BAG_L1   0.957599    accuracy       0.047842   2.482522                0.047842           2.482522            1       True         31
# 2          CatBoost_r167_BAG_L1   0.957273    accuracy       0.022014  13.454717                0.022014          13.454717            1       True         46
# 3           CatBoost_r50_BAG_L1   0.957273    accuracy       0.025862  14.646904                0.025862          14.646904            1       True         33
# 4           CatBoost_r70_BAG_L1   0.957273    accuracy       0.027936  25.316712                0.027936          25.316712            1       True         42
# 5           XGBoost_r194_BAG_L1   0.957273    accuracy       0.047917   1.917394                0.047917           1.917394            1       True         35
# 6            XGBoost_r89_BAG_L1   0.957273    accuracy       0.050369   1.957424                0.050369           1.957424            1       True         29
# 7                XGBoost_BAG_L1   0.957273    accuracy       0.054549   1.799565                0.054549           1.799565            1       True         11
# 8             LightGBMXT_BAG_L1   0.957273    accuracy       0.072824   1.835377                0.072824           1.835377            1       True          3
# 9           CatBoost_r69_BAG_L1   0.956947    accuracy       0.015806  21.214081                0.015806          21.214081            1       True         37
# 10              CatBoost_BAG_L1   0.956947    accuracy       0.016646  23.240541                0.016646          23.240541            1       True          7
# 11         CatBoost_r177_BAG_L1   0.956947    accuracy       0.023082   4.054587                0.023082           4.054587            1       True         14
# 12         LightGBM_r188_BAG_L1   0.956947    accuracy       0.039991   2.393146                0.039991           2.393146            1       True         27
# 13           XGBoost_r33_BAG_L1   0.956947    accuracy       0.081943   2.257552                0.081943           2.257552            1       True         21
# 14    NeuralNetTorch_r22_BAG_L1   0.956947    accuracy       0.159820  41.258535                0.159820          41.258535            1       True         20
# 15   NeuralNetFastAI_r11_BAG_L1   0.956947    accuracy       0.222771  21.729237                0.222771          21.729237            1       True         34
# 16           CatBoost_r9_BAG_L1   0.956621    accuracy       0.030594  31.320216                0.030594          31.320216            1       True         18
# 17          CatBoost_r13_BAG_L1   0.956621    accuracy       0.033294   5.444761                0.033294           5.444761            1       True         25
# 18              LightGBM_BAG_L1   0.956621    accuracy       0.035490   2.480857                0.035490           2.480857            1       True          4
# 19         LightGBMLarge_BAG_L1   0.956621    accuracy       0.041568   2.381448                0.041568           2.381448            1       True         13
# 20    NeuralNetTorch_r79_BAG_L1   0.956621    accuracy       0.107784  35.217832                0.107784          35.217832            1       True         15
# 21  NeuralNetFastAI_r143_BAG_L1   0.956621    accuracy       0.119333   7.469856                0.119333           7.469856            1       True         41
# 22  NeuralNetFastAI_r102_BAG_L1   0.956621    accuracy       0.134336   7.376177                0.134336           7.376177            1       True         24
# 23  NeuralNetFastAI_r103_BAG_L1   0.956621    accuracy       0.178927  13.047078                0.178927          13.047078            1       True         38
# 24  NeuralNetFastAI_r191_BAG_L1   0.956621    accuracy       0.197157  20.750089                0.197157          20.750089            1       True         17
# 25  NeuralNetFastAI_r145_BAG_L1   0.956621    accuracy       0.234760  18.786882                0.234760          18.786882            1       True         28
# 26         CatBoost_r137_BAG_L1   0.956295    accuracy       0.020307  16.430430                0.020307          16.430430            1       True         23
# 27  NeuralNetFastAI_r156_BAG_L1   0.956295    accuracy       0.100617   7.986934                0.100617           7.986934            1       True         43
# 28    NeuralNetTorch_r14_BAG_L1   0.956295    accuracy       0.112763  31.369536                0.112763          31.369536            1       True         39
# 29    NeuralNetTorch_r86_BAG_L1   0.956295    accuracy       0.124370  34.294407                0.124370          34.294407            1       True         32
# 30    NeuralNetTorch_r30_BAG_L1   0.956295    accuracy       0.165516  53.882701                0.165516          53.882701            1       True         30
# 31         LightGBM_r161_BAG_L1   0.955969    accuracy       0.013048   3.548269                0.013048           3.548269            1       True         40
# 32          LightGBM_r96_BAG_L1   0.955969    accuracy       0.017167   2.144955                0.017167           2.144955            1       True         19
# 33         LightGBM_r131_BAG_L1   0.955969    accuracy       0.037498   2.119887                0.037498           2.119887            1       True         16
# 34         LightGBM_r196_BAG_L1   0.955969    accuracy       0.039757   1.583412                0.039757           1.583412            1       True         44
# 35       ExtraTrees_r172_BAG_L1   0.955969    accuracy       0.117157   0.764478                0.117157           0.764478            1       True         36
# 36        NeuralNetTorch_BAG_L1   0.955969    accuracy       0.143447  34.410459                0.143447          34.410459            1       True         12
# 37      RandomForestEntr_BAG_L1   0.955316    accuracy       0.110959   0.625150                0.110959           0.625150            1       True          6
# 38       NeuralNetFastAI_BAG_L1   0.955316    accuracy       0.168738  10.390023                0.168738          10.390023            1       True         10
# 39      RandomForestGini_BAG_L1   0.954664    accuracy       0.134330   0.885876                0.134330           0.885876            1       True          5
# 40      RandomForest_r39_BAG_L1   0.954338    accuracy       0.118204   0.895854                0.118204           0.895854            1       True         45
# 41        ExtraTreesEntr_BAG_L1   0.954338    accuracy       0.127923   0.613879                0.127923           0.613879            1       True          9
# 42        ExtraTreesGini_BAG_L1   0.954012    accuracy       0.126427   0.644592                0.126427           0.644592            1       True          8
# 43        ExtraTrees_r42_BAG_L1   0.953686    accuracy       0.127156   0.864105                0.127156           0.864105            1       True         22
# 44        KNeighborsUnif_BAG_L1   0.953033    accuracy       0.028483   0.019715                0.028483           0.019715            1       True          1
# 45     RandomForest_r195_BAG_L1   0.952381    accuracy       0.119380   0.939562                0.119380           0.939562            1       True         26
# 46        KNeighborsDist_BAG_L1   0.951729    accuracy       0.019974   0.011417                0.019974           0.011417            1       True          2
# Number of models trained: 47
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 2 | ['work_type', 'smoking_status']
# ('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# ('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.9530332681017613,
#   'KNeighborsDist_BAG_L1': 0.9517286366601435,
#   'LightGBMXT_BAG_L1': 0.957273320287019,
#   'LightGBM_BAG_L1': 0.95662100456621,
#   'RandomForestGini_BAG_L1': 0.9546640574037835,
#   'RandomForestEntr_BAG_L1': 0.9553163731245923,
#   'CatBoost_BAG_L1': 0.9569471624266145,
#   'ExtraTreesGini_BAG_L1': 0.9540117416829745,
#   'ExtraTreesEntr_BAG_L1': 0.954337899543379,
#   'NeuralNetFastAI_BAG_L1': 0.9553163731245923,
#   'XGBoost_BAG_L1': 0.957273320287019,
#   'NeuralNetTorch_BAG_L1': 0.9559686888454012,
#   'LightGBMLarge_BAG_L1': 0.95662100456621,
#   'CatBoost_r177_BAG_L1': 0.9569471624266145,
#   'NeuralNetTorch_r79_BAG_L1': 0.95662100456621,
#   'LightGBM_r131_BAG_L1': 0.9559686888454012,
#   'NeuralNetFastAI_r191_BAG_L1': 0.95662100456621,
#   'CatBoost_r9_BAG_L1': 0.95662100456621,
#   'LightGBM_r96_BAG_L1': 0.9559686888454012,
#   'NeuralNetTorch_r22_BAG_L1': 0.9569471624266145,
#   'XGBoost_r33_BAG_L1': 0.9569471624266145,
#   'ExtraTrees_r42_BAG_L1': 0.9536855838225701,
#   'CatBoost_r137_BAG_L1': 0.9562948467058056,
#   'NeuralNetFastAI_r102_BAG_L1': 0.95662100456621,
#   'CatBoost_r13_BAG_L1': 0.95662100456621,
#   'RandomForest_r195_BAG_L1': 0.9523809523809523,
#   'LightGBM_r188_BAG_L1': 0.9569471624266145,
#   'NeuralNetFastAI_r145_BAG_L1': 0.95662100456621,
#   'XGBoost_r89_BAG_L1': 0.957273320287019,
#   'NeuralNetTorch_r30_BAG_L1': 0.9562948467058056,
#   'LightGBM_r130_BAG_L1': 0.9575994781474233,
#   'NeuralNetTorch_r86_BAG_L1': 0.9562948467058056,
#   'CatBoost_r50_BAG_L1': 0.957273320287019,
#   'NeuralNetFastAI_r11_BAG_L1': 0.9569471624266145,
#   'XGBoost_r194_BAG_L1': 0.957273320287019,
#   'ExtraTrees_r172_BAG_L1': 0.9559686888454012,
#   'CatBoost_r69_BAG_L1': 0.9569471624266145,
#   'NeuralNetFastAI_r103_BAG_L1': 0.95662100456621,
#   'NeuralNetTorch_r14_BAG_L1': 0.9562948467058056,
#   'LightGBM_r161_BAG_L1': 0.9559686888454012,
#   'NeuralNetFastAI_r143_BAG_L1': 0.95662100456621,
#   'CatBoost_r70_BAG_L1': 0.957273320287019,
#   'NeuralNetFastAI_r156_BAG_L1': 0.9562948467058056,
#   'LightGBM_r196_BAG_L1': 0.9559686888454012,
#   'RandomForest_r39_BAG_L1': 0.954337899543379,
#   'CatBoost_r167_BAG_L1': 0.957273320287019,
#   'WeightedEnsemble_L2': 0.9575994781474233},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.019714832305908203,
#   'KNeighborsDist_BAG_L1': 0.01141667366027832,
#   'LightGBMXT_BAG_L1': 1.8353769779205322,
#   'LightGBM_BAG_L1': 2.4808573722839355,
#   'RandomForestGini_BAG_L1': 0.8858761787414551,
#   'RandomForestEntr_BAG_L1': 0.6251497268676758,
#   'CatBoost_BAG_L1': 23.240540981292725,
#   'ExtraTreesGini_BAG_L1': 0.6445920467376709,
#   'ExtraTreesEntr_BAG_L1': 0.6138792037963867,
#   'NeuralNetFastAI_BAG_L1': 10.39002251625061,
#   'XGBoost_BAG_L1': 1.7995648384094238,
#   'NeuralNetTorch_BAG_L1': 34.41045928001404,
#   'LightGBMLarge_BAG_L1': 2.3814475536346436,
#   'CatBoost_r177_BAG_L1': 4.05458664894104,
#   'NeuralNetTorch_r79_BAG_L1': 35.21783208847046,
#   'LightGBM_r131_BAG_L1': 2.119887351989746,
#   'NeuralNetFastAI_r191_BAG_L1': 20.750088930130005,
#   'CatBoost_r9_BAG_L1': 31.320216417312622,
#   'LightGBM_r96_BAG_L1': 2.1449553966522217,
#   'NeuralNetTorch_r22_BAG_L1': 41.2585346698761,
#   'XGBoost_r33_BAG_L1': 2.257551670074463,
#   'ExtraTrees_r42_BAG_L1': 0.8641045093536377,
#   'CatBoost_r137_BAG_L1': 16.430429697036743,
#   'NeuralNetFastAI_r102_BAG_L1': 7.376176834106445,
#   'CatBoost_r13_BAG_L1': 5.444761037826538,
#   'RandomForest_r195_BAG_L1': 0.9395618438720703,
#   'LightGBM_r188_BAG_L1': 2.3931455612182617,
#   'NeuralNetFastAI_r145_BAG_L1': 18.786881685256958,
#   'XGBoost_r89_BAG_L1': 1.9574239253997803,
#   'NeuralNetTorch_r30_BAG_L1': 53.8827006816864,
#   'LightGBM_r130_BAG_L1': 2.482522487640381,
#   'NeuralNetTorch_r86_BAG_L1': 34.29440665245056,
#   'CatBoost_r50_BAG_L1': 14.64690351486206,
#   'NeuralNetFastAI_r11_BAG_L1': 21.729236841201782,
#   'XGBoost_r194_BAG_L1': 1.9173939228057861,
#   'ExtraTrees_r172_BAG_L1': 0.7644779682159424,
#   'CatBoost_r69_BAG_L1': 21.214081287384033,
#   'NeuralNetFastAI_r103_BAG_L1': 13.047078132629395,
#   'NeuralNetTorch_r14_BAG_L1': 31.36953592300415,
#   'LightGBM_r161_BAG_L1': 3.5482687950134277,
#   'NeuralNetFastAI_r143_BAG_L1': 7.469856023788452,
#   'CatBoost_r70_BAG_L1': 25.31671166419983,
#   'NeuralNetFastAI_r156_BAG_L1': 7.986933946609497,
#   'LightGBM_r196_BAG_L1': 1.5834124088287354,
#   'RandomForest_r39_BAG_L1': 0.8958537578582764,
#   'CatBoost_r167_BAG_L1': 13.454716682434082,
#   'WeightedEnsemble_L2': 0.3331105709075928},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.028482675552368164,
#   'KNeighborsDist_BAG_L1': 0.0199739933013916,
#   'LightGBMXT_BAG_L1': 0.07282376289367676,
#   'LightGBM_BAG_L1': 0.03549027442932129,
#   'RandomForestGini_BAG_L1': 0.13433027267456055,
#   'RandomForestEntr_BAG_L1': 0.11095881462097168,
#   'CatBoost_BAG_L1': 0.016646385192871094,
#   'ExtraTreesGini_BAG_L1': 0.12642717361450195,
#   'ExtraTreesEntr_BAG_L1': 0.12792348861694336,
#   'NeuralNetFastAI_BAG_L1': 0.16873764991760254,
#   'XGBoost_BAG_L1': 0.054549455642700195,
#   'NeuralNetTorch_BAG_L1': 0.1434469223022461,
#   'LightGBMLarge_BAG_L1': 0.04156804084777832,
#   'CatBoost_r177_BAG_L1': 0.02308201789855957,
#   'NeuralNetTorch_r79_BAG_L1': 0.10778355598449707,
#   'LightGBM_r131_BAG_L1': 0.03749847412109375,
#   'NeuralNetFastAI_r191_BAG_L1': 0.1971573829650879,
#   'CatBoost_r9_BAG_L1': 0.0305941104888916,
#   'LightGBM_r96_BAG_L1': 0.017167091369628906,
#   'NeuralNetTorch_r22_BAG_L1': 0.1598198413848877,
#   'XGBoost_r33_BAG_L1': 0.08194327354431152,
#   'ExtraTrees_r42_BAG_L1': 0.12715625762939453,
#   'CatBoost_r137_BAG_L1': 0.020307064056396484,
#   'NeuralNetFastAI_r102_BAG_L1': 0.13433599472045898,
#   'CatBoost_r13_BAG_L1': 0.0332942008972168,
#   'RandomForest_r195_BAG_L1': 0.11938047409057617,
#   'LightGBM_r188_BAG_L1': 0.03999137878417969,
#   'NeuralNetFastAI_r145_BAG_L1': 0.23475956916809082,
#   'XGBoost_r89_BAG_L1': 0.0503690242767334,
#   'NeuralNetTorch_r30_BAG_L1': 0.16551637649536133,
#   'LightGBM_r130_BAG_L1': 0.04784202575683594,
#   'NeuralNetTorch_r86_BAG_L1': 0.12436985969543457,
#   'CatBoost_r50_BAG_L1': 0.02586221694946289,
#   'NeuralNetFastAI_r11_BAG_L1': 0.22277116775512695,
#   'XGBoost_r194_BAG_L1': 0.04791736602783203,
#   'ExtraTrees_r172_BAG_L1': 0.1171567440032959,
#   'CatBoost_r69_BAG_L1': 0.015805721282958984,
#   'NeuralNetFastAI_r103_BAG_L1': 0.17892694473266602,
#   'NeuralNetTorch_r14_BAG_L1': 0.1127634048461914,
#   'LightGBM_r161_BAG_L1': 0.013048410415649414,
#   'NeuralNetFastAI_r143_BAG_L1': 0.11933279037475586,
#   'CatBoost_r70_BAG_L1': 0.027935504913330078,
#   'NeuralNetFastAI_r156_BAG_L1': 0.1006169319152832,
#   'LightGBM_r196_BAG_L1': 0.03975725173950195,
#   'RandomForest_r39_BAG_L1': 0.11820435523986816,
#   'CatBoost_r167_BAG_L1': 0.02201366424560547,
#   'WeightedEnsemble_L2': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.957599    accuracy       0.047842
#  1          LightGBM_r130_BAG_L1   0.957599    accuracy       0.047842
#  2          CatBoost_r167_BAG_L1   0.957273    accuracy       0.022014
#  3           CatBoost_r50_BAG_L1   0.957273    accuracy       0.025862
#  4           CatBoost_r70_BAG_L1   0.957273    accuracy       0.027936
#  5           XGBoost_r194_BAG_L1   0.957273    accuracy       0.047917
#  6            XGBoost_r89_BAG_L1   0.957273    accuracy       0.050369
#  7                XGBoost_BAG_L1   0.957273    accuracy       0.054549
#  8             LightGBMXT_BAG_L1   0.957273    accuracy       0.072824
#  9           CatBoost_r69_BAG_L1   0.956947    accuracy       0.015806
#  10              CatBoost_BAG_L1   0.956947    accuracy       0.016646
#  11         CatBoost_r177_BAG_L1   0.956947    accuracy       0.023082
#  12         LightGBM_r188_BAG_L1   0.956947    accuracy       0.039991
#  13           XGBoost_r33_BAG_L1   0.956947    accuracy       0.081943
#  14    NeuralNetTorch_r22_BAG_L1   0.956947    accuracy       0.159820
#  15   NeuralNetFastAI_r11_BAG_L1   0.956947    accuracy       0.222771
#  16           CatBoost_r9_BAG_L1   0.956621    accuracy       0.030594
#  17          CatBoost_r13_BAG_L1   0.956621    accuracy       0.033294
#  18              LightGBM_BAG_L1   0.956621    accuracy       0.035490
#  19         LightGBMLarge_BAG_L1   0.956621    accuracy       0.041568
#  20    NeuralNetTorch_r79_BAG_L1   0.956621    accuracy       0.107784
#  21  NeuralNetFastAI_r143_BAG_L1   0.956621    accuracy       0.119333
#  22  NeuralNetFastAI_r102_BAG_L1   0.956621    accuracy       0.134336
#  23  NeuralNetFastAI_r103_BAG_L1   0.956621    accuracy       0.178927
#  24  NeuralNetFastAI_r191_BAG_L1   0.956621    accuracy       0.197157
#  25  NeuralNetFastAI_r145_BAG_L1   0.956621    accuracy       0.234760
#  26         CatBoost_r137_BAG_L1   0.956295    accuracy       0.020307
#  27  NeuralNetFastAI_r156_BAG_L1   0.956295    accuracy       0.100617
#  28    NeuralNetTorch_r14_BAG_L1   0.956295    accuracy       0.112763
#  29    NeuralNetTorch_r86_BAG_L1   0.956295    accuracy       0.124370
#  30    NeuralNetTorch_r30_BAG_L1   0.956295    accuracy       0.165516
#  31         LightGBM_r161_BAG_L1   0.955969    accuracy       0.013048
#  32          LightGBM_r96_BAG_L1   0.955969    accuracy       0.017167
#  33         LightGBM_r131_BAG_L1   0.955969    accuracy       0.037498
#  34         LightGBM_r196_BAG_L1   0.955969    accuracy       0.039757
#  35       ExtraTrees_r172_BAG_L1   0.955969    accuracy       0.117157
#  36        NeuralNetTorch_BAG_L1   0.955969    accuracy       0.143447
#  37      RandomForestEntr_BAG_L1   0.955316    accuracy       0.110959
#  38       NeuralNetFastAI_BAG_L1   0.955316    accuracy       0.168738
#  39      RandomForestGini_BAG_L1   0.954664    accuracy       0.134330
#  40      RandomForest_r39_BAG_L1   0.954338    accuracy       0.118204
#  41        ExtraTreesEntr_BAG_L1   0.954338    accuracy       0.127923
#  42        ExtraTreesGini_BAG_L1   0.954012    accuracy       0.126427
#  43        ExtraTrees_r42_BAG_L1   0.953686    accuracy       0.127156
#  44        KNeighborsUnif_BAG_L1   0.953033    accuracy       0.028483
#  45     RandomForest_r195_BAG_L1   0.952381    accuracy       0.119380
#  46        KNeighborsDist_BAG_L1   0.951729    accuracy       0.019974
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    2.815633                0.000000           0.333111            2
#  1    2.482522                0.047842           2.482522            1
#  2   13.454717                0.022014          13.454717            1
#  3   14.646904                0.025862          14.646904            1
#  4   25.316712                0.027936          25.316712            1
#  5    1.917394                0.047917           1.917394            1
#  6    1.957424                0.050369           1.957424            1
#  7    1.799565                0.054549           1.799565            1
#  8    1.835377                0.072824           1.835377            1
#  9   21.214081                0.015806          21.214081            1
#  10  23.240541                0.016646          23.240541            1
#  11   4.054587                0.023082           4.054587            1
#  12   2.393146                0.039991           2.393146            1
#  13   2.257552                0.081943           2.257552            1
#  14  41.258535                0.159820          41.258535            1
#  15  21.729237                0.222771          21.729237            1
#  16  31.320216                0.030594          31.320216            1
#  17   5.444761                0.033294           5.444761            1
#  18   2.480857                0.035490           2.480857            1
#  19   2.381448                0.041568           2.381448            1
#  20  35.217832                0.107784          35.217832            1
#  21   7.469856                0.119333           7.469856            1
#  22   7.376177                0.134336           7.376177            1
#  23  13.047078                0.178927          13.047078            1
#  24  20.750089                0.197157          20.750089            1
#  25  18.786882                0.234760          18.786882            1
#  26  16.430430                0.020307          16.430430            1
#  27   7.986934                0.100617           7.986934            1
#  28  31.369536                0.112763          31.369536            1
#  29  34.294407                0.124370          34.294407            1
#  30  53.882701                0.165516          53.882701            1
#  31   3.548269                0.013048           3.548269            1
#  32   2.144955                0.017167           2.144955            1
#  33   2.119887                0.037498           2.119887            1
#  34   1.583412                0.039757           1.583412            1
#  35   0.764478                0.117157           0.764478            1
#  36  34.410459                0.143447          34.410459            1
#  37   0.625150                0.110959           0.625150            1
#  38  10.390023                0.168738          10.390023            1
#  39   0.885876                0.134330           0.885876            1
#  40   0.895854                0.118204           0.895854            1
#  41   0.613879                0.127923           0.613879            1
#  42   0.644592                0.126427           0.644592            1
#  43   0.864105                0.127156           0.864105            1
#  44   0.019715                0.028483           0.019715            1
#  45   0.939562                0.119380           0.939562            1
#  46   0.011417                0.019974           0.011417            1
#
#      can_infer  fit_order
#  0        True         47
#  1        True         31
#  2        True         46
#  3        True         33
#  4        True         42
#  5        True         35
#  6        True         29
#  7        True         11
#  8        True          3
#  9        True         37
#  10       True          7
#  11       True         14
#  12       True         27
#  13       True         21
#  14       True         20
#  15       True         34
#  16       True         18
#  17       True         25
#  18       True          4
#  19       True         13
#  20       True         15
#  21       True         41
#  22       True         24
#  23       True         38
#  24       True         17
#  25       True         28
#  26       True         23
#  27       True         43
#  28       True         39
#  29       True         32
#  30       True         30
#  31       True         40
#  32       True         19
#  33       True         16
#  34       True         44
#  35       True         36
#  36       True         12
#  37       True          6
#  38       True         10
#  39       True          5
#  40       True         45
#  41       True          9
#  42       True          8
#  43       True         22
#  44       True          1
#  45       True         26
#  46       True          2  }

# %%
predictor.evaluate(df_test)
# Out:
# c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'accuracy': 0.9442270058708415,
#  'balanced_accuracy': 0.5,
#  'mcc': 0.0,
#  'roc_auc': 0.8325606763021544,
#  'f1': 0.0,
#  'precision': 0.0,
#  'recall': 0.0}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                           model  score_test  score_val eval_metric  \
# 0         KNeighborsDist_BAG_L1    1.000000   0.951729    accuracy
# 1      RandomForest_r195_BAG_L1    1.000000   0.952381    accuracy
# 2         ExtraTrees_r42_BAG_L1    1.000000   0.953686    accuracy
# 3       RandomForestGini_BAG_L1    1.000000   0.954664    accuracy
# 4       RandomForestEntr_BAG_L1    1.000000   0.955316    accuracy
# 5         ExtraTreesGini_BAG_L1    1.000000   0.954012    accuracy
# 6         ExtraTreesEntr_BAG_L1    1.000000   0.954338    accuracy
# 7       RandomForest_r39_BAG_L1    0.979778   0.954338    accuracy
# 8            CatBoost_r9_BAG_L1    0.962492   0.956621    accuracy
# 9           CatBoost_r70_BAG_L1    0.961840   0.957273    accuracy
# 10        KNeighborsUnif_BAG_L1    0.960535   0.953033    accuracy
# 11          CatBoost_r13_BAG_L1    0.960535   0.956621    accuracy
# 12         CatBoost_r167_BAG_L1    0.959883   0.957273    accuracy
# 13          CatBoost_r69_BAG_L1    0.957926   0.956947    accuracy
# 14          CatBoost_r50_BAG_L1    0.957926   0.957273    accuracy
# 15         CatBoost_r177_BAG_L1    0.957273   0.956947    accuracy
# 16              CatBoost_BAG_L1    0.957273   0.956947    accuracy
# 17       ExtraTrees_r172_BAG_L1    0.956621   0.955969    accuracy
# 18    NeuralNetTorch_r14_BAG_L1    0.956295   0.956295    accuracy
# 19    NeuralNetTorch_r86_BAG_L1    0.956295   0.956295    accuracy
# 20  NeuralNetFastAI_r156_BAG_L1    0.956295   0.956295    accuracy
# 21    NeuralNetTorch_r22_BAG_L1    0.956295   0.956947    accuracy
# 22          WeightedEnsemble_L2    0.955969   0.957599    accuracy
# 23         LightGBM_r130_BAG_L1    0.955969   0.957599    accuracy
# 24         CatBoost_r137_BAG_L1    0.955969   0.956295    accuracy
# 25          LightGBM_r96_BAG_L1    0.955969   0.955969    accuracy
# 26              LightGBM_BAG_L1    0.955969   0.956621    accuracy
# 27         LightGBM_r196_BAG_L1    0.955969   0.955969    accuracy
# 28         LightGBM_r161_BAG_L1    0.955969   0.955969    accuracy
# 29         LightGBM_r188_BAG_L1    0.955969   0.956947    accuracy
# 30         LightGBMLarge_BAG_L1    0.955969   0.956621    accuracy
# 31         LightGBM_r131_BAG_L1    0.955969   0.955969    accuracy
# 32            LightGBMXT_BAG_L1    0.955969   0.957273    accuracy
# 33          XGBoost_r194_BAG_L1    0.955969   0.957273    accuracy
# 34           XGBoost_r89_BAG_L1    0.955969   0.957273    accuracy
# 35        NeuralNetTorch_BAG_L1    0.955969   0.955969    accuracy
# 36           XGBoost_r33_BAG_L1    0.955969   0.956947    accuracy
# 37               XGBoost_BAG_L1    0.955969   0.957273    accuracy
# 38  NeuralNetFastAI_r102_BAG_L1    0.955969   0.956621    accuracy
# 39    NeuralNetTorch_r79_BAG_L1    0.955969   0.956621    accuracy
# 40  NeuralNetFastAI_r143_BAG_L1    0.955969   0.956621    accuracy
# 41    NeuralNetTorch_r30_BAG_L1    0.955969   0.956295    accuracy
# 42  NeuralNetFastAI_r103_BAG_L1    0.955969   0.956621    accuracy
# 43  NeuralNetFastAI_r191_BAG_L1    0.955969   0.956621    accuracy
# 44       NeuralNetFastAI_BAG_L1    0.955969   0.955316    accuracy
# 45   NeuralNetFastAI_r11_BAG_L1    0.955969   0.956947    accuracy
# 46  NeuralNetFastAI_r145_BAG_L1    0.955969   0.956621    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.030048       0.019974   0.011417                 0.030048
# 1         0.115819       0.119380   0.939562                 0.115819
# 2         0.125780       0.127156   0.864105                 0.125780
# 3         0.142690       0.134330   0.885876                 0.142690
# 4         0.143310       0.110959   0.625150                 0.143310
# 5         0.190141       0.126427   0.644592                 0.190141
# 6         0.190220       0.127923   0.613879                 0.190220
# 7         0.126749       0.118204   0.895854                 0.126749
# 8         0.101517       0.030594  31.320216                 0.101517
# 9         0.113257       0.027936  25.316712                 0.113257
# 10        0.053421       0.028483   0.019715                 0.053421
# 11        0.096534       0.033294   5.444761                 0.096534
# 12        0.073137       0.022014  13.454717                 0.073137
# 13        0.079320       0.015806  21.214081                 0.079320
# 14        0.108499       0.025862  14.646904                 0.108499
# 15        0.098833       0.023082   4.054587                 0.098833
# 16        0.131694       0.016646  23.240541                 0.131694
# 17        0.103713       0.117157   0.764478                 0.103713
# 18        0.222959       0.112763  31.369536                 0.222959
# 19        0.263895       0.124370  34.294407                 0.263895
# 20        0.357337       0.100617   7.986934                 0.357337
# 21        0.442808       0.159820  41.258535                 0.442808
# 22        0.072415       0.047842   2.815633                 0.000000
# 23        0.072415       0.047842   2.482522                 0.072415
# 24        0.078951       0.020307  16.430430                 0.078951
# 25        0.094645       0.017167   2.144955                 0.094645
# 26        0.097471       0.035490   2.480857                 0.097471
# 27        0.107094       0.039757   1.583412                 0.107094
# 28        0.107866       0.013048   3.548269                 0.107866
# 29        0.130220       0.039991   2.393146                 0.130220
# 30        0.144338       0.041568   2.381448                 0.144338
# 31        0.159804       0.037498   2.119887                 0.159804
# 32        0.169326       0.072824   1.835377                 0.169326
# 33        0.254463       0.047917   1.917394                 0.254463
# 34        0.255892       0.050369   1.957424                 0.255892
# 35        0.288064       0.143447  34.410459                 0.288064
# 36        0.288503       0.081943   2.257552                 0.288503
# 37        0.303595       0.054549   1.799565                 0.303595
# 38        0.354091       0.134336   7.376177                 0.354091
# 39        0.391256       0.107784  35.217832                 0.391256
# 40        0.440031       0.119333   7.469856                 0.440031
# 41        0.463290       0.165516  53.882701                 0.463290
# 42        0.615957       0.178927  13.047078                 0.615957
# 43        0.747053       0.197157  20.750089                 0.747053
# 44        0.984598       0.168738  10.390023                 0.984598
# 45        1.009078       0.222771  21.729237                 1.009078
# 46        1.237867       0.234760  18.786882                 1.237867
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.019974           0.011417            1       True
# 1                 0.119380           0.939562            1       True
# 2                 0.127156           0.864105            1       True
# 3                 0.134330           0.885876            1       True
# 4                 0.110959           0.625150            1       True
# 5                 0.126427           0.644592            1       True
# 6                 0.127923           0.613879            1       True
# 7                 0.118204           0.895854            1       True
# 8                 0.030594          31.320216            1       True
# 9                 0.027936          25.316712            1       True
# 10                0.028483           0.019715            1       True
# 11                0.033294           5.444761            1       True
# 12                0.022014          13.454717            1       True
# 13                0.015806          21.214081            1       True
# 14                0.025862          14.646904            1       True
# 15                0.023082           4.054587            1       True
# 16                0.016646          23.240541            1       True
# 17                0.117157           0.764478            1       True
# 18                0.112763          31.369536            1       True
# 19                0.124370          34.294407            1       True
# 20                0.100617           7.986934            1       True
# 21                0.159820          41.258535            1       True
# 22                0.000000           0.333111            2       True
# 23                0.047842           2.482522            1       True
# 24                0.020307          16.430430            1       True
# 25                0.017167           2.144955            1       True
# 26                0.035490           2.480857            1       True
# 27                0.039757           1.583412            1       True
# 28                0.013048           3.548269            1       True
# 29                0.039991           2.393146            1       True
# 30                0.041568           2.381448            1       True
# 31                0.037498           2.119887            1       True
# 32                0.072824           1.835377            1       True
# 33                0.047917           1.917394            1       True
# 34                0.050369           1.957424            1       True
# 35                0.143447          34.410459            1       True
# 36                0.081943           2.257552            1       True
# 37                0.054549           1.799565            1       True
# 38                0.134336           7.376177            1       True
# 39                0.107784          35.217832            1       True
# 40                0.119333           7.469856            1       True
# 41                0.165516          53.882701            1       True
# 42                0.178927          13.047078            1       True
# 43                0.197157          20.750089            1       True
# 44                0.168738          10.390023            1       True
# 45                0.222771          21.729237            1       True
# 46                0.234760          18.786882            1       True
#
#     fit_order
# 0           2
# 1          26
# 2          22
# 3           5
# 4           6
# 5           8
# 6           9
# 7          45
# 8          18
# 9          42
# 10          1
# 11         25
# 12         46
# 13         37
# 14         33
# 15         14
# 16          7
# 17         36
# 18         39
# 19         32
# 20         43
# 21         20
# 22         47
# 23         31
# 24         23
# 25         19
# 26          4
# 27         44
# 28         40
# 29         27
# 30         13
# 31         16
# 32          3
# 33         35
# 34         29
# 35         12
# 36         21
# 37         11
# 38         24
# 39         15
# 40         41
# 41         30
# 42         38
# 43         17
# 44         10
# 45         34
# 46         28

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 3066 rows with 5 shuffle sets...
# 	4.99s	= Expected runtime (1.0s per shuffle set)
# 	2.34s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance  stddev  p_value  n  p99_high  p99_low
# gender                    0.0     0.0      0.5  5       0.0      0.0
# age                       0.0     0.0      0.5  5       0.0      0.0
# hypertension              0.0     0.0      0.5  5       0.0      0.0
# heart_disease             0.0     0.0      0.5  5       0.0      0.0
# ever_married              0.0     0.0      0.5  5       0.0      0.0
# work_type                 0.0     0.0      0.5  5       0.0      0.0
# Residence_type            0.0     0.0      0.5  5       0.0      0.0
# avg_glucose_level         0.0     0.0      0.5  5       0.0      0.0
# bmi                       0.0     0.0      0.5  5       0.0      0.0
# smoking_status            0.0     0.0      0.5  5       0.0      0.0
