# %%
from table_evaluator import load_data, TableEvaluator
import pandas as pd

# %%
df = pd.read_csv('../data/tlp/preprocesado.csv')

# %%
synthetic_data = pd.read_csv('../data/tlp/synthetic-smote.csv').tail(314)

# %%
cat_cols = df.select_dtypes(include='object').columns.to_list()

# %%
evaluator = TableEvaluator(df, synthetic_data, cat_cols=cat_cols)

# %%
evaluator.evaluate(target_col='clin-reservaCognitiva_total', notebook=False, verbose=False)
# Out:
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Adding column demo-fechaEvaluacion_65 with all 0s
# Adding column demo-fechaEvaluacion_66 with all 0s
# ...

# %%
table_evaluator.evaluate(target_col='trans_type')
