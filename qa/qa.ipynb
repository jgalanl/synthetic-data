# %%
from table_evaluator import load_data, TableEvaluator

# %%
table_evaluator = TableEvaluator(df, gc_synthetic_data)

# %%
table_evaluator.visual_evaluation()
# Out:
# Error while plotting column demo-genero
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[72], line 1
#
# ----> 1 table_evaluator.visual_evaluation()
#
#
#
# File c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\table_evaluator\table_evaluator.py:528, in TableEvaluator.visual_evaluation(self, save_dir, show, **kwargs)
#
#     526 if save_dir is None:
#
#     527     self.plot_mean_std(show=show)
#
# --> 528     self.plot_cumsums(show=show)
#
#     529     self.plot_distributions(show=show)
#
#     530     self.plot_correlation_difference(show=show, **kwargs)
#
#
#
# File c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\table_evaluator\table_evaluator.py:187, in TableEvaluator.plot_cumsums(self, nr_cols, fname, show)
#
#     185     except Exception as e:
#
#     186         print(f'Error while plotting column {col}')
#
# ...

# %%
table_evaluator.evaluate(target_col='trans_type')
