# %%
import pandas as pd
import json
from sdv.evaluation.single_table import run_diagnostic
from sdv.metadata import Metadata
import matplotlib.pyplot as plt

# %% [markdown]
# #### GaussianCopulaSynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/gc_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/gc/set_{i}.csv'
    )

    report = run_diagnostic(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.99:
        print(f'Warning: Diagnostic score for set {i} is below 0.99')
        print(f'Score: {report.get_score()}')
        break
    fig = report.get_visualization(property_name='Data Validity')
    fig.update_layout(
        title=dict(
            text=f'Diagnostic Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )

    fig.write_image(
        f'diagnostics/gc/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 3338.62it/s]|
# Data Validity Score: 99.93%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 103.76it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.96%
#
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1818.59it/s]|
# Data Validity Score: 99.75%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 308.47it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.88%
#
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 835.80it/s]|
# Data Validity Score: 99.91%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.96%
#
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2222.56it/s]|
# Data Validity Score: 99.77%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 483.44it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.88%
#
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2911.09it/s]|
# Data Validity Score: 99.91%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.96%
#
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2618.66it/s]|
# Data Validity Score: 99.88%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.94%
#
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2221.56it/s]|
# Data Validity Score: 99.88%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 486.01it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.94%
#
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2032.71it/s]|
# Data Validity Score: 99.86%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.93%
#
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2222.80it/s]|
# Data Validity Score: 99.84%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 443.61it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.92%
#
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2045.80it/s]|
# Data Validity Score: 99.82%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 485.96it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.91%

# %% [markdown]
# #### CTGANSynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/ctgan_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/ctgan/set_{i}.csv'
    )

    report = run_diagnostic(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.99:
        print(f'Warning: Diagnostic score for set {i} is below 0.99')
        print(f'Score: {report.get_score()}')
        break
    fig = report.get_visualization(property_name='Data Validity')
    fig.update_layout(
        title=dict(
            text=f'Diagnostic Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )

    fig.write_image(
        f'diagnostics/ctgan/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1877.74it/s]|
# Data Validity Score: 99.7%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.85%
#
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<?, ?it/s]|
# Data Validity Score: 99.65%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 69.26it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.82%
#
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 5204.17it/s]|
# Data Validity Score: 99.24%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 85.45it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.62%
#
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1241.14it/s]|
# Data Validity Score: 98.94%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.47%
#
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 20636.18it/s]|
# Data Validity Score: 98.45%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 490.56it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.22%
#
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1855.85it/s]|
# Data Validity Score: 99.38%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 350.08it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.69%
#
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1921.61it/s]|
# Data Validity Score: 98.82%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.41%
#
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 2260.84it/s]|
# Data Validity Score: 98.85%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 332.59it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.43%
#
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1346.59it/s]|
# Data Validity Score: 98.53%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 500.22it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.27%
#
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<?, ?it/s]|
# Data Validity Score: 99.45%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1596.61it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.73%

# %% [markdown]
# #### CopulaGANSynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/cgan_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/cgan/set_{i}.csv'
    )

    report = run_diagnostic(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.99:
        print(f'Warning: Diagnostic score for set {i} is below 0.99')
        print(f'Score: {report.get_score()}')
        break
    fig = report.get_visualization(property_name='Data Validity')
    fig.update_layout(
        title=dict(
            text=f'Diagnostic Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )

    fig.write_image(
        f'diagnostics/cgan/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1276.63it/s]|
# Data Validity Score: 99.27%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.64%
#
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1206.56it/s]|
# Data Validity Score: 98.92%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.46%
#
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 3094.63it/s]|
# Data Validity Score: 98.39%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.19%
#
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<?, ?it/s]|
# Data Validity Score: 98.14%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 65.51it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.07%
#
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1252.74it/s]|
# Data Validity Score: 99.1%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.55%
#
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<?, ?it/s]|
# Data Validity Score: 99.56%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.78%
#
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 4331.84it/s]|
# Data Validity Score: 99.38%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 97.88it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.69%
#
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1268.39it/s]|
# Data Validity Score: 98.57%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.28%
#
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 1275.00it/s]|
# Data Validity Score: 99.33%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.66%
#
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 20/20 [00:00<00:00, 697.06it/s]|
# Data Validity Score: 98.2%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<?, ?it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.1%
