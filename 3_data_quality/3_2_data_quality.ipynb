# %%
import os
import pandas as pd
import json
from sdv.metadata import Metadata
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import get_column_plot

# %% [markdown]
# #### GaussianCopulaSynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/gc_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/gc/set_{i}.csv'
    )
    report = evaluate_quality(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.85:
        print(f'Warning: Queality score for set {i} is below 0.85')
        print(f'Score: {report.get_score()}')
        break
    print(report.get_properties())
    fig = report.get_visualization(property_name='Column Shapes')
    fig.update_layout(
        title=dict(
            text=f'Quality Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )
    fig.write_image(
        f'quality_reports/gc/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
    os.makedirs(f'quality_reports/gc/set_{i}', exist_ok=True)

    for column_name in metadata.get_column_names():
        fig = get_column_plot(
            real_data=real_data,
            synthetic_data=synthetic_data,
            metadata=metadata,
            column_name=column_name
        )
        fig.update_layout(
            title=f'Quality Report for column {column_name} in set {i}'
        )
        fig.write_image(
            f'quality_reports/gc/set_{i}/column_{column_name}.png',
            width=1200,
            height=800,
            scale=2
        )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 836.27it/s]|
# Column Shapes Score: 84.57%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 197.67it/s]|
# Column Pair Trends Score: 92.09%
#
# Overall Score (Average): 88.33%
#
#              Property     Score
# 0       Column Shapes  0.845745
# 1  Column Pair Trends  0.920895
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 850.37it/s]|
# Column Shapes Score: 83.71%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 225.47it/s]|
# Column Pair Trends Score: 91.96%
#
# Overall Score (Average): 87.83%
#
#              Property     Score
# 0       Column Shapes  0.837057
# 1  Column Pair Trends  0.919601
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 909.20it/s]|
# Column Shapes Score: 84.15%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 223.07it/s]|
# Column Pair Trends Score: 92.01%
#
# Overall Score (Average): 88.08%
#
#              Property     Score
# 0       Column Shapes  0.841489
# 1  Column Pair Trends  0.920071
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 813.74it/s]|
# Column Shapes Score: 84.54%
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning:
#
# ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 200.84it/s]|
# Column Pair Trends Score: 92.32%
#
# Overall Score (Average): 88.43%
#
#              Property     Score
# 0       Column Shapes  0.845390
# 1  Column Pair Trends  0.923211
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 907.88it/s]|
# Column Shapes Score: 82.67%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 203.29it/s]|
# Column Pair Trends Score: 92.28%
#
# Overall Score (Average): 87.48%
#
#              Property     Score
# 0       Column Shapes  0.826678
# 1  Column Pair Trends  0.922844
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 882.42it/s]|
# Column Shapes Score: 82.24%
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning:
#
# ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 210.74it/s]|
# Column Pair Trends Score: 92.34%
#
# Overall Score (Average): 87.29%
#
#              Property     Score
# 0       Column Shapes  0.822438
# 1  Column Pair Trends  0.923434
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 1003.81it/s]|
# Column Shapes Score: 83.78%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 200.98it/s]|
# Column Pair Trends Score: 92.54%
#
# Overall Score (Average): 88.16%
#
#              Property     Score
# 0       Column Shapes  0.837809
# 1  Column Pair Trends  0.925374
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 921.25it/s]|
# Column Shapes Score: 82.88%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 219.05it/s]|
# Column Pair Trends Score: 92.46%
#
# Overall Score (Average): 87.67%
#
#              Property     Score
# 0       Column Shapes  0.828799
# 1  Column Pair Trends  0.924571
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 944.31it/s]|
# Column Shapes Score: 84.12%
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning:
#
# ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 214.98it/s]|
# Column Pair Trends Score: 92.35%
#
# Overall Score (Average): 88.24%
#
#              Property     Score
# 0       Column Shapes  0.841166
# 1  Column Pair Trends  0.923547
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 1753.58it/s]|
# Column Shapes Score: 83.75%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 193.79it/s]|
# Column Pair Trends Score: 92.24%
#
# Overall Score (Average): 87.99%
#
#              Property     Score
# 0       Column Shapes  0.837456
# 1  Column Pair Trends  0.922396

# %% [markdown]
# CTGANSynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/ctgan_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/ctgan/set_{i}.csv'
    )
    report = evaluate_quality(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.85:
        print(f'Warning: Queality score for set {i} is below 0.85')
        print(f'Score: {report.get_score()}')
        break
    print(report.get_properties())
    fig = report.get_visualization(property_name='Column Shapes')
    fig.update_layout(
        title=dict(
            text=f'Quality Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )
    fig.write_image(
        f'quality_reports/ctgan/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
    os.makedirs(f'quality_reports/ctgan/set_{i}', exist_ok=True)

    for column_name in metadata.get_column_names():
        fig = get_column_plot(
            real_data=real_data,
            synthetic_data=synthetic_data,
            metadata=metadata,
            column_name=column_name
        )
        fig.update_layout(
            title=f'Quality Report for column {column_name} in set {i}'
        )
        fig.write_image(
            f'quality_reports/ctgan/set_{i}/column_{column_name}.png',
            width=1200,
            height=800,
            scale=2
        )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 712.08it/s]|
# Column Shapes Score: 85.89%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 203.21it/s]|
# Column Pair Trends Score: 94.32%
#
# Overall Score (Average): 90.1%
#
#              Property     Score
# 0       Column Shapes  0.858930
# 1  Column Pair Trends  0.943168
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 878.66it/s]|
# Column Shapes Score: 86.05%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 217.73it/s]|
# Column Pair Trends Score: 94.68%
#
# Overall Score (Average): 90.37%
#
#              Property     Score
# 0       Column Shapes  0.860524
# 1  Column Pair Trends  0.946828
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 849.60it/s]|
# Column Shapes Score: 86.91%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 218.77it/s]|
# Column Pair Trends Score: 93.67%
#
# Overall Score (Average): 90.29%
#
#              Property     Score
# 0       Column Shapes  0.869064
# 1  Column Pair Trends  0.936675
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 787.43it/s]|
# Column Shapes Score: 85.18%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 218.14it/s]|
# Column Pair Trends Score: 94.14%
#
# Overall Score (Average): 89.66%
#
#              Property     Score
# 0       Column Shapes  0.851844
# 1  Column Pair Trends  0.941350
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 817.52it/s]|
# Column Shapes Score: 87.65%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 202.86it/s]|
# Column Pair Trends Score: 94.55%
#
# Overall Score (Average): 91.1%
#
#              Property     Score
# 0       Column Shapes  0.876547
# 1  Column Pair Trends  0.945505
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 815.62it/s]|
# Column Shapes Score: 86.3%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 214.73it/s]|
# Column Pair Trends Score: 94.8%
#
# Overall Score (Average): 90.55%
#
#              Property     Score
# 0       Column Shapes  0.862996
# 1  Column Pair Trends  0.948031
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 857.40it/s]|
# Column Shapes Score: 86.61%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 213.84it/s]|
# Column Pair Trends Score: 94.78%
#
# Overall Score (Average): 90.69%
#
#              Property     Score
# 0       Column Shapes  0.866058
# 1  Column Pair Trends  0.947752
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 735.33it/s]|
# Column Shapes Score: 87.81%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 217.33it/s]|
# Column Pair Trends Score: 94.51%
#
# Overall Score (Average): 91.16%
#
#              Property     Score
# 0       Column Shapes  0.878106
# 1  Column Pair Trends  0.945122
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 609.11it/s]|
# Column Shapes Score: 84.6%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 217.75it/s]|
# Column Pair Trends Score: 94.57%
#
# Overall Score (Average): 89.59%
#
#              Property     Score
# 0       Column Shapes  0.846006
# 1  Column Pair Trends  0.945716
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 738.75it/s]|
# Column Shapes Score: 83.27%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 219.03it/s]|
# Column Pair Trends Score: 94.67%
#
# Overall Score (Average): 88.97%
#
#              Property     Score
# 0       Column Shapes  0.832704
# 1  Column Pair Trends  0.946680

# %% [markdown]
# #### TVAESynthesizer

# %%
metadata = Metadata.load_from_json(filepath='../2_modeling/tvaes_metadata.json')
for i in range(0, 10):
    print(f'Running diagnostic for set {i}')
    real_data = pd.read_csv(
        f'../data/train/set_{i}.csv'
    )
    synthetic_data = pd.read_csv(
        f'../data/synthetic/tvaes/set_{i}.csv'
    )
    report = evaluate_quality(
        real_data=real_data,
        synthetic_data=synthetic_data,
        metadata=metadata
    )
    if report.get_score() < 0.85:
        print(f'Warning: Queality score for set {i} is below 0.85')
        print(f'Score: {report.get_score()}')
        break
    print(report.get_properties())
    fig = report.get_visualization(property_name='Column Shapes')
    fig.update_layout(
        title=dict(
            text=f'Quality Report for Set {i}',
            x=0.5,
            y=0.95,
            font=dict(
                family='Helvetica, Arial, sans-serif',
                size=24,
                color='black'
            )
        ),
        margin=dict(l=40, r=40, t=80, b=40),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )
    fig.write_image(
        f'quality_reports/tvaes/set_{i}.png',
        width=1200,
        height=800,
        scale=2
    )
    os.makedirs(f'quality_reports/tvaes/set_{i}', exist_ok=True)

    for column_name in metadata.get_column_names():
        fig = get_column_plot(
            real_data=real_data,
            synthetic_data=synthetic_data,
            metadata=metadata,
            column_name=column_name
        )
        fig.update_layout(
            title=f'Quality Report for column {column_name} in set {i}'
        )
        fig.write_image(
            f'quality_reports/tvaes/set_{i}/column_{column_name}.png',
            width=1200,
            height=800,
            scale=2
        )
# Out:
# Running diagnostic for set 0
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 826.82it/s]|
# Column Shapes Score: 86.12%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 210.61it/s]|
# Column Pair Trends Score: 95.72%
#
# Overall Score (Average): 90.92%
#
#              Property     Score
# 0       Column Shapes  0.861184
# 1  Column Pair Trends  0.957175
# Running diagnostic for set 1
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 695.35it/s]|
# Column Shapes Score: 86.57%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 219.47it/s]|
# Column Pair Trends Score: 95.28%
#
# Overall Score (Average): 90.93%
#
#              Property     Score
# 0       Column Shapes  0.865747
# 1  Column Pair Trends  0.952803
# Running diagnostic for set 2
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 728.32it/s]|
# Column Shapes Score: 85.78%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 220.87it/s]|
# Column Pair Trends Score: 95.42%
#
# Overall Score (Average): 90.6%
#
#              Property     Score
# 0       Column Shapes  0.857752
# 1  Column Pair Trends  0.954200
# Running diagnostic for set 3
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 832.64it/s]|
# Column Shapes Score: 86.09%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 226.39it/s]|
# Column Pair Trends Score: 95.63%
#
# Overall Score (Average): 90.86%
#
#              Property     Score
# 0       Column Shapes  0.860944
# 1  Column Pair Trends  0.956333
# Running diagnostic for set 4
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 750.46it/s]|
# Column Shapes Score: 86.01%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 199.52it/s]|
# Column Pair Trends Score: 95.58%
#
# Overall Score (Average): 90.8%
#
#              Property     Score
# 0       Column Shapes  0.860128
# 1  Column Pair Trends  0.955813
# Running diagnostic for set 5
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 698.38it/s]|
# Column Shapes Score: 85.53%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 215.07it/s]|
# Column Pair Trends Score: 95.7%
#
# Overall Score (Average): 90.62%
#
#              Property     Score
# 0       Column Shapes  0.855298
# 1  Column Pair Trends  0.957041
# Running diagnostic for set 6
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 767.45it/s]|
# Column Shapes Score: 86.24%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 223.48it/s]|
# Column Pair Trends Score: 95.88%
#
# Overall Score (Average): 91.06%
#
#              Property     Score
# 0       Column Shapes  0.862446
# 1  Column Pair Trends  0.958754
# Running diagnostic for set 7
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 850.04it/s]|
# Column Shapes Score: 87.38%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 231.41it/s]|
# Column Pair Trends Score: 95.62%
#
# Overall Score (Average): 91.5%
#
#              Property     Score
# 0       Column Shapes  0.873803
# 1  Column Pair Trends  0.956183
# Running diagnostic for set 8
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 849.75it/s]|
# Column Shapes Score: 86.05%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 221.39it/s]|
# Column Pair Trends Score: 95.7%
#
# Overall Score (Average): 90.87%
#
#              Property     Score
# 0       Column Shapes  0.860455
# 1  Column Pair Trends  0.957018
# Running diagnostic for set 9
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 20/20 [00:00<00:00, 867.28it/s]|
# Column Shapes Score: 85.42%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 190/190 [00:00<00:00, 223.61it/s]|
# Column Pair Trends Score: 95.6%
#
# Overall Score (Average): 90.51%
#
#              Property     Score
# 0       Column Shapes  0.854194
# 1  Column Pair Trends  0.955983
