# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, auc

# %%
def pr_auc_Metric(y_true, y_pred):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    score = auc(recall, precision)
    return score

# %%
ag_roc_auc_scorer = make_scorer(
    name='roc_auc',
    score_func=pr_auc_Metric,
    optimum=1,
    greater_is_better=True,
    needs_proba=True
)

# %%
TIME_LIMIT = 2 * 3600

# %%
extra_metrics = ['roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
for i in range(0, 10):
    print(f'Fitting model {i}')
    train_data = pd.read_csv(
        f'../../data/train/set_{i}.csv'
        )

    predictor= TabularPredictor(
        label='ED_2Clases',
        problem_type='binary',
        eval_metric=ag_roc_auc_scorer,
        sample_weight='balance_weight',
        path=f'AutogluonModels/original/v{i}'
    )

    predictor.fit(
        train_data = train_data,
        time_limit = TIME_LIMIT,
        presets = ['high_quality'],
        auto_stack = False,
        excluded_model_types=['KNN', 'LR'],
        num_stack_levels=0,
        num_bag_folds=0,
        verbosity = 2
    )

    df_test = pd.read_csv(
        f'../../data/test/set_{i}.csv'
    )

    predictors = predictor.leaderboard(
        df_test,
        extra_metrics = extra_metrics,
        extra_info=True,
        silent=True
    )
    predictors.to_excel(
        f'../../5_results/5_1_original/predictors_set_{i}.xlsx',
        index=False
    )

    feature_importance = predictor.feature_importance(train_data)
    feature_importance.to_excel(
        f'../../5_results/5_1_original/feature_importance_set_{i}.xlsx',
        index=True
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/original/v0"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       7.24 GB / 15.94 GB (45.4%)
# Disk Space Avail:   78.30 GB / 446.36 GB (17.5%)
# ===================================================
# Presets specified: ['high_quality']
# Fitting model 0
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\4_ml\4_1_original\AutogluonModels\original\v0"
# Train Data Rows:    282
# Train Data Columns: 19
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7429.67 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])   :  3 | ['clin-reservaCognitiva_escolaridad', 'demo-edad', 'demo-genero']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])       :  2 | ['clin-reservaCognitiva_escolaridad', 'demo-edad']
# 		('int', ['bool']) :  1 | ['demo-genero']
# 	0.0s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 225, Val Rows: 57
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ... Training model for up to 7199.94s of the 7199.93s of remaining time.
# 	0.7476	 = Validation score   (roc_auc)
# 	2.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 7197.24s of the 7197.23s of remaining time.
# 	0.7072	 = Validation score   (roc_auc)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 7196.95s of the 7196.94s of remaining time.
# 	0.853	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 7196.26s of the 7196.25s of remaining time.
# 	0.8183	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 7195.68s of the 7195.67s of remaining time.
# 	0.7945	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 7194.76s of the 7194.75s of remaining time.
# 	0.6453	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 7194.18s of the 7194.17s of remaining time.
# 	0.7092	 = Validation score   (roc_auc)
# 	0.5s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 7193.62s of the 7193.61s of remaining time.
# 	0.8032	 = Validation score   (roc_auc)
# 	2.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 7191.53s of the 7191.52s of remaining time.
# 	0.711	 = Validation score   (roc_auc)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 7191.16s of the 7191.15s of remaining time.
# 	0.8179	 = Validation score   (roc_auc)
# 	2.21s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 7188.93s of the 7188.92s of remaining time.
# 	0.7407	 = Validation score   (roc_auc)
# 	0.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r177 ... Training model for up to 7188.50s of the 7188.49s of remaining time.
# 	0.7485	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79 ... Training model for up to 7187.84s of the 7187.84s of remaining time.
# 	0.7446	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r131 ... Training model for up to 7186.97s of the 7186.97s of remaining time.
# 	0.7915	 = Validation score   (roc_auc)
# 	0.5s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191 ... Training model for up to 7186.46s of the 7186.45s of remaining time.
# No improvement since epoch 18: early stopping
# 	0.7228	 = Validation score   (roc_auc)
# 	2.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r9 ... Training model for up to 7183.89s of the 7183.88s of remaining time.
# 	0.766	 = Validation score   (roc_auc)
# 	2.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r96 ... Training model for up to 7181.66s of the 7181.66s of remaining time.
# 	0.7745	 = Validation score   (roc_auc)
# [1000]	valid_set's binary_logloss: 0.381162
# 	0.7s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22 ... Training model for up to 7180.94s of the 7180.93s of remaining time.
# 	0.8188	 = Validation score   (roc_auc)
# 	0.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r33 ... Training model for up to 7180.15s of the 7180.14s of remaining time.
# 	0.7547	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r42 ... Training model for up to 7179.68s of the 7179.68s of remaining time.
# 	0.7198	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r137 ... Training model for up to 7178.98s of the 7178.97s of remaining time.
# 	0.7397	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102 ... Training model for up to 7178.40s of the 7178.39s of remaining time.
# 	0.4724	 = Validation score   (roc_auc)
# 	1.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r13 ... Training model for up to 7176.86s of the 7176.85s of remaining time.
# 	0.7617	 = Validation score   (roc_auc)
# 	1.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r195 ... Training model for up to 7175.00s of the 7174.99s of remaining time.
# 	0.72	 = Validation score   (roc_auc)
# 	0.77s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r188 ... Training model for up to 7174.16s of the 7174.15s of remaining time.
# 	0.7266	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145 ... Training model for up to 7173.79s of the 7173.78s of remaining time.
# 	0.6904	 = Validation score   (roc_auc)
# 	0.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r89 ... Training model for up to 7173.16s of the 7173.15s of remaining time.
# 	0.7319	 = Validation score   (roc_auc)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30 ... Training model for up to 7172.88s of the 7172.87s of remaining time.
# 	0.8318	 = Validation score   (roc_auc)
# 	1.19s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r130 ... Training model for up to 7171.67s of the 7171.66s of remaining time.
# 	0.6651	 = Validation score   (roc_auc)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86 ... Training model for up to 7171.29s of the 7171.28s of remaining time.
# 	0.8742	 = Validation score   (roc_auc)
# 	0.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r50 ... Training model for up to 7170.51s of the 7170.50s of remaining time.
# 	0.7734	 = Validation score   (roc_auc)
# 	0.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11 ... Training model for up to 7169.93s of the 7169.91s of remaining time.
# No improvement since epoch 0: early stopping
# 	0.7411	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r194 ... Training model for up to 7169.55s of the 7169.54s of remaining time.
# 	0.7347	 = Validation score   (roc_auc)
# 	0.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r172 ... Training model for up to 7169.19s of the 7169.18s of remaining time.
# 	0.7758	 = Validation score   (roc_auc)
# 	0.5s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r69 ... Training model for up to 7168.63s of the 7168.62s of remaining time.
# 	0.7589	 = Validation score   (roc_auc)
# 	0.59s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103 ... Training model for up to 7168.03s of the 7168.02s of remaining time.
# No improvement since epoch 18: early stopping
# 	0.6216	 = Validation score   (roc_auc)
# 	1.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14 ... Training model for up to 7166.04s of the 7166.04s of remaining time.
# 	0.7463	 = Validation score   (roc_auc)
# 	0.42s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r161 ... Training model for up to 7165.61s of the 7165.60s of remaining time.
# 	0.8308	 = Validation score   (roc_auc)
# 	0.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143 ... Training model for up to 7165.01s of the 7165.00s of remaining time.
# 	0.6913	 = Validation score   (roc_auc)
# 	2.26s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r70 ... Training model for up to 7162.71s of the 7162.70s of remaining time.
# 	0.7014	 = Validation score   (roc_auc)
# 	1.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156 ... Training model for up to 7161.64s of the 7161.63s of remaining time.
# No improvement since epoch 18: early stopping
# 	0.8243	 = Validation score   (roc_auc)
# 	2.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r196 ... Training model for up to 7159.59s of the 7159.58s of remaining time.
# [1000]	valid_set's binary_logloss: 0.334751
# [2000]	valid_set's binary_logloss: 0.30174
# [3000]	valid_set's binary_logloss: 0.298938
# 	0.7474	 = Validation score   (roc_auc)
# 	2.25s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r39 ... Training model for up to 7157.23s of the 7157.22s of remaining time.
# 	0.789	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r167 ... Training model for up to 7156.53s of the 7156.52s of remaining time.
# 	0.772	 = Validation score   (roc_auc)
# 	1.75s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95 ... Training model for up to 7154.76s of the 7154.75s of remaining time.
# 	0.6492	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41 ... Training model for up to 7154.06s of the 7154.05s of remaining time.
# 	0.8585	 = Validation score   (roc_auc)
# 	0.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r98 ... Training model for up to 7153.42s of the 7153.41s of remaining time.
# 	0.7786	 = Validation score   (roc_auc)
# 	1.56s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r15 ... Training model for up to 7151.82s of the 7151.81s of remaining time.
# 	0.6865	 = Validation score   (roc_auc)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158 ... Training model for up to 7151.33s of the 7151.32s of remaining time.
# 	0.8032	 = Validation score   (roc_auc)
# 	1.94s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r86 ... Training model for up to 7149.37s of the 7149.36s of remaining time.
# 	0.7209	 = Validation score   (roc_auc)
# 	1.71s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37 ... Training model for up to 7147.65s of the 7147.64s of remaining time.
# 	0.5914	 = Validation score   (roc_auc)
# 	3.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197 ... Training model for up to 7144.52s of the 7144.51s of remaining time.
# 	0.853	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r49 ... Training model for up to 7144.14s of the 7144.14s of remaining time.
# 	0.7575	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r49 ... Training model for up to 7143.43s of the 7143.42s of remaining time.
# 	0.6453	 = Validation score   (roc_auc)
# 	0.75s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r143 ... Training model for up to 7142.62s of the 7142.62s of remaining time.
# 	0.743	 = Validation score   (roc_auc)
# 	0.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r127 ... Training model for up to 7142.00s of the 7142.00s of remaining time.
# 	0.7721	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134 ... Training model for up to 7141.06s of the 7141.05s of remaining time.
# No improvement since epoch 12: early stopping
# 	0.7731	 = Validation score   (roc_auc)
# 	2.49s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r34 ... Training model for up to 7138.54s of the 7138.53s of remaining time.
# 	0.8121	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r94 ... Training model for up to 7137.75s of the 7137.74s of remaining time.
# [1000]	valid_set's binary_logloss: 0.334251
# 	0.7589	 = Validation score   (roc_auc)
# 	1.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143 ... Training model for up to 7136.54s of the 7136.54s of remaining time.
# 	0.8228	 = Validation score   (roc_auc)
# 	2.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r128 ... Training model for up to 7134.22s of the 7134.21s of remaining time.
# 	0.7293	 = Validation score   (roc_auc)
# 	3.29s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111 ... Training model for up to 7130.91s of the 7130.90s of remaining time.
# 	0.5815	 = Validation score   (roc_auc)
# 	1.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31 ... Training model for up to 7129.28s of the 7129.27s of remaining time.
# 	0.8312	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r4 ... Training model for up to 7128.74s of the 7128.73s of remaining time.
# 	0.8569	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65 ... Training model for up to 7128.00s of the 7127.99s of remaining time.
# 	0.6202	 = Validation score   (roc_auc)
# 	2.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88 ... Training model for up to 7125.65s of the 7125.64s of remaining time.
# No improvement since epoch 2: early stopping
# 	0.6015	 = Validation score   (roc_auc)
# 	1.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r30 ... Training model for up to 7124.15s of the 7124.14s of remaining time.
# [1000]	valid_set's binary_logloss: 0.325656
# 	0.762	 = Validation score   (roc_auc)
# 	1.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r49 ... Training model for up to 7122.73s of the 7122.72s of remaining time.
# 	0.7527	 = Validation score   (roc_auc)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r5 ... Training model for up to 7122.27s of the 7122.26s of remaining time.
# 	0.7238	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87 ... Training model for up to 7121.47s of the 7121.46s of remaining time.
# 	0.8893	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71 ... Training model for up to 7120.82s of the 7120.81s of remaining time.
# 	0.8441	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r143 ... Training model for up to 7120.49s of the 7120.48s of remaining time.
# 	0.6578	 = Validation score   (roc_auc)
# 	0.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r178 ... Training model for up to 7119.51s of the 7119.49s of remaining time.
# 	0.7966	 = Validation score   (roc_auc)
# 	0.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForest_r166 ... Training model for up to 7118.67s of the 7118.67s of remaining time.
# 	0.853	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_r31 ... Training model for up to 7117.74s of the 7117.73s of remaining time.
# 	0.7998	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185 ... Training model for up to 7116.79s of the 7116.78s of remaining time.
# 	0.8213	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160 ... Training model for up to 7115.84s of the 7115.83s of remaining time.
# 	0.4486	 = Validation score   (roc_auc)
# 	0.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r60 ... Training model for up to 7115.32s of the 7115.32s of remaining time.
# 	0.7616	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r15 ... Training model for up to 7114.46s of the 7114.45s of remaining time.
# 	0.7718	 = Validation score   (roc_auc)
# 	0.82s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r135 ... Training model for up to 7113.57s of the 7113.56s of remaining time.
# 	0.7229	 = Validation score   (roc_auc)
# 	0.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r22 ... Training model for up to 7113.09s of the 7113.08s of remaining time.
# 	0.7978	 = Validation score   (roc_auc)
# 	0.38s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69 ... Training model for up to 7112.69s of the 7112.68s of remaining time.
# 	0.7569	 = Validation score   (roc_auc)
# 	0.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r6 ... Training model for up to 7112.18s of the 7112.17s of remaining time.
# 	0.7034	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138 ... Training model for up to 7111.39s of the 7111.38s of remaining time.
# No improvement since epoch 18: early stopping
# 	0.7079	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r121 ... Training model for up to 7110.49s of the 7110.48s of remaining time.
# 	0.808	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172 ... Training model for up to 7109.83s of the 7109.83s of remaining time.
# 	0.8388	 = Validation score   (roc_auc)
# 	1.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r180 ... Training model for up to 7107.98s of the 7107.97s of remaining time.
# 	0.7394	 = Validation score   (roc_auc)
# 	2.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76 ... Training model for up to 7105.78s of the 7105.78s of remaining time.
# 	0.8384	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r197 ... Training model for up to 7105.45s of the 7105.45s of remaining time.
# 	0.7133	 = Validation score   (roc_auc)
# 	0.96s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121 ... Training model for up to 7104.39s of the 7104.39s of remaining time.
# 	0.8739	 = Validation score   (roc_auc)
# 	1.14s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127 ... Training model for up to 7103.23s of the 7103.22s of remaining time.
# 	0.6982	 = Validation score   (roc_auc)
# 	1.78s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r16 ... Training model for up to 7101.41s of the 7101.40s of remaining time.
# 	0.6723	 = Validation score   (roc_auc)
# 	1.03s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194 ... Training model for up to 7100.32s of the 7100.31s of remaining time.
# 	0.8481	 = Validation score   (roc_auc)
# 	1.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r12 ... Training model for up to 7098.60s of the 7098.59s of remaining time.
# 	0.7513	 = Validation score   (roc_auc)
# 	1.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135 ... Training model for up to 7097.08s of the 7097.07s of remaining time.
# 	0.821	 = Validation score   (roc_auc)
# 	2.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4 ... Training model for up to 7094.79s of the 7094.79s of remaining time.
# No improvement since epoch 16: early stopping
# 	0.7811	 = Validation score   (roc_auc)
# 	2.33s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r126 ... Training model for up to 7092.44s of the 7092.43s of remaining time.
# 	0.6652	 = Validation score   (roc_auc)
# 	0.72s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36 ... Training model for up to 7091.65s of the 7091.64s of remaining time.
# 	0.7563	 = Validation score   (roc_auc)
# 	6.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100 ... Training model for up to 7085.15s of the 7085.14s of remaining time.
# 	0.6668	 = Validation score   (roc_auc)
# 	3.12s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r163 ... Training model for up to 7082.00s of the 7082.00s of remaining time.
# 	0.7934	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r198 ... Training model for up to 7081.33s of the 7081.32s of remaining time.
# 	0.7656	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187 ... Training model for up to 7080.44s of the 7080.43s of remaining time.
# No improvement since epoch 16: early stopping
# 	0.8039	 = Validation score   (roc_auc)
# 	2.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19 ... Training model for up to 7077.73s of the 7077.72s of remaining time.
# 	0.8205	 = Validation score   (roc_auc)
# 	0.36s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r95 ... Training model for up to 7077.35s of the 7077.34s of remaining time.
# 	0.7418	 = Validation score   (roc_auc)
# 	0.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r34 ... Training model for up to 7076.92s of the 7076.91s of remaining time.
# 	0.8308	 = Validation score   (roc_auc)
# 	0.61s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r42 ... Training model for up to 7076.28s of the 7076.28s of remaining time.
# 	0.798	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1 ... Training model for up to 7075.63s of the 7075.62s of remaining time.
# 	0.897	 = Validation score   (roc_auc)
# 	1.87s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89 ... Training model for up to 7073.73s of the 7073.73s of remaining time.
# 	0.8219	 = Validation score   (roc_auc)
# 	0.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 719.99s of the 7072.67s of remaining time.
# 	Ensemble Weights: {'ExtraTrees_r4': 0.375, 'CatBoost': 0.25, 'NeuralNetTorch_r1': 0.25, 'RandomForestGini': 0.125}
# 	0.9562	 = Validation score   (roc_auc)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 127.51s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 553.9 rows/s (57 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_FULL ...
# 	0.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestGini_FULL ...
# 	0.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestEntr_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesGini_FULL ...
# 	0.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesEntr_FULL ...
# 	0.58s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_FULL ...
# 	0.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_FULL ...
# 	0.22s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_FULL ...
# 	0.69s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r42_FULL ...
# 	0.57s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_FULL ...
# 	0.09s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	1.03s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_FULL ...
# 	1.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r195_FULL ...
# 	0.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_FULL ...
# 	0.19s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	0.7s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_FULL ...
# 	0.12s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_FULL ...
# 	0.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r172_FULL ...
# 	0.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_FULL ...
# 	0.09s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	0.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_FULL ...
# 	0.35s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_FULL ...
# 	Stopping at the best epoch learned earlier - 20.
# 	1.97s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_FULL ...
# 	0.31s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	1.33s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_FULL ...
# 	0.82s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r39_FULL ...
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_FULL ...
# 	1.21s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_FULL ...
# 	0.58s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_FULL ...
# 	0.19s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_FULL ...
# 	0.84s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_FULL ...
# 	0.6s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_FULL ...
# 	Stopping at the best epoch learned earlier - 21.
# 	1.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_FULL ...
# 	0.06s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r49_FULL ...
# 	0.73s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r127_FULL ...
# 	0.93s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	1.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r34_FULL ...
# 	0.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_FULL ...
# 	0.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_FULL ...
# 	0.78s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	1.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r4_FULL ...
# 	0.65s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_FULL ...
# 	Stopping at the best epoch learned earlier - 37.
# 	2.32s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_FULL ...
# 	0.47s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_FULL ...
# 	0.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_FULL ...
# 	0.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r178_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r166_FULL ...
# 	0.88s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_FULL ...
# 	0.12s	 = Training   runtime
# ...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Computing feature importance via permutation shuffling for 19 features using 283 rows with 5 shuffle sets...
# 	2.38s	= Expected runtime (0.48s per shuffle set)
# 	0.48s	= Actual runtime (Completed 5 of 5 shuffle sets)
