# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, auc

# %%
def pr_auc_Metric(y_true, y_pred):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    score = auc(recall, precision)
    return score

# %%
ag_roc_auc_scorer = make_scorer(
    name='roc_auc',
    score_func=pr_auc_Metric,
    optimum=1,
    greater_is_better=True,
    needs_proba=True
)

# %%
TIME_LIMIT = 2 * 3600

# %%
extra_metrics = ['roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
generator = 'cgan'

# %%
for i in range(0, 10):
    print(f'Fitting model {i}')
    train_data = pd.read_csv(
        f'../../data/synthetic/{generator}/set_{i}.csv'
        )

    predictor= TabularPredictor(
        label='ED_2Clases',
        problem_type='binary',
        eval_metric=ag_roc_auc_scorer,
        sample_weight='balance_weight',
        path=f'AutogluonModels/{generator}/v{i}'
    )

    predictor.fit(
        train_data = train_data,
        time_limit = TIME_LIMIT,
        presets = ['high_quality'],
        auto_stack = False,
        excluded_model_types=['KNN', 'LR'],
        num_stack_levels=0,
        num_bag_folds=0,
        verbosity = 2
    )

    df_test = pd.read_csv(
        f'../../data/test/set_{i}.csv'
    )

    predictors = predictor.leaderboard(
        df_test,
        extra_metrics = extra_metrics,
        extra_info=True,
        silent=True
    )
    predictors.to_excel(
        f'../../5_results/5_2_synthetic/{generator}/predictors_set_{i}.xlsx',
        index=False
    )

    feature_importance = predictor.feature_importance(train_data)
    feature_importance.to_excel(
        f'../../5_results/5_2_synthetic/{generator}/feature_importance_set_{i}.xlsx',
        index=True
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/cgan/v0"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       6.70 GB / 15.94 GB (42.0%)
# Disk Space Avail:   73.16 GB / 446.36 GB (16.4%)
# ===================================================
# Presets specified: ['high_quality']
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\4_ml\4_2_synthetic\AutogluonModels\cgan\v0"
# Train Data Rows:    282
# Train Data Columns: 19
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6858.82 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])   :  3 | ['clin-reservaCognitiva_escolaridad', 'demo-edad', 'demo-genero']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])       :  2 | ['clin-reservaCognitiva_escolaridad', 'demo-edad']
# 		('int', ['bool']) :  1 | ['demo-genero']
# 	0.0s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 225, Val Rows: 57
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ... Training model for up to 7199.92s of the 7199.91s of remaining time.
# Fitting model 0
# 	0.9674	 = Validation score   (roc_auc)
# 	0.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 7199.30s of the 7199.29s of remaining time.
# 	0.9577	 = Validation score   (roc_auc)
# 	0.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 7198.83s of the 7198.82s of remaining time.
# 	0.9625	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 7198.08s of the 7198.07s of remaining time.
# 	0.9651	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 7197.36s of the 7197.35s of remaining time.
# 	0.9562	 = Validation score   (roc_auc)
# 	1.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 7195.70s of the 7195.69s of remaining time.
# 	0.9631	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 7194.97s of the 7194.96s of remaining time.
# 	0.958	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 7194.21s of the 7194.20s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.9401	 = Validation score   (roc_auc)
# 	1.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 7192.67s of the 7192.66s of remaining time.
# 	0.9568	 = Validation score   (roc_auc)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 7192.27s of the 7192.26s of remaining time.
# 	0.9531	 = Validation score   (roc_auc)
# 	1.36s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 7190.89s of the 7190.88s of remaining time.
# 	0.9619	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r177 ... Training model for up to 7190.22s of the 7190.21s of remaining time.
# 	0.9616	 = Validation score   (roc_auc)
# 	1.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79 ... Training model for up to 7188.95s of the 7188.94s of remaining time.
# 	0.9585	 = Validation score   (roc_auc)
# 	1.14s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r131 ... Training model for up to 7187.78s of the 7187.77s of remaining time.
# 	0.9568	 = Validation score   (roc_auc)
# 	0.76s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191 ... Training model for up to 7187.00s of the 7186.99s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.9406	 = Validation score   (roc_auc)
# 	1.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r9 ... Training model for up to 7185.28s of the 7185.27s of remaining time.
# 	0.9569	 = Validation score   (roc_auc)
# 	7.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r96 ... Training model for up to 7177.65s of the 7177.64s of remaining time.
# [1000]	valid_set's binary_logloss: 0.46685
# 	0.9512	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22 ... Training model for up to 7176.66s of the 7176.65s of remaining time.
# 	0.9682	 = Validation score   (roc_auc)
# 	1.4s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r33 ... Training model for up to 7175.24s of the 7175.23s of remaining time.
# 	0.9497	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r42 ... Training model for up to 7174.37s of the 7174.36s of remaining time.
# 	0.9657	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r137 ... Training model for up to 7173.60s of the 7173.59s of remaining time.
# 	0.9571	 = Validation score   (roc_auc)
# 	1.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102 ... Training model for up to 7172.29s of the 7172.28s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.957	 = Validation score   (roc_auc)
# 	1.39s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r13 ... Training model for up to 7170.87s of the 7170.86s of remaining time.
# 	0.9505	 = Validation score   (roc_auc)
# 	7.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r195 ... Training model for up to 7163.38s of the 7163.37s of remaining time.
# 	0.9582	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r188 ... Training model for up to 7162.34s of the 7162.33s of remaining time.
# 	0.9707	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145 ... Training model for up to 7161.58s of the 7161.57s of remaining time.
# No improvement since epoch 8: early stopping
# 	0.884	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r89 ... Training model for up to 7160.91s of the 7160.90s of remaining time.
# 	0.9359	 = Validation score   (roc_auc)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30 ... Training model for up to 7160.49s of the 7160.48s of remaining time.
# 	0.9683	 = Validation score   (roc_auc)
# 	3.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r130 ... Training model for up to 7157.46s of the 7157.45s of remaining time.
# 	0.9613	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86 ... Training model for up to 7156.73s of the 7156.72s of remaining time.
# 	0.9456	 = Validation score   (roc_auc)
# 	1.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r50 ... Training model for up to 7155.64s of the 7155.62s of remaining time.
# 	0.9617	 = Validation score   (roc_auc)
# 	0.98s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11 ... Training model for up to 7154.63s of the 7154.62s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.9335	 = Validation score   (roc_auc)
# 	0.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r194 ... Training model for up to 7154.15s of the 7154.14s of remaining time.
# 	0.9516	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r172 ... Training model for up to 7153.68s of the 7153.67s of remaining time.
# 	0.9662	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r69 ... Training model for up to 7152.98s of the 7152.97s of remaining time.
# 	0.9508	 = Validation score   (roc_auc)
# 	0.99s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103 ... Training model for up to 7151.98s of the 7151.97s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.9585	 = Validation score   (roc_auc)
# 	1.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14 ... Training model for up to 7150.42s of the 7150.41s of remaining time.
# 	0.9488	 = Validation score   (roc_auc)
# 	0.56s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r161 ... Training model for up to 7149.85s of the 7149.83s of remaining time.
# 	0.9519	 = Validation score   (roc_auc)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143 ... Training model for up to 7149.13s of the 7149.12s of remaining time.
# No improvement since epoch 10: early stopping
# 	0.9732	 = Validation score   (roc_auc)
# 	2.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r70 ... Training model for up to 7146.79s of the 7146.78s of remaining time.
# 	0.9539	 = Validation score   (roc_auc)
# 	2.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156 ... Training model for up to 7144.27s of the 7144.26s of remaining time.
# No improvement since epoch 7: early stopping
# 	0.9588	 = Validation score   (roc_auc)
# 	1.65s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r196 ... Training model for up to 7142.59s of the 7142.58s of remaining time.
# [1000]	valid_set's binary_logloss: 0.359708
# [2000]	valid_set's binary_logloss: 0.355408
# 	0.9655	 = Validation score   (roc_auc)
# 	2.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r39 ... Training model for up to 7140.51s of the 7140.49s of remaining time.
# 	0.9553	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r167 ... Training model for up to 7139.68s of the 7139.67s of remaining time.
# 	0.9539	 = Validation score   (roc_auc)
# 	2.61s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95 ... Training model for up to 7137.05s of the 7137.04s of remaining time.
# No improvement since epoch 5: early stopping
# 	0.8674	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41 ... Training model for up to 7136.58s of the 7136.57s of remaining time.
# 	0.9538	 = Validation score   (roc_auc)
# 	2.17s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r98 ... Training model for up to 7134.39s of the 7134.38s of remaining time.
# 	0.9533	 = Validation score   (roc_auc)
# 	1.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r15 ... Training model for up to 7133.03s of the 7133.02s of remaining time.
# 	0.9544	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158 ... Training model for up to 7132.56s of the 7132.55s of remaining time.
# 	0.9673	 = Validation score   (roc_auc)
# 	3.23s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r86 ... Training model for up to 7129.31s of the 7129.29s of remaining time.
# 	0.9529	 = Validation score   (roc_auc)
# 	5.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37 ... Training model for up to 7124.01s of the 7124.00s of remaining time.
# No improvement since epoch 18: early stopping
# 	0.9337	 = Validation score   (roc_auc)
# 	3.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197 ... Training model for up to 7120.94s of the 7120.93s of remaining time.
# 	0.9678	 = Validation score   (roc_auc)
# 	0.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r49 ... Training model for up to 7120.50s of the 7120.49s of remaining time.
# 	0.9601	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r49 ... Training model for up to 7119.57s of the 7119.56s of remaining time.
# 	0.9631	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r143 ... Training model for up to 7118.81s of the 7118.80s of remaining time.
# 	0.9524	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r127 ... Training model for up to 7118.23s of the 7118.21s of remaining time.
# 	0.9656	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134 ... Training model for up to 7117.27s of the 7117.26s of remaining time.
# No improvement since epoch 6: early stopping
# 	0.9738	 = Validation score   (roc_auc)
# 	2.14s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r34 ... Training model for up to 7115.09s of the 7115.08s of remaining time.
# 	0.9199	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r94 ... Training model for up to 7114.38s of the 7114.37s of remaining time.
# 	0.9529	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143 ... Training model for up to 7113.68s of the 7113.67s of remaining time.
# [1000]	valid_set's binary_logloss: 0.417047
# 	0.9541	 = Validation score   (roc_auc)
# 	1.41s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r128 ... Training model for up to 7112.24s of the 7112.23s of remaining time.
# 	0.9637	 = Validation score   (roc_auc)
# 	6.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111 ... Training model for up to 7105.86s of the 7105.85s of remaining time.
# No improvement since epoch 0: early stopping
# 	0.9572	 = Validation score   (roc_auc)
# 	1.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31 ... Training model for up to 7104.37s of the 7104.36s of remaining time.
# 	0.9712	 = Validation score   (roc_auc)
# 	0.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r4 ... Training model for up to 7103.63s of the 7103.62s of remaining time.
# 	0.9634	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65 ... Training model for up to 7102.91s of the 7102.90s of remaining time.
# 	0.9583	 = Validation score   (roc_auc)
# 	2.4s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88 ... Training model for up to 7100.49s of the 7100.48s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.9701	 = Validation score   (roc_auc)
# 	1.44s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r30 ... Training model for up to 7099.01s of the 7099.00s of remaining time.
# [1000]	valid_set's binary_logloss: 0.356264
# 	0.9663	 = Validation score   (roc_auc)
# 	1.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r49 ... Training model for up to 7097.78s of the 7097.77s of remaining time.
# 	0.9441	 = Validation score   (roc_auc)
# 	0.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r5 ... Training model for up to 7097.20s of the 7097.19s of remaining time.
# 	0.9597	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87 ... Training model for up to 7096.27s of the 7096.25s of remaining time.
# 	0.9576	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71 ... Training model for up to 7095.51s of the 7095.50s of remaining time.
# 	0.9536	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r143 ... Training model for up to 7095.17s of the 7095.16s of remaining time.
# 	0.9409	 = Validation score   (roc_auc)
# 	1.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r178 ... Training model for up to 7093.55s of the 7093.54s of remaining time.
# 	0.9645	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForest_r166 ... Training model for up to 7092.78s of the 7092.77s of remaining time.
# 	0.9625	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_r31 ... Training model for up to 7091.79s of the 7091.78s of remaining time.
# 	0.9521	 = Validation score   (roc_auc)
# 	1.11s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185 ... Training model for up to 7090.66s of the 7090.65s of remaining time.
# 	0.9558	 = Validation score   (roc_auc)
# 	4.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160 ... Training model for up to 7085.82s of the 7085.81s of remaining time.
# 	0.9594	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r60 ... Training model for up to 7085.34s of the 7085.33s of remaining time.
# 	0.9491	 = Validation score   (roc_auc)
# 	1.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r15 ... Training model for up to 7084.15s of the 7084.14s of remaining time.
# 	0.9619	 = Validation score   (roc_auc)
# 	0.89s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r135 ... Training model for up to 7083.17s of the 7083.16s of remaining time.
# 	0.9532	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r22 ... Training model for up to 7082.63s of the 7082.62s of remaining time.
# 	0.9412	 = Validation score   (roc_auc)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69 ... Training model for up to 7082.25s of the 7082.24s of remaining time.
# 	0.8802	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r6 ... Training model for up to 7081.77s of the 7081.76s of remaining time.
# 	0.9752	 = Validation score   (roc_auc)
# 	1.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138 ... Training model for up to 7080.71s of the 7080.70s of remaining time.
# No improvement since epoch 8: early stopping
# 	0.9469	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r121 ... Training model for up to 7079.93s of the 7079.92s of remaining time.
# 	0.9504	 = Validation score   (roc_auc)
# 	0.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172 ... Training model for up to 7079.08s of the 7079.07s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.9505	 = Validation score   (roc_auc)
# 	1.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r180 ... Training model for up to 7077.58s of the 7077.56s of remaining time.
# 	0.9671	 = Validation score   (roc_auc)
# 	4.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76 ... Training model for up to 7073.37s of the 7073.36s of remaining time.
# 	0.9521	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r197 ... Training model for up to 7073.00s of the 7072.99s of remaining time.
# 	0.971	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121 ... Training model for up to 7072.07s of the 7072.06s of remaining time.
# 	0.975	 = Validation score   (roc_auc)
# 	2.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127 ... Training model for up to 7069.70s of the 7069.69s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.966	 = Validation score   (roc_auc)
# 	1.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r16 ... Training model for up to 7068.20s of the 7068.19s of remaining time.
# 	0.9644	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194 ... Training model for up to 7067.11s of the 7067.10s of remaining time.
# 	0.8832	 = Validation score   (roc_auc)
# 	1.59s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r12 ... Training model for up to 7065.49s of the 7065.48s of remaining time.
# 	0.949	 = Validation score   (roc_auc)
# 	3.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135 ... Training model for up to 7061.72s of the 7061.71s of remaining time.
# 	0.9648	 = Validation score   (roc_auc)
# 	1.2s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4 ... Training model for up to 7060.49s of the 7060.48s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.9585	 = Validation score   (roc_auc)
# 	1.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r126 ... Training model for up to 7059.14s of the 7059.13s of remaining time.
# 	0.95	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36 ... Training model for up to 7058.40s of the 7058.38s of remaining time.
# 	0.9685	 = Validation score   (roc_auc)
# 	0.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100 ... Training model for up to 7057.77s of the 7057.76s of remaining time.
# No improvement since epoch 6: early stopping
# 	0.9607	 = Validation score   (roc_auc)
# 	2.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r163 ... Training model for up to 7055.64s of the 7055.63s of remaining time.
# 	0.951	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r198 ... Training model for up to 7054.70s of the 7054.69s of remaining time.
# 	0.9475	 = Validation score   (roc_auc)
# 	1.54s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187 ... Training model for up to 7053.15s of the 7053.14s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.9637	 = Validation score   (roc_auc)
# 	1.7s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19 ... Training model for up to 7051.42s of the 7051.41s of remaining time.
# 	0.951	 = Validation score   (roc_auc)
# 	0.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r95 ... Training model for up to 7050.97s of the 7050.96s of remaining time.
# 	0.9489	 = Validation score   (roc_auc)
# 	0.42s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r34 ... Training model for up to 7050.53s of the 7050.52s of remaining time.
# 	0.9425	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r42 ... Training model for up to 7049.93s of the 7049.92s of remaining time.
# 	0.9662	 = Validation score   (roc_auc)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1 ... Training model for up to 7049.40s of the 7049.39s of remaining time.
# 	0.9529	 = Validation score   (roc_auc)
# 	1.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89 ... Training model for up to 7048.31s of the 7048.30s of remaining time.
# 	0.953	 = Validation score   (roc_auc)
# 	0.86s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 719.99s of the 7047.09s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r134': 0.273, 'CatBoost_r6': 0.273, 'ExtraTrees_r197': 0.273, 'NeuralNetTorch_r121': 0.182}
# 	0.9867	 = Validation score   (roc_auc)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 153.09s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 790.4 rows/s (57 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_FULL ...
# 	0.19s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestGini_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestEntr_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesGini_FULL ...
# 	0.62s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesEntr_FULL ...
# 	0.63s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_FULL ...
# 	Stopping at the best epoch learned earlier - 3.
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_FULL ...
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_FULL ...
# 	0.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_FULL ...
# 	0.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_FULL ...
# 	0.31s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_FULL ...
# 	3.62s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_FULL ...
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r42_FULL ...
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_FULL ...
# 	0.49s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_FULL ...
# 	5.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r195_FULL ...
# 	0.94s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_FULL ...
# 	0.24s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_FULL ...
# 	0.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_FULL ...
# 	1.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_FULL ...
# 	0.19s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r172_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_FULL ...
# 	0.19s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_FULL ...
# 	0.32s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.02s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_FULL ...
# 	0.73s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_FULL ...
# 	0.82s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r39_FULL ...
# 	0.78s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_FULL ...
# 	1.25s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_FULL ...
# 	1.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_FULL ...
# 	0.7s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_FULL ...
# 	1.44s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_FULL ...
# 	3.18s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	1.67s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_FULL ...
# 	0.08s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r49_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r127_FULL ...
# 	0.93s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r34_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_FULL ...
# 	1.55s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r4_FULL ...
# 	0.69s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_FULL ...
# 	Stopping at the best epoch learned earlier - 30.
# 	1.77s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r178_FULL ...
# ...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Computing feature importance via permutation shuffling for 19 features using 283 rows with 5 shuffle sets...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	13.78s	= Expected runtime (2.76s per shuffle set)
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	2.94s	= Actual runtime (Completed 5 of 5 shuffle sets)
