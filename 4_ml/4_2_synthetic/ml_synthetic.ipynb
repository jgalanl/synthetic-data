# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, auc

# %%
def pr_auc_Metric(y_true, y_pred):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    score = auc(recall, precision)
    return score

# %%
ag_roc_auc_scorer = make_scorer(
    name='roc_auc',
    score_func=pr_auc_Metric,
    optimum=1,
    greater_is_better=True,
    needs_proba=True
)

# %%
TIME_LIMIT = 2 * 3600

# %%
extra_metrics = ['roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
for i in range(0, 10):
    print(f'Fitting model {i}')
    train_data = pd.read_csv(
        f'../../data/synthetic/tvaes/set_{i}.csv'
        )

    predictor= TabularPredictor(
        label='ED_2Clases',
        problem_type='binary',
        eval_metric=ag_roc_auc_scorer,
        sample_weight='balance_weight',
        path=f'AutogluonModels/tvaes/v{i}'
    )

    predictor.fit(
        train_data = train_data,
        time_limit = TIME_LIMIT,
        presets = ['high_quality'],
        auto_stack = False,
        excluded_model_types=['KNN', 'LR'],
        num_stack_levels=0,
        num_bag_folds=0,
        verbosity = 2
    )

    df_test = pd.read_csv(
        f'../../data/test/set_{i}.csv'
    )

    predictors = predictor.leaderboard(
        df_test,
        extra_metrics = extra_metrics,
        extra_info=True,
        silent=True
    )
    predictors.to_excel(
        f'../../5_results/synthetic/tvaes/predictors_set_{i}.xlsx',
        index=False
    )

    feature_importance = predictor.feature_importance(train_data)
    feature_importance.to_excel(
        f'../../5_results/synthetic/tvaes/feature_importance_set_{i}.xlsx',
        index=True
    )
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       9.78 GB / 15.94 GB (61.4%)
# Disk Space Avail:   63.98 GB / 446.36 GB (14.3%)
# ===================================================
# Presets specified: ['high_quality']
# Fitting model 0
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\4_ml\4_2_synthetic\AutogluonModels\tvaes\v0"
# Train Data Rows:    646
# Train Data Columns: 19
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10027.18 MB
# 	Train Data (Original)  Memory Usage: 0.09 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])   :  3 | ['clin-reservaCognitiva_escolaridad', 'demo-edad', 'demo-genero']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])       :  2 | ['clin-reservaCognitiva_escolaridad', 'demo-edad']
# 		('int', ['bool']) :  1 | ['demo-genero']
# 	0.0s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.09 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 516, Val Rows: 130
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ... Training model for up to 7199.95s of the 7199.93s of remaining time.
# 	0.9053	 = Validation score   (roc_auc)
# 	3.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 7196.14s of the 7196.13s of remaining time.
# 	0.9096	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 7195.82s of the 7195.81s of remaining time.
# 	0.9158	 = Validation score   (roc_auc)
# 	0.84s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 7194.91s of the 7194.89s of remaining time.
# 	0.9233	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 7194.30s of the 7194.28s of remaining time.
# 	0.9249	 = Validation score   (roc_auc)
# 	1.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 7192.66s of the 7192.65s of remaining time.
# 	0.9096	 = Validation score   (roc_auc)
# 	0.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 7192.03s of the 7192.01s of remaining time.
# 	0.9092	 = Validation score   (roc_auc)
# 	0.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 7191.39s of the 7191.38s of remaining time.
# 	0.8741	 = Validation score   (roc_auc)
# 	1.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 7189.79s of the 7189.78s of remaining time.
# 	0.9173	 = Validation score   (roc_auc)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 7189.30s of the 7189.29s of remaining time.
# 	0.9104	 = Validation score   (roc_auc)
# 	2.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 7186.29s of the 7186.27s of remaining time.
# 	0.8777	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r177 ... Training model for up to 7185.56s of the 7185.55s of remaining time.
# 	0.9306	 = Validation score   (roc_auc)
# 	1.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79 ... Training model for up to 7184.36s of the 7184.35s of remaining time.
# 	0.8993	 = Validation score   (roc_auc)
# 	2.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r131 ... Training model for up to 7182.00s of the 7181.98s of remaining time.
# 	0.9094	 = Validation score   (roc_auc)
# 	0.8s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191 ... Training model for up to 7181.17s of the 7181.16s of remaining time.
# No improvement since epoch 8: early stopping
# 	0.8919	 = Validation score   (roc_auc)
# 	1.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r9 ... Training model for up to 7179.80s of the 7179.79s of remaining time.
# 	0.9221	 = Validation score   (roc_auc)
# 	5.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r96 ... Training model for up to 7174.28s of the 7174.26s of remaining time.
# [1000]	valid_set's binary_logloss: 0.363139
# [2000]	valid_set's binary_logloss: 0.360276
# 	0.9005	 = Validation score   (roc_auc)
# 	1.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22 ... Training model for up to 7172.93s of the 7172.91s of remaining time.
# [3000]	valid_set's binary_logloss: 0.36449
# 	0.9023	 = Validation score   (roc_auc)
# 	4.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r33 ... Training model for up to 7168.89s of the 7168.87s of remaining time.
# 	0.9211	 = Validation score   (roc_auc)
# 	0.76s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r42 ... Training model for up to 7168.11s of the 7168.09s of remaining time.
# 	0.9245	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r137 ... Training model for up to 7167.37s of the 7167.35s of remaining time.
# 	0.9245	 = Validation score   (roc_auc)
# 	0.96s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102 ... Training model for up to 7166.39s of the 7166.38s of remaining time.
# 	0.9038	 = Validation score   (roc_auc)
# 	3.13s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r13 ... Training model for up to 7163.23s of the 7163.22s of remaining time.
# 	0.9229	 = Validation score   (roc_auc)
# 	5.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r195 ... Training model for up to 7158.01s of the 7158.00s of remaining time.
# 	0.9057	 = Validation score   (roc_auc)
# 	0.77s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r188 ... Training model for up to 7157.16s of the 7157.15s of remaining time.
# 	0.91	 = Validation score   (roc_auc)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145 ... Training model for up to 7156.66s of the 7156.65s of remaining time.
# No improvement since epoch 4: early stopping
# 	0.8922	 = Validation score   (roc_auc)
# 	1.06s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r89 ... Training model for up to 7155.58s of the 7155.56s of remaining time.
# 	0.9159	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30 ... Training model for up to 7155.25s of the 7155.24s of remaining time.
# 	0.8931	 = Validation score   (roc_auc)
# 	2.83s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r130 ... Training model for up to 7152.41s of the 7152.39s of remaining time.
# 	0.9205	 = Validation score   (roc_auc)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86 ... Training model for up to 7152.12s of the 7152.10s of remaining time.
# 	0.898	 = Validation score   (roc_auc)
# 	1.4s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r50 ... Training model for up to 7150.70s of the 7150.69s of remaining time.
# 	0.9189	 = Validation score   (roc_auc)
# 	1.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11 ... Training model for up to 7149.67s of the 7149.66s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.8861	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r194 ... Training model for up to 7148.65s of the 7148.63s of remaining time.
# 	0.9182	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r172 ... Training model for up to 7148.28s of the 7148.27s of remaining time.
# 	0.9206	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r69 ... Training model for up to 7147.67s of the 7147.66s of remaining time.
# 	0.9291	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103 ... Training model for up to 7146.69s of the 7146.68s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.8782	 = Validation score   (roc_auc)
# 	0.51s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14 ... Training model for up to 7146.16s of the 7146.14s of remaining time.
# 	0.9067	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r161 ... Training model for up to 7145.51s of the 7145.49s of remaining time.
# 	0.913	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143 ... Training model for up to 7144.96s of the 7144.94s of remaining time.
# No improvement since epoch 4: early stopping
# 	0.9073	 = Validation score   (roc_auc)
# 	2.84s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r70 ... Training model for up to 7142.10s of the 7142.09s of remaining time.
# 	0.9217	 = Validation score   (roc_auc)
# 	2.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156 ... Training model for up to 7139.98s of the 7139.96s of remaining time.
# No improvement since epoch 5: early stopping
# 	0.9011	 = Validation score   (roc_auc)
# 	2.45s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r196 ... Training model for up to 7137.49s of the 7137.47s of remaining time.
# [1000]	valid_set's binary_logloss: 0.365862
# [2000]	valid_set's binary_logloss: 0.350408
# 	0.9153	 = Validation score   (roc_auc)
# 	1.88s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r39 ... Training model for up to 7135.49s of the 7135.47s of remaining time.
# 	0.9036	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r167 ... Training model for up to 7134.75s of the 7134.74s of remaining time.
# 	0.9278	 = Validation score   (roc_auc)
# 	1.72s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95 ... Training model for up to 7133.01s of the 7132.99s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.8639	 = Validation score   (roc_auc)
# 	0.99s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41 ... Training model for up to 7132.00s of the 7131.98s of remaining time.
# 	0.9192	 = Validation score   (roc_auc)
# 	1.07s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost_r98 ... Training model for up to 7130.90s of the 7130.89s of remaining time.
# 	0.9201	 = Validation score   (roc_auc)
# 	1.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r15 ... Training model for up to 7129.77s of the 7129.75s of remaining time.
# 	0.9133	 = Validation score   (roc_auc)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158 ... Training model for up to 7129.38s of the 7129.36s of remaining time.
# 	0.9006	 = Validation score   (roc_auc)
# 	2.83s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r86 ... Training model for up to 7126.52s of the 7126.51s of remaining time.
# 	0.9305	 = Validation score   (roc_auc)
# 	4.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37 ... Training model for up to 7121.59s of the 7121.58s of remaining time.
# No improvement since epoch 4: early stopping
# 	0.8908	 = Validation score   (roc_auc)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197 ... Training model for up to 7121.06s of the 7121.05s of remaining time.
# 	0.9004	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r49 ... Training model for up to 7120.26s of the 7120.24s of remaining time.
# 	0.9233	 = Validation score   (roc_auc)
# 	1.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r49 ... Training model for up to 7119.21s of the 7119.20s of remaining time.
# 	0.9096	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r143 ... Training model for up to 7118.48s of the 7118.47s of remaining time.
# 	0.9113	 = Validation score   (roc_auc)
# 	0.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r127 ... Training model for up to 7118.04s of the 7118.02s of remaining time.
# 	0.9044	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134 ... Training model for up to 7117.18s of the 7117.15s of remaining time.
# No improvement since epoch 25: early stopping
# 	0.9092	 = Validation score   (roc_auc)
# 	5.76s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r34 ... Training model for up to 7111.37s of the 7111.36s of remaining time.
# 	0.9119	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r94 ... Training model for up to 7110.73s of the 7110.72s of remaining time.
# 	0.9087	 = Validation score   (roc_auc)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143 ... Training model for up to 7110.24s of the 7110.23s of remaining time.
# 	0.9031	 = Validation score   (roc_auc)
# 	2.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r128 ... Training model for up to 7107.40s of the 7107.39s of remaining time.
# 	0.9131	 = Validation score   (roc_auc)
# 	3.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111 ... Training model for up to 7103.71s of the 7103.69s of remaining time.
# 	0.8431	 = Validation score   (roc_auc)
# 	2.33s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31 ... Training model for up to 7101.35s of the 7101.34s of remaining time.
# 	0.8982	 = Validation score   (roc_auc)
# 	1.62s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTrees_r4 ... Training model for up to 7099.70s of the 7099.69s of remaining time.
# 	0.9048	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65 ... Training model for up to 7099.05s of the 7099.04s of remaining time.
# 	0.9002	 = Validation score   (roc_auc)
# 	3.5s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88 ... Training model for up to 7095.52s of the 7095.50s of remaining time.
# No improvement since epoch 28: early stopping
# 	0.9107	 = Validation score   (roc_auc)
# 	4.91s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r30 ... Training model for up to 7090.57s of the 7090.55s of remaining time.
# [1000]	valid_set's binary_logloss: 0.359178
# 	0.91	 = Validation score   (roc_auc)
# 	1.13s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r49 ... Training model for up to 7089.36s of the 7089.35s of remaining time.
# 	0.9192	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r5 ... Training model for up to 7088.63s of the 7088.61s of remaining time.
# 	0.9222	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87 ... Training model for up to 7087.70s of the 7087.69s of remaining time.
# 	0.9061	 = Validation score   (roc_auc)
# 	1.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71 ... Training model for up to 7086.40s of the 7086.39s of remaining time.
# 	0.9186	 = Validation score   (roc_auc)
# 	0.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r143 ... Training model for up to 7085.94s of the 7085.93s of remaining time.
# 	0.9285	 = Validation score   (roc_auc)
# 	2.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r178 ... Training model for up to 7083.55s of the 7083.54s of remaining time.
# 	0.9248	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForest_r166 ... Training model for up to 7082.81s of the 7082.80s of remaining time.
# 	0.9158	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_r31 ... Training model for up to 7081.88s of the 7081.87s of remaining time.
# 	0.9085	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185 ... Training model for up to 7081.17s of the 7081.16s of remaining time.
# 	0.9049	 = Validation score   (roc_auc)
# 	2.11s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160 ... Training model for up to 7079.05s of the 7079.03s of remaining time.
# 	0.8836	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r60 ... Training model for up to 7078.16s of the 7078.14s of remaining time.
# 	0.9256	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r15 ... Training model for up to 7077.20s of the 7077.17s of remaining time.
# 	0.9074	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r135 ... Training model for up to 7076.24s of the 7076.23s of remaining time.
# 	0.9071	 = Validation score   (roc_auc)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r22 ... Training model for up to 7075.89s of the 7075.87s of remaining time.
# 	0.9236	 = Validation score   (roc_auc)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69 ... Training model for up to 7075.57s of the 7075.56s of remaining time.
# 	0.8977	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r6 ... Training model for up to 7074.68s of the 7074.67s of remaining time.
# 	0.9159	 = Validation score   (roc_auc)
# 	1.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138 ... Training model for up to 7073.62s of the 7073.60s of remaining time.
# No improvement since epoch 8: early stopping
# 	0.8872	 = Validation score   (roc_auc)
# 	1.38s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r121 ... Training model for up to 7072.21s of the 7072.20s of remaining time.
# 	0.9122	 = Validation score   (roc_auc)
# 	0.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172 ... Training model for up to 7071.56s of the 7071.55s of remaining time.
# 	0.8694	 = Validation score   (roc_auc)
# 	0.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r180 ... Training model for up to 7071.10s of the 7071.09s of remaining time.
# 	0.9247	 = Validation score   (roc_auc)
# 	3.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76 ... Training model for up to 7067.93s of the 7067.91s of remaining time.
# 	0.8705	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r197 ... Training model for up to 7067.37s of the 7067.36s of remaining time.
# 	0.9142	 = Validation score   (roc_auc)
# 	0.81s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121 ... Training model for up to 7066.48s of the 7066.46s of remaining time.
# 	0.9095	 = Validation score   (roc_auc)
# 	1.77s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127 ... Training model for up to 7064.69s of the 7064.68s of remaining time.
# 	0.8743	 = Validation score   (roc_auc)
# 	2.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r16 ... Training model for up to 7062.10s of the 7062.08s of remaining time.
# 	0.9004	 = Validation score   (roc_auc)
# 	0.89s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194 ... Training model for up to 7061.14s of the 7061.12s of remaining time.
# 	0.8682	 = Validation score   (roc_auc)
# 	0.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r12 ... Training model for up to 7060.56s of the 7060.55s of remaining time.
# 	0.927	 = Validation score   (roc_auc)
# 	2.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135 ... Training model for up to 7058.44s of the 7058.43s of remaining time.
# 	0.8982	 = Validation score   (roc_auc)
# 	4.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4 ... Training model for up to 7054.42s of the 7054.41s of remaining time.
# No improvement since epoch 11: early stopping
# 	0.8934	 = Validation score   (roc_auc)
# 	0.53s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r126 ... Training model for up to 7053.88s of the 7053.85s of remaining time.
# 	0.9166	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36 ... Training model for up to 7053.13s of the 7053.12s of remaining time.
# 	0.9088	 = Validation score   (roc_auc)
# 	0.99s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100 ... Training model for up to 7052.12s of the 7052.11s of remaining time.
# No improvement since epoch 10: early stopping
# 	0.9116	 = Validation score   (roc_auc)
# 	4.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r163 ... Training model for up to 7048.07s of the 7048.05s of remaining time.
# 	0.9219	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r198 ... Training model for up to 7047.10s of the 7047.09s of remaining time.
# 	0.932	 = Validation score   (roc_auc)
# 	1.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187 ... Training model for up to 7045.22s of the 7045.21s of remaining time.
# No improvement since epoch 10: early stopping
# 	0.8688	 = Validation score   (roc_auc)
# 	3.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19 ... Training model for up to 7041.41s of the 7041.39s of remaining time.
# 	0.8896	 = Validation score   (roc_auc)
# 	0.53s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r95 ... Training model for up to 7040.86s of the 7040.84s of remaining time.
# 	0.9147	 = Validation score   (roc_auc)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r34 ... Training model for up to 7040.50s of the 7040.48s of remaining time.
# 	0.9213	 = Validation score   (roc_auc)
# 	0.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r42 ... Training model for up to 7040.07s of the 7040.06s of remaining time.
# 	0.9178	 = Validation score   (roc_auc)
# 	0.36s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1 ... Training model for up to 7039.70s of the 7039.68s of remaining time.
# 	0.8904	 = Validation score   (roc_auc)
# 	1.92s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89 ... Training model for up to 7037.76s of the 7037.74s of remaining time.
# 	0.9056	 = Validation score   (roc_auc)
# 	1.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 719.99s of the 7035.17s of remaining time.
# 	Ensemble Weights: {'XGBoost_r22': 0.263, 'CatBoost_r198': 0.263, 'NeuralNetTorch_r41': 0.211, 'NeuralNetFastAI_r100': 0.211, 'RandomForestEntr': 0.053}
# 	0.9411	 = Validation score   (roc_auc)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 165.09s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1329.3 rows/s (130 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestGini_FULL ...
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestEntr_FULL ...
# 	0.55s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesGini_FULL ...
# 	0.57s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesEntr_FULL ...
# 	0.56s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_FULL ...
# 	0.53s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_FULL ...
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_FULL ...
# 	0.26s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.33s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_FULL ...
# 	1.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_FULL ...
# 	0.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_FULL ...
# 	1.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r42_FULL ...
# 	0.56s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_FULL ...
# 	0.31s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	1.5s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_FULL ...
# 	2.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r195_FULL ...
# 	0.77s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_FULL ...
# 	0.26s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.29s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_FULL ...
# 	0.06s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_FULL ...
# 	0.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_FULL ...
# 	0.22s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_FULL ...
# 	0.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r172_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_FULL ...
# 	0.24s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_FULL ...
# 	Stopping at the best epoch learned earlier - 3.
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_FULL ...
# 	0.33s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.67s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_FULL ...
# 	0.52s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_FULL ...
# 	0.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r39_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_FULL ...
# 	0.43s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_FULL ...
# 	Stopping at the best epoch learned earlier - 3.
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_FULL ...
# 	0.5s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_FULL ...
# 	1.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_FULL ...
# 	2.93s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_FULL ...
# 	0.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r49_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r127_FULL ...
# 	0.91s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_FULL ...
# 	Stopping at the best epoch learned earlier - 25.
# 	3.78s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r34_FULL ...
# 	0.62s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_FULL ...
# 	0.74s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_FULL ...
# 	0.89s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	1.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r4_FULL ...
# 	0.65s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_FULL ...
# No improvement since epoch 2: early stopping
# 	2.82s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_FULL ...
# 	Stopping at the best epoch learned earlier - 28.
# 	3.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_FULL ...
# 	0.04s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_FULL ...
# 	0.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r178_FULL ...
# 	0.78s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r166_FULL ...
# 	0.82s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_FULL ...
# ...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Computing feature importance via permutation shuffling for 19 features using 648 rows with 5 shuffle sets...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	23.78s	= Expected runtime (4.76s per shuffle set)
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	5.95s	= Actual runtime (Completed 5 of 5 shuffle sets)
