# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, auc

# %%
def pr_auc_Metric(y_true, y_pred):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    score = auc(recall, precision)
    return score

# %%
ag_roc_auc_scorer = make_scorer(
    name='roc_auc',
    score_func=pr_auc_Metric,
    optimum=1,
    greater_is_better=True,
    needs_proba=True
)

# %%
TIME_LIMIT = 2 * 3600

# %%
extra_metrics = ['roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
generator = 'gc'

# %%
for i in range(0, 10):
    print(f'Fitting model {i}')
    train_data = pd.read_csv(
        f'../../data/synthetic/{generator}/set_{i}.csv'
        )

    predictor= TabularPredictor(
        label='ED_2Clases',
        problem_type='binary',
        eval_metric=ag_roc_auc_scorer,
        sample_weight='balance_weight',
        path=f'AutogluonModels/{generator}/v{i}'
    )

    predictor.fit(
        train_data = train_data,
        time_limit = TIME_LIMIT,
        presets = ['high_quality'],
        auto_stack = False,
        excluded_model_types=['KNN', 'LR'],
        num_stack_levels=0,
        num_bag_folds=0,
        verbosity = 2
    )

    df_test = pd.read_csv(
        f'../../data/test/set_{i}.csv'
    )

    predictors = predictor.leaderboard(
        df_test,
        extra_metrics = extra_metrics,
        extra_info=True,
        silent=True
    )
    predictors.to_excel(
        f'../../5_results/synthetic/{generator}/predictors_set_{i}.xlsx',
        index=False
    )

    feature_importance = predictor.feature_importance(train_data)
    feature_importance.to_excel(
        f'../../5_results/synthetic/{generator}/feature_importance_set_{i}.xlsx',
        index=True
    )
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       8.56 GB / 15.94 GB (53.7%)
# Disk Space Avail:   67.47 GB / 446.36 GB (15.1%)
# ===================================================
# Presets specified: ['high_quality']
# Fitting model 0
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\4_ml\4_2_synthetic\AutogluonModels\gc\v0"
# Train Data Rows:    282
# Train Data Columns: 19
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8777.09 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])   :  3 | ['clin-reservaCognitiva_escolaridad', 'demo-edad', 'demo-genero']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 16 | ['eval-TLP-CubCorsi-totalDirectos-PD', 'eval-TLP-CubCorsi-totalinversos-PD', 'eval-TLP-CubCorsi-total-PD', 'eval-TLP-FigRey-Duracion-PD', 'eval-TLP-FigRey-totalCopia-PD', ...]
# 		('int', [])       :  2 | ['clin-reservaCognitiva_escolaridad', 'demo-edad']
# 		('int', ['bool']) :  1 | ['demo-genero']
# 	0.0s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 225, Val Rows: 57
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ... Training model for up to 7199.94s of the 7199.92s of remaining time.
# 	0.7903	 = Validation score   (roc_auc)
# 	2.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 7197.64s of the 7197.62s of remaining time.
# 	0.7674	 = Validation score   (roc_auc)
# 	0.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 7197.41s of the 7197.40s of remaining time.
# 	0.8611	 = Validation score   (roc_auc)
# 	0.61s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 7196.73s of the 7196.72s of remaining time.
# 	0.8467	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 7196.15s of the 7196.14s of remaining time.
# 	0.8533	 = Validation score   (roc_auc)
# 	1.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 7194.92s of the 7194.90s of remaining time.
# 	0.8277	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 7194.28s of the 7194.27s of remaining time.
# 	0.8666	 = Validation score   (roc_auc)
# 	0.53s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 7193.69s of the 7193.67s of remaining time.
# No improvement since epoch 5: early stopping
# 	0.8127	 = Validation score   (roc_auc)
# 	1.73s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 7191.93s of the 7191.92s of remaining time.
# 	0.8645	 = Validation score   (roc_auc)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 7191.53s of the 7191.51s of remaining time.
# 	0.8279	 = Validation score   (roc_auc)
# 	2.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 7189.25s of the 7189.24s of remaining time.
# 	0.7749	 = Validation score   (roc_auc)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r177 ... Training model for up to 7188.87s of the 7188.85s of remaining time.
# 	0.8527	 = Validation score   (roc_auc)
# 	0.81s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79 ... Training model for up to 7188.05s of the 7188.03s of remaining time.
# 	0.8877	 = Validation score   (roc_auc)
# 	2.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r131 ... Training model for up to 7185.80s of the 7185.79s of remaining time.
# 	0.8034	 = Validation score   (roc_auc)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191 ... Training model for up to 7185.46s of the 7185.45s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.8254	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r9 ... Training model for up to 7184.12s of the 7184.11s of remaining time.
# 	0.8074	 = Validation score   (roc_auc)
# 	3.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r96 ... Training model for up to 7181.01s of the 7181.00s of remaining time.
# 	0.8254	 = Validation score   (roc_auc)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22 ... Training model for up to 7180.75s of the 7180.74s of remaining time.
# 	0.8713	 = Validation score   (roc_auc)
# 	1.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r33 ... Training model for up to 7179.67s of the 7179.65s of remaining time.
# 	0.8523	 = Validation score   (roc_auc)
# 	0.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r42 ... Training model for up to 7179.19s of the 7179.18s of remaining time.
# 	0.8665	 = Validation score   (roc_auc)
# 	0.55s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r137 ... Training model for up to 7178.58s of the 7178.56s of remaining time.
# 	0.8173	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102 ... Training model for up to 7177.92s of the 7177.91s of remaining time.
# No improvement since epoch 2: early stopping
# 	0.7824	 = Validation score   (roc_auc)
# 	1.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r13 ... Training model for up to 7176.80s of the 7176.79s of remaining time.
# 	0.8141	 = Validation score   (roc_auc)
# 	3.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r195 ... Training model for up to 7172.81s of the 7172.79s of remaining time.
# 	0.8346	 = Validation score   (roc_auc)
# 	0.84s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r188 ... Training model for up to 7171.89s of the 7171.88s of remaining time.
# 	0.8154	 = Validation score   (roc_auc)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145 ... Training model for up to 7171.47s of the 7171.46s of remaining time.
# 	0.8709	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r89 ... Training model for up to 7170.77s of the 7170.76s of remaining time.
# 	0.8631	 = Validation score   (roc_auc)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30 ... Training model for up to 7170.42s of the 7170.41s of remaining time.
# 	0.9003	 = Validation score   (roc_auc)
# 	1.14s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r130 ... Training model for up to 7169.27s of the 7169.25s of remaining time.
# 	0.8172	 = Validation score   (roc_auc)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86 ... Training model for up to 7169.03s of the 7169.02s of remaining time.
# 	0.9029	 = Validation score   (roc_auc)
# 	10.83s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r50 ... Training model for up to 7158.19s of the 7158.16s of remaining time.
# 	0.8259	 = Validation score   (roc_auc)
# 	0.82s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11 ... Training model for up to 7157.34s of the 7157.32s of remaining time.
# No improvement since epoch 0: early stopping
# 	0.8656	 = Validation score   (roc_auc)
# 	0.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost_r194 ... Training model for up to 7156.98s of the 7156.97s of remaining time.
# 	0.8508	 = Validation score   (roc_auc)
# 	0.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r172 ... Training model for up to 7156.66s of the 7156.65s of remaining time.
# 	0.8178	 = Validation score   (roc_auc)
# 	0.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r69 ... Training model for up to 7156.09s of the 7156.08s of remaining time.
# 	0.8153	 = Validation score   (roc_auc)
# 	0.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103 ... Training model for up to 7155.46s of the 7155.44s of remaining time.
# No improvement since epoch 2: early stopping
# 	0.7977	 = Validation score   (roc_auc)
# 	1.13s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14 ... Training model for up to 7154.31s of the 7154.29s of remaining time.
# 	0.8347	 = Validation score   (roc_auc)
# 	0.23s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r161 ... Training model for up to 7154.06s of the 7154.04s of remaining time.
# 	0.8151	 = Validation score   (roc_auc)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143 ... Training model for up to 7153.65s of the 7153.64s of remaining time.
# No improvement since epoch 6: early stopping
# 	0.8831	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r70 ... Training model for up to 7152.20s of the 7152.19s of remaining time.
# 	0.7777	 = Validation score   (roc_auc)
# 	1.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156 ... Training model for up to 7150.63s of the 7150.62s of remaining time.
# No improvement since epoch 5: early stopping
# 	0.8418	 = Validation score   (roc_auc)
# 	1.21s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r196 ... Training model for up to 7149.38s of the 7149.37s of remaining time.
# 	0.8014	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r39 ... Training model for up to 7148.55s of the 7148.54s of remaining time.
# [1000]	valid_set's binary_logloss: 0.638603
# 	0.8466	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r167 ... Training model for up to 7147.75s of the 7147.74s of remaining time.
# 	0.816	 = Validation score   (roc_auc)
# 	1.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95 ... Training model for up to 7146.39s of the 7146.37s of remaining time.
# 	0.8134	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41 ... Training model for up to 7145.91s of the 7145.90s of remaining time.
# 	0.8935	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r98 ... Training model for up to 7144.95s of the 7144.94s of remaining time.
# 	0.8566	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r15 ... Training model for up to 7144.13s of the 7144.11s of remaining time.
# 	0.8081	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158 ... Training model for up to 7143.80s of the 7143.79s of remaining time.
# 	0.8998	 = Validation score   (roc_auc)
# 	4.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r86 ... Training model for up to 7139.36s of the 7139.34s of remaining time.
# 	0.8275	 = Validation score   (roc_auc)
# 	2.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37 ... Training model for up to 7136.87s of the 7136.86s of remaining time.
# 	0.8654	 = Validation score   (roc_auc)
# 	2.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197 ... Training model for up to 7134.51s of the 7134.50s of remaining time.
# 	0.8798	 = Validation score   (roc_auc)
# 	0.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r49 ... Training model for up to 7133.94s of the 7133.93s of remaining time.
# 	0.8285	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r49 ... Training model for up to 7133.27s of the 7133.26s of remaining time.
# 	0.8277	 = Validation score   (roc_auc)
# 	0.6s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r143 ... Training model for up to 7132.61s of the 7132.60s of remaining time.
# 	0.7848	 = Validation score   (roc_auc)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r127 ... Training model for up to 7132.30s of the 7132.29s of remaining time.
# 	0.8144	 = Validation score   (roc_auc)
# 	0.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134 ... Training model for up to 7131.48s of the 7131.46s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.8298	 = Validation score   (roc_auc)
# 	1.29s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r34 ... Training model for up to 7130.16s of the 7130.15s of remaining time.
# 	0.8042	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r94 ... Training model for up to 7129.57s of the 7129.55s of remaining time.
# 	0.8051	 = Validation score   (roc_auc)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143 ... Training model for up to 7129.34s of the 7129.33s of remaining time.
# 	0.855	 = Validation score   (roc_auc)
# 	5.37s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r128 ... Training model for up to 7123.95s of the 7123.93s of remaining time.
# 	0.822	 = Validation score   (roc_auc)
# 	2.89s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111 ... Training model for up to 7121.04s of the 7121.03s of remaining time.
# 	0.8338	 = Validation score   (roc_auc)
# 	0.99s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31 ... Training model for up to 7120.02s of the 7120.01s of remaining time.
# 	0.8976	 = Validation score   (roc_auc)
# 	1.99s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r4 ... Training model for up to 7118.02s of the 7118.01s of remaining time.
# 	0.8271	 = Validation score   (roc_auc)
# 	0.53s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65 ... Training model for up to 7117.43s of the 7117.42s of remaining time.
# 	0.8182	 = Validation score   (roc_auc)
# 	1.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88 ... Training model for up to 7115.87s of the 7115.85s of remaining time.
# No improvement since epoch 1: early stopping
# 	0.7998	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r30 ... Training model for up to 7114.90s of the 7114.89s of remaining time.
# 	0.7984	 = Validation score   (roc_auc)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r49 ... Training model for up to 7114.59s of the 7114.57s of remaining time.
# 	0.8536	 = Validation score   (roc_auc)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r5 ... Training model for up to 7114.21s of the 7114.19s of remaining time.
# 	0.8126	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87 ... Training model for up to 7113.53s of the 7113.52s of remaining time.
# 	0.857	 = Validation score   (roc_auc)
# 	1.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71 ... Training model for up to 7112.52s of the 7112.50s of remaining time.
# 	0.8623	 = Validation score   (roc_auc)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r143 ... Training model for up to 7112.05s of the 7112.04s of remaining time.
# 	0.8391	 = Validation score   (roc_auc)
# 	1.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r178 ... Training model for up to 7110.81s of the 7110.79s of remaining time.
# 	0.8248	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForest_r166 ... Training model for up to 7109.93s of the 7109.92s of remaining time.
# 	0.8611	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_r31 ... Training model for up to 7108.91s of the 7108.90s of remaining time.
# 	0.8553	 = Validation score   (roc_auc)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185 ... Training model for up to 7108.42s of the 7108.41s of remaining time.
# 	0.8975	 = Validation score   (roc_auc)
# 	1.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160 ... Training model for up to 7107.13s of the 7107.11s of remaining time.
# 	0.85	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r60 ... Training model for up to 7106.79s of the 7106.77s of remaining time.
# 	0.8358	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r15 ... Training model for up to 7105.85s of the 7105.84s of remaining time.
# 	0.8395	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r135 ... Training model for up to 7104.78s of the 7104.77s of remaining time.
# 	0.8169	 = Validation score   (roc_auc)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r22 ... Training model for up to 7104.51s of the 7104.50s of remaining time.
# 	0.8456	 = Validation score   (roc_auc)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69 ... Training model for up to 7104.16s of the 7104.15s of remaining time.
# 	0.8186	 = Validation score   (roc_auc)
# 	0.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r6 ... Training model for up to 7103.70s of the 7103.69s of remaining time.
# 	0.8134	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138 ... Training model for up to 7102.76s of the 7102.75s of remaining time.
# No improvement since epoch 22: early stopping
# 	0.8126	 = Validation score   (roc_auc)
# 	0.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r121 ... Training model for up to 7101.98s of the 7101.97s of remaining time.
# 	0.8256	 = Validation score   (roc_auc)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172 ... Training model for up to 7101.52s of the 7101.51s of remaining time.
# No improvement since epoch 2: early stopping
# 	0.8209	 = Validation score   (roc_auc)
# 	1.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r180 ... Training model for up to 7100.47s of the 7100.45s of remaining time.
# 	0.8711	 = Validation score   (roc_auc)
# 	2.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76 ... Training model for up to 7098.35s of the 7098.32s of remaining time.
# 	0.8501	 = Validation score   (roc_auc)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTrees_r197 ... Training model for up to 7097.85s of the 7097.83s of remaining time.
# 	0.866	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121 ... Training model for up to 7097.00s of the 7096.99s of remaining time.
# 	0.8411	 = Validation score   (roc_auc)
# 	1.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127 ... Training model for up to 7095.93s of the 7095.92s of remaining time.
# No improvement since epoch 0: early stopping
# 	0.8369	 = Validation score   (roc_auc)
# 	1.05s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r16 ... Training model for up to 7094.87s of the 7094.85s of remaining time.
# 	0.8524	 = Validation score   (roc_auc)
# 	0.82s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194 ... Training model for up to 7093.99s of the 7093.98s of remaining time.
# 	0.8519	 = Validation score   (roc_auc)
# 	1.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r12 ... Training model for up to 7092.82s of the 7092.80s of remaining time.
# 	0.8256	 = Validation score   (roc_auc)
# 	1.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135 ... Training model for up to 7090.83s of the 7090.82s of remaining time.
# 	0.8419	 = Validation score   (roc_auc)
# 	1.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4 ... Training model for up to 7088.85s of the 7088.84s of remaining time.
# 	0.8526	 = Validation score   (roc_auc)
# 	1.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r126 ... Training model for up to 7087.26s of the 7087.25s of remaining time.
# 	0.8403	 = Validation score   (roc_auc)
# 	0.62s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36 ... Training model for up to 7086.58s of the 7086.57s of remaining time.
# 	0.8528	 = Validation score   (roc_auc)
# 	1.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100 ... Training model for up to 7085.28s of the 7085.26s of remaining time.
# No improvement since epoch 15: early stopping
# 	0.8354	 = Validation score   (roc_auc)
# 	2.09s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r163 ... Training model for up to 7083.16s of the 7083.15s of remaining time.
# 	0.7934	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r198 ... Training model for up to 7082.48s of the 7082.46s of remaining time.
# 	0.819	 = Validation score   (roc_auc)
# 	1.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187 ... Training model for up to 7081.19s of the 7081.18s of remaining time.
# No improvement since epoch 5: early stopping
# 	0.8995	 = Validation score   (roc_auc)
# 	1.34s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19 ... Training model for up to 7079.81s of the 7079.80s of remaining time.
# 	0.8519	 = Validation score   (roc_auc)
# 	0.8s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r95 ... Training model for up to 7079.00s of the 7078.98s of remaining time.
# 	0.8247	 = Validation score   (roc_auc)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r34 ... Training model for up to 7078.71s of the 7078.69s of remaining time.
# 	0.8431	 = Validation score   (roc_auc)
# 	0.32s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_r42 ... Training model for up to 7078.36s of the 7078.35s of remaining time.
# 	0.8351	 = Validation score   (roc_auc)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1 ... Training model for up to 7078.05s of the 7078.04s of remaining time.
# 	0.8483	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89 ... Training model for up to 7076.72s of the 7076.71s of remaining time.
# 	0.8943	 = Validation score   (roc_auc)
# 	3.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 719.99s of the 7073.00s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r86': 1.0}
# 	0.9029	 = Validation score   (roc_auc)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 127.16s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 3132.5 rows/s (57 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestGini_FULL ...
# 	0.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForestEntr_FULL ...
# 	0.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesGini_FULL ...
# 	0.55s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTreesEntr_FULL ...
# 	0.51s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_FULL ...
# 	0.04s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_FULL ...
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_FULL ...
# 	0.08s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_FULL ...
# 	1.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_FULL ...
# 	0.17s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_FULL ...
# 	0.71s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_FULL ...
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r42_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_FULL ...
# 	0.11s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_FULL ...
# 	2.0s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r195_FULL ...
# 	0.76s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_FULL ...
# 	0.14s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_FULL ...
# 	6.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_FULL ...
# 	0.15s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_FULL ...
# 	0.04s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r172_FULL ...
# 	0.65s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_FULL ...
# 	0.09s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_FULL ...
# 	0.04s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_FULL ...
# 	0.19s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.49s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_FULL ...
# 	0.21s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_FULL ...
# 	0.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r39_FULL ...
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_FULL ...
# 	0.25s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_FULL ...
# 	0.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_FULL ...
# 	2.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_FULL ...
# 	0.68s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_FULL ...
# No improvement since epoch 5: early stopping
# 	1.76s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r49_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r127_FULL ...
# 	0.75s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r34_FULL ...
# 	0.55s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_FULL ...
# 	3.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_FULL ...
# 	0.56s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_FULL ...
# 	1.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r4_FULL ...
# 	0.56s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_FULL ...
# 	Stopping at the best epoch learned earlier - 26.
# 	1.18s	 = Training   runtime
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_FULL ...
# 	0.08s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: ExtraTrees_r178_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest_r166_FULL ...
# 	0.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_FULL ...
# 	0.45s	 = Training   runtime
# ...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Computing feature importance via permutation shuffling for 19 features using 283 rows with 5 shuffle sets...
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	2.77s	= Expected runtime (0.55s per shuffle set)
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# 	1.96s	= Actual runtime (Completed 5 of 5 shuffle sets)
