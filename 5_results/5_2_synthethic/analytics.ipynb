# %%
import pandas as pd
from glob import glob

# %%
files = glob(f'tvaes/predictors*.xlsx')
df = pd.concat(pd.read_excel(excel_file) for excel_file in files)

# %%
metrics = [
    'type', 'generator', 'roc_auc', 'accuracy', 'balanced_accuracy', 'recall', 'score_test', 'f1', 'f1_macro', 'f1_micro'
]
sort_metrics = metrics[2:]

# %%
# Revisar 'fit_time', 'memory_size',     'log_loss' en otros gráficos

# %%
df
# Out:
#                          model  score_test   roc_auc  accuracy  \
# 0    NeuralNetFastAI_r100_FULL    1.000000  1.000000  0.968750
# 1          NeuralNetFastAI_r95    1.000000  1.000000  0.937500
# 2      NeuralNetTorch_r31_FULL    0.980867  0.994286  0.812500
# 3    NeuralNetFastAI_r160_FULL    0.980867  0.994286  0.906250
# 4    NeuralNetFastAI_r138_FULL    0.980867  0.994286  0.906250
# ..                         ...         ...       ...       ...
# 213        NeuralNetTorch_r121    0.362604  0.779762  0.709677
# 214        NeuralNetTorch_r158    0.361899  0.755952  0.709677
# 215             NeuralNetTorch    0.359162  0.767857  0.677419
# 216       NeuralNetFastAI_r100    0.350530  0.755952  0.709677
# 217   NeuralNetTorch_r197_FULL    0.347821  0.738095  0.741935
#
#      balanced_accuracy        f1  f1_macro  f1_micro  average_precision  \
# 0             0.980000  0.933333  0.956463  0.968750           1.000000
# 1             0.960000  0.875000  0.916667  0.937500           1.000000
# 2             0.880000  0.700000  0.781818  0.812500           0.982143
# 3             0.940000  0.823529  0.879850  0.906250           0.982143
# 4             0.940000  0.823529  0.879850  0.906250           0.982143
# ..                 ...       ...       ...       ...                ...
# 213           0.508929  0.181818  0.502674  0.709677           0.428937
# 214           0.559524  0.307692  0.562009  0.709677           0.418764
# 215           0.538690  0.285714  0.538690  0.677419           0.414683
# 216           0.660714  0.470588  0.635294  0.709677           0.415672
# 217           0.580357  0.333333  0.586667  0.741935           0.403651
#
#      precision  ...                                    hyperparameters  \
# 0     0.875000  ...  {'layers': [800, 400], 'emb_drop': 0.696080552...
# 1     0.777778  ...  {'layers': [400, 200, 100], 'emb_drop': 0.6656...
# 2     0.538462  ...  {'num_epochs': 12, 'epochs_wo_improve': None, ...
# 3     0.700000  ...  {'layers': [400, 200, 100], 'emb_drop': 0.3171...
# 4     0.700000  ...  {'layers': [800, 400], 'emb_drop': 0.086691092...
# ..         ...  ...                                                ...
# 213   0.250000  ...  {'num_epochs': 1000, 'epochs_wo_improve': None...
# 214   0.333333  ...  {'num_epochs': 1000, 'epochs_wo_improve': None...
# 215   0.285714  ...  {'num_epochs': 1000, 'epochs_wo_improve': None...
# 216   0.400000  ...  {'layers': [800, 400], 'emb_drop': 0.696080552...
# 217   0.400000  ...  {'num_epochs': 7, 'epochs_wo_improve': None, '...
#
#                       hyperparameters_fit  \
# 0        {'epochs': 38, 'best_epoch': 10}
# 1         {'epochs': 32, 'best_epoch': 3}
# 2     {'batch_size': 32, 'num_epochs': 0}
# 3        {'epochs': 20, 'best_epoch': 13}
# 4         {'epochs': 45, 'best_epoch': 8}
# ..                                    ...
# 213  {'batch_size': 32, 'num_epochs': 10}
# 214   {'batch_size': 32, 'num_epochs': 8}
# 215  {'batch_size': 32, 'num_epochs': 14}
# 216       {'epochs': 38, 'best_epoch': 7}
# 217   {'batch_size': 32, 'num_epochs': 0}
#
#                                            ag_args_fit  \
# 0    {'max_memory_usage_ratio': 1.15, 'max_time_lim...
# 1    {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 2    {'max_memory_usage_ratio': 1.15, 'max_time_lim...
# 3    {'max_memory_usage_ratio': 1.15, 'max_time_lim...
# 4    {'max_memory_usage_ratio': 1.15, 'max_time_lim...
# ..                                                 ...
# 213  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 214  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 215  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 216  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 217  {'max_memory_usage_ratio': 1.15, 'max_time_lim...
#
#                                               features compile_time  \
# 0    ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 1    ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 2    ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 3    ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 4    ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# ..                                                 ...          ...
# 213  ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 214  ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 215  ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 216  ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
# 217  ['clin-reservaCognitiva_escolaridad', 'demo-ed...          NaN
#
#      child_hyperparameters  child_hyperparameters_fit  child_ag_args_fit  \
# 0                      NaN                        NaN                NaN
# 1                      NaN                        NaN                NaN
# 2                      NaN                        NaN                NaN
# 3                      NaN                        NaN                NaN
# 4                      NaN                        NaN                NaN
# ..                     ...                        ...                ...
# 213                    NaN                        NaN                NaN
# 214                    NaN                        NaN                NaN
# 215                    NaN                        NaN                NaN
# 216                    NaN                        NaN                NaN
# 217                    NaN                        NaN                NaN
#
#      ancestors                   descendants
# 0           []  ['WeightedEnsemble_L2_FULL']
# 1           []                            []
# 2           []                            []
# 3           []                            []
# 4           []                            []
# ..         ...                           ...
# 213         []                            []
# 214         []                            []
# 215         []                            []
# 216         []                            []
# 217         []                            []
#
# [2180 rows x 46 columns]

# %% [markdown]
# #### Hay 10 entradas por cada modelo

# %%
df.groupby(['model']).size()
# Out:
# model
# CatBoost              10
# CatBoost_FULL         10
# CatBoost_r12          10
# CatBoost_r128         10
# CatBoost_r128_FULL    10
#                       ..
# XGBoost_r89_FULL      10
# XGBoost_r95           10
# XGBoost_r95_FULL      10
# XGBoost_r98           10
# XGBoost_r98_FULL      10
# Length: 218, dtype: int64

# %%
df.groupby('model').count()
# Out:
#                     score_test  roc_auc  accuracy  balanced_accuracy  f1  \
# model
# CatBoost                    10       10        10                 10  10
# CatBoost_FULL               10       10        10                 10  10
# CatBoost_r12                10       10        10                 10  10
# CatBoost_r128               10       10        10                 10  10
# CatBoost_r128_FULL          10       10        10                 10  10
# ...                        ...      ...       ...                ...  ..
# XGBoost_r89_FULL            10       10        10                 10  10
# XGBoost_r95                 10       10        10                 10  10
# XGBoost_r95_FULL            10       10        10                 10  10
# XGBoost_r98                 10       10        10                 10  10
# XGBoost_r98_FULL            10       10        10                 10  10
#
#                     f1_macro  f1_micro  average_precision  precision  recall  \
# model
# CatBoost                  10        10                 10         10      10
# CatBoost_FULL             10        10                 10         10      10
# CatBoost_r12              10        10                 10         10      10
# CatBoost_r128             10        10                 10         10      10
# CatBoost_r128_FULL        10        10                 10         10      10
# ...                      ...       ...                ...        ...     ...
# XGBoost_r89_FULL          10        10                 10         10      10
# XGBoost_r95               10        10                 10         10      10
# XGBoost_r95_FULL          10        10                 10         10      10
# XGBoost_r98               10        10                 10         10      10
# XGBoost_r98_FULL          10        10                 10         10      10
#
#                     ...  hyperparameters  hyperparameters_fit  ag_args_fit  \
# model               ...
# CatBoost            ...               10                   10           10
# CatBoost_FULL       ...               10                   10           10
# CatBoost_r12        ...               10                   10           10
# CatBoost_r128       ...               10                   10           10
# CatBoost_r128_FULL  ...               10                   10           10
# ...                 ...              ...                  ...          ...
# XGBoost_r89_FULL    ...               10                   10           10
# XGBoost_r95         ...               10                   10           10
# XGBoost_r95_FULL    ...               10                   10           10
# XGBoost_r98         ...               10                   10           10
# XGBoost_r98_FULL    ...               10                   10           10
#
#                     features  compile_time  child_hyperparameters  \
# model
# CatBoost                  10             0                      0
# CatBoost_FULL             10             0                      0
# CatBoost_r12              10             0                      0
# CatBoost_r128             10             0                      0
# CatBoost_r128_FULL        10             0                      0
# ...                      ...           ...                    ...
# XGBoost_r89_FULL          10             0                      0
# XGBoost_r95               10             0                      0
# XGBoost_r95_FULL          10             0                      0
# XGBoost_r98               10             0                      0
# XGBoost_r98_FULL          10             0                      0
#
#                     child_hyperparameters_fit  child_ag_args_fit  ancestors  \
# model
# CatBoost                                    0                  0         10
# CatBoost_FULL                               0                  0         10
# CatBoost_r12                                0                  0         10
# CatBoost_r128                               0                  0         10
# CatBoost_r128_FULL                          0                  0         10
# ...                                       ...                ...        ...
# XGBoost_r89_FULL                            0                  0         10
# XGBoost_r95                                 0                  0         10
# XGBoost_r95_FULL                            0                  0         10
# XGBoost_r98                                 0                  0         10
# XGBoost_r98_FULL                            0                  0         10
#
#                     descendants
# model
# CatBoost                     10
# CatBoost_FULL                10
# CatBoost_r12                 10
# CatBoost_r128                10
# CatBoost_r128_FULL           10
# ...                         ...
# XGBoost_r89_FULL             10
# XGBoost_r95                  10
# XGBoost_r95_FULL             10
# XGBoost_r98                  10
# XGBoost_r98_FULL             10
#
# [218 rows x 45 columns]

# %%
# Calcular media por modelo
top_models = (
    df.groupby("model")["roc_auc"]
    .mean()
    .sort_values(ascending=False)
    .head(5)  # Top 20 modelos con mayor media
    .index
)

# Filtrar el DataFrame
df_top = df[df["model"].isin(top_models)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Estilo
sns.set_theme(style="whitegrid", context="talk", palette="deep")

# Altura proporcional a la cantidad de modelos seleccionados
num_models = df_top["model"].nunique()
fig_height = 1.2 * num_models
fig, ax = plt.subplots(figsize=(10, fig_height))

# Boxplot
sns.boxplot(
    data=df_top, x="roc_auc", y="model", hue="model",
    whis=[0, 100], width=0.4, palette="Blues", 
    linewidth=1.5, fliersize=0
)

# Stripplot
sns.stripplot(
    data=df_top, x="roc_auc", y="model", size=6, 
    color="black", alpha=0.6, jitter=0.25
)

# Etiquetas y estilo
ax.set_title("Top Modelos por Media de ROC AUC", fontsize=18, fontweight="bold")
ax.set_xlabel("ROC AUC", fontsize=14)
ax.set_ylabel("")

# Límites del eje X ajustados
ax.set_xlim(0.8, 1.0)

# Cuadrícula y diseño
ax.xaxis.grid(True, linestyle="--", alpha=0.6)
sns.despine(trim=True, left=True)
plt.tight_layout()
plt.show()
