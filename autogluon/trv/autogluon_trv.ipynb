# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('../../data/trv/TRV_Identia.xlsx')

# %%
VARS = ["ISC.FPacientes.IDUsuario",
"ISC.FPacientes.etiquetaDiagnosticaExpTLP",
"ED_2Clases",
"ISC.FPacientes.etiquetaDiagnostica",
"ED_MMSE_2Clases",
"ISC.FPacientes.genero",
"ISC.FPacientes.Edad",
"ISC.resultadosCovid.numDosis",
"ISC.resultadosCovid.numVecesCovid",
"ISC.resultadosCovid.numVecesCovid_mode",
"ISC.resultadosCovid.pasadoCovid",
"ISC.resultadosCovid.sentimientoAislado",
"ISC.resultadosCovid.sentimientoAislado_mediaFiltro",
"ISC.resultadosCovid.sentimientoAislado_mode",
"ISC.resultadosCovid.sintomaCansancio",
"ISC.resultadosCovid.sintomaDiarrea",
"ISC.resultadosCovid.sintomaDifRespirar",
"ISC.resultadosCovid.sintomaDolCabeza",
"ISC.resultadosCovid.sintomaDolGarganta",
"ISC.resultadosCovid.sintomaDolMuscular",
"ISC.resultadosCovid.sintomaEscalofrios",
"ISC.resultadosCovid.sintomaFiebre",
"ISC.resultadosCovid.sintomaOtro",
"ISC.resultadosCovid.sintomaOtroString",
"ISC.resultadosCovid.sintomaPerGusto",
"ISC.resultadosCovid.sintomaPerOlfato",
"ISC.resultadosCovid.vacunado",
"ISC.resultadosCribaje.Total.PD",
"ISC.resultadosObservacion.alcohol",
"ISC.resultadosObservacion.ansiedad",
"ISC.resultadosObservacion.añosSinFumar",
"ISC.resultadosObservacion.añosSinFumar_Rangos",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn",
"ISC.resultadosObservacion.depresion",
"ISC.resultadosObservacion.enfermedadesAltTiroides",
"ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos",
"ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica",
"ISC.resultadosObservacion.enfermedadesDiabetes",
"ISC.resultadosObservacion.enfermedadesHepatica",
"ISC.resultadosObservacion.enfermedadesHipercolesterolemia",
"ISC.resultadosObservacion.enfermedadesHipertension",
"ISC.resultadosObservacion.enfermedadesNinguna",
"ISC.resultadosObservacion.enfermedadesOtros",
"ISC.resultadosObservacion.enfermedadesOtrosString",
"ISC.resultadosObservacion.enfermedadesRenal",
"ISC.resultadosObservacion.entorno",
"ISC.resultadosObservacion.familiaresAlzheimer",
"ISC.resultadosObservacion.familiaresOtraDemencia",
"ISC.resultadosObservacion.fumador",
"ISC.resultadosObservacion.numCigarros",
"ISC.resultadosObservacion.numCigarrosDia_knn",
"ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad",
"ISC.resultadosObservacion.tratCronico",
"ISC.resultadosObservacion.tratPsicologic",
"ISC.resultadosObservacion.tratPsiquiatrico",
"ISC.resultadosOtros.frecOlvidos",
"ISC.resultadosOtros.frecUsoEmail",
"ISC.resultadosOtros.frecUsoMovil",
"ISC.resultadosOtros.frecUsoOrdenador",
"ISC.resultadosOtros.frecUsoRSociales",
"ISC.resultadosOtros.frecUsoTele",
"ISC.resultadosOtros.nivelActFisica",
"ISC.resultadosOtros.nivelSociabilidad",
"ISC.resultadosReservaCognitiva.Total.PD",
"ISC.resultadosReservaCognitiva.actividadLectora",
"ISC.resultadosReservaCognitiva.cursos",
"ISC.resultadosReservaCognitiva.escolaridad",
"ISC.resultadosReservaCognitiva.escolaridadPadres",
"ISC.resultadosReservaCognitiva.formacionMusical",
"ISC.resultadosReservaCognitiva.idiomas",
"ISC.resultadosReservaCognitiva.juegos",
"ISC.resultadosReservaCognitiva.ocupacion",
"ISC.resultadosWFQ.DE_array",
"ISC.resultadosWFQ.DE_total.PD",
"ISC.resultadosWFQ.NO_array",
"ISC.resultadosWFQ.NO_total.PD",
"ISC.resultadosWFQ.SA_array",
"ISC.resultadosWFQ.SA_total.PD",
"TRV.LeidenNT.CaminosRuta_total.PD",
"TRV.LeidenNT.CaminosTopgrafico_total.PD",
"TRV.LeidenNT.Orden_total.PD",
"TRV.LeidenNT.PuntoReferencia_total.PD",
"TRV.LeidenNT.UbicacionAlocentrica_total.PD",
"TRV.LeidenNT.UbicacionEgocentrico_total.PD",
"TRV.Stroop.color.PD",
"TRV.Stroop.color.PDC",
"TRV.Stroop.interferencia.PD",
"TRV.Stroop.palabras.PD",
"TRV.Stroop.palabras.PDC",
"TRV.Stroop.palabrasColor.PD",
"TRV.Stroop.palabrasColor.PDC",
"TRV.Tavec.00_RI-A1.PD",
"TRV.Tavec.01_RI-A5.PD",
"TRV.Tavec.02_RI-AT.PD",
"TRV.Tavec.03_RI-B.PD",
"TRV.Tavec.04_Rg-Pr.PD",
"TRV.Tavec.05_Rg-Md.PD",
"TRV.Tavec.06_Rg-Rc.PD",
"TRV.Tavec.07_RL-CP.PD",
"TRV.Tavec.08_RCl-CP.PD",
"TRV.Tavec.09_RL-LP.PD",
"TRV.Tavec.10_RCl-LP.PD",
"TRV.Tavec.11_ESem-RI-A.PD",
"TRV.Tavec.12_ESem-RI-B.PD",
"TRV.Tavec.13_ESem-RL-CP.PD",
"TRV.Tavec.14_ESem-RL-LP.PD",
"TRV.Tavec.15_ESer-RI-A.PD",
"TRV.Tavec.16_ESer-RI-B.PD",
"TRV.Tavec.17_ESer-RL-CP.PD",
"TRV.Tavec.18_ESer-RL-LP.PD",
"TRV.Tavec.19_P.PD",
"TRV.Tavec.20_I-RL.PD",
"TRV.Tavec.21_I-RCL.PD",
"TRV.Tavec.22_Recon-Ac.PD",
"TRV.Tavec.23_FP.PD",
"TRV.Tavec.24_Discriminabilidad.PD",
"TRV.Tavec.25_Sesgo.PD",
"TRV.Tavec.26_RI-B_frente_RI-A1.PD",
"TRV.Tavec.27_RL-CP_frente_RI-A5.PD",
"TRV.Tavec.28_RCl-Cp_frente_RCl-LP.PD",
"TRV.Tavec.29_RL-LP_frente_RL-CP.PD",
"TRV.Tavec.30_RCl-LP_frente_RL-LP.PD",
"TRV.Tavec.31_Recon-Ac_frente_RL-LP.PD",
"TRV.Tavec.32_Recon-Ac_frente_RCl-LP.PD"
]

VARS = [
'ISC.resultadosReservaCognitiva.Total.PD',
'ISC.resultadosReservaCognitiva.escolaridad',
'ISC.resultadosObservacion.enfermedadesDiabetes',
'ISC.resultadosObservacion.alcohol',
'TRV.LeidenNT.UbicacionAlocentrica_total.PD',
'TRV.LeidenNT.PuntoReferencia_total.PD',
'TRV.LeidenNT.CaminosTopgrafico_total.PD',
'TRV.Stroop.palabras.PD',
'TRV.Stroop.color.PD',
#'TRV.Stroop.palabras.PDC',
'TRV.Tavec.12_ESem-RI-B.PD',
'TRV.Tavec.10_RCl-LP.PD',
'TRV.Tavec.05_Rg-Md.PD',
'ISC.FPacientes.genero',
'TRV.Tavec.20_I-RL.PD',
'TRV.Tavec.17_ESer-RL-CP.PD',
'TRV.Tavec.14_ESem-RL-LP.PD',
'TRV.Tavec.24_Discriminabilidad.PD']

CLASS = 'ED_2Clases'

drop_columns = []
for v in df.columns:
    if not v in VARS+[CLASS]:
        drop_columns.append(v)

# %%
drop_columns
# Out:
# ['ISC.FPacientes.IDUsuario',
#  'ISC.FPacientes.etiquetaDiagnosticaExpTLP',
#  'ISC.FPacientes.etiquetaDiagnostica',
#  'ED_MMSE_2Clases',
#  'ISC.FPacientes.Edad',
#  'ISC.resultadosCovid.numDosis',
#  'ISC.resultadosCovid.numVecesCovid',
#  'ISC.resultadosCovid.numVecesCovid_mode',
#  'ISC.resultadosCovid.pasadoCovid',
#  'ISC.resultadosCovid.sentimientoAislado',
#  'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
#  'ISC.resultadosCovid.sentimientoAislado_mode',
#  'ISC.resultadosCovid.sintomaCansancio',
#  'ISC.resultadosCovid.sintomaDiarrea',
#  'ISC.resultadosCovid.sintomaDifRespirar',
#  'ISC.resultadosCovid.sintomaDolCabeza',
#  'ISC.resultadosCovid.sintomaDolGarganta',
#  'ISC.resultadosCovid.sintomaDolMuscular',
#  'ISC.resultadosCovid.sintomaEscalofrios',
#  'ISC.resultadosCovid.sintomaFiebre',
#  'ISC.resultadosCovid.sintomaOtro',
#  'ISC.resultadosCovid.sintomaOtroString',
#  'ISC.resultadosCovid.sintomaPerGusto',
#  'ISC.resultadosCovid.sintomaPerOlfato',
#  'ISC.resultadosCovid.vacunado',
#  'ISC.resultadosCribaje.Total.PD',
#  'ISC.resultadosObservacion.ansiedad',
#  'ISC.resultadosObservacion.añosSinFumar',
#  'ISC.resultadosObservacion.añosSinFumar_Rangos',
#  'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
#  'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
#  'ISC.resultadosObservacion.depresion',
#  'ISC.resultadosObservacion.enfermedadesAltTiroides',
#  'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
#  'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
#  'ISC.resultadosObservacion.enfermedadesHepatica',
#  'ISC.resultadosObservacion.enfermedadesHipercolesterolemia',
#  'ISC.resultadosObservacion.enfermedadesHipertension',
#  'ISC.resultadosObservacion.enfermedadesNinguna',
#  'ISC.resultadosObservacion.enfermedadesOtros',
#  'ISC.resultadosObservacion.enfermedadesOtrosString',
#  'ISC.resultadosObservacion.enfermedadesRenal',
#  'ISC.resultadosObservacion.entorno',
#  'ISC.resultadosObservacion.familiaresAlzheimer',
#  'ISC.resultadosObservacion.familiaresOtraDemencia',
#  'ISC.resultadosObservacion.fumador',
#  'ISC.resultadosObservacion.numCigarros',
#  'ISC.resultadosObservacion.numCigarrosDia_knn',
#  'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
#  'ISC.resultadosObservacion.tratCronico',
#  'ISC.resultadosObservacion.tratPsicologic',
#  'ISC.resultadosObservacion.tratPsiquiatrico',
#  'ISC.resultadosOtros.frecOlvidos',
#  'ISC.resultadosOtros.frecUsoEmail',
#  'ISC.resultadosOtros.frecUsoMovil',
#  'ISC.resultadosOtros.frecUsoOrdenador',
#  'ISC.resultadosOtros.frecUsoRSociales',
#  'ISC.resultadosOtros.frecUsoTele',
#  'ISC.resultadosOtros.nivelActFisica',
#  'ISC.resultadosOtros.nivelSociabilidad',
#  'ISC.resultadosReservaCognitiva.actividadLectora',
#  'ISC.resultadosReservaCognitiva.cursos',
#  'ISC.resultadosReservaCognitiva.escolaridadPadres',
#  'ISC.resultadosReservaCognitiva.formacionMusical',
#  'ISC.resultadosReservaCognitiva.idiomas',
#  'ISC.resultadosReservaCognitiva.juegos',
#  'ISC.resultadosReservaCognitiva.ocupacion',
#  'ISC.resultadosWFQ.DE_array',
#  'ISC.resultadosWFQ.DE_total.PD',
#  'ISC.resultadosWFQ.NO_array',
#  'ISC.resultadosWFQ.NO_total.PD',
#  'ISC.resultadosWFQ.SA_array',
#  'ISC.resultadosWFQ.SA_total.PD',
#  'TRV.LeidenNT.CaminosRuta_total.PD',
#  'TRV.LeidenNT.Orden_total.PD',
#  'TRV.LeidenNT.UbicacionEgocentrico_total.PD',
#  'TRV.Stroop.color.PDC',
#  'TRV.Stroop.interferencia.PD',
#  'TRV.Stroop.palabras.PDC',
#  'TRV.Stroop.palabrasColor.PD',
#  'TRV.Stroop.palabrasColor.PDC',
#  'TRV.Tavec.00_RI-A1.PD',
#  'TRV.Tavec.01_RI-A5.PD',
#  'TRV.Tavec.02_RI-AT.PD',
#  'TRV.Tavec.03_RI-B.PD',
#  'TRV.Tavec.04_Rg-Pr.PD',
#  'TRV.Tavec.06_Rg-Rc.PD',
#  'TRV.Tavec.07_RL-CP.PD',
#  'TRV.Tavec.08_RCl-CP.PD',
#  'TRV.Tavec.09_RL-LP.PD',
#  'TRV.Tavec.11_ESem-RI-A.PD',
#  'TRV.Tavec.13_ESem-RL-CP.PD',
#  'TRV.Tavec.15_ESer-RI-A.PD',
#  'TRV.Tavec.16_ESer-RI-B.PD',
#  'TRV.Tavec.18_ESer-RL-LP.PD',
#  'TRV.Tavec.19_P.PD',
#  'TRV.Tavec.21_I-RCL.PD',
#  'TRV.Tavec.22_Recon-Ac.PD',
#  'TRV.Tavec.23_FP.PD',
#  'TRV.Tavec.25_Sesgo.PD',
#  'TRV.Tavec.26_RI-B_frente_RI-A1.PD',
#  'TRV.Tavec.27_RL-CP_frente_RI-A5.PD',
#  'TRV.Tavec.28_RCl-Cp_frente_RCl-LP.PD',
#  'TRV.Tavec.29_RL-LP_frente_RL-CP.PD',
#  'TRV.Tavec.30_RCl-LP_frente_RL-LP.PD',
#  'TRV.Tavec.31_Recon-Ac_frente_RL-LP.PD',
#  'TRV.Tavec.32_Recon-Ac_frente_RCl-LP.PD']

# %%
df.drop(columns=drop_columns, inplace=True)

# %%
categorical_columns = [
    'ED_2Clases'
]

# %%
df[categorical_columns] = df[categorical_columns].astype('object')

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.resultadosObservacion.alcohol  \
# 0          D                      2                              False
# 1          D                      2                              False
# 2          H                      2                              False
# 3          D                      2                              False
# 4          D                      2                              False
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ISC.resultadosReservaCognitiva.Total.PD  \
# 0                                       12
# 1                                        8
# 2                                       11
# 3                                       18
# 4                                       13
#
#    ISC.resultadosReservaCognitiva.escolaridad  \
# 0                                           3
# 1                                           3
# 2                                           4
# 3                                           4
# 4                                           4
#
#    TRV.LeidenNT.CaminosTopgrafico_total.PD  \
# 0                                        2
# 1                                        1
# 2                                        3
# 3                                        4
# 4                                        2
#
#    TRV.LeidenNT.PuntoReferencia_total.PD  \
# 0                                      8
# 1                                      7
# 2                                      8
# 3                                      8
# 4                                      6
#
#    TRV.LeidenNT.UbicacionAlocentrica_total.PD  TRV.Stroop.color.PD  \
# 0                                           1                   27
# 1                                           1                   17
# 2                                           1                   40
# 3                                           3                   46
# 4                                           0                   32
#
#    TRV.Stroop.palabras.PD  TRV.Tavec.05_Rg-Md.PD  TRV.Tavec.10_RCl-LP.PD  \
# 0                      33              50.000000                      12
# 1                      18              45.714286                       8
# 2                      45              50.000000                      13
# 3                      51              48.648649                      12
# 4                      35              46.153846                      15
#
#    TRV.Tavec.12_ESem-RI-B.PD  TRV.Tavec.14_ESem-RL-LP.PD  \
# 0                          0                           1
# 1                          2                           2
# 2                          0                           3
# 3                          3                           2
# 4                          0                           3
#
#    TRV.Tavec.17_ESer-RL-CP.PD  TRV.Tavec.20_I-RL.PD  \
# 0                           1                    10
# 1                           1                    34
# 2                           5                     3
# 3                           1                     3
# 4                           0                     4
#
#    TRV.Tavec.24_Discriminabilidad.PD
# 0                          81.818182
# 1                          68.181818
# 2                          88.636364
# 3                          90.909091
# 4                          93.181818

# %%
df_train, df_test=train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((245, 18), (62, 18))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/real/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       10.54 GB / 15.94 GB (66.1%)
# Disk Space Avail:   124.54 GB / 446.36 GB (27.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 15:45:25,944	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/real/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=32232) Running DyStack sub-fit ...
# (_dystack pid=32232) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=32232) Beginning AutoGluon training ... Time limit = 895s
# (_dystack pid=32232) AutoGluon will save models to "AutogluonModels/real/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=32232) Train Data Rows:    217
# (_dystack pid=32232) Train Data Columns: 17
# (_dystack pid=32232) Label Column:       ED_2Clases
# (_dystack pid=32232) Problem Type:       binary
# (_dystack pid=32232) Preprocessing data ...
# (_dystack pid=32232) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=32232) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=32232) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=32232) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=32232) Using Feature Generators to preprocess the data ...
# (_dystack pid=32232) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=32232) 	Available Memory:                    10223.56 MB
# (_dystack pid=32232) 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# (_dystack pid=32232) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=32232) 	Stage 1 Generators:
# (_dystack pid=32232) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=32232) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=32232) 	Stage 2 Generators:
# (_dystack pid=32232) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=32232) 	Stage 3 Generators:
# (_dystack pid=32232) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=32232) 	Stage 4 Generators:
# (_dystack pid=32232) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=32232) 	Stage 5 Generators:
# (_dystack pid=32232) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=32232) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=32232) 		('bool', [])  :  2 | ['ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=32232) 		('float', []) :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=32232) 		('int', [])   : 13 | ['ISC.FPacientes.genero', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', ...]
# (_dystack pid=32232) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=32232) 		('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=32232) 		('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# (_dystack pid=32232) 		('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=32232) 	0.0s = Fit runtime
# (_dystack pid=32232) 	17 features in original data used to generate 17 features in processed data.
# (_dystack pid=32232) 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=32232) Data preprocessing and feature engineering runtime = 0.04s ...
# (_dystack pid=32232) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=32232) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=32232) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=32232) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=32232) User-specified model hyperparameters to be fit:
# (_dystack pid=32232) {
# (_dystack pid=32232) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=32232) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=32232) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=32232) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=32232) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=32232) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=32232) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=32232) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=32232) }
# (_dystack pid=32232) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=32232) Fitting 110 L1 models ...
# (_dystack pid=32232) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 596.62s of the 895.15s of remaining time.
# (_dystack pid=32232) 	0.6386	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.0s	 = Training   runtime
# (_dystack pid=32232) 	0.03s	 = Validation runtime
# (_dystack pid=32232) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 594.45s of the 892.98s of remaining time.
# (_dystack pid=32232) 	0.6641	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.0s	 = Training   runtime
# (_dystack pid=32232) 	0.03s	 = Validation runtime
# (_dystack pid=32232) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.41s of the 892.94s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_dystack pid=32232) 	0.7534	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.75s	 = Training   runtime
# (_dystack pid=32232) 	0.01s	 = Validation runtime
# (_dystack pid=32232) Fitting model: LightGBM_BAG_L1 ... Training model for up to 590.38s of the 888.9s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=32232) 	0.7589	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.71s	 = Training   runtime
# (_dystack pid=32232) 	0.01s	 = Validation runtime
# (_dystack pid=32232) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 586.04s of the 884.57s of remaining time.
# (_dystack pid=32232) 	0.7396	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.79s	 = Training   runtime
# (_dystack pid=32232) 	0.08s	 = Validation runtime
# (_dystack pid=32232) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 585.14s of the 883.67s of remaining time.
# (_dystack pid=32232) 	0.7397	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.53s	 = Training   runtime
# (_dystack pid=32232) 	0.06s	 = Validation runtime
# (_dystack pid=32232) Fitting model: CatBoost_BAG_L1 ... Training model for up to 584.52s of the 883.05s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# (_dystack pid=32232) 	0.7868	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	1.7s	 = Training   runtime
# (_dystack pid=32232) 	0.03s	 = Validation runtime
# (_dystack pid=32232) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 579.66s of the 878.19s of remaining time.
# (_dystack pid=32232) 	0.716	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.71s	 = Training   runtime
# (_dystack pid=32232) 	0.09s	 = Validation runtime
# (_dystack pid=32232) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 578.83s of the 877.36s of remaining time.
# (_dystack pid=32232) 	0.722	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.51s	 = Training   runtime
# (_dystack pid=32232) 	0.06s	 = Validation runtime
# (_dystack pid=32232) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 578.22s of the 876.75s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=32232) 	0.6999	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	6.67s	 = Training   runtime
# (_dystack pid=32232) 	0.11s	 = Validation runtime
# (_dystack pid=32232) Fitting model: XGBoost_BAG_L1 ... Training model for up to 568.28s of the 866.81s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_dystack pid=32232) 	0.7474	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.96s	 = Training   runtime
# (_dystack pid=32232) 	0.03s	 = Validation runtime
# (_dystack pid=32232) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 562.16s of the 860.69s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=7496) Stack (most recent call first):
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7496)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=7496)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=32232) 	0.7382	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	16.8s	 = Training   runtime
# (_dystack pid=32232) 	0.1s	 = Validation runtime
# (_dystack pid=32232) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 541.04s of the 839.57s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_ray_fit pid=29024) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=29024)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=32232) 	0.6893	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.79s	 = Training   runtime
# (_dystack pid=32232) 	0.01s	 = Validation runtime
# (_dystack pid=32232) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 536.49s of the 835.02s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=32232) 	0.7975	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	2.8s	 = Training   runtime
# (_dystack pid=32232) 	0.02s	 = Validation runtime
# (_dystack pid=32232) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 528.58s of the 827.11s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=20824) Stack (most recent call first):
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=20824)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=20824)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=32232) 	0.7612	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	12.87s	 = Training   runtime
# (_dystack pid=32232) 	0.1s	 = Validation runtime
# (_dystack pid=32232) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 511.48s of the 810.01s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_ray_fit pid=22652) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=22652)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=32232) 	0.7553	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	0.93s	 = Training   runtime
# (_dystack pid=32232) 	0.02s	 = Validation runtime
# (_dystack pid=32232) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 506.97s of the 805.5s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=32232) 	0.6857	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	8.62s	 = Training   runtime
# (_dystack pid=32232) 	0.04s	 = Validation runtime
# (_dystack pid=32232) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 494.72s of the 793.25s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=32232) 	0.7798	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	4.28s	 = Training   runtime
# (_dystack pid=32232) 	0.05s	 = Validation runtime
# (_dystack pid=32232) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 486.96s of the 785.5s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=16084) [1000]	valid_set's binary_logloss: 0.486286
# (_dystack pid=32232) 	0.7987	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	5.45s	 = Training   runtime
# (_dystack pid=32232) 	0.03s	 = Validation runtime
# (_dystack pid=32232) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 477.94s of the 776.47s of remaining time.
# (_dystack pid=32232) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=19952) Stack (most recent call first):
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=19952)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=19952)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=32232) 	0.7466	 = Validation score   (roc_auc)
# (_dystack pid=32232) 	11.65s	 = Training   runtime
# (_dystack pid=32232) 	0.1s	 = Validation runtime
# (_dystack pid=32232) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 462.95s of the 761.48s of remaining time.
# (_ray_fit pid=15352) Stack (most recent call first): [repeated 7x across cluster]
# ...
# 	5.87s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 2120.61s of the 2120.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.6879	 = Validation score   (roc_auc)
# 	7.31s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 2110.36s of the 2110.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7443	 = Validation score   (roc_auc)
# 	14.55s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 2091.98s of the 2091.97s of remaining time.
# 	0.7276	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 2091.23s of the 2091.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7436	 = Validation score   (roc_auc)
# 	12.12s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 2074.12s of the 2074.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7008	 = Validation score   (roc_auc)
# 	9.02s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 2062.59s of the 2062.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.7173	 = Validation score   (roc_auc)
# 	2.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 2057.7s of the 2057.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.7584	 = Validation score   (roc_auc)
# 	1.89s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 2052.96s of the 2052.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7549	 = Validation score   (roc_auc)
# 	2.36s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 2046.97s of the 2046.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7609	 = Validation score   (roc_auc)
# 	19.59s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 2021.62s of the 2021.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7408	 = Validation score   (roc_auc)
# 	31.34s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 1987.7s of the 1987.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.7715	 = Validation score   (roc_auc)
# 	2.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 1981.81s of the 1981.81s of remaining time.
# 	0.7478	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 1980.76s of the 1980.76s of remaining time.
# 	0.7406	 = Validation score   (roc_auc)
# 	0.83s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 1979.81s of the 1979.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.743	 = Validation score   (roc_auc)
# 	3.29s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 1973.95s of the 1973.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7235	 = Validation score   (roc_auc)
# 	28.57s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 1942.94s of the 1942.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.6569	 = Validation score   (roc_auc)
# 	5.77s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 1933.93s of the 1933.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.773	 = Validation score   (roc_auc)
# 	2.28s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 1928.29s of the 1928.29s of remaining time.
# 	0.7265	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 1927.25s of the 1927.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	0.8092	 = Validation score   (roc_auc)
# 	2.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 1922.37s of the 1922.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.7658	 = Validation score   (roc_auc)
# 	2.22s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 1917.58s of the 1917.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7133	 = Validation score   (roc_auc)
# 	5.99s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 1908.53s of the 1908.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.7633	 = Validation score   (roc_auc)
# 	2.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 1902.27s of the 1902.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.6851	 = Validation score   (roc_auc)
# 	6.83s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 1892.39s of the 1892.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.7675	 = Validation score   (roc_auc)
# 	1.62s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 1886.66s of the 1886.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.714	 = Validation score   (roc_auc)
# 	8.05s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 1875.16s of the 1875.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.7773	 = Validation score   (roc_auc)
# 	3.6s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 1867.9s of the 1867.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7637	 = Validation score   (roc_auc)
# 	24.16s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 1841.08s of the 1841.08s of remaining time.
# 	0.7378	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 1840.19s of the 1840.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7248	 = Validation score   (roc_auc)
# 	29.02s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 1809.11s of the 1809.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7324	 = Validation score   (roc_auc)
# 	8.65s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 1798.44s of the 1798.44s of remaining time.
# 	0.7148	 = Validation score   (roc_auc)
# 	1.04s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 1797.26s of the 1797.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7387	 = Validation score   (roc_auc)
# 	8.88s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 1786.03s of the 1786.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7568	 = Validation score   (roc_auc)
# 	2.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 1779.01s of the 1779.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7661	 = Validation score   (roc_auc)
# 	13.28s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 1762.82s of the 1762.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7481	 = Validation score   (roc_auc)
# 	9.3s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTrees_r126_BAG_L1 ... Training model for up to 1750.35s of the 1750.35s of remaining time.
# 	0.7423	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 1749.51s of the 1749.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7145	 = Validation score   (roc_auc)
# 	23.92s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 1723.1s of the 1723.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7158	 = Validation score   (roc_auc)
# 	12.15s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r163_BAG_L1 ... Training model for up to 1707.96s of the 1707.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7716	 = Validation score   (roc_auc)
# 	2.55s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r198_BAG_L1 ... Training model for up to 1702.31s of the 1702.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.7663	 = Validation score   (roc_auc)
# 	2.57s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 1696.65s of the 1696.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7658	 = Validation score   (roc_auc)
# 	8.26s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 1685.38s of the 1685.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7412	 = Validation score   (roc_auc)
# 	11.27s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_r95_BAG_L1 ... Training model for up to 1671.12s of the 1671.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.7506	 = Validation score   (roc_auc)
# 	6.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost_r34_BAG_L1 ... Training model for up to 1661.71s of the 1661.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.762	 = Validation score   (roc_auc)
# 	1.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L1 ... Training model for up to 1657.21s of the 1657.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	0.7399	 = Validation score   (roc_auc)
# 	4.82s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 1650.0s of the 1650.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7166	 = Validation score   (roc_auc)
# 	13.93s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 1633.36s of the 1633.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.7375	 = Validation score   (roc_auc)
# 	24.87s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1603.57s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r102_BAG_L1': 0.188, 'LightGBM_r130_BAG_L1': 0.188, 'LightGBM_r135_BAG_L1': 0.188, 'CatBoost_r180_BAG_L1': 0.125, 'NeuralNetFastAI_r187_BAG_L1': 0.125, 'NeuralNetTorch_r87_BAG_L1': 0.062, 'NeuralNetTorch_r76_BAG_L1': 0.062, 'NeuralNetTorch_r135_BAG_L1': 0.062}
# 	0.8608	 = Validation score   (roc_auc)
# 	0.14s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1078.57s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 70.1 rows/s (31 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/real/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L2   0.860828     roc_auc       0.442216  81.147807                0.000000           0.144139            2       True        111
# 1           LightGBM_r130_BAG_L1   0.811508     roc_auc       0.001512   2.651809                0.001512           2.651809            1       True         31
# 2           LightGBM_r135_BAG_L1   0.809240     roc_auc       0.004017   2.475472                0.004017           2.475472            1       True         82
# 3            CatBoost_r50_BAG_L1   0.784675     roc_auc       0.020862   3.243916                0.020862           3.243916            1       True         33
# 4            CatBoost_r70_BAG_L1   0.783541     roc_auc       0.023326   3.083571                0.023326           3.083571            1       True         42
# 5           CatBoost_r180_BAG_L1   0.777305     roc_auc       0.022025   3.604423                0.022025           3.604423            1       True         89
# 6            CatBoost_r49_BAG_L1   0.777116     roc_auc       0.019500  11.273321                0.019500          11.273321            1       True         55
# 7    NeuralNetFastAI_r102_BAG_L1   0.776077     roc_auc       0.070679   6.986489                0.070679           6.986489            1       True         24
# 8            CatBoost_r60_BAG_L1   0.772959     roc_auc       0.027172   2.281235                0.027172           2.281235            1       True         80
# 9            LightGBM_r96_BAG_L1   0.772581     roc_auc       0.021650   5.258573                0.021650           5.258573            1       True         19
# 10          CatBoost_r167_BAG_L1   0.772487     roc_auc       0.021555   3.018396                0.021555           3.018396            1       True         46
# 11           CatBoost_r86_BAG_L1   0.772014     roc_auc       0.018509   6.018641                0.018509           6.018641            1       True         52
# 12          CatBoost_r163_BAG_L1   0.771636     roc_auc       0.019005   2.547593                0.019005           2.547593            1       True        102
# 13          CatBoost_r143_BAG_L1   0.771542     roc_auc       0.035974   2.777992                0.035974           2.777992            1       True         74
# 14           CatBoost_r13_BAG_L1   0.770975     roc_auc       0.043384   3.539665                0.043384           3.539665            1       True         25
# 15     NeuralNetTorch_r30_BAG_L1   0.770503     roc_auc       0.114328  24.762595                0.114328          24.762595            1       True         30
# 16          LightGBM_r121_BAG_L1   0.767479     roc_auc       0.020509   1.617772                0.020509           1.617772            1       True         87
# 17               LightGBM_BAG_L1   0.766912     roc_auc       0.018040   1.964599                0.018040           1.964599            1       True          4
# 18          CatBoost_r198_BAG_L1   0.766251     roc_auc       0.020006   2.565689                0.020006           2.565689            1       True        103
# 19          LightGBM_r161_BAG_L1   0.766062     roc_auc       0.017993   5.304497                0.017993           5.304497            1       True         40
# 20   NeuralNetFastAI_r143_BAG_L1   0.766062     roc_auc       0.073232   8.792580                0.073232           8.792580            1       True         41
# 21    NeuralNetTorch_r135_BAG_L1   0.766062     roc_auc       0.102332  13.276743                0.102332          13.276743            1       True         97
# 22            XGBoost_r22_BAG_L1   0.765779     roc_auc       0.053440   2.215240                0.053440           2.215240            1       True         83
# 23   NeuralNetFastAI_r187_BAG_L1   0.765779     roc_auc       0.071531   8.260377                0.071531           8.260377            1       True        104
# 24            CatBoost_r9_BAG_L1   0.764550     roc_auc       0.032007   5.701053                0.032007           5.701053            1       True         18
# 25     NeuralNetTorch_r76_BAG_L1   0.763700     roc_auc       0.094640  24.157483                0.094640          24.157483            1       True         90
# 26            CatBoost_r6_BAG_L1   0.763322     roc_auc       0.015592   2.252848                0.015592           2.252848            1       True         85
# 27               CatBoost_BAG_L1   0.762661     roc_auc       0.021596   2.944695                0.021596           2.944695            1       True          7
# 28          CatBoost_r137_BAG_L1   0.762566     roc_auc       0.024365   2.441384                0.024365           2.441384            1       True         23
# 29            XGBoost_r34_BAG_L1   0.761999     roc_auc       0.013992   1.963597                0.013992           1.963597            1       True        107
# 30     NeuralNetTorch_r87_BAG_L1   0.760865     roc_auc       0.075480  19.590873                0.075480          19.590873            1       True         72
# 31            XGBoost_r89_BAG_L1   0.760393     roc_auc       0.042917   1.850639                0.042917           1.850639            1       True         29
# 32    NeuralNetTorch_r158_BAG_L1   0.760299     roc_auc       0.089292  17.957540                0.089292          17.957540            1       True         51
# 33                XGBoost_BAG_L1   0.760110     roc_auc       0.017034   2.138697                0.017034           2.138697            1       True         11
# 34            XGBoost_r49_BAG_L1   0.758409     roc_auc       0.020097   1.894316                0.020097           1.894316            1       True         70
# 35           CatBoost_r12_BAG_L1   0.756803     roc_auc       0.006366   2.786487                0.006366           2.786487            1       True         96
# 36            CatBoost_r5_BAG_L1   0.754913     roc_auc       0.020928   2.359693                0.020928           2.359693            1       True         71
# 37           CatBoost_r69_BAG_L1   0.754724     roc_auc       0.019951   2.630142                0.019951           2.630142            1       True         37
# 38    NeuralNetTorch_r197_BAG_L1   0.754630     roc_auc       0.126718  16.796286                0.126718          16.796286            1       True         54
# 39            XGBoost_r98_BAG_L1   0.753023     roc_auc       0.031283   6.277362                0.031283           6.277362            1       True         49
# 40            XGBoost_r33_BAG_L1   0.752079     roc_auc       0.019778   3.124882                0.019778           3.124882            1       True         21
# 41            XGBoost_r95_BAG_L1   0.750614     roc_auc       0.004985   6.737458                0.004985           6.737458            1       True        106
# 42           LightGBM_r15_BAG_L1   0.750378     roc_auc       0.007799   1.638838                0.007799           1.638838            1       True         50
# 43         ExtraTreesEntr_BAG_L1   0.749480     roc_auc       0.063411   0.615895                0.063411           0.615895            1       True          9
# 44          CatBoost_r177_BAG_L1   0.748819     roc_auc       0.033627   2.445865                0.033627           2.445865            1       True         14
# 45          LightGBM_r143_BAG_L1   0.748583     roc_auc       0.015486   1.760696                0.015486           1.760696            1       True         57
# 46         ExtraTrees_r42_BAG_L1   0.748347     roc_auc       0.078925   0.567748                0.078925           0.567748            1       True         22
# 47     NeuralNetTorch_r22_BAG_L1   0.748205     roc_auc       0.084611  21.530974                0.084611          21.530974            1       True         20
# 48     NeuralNetFastAI_r4_BAG_L1   0.748110     roc_auc       0.074970   9.302306                0.074970           9.302306            1       True         98
# 49        ExtraTrees_r178_BAG_L1   0.747827     roc_auc       0.074891   0.937819                0.074891           0.937819            1       True         75
# 50   NeuralNetFastAI_r191_BAG_L1   0.746032     roc_auc       0.087240  10.358381                0.087240          10.358381            1       True         17
# 51           XGBoost_r194_BAG_L1   0.745134     roc_auc       0.042119   2.705261                0.042119           2.705261            1       True         35
# 52     NeuralNetTorch_r31_BAG_L1   0.744331     roc_auc       0.105609  14.549782                0.105609          14.549782            1       True         65
# 53          LightGBMLarge_BAG_L1   0.744048     roc_auc       0.017502   1.352059                0.017502           1.352059            1       True         13
# 54          CatBoost_r128_BAG_L1   0.743717     roc_auc       0.013973   5.872588                0.013973           5.872588            1       True         63
# 55    NeuralNetFastAI_r65_BAG_L1   0.743575     roc_auc       0.079075  12.118476                0.079075          12.118476            1       True         67
# 56            XGBoost_r31_BAG_L1   0.743008     roc_auc       0.014683   3.287572                0.014683           3.287572            1       True         77
# 57        ExtraTrees_r126_BAG_L1   0.742252     roc_auc       0.083114   0.698743                0.083114           0.698743            1       True         99
# 58        ExtraTrees_r172_BAG_L1   0.742252     roc_auc       0.064102   0.521256                0.064102           0.521256            1       True         36
# 59          LightGBM_r131_BAG_L1   0.741875     roc_auc       0.000000   4.062809                0.000000           4.062809            1       True         16
# 60     NeuralNetTorch_r19_BAG_L1   0.741213     roc_auc       0.078681  11.269662                0.078681          11.269662            1       True        105
# 61     NeuralNetTorch_r71_BAG_L1   0.740835     roc_auc       0.129108  31.341927                0.129108          31.341927            1       True         73
# 62      RandomForest_r166_BAG_L1   0.740646     roc_auc       0.068199   0.831863                0.068199           0.831863            1       True         76
# 63       RandomForestGini_BAG_L1   0.740646     roc_auc       0.078959   0.679573                0.078959           0.679573            1       True          5
# 64           LightGBM_r42_BAG_L1   0.739890     roc_auc       0.016922   4.820275                0.016922           4.820275            1       True        108
# 65   NeuralNetFastAI_r194_BAG_L1   0.738662     roc_auc       0.100400   8.883850                0.100400           8.883850            1       True         95
# 66        ExtraTrees_r197_BAG_L1   0.737812     roc_auc       0.080033   0.775390                0.080033           0.775390            1       True         91
# 67     NeuralNetTorch_r89_BAG_L1   0.737528     roc_auc       0.113466  24.866933                0.113466          24.866933            1       True        110
# 68           LightGBM_r94_BAG_L1   0.737056     roc_auc       0.013861   1.687316                0.013861           1.687316            1       True         61
# 69         ExtraTrees_r49_BAG_L1   0.735119     roc_auc       0.075040   0.820242                0.075040           0.820242            1       True         56
# 70         ExtraTreesGini_BAG_L1   0.735119     roc_auc       0.078932   0.723998                0.078932           0.723998            1       True          8
# 71       RandomForestEntr_BAG_L1   0.733985     roc_auc       0.079155   0.554525                0.079155           0.554525            1       True          6
# 72   NeuralNetFastAI_r127_BAG_L1   0.732426     roc_auc       0.080333   8.648170                0.080333           8.648170            1       True         93
# 73         NeuralNetTorch_BAG_L1   0.731765     roc_auc       0.072488  33.826530                0.072488          33.826530            1       True         12
# 74          LightGBM_r196_BAG_L1   0.731293     roc_auc       0.040234   2.227424                0.040234           2.227424            1       True         44
# 75      RandomForest_r195_BAG_L1   0.728978     roc_auc       0.063718   0.789617                0.063718           0.789617            1       True         26
# 76     NeuralNetTorch_r86_BAG_L1   0.727702     roc_auc       0.110418  21.540117                0.110418          21.540117            1       True         32
# 77          ExtraTrees_r4_BAG_L1   0.727608     roc_auc       0.071862   0.568670                0.071862           0.568670            1       True         66
# 78       RandomForest_r15_BAG_L1   0.726474     roc_auc       0.072208   0.917010                0.072208           0.917010            1       True         81
# 79   NeuralNetFastAI_r156_BAG_L1   0.726285     roc_auc       0.052125   7.336916                0.052125           7.336916            1       True         43
# 80    NeuralNetTorch_r143_BAG_L1   0.725907     roc_auc       0.091434  19.713165                0.091434          19.713165            1       True         62
# 81     NeuralNetTorch_r79_BAG_L1   0.725624     roc_auc       0.106708  13.446657                0.106708          13.446657            1       True         15
# 82          LightGBM_r188_BAG_L1   0.724773     roc_auc       0.009580   1.664364                0.009580           1.664364            1       True         27
# 83    NeuralNetTorch_r121_BAG_L1   0.724773     roc_auc       0.118888  29.018728                0.118888          29.018728            1       True         92
# 84    NeuralNetTorch_r185_BAG_L1   0.723450     roc_auc       0.112641  28.573646                0.112641          28.573646            1       True         78
# 85   NeuralNetFastAI_r134_BAG_L1   0.722600     roc_auc       0.082186   9.785403                0.082186           9.785403            1       True         59
# 86     NeuralNetTorch_r41_BAG_L1   0.720522     roc_auc       0.065553  18.475261                0.065553          18.475261            1       True         48
# 87     NeuralNetTorch_r14_BAG_L1   0.719104     roc_auc       0.110664  26.948570                0.110664          26.948570            1       True         39
# 88             LightGBMXT_BAG_L1   0.718537     roc_auc       0.000000   3.014051                0.000000           3.014051            1       True          3
# 89           LightGBM_r30_BAG_L1   0.717309     roc_auc       0.011573   2.075438                0.011573           2.075438            1       True         69
# 90      RandomForest_r127_BAG_L1   0.717309     roc_auc       0.075505   0.948747                0.075505           0.948747            1       True         58
# 91      NeuralNetTorch_r1_BAG_L1   0.716648     roc_auc       0.112712  13.929529                0.112712          13.929529            1       True        109
# 92       RandomForest_r39_BAG_L1   0.715892     roc_auc       0.063856   0.599866                0.063856           0.599866            1       True         45
# 93   NeuralNetFastAI_r100_BAG_L1   0.715797     roc_auc       0.088046  12.146972                0.088046          12.146972            1       True        101
# 94       RandomForest_r16_BAG_L1   0.714805     roc_auc       0.085346   1.037293                0.085346           1.037293            1       True         94
# 95   NeuralNetFastAI_r145_BAG_L1   0.714664     roc_auc       0.048559   6.164361                0.048559           6.164361            1       True         28
# 96     NeuralNetTorch_r36_BAG_L1   0.714475     roc_auc       0.098520  23.918204                0.098520          23.918204            1       True        100
# 97   NeuralNetFastAI_r172_BAG_L1   0.714002     roc_auc       0.062985   8.045950                0.062985           8.045950            1       True         88
# 98    NeuralNetFastAI_r69_BAG_L1   0.713341     roc_auc       0.063790   5.986928                0.063790           5.986928            1       True         84
# 99        NeuralNetFastAI_BAG_L1   0.703420     roc_auc       0.104931   7.795887                0.104931           7.795887            1       True         10
# 100   NeuralNetFastAI_r88_BAG_L1   0.700775     roc_auc       0.078093   9.015967                0.078093           9.015967            1       True         68
# 101      RandomForest_r34_BAG_L1   0.700208     roc_auc       0.077568   0.625370                0.077568           0.625370            1       True         60
# 102   NeuralNetFastAI_r37_BAG_L1   0.699924     roc_auc       0.067618   8.646983                0.067618           8.646983            1       True         53
# 103   NeuralNetFastAI_r11_BAG_L1   0.699358     roc_auc       0.111122   6.457543                0.111122           6.457543            1       True         34
# 104   NeuralNetFastAI_r95_BAG_L1   0.695484     roc_auc       0.047952   6.200335                0.047952           6.200335            1       True         47
# 105  NeuralNetFastAI_r103_BAG_L1   0.694539     roc_auc       0.080672   8.492143                0.080672           8.492143            1       True         38
# 106  NeuralNetFastAI_r111_BAG_L1   0.687925     roc_auc       0.092247   7.308355                0.092247           7.308355            1       True         64
# 107  NeuralNetFastAI_r138_BAG_L1   0.685091     roc_auc       0.080191   6.828713                0.080191           6.828713            1       True         86
# 108  NeuralNetFastAI_r160_BAG_L1   0.656935     roc_auc       0.084579   5.774335                0.084579           5.774335            1       True         79
# 109        KNeighborsDist_BAG_L1   0.638133     roc_auc       0.031416   0.000000                0.031416           0.000000            1       True          2
# 110        KNeighborsUnif_BAG_L1   0.626842     roc_auc       0.025662   0.005081                0.025662           0.005081            1       True          1
# Number of models trained: 111
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# ('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# ('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# Plot summary of models saved to file: AutogluonModels/real/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r37_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r160_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetFastAI_r69_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r138_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r172_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r127_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r194_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r4_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r100_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r187_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r19_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r42_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r1_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r89_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6268424036281179,
#   'KNeighborsDist_BAG_L1': 0.6381330309901738,
#   'LightGBMXT_BAG_L1': 0.7185374149659864,
#   'LightGBM_BAG_L1': 0.766912320483749,
#   'RandomForestGini_BAG_L1': 0.7406462585034013,
#   'RandomForestEntr_BAG_L1': 0.7339852607709747,
#   'CatBoost_BAG_L1': 0.7626606198034769,
#   'ExtraTreesGini_BAG_L1': 0.7351190476190476,
#   'ExtraTreesEntr_BAG_L1': 0.7494803476946333,
#   'NeuralNetFastAI_BAG_L1': 0.7034202569916855,
#   'XGBoost_BAG_L1': 0.7601095993953136,
#   'NeuralNetTorch_BAG_L1': 0.7317649281934997,
#   'LightGBMLarge_BAG_L1': 0.7440476190476191,
#   'CatBoost_r177_BAG_L1': 0.7488189720332576,
#   'NeuralNetTorch_r79_BAG_L1': 0.7256235827664399,
#   'LightGBM_r131_BAG_L1': 0.7418745275888132,
#   'NeuralNetFastAI_r191_BAG_L1': 0.7460317460317459,
#   'CatBoost_r9_BAG_L1': 0.7645502645502646,
#   'LightGBM_r96_BAG_L1': 0.7725812547241118,
#   'NeuralNetTorch_r22_BAG_L1': 0.7482048374905517,
#   'XGBoost_r33_BAG_L1': 0.7520786092214664,
#   'ExtraTrees_r42_BAG_L1': 0.7483465608465605,
#   'CatBoost_r137_BAG_L1': 0.7625661375661374,
#   'NeuralNetFastAI_r102_BAG_L1': 0.7760770975056689,
#   'CatBoost_r13_BAG_L1': 0.7709750566893423,
#   'RandomForest_r195_BAG_L1': 0.7289777021919879,
#   'LightGBM_r188_BAG_L1': 0.7247732426303855,
#   'NeuralNetFastAI_r145_BAG_L1': 0.7146636432350719,
#   'XGBoost_r89_BAG_L1': 0.7603930461073318,
#   'NeuralNetTorch_r30_BAG_L1': 0.7705026455026455,
#   'LightGBM_r130_BAG_L1': 0.8115079365079365,
#   'NeuralNetTorch_r86_BAG_L1': 0.7277021919879063,
#   'CatBoost_r50_BAG_L1': 0.7846749811035525,
#   'NeuralNetFastAI_r11_BAG_L1': 0.6993575207860923,
#   'XGBoost_r194_BAG_L1': 0.745134164777022,
#   'ExtraTrees_r172_BAG_L1': 0.7422524565381706,
#   'CatBoost_r69_BAG_L1': 0.754724111866969,
#   'NeuralNetFastAI_r103_BAG_L1': 0.6945389266817839,
#   'NeuralNetTorch_r14_BAG_L1': 0.7191043083900227,
#   'LightGBM_r161_BAG_L1': 0.7660619803476947,
#   'NeuralNetFastAI_r143_BAG_L1': 0.7660619803476947,
#   'CatBoost_r70_BAG_L1': 0.78354119425548,
#   'NeuralNetFastAI_r156_BAG_L1': 0.7262849584278155,
#   'LightGBM_r196_BAG_L1': 0.7312925170068028,
#   'RandomForest_r39_BAG_L1': 0.7158919123204837,
#   'CatBoost_r167_BAG_L1': 0.7724867724867724,
#   'NeuralNetFastAI_r95_BAG_L1': 0.6954837490551776,
#   'NeuralNetTorch_r41_BAG_L1': 0.7205215419501134,
#   'XGBoost_r98_BAG_L1': 0.7530234315948602,
#   'LightGBM_r15_BAG_L1': 0.7503779289493575,
#   'NeuralNetTorch_r158_BAG_L1': 0.7602985638699925,
#   'CatBoost_r86_BAG_L1': 0.7720143613000756,
#   'NeuralNetFastAI_r37_BAG_L1': 0.6999244142101285,
#   'NeuralNetTorch_r197_BAG_L1': 0.7546296296296297,
#   'CatBoost_r49_BAG_L1': 0.7771164021164021,
#   'ExtraTrees_r49_BAG_L1': 0.7351190476190476,
#   'LightGBM_r143_BAG_L1': 0.7485827664399093,
#   'RandomForest_r127_BAG_L1': 0.7173091458805745,
#   'NeuralNetFastAI_r134_BAG_L1': 0.7226001511715798,
#   'RandomForest_r34_BAG_L1': 0.7002078609221466,
#   'LightGBM_r94_BAG_L1': 0.7370559334845049,
#   'NeuralNetTorch_r143_BAG_L1': 0.7259070294784581,
#   'CatBoost_r128_BAG_L1': 0.7437169312169312,
#   'NeuralNetFastAI_r111_BAG_L1': 0.6879251700680273,
#   'NeuralNetTorch_r31_BAG_L1': 0.7443310657596371,
#   'ExtraTrees_r4_BAG_L1': 0.7276077097505667,
#   'NeuralNetFastAI_r65_BAG_L1': 0.7435752078609221,
#   'NeuralNetFastAI_r88_BAG_L1': 0.700774754346183,
#   'LightGBM_r30_BAG_L1': 0.7173091458805745,
#   'XGBoost_r49_BAG_L1': 0.7584089191232048,
#   'CatBoost_r5_BAG_L1': 0.7549130763416478,
#   'NeuralNetTorch_r87_BAG_L1': 0.7608654572940285,
#   'NeuralNetTorch_r71_BAG_L1': 0.7408352229780801,
#   'CatBoost_r143_BAG_L1': 0.7715419501133788,
#   'ExtraTrees_r178_BAG_L1': 0.747826908541194,
#   'RandomForest_r166_BAG_L1': 0.7406462585034013,
#   'XGBoost_r31_BAG_L1': 0.7430083144368859,
#   'NeuralNetTorch_r185_BAG_L1': 0.7234504913076343,
#   'NeuralNetFastAI_r160_BAG_L1': 0.6569349962207106,
#   'CatBoost_r60_BAG_L1': 0.7729591836734694,
#   'RandomForest_r15_BAG_L1': 0.7264739229024945,
#   'LightGBM_r135_BAG_L1': 0.8092403628117915,
#   'XGBoost_r22_BAG_L1': 0.7657785336356767,
#   'NeuralNetFastAI_r69_BAG_L1': 0.7133408919123205,
#   'CatBoost_r6_BAG_L1': 0.7633219954648526,
#   'NeuralNetFastAI_r138_BAG_L1': 0.6850907029478458,
#   'LightGBM_r121_BAG_L1': 0.7674792139077854,
#   'NeuralNetFastAI_r172_BAG_L1': 0.7140022675736961,
#   'CatBoost_r180_BAG_L1': 0.777305366591081,
#   'NeuralNetTorch_r76_BAG_L1': 0.7636999244142101,
#   'ExtraTrees_r197_BAG_L1': 0.73781179138322,
#   'NeuralNetTorch_r121_BAG_L1': 0.7247732426303855,
#   'NeuralNetFastAI_r127_BAG_L1': 0.7324263038548753,
#   'RandomForest_r16_BAG_L1': 0.7148053665910808,
#   'NeuralNetFastAI_r194_BAG_L1': 0.7386621315192744,
#   'CatBoost_r12_BAG_L1': 0.7568027210884354,
#   'NeuralNetTorch_r135_BAG_L1': 0.7660619803476946,
#   'NeuralNetFastAI_r4_BAG_L1': 0.7481103552532125,
#   'ExtraTrees_r126_BAG_L1': 0.7422524565381707,
#   'NeuralNetTorch_r36_BAG_L1': 0.7144746787603931,
#   'NeuralNetFastAI_r100_BAG_L1': 0.7157974300831444,
#   'CatBoost_r163_BAG_L1': 0.7716364323507181,
#   'CatBoost_r198_BAG_L1': 0.7662509448223734,
#   'NeuralNetFastAI_r187_BAG_L1': 0.7657785336356765,
#   'NeuralNetTorch_r19_BAG_L1': 0.7412131519274376,
#   'XGBoost_r95_BAG_L1': 0.750614134542706,
#   'XGBoost_r34_BAG_L1': 0.7619992441421013,
#   'LightGBM_r42_BAG_L1': 0.7398904006046862,
#   'NeuralNetTorch_r1_BAG_L1': 0.7166477702191989,
#   'NeuralNetTorch_r89_BAG_L1': 0.7375283446712018,
#   'WeightedEnsemble_L2': 0.8608276643990931},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetFastAI_r95_BAG_L1': ['NeuralNetFastAI_r95_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetFastAI_r37_BAG_L1': ['NeuralNetFastAI_r37_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'NeuralNetFastAI_r134_BAG_L1': ['NeuralNetFastAI_r134_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetFastAI_r111_BAG_L1': ['NeuralNetFastAI_r111_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'NeuralNetFastAI_r65_BAG_L1': ['NeuralNetFastAI_r65_BAG_L1'],
#   'NeuralNetFastAI_r88_BAG_L1': ['NeuralNetFastAI_r88_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'NeuralNetFastAI_r160_BAG_L1': ['NeuralNetFastAI_r160_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'NeuralNetFastAI_r69_BAG_L1': ['NeuralNetFastAI_r69_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'NeuralNetFastAI_r138_BAG_L1': ['NeuralNetFastAI_r138_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'NeuralNetFastAI_r172_BAG_L1': ['NeuralNetFastAI_r172_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'NeuralNetFastAI_r127_BAG_L1': ['NeuralNetFastAI_r127_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'NeuralNetFastAI_r194_BAG_L1': ['NeuralNetFastAI_r194_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'NeuralNetFastAI_r4_BAG_L1': ['NeuralNetFastAI_r4_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'NeuralNetTorch_r36_BAG_L1': ['NeuralNetTorch_r36_BAG_L1'],
#   'NeuralNetFastAI_r100_BAG_L1': ['NeuralNetFastAI_r100_BAG_L1'],
#   'CatBoost_r163_BAG_L1': ['CatBoost_r163_BAG_L1'],
#   'CatBoost_r198_BAG_L1': ['CatBoost_r198_BAG_L1'],
#   'NeuralNetFastAI_r187_BAG_L1': ['NeuralNetFastAI_r187_BAG_L1'],
#   'NeuralNetTorch_r19_BAG_L1': ['NeuralNetTorch_r19_BAG_L1'],
#   'XGBoost_r95_BAG_L1': ['XGBoost_r95_BAG_L1'],
#   'XGBoost_r34_BAG_L1': ['XGBoost_r34_BAG_L1'],
#   'LightGBM_r42_BAG_L1': ['LightGBM_r42_BAG_L1'],
#   'NeuralNetTorch_r1_BAG_L1': ['NeuralNetTorch_r1_BAG_L1'],
#   'NeuralNetTorch_r89_BAG_L1': ['NeuralNetTorch_r89_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0050814151763916016,
#   'KNeighborsDist_BAG_L1': 0.0,
#   'LightGBMXT_BAG_L1': 3.0140511989593506,
#   'LightGBM_BAG_L1': 1.9645986557006836,
#   'RandomForestGini_BAG_L1': 0.679572582244873,
#   'RandomForestEntr_BAG_L1': 0.5545246601104736,
#   'CatBoost_BAG_L1': 2.944695234298706,
#   'ExtraTreesGini_BAG_L1': 0.7239980697631836,
#   'ExtraTreesEntr_BAG_L1': 0.6158950328826904,
#   'NeuralNetFastAI_BAG_L1': 7.795887470245361,
#   'XGBoost_BAG_L1': 2.138697385787964,
#   'NeuralNetTorch_BAG_L1': 33.82653045654297,
#   'LightGBMLarge_BAG_L1': 1.3520588874816895,
#   'CatBoost_r177_BAG_L1': 2.4458651542663574,
#   'NeuralNetTorch_r79_BAG_L1': 13.446656942367554,
#   'LightGBM_r131_BAG_L1': 4.062808513641357,
#   'NeuralNetFastAI_r191_BAG_L1': 10.358381032943726,
#   'CatBoost_r9_BAG_L1': 5.701053142547607,
#   'LightGBM_r96_BAG_L1': 5.258572578430176,
#   'NeuralNetTorch_r22_BAG_L1': 21.53097414970398,
#   'XGBoost_r33_BAG_L1': 3.1248819828033447,
#   'ExtraTrees_r42_BAG_L1': 0.5677480697631836,
#   'CatBoost_r137_BAG_L1': 2.4413838386535645,
#   'NeuralNetFastAI_r102_BAG_L1': 6.986488580703735,
#   'CatBoost_r13_BAG_L1': 3.5396649837493896,
#   'RandomForest_r195_BAG_L1': 0.7896170616149902,
#   'LightGBM_r188_BAG_L1': 1.6643636226654053,
#   'NeuralNetFastAI_r145_BAG_L1': 6.164361000061035,
#   'XGBoost_r89_BAG_L1': 1.8506386280059814,
#   'NeuralNetTorch_r30_BAG_L1': 24.7625949382782,
#   'LightGBM_r130_BAG_L1': 2.651808738708496,
#   'NeuralNetTorch_r86_BAG_L1': 21.540117263793945,
#   'CatBoost_r50_BAG_L1': 3.2439160346984863,
#   'NeuralNetFastAI_r11_BAG_L1': 6.45754337310791,
#   'XGBoost_r194_BAG_L1': 2.7052605152130127,
#   'ExtraTrees_r172_BAG_L1': 0.5212564468383789,
#   'CatBoost_r69_BAG_L1': 2.6301419734954834,
#   'NeuralNetFastAI_r103_BAG_L1': 8.492142915725708,
#   'NeuralNetTorch_r14_BAG_L1': 26.948570251464844,
#   'LightGBM_r161_BAG_L1': 5.304497480392456,
#   'NeuralNetFastAI_r143_BAG_L1': 8.792580366134644,
#   'CatBoost_r70_BAG_L1': 3.083571195602417,
#   'NeuralNetFastAI_r156_BAG_L1': 7.336916446685791,
#   'LightGBM_r196_BAG_L1': 2.227423667907715,
#   'RandomForest_r39_BAG_L1': 0.5998661518096924,
#   'CatBoost_r167_BAG_L1': 3.0183961391448975,
#   'NeuralNetFastAI_r95_BAG_L1': 6.2003350257873535,
#   'NeuralNetTorch_r41_BAG_L1': 18.475260734558105,
#   'XGBoost_r98_BAG_L1': 6.277362108230591,
#   'LightGBM_r15_BAG_L1': 1.6388378143310547,
#   'NeuralNetTorch_r158_BAG_L1': 17.957539558410645,
#   'CatBoost_r86_BAG_L1': 6.018640995025635,
#   'NeuralNetFastAI_r37_BAG_L1': 8.64698338508606,
#   'NeuralNetTorch_r197_BAG_L1': 16.79628586769104,
#   'CatBoost_r49_BAG_L1': 11.27332091331482,
#   'ExtraTrees_r49_BAG_L1': 0.820242166519165,
#   'LightGBM_r143_BAG_L1': 1.7606964111328125,
#   'RandomForest_r127_BAG_L1': 0.9487466812133789,
#   'NeuralNetFastAI_r134_BAG_L1': 9.785402536392212,
#   'RandomForest_r34_BAG_L1': 0.6253697872161865,
#   'LightGBM_r94_BAG_L1': 1.6873164176940918,
#   'NeuralNetTorch_r143_BAG_L1': 19.713165283203125,
#   'CatBoost_r128_BAG_L1': 5.8725879192352295,
#   'NeuralNetFastAI_r111_BAG_L1': 7.308355331420898,
#   'NeuralNetTorch_r31_BAG_L1': 14.549781799316406,
#   'ExtraTrees_r4_BAG_L1': 0.5686700344085693,
#   'NeuralNetFastAI_r65_BAG_L1': 12.118475914001465,
#   'NeuralNetFastAI_r88_BAG_L1': 9.01596713066101,
#   'LightGBM_r30_BAG_L1': 2.075437545776367,
#   'XGBoost_r49_BAG_L1': 1.8943159580230713,
#   'CatBoost_r5_BAG_L1': 2.3596932888031006,
#   'NeuralNetTorch_r87_BAG_L1': 19.59087347984314,
#   'NeuralNetTorch_r71_BAG_L1': 31.34192705154419,
#   'CatBoost_r143_BAG_L1': 2.7779924869537354,
#   'ExtraTrees_r178_BAG_L1': 0.937819242477417,
#   'RandomForest_r166_BAG_L1': 0.8318626880645752,
#   'XGBoost_r31_BAG_L1': 3.2875723838806152,
#   'NeuralNetTorch_r185_BAG_L1': 28.573646068572998,
#   'NeuralNetFastAI_r160_BAG_L1': 5.7743353843688965,
#   'CatBoost_r60_BAG_L1': 2.281235456466675,
#   'RandomForest_r15_BAG_L1': 0.9170095920562744,
#   'LightGBM_r135_BAG_L1': 2.4754717350006104,
#   'XGBoost_r22_BAG_L1': 2.215240478515625,
#   'NeuralNetFastAI_r69_BAG_L1': 5.9869279861450195,
#   'CatBoost_r6_BAG_L1': 2.2528483867645264,
#   'NeuralNetFastAI_r138_BAG_L1': 6.8287129402160645,
#   'LightGBM_r121_BAG_L1': 1.6177716255187988,
#   'NeuralNetFastAI_r172_BAG_L1': 8.045950174331665,
#   'CatBoost_r180_BAG_L1': 3.6044225692749023,
#   'NeuralNetTorch_r76_BAG_L1': 24.157483100891113,
#   'ExtraTrees_r197_BAG_L1': 0.7753903865814209,
#   'NeuralNetTorch_r121_BAG_L1': 29.01872754096985,
#   'NeuralNetFastAI_r127_BAG_L1': 8.648169994354248,
#   'RandomForest_r16_BAG_L1': 1.0372934341430664,
#   'NeuralNetFastAI_r194_BAG_L1': 8.883850336074829,
#   'CatBoost_r12_BAG_L1': 2.786487102508545,
#   'NeuralNetTorch_r135_BAG_L1': 13.276743173599243,
#   'NeuralNetFastAI_r4_BAG_L1': 9.302305698394775,
#   'ExtraTrees_r126_BAG_L1': 0.6987433433532715,
#   'NeuralNetTorch_r36_BAG_L1': 23.918203592300415,
#   'NeuralNetFastAI_r100_BAG_L1': 12.146972179412842,
#   'CatBoost_r163_BAG_L1': 2.547592878341675,
#   'CatBoost_r198_BAG_L1': 2.5656888484954834,
#   'NeuralNetFastAI_r187_BAG_L1': 8.260376930236816,
#   'NeuralNetTorch_r19_BAG_L1': 11.269662141799927,
#   'XGBoost_r95_BAG_L1': 6.737457752227783,
#   'XGBoost_r34_BAG_L1': 1.963597297668457,
#   'LightGBM_r42_BAG_L1': 4.820274591445923,
#   'NeuralNetTorch_r1_BAG_L1': 13.929528951644897,
#   'NeuralNetTorch_r89_BAG_L1': 24.86693286895752,
#   'WeightedEnsemble_L2': 0.14413881301879883},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.025661945343017578,
#   'KNeighborsDist_BAG_L1': 0.03141617774963379,
#   'LightGBMXT_BAG_L1': 0.0,
#   'LightGBM_BAG_L1': 0.018039941787719727,
#   'RandomForestGini_BAG_L1': 0.07895851135253906,
#   'RandomForestEntr_BAG_L1': 0.07915544509887695,
#   'CatBoost_BAG_L1': 0.021596193313598633,
#   'ExtraTreesGini_BAG_L1': 0.07893180847167969,
#   'ExtraTreesEntr_BAG_L1': 0.06341099739074707,
#   'NeuralNetFastAI_BAG_L1': 0.10493087768554688,
#   'XGBoost_BAG_L1': 0.017034053802490234,
#   'NeuralNetTorch_BAG_L1': 0.07248806953430176,
#   'LightGBMLarge_BAG_L1': 0.0175015926361084,
#   'CatBoost_r177_BAG_L1': 0.03362679481506348,
#   'NeuralNetTorch_r79_BAG_L1': 0.10670757293701172,
#   'LightGBM_r131_BAG_L1': 0.0,
#   'NeuralNetFastAI_r191_BAG_L1': 0.08724021911621094,
#   'CatBoost_r9_BAG_L1': 0.03200650215148926,
#   'LightGBM_r96_BAG_L1': 0.021649599075317383,
#   'NeuralNetTorch_r22_BAG_L1': 0.08461117744445801,
#   'XGBoost_r33_BAG_L1': 0.01977849006652832,
#   'ExtraTrees_r42_BAG_L1': 0.07892465591430664,
#   'CatBoost_r137_BAG_L1': 0.024364948272705078,
#   'NeuralNetFastAI_r102_BAG_L1': 0.0706789493560791,
#   'CatBoost_r13_BAG_L1': 0.04338431358337402,
#   'RandomForest_r195_BAG_L1': 0.06371760368347168,
#   'LightGBM_r188_BAG_L1': 0.009580373764038086,
#   'NeuralNetFastAI_r145_BAG_L1': 0.048558950424194336,
#   'XGBoost_r89_BAG_L1': 0.04291653633117676,
#   'NeuralNetTorch_r30_BAG_L1': 0.11432814598083496,
#   'LightGBM_r130_BAG_L1': 0.001512289047241211,
#   'NeuralNetTorch_r86_BAG_L1': 0.11041808128356934,
#   'CatBoost_r50_BAG_L1': 0.020862340927124023,
#   'NeuralNetFastAI_r11_BAG_L1': 0.11112165451049805,
#   'XGBoost_r194_BAG_L1': 0.04211854934692383,
#   'ExtraTrees_r172_BAG_L1': 0.0641024112701416,
#   'CatBoost_r69_BAG_L1': 0.01995062828063965,
#   'NeuralNetFastAI_r103_BAG_L1': 0.08067178726196289,
#   'NeuralNetTorch_r14_BAG_L1': 0.11066412925720215,
#   'LightGBM_r161_BAG_L1': 0.017993450164794922,
#   'NeuralNetFastAI_r143_BAG_L1': 0.07323169708251953,
#   'CatBoost_r70_BAG_L1': 0.02332592010498047,
#   'NeuralNetFastAI_r156_BAG_L1': 0.052124738693237305,
#   'LightGBM_r196_BAG_L1': 0.04023385047912598,
#   'RandomForest_r39_BAG_L1': 0.06385588645935059,
#   'CatBoost_r167_BAG_L1': 0.021555423736572266,
#   'NeuralNetFastAI_r95_BAG_L1': 0.04795193672180176,
#   'NeuralNetTorch_r41_BAG_L1': 0.06555294990539551,
#   'XGBoost_r98_BAG_L1': 0.03128314018249512,
#   'LightGBM_r15_BAG_L1': 0.007798671722412109,
#   'NeuralNetTorch_r158_BAG_L1': 0.08929228782653809,
#   'CatBoost_r86_BAG_L1': 0.0185089111328125,
#   'NeuralNetFastAI_r37_BAG_L1': 0.06761837005615234,
#   'NeuralNetTorch_r197_BAG_L1': 0.12671804428100586,
#   'CatBoost_r49_BAG_L1': 0.019500255584716797,
#   'ExtraTrees_r49_BAG_L1': 0.07503962516784668,
#   'LightGBM_r143_BAG_L1': 0.015486478805541992,
#   'RandomForest_r127_BAG_L1': 0.07550477981567383,
#   'NeuralNetFastAI_r134_BAG_L1': 0.08218622207641602,
#   'RandomForest_r34_BAG_L1': 0.07756805419921875,
#   'LightGBM_r94_BAG_L1': 0.013861417770385742,
#   'NeuralNetTorch_r143_BAG_L1': 0.09143376350402832,
#   'CatBoost_r128_BAG_L1': 0.013972759246826172,
#   'NeuralNetFastAI_r111_BAG_L1': 0.09224748611450195,
#   'NeuralNetTorch_r31_BAG_L1': 0.10560941696166992,
#   'ExtraTrees_r4_BAG_L1': 0.07186198234558105,
#   'NeuralNetFastAI_r65_BAG_L1': 0.07907462120056152,
#   'NeuralNetFastAI_r88_BAG_L1': 0.07809305191040039,
#   'LightGBM_r30_BAG_L1': 0.011573314666748047,
#   'XGBoost_r49_BAG_L1': 0.020096778869628906,
#   'CatBoost_r5_BAG_L1': 0.02092766761779785,
#   'NeuralNetTorch_r87_BAG_L1': 0.07548046112060547,
#   'NeuralNetTorch_r71_BAG_L1': 0.12910771369934082,
#   'CatBoost_r143_BAG_L1': 0.03597426414489746,
#   'ExtraTrees_r178_BAG_L1': 0.0748908519744873,
#   'RandomForest_r166_BAG_L1': 0.06819915771484375,
#   'XGBoost_r31_BAG_L1': 0.014682769775390625,
#   'NeuralNetTorch_r185_BAG_L1': 0.1126413345336914,
#   'NeuralNetFastAI_r160_BAG_L1': 0.0845789909362793,
#   'CatBoost_r60_BAG_L1': 0.027172088623046875,
#   'RandomForest_r15_BAG_L1': 0.07220816612243652,
#   'LightGBM_r135_BAG_L1': 0.004017353057861328,
#   'XGBoost_r22_BAG_L1': 0.05343985557556152,
#   'NeuralNetFastAI_r69_BAG_L1': 0.06378960609436035,
#   'CatBoost_r6_BAG_L1': 0.015592336654663086,
#   'NeuralNetFastAI_r138_BAG_L1': 0.08019113540649414,
#   'LightGBM_r121_BAG_L1': 0.020509004592895508,
#   'NeuralNetFastAI_r172_BAG_L1': 0.06298542022705078,
#   'CatBoost_r180_BAG_L1': 0.022024869918823242,
#   'NeuralNetTorch_r76_BAG_L1': 0.09463953971862793,
#   'ExtraTrees_r197_BAG_L1': 0.0800325870513916,
#   'NeuralNetTorch_r121_BAG_L1': 0.11888790130615234,
#   'NeuralNetFastAI_r127_BAG_L1': 0.08033275604248047,
#   'RandomForest_r16_BAG_L1': 0.08534598350524902,
#   'NeuralNetFastAI_r194_BAG_L1': 0.10039997100830078,
#   'CatBoost_r12_BAG_L1': 0.006365776062011719,
#   'NeuralNetTorch_r135_BAG_L1': 0.10233235359191895,
#   'NeuralNetFastAI_r4_BAG_L1': 0.07497024536132812,
#   'ExtraTrees_r126_BAG_L1': 0.0831136703491211,
#   'NeuralNetTorch_r36_BAG_L1': 0.09852004051208496,
# ...
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                            model  score_val eval_metric  pred_time_val  \
#  0            WeightedEnsemble_L2   0.860828     roc_auc       0.442216
#  1           LightGBM_r130_BAG_L1   0.811508     roc_auc       0.001512
#  2           LightGBM_r135_BAG_L1   0.809240     roc_auc       0.004017
#  3            CatBoost_r50_BAG_L1   0.784675     roc_auc       0.020862
#  4            CatBoost_r70_BAG_L1   0.783541     roc_auc       0.023326
#  ..                           ...        ...         ...            ...
#  106  NeuralNetFastAI_r111_BAG_L1   0.687925     roc_auc       0.092247
#  107  NeuralNetFastAI_r138_BAG_L1   0.685091     roc_auc       0.080191
#  108  NeuralNetFastAI_r160_BAG_L1   0.656935     roc_auc       0.084579
#  109        KNeighborsDist_BAG_L1   0.638133     roc_auc       0.031416
#  110        KNeighborsUnif_BAG_L1   0.626842     roc_auc       0.025662
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    81.147807                0.000000           0.144139            2
#  1     2.651809                0.001512           2.651809            1
#  2     2.475472                0.004017           2.475472            1
#  3     3.243916                0.020862           3.243916            1
#  4     3.083571                0.023326           3.083571            1
#  ..         ...                     ...                ...          ...
#  106   7.308355                0.092247           7.308355            1
#  107   6.828713                0.080191           6.828713            1
#  108   5.774335                0.084579           5.774335            1
#  109   0.000000                0.031416           0.000000            1
#  110   0.005081                0.025662           0.005081            1
#
#       can_infer  fit_order
#  0         True        111
#  1         True         31
#  2         True         82
#  3         True         33
#  4         True         42
#  ..         ...        ...
#  106       True         64
#  107       True         86
#  108       True         79
#  109       True          2
#  110       True          1
#
#  [111 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.8005050505050505
# Evaluations on test data:
# {
#     "roc_auc": 0.8005050505050505,
#     "accuracy": 0.7580645161290323,
#     "balanced_accuracy": 0.731060606060606,
#     "mcc": 0.4432175195234292,
#     "f1": 0.6153846153846154,
#     "precision": 0.5714285714285714,
#     "recall": 0.6666666666666666
# }
# {'roc_auc': 0.8005050505050505,
#  'accuracy': 0.7580645161290323,
#  'balanced_accuracy': 0.731060606060606,
#  'mcc': 0.4432175195234292,
#  'f1': 0.6153846153846154,
#  'precision': 0.5714285714285714,
#  'recall': 0.6666666666666666}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                          model  score_test  balanced_accuracy        f1  \
# 0         CatBoost_r180_BAG_L1    1.000000           0.989418  0.965517
# 1        KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 2      RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 3        ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 4     RandomForest_r166_BAG_L1    1.000000           1.000000  1.000000
# ..                         ...         ...                ...       ...
# 106        LightGBM_r94_BAG_L1    0.841459           0.749339  0.564417
# 107  NeuralNetTorch_r14_BAG_L1    0.832200           0.566138  0.242424
# 108       ExtraTrees_r4_BAG_L1    0.830310           0.777447  0.608108
# 109  NeuralNetTorch_r36_BAG_L1    0.811980           0.684193  0.528736
# 110    RandomForest_r34_BAG_L1    0.793178           0.750992  0.569620
#
#      f1_macro  f1_micro   roc_auc  average_precision  precision    recall  \
# 0    0.977411  0.983673  1.000000           1.000000   0.933333  1.000000
# 1    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 2    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 3    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 4    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# ..        ...       ...       ...                ...        ...       ...
# 106  0.673646  0.710204  0.841459           0.597566   0.429907  0.821429
# 107  0.562250  0.795918  0.832200           0.648334   0.800000  0.142857
# 108  0.719259  0.763265  0.830310           0.582106   0.489130  0.803571
# 109  0.713499  0.832653  0.811980           0.569678   0.741935  0.410714
# 110  0.682400  0.722449  0.793178           0.555142   0.441176  0.803571
#
#      ...  eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0    ...      roc_auc        0.028999       0.022025   3.604423
# 1    ...      roc_auc        0.031522       0.031416   0.000000
# 2    ...      roc_auc        0.077536       0.079155   0.554525
# 3    ...      roc_auc        0.078403       0.063411   0.615895
# 4    ...      roc_auc        0.079517       0.068199   0.831863
# ..   ...          ...             ...            ...        ...
# 106  ...      roc_auc        0.091512       0.013861   1.687316
# 107  ...      roc_auc        0.189031       0.110664  26.948570
# 108  ...      roc_auc        0.089521       0.071862   0.568670
# 109  ...      roc_auc        0.190521       0.098520  23.918204
# 110  ...      roc_auc        0.086518       0.077568   0.625370
#
#      pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                   0.028999                0.022025           3.604423
# 1                   0.031522                0.031416           0.000000
# 2                   0.077536                0.079155           0.554525
# 3                   0.078403                0.063411           0.615895
# 4                   0.079517                0.068199           0.831863
# ..                       ...                     ...                ...
# 106                 0.091512                0.013861           1.687316
# 107                 0.189031                0.110664          26.948570
# 108                 0.089521                0.071862           0.568670
# 109                 0.190521                0.098520          23.918204
# 110                 0.086518                0.077568           0.625370
#
#      stack_level  can_infer  fit_order
# 0              1       True         89
# 1              1       True          2
# 2              1       True          6
# 3              1       True          9
# 4              1       True         76
# ..           ...        ...        ...
# 106            1       True         61
# 107            1       True         39
# 108            1       True         66
# 109            1       True        100
# 110            1       True         60
#
# [111 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 245 rows with 5 shuffle sets...
# 	77.84s	= Expected runtime (15.57s per shuffle set)
# 	33.65s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                 importance    stddev  \
# TRV.Stroop.palabras.PD                            0.052683  0.008169
# ISC.resultadosReservaCognitiva.escolaridad        0.038511  0.008857
# TRV.LeidenNT.UbicacionAlocentrica_total.PD        0.026153  0.004172
# TRV.LeidenNT.PuntoReferencia_total.PD             0.024036  0.005101
# TRV.Tavec.12_ESem-RI-B.PD                         0.023583  0.004061
# TRV.Tavec.20_I-RL.PD                              0.023526  0.009810
# TRV.Stroop.color.PD                               0.019728  0.005620
# TRV.Tavec.17_ESer-RL-CP.PD                        0.016950  0.003469
# TRV.Tavec.05_Rg-Md.PD                             0.016327  0.003078
# TRV.LeidenNT.CaminosTopgrafico_total.PD           0.015816  0.002248
# TRV.Tavec.14_ESem-RL-LP.PD                        0.015098  0.005494
# ISC.FPacientes.genero                             0.014588  0.004238
# TRV.Tavec.24_Discriminabilidad.PD                 0.013946  0.002745
# ISC.resultadosReservaCognitiva.Total.PD           0.011357  0.003327
# ISC.resultadosObservacion.enfermedadesDiabetes    0.011130  0.003946
# ISC.resultadosObservacion.alcohol                 0.011130  0.004116
# TRV.Tavec.10_RCl-LP.PD                            0.010147  0.003447
#
#                                                  p_value  n  p99_high  \
# TRV.Stroop.palabras.PD                          0.000067  5  0.069503
# ISC.resultadosReservaCognitiva.escolaridad      0.000313  5  0.056748
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.000075  5  0.034744
# TRV.LeidenNT.PuntoReferencia_total.PD           0.000229  5  0.034538
# TRV.Tavec.12_ESem-RI-B.PD                       0.000101  5  0.031944
# TRV.Tavec.20_I-RL.PD                            0.002918  5  0.043724
# TRV.Stroop.color.PD                             0.000712  5  0.031301
# TRV.Tavec.17_ESer-RL-CP.PD                      0.000199  5  0.024092
# TRV.Tavec.05_Rg-Md.PD                           0.000145  5  0.022664
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.000048  5  0.020446
# TRV.Tavec.14_ESem-RL-LP.PD                      0.001779  5  0.026411
# ISC.FPacientes.genero                           0.000767  5  0.023315
# TRV.Tavec.24_Discriminabilidad.PD               0.000171  5  0.019598
# ISC.resultadosReservaCognitiva.Total.PD         0.000791  5  0.018206
# ISC.resultadosObservacion.enfermedadesDiabetes  0.001615  5  0.019255
# ISC.resultadosObservacion.alcohol               0.001887  5  0.019605
# TRV.Tavec.10_RCl-LP.PD                          0.001378  5  0.017244
#
#                                                  p99_low
# TRV.Stroop.palabras.PD                          0.035863
# ISC.resultadosReservaCognitiva.escolaridad      0.020274
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.017562
# TRV.LeidenNT.PuntoReferencia_total.PD           0.013534
# TRV.Tavec.12_ESem-RI-B.PD                       0.015221
# TRV.Tavec.20_I-RL.PD                            0.003328
# TRV.Stroop.color.PD                             0.008155
# TRV.Tavec.17_ESer-RL-CP.PD                      0.009808
# TRV.Tavec.05_Rg-Md.PD                           0.009989
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.011187
# TRV.Tavec.14_ESem-RL-LP.PD                      0.003785
# ISC.FPacientes.genero                           0.005861
# TRV.Tavec.24_Discriminabilidad.PD               0.008293
# ISC.resultadosReservaCognitiva.Total.PD         0.004507
# ISC.resultadosObservacion.enfermedadesDiabetes  0.003005
# ISC.resultadosObservacion.alcohol               0.002655
# TRV.Tavec.10_RCl-LP.PD                          0.003051
