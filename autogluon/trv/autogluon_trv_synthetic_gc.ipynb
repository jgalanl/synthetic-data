# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/trv/synthetic-gc.csv')

# %%
VARS = ["ISC.FPacientes.IDUsuario",
"ISC.FPacientes.etiquetaDiagnosticaExpTLP",
"ED_2Clases",
"ISC.FPacientes.etiquetaDiagnostica",
"ED_MMSE_2Clases",
"ISC.FPacientes.genero",
"ISC.FPacientes.Edad",
"ISC.resultadosCovid.numDosis",
"ISC.resultadosCovid.numVecesCovid",
"ISC.resultadosCovid.numVecesCovid_mode",
"ISC.resultadosCovid.pasadoCovid",
"ISC.resultadosCovid.sentimientoAislado",
"ISC.resultadosCovid.sentimientoAislado_mediaFiltro",
"ISC.resultadosCovid.sentimientoAislado_mode",
"ISC.resultadosCovid.sintomaCansancio",
"ISC.resultadosCovid.sintomaDiarrea",
"ISC.resultadosCovid.sintomaDifRespirar",
"ISC.resultadosCovid.sintomaDolCabeza",
"ISC.resultadosCovid.sintomaDolGarganta",
"ISC.resultadosCovid.sintomaDolMuscular",
"ISC.resultadosCovid.sintomaEscalofrios",
"ISC.resultadosCovid.sintomaFiebre",
"ISC.resultadosCovid.sintomaOtro",
"ISC.resultadosCovid.sintomaOtroString",
"ISC.resultadosCovid.sintomaPerGusto",
"ISC.resultadosCovid.sintomaPerOlfato",
"ISC.resultadosCovid.vacunado",
"ISC.resultadosCribaje.Total.PD",
"ISC.resultadosObservacion.alcohol",
"ISC.resultadosObservacion.ansiedad",
"ISC.resultadosObservacion.añosSinFumar",
"ISC.resultadosObservacion.añosSinFumar_Rangos",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn",
"ISC.resultadosObservacion.depresion",
"ISC.resultadosObservacion.enfermedadesAltTiroides",
"ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos",
"ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica",
"ISC.resultadosObservacion.enfermedadesDiabetes",
"ISC.resultadosObservacion.enfermedadesHepatica",
"ISC.resultadosObservacion.enfermedadesHipercolesterolemia",
"ISC.resultadosObservacion.enfermedadesHipertension",
"ISC.resultadosObservacion.enfermedadesNinguna",
"ISC.resultadosObservacion.enfermedadesOtros",
"ISC.resultadosObservacion.enfermedadesOtrosString",
"ISC.resultadosObservacion.enfermedadesRenal",
"ISC.resultadosObservacion.entorno",
"ISC.resultadosObservacion.familiaresAlzheimer",
"ISC.resultadosObservacion.familiaresOtraDemencia",
"ISC.resultadosObservacion.fumador",
"ISC.resultadosObservacion.numCigarros",
"ISC.resultadosObservacion.numCigarrosDia_knn",
"ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad",
"ISC.resultadosObservacion.tratCronico",
"ISC.resultadosObservacion.tratPsicologic",
"ISC.resultadosObservacion.tratPsiquiatrico",
"ISC.resultadosOtros.frecOlvidos",
"ISC.resultadosOtros.frecUsoEmail",
"ISC.resultadosOtros.frecUsoMovil",
"ISC.resultadosOtros.frecUsoOrdenador",
"ISC.resultadosOtros.frecUsoRSociales",
"ISC.resultadosOtros.frecUsoTele",
"ISC.resultadosOtros.nivelActFisica",
"ISC.resultadosOtros.nivelSociabilidad",
"ISC.resultadosReservaCognitiva.Total.PD",
"ISC.resultadosReservaCognitiva.actividadLectora",
"ISC.resultadosReservaCognitiva.cursos",
"ISC.resultadosReservaCognitiva.escolaridad",
"ISC.resultadosReservaCognitiva.escolaridadPadres",
"ISC.resultadosReservaCognitiva.formacionMusical",
"ISC.resultadosReservaCognitiva.idiomas",
"ISC.resultadosReservaCognitiva.juegos",
"ISC.resultadosReservaCognitiva.ocupacion",
"ISC.resultadosWFQ.DE_array",
"ISC.resultadosWFQ.DE_total.PD",
"ISC.resultadosWFQ.NO_array",
"ISC.resultadosWFQ.NO_total.PD",
"ISC.resultadosWFQ.SA_array",
"ISC.resultadosWFQ.SA_total.PD",
"TRV.LeidenNT.CaminosRuta_total.PD",
"TRV.LeidenNT.CaminosTopgrafico_total.PD",
"TRV.LeidenNT.Orden_total.PD",
"TRV.LeidenNT.PuntoReferencia_total.PD",
"TRV.LeidenNT.UbicacionAlocentrica_total.PD",
"TRV.LeidenNT.UbicacionEgocentrico_total.PD",
"TRV.Stroop.color.PD",
"TRV.Stroop.color.PDC",
"TRV.Stroop.interferencia.PD",
"TRV.Stroop.palabras.PD",
"TRV.Stroop.palabras.PDC",
"TRV.Stroop.palabrasColor.PD",
"TRV.Stroop.palabrasColor.PDC",
"TRV.Tavec.00_RI-A1.PD",
"TRV.Tavec.01_RI-A5.PD",
"TRV.Tavec.02_RI-AT.PD",
"TRV.Tavec.03_RI-B.PD",
"TRV.Tavec.04_Rg-Pr.PD",
"TRV.Tavec.05_Rg-Md.PD",
"TRV.Tavec.06_Rg-Rc.PD",
"TRV.Tavec.07_RL-CP.PD",
"TRV.Tavec.08_RCl-CP.PD",
"TRV.Tavec.09_RL-LP.PD",
"TRV.Tavec.10_RCl-LP.PD",
"TRV.Tavec.11_ESem-RI-A.PD",
"TRV.Tavec.12_ESem-RI-B.PD",
"TRV.Tavec.13_ESem-RL-CP.PD",
"TRV.Tavec.14_ESem-RL-LP.PD",
"TRV.Tavec.15_ESer-RI-A.PD",
"TRV.Tavec.16_ESer-RI-B.PD",
"TRV.Tavec.17_ESer-RL-CP.PD",
"TRV.Tavec.18_ESer-RL-LP.PD",
"TRV.Tavec.19_P.PD",
"TRV.Tavec.20_I-RL.PD",
"TRV.Tavec.21_I-RCL.PD",
"TRV.Tavec.22_Recon-Ac.PD",
"TRV.Tavec.23_FP.PD",
"TRV.Tavec.24_Discriminabilidad.PD",
"TRV.Tavec.25_Sesgo.PD",
"TRV.Tavec.26_RI-B_frente_RI-A1.PD",
"TRV.Tavec.27_RL-CP_frente_RI-A5.PD",
"TRV.Tavec.28_RCl-Cp_frente_RCl-LP.PD",
"TRV.Tavec.29_RL-LP_frente_RL-CP.PD",
"TRV.Tavec.30_RCl-LP_frente_RL-LP.PD",
"TRV.Tavec.31_Recon-Ac_frente_RL-LP.PD",
"TRV.Tavec.32_Recon-Ac_frente_RCl-LP.PD"
]

VARS = [
'ISC.resultadosReservaCognitiva.Total.PD',
'ISC.resultadosReservaCognitiva.escolaridad',
'ISC.resultadosObservacion.enfermedadesDiabetes',
'ISC.resultadosObservacion.alcohol',
'TRV.LeidenNT.UbicacionAlocentrica_total.PD',
'TRV.LeidenNT.PuntoReferencia_total.PD',
'TRV.LeidenNT.CaminosTopgrafico_total.PD',
'TRV.Stroop.palabras.PD',
'TRV.Stroop.color.PD',
#'TRV.Stroop.palabras.PDC',
'TRV.Tavec.12_ESem-RI-B.PD',
'TRV.Tavec.10_RCl-LP.PD',
'TRV.Tavec.05_Rg-Md.PD',
'ISC.FPacientes.genero',
'TRV.Tavec.20_I-RL.PD',
'TRV.Tavec.17_ESer-RL-CP.PD',
'TRV.Tavec.14_ESem-RL-LP.PD',
'TRV.Tavec.24_Discriminabilidad.PD']

CLASS = 'ED_2Clases'

drop_columns = []
for v in df.columns:
    if not v in VARS+[CLASS]:
        drop_columns.append(v)

# %%
drop_columns
# Out:
# []

# %%
categorical_columns = [
    'ED_2Clases'
]

# %%
df[categorical_columns] = df[categorical_columns].astype('object')

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.resultadosObservacion.alcohol  \
# 0          D                      2                              False
# 1          D                      2                              False
# 2          H                      2                              False
# 3          D                      2                              False
# 4          D                      2                              False
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ISC.resultadosReservaCognitiva.Total.PD  \
# 0                                       12
# 1                                        8
# 2                                       11
# 3                                       18
# 4                                       13
#
#    ISC.resultadosReservaCognitiva.escolaridad  \
# 0                                           3
# 1                                           3
# 2                                           4
# 3                                           4
# 4                                           4
#
#    TRV.LeidenNT.CaminosTopgrafico_total.PD  \
# 0                                        2
# 1                                        1
# 2                                        3
# 3                                        4
# 4                                        2
#
#    TRV.LeidenNT.PuntoReferencia_total.PD  \
# 0                                      8
# 1                                      7
# 2                                      8
# 3                                      8
# 4                                      6
#
#    TRV.LeidenNT.UbicacionAlocentrica_total.PD  TRV.Stroop.color.PD  \
# 0                                           1                   27
# 1                                           1                   17
# 2                                           1                   40
# 3                                           3                   46
# 4                                           0                   32
#
#    TRV.Stroop.palabras.PD  TRV.Tavec.05_Rg-Md.PD  TRV.Tavec.10_RCl-LP.PD  \
# 0                      33              50.000000                      12
# 1                      18              45.714286                       8
# 2                      45              50.000000                      13
# 3                      51              48.648649                      12
# 4                      35              46.153846                      15
#
#    TRV.Tavec.12_ESem-RI-B.PD  TRV.Tavec.14_ESem-RL-LP.PD  \
# 0                          0                           1
# 1                          2                           2
# 2                          0                           3
# 3                          3                           2
# 4                          0                           3
#
#    TRV.Tavec.17_ESer-RL-CP.PD  TRV.Tavec.20_I-RL.PD  \
# 0                           1                    10
# 1                           1                    34
# 2                           5                     3
# 3                           1                     3
# 4                           0                     4
#
#    TRV.Tavec.24_Discriminabilidad.PD
# 0                          81.818182
# 1                          68.181818
# 2                          88.636364
# 3                          90.909091
# 4                          93.181818

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((372, 18), (94, 18))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/gc/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       7.08 GB / 15.94 GB (44.4%)
# Disk Space Avail:   120.62 GB / 446.36 GB (27.0%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 17:55:50,542	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# 		Context path: "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=8624) Running DyStack sub-fit ...
# (_dystack pid=8624) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=8624) Beginning AutoGluon training ... Time limit = 894s
# (_dystack pid=8624) AutoGluon will save models to "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=8624) Train Data Rows:    330
# (_dystack pid=8624) Train Data Columns: 17
# (_dystack pid=8624) Label Column:       ED_2Clases
# (_dystack pid=8624) Problem Type:       binary
# (_dystack pid=8624) Preprocessing data ...
# (_dystack pid=8624) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=8624) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=8624) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=8624) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=8624) Using Feature Generators to preprocess the data ...
# (_dystack pid=8624) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=8624) 	Available Memory:                    6344.24 MB
# (_dystack pid=8624) 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=8624) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=8624) 	Stage 1 Generators:
# (_dystack pid=8624) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=8624) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=8624) 	Stage 2 Generators:
# (_dystack pid=8624) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=8624) 	Stage 3 Generators:
# (_dystack pid=8624) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=8624) 	Stage 4 Generators:
# (_dystack pid=8624) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=8624) 	Stage 5 Generators:
# (_dystack pid=8624) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=8624) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=8624) 		('bool', [])  :  2 | ['ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=8624) 		('float', []) :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=8624) 		('int', [])   : 13 | ['ISC.FPacientes.genero', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', ...]
# (_dystack pid=8624) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=8624) 		('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=8624) 		('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# (_dystack pid=8624) 		('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=8624) 	0.0s = Fit runtime
# (_dystack pid=8624) 	17 features in original data used to generate 17 features in processed data.
# (_dystack pid=8624) 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=8624) Data preprocessing and feature engineering runtime = 0.05s ...
# (_dystack pid=8624) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=8624) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=8624) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=8624) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=8624) User-specified model hyperparameters to be fit:
# (_dystack pid=8624) {
# (_dystack pid=8624) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=8624) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=8624) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=8624) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=8624) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=8624) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8624) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8624) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=8624) }
# (_dystack pid=8624) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=8624) Fitting 110 L1 models ...
# (_dystack pid=8624) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 595.88s of the 894.03s of remaining time.
# (_dystack pid=8624) 	0.6132	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	0.01s	 = Training   runtime
# (_dystack pid=8624) 	0.03s	 = Validation runtime
# (_dystack pid=8624) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 592.58s of the 890.73s of remaining time.
# (_dystack pid=8624) 	0.6155	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	0.01s	 = Training   runtime
# (_dystack pid=8624) 	0.01s	 = Validation runtime
# (_dystack pid=8624) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 592.55s of the 890.7s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# (_ray_fit pid=11572) [1000]	valid_set's binary_logloss: 0.5452
# (_dystack pid=8624) 	0.7266	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	1.62s	 = Training   runtime
# (_dystack pid=8624) 	0.01s	 = Validation runtime
# (_dystack pid=8624) Fitting model: LightGBM_BAG_L1 ... Training model for up to 586.68s of the 884.83s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# (_dystack pid=8624) 	0.7759	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	2.76s	 = Training   runtime
# (_dystack pid=8624) 	0.02s	 = Validation runtime
# (_dystack pid=8624) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 578.27s of the 876.42s of remaining time.
# (_dystack pid=8624) 	0.7461	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	0.99s	 = Training   runtime
# (_dystack pid=8624) 	0.11s	 = Validation runtime
# (_dystack pid=8624) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 577.13s of the 875.28s of remaining time.
# (_dystack pid=8624) 	0.7552	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	0.89s	 = Training   runtime
# (_dystack pid=8624) 	0.15s	 = Validation runtime
# (_dystack pid=8624) Fitting model: CatBoost_BAG_L1 ... Training model for up to 576.02s of the 874.17s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=8624) 	0.7907	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	4.18s	 = Training   runtime
# (_dystack pid=8624) 	0.04s	 = Validation runtime
# (_dystack pid=8624) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 565.42s of the 863.57s of remaining time.
# (_dystack pid=8624) 	0.7052	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	1.02s	 = Training   runtime
# (_dystack pid=8624) 	0.17s	 = Validation runtime
# (_dystack pid=8624) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 564.17s of the 862.32s of remaining time.
# (_dystack pid=8624) 	0.7101	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	0.96s	 = Training   runtime
# (_dystack pid=8624) 	0.15s	 = Validation runtime
# (_dystack pid=8624) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 562.99s of the 861.14s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=8624) 	0.7325	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	9.05s	 = Training   runtime
# (_dystack pid=8624) 	0.12s	 = Validation runtime
# (_dystack pid=8624) Fitting model: XGBoost_BAG_L1 ... Training model for up to 546.81s of the 844.96s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=8624) 	0.7621	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	3.37s	 = Training   runtime
# (_dystack pid=8624) 	0.04s	 = Validation runtime
# (_dystack pid=8624) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 535.86s of the 834.01s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=7144) Stack (most recent call first):
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=7144)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=7144)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=8624) 	0.6918	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	32.17s	 = Training   runtime
# (_dystack pid=8624) 	0.13s	 = Validation runtime
# (_dystack pid=8624) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 495.9s of the 794.05s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_ray_fit pid=30432) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=30432)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=8624) 	0.7606	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	3.73s	 = Training   runtime
# (_dystack pid=8624) 	0.02s	 = Validation runtime
# (_dystack pid=8624) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 484.89s of the 783.04s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_dystack pid=8624) 	0.781	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	5.29s	 = Training   runtime
# (_dystack pid=8624) 	0.04s	 = Validation runtime
# (_dystack pid=8624) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 472.63s of the 770.78s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=21988) Stack (most recent call first):
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21988)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=21988)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=8624) 	0.7174	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	37.61s	 = Training   runtime
# (_dystack pid=8624) 	0.13s	 = Validation runtime
# (_dystack pid=8624) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 428.4s of the 726.55s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=28660) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=28660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_ray_fit pid=31332) [1000]	valid_set's binary_logloss: 0.50728
# (_dystack pid=8624) 	0.7827	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	3.18s	 = Training   runtime
# (_dystack pid=8624) 	0.03s	 = Validation runtime
# (_dystack pid=8624) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 418.75s of the 716.9s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=8624) 	0.6796	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	13.07s	 = Training   runtime
# (_dystack pid=8624) 	0.2s	 = Validation runtime
# (_dystack pid=8624) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 398.86s of the 697.0s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# (_dystack pid=8624) 	0.7857	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	14.62s	 = Training   runtime
# (_dystack pid=8624) 	0.02s	 = Validation runtime
# (_dystack pid=8624) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 376.41s of the 674.56s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=28356) [1000]	valid_set's binary_logloss: 0.590602
# (_ray_fit pid=33516) [10000]	valid_set's binary_logloss: 0.575663 [repeated 13x across cluster]
# (_dystack pid=8624) 	0.7259	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	7.74s	 = Training   runtime
# (_dystack pid=8624) 	0.04s	 = Validation runtime
# (_dystack pid=8624) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 364.72s of the 662.87s of remaining time.
# (_dystack pid=8624) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=25932) Stack (most recent call first):
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=25932)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=25932)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=8624) 	0.7131	 = Validation score   (roc_auc)
# (_dystack pid=8624) 	38.5s	 = Training   runtime
# (_dystack pid=8624) 	0.14s	 = Validation runtime
# (_dystack pid=8624) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 319.61s of the 617.76s of remaining time.
# ...
#     from torch import multiprocessing
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\__init__.py", line 132, in <module>
#     raise err
# OSError: [WinError 1455] El archivo de paginación es demasiado pequeño para completar la operación. Error loading "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\lib\cudnn_cnn_infer64_8.dll" or one of its dependencies.
# 2025-01-20 18:40:35,341	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-20 18:40:35,344	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-20 18:40:35,346	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-20 18:40:35,348	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Time limit exceeded... Skipping NeuralNetTorch_r36_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 889.96s of remaining time.
# 	Ensemble Weights: {'XGBoost_r22_BAG_L1': 0.4, 'CatBoost_r6_BAG_L1': 0.2, 'NeuralNetTorch_r30_BAG_L1': 0.133, 'NeuralNetTorch_r76_BAG_L1': 0.133, 'NeuralNetFastAI_r102_BAG_L1': 0.067, 'NeuralNetFastAI_r37_BAG_L1': 0.067}
# 	0.8365	 = Validation score   (roc_auc)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 889.7s of the 889.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.8194	 = Validation score   (roc_auc)
# 	5.48s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 878.87s of the 878.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	0.8251	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 867.67s of the 867.0s of remaining time.
# 	0.8145	 = Validation score   (roc_auc)
# 	1.05s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 866.36s of the 865.69s of remaining time.
# 	0.8143	 = Validation score   (roc_auc)
# 	1.04s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 865.04s of the 864.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.8147	 = Validation score   (roc_auc)
# 	33.26s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 822.49s of the 821.82s of remaining time.
# 	0.8131	 = Validation score   (roc_auc)
# 	0.99s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 821.24s of the 820.57s of remaining time.
# 	0.8123	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 820.02s of the 819.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.8201	 = Validation score   (roc_auc)
# 	10.66s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 799.97s of the 799.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.7964	 = Validation score   (roc_auc)
# 	6.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 787.03s of the 786.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8182	 = Validation score   (roc_auc)
# 	39.97s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 740.54s of the 739.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.29%)
# 	0.7934	 = Validation score   (roc_auc)
# 	10.92s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 724.21s of the 723.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.02%)
# 	0.819	 = Validation score   (roc_auc)
# 	34.23s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 684.89s of the 684.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8316	 = Validation score   (roc_auc)
# 	35.68s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 641.32s of the 640.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.815	 = Validation score   (roc_auc)
# 	6.96s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 628.61s of the 627.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.8193	 = Validation score   (roc_auc)
# 	15.0s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 603.67s of the 603.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.15%)
# 	0.8276	 = Validation score   (roc_auc)
# 	141.11s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 458.49s of the 457.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.8287	 = Validation score   (roc_auc)
# 	10.43s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 435.63s of the 434.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8241	 = Validation score   (roc_auc)
# 	38.57s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 386.68s of the 386.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.63%)
# 	0.8095	 = Validation score   (roc_auc)
# 	10.72s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 372.85s of the 372.19s of remaining time.
# 	0.8137	 = Validation score   (roc_auc)
# 	0.73s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 371.93s of the 371.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.8308	 = Validation score   (roc_auc)
# 	13.19s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 355.64s of the 354.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8269	 = Validation score   (roc_auc)
# 	10.39s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 342.19s of the 341.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.06%)
# 	0.8125	 = Validation score   (roc_auc)
# 	162.27s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 176.17s of the 175.51s of remaining time.
# 	0.8095	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 175.06s of the 174.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.10%)
# 	0.824	 = Validation score   (roc_auc)
# 	2.21s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 169.95s of the 169.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.817	 = Validation score   (roc_auc)
# 	7.81s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 159.02s of the 158.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.8149	 = Validation score   (roc_auc)
# 	4.24s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 150.86s of the 150.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8456	 = Validation score   (roc_auc)
# 	19.77s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 124.42s of the 123.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.8399	 = Validation score   (roc_auc)
# 	2.35s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 119.07s of the 118.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7998	 = Validation score   (roc_auc)
# 	30.14s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 85.73s of the 85.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.8134	 = Validation score   (roc_auc)
# 	16.38s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 66.22s of the 65.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.7911	 = Validation score   (roc_auc)
# 	7.89s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L2 ... Training model for up to 55.07s of the 54.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.74%)
# 	0.8044	 = Validation score   (roc_auc)
# 	4.5s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L2 ... Training model for up to 46.61s of the 45.94s of remaining time.
# 	0.8185	 = Validation score   (roc_auc)
# 	0.64s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L2 ... Training model for up to 45.8s of the 45.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.8236	 = Validation score   (roc_auc)
# 	16.94s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 25.57s of the 24.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8064	 = Validation score   (roc_auc)
# 	6.68s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 15.27s of the 14.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r14_BAG_L2.
# 2025-01-20 18:55:59,389	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=10260, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# 2025-01-20 18:55:59,392	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=3700, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
#     raise TimeLimitExceeded
# autogluon.core.utils.exceptions.TimeLimitExceeded
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -18.7s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r30_BAG_L2': 0.3, 'LightGBM_r130_BAG_L2': 0.15, 'XGBoost_r22_BAG_L1': 0.1, 'NeuralNetTorch_r79_BAG_L2': 0.1, 'CatBoost_r9_BAG_L2': 0.1, 'XGBoost_r89_BAG_L2': 0.1, 'LightGBM_BAG_L2': 0.05, 'NeuralNetTorch_r22_BAG_L2': 0.05, 'NeuralNetFastAI_r102_BAG_L2': 0.05}
# 	0.8601	 = Validation score   (roc_auc)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2697.38s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 6.5 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/gc/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L3   0.860072     roc_auc      10.280145  1425.068233                0.001000           0.133768            3       True        136
# 1      NeuralNetTorch_r30_BAG_L2   0.845592     roc_auc       9.764906  1188.753238                0.111548          19.766773            2       True        127
# 2           LightGBM_r130_BAG_L2   0.839917     roc_auc       9.677868  1171.336583                0.024509           2.350118            2       True        128
# 3            WeightedEnsemble_L2   0.836471     roc_auc       0.626944   121.384676                0.000000           0.227889            2       True         99
# 4      NeuralNetTorch_r79_BAG_L2   0.831577     roc_auc       9.778688  1204.665307                0.125330          35.678842            2       True        112
# 5           CatBoost_r137_BAG_L2   0.830824     roc_auc       9.719851  1182.174159                0.066493          13.187693            2       True        120
# 6            LightGBM_r96_BAG_L2   0.828652     roc_auc       9.686529  1179.417723                0.033170          10.431258            2       True        116
# 7             CatBoost_r9_BAG_L2   0.827609     roc_auc       9.733124  1310.097932                0.079766         141.111466            2       True        115
# 8    NeuralNetFastAI_r102_BAG_L2   0.826885     roc_auc       9.761836  1179.372585                0.108477          10.386120            2       True        121
# 9                LightGBM_BAG_L2   0.825119     roc_auc       9.677071  1172.829289                0.023713           3.842824            2       True        101
# 10     NeuralNetTorch_r22_BAG_L2   0.824105     roc_auc       9.765478  1207.560948                0.112119          38.574482            2       True        117
# 11          LightGBM_r188_BAG_L2   0.824047     roc_auc       9.675364  1171.197212                0.022006           2.210747            2       True        124
# 12           CatBoost_r69_BAG_L2   0.823613     roc_auc       9.719903  1185.930193                0.066544          16.943727            2       True        134
# 13        NeuralNetFastAI_BAG_L2   0.820109     roc_auc       9.777147  1179.648821                0.123788          10.662355            2       True        107
# 14             LightGBMXT_BAG_L2   0.819356     roc_auc       9.677007  1174.465246                0.023649           5.478780            2       True        100
# 15   NeuralNetFastAI_r191_BAG_L2   0.819298     roc_auc       9.737814  1183.987233                0.084455          15.000768            2       True        114
# 16          CatBoost_r177_BAG_L2   0.819008     roc_auc       9.758736  1203.216463                0.105378          34.229998            2       True        111
# 17        ExtraTrees_r172_BAG_L2   0.818516     roc_auc       9.746597  1169.623147                0.093238           0.636682            2       True        133
# 18         NeuralNetTorch_BAG_L2   0.818227     roc_auc       9.788712  1208.951979                0.135353          39.965514            2       True        109
# 19   NeuralNetFastAI_r145_BAG_L2   0.817039     roc_auc       9.745641  1176.794046                0.092282           7.807581            2       True        125
# 20          LightGBM_r131_BAG_L2   0.814954     roc_auc       9.680507  1175.944103                0.027149           6.957637            2       True        113
# 21            XGBoost_r89_BAG_L2   0.814896     roc_auc       9.693683  1173.223841                0.040324           4.237376            2       True        126
# 22               CatBoost_BAG_L2   0.814694     roc_auc       9.747751  1202.243447                0.094393          33.256981            2       True        104
# 23       RandomForestGini_BAG_L2   0.814549     roc_auc       9.831087  1170.037122                0.177729           1.050657            2       True        102
# 24       RandomForestEntr_BAG_L2   0.814303     roc_auc       9.830771  1170.025550                0.177413           1.039085            2       True        103
# 25         ExtraTrees_r42_BAG_L2   0.813709     roc_auc       9.774121  1169.713511                0.120762           0.727045            2       True        119
# 26           CatBoost_r50_BAG_L2   0.813448     roc_auc       9.714481  1185.364178                0.061122          16.377713            2       True        130
# 27         ExtraTreesGini_BAG_L2   0.813072     roc_auc       9.817729  1169.974070                0.164371           0.987605            2       True        105
# 28            XGBoost_r22_BAG_L1   0.812522     roc_auc       0.035918     5.444865                0.035918           5.444865            1       True         83
# 29           CatBoost_r13_BAG_L2   0.812493     roc_auc       9.732039  1331.259384                0.078681         162.272918            2       True        122
# 30         ExtraTreesEntr_BAG_L2   0.812333     roc_auc       9.832083  1169.925467                0.178725           0.939002            2       True        106
# 31            XGBoost_r33_BAG_L2   0.809510     roc_auc       9.690256  1179.706120                0.036897          10.719654            2       True        118
# 32      RandomForest_r195_BAG_L2   0.809452     roc_auc       9.736665  1169.952475                0.083307           0.966009            2       True        123
# 33            CatBoost_r6_BAG_L1   0.809278     roc_auc       0.031996     5.307995                0.031996           5.307995            1       True         85
# 34           CatBoost_r50_BAG_L1   0.809163     roc_auc       0.031577     5.330238                0.031577           5.330238            1       True         33
# 35   NeuralNetFastAI_r103_BAG_L2   0.806382     roc_auc       9.751444  1175.662156                0.098085           6.675690            2       True        135
# 36           XGBoost_r194_BAG_L2   0.804384     roc_auc       9.782841  1173.486639                0.129483           4.500174            2       True        132
# 37            XGBoost_r89_BAG_L1   0.803834     roc_auc       0.034669     4.358855                0.034669           4.358855            1       True         29
# 38     NeuralNetTorch_r86_BAG_L2   0.799751     roc_auc       9.758780  1199.124265                0.105422          30.137800            2       True        129
# 39                XGBoost_BAG_L2   0.796363     roc_auc       9.697942  1175.693599                0.044584           6.707133            2       True        108
# 40            XGBoost_r31_BAG_L1   0.794973     roc_auc       0.034072     2.743698                0.034072           2.743698            1       True         77
# 41            XGBoost_r98_BAG_L1   0.793901     roc_auc       0.056193    15.016787                0.056193          15.016787            1       True         49
# 42          LightGBMLarge_BAG_L2   0.793351     roc_auc       9.679098  1179.906114                0.025739          10.919649            2       True        110
# 43           CatBoost_r60_BAG_L1   0.792019     roc_auc       0.022281     3.292476                0.022281           3.292476            1       True         80
# 44    NeuralNetFastAI_r11_BAG_L2   0.791063     roc_auc       9.773167  1176.878439                0.119808           7.891973            2       True        131
# 45           CatBoost_r70_BAG_L1   0.790919     roc_auc       0.043676     9.580496                0.043676           9.580496            1       True         42
# 46           CatBoost_r69_BAG_L1   0.790629     roc_auc       0.030020     5.400537                0.030020           5.400537            1       True         37
# 47           XGBoost_r194_BAG_L1   0.790484     roc_auc       0.056138     6.912199                0.056138           6.912199            1       True         35
# 48           CatBoost_r49_BAG_L1   0.789529     roc_auc       0.020011     8.610446                0.020011           8.610446            1       True         55
# 49          LightGBM_r161_BAG_L1   0.788457     roc_auc       0.030354    22.662747                0.030354          22.662747            1       True         40
# 50          CatBoost_r137_BAG_L1   0.787067     roc_auc       0.022333     5.744652                0.022333           5.744652            1       True         23
# 51            XGBoost_r49_BAG_L1   0.786111     roc_auc       0.036277     3.527220                0.036277           3.527220            1       True         70
# 52            XGBoost_r33_BAG_L1   0.786082     roc_auc       0.027998     4.151791                0.027998           4.151791            1       True         21
# 53          CatBoost_r180_BAG_L1   0.785909     roc_auc       0.030785     7.736933                0.030785           7.736933            1       True         89
# 54          LightGBM_r131_BAG_L1   0.785156     roc_auc       0.028048     4.939875                0.028048           4.939875            1       True         16
# 55               LightGBM_BAG_L1   0.784982     roc_auc       0.018003     2.281681                0.018003           2.281681            1       True          4
# 56               CatBoost_BAG_L1   0.783882     roc_auc       0.030852     4.442211                0.030852           4.442211            1       True          7
# 57          LightGBM_r121_BAG_L1   0.783476     roc_auc       0.026597     3.527021                0.026597           3.527021            1       True         87
# 58            CatBoost_r5_BAG_L1   0.782607     roc_auc       0.034372     4.085699                0.034372           4.085699            1       True         71
# 59       RandomForestGini_BAG_L1   0.780855     roc_auc       0.102206     1.058523                0.102206           1.058523            1       True          5
# 60      RandomForest_r166_BAG_L1   0.780855     roc_auc       0.147398     1.533607                0.147398           1.533607            1       True         76
# 61            CatBoost_r9_BAG_L1   0.779683     roc_auc       0.032150    17.439350                0.032150          17.439350            1       True         18
# 62          LightGBM_r143_BAG_L1   0.778959     roc_auc       0.022177     3.034218                0.022177           3.034218            1       True         57
# 63           LightGBM_r15_BAG_L1   0.777598     roc_auc       0.031669     3.163010                0.031669           3.163010            1       True         50
# 64                XGBoost_BAG_L1   0.777120     roc_auc       0.031092    10.969019                0.031092          10.969019            1       True         11
# 65       RandomForest_r16_BAG_L1   0.775180     roc_auc       0.088221     0.912657                0.088221           0.912657            1       True         94
# 66       RandomForest_r39_BAG_L1   0.773370     roc_auc       0.158076     1.142511                0.158076           1.142511            1       True         45
# 67          CatBoost_r177_BAG_L1   0.772935     roc_auc       0.031944     6.580450                0.031944           6.580450            1       True         14
# 68           CatBoost_r12_BAG_L1   0.769895     roc_auc       0.038687     7.184773                0.038687           7.184773            1       True         96
# 69          CatBoost_r128_BAG_L1   0.769171     roc_auc       0.027248    15.823575                0.027248          15.823575            1       True         63
# 70      RandomForest_r195_BAG_L1   0.766405     roc_auc       0.159447     1.333279                0.159447           1.333279            1       True         26
# 71           CatBoost_r13_BAG_L1   0.765493     roc_auc       0.030519    12.371970                0.030519          12.371970            1       True         25
# 72       RandomForest_r15_BAG_L1   0.765087     roc_auc       0.079285     0.771760                0.079285           0.771760            1       True         81
# 73       RandomForestEntr_BAG_L1   0.762858     roc_auc       0.152909     0.770470                0.152909           0.770470            1       True          6
# 74      RandomForest_r127_BAG_L1   0.762742     roc_auc       0.103885     1.016422                0.103885           1.016422            1       True         58
# 75          CatBoost_r143_BAG_L1   0.761931     roc_auc       0.027337    16.747918                0.027337          16.747918            1       True         74
# 76          CatBoost_r167_BAG_L1   0.761236     roc_auc       0.032355     6.711982                0.032355           6.711982            1       True         46
# 77     NeuralNetTorch_r76_BAG_L1   0.759093     roc_auc       0.128852    35.886742                0.128852          35.886742            1       True         90
# 78    NeuralNetFastAI_r37_BAG_L1   0.758774     roc_auc       0.148154    19.162464                0.148154          19.162464            1       True         53
# 79          LightGBMLarge_BAG_L1   0.757877     roc_auc       0.002006     5.079074                0.002006           5.079074            1       True         13
# 80          LightGBM_r135_BAG_L1   0.757761     roc_auc       0.018517     2.463002                0.018517           2.463002            1       True         82
# 81   NeuralNetFastAI_r102_BAG_L1   0.757761     roc_auc       0.144702    15.201077                0.144702          15.201077            1       True         24
# 82          LightGBM_r130_BAG_L1   0.754547     roc_auc       0.013169     4.504524                0.013169           4.504524            1       True         31
# 83     NeuralNetTorch_r30_BAG_L1   0.751766     roc_auc       0.137321    40.153643                0.137321          40.153643            1       True         30
# 84   NeuralNetFastAI_r138_BAG_L1   0.750261     roc_auc       0.133653    15.022783                0.133653          15.022783            1       True         86
# 85    NeuralNetTorch_r135_BAG_L1   0.749305     roc_auc       0.150359    45.305926                0.150359          45.305926            1       True         97
# 86           CatBoost_r86_BAG_L1   0.746757     roc_auc       0.020785    10.088914                0.020785          10.088914            1       True         52
# 87    NeuralNetTorch_r158_BAG_L1   0.746612     roc_auc       0.152429    19.167370                0.152429          19.167370            1       True         51
# 88   NeuralNetFastAI_r145_BAG_L1   0.740907     roc_auc       0.101988    11.905831                0.101988          11.905831            1       True         28
# 89     NeuralNetTorch_r87_BAG_L1   0.739459     roc_auc       0.130205    34.995826                0.130205          34.995826            1       True         72
# 90    NeuralNetTorch_r197_BAG_L1   0.739227     roc_auc       0.130361    23.326263                0.130361          23.326263            1       True         54
# 91         ExtraTrees_r42_BAG_L1   0.737722     roc_auc       0.089185     1.022430                0.089185           1.022430            1       True         22
# 92         ExtraTrees_r49_BAG_L1   0.737548     roc_auc       0.079454     0.627117                0.079454           0.627117            1       True         56
# 93         ExtraTreesGini_BAG_L1   0.737548     roc_auc       0.082386     1.652486                0.082386           1.652486            1       True          8
# 94   NeuralNetFastAI_r191_BAG_L1   0.737171     roc_auc       0.126306    12.147176                0.126306          12.147176            1       True         17
# 95        ExtraTrees_r126_BAG_L1   0.736129     roc_auc       0.152962     1.070637                0.152962           1.070637            1       True         98
# 96         ExtraTreesEntr_BAG_L1   0.734724     roc_auc       0.142377     0.693802                0.142377           0.693802            1       True          9
# 97        NeuralNetFastAI_BAG_L1   0.734333     roc_auc       0.098888    10.763128                0.098888          10.763128            1       True         10
# 98    NeuralNetFastAI_r95_BAG_L1   0.733001     roc_auc       0.104701     9.805733                0.104701           9.805733            1       True         47
# 99   NeuralNetFastAI_r172_BAG_L1   0.730714     roc_auc       0.159665    13.677703                0.159665          13.677703            1       True         88
# 100            LightGBMXT_BAG_L1   0.730019     roc_auc       0.017305     1.173638                0.017305           1.173638            1       True          3
# 101    NeuralNetTorch_r79_BAG_L1   0.729063     roc_auc       0.125945    38.715785                0.125945          38.715785            1       True         15
# 102   NeuralNetFastAI_r65_BAG_L1   0.729063     roc_auc       0.161608    19.201326                0.161608          19.201326            1       True         67
# 103       ExtraTrees_r178_BAG_L1   0.728310     roc_auc       0.129307     1.050966                0.129307           1.050966            1       True         75
# 104       ExtraTrees_r197_BAG_L1   0.728267     roc_auc       0.135037     1.206031                0.135037           1.206031            1       True         91
# 105   NeuralNetFastAI_r88_BAG_L1   0.728165     roc_auc       0.123716    13.111745                0.123716          13.111745            1       True         68
# 106         LightGBM_r196_BAG_L1   0.727441     roc_auc       0.094155     6.062838                0.094155           6.062838            1       True         44
# 107       ExtraTrees_r172_BAG_L1   0.726428     roc_auc       0.159977     0.907634                0.159977           0.907634            1       True         36
# 108          LightGBM_r94_BAG_L1   0.724458     roc_auc       0.023815     3.456281                0.023815           3.456281            1       True         61
# 109   NeuralNetTorch_r185_BAG_L1   0.722692     roc_auc       0.133424    34.483321                0.133424          34.483321            1       True         78
# 110    NeuralNetTorch_r14_BAG_L1   0.722634     roc_auc       0.114576    37.966332                0.114576          37.966332            1       True         39
# 111    NeuralNetTorch_r41_BAG_L1   0.722576     roc_auc       0.160817    36.762400                0.160817          36.762400            1       True         48
# 112    NeuralNetTorch_r86_BAG_L1   0.722084     roc_auc       0.134969    38.604707                0.134969          38.604707            1       True         32
# 113         LightGBM_r188_BAG_L1   0.721968     roc_auc       0.021297     4.106939                0.021297           4.106939            1       True         27
# 114    NeuralNetTorch_r31_BAG_L1   0.721794     roc_auc       0.138886    35.187639                0.138886          35.187639            1       True         65
# 115  NeuralNetFastAI_r127_BAG_L1   0.720665     roc_auc       0.087187    21.480709                0.087187          21.480709            1       True         93
# 116   NeuralNetFastAI_r69_BAG_L1   0.720433     roc_auc       0.121746    10.684717                0.121746          10.684717            1       True         84
# 117    NeuralNetTorch_r22_BAG_L1   0.719738     roc_auc       0.140310    37.357835                0.140310          37.357835            1       True         20
# 118      RandomForest_r34_BAG_L1   0.719709     roc_auc       0.163632     1.376427                0.163632           1.376427            1       True         60
# 119  NeuralNetFastAI_r143_BAG_L1   0.718290     roc_auc       0.136454    14.327618                0.136454          14.327618            1       True         41
# 120  NeuralNetFastAI_r156_BAG_L1   0.716784     roc_auc       0.139984    12.863360                0.139984          12.863360            1       True         43
# 121  NeuralNetFastAI_r103_BAG_L1   0.714439     roc_auc       0.107532     8.799849                0.107532           8.799849            1       True         38
# 122         ExtraTrees_r4_BAG_L1   0.714352     roc_auc       0.145254     1.015719                0.145254           1.015719            1       True         66
# 123  NeuralNetFastAI_r134_BAG_L1   0.713831     roc_auc       0.169976    13.257842                0.169976          13.257842            1       True         59
# 124   NeuralNetTorch_r143_BAG_L1   0.713454     roc_auc       0.137289    41.064359                0.137289          41.064359            1       True         62
# 125   NeuralNetFastAI_r11_BAG_L1   0.712991     roc_auc       0.119199     9.777058                0.119199           9.777058            1       True         34
# 126   NeuralNetTorch_r121_BAG_L1   0.712672     roc_auc       0.135062    40.477809                0.135062          40.477809            1       True         92
# 127          LightGBM_r30_BAG_L1   0.712006     roc_auc       0.034186     5.489835                0.034186           5.489835            1       True         69
# 128    NeuralNetTorch_r71_BAG_L1   0.711717     roc_auc       0.173244    33.162994                0.173244          33.162994            1       True         73
# 129  NeuralNetFastAI_r194_BAG_L1   0.703956     roc_auc       0.113729     9.947655                0.113729           9.947655            1       True         95
# 130  NeuralNetFastAI_r111_BAG_L1   0.703608     roc_auc       0.140924    11.627015                0.140924          11.627015            1       True         64
# 131  NeuralNetFastAI_r160_BAG_L1   0.703348     roc_auc       0.109744    11.615845                0.109744          11.615845            1       True         79
# 132          LightGBM_r96_BAG_L1   0.703319     roc_auc       0.022687     2.765582                0.022687           2.765582            1       True         19
# 133        NeuralNetTorch_BAG_L1   0.688086     roc_auc       0.139687    32.500090                0.139687          32.500090            1       True         12
# 134        KNeighborsDist_BAG_L1   0.649861     roc_auc       0.021375     0.003998                0.021375           0.003998            1       True          2
# 135        KNeighborsUnif_BAG_L1   0.646791     roc_auc       1.192120     0.004996                1.192120           0.004996            1       True          1
# Number of models trained: 136
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# ('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# ('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# Plot summary of models saved to file: AutogluonModels/synthetic/gc/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r37_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r160_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetFastAI_r69_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r138_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r172_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r127_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r194_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L2': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6467913819066373,
#   'KNeighborsDist_BAG_L1': 0.6498609984941504,
#   'LightGBMXT_BAG_L1': 0.7300185335341132,
#   'LightGBM_BAG_L1': 0.7849820456388278,
#   'RandomForestGini_BAG_L1': 0.7808554384339164,
#   'RandomForestEntr_BAG_L1': 0.7628576392910923,
#   'CatBoost_BAG_L1': 0.7838816170508514,
#   'ExtraTreesGini_BAG_L1': 0.7375477817676359,
#   'ExtraTreesEntr_BAG_L1': 0.7347243136800649,
#   'NeuralNetFastAI_BAG_L1': 0.7343333719448627,
#   'XGBoost_BAG_L1': 0.7771197729642072,
#   'NeuralNetTorch_BAG_L1': 0.6880864126028032,
#   'LightGBMLarge_BAG_L1': 0.7578767519981466,
#   'CatBoost_r177_BAG_L1': 0.7729352484651917,
#   'NeuralNetTorch_r79_BAG_L1': 0.729062898181397,
#   'LightGBM_r131_BAG_L1': 0.7851557975211397,
#   'NeuralNetFastAI_r191_BAG_L1': 0.7371713193559597,
#   'CatBoost_r9_BAG_L1': 0.77968261322831,
#   'LightGBM_r96_BAG_L1': 0.7033186609521603,
#   'NeuralNetTorch_r22_BAG_L1': 0.71973821383065,
#   'XGBoost_r33_BAG_L1': 0.7860824742268042,
#   'ExtraTrees_r42_BAG_L1': 0.7377215336499479,
#   'CatBoost_r137_BAG_L1': 0.7870670682265726,
#   'NeuralNetFastAI_r102_BAG_L1': 0.7577609174099386,
#   'CatBoost_r13_BAG_L1': 0.7654928761728252,
#   'RandomForest_r195_BAG_L1': 0.7664050735549635,
#   'LightGBM_r188_BAG_L1': 0.7219680296536546,
#   'NeuralNetFastAI_r145_BAG_L1': 0.740906984825669,
#   'XGBoost_r89_BAG_L1': 0.8038341248696861,
#   'NeuralNetTorch_r30_BAG_L1': 0.7517664774701724,
#   'LightGBM_r130_BAG_L1': 0.7545465075871656,
#   'NeuralNetTorch_r86_BAG_L1': 0.7220838642418627,
#   'CatBoost_r50_BAG_L1': 0.8091625159272559,
#   'NeuralNetFastAI_r11_BAG_L1': 0.7129908490675316,
#   'XGBoost_r194_BAG_L1': 0.7904841885787095,
#   'ExtraTrees_r172_BAG_L1': 0.7264276612996641,
#   'CatBoost_r69_BAG_L1': 0.7906289818139697,
#   'NeuralNetFastAI_r103_BAG_L1': 0.7144387814201321,
#   'NeuralNetTorch_r14_BAG_L1': 0.7226340785358508,
#   'LightGBM_r161_BAG_L1': 0.7884570832850689,
#   'NeuralNetFastAI_r143_BAG_L1': 0.7182902814780493,
#   'CatBoost_r70_BAG_L1': 0.7909185682844897,
#   'NeuralNetFastAI_r156_BAG_L1': 0.7167844318313448,
#   'LightGBM_r196_BAG_L1': 0.7274412139464844,
#   'RandomForest_r39_BAG_L1': 0.7733696281709719,
#   'CatBoost_r167_BAG_L1': 0.7612359550561798,
#   'NeuralNetFastAI_r95_BAG_L1': 0.7330012741804702,
#   'NeuralNetTorch_r41_BAG_L1': 0.7225761612417467,
#   'XGBoost_r98_BAG_L1': 0.7939013089308468,
#   'LightGBM_r15_BAG_L1': 0.7775975906405653,
#   'NeuralNetTorch_r158_BAG_L1': 0.746611838294915,
#   'CatBoost_r86_BAG_L1': 0.7467566315301749,
#   'NeuralNetFastAI_r37_BAG_L1': 0.7587744700567589,
#   'NeuralNetTorch_r197_BAG_L1': 0.7392273832966524,
#   'CatBoost_r49_BAG_L1': 0.7895285532259931,
#   'ExtraTrees_r49_BAG_L1': 0.7375477817676359,
#   'LightGBM_r143_BAG_L1': 0.7789586470520097,
#   'RandomForest_r127_BAG_L1': 0.7627418047028843,
#   'NeuralNetFastAI_r134_BAG_L1': 0.7138306498320398,
#   'RandomForest_r34_BAG_L1': 0.7197092551835979,
#   'LightGBM_r94_BAG_L1': 0.7244584733001275,
#   'NeuralNetTorch_r143_BAG_L1': 0.7134541874203637,
#   'CatBoost_r128_BAG_L1': 0.7691706243484304,
#   'NeuralNetFastAI_r111_BAG_L1': 0.7036082474226804,
#   'NeuralNetTorch_r31_BAG_L1': 0.7217942777713425,
#   'ExtraTrees_r4_BAG_L1': 0.7143519054789761,
#   'NeuralNetFastAI_r65_BAG_L1': 0.7290628981813969,
#   'NeuralNetFastAI_r88_BAG_L1': 0.7281651801227846,
#   'LightGBM_r30_BAG_L1': 0.7120062550677634,
#   'XGBoost_r49_BAG_L1': 0.7861114328738561,
#   'CatBoost_r5_BAG_L1': 0.782607436580563,
#   'NeuralNetTorch_r87_BAG_L1': 0.7394590524730684,
#   'NeuralNetTorch_r71_BAG_L1': 0.7117166685972431,
#   'CatBoost_r143_BAG_L1': 0.761930962585428,
#   'ExtraTrees_r178_BAG_L1': 0.7283099733580447,
#   'RandomForest_r166_BAG_L1': 0.7808554384339164,
#   'XGBoost_r31_BAG_L1': 0.7949727788717711,
#   'NeuralNetTorch_r185_BAG_L1': 0.7226919958299549,
#   'NeuralNetFastAI_r160_BAG_L1': 0.7033476195992123,
#   'CatBoost_r60_BAG_L1': 0.7920189968724661,
#   'RandomForest_r15_BAG_L1': 0.765087455114097,
#   'LightGBM_r135_BAG_L1': 0.7577609174099386,
#   'XGBoost_r22_BAG_L1': 0.8125217189852889,
#   'NeuralNetFastAI_r69_BAG_L1': 0.7204332213598982,
#   'CatBoost_r6_BAG_L1': 0.8092783505154639,
#   'NeuralNetFastAI_r138_BAG_L1': 0.7502606278234681,
#   'LightGBM_r121_BAG_L1': 0.7834761959921233,
#   'NeuralNetFastAI_r172_BAG_L1': 0.7307135410633616,
#   'CatBoost_r180_BAG_L1': 0.785908722344492,
#   'NeuralNetTorch_r76_BAG_L1': 0.759093015174331,
#   'ExtraTrees_r197_BAG_L1': 0.7282665353874667,
#   'NeuralNetTorch_r121_BAG_L1': 0.7126723039499596,
#   'NeuralNetFastAI_r127_BAG_L1': 0.7206648905363142,
#   'RandomForest_r16_BAG_L1': 0.7751795436117226,
#   'NeuralNetFastAI_r194_BAG_L1': 0.7039557511873046,
#   'CatBoost_r12_BAG_L1': 0.7698945905247306,
#   'NeuralNetTorch_r135_BAG_L1': 0.7493049924707518,
#   'ExtraTrees_r126_BAG_L1': 0.7361288080620874,
#   'WeightedEnsemble_L2': 0.8364705200973012,
#   'LightGBMXT_BAG_L2': 0.8193559596895632,
#   'LightGBM_BAG_L2': 0.8251187304529133,
#   'RandomForestGini_BAG_L2': 0.8145488242789296,
#   'RandomForestEntr_BAG_L2': 0.8143026757789875,
#   'CatBoost_BAG_L2': 0.8146936175141897,
#   'ExtraTreesGini_BAG_L2': 0.8130719332792773,
#   'ExtraTreesEntr_BAG_L2': 0.8123334877794509,
#   'NeuralNetFastAI_BAG_L2': 0.8201088845129156,
#   'XGBoost_BAG_L2': 0.7963627939302675,
#   'NeuralNetTorch_BAG_L2': 0.818226572454535,
#   'LightGBMLarge_BAG_L2': 0.7933510946368585,
#   'CatBoost_r177_BAG_L2': 0.8190084559249393,
#   'NeuralNetTorch_r79_BAG_L2': 0.8315765087455114,
#   'LightGBM_r131_BAG_L2': 0.8149542453376578,
#   'NeuralNetFastAI_r191_BAG_L2': 0.8192980423954594,
#   'CatBoost_r9_BAG_L2': 0.827609174099386,
#   'LightGBM_r96_BAG_L2': 0.8286516853932584,
#   'NeuralNetTorch_r22_BAG_L2': 0.8241051778060929,
#   'XGBoost_r33_BAG_L2': 0.80951001969188,
#   'ExtraTrees_r42_BAG_L2': 0.8137090235144214,
#   'CatBoost_r137_BAG_L2': 0.8308235839221592,
#   'NeuralNetFastAI_r102_BAG_L2': 0.8268852079230858,
#   'CatBoost_r13_BAG_L2': 0.812492760338237,
#   'RandomForest_r195_BAG_L2': 0.8094521023977761,
#   'LightGBM_r188_BAG_L2': 0.8240472605119888,
#   'NeuralNetFastAI_r145_BAG_L2': 0.8170392679254025,
#   'XGBoost_r89_BAG_L2': 0.8148963280435537,
#   'NeuralNetTorch_r30_BAG_L2': 0.8455924939186841,
#   'LightGBM_r130_BAG_L2': 0.8399165990964903,
#   'NeuralNetTorch_r86_BAG_L2': 0.7997509556353527,
#   'CatBoost_r50_BAG_L2': 0.8134483956909533,
#   'NeuralNetFastAI_r11_BAG_L2': 0.7910633615197498,
#   'XGBoost_r194_BAG_L2': 0.8043843391636742,
#   'ExtraTrees_r172_BAG_L2': 0.8185161589250551,
#   'CatBoost_r69_BAG_L2': 0.8236128808062088,
#   'NeuralNetFastAI_r103_BAG_L2': 0.8063824858102631,
#   'WeightedEnsemble_L3': 0.8600718174446889},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetFastAI_r95_BAG_L1': ['NeuralNetFastAI_r95_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetFastAI_r37_BAG_L1': ['NeuralNetFastAI_r37_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'NeuralNetFastAI_r134_BAG_L1': ['NeuralNetFastAI_r134_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetFastAI_r111_BAG_L1': ['NeuralNetFastAI_r111_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'NeuralNetFastAI_r65_BAG_L1': ['NeuralNetFastAI_r65_BAG_L1'],
#   'NeuralNetFastAI_r88_BAG_L1': ['NeuralNetFastAI_r88_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'NeuralNetFastAI_r160_BAG_L1': ['NeuralNetFastAI_r160_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'NeuralNetFastAI_r69_BAG_L1': ['NeuralNetFastAI_r69_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'NeuralNetFastAI_r138_BAG_L1': ['NeuralNetFastAI_r138_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'NeuralNetFastAI_r172_BAG_L1': ['NeuralNetFastAI_r172_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'NeuralNetFastAI_r127_BAG_L1': ['NeuralNetFastAI_r127_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'NeuralNetFastAI_r194_BAG_L1': ['NeuralNetFastAI_r194_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'NeuralNetFastAI_r191_BAG_L2': ['NeuralNetFastAI_r191_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'LightGBM_r96_BAG_L2': ['LightGBM_r96_BAG_L2'],
#   'NeuralNetTorch_r22_BAG_L2': ['NeuralNetTorch_r22_BAG_L2'],
#   'XGBoost_r33_BAG_L2': ['XGBoost_r33_BAG_L2'],
#   'ExtraTrees_r42_BAG_L2': ['ExtraTrees_r42_BAG_L2'],
#   'CatBoost_r137_BAG_L2': ['CatBoost_r137_BAG_L2'],
#   'NeuralNetFastAI_r102_BAG_L2': ['NeuralNetFastAI_r102_BAG_L2'],
#   'CatBoost_r13_BAG_L2': ['CatBoost_r13_BAG_L2'],
#   'RandomForest_r195_BAG_L2': ['RandomForest_r195_BAG_L2'],
#   'LightGBM_r188_BAG_L2': ['LightGBM_r188_BAG_L2'],
#   'NeuralNetFastAI_r145_BAG_L2': ['NeuralNetFastAI_r145_BAG_L2'],
#   'XGBoost_r89_BAG_L2': ['XGBoost_r89_BAG_L2'],
#   'NeuralNetTorch_r30_BAG_L2': ['NeuralNetTorch_r30_BAG_L2'],
#   'LightGBM_r130_BAG_L2': ['LightGBM_r130_BAG_L2'],
#   'NeuralNetTorch_r86_BAG_L2': ['NeuralNetTorch_r86_BAG_L2'],
#   'CatBoost_r50_BAG_L2': ['CatBoost_r50_BAG_L2'],
#   'NeuralNetFastAI_r11_BAG_L2': ['NeuralNetFastAI_r11_BAG_L2'],
#   'XGBoost_r194_BAG_L2': ['XGBoost_r194_BAG_L2'],
#   'ExtraTrees_r172_BAG_L2': ['ExtraTrees_r172_BAG_L2'],
#   'CatBoost_r69_BAG_L2': ['CatBoost_r69_BAG_L2'],
#   'NeuralNetFastAI_r103_BAG_L2': ['NeuralNetFastAI_r103_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.004996299743652344,
#   'KNeighborsDist_BAG_L1': 0.0039980411529541016,
#   'LightGBMXT_BAG_L1': 1.173638105392456,
#   'LightGBM_BAG_L1': 2.2816808223724365,
#   'RandomForestGini_BAG_L1': 1.058523416519165,
#   'RandomForestEntr_BAG_L1': 0.770470142364502,
#   'CatBoost_BAG_L1': 4.442210912704468,
#   'ExtraTreesGini_BAG_L1': 1.6524860858917236,
#   'ExtraTreesEntr_BAG_L1': 0.6938021183013916,
#   'NeuralNetFastAI_BAG_L1': 10.76312804222107,
#   'XGBoost_BAG_L1': 10.969018697738647,
#   'NeuralNetTorch_BAG_L1': 32.5000901222229,
#   'LightGBMLarge_BAG_L1': 5.079074144363403,
#   'CatBoost_r177_BAG_L1': 6.58044958114624,
#   'NeuralNetTorch_r79_BAG_L1': 38.71578526496887,
#   'LightGBM_r131_BAG_L1': 4.939874649047852,
#   'NeuralNetFastAI_r191_BAG_L1': 12.147176265716553,
#   'CatBoost_r9_BAG_L1': 17.439350128173828,
#   'LightGBM_r96_BAG_L1': 2.7655820846557617,
#   'NeuralNetTorch_r22_BAG_L1': 37.357834577560425,
#   'XGBoost_r33_BAG_L1': 4.151790618896484,
#   'ExtraTrees_r42_BAG_L1': 1.022430181503296,
#   'CatBoost_r137_BAG_L1': 5.744651794433594,
#   'NeuralNetFastAI_r102_BAG_L1': 15.201077461242676,
#   'CatBoost_r13_BAG_L1': 12.371970176696777,
#   'RandomForest_r195_BAG_L1': 1.3332788944244385,
#   'LightGBM_r188_BAG_L1': 4.106939077377319,
#   'NeuralNetFastAI_r145_BAG_L1': 11.905831336975098,
#   'XGBoost_r89_BAG_L1': 4.358855247497559,
#   'NeuralNetTorch_r30_BAG_L1': 40.1536431312561,
#   'LightGBM_r130_BAG_L1': 4.50452446937561,
#   'NeuralNetTorch_r86_BAG_L1': 38.60470652580261,
#   'CatBoost_r50_BAG_L1': 5.330237627029419,
#   'NeuralNetFastAI_r11_BAG_L1': 9.777058124542236,
#   'XGBoost_r194_BAG_L1': 6.912198543548584,
#   'ExtraTrees_r172_BAG_L1': 0.9076344966888428,
#   'CatBoost_r69_BAG_L1': 5.400537490844727,
#   'NeuralNetFastAI_r103_BAG_L1': 8.799849271774292,
#   'NeuralNetTorch_r14_BAG_L1': 37.96633172035217,
#   'LightGBM_r161_BAG_L1': 22.662747144699097,
#   'NeuralNetFastAI_r143_BAG_L1': 14.327617645263672,
#   'CatBoost_r70_BAG_L1': 9.580495595932007,
#   'NeuralNetFastAI_r156_BAG_L1': 12.863359928131104,
# ...
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                            model  score_val eval_metric  pred_time_val  \
#  0            WeightedEnsemble_L3   0.860072     roc_auc      10.280145
#  1      NeuralNetTorch_r30_BAG_L2   0.845592     roc_auc       9.764906
#  2           LightGBM_r130_BAG_L2   0.839917     roc_auc       9.677868
#  3            WeightedEnsemble_L2   0.836471     roc_auc       0.626944
#  4      NeuralNetTorch_r79_BAG_L2   0.831577     roc_auc       9.778688
#  ..                           ...        ...         ...            ...
#  131  NeuralNetFastAI_r160_BAG_L1   0.703348     roc_auc       0.109744
#  132          LightGBM_r96_BAG_L1   0.703319     roc_auc       0.022687
#  133        NeuralNetTorch_BAG_L1   0.688086     roc_auc       0.139687
#  134        KNeighborsDist_BAG_L1   0.649861     roc_auc       0.021375
#  135        KNeighborsUnif_BAG_L1   0.646791     roc_auc       1.192120
#
#          fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    1425.068233                0.001000           0.133768            3
#  1    1188.753238                0.111548          19.766773            2
#  2    1171.336583                0.024509           2.350118            2
#  3     121.384676                0.000000           0.227889            2
#  4    1204.665307                0.125330          35.678842            2
#  ..           ...                     ...                ...          ...
#  131    11.615845                0.109744          11.615845            1
#  132     2.765582                0.022687           2.765582            1
#  133    32.500090                0.139687          32.500090            1
#  134     0.003998                0.021375           0.003998            1
#  135     0.004996                1.192120           0.004996            1
#
#       can_infer  fit_order
#  0         True        136
#  1         True        127
#  2         True        128
#  3         True         99
#  4         True        112
#  ..         ...        ...
#  131       True         79
#  132       True         19
#  133       True         12
#  134       True          2
#  135       True          1
#
#  [136 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.7617715617715617
# Evaluations on test data:
# {
#     "roc_auc": 0.7617715617715617,
#     "accuracy": 0.6702127659574468,
#     "balanced_accuracy": 0.6808857808857809,
#     "mcc": 0.357220794934966,
#     "f1": 0.6868686868686869,
#     "precision": 0.7727272727272727,
#     "recall": 0.6181818181818182
# }
# {'roc_auc': 0.7617715617715617,
#  'accuracy': 0.6702127659574468,
#  'balanced_accuracy': 0.6808857808857809,
#  'mcc': 0.357220794934966,
#  'f1': 0.6868686868686869,
#  'precision': 0.7727272727272727,
#  'recall': 0.6181818181818182}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                            model  score_test  balanced_accuracy        f1  \
# 0          KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 1          ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 2        RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 3       RandomForest_r195_BAG_L1    1.000000           1.000000  1.000000
# 4          ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# ..                           ...         ...                ...       ...
# 131          LightGBM_r96_BAG_L1    0.807396           0.725530  0.715084
# 132         ExtraTrees_r4_BAG_L1    0.799722           0.729266  0.724796
# 133      RandomForest_r34_BAG_L1    0.790542           0.711224  0.711230
# 134  NeuralNetFastAI_r143_BAG_L1    0.785243           0.708937  0.676737
# 135  NeuralNetFastAI_r103_BAG_L1    0.781044           0.672072  0.696078
#
#      f1_macro  f1_micro   roc_auc  average_precision  precision    recall  \
# 0    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 1    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 2    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 3    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 4    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# ..        ...       ...       ...                ...        ...       ...
# 131  0.725418  0.725806  0.807396           0.804074   0.711111  0.719101
# 132  0.728446  0.728495  0.799722           0.799100   0.703704  0.747191
# 133  0.709669  0.709677  0.790542           0.790799   0.678571  0.747191
# 134  0.708829  0.712366  0.785243           0.798863   0.732026  0.629213
# 135  0.663515  0.666667  0.781044           0.785251   0.617391  0.797753
#
#      ...  eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0    ...      roc_auc        0.030718       0.021375   0.003998
# 1    ...      roc_auc        0.078247       0.142377   0.693802
# 2    ...      roc_auc        0.079027       0.152909   0.770470
# 3    ...      roc_auc        0.079112       0.159447   1.333279
# 4    ...      roc_auc        0.085756       0.082386   1.652486
# ..   ...          ...             ...            ...        ...
# 131  ...      roc_auc        0.060058       0.022687   2.765582
# 132  ...      roc_auc        0.099416       0.145254   1.015719
# 133  ...      roc_auc        0.079943       0.163632   1.376427
# 134  ...      roc_auc        0.375268       0.136454  14.327618
# 135  ...      roc_auc        0.140124       0.107532   8.799849
#
#      pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                   0.030718                0.021375           0.003998
# 1                   0.078247                0.142377           0.693802
# 2                   0.079027                0.152909           0.770470
# 3                   0.079112                0.159447           1.333279
# 4                   0.085756                0.082386           1.652486
# ..                       ...                     ...                ...
# 131                 0.060058                0.022687           2.765582
# 132                 0.099416                0.145254           1.015719
# 133                 0.079943                0.163632           1.376427
# 134                 0.375268                0.136454          14.327618
# 135                 0.140124                0.107532           8.799849
#
#      stack_level  can_infer  fit_order
# 0              1       True          2
# 1              1       True          9
# 2              1       True          6
# 3              1       True         26
# 4              1       True          8
# ..           ...        ...        ...
# 131            1       True         19
# 132            1       True         66
# 133            1       True         60
# 134            1       True         41
# 135            1       True         38
#
# [136 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 372 rows with 5 shuffle sets...
# 	1091.66s	= Expected runtime (218.33s per shuffle set)
# 	431.41s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                 importance    stddev  \
# TRV.Tavec.24_Discriminabilidad.PD                 0.090363  0.012743
# TRV.Stroop.palabras.PD                            0.032804  0.003985
# TRV.Tavec.05_Rg-Md.PD                             0.023735  0.009644
# ISC.resultadosReservaCognitiva.escolaridad        0.015950  0.004633
# TRV.LeidenNT.CaminosTopgrafico_total.PD           0.015308  0.002570
# TRV.LeidenNT.UbicacionAlocentrica_total.PD        0.012788  0.003274
# TRV.Tavec.10_RCl-LP.PD                            0.012273  0.002938
# TRV.Tavec.12_ESem-RI-B.PD                         0.010553  0.003693
# TRV.Tavec.20_I-RL.PD                              0.006886  0.001183
# ISC.resultadosReservaCognitiva.Total.PD           0.005404  0.001976
# ISC.resultadosObservacion.enfermedadesDiabetes    0.005265  0.001944
# TRV.Stroop.color.PD                               0.004077  0.001058
# TRV.Tavec.14_ESem-RL-LP.PD                        0.003290  0.000633
# TRV.LeidenNT.PuntoReferencia_total.PD             0.003145  0.000779
# TRV.Tavec.17_ESer-RL-CP.PD                        0.001506  0.000721
# ISC.resultadosObservacion.alcohol                 0.000579  0.000354
# ISC.FPacientes.genero                             0.000463  0.000079
#
#                                                  p_value  n  p99_high  \
# TRV.Tavec.24_Discriminabilidad.PD               0.000046  5  0.116600
# TRV.Stroop.palabras.PD                          0.000026  5  0.041010
# TRV.Tavec.05_Rg-Md.PD                           0.002659  5  0.043592
# ISC.resultadosReservaCognitiva.escolaridad      0.000766  5  0.025490
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.000092  5  0.020599
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.000473  5  0.019528
# TRV.Tavec.10_RCl-LP.PD                          0.000366  5  0.018322
# TRV.Tavec.12_ESem-RI-B.PD                       0.001540  5  0.018157
# TRV.Tavec.20_I-RL.PD                            0.000101  5  0.009323
# ISC.resultadosReservaCognitiva.Total.PD         0.001809  5  0.009471
# ISC.resultadosObservacion.enfermedadesDiabetes  0.001877  5  0.009268
# TRV.Stroop.color.PD                             0.000499  5  0.006257
# TRV.Tavec.14_ESem-RL-LP.PD                      0.000157  5  0.004593
# TRV.LeidenNT.PuntoReferencia_total.PD           0.000417  5  0.004749
# TRV.Tavec.17_ESer-RL-CP.PD                      0.004753  5  0.002990
# ISC.resultadosObservacion.alcohol               0.010813  5  0.001308
# ISC.FPacientes.genero                           0.000099  5  0.000627
#
#                                                  p99_low
# TRV.Tavec.24_Discriminabilidad.PD               0.064125
# TRV.Stroop.palabras.PD                          0.024599
# TRV.Tavec.05_Rg-Md.PD                           0.003877
# ISC.resultadosReservaCognitiva.escolaridad      0.006411
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.010016
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.006048
# TRV.Tavec.10_RCl-LP.PD                          0.006224
# TRV.Tavec.12_ESem-RI-B.PD                       0.002949
# TRV.Tavec.20_I-RL.PD                            0.004450
# ISC.resultadosReservaCognitiva.Total.PD         0.001336
# ISC.resultadosObservacion.enfermedadesDiabetes  0.001262
# TRV.Stroop.color.PD                             0.001898
# TRV.Tavec.14_ESem-RL-LP.PD                      0.001986
# TRV.LeidenNT.PuntoReferencia_total.PD           0.001541
# TRV.Tavec.17_ESer-RL-CP.PD                      0.000022
# ISC.resultadosObservacion.alcohol              -0.000150
# ISC.FPacientes.genero                           0.000300
