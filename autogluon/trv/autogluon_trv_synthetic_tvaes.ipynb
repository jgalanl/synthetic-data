# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/trv/synthetic-tvaes.csv')

# %%
VARS = ["ISC.FPacientes.IDUsuario",
"ISC.FPacientes.etiquetaDiagnosticaExpTLP",
"ED_2Clases",
"ISC.FPacientes.etiquetaDiagnostica",
"ED_MMSE_2Clases",
"ISC.FPacientes.genero",
"ISC.FPacientes.Edad",
"ISC.resultadosCovid.numDosis",
"ISC.resultadosCovid.numVecesCovid",
"ISC.resultadosCovid.numVecesCovid_mode",
"ISC.resultadosCovid.pasadoCovid",
"ISC.resultadosCovid.sentimientoAislado",
"ISC.resultadosCovid.sentimientoAislado_mediaFiltro",
"ISC.resultadosCovid.sentimientoAislado_mode",
"ISC.resultadosCovid.sintomaCansancio",
"ISC.resultadosCovid.sintomaDiarrea",
"ISC.resultadosCovid.sintomaDifRespirar",
"ISC.resultadosCovid.sintomaDolCabeza",
"ISC.resultadosCovid.sintomaDolGarganta",
"ISC.resultadosCovid.sintomaDolMuscular",
"ISC.resultadosCovid.sintomaEscalofrios",
"ISC.resultadosCovid.sintomaFiebre",
"ISC.resultadosCovid.sintomaOtro",
"ISC.resultadosCovid.sintomaOtroString",
"ISC.resultadosCovid.sintomaPerGusto",
"ISC.resultadosCovid.sintomaPerOlfato",
"ISC.resultadosCovid.vacunado",
"ISC.resultadosCribaje.Total.PD",
"ISC.resultadosObservacion.alcohol",
"ISC.resultadosObservacion.ansiedad",
"ISC.resultadosObservacion.añosSinFumar",
"ISC.resultadosObservacion.añosSinFumar_Rangos",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn",
"ISC.resultadosObservacion.depresion",
"ISC.resultadosObservacion.enfermedadesAltTiroides",
"ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos",
"ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica",
"ISC.resultadosObservacion.enfermedadesDiabetes",
"ISC.resultadosObservacion.enfermedadesHepatica",
"ISC.resultadosObservacion.enfermedadesHipercolesterolemia",
"ISC.resultadosObservacion.enfermedadesHipertension",
"ISC.resultadosObservacion.enfermedadesNinguna",
"ISC.resultadosObservacion.enfermedadesOtros",
"ISC.resultadosObservacion.enfermedadesOtrosString",
"ISC.resultadosObservacion.enfermedadesRenal",
"ISC.resultadosObservacion.entorno",
"ISC.resultadosObservacion.familiaresAlzheimer",
"ISC.resultadosObservacion.familiaresOtraDemencia",
"ISC.resultadosObservacion.fumador",
"ISC.resultadosObservacion.numCigarros",
"ISC.resultadosObservacion.numCigarrosDia_knn",
"ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad",
"ISC.resultadosObservacion.tratCronico",
"ISC.resultadosObservacion.tratPsicologic",
"ISC.resultadosObservacion.tratPsiquiatrico",
"ISC.resultadosOtros.frecOlvidos",
"ISC.resultadosOtros.frecUsoEmail",
"ISC.resultadosOtros.frecUsoMovil",
"ISC.resultadosOtros.frecUsoOrdenador",
"ISC.resultadosOtros.frecUsoRSociales",
"ISC.resultadosOtros.frecUsoTele",
"ISC.resultadosOtros.nivelActFisica",
"ISC.resultadosOtros.nivelSociabilidad",
"ISC.resultadosReservaCognitiva.Total.PD",
"ISC.resultadosReservaCognitiva.actividadLectora",
"ISC.resultadosReservaCognitiva.cursos",
"ISC.resultadosReservaCognitiva.escolaridad",
"ISC.resultadosReservaCognitiva.escolaridadPadres",
"ISC.resultadosReservaCognitiva.formacionMusical",
"ISC.resultadosReservaCognitiva.idiomas",
"ISC.resultadosReservaCognitiva.juegos",
"ISC.resultadosReservaCognitiva.ocupacion",
"ISC.resultadosWFQ.DE_array",
"ISC.resultadosWFQ.DE_total.PD",
"ISC.resultadosWFQ.NO_array",
"ISC.resultadosWFQ.NO_total.PD",
"ISC.resultadosWFQ.SA_array",
"ISC.resultadosWFQ.SA_total.PD",
"TRV.LeidenNT.CaminosRuta_total.PD",
"TRV.LeidenNT.CaminosTopgrafico_total.PD",
"TRV.LeidenNT.Orden_total.PD",
"TRV.LeidenNT.PuntoReferencia_total.PD",
"TRV.LeidenNT.UbicacionAlocentrica_total.PD",
"TRV.LeidenNT.UbicacionEgocentrico_total.PD",
"TRV.Stroop.color.PD",
"TRV.Stroop.color.PDC",
"TRV.Stroop.interferencia.PD",
"TRV.Stroop.palabras.PD",
"TRV.Stroop.palabras.PDC",
"TRV.Stroop.palabrasColor.PD",
"TRV.Stroop.palabrasColor.PDC",
"TRV.Tavec.00_RI-A1.PD",
"TRV.Tavec.01_RI-A5.PD",
"TRV.Tavec.02_RI-AT.PD",
"TRV.Tavec.03_RI-B.PD",
"TRV.Tavec.04_Rg-Pr.PD",
"TRV.Tavec.05_Rg-Md.PD",
"TRV.Tavec.06_Rg-Rc.PD",
"TRV.Tavec.07_RL-CP.PD",
"TRV.Tavec.08_RCl-CP.PD",
"TRV.Tavec.09_RL-LP.PD",
"TRV.Tavec.10_RCl-LP.PD",
"TRV.Tavec.11_ESem-RI-A.PD",
"TRV.Tavec.12_ESem-RI-B.PD",
"TRV.Tavec.13_ESem-RL-CP.PD",
"TRV.Tavec.14_ESem-RL-LP.PD",
"TRV.Tavec.15_ESer-RI-A.PD",
"TRV.Tavec.16_ESer-RI-B.PD",
"TRV.Tavec.17_ESer-RL-CP.PD",
"TRV.Tavec.18_ESer-RL-LP.PD",
"TRV.Tavec.19_P.PD",
"TRV.Tavec.20_I-RL.PD",
"TRV.Tavec.21_I-RCL.PD",
"TRV.Tavec.22_Recon-Ac.PD",
"TRV.Tavec.23_FP.PD",
"TRV.Tavec.24_Discriminabilidad.PD",
"TRV.Tavec.25_Sesgo.PD",
"TRV.Tavec.26_RI-B_frente_RI-A1.PD",
"TRV.Tavec.27_RL-CP_frente_RI-A5.PD",
"TRV.Tavec.28_RCl-Cp_frente_RCl-LP.PD",
"TRV.Tavec.29_RL-LP_frente_RL-CP.PD",
"TRV.Tavec.30_RCl-LP_frente_RL-LP.PD",
"TRV.Tavec.31_Recon-Ac_frente_RL-LP.PD",
"TRV.Tavec.32_Recon-Ac_frente_RCl-LP.PD"
]

VARS = [
'ISC.resultadosReservaCognitiva.Total.PD',
'ISC.resultadosReservaCognitiva.escolaridad',
'ISC.resultadosObservacion.enfermedadesDiabetes',
'ISC.resultadosObservacion.alcohol',
'TRV.LeidenNT.UbicacionAlocentrica_total.PD',
'TRV.LeidenNT.PuntoReferencia_total.PD',
'TRV.LeidenNT.CaminosTopgrafico_total.PD',
'TRV.Stroop.palabras.PD',
'TRV.Stroop.color.PD',
#'TRV.Stroop.palabras.PDC',
'TRV.Tavec.12_ESem-RI-B.PD',
'TRV.Tavec.10_RCl-LP.PD',
'TRV.Tavec.05_Rg-Md.PD',
'ISC.FPacientes.genero',
'TRV.Tavec.20_I-RL.PD',
'TRV.Tavec.17_ESer-RL-CP.PD',
'TRV.Tavec.14_ESem-RL-LP.PD',
'TRV.Tavec.24_Discriminabilidad.PD']

CLASS = 'ED_2Clases'

drop_columns = []
for v in df.columns:
    if not v in VARS+[CLASS]:
        drop_columns.append(v)

# %%
drop_columns
# Out:
# []

# %%
categorical_columns = [
    'ED_2Clases'
]

# %%
df[categorical_columns] = df[categorical_columns].astype('object')

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.resultadosObservacion.alcohol  \
# 0          D                      2                              False
# 1          D                      2                              False
# 2          H                      2                              False
# 3          D                      2                              False
# 4          D                      2                              False
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ISC.resultadosReservaCognitiva.Total.PD  \
# 0                                       12
# 1                                        8
# 2                                       11
# 3                                       18
# 4                                       13
#
#    ISC.resultadosReservaCognitiva.escolaridad  \
# 0                                           3
# 1                                           3
# 2                                           4
# 3                                           4
# 4                                           4
#
#    TRV.LeidenNT.CaminosTopgrafico_total.PD  \
# 0                                        2
# 1                                        1
# 2                                        3
# 3                                        4
# 4                                        2
#
#    TRV.LeidenNT.PuntoReferencia_total.PD  \
# 0                                      8
# 1                                      7
# 2                                      8
# 3                                      8
# 4                                      6
#
#    TRV.LeidenNT.UbicacionAlocentrica_total.PD  TRV.Stroop.color.PD  \
# 0                                           1                   27
# 1                                           1                   17
# 2                                           1                   40
# 3                                           3                   46
# 4                                           0                   32
#
#    TRV.Stroop.palabras.PD  TRV.Tavec.05_Rg-Md.PD  TRV.Tavec.10_RCl-LP.PD  \
# 0                      33              50.000000                      12
# 1                      18              45.714286                       8
# 2                      45              50.000000                      13
# 3                      51              48.648649                      12
# 4                      35              46.153846                      15
#
#    TRV.Tavec.12_ESem-RI-B.PD  TRV.Tavec.14_ESem-RL-LP.PD  \
# 0                          0                           1
# 1                          2                           2
# 2                          0                           3
# 3                          3                           2
# 4                          0                           3
#
#    TRV.Tavec.17_ESer-RL-CP.PD  TRV.Tavec.20_I-RL.PD  \
# 0                           1                    10
# 1                           1                    34
# 2                           5                     3
# 3                           1                     3
# 4                           0                     4
#
#    TRV.Tavec.24_Discriminabilidad.PD
# 0                          81.818182
# 1                          68.181818
# 2                          88.636364
# 3                          90.909091
# 4                          93.181818

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((372, 18), (94, 18))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/tvaes/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       6.72 GB / 15.94 GB (42.1%)
# Disk Space Avail:   120.62 GB / 446.36 GB (27.0%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 17:55:56,251	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8267
# 		Context path: "AutogluonModels/synthetic/tvaes/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=20200) Running DyStack sub-fit ...
# (_dystack pid=20200) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=20200) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=20200) AutoGluon will save models to "AutogluonModels/synthetic/tvaes/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=20200) Train Data Rows:    330
# (_dystack pid=20200) Train Data Columns: 17
# (_dystack pid=20200) Label Column:       ED_2Clases
# (_dystack pid=20200) Problem Type:       binary
# (_dystack pid=20200) Preprocessing data ...
# (_dystack pid=20200) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=20200) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=20200) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=20200) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=20200) Using Feature Generators to preprocess the data ...
# (_dystack pid=20200) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=20200) 	Available Memory:                    5106.31 MB
# (_dystack pid=20200) 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=20200) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=20200) 	Stage 1 Generators:
# (_dystack pid=20200) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=20200) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=20200) 	Stage 2 Generators:
# (_dystack pid=20200) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=20200) 	Stage 3 Generators:
# (_dystack pid=20200) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=20200) 	Stage 4 Generators:
# (_dystack pid=20200) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=20200) 	Stage 5 Generators:
# (_dystack pid=20200) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=20200) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=20200) 		('bool', [])  :  2 | ['ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=20200) 		('float', []) :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=20200) 		('int', [])   : 13 | ['ISC.FPacientes.genero', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', ...]
# (_dystack pid=20200) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=20200) 		('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=20200) 		('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# (_dystack pid=20200) 		('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=20200) 	0.1s = Fit runtime
# (_dystack pid=20200) 	17 features in original data used to generate 17 features in processed data.
# (_dystack pid=20200) 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=20200) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=20200) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=20200) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=20200) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=20200) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=20200) User-specified model hyperparameters to be fit:
# (_dystack pid=20200) {
# (_dystack pid=20200) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=20200) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=20200) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=20200) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=20200) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=20200) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=20200) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=20200) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=20200) }
# (_dystack pid=20200) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=20200) Fitting 110 L1 models ...
# (_dystack pid=20200) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.71s of the 892.27s of remaining time.
# (_dystack pid=20200) 	0.7782	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	0.01s	 = Training   runtime
# (_dystack pid=20200) 	0.03s	 = Validation runtime
# (_dystack pid=20200) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 591.05s of the 888.61s of remaining time.
# (_dystack pid=20200) 	0.7779	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	0.02s	 = Training   runtime
# (_dystack pid=20200) 	0.04s	 = Validation runtime
# (_dystack pid=20200) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 590.98s of the 888.54s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# (_dystack pid=20200) 	0.8553	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	2.0s	 = Training   runtime
# (_dystack pid=20200) 	0.02s	 = Validation runtime
# (_dystack pid=20200) Fitting model: LightGBM_BAG_L1 ... Training model for up to 582.28s of the 879.84s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# (_dystack pid=20200) 	0.8634	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	2.25s	 = Training   runtime
# (_dystack pid=20200) 	0.02s	 = Validation runtime
# (_dystack pid=20200) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 573.61s of the 871.17s of remaining time.
# (_dystack pid=20200) 	0.8526	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	1.0s	 = Training   runtime
# (_dystack pid=20200) 	0.12s	 = Validation runtime
# (_dystack pid=20200) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 572.44s of the 870.0s of remaining time.
# (_dystack pid=20200) 	0.8512	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	0.96s	 = Training   runtime
# (_dystack pid=20200) 	0.11s	 = Validation runtime
# (_dystack pid=20200) Fitting model: CatBoost_BAG_L1 ... Training model for up to 571.31s of the 868.87s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=20200) 	0.8843	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	5.39s	 = Training   runtime
# (_dystack pid=20200) 	0.03s	 = Validation runtime
# (_dystack pid=20200) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 559.93s of the 857.49s of remaining time.
# (_dystack pid=20200) 	0.8461	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	1.15s	 = Training   runtime
# (_dystack pid=20200) 	0.17s	 = Validation runtime
# (_dystack pid=20200) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 558.55s of the 856.12s of remaining time.
# (_dystack pid=20200) 	0.8454	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	0.98s	 = Training   runtime
# (_dystack pid=20200) 	0.15s	 = Validation runtime
# (_dystack pid=20200) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 557.37s of the 854.93s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20200) 	0.8414	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	9.58s	 = Training   runtime
# (_dystack pid=20200) 	0.1s	 = Validation runtime
# (_dystack pid=20200) Fitting model: XGBoost_BAG_L1 ... Training model for up to 539.01s of the 836.57s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=20200) 	0.8624	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	3.31s	 = Training   runtime
# (_dystack pid=20200) 	0.04s	 = Validation runtime
# (_dystack pid=20200) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 528.7s of the 826.26s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=18964) Stack (most recent call first):
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18964)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=18964)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=20200) 	0.8463	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	17.51s	 = Training   runtime
# (_dystack pid=20200) 	0.14s	 = Validation runtime
# (_dystack pid=20200) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 501.88s of the 799.44s of remaining time.
# (_ray_fit pid=28624) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=28624)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.92%)
# (_dystack pid=20200) 	0.8586	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	2.69s	 = Training   runtime
# (_dystack pid=20200) 	0.02s	 = Validation runtime
# (_dystack pid=20200) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 490.75s of the 788.31s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=20200) 	0.8856	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	5.61s	 = Training   runtime
# (_dystack pid=20200) 	0.03s	 = Validation runtime
# (_dystack pid=20200) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 478.08s of the 775.64s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=23680) Stack (most recent call first):
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=23680)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=23680)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=20200) 	0.8506	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	36.6s	 = Training   runtime
# (_dystack pid=20200) 	0.16s	 = Validation runtime
# (_dystack pid=20200) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 434.77s of the 732.33s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=11948) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=11948)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_ray_fit pid=21376) [1000]	valid_set's binary_logloss: 0.295061
# (_dystack pid=20200) 	0.877	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	2.97s	 = Training   runtime
# (_dystack pid=20200) 	0.03s	 = Validation runtime
# (_dystack pid=20200) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 425.15s of the 722.71s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20200) 	0.8215	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	12.81s	 = Training   runtime
# (_dystack pid=20200) 	0.12s	 = Validation runtime
# (_dystack pid=20200) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 404.84s of the 702.4s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=20200) 	0.8828	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	26.07s	 = Training   runtime
# (_dystack pid=20200) 	0.05s	 = Validation runtime
# (_dystack pid=20200) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 370.54s of the 668.1s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=5280) [1000]	valid_set's binary_logloss: 0.398806 [repeated 2x across cluster]
# (_ray_fit pid=5280) [7000]	valid_set's binary_logloss: 0.356076 [repeated 16x across cluster]
# (_dystack pid=20200) 	0.8589	 = Validation score   (roc_auc)
# (_dystack pid=20200) 	12.12s	 = Training   runtime
# (_dystack pid=20200) 	0.14s	 = Validation runtime
# (_dystack pid=20200) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 346.3s of the 643.87s of remaining time.
# (_dystack pid=20200) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=33596) Stack (most recent call first):
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=33596)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=33596)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=15476)
# (_dystack pid=20200) 	0.8519	 = Validation score   (roc_auc)
# ...
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 1588.17s of the 1588.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8489	 = Validation score   (roc_auc)
# 	16.81s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 1566.1s of the 1566.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8668	 = Validation score   (roc_auc)
# 	32.32s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 1529.43s of the 1529.41s of remaining time.
# 	0.8408	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 1526.98s of the 1526.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8546	 = Validation score   (roc_auc)
# 	13.16s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 1505.61s of the 1505.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.842	 = Validation score   (roc_auc)
# 	15.22s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 1483.96s of the 1483.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.8582	 = Validation score   (roc_auc)
# 	5.99s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 1470.52s of the 1470.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	0.8549	 = Validation score   (roc_auc)
# 	2.07s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 1459.45s of the 1459.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8679	 = Validation score   (roc_auc)
# 	6.65s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 1441.52s of the 1441.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.852	 = Validation score   (roc_auc)
# 	34.74s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 1399.61s of the 1399.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8536	 = Validation score   (roc_auc)
# 	43.61s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 1353.75s of the 1353.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.8746	 = Validation score   (roc_auc)
# 	7.79s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 1338.31s of the 1338.28s of remaining time.
# 	0.8579	 = Validation score   (roc_auc)
# 	0.98s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 1337.17s of the 1337.15s of remaining time.
# 	0.8689	 = Validation score   (roc_auc)
# 	1.17s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 1333.58s of the 1333.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.8618	 = Validation score   (roc_auc)
# 	11.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 1318.24s of the 1318.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8359	 = Validation score   (roc_auc)
# 	43.33s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 1268.54s of the 1268.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8352	 = Validation score   (roc_auc)
# 	9.81s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 1252.01s of the 1251.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.87	 = Validation score   (roc_auc)
# 	6.6s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 1239.22s of the 1239.2s of remaining time.
# 	0.8558	 = Validation score   (roc_auc)
# 	1.22s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 1237.76s of the 1237.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8478	 = Validation score   (roc_auc)
# 	3.45s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 1225.93s of the 1225.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.8649	 = Validation score   (roc_auc)
# 	2.15s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 1216.84s of the 1216.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8452	 = Validation score   (roc_auc)
# 	11.34s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 1197.73s of the 1197.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8741	 = Validation score   (roc_auc)
# 	5.36s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 1185.42s of the 1185.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8546	 = Validation score   (roc_auc)
# 	18.01s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 1160.65s of the 1160.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8742	 = Validation score   (roc_auc)
# 	2.82s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 1148.4s of the 1148.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8482	 = Validation score   (roc_auc)
# 	16.69s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 1115.7s of the 1115.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8713	 = Validation score   (roc_auc)
# 	8.29s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 1102.42s of the 1102.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8533	 = Validation score   (roc_auc)
# 	16.32s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 1076.8s of the 1076.78s of remaining time.
# 	0.8602	 = Validation score   (roc_auc)
# 	1.06s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 1064.9s of the 1064.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8641	 = Validation score   (roc_auc)
# 	42.71s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 1017.91s of the 1017.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8429	 = Validation score   (roc_auc)
# 	12.73s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 995.68s of the 995.66s of remaining time.
# 	0.8515	 = Validation score   (roc_auc)
# 	1.75s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 993.64s of the 993.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8383	 = Validation score   (roc_auc)
# 	12.06s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 973.7s of the 973.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8655	 = Validation score   (roc_auc)
# 	5.36s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 957.33s of the 957.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8526	 = Validation score   (roc_auc)
# 	49.85s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 898.53s of the 898.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8475	 = Validation score   (roc_auc)
# 	10.92s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTrees_r126_BAG_L1 ... Training model for up to 882.96s of the 882.94s of remaining time.
# 	0.8622	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 881.41s of the 881.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.852	 = Validation score   (roc_auc)
# 	28.8s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 845.89s of the 845.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8602	 = Validation score   (roc_auc)
# 	17.55s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r163_BAG_L1 ... Training model for up to 816.79s of the 816.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.8675	 = Validation score   (roc_auc)
# 	8.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r198_BAG_L1 ... Training model for up to 801.64s of the 801.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.8681	 = Validation score   (roc_auc)
# 	7.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 787.51s of the 787.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8561	 = Validation score   (roc_auc)
# 	30.95s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 750.04s of the 750.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8472	 = Validation score   (roc_auc)
# 	30.77s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: XGBoost_r95_BAG_L1 ... Training model for up to 715.03s of the 715.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.8591	 = Validation score   (roc_auc)
# 	4.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_r34_BAG_L1 ... Training model for up to 696.43s of the 696.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	0.8657	 = Validation score   (roc_auc)
# 	2.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L1 ... Training model for up to 688.09s of the 688.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8651	 = Validation score   (roc_auc)
# 	4.98s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 675.99s of the 675.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8443	 = Validation score   (roc_auc)
# 	21.45s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 647.53s of the 647.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8387	 = Validation score   (roc_auc)
# 	37.84s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 603.37s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r31_BAG_L1': 0.174, 'CatBoost_r50_BAG_L1': 0.13, 'LightGBM_r15_BAG_L1': 0.13, 'NeuralNetTorch_r197_BAG_L1': 0.13, 'LightGBM_r121_BAG_L1': 0.13, 'NeuralNetTorch_r22_BAG_L1': 0.087, 'CatBoost_r6_BAG_L1': 0.087, 'LightGBM_BAG_L1': 0.043, 'NeuralNetTorch_r143_BAG_L1': 0.043, 'RandomForest_r166_BAG_L1': 0.043}
# 	0.8935	 = Validation score   (roc_auc)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2072.46s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 61.1 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/tvaes/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L2   0.893490     roc_auc       0.853921  177.364443                0.000000           0.232055            2       True        111
# 1            CatBoost_r50_BAG_L1   0.876578     roc_auc       0.030463    5.040331                0.030463           5.040331            1       True         33
# 2            LightGBM_r15_BAG_L1   0.875478     roc_auc       0.021160    3.220350                0.021160           3.220350            1       True         50
# 3           CatBoost_r177_BAG_L1   0.874725     roc_auc       0.087111    6.010501                0.087111           6.010501            1       True         14
# 4           CatBoost_r143_BAG_L1   0.874580     roc_auc       0.049025    7.790887                0.049025           7.790887            1       True         74
# 5           LightGBM_r121_BAG_L1   0.874233     roc_auc       0.030977    2.819819                0.030977           2.819819            1       True         87
# 6             CatBoost_r6_BAG_L1   0.874146     roc_auc       0.033035    5.362411                0.033035           5.362411            1       True         85
# 7             XGBoost_r98_BAG_L1   0.872669     roc_auc       0.064440   12.482337                0.064440          12.482337            1       True         49
# 8           LightGBM_r161_BAG_L1   0.872582     roc_auc       0.032619    5.120522                0.032619           5.120522            1       True         40
# 9            CatBoost_r69_BAG_L1   0.872379     roc_auc       0.030082    7.258073                0.030082           7.258073            1       True         37
# 10               LightGBM_BAG_L1   0.871945     roc_auc       0.016705    2.053677                0.016705           2.053677            1       True          4
# 11          CatBoost_r137_BAG_L1   0.871482     roc_auc       0.031894    5.703974                0.031894           5.703974            1       True         23
# 12            CatBoost_r9_BAG_L1   0.871482     roc_auc       0.030439   20.693990                0.030439          20.693990            1       True         18
# 13          CatBoost_r180_BAG_L1   0.871279     roc_auc       0.032493    8.294628                0.032493           8.294628            1       True         89
# 14     NeuralNetTorch_r22_BAG_L1   0.870873     roc_auc       0.141428   43.517410                0.141428          43.517410            1       True         20
# 15          LightGBM_r131_BAG_L1   0.870178     roc_auc       0.033241    4.592812                0.033241           4.592812            1       True         16
# 16          LightGBM_r143_BAG_L1   0.870149     roc_auc       0.029753    3.382929                0.029753           3.382929            1       True         57
# 17           CatBoost_r60_BAG_L1   0.870005     roc_auc       0.031671    6.604636                0.031671           6.604636            1       True         80
# 18           CatBoost_r49_BAG_L1   0.869947     roc_auc       0.026703    5.310379                0.026703           5.310379            1       True         55
# 19           CatBoost_r70_BAG_L1   0.869686     roc_auc       0.032218    8.710350                0.032218           8.710350            1       True         42
# 20      RandomForest_r166_BAG_L1   0.868890     roc_auc       0.097245    1.172319                0.097245           1.172319            1       True         76
# 21       RandomForestGini_BAG_L1   0.868890     roc_auc       0.135550    1.008821                0.135550           1.008821            1       True          5
# 22          CatBoost_r198_BAG_L1   0.868064     roc_auc       0.029160    7.003797                0.029160           7.003797            1       True        103
# 23            CatBoost_r5_BAG_L1   0.867891     roc_auc       0.019417    6.647022                0.019417           6.647022            1       True         71
# 24    NeuralNetTorch_r197_BAG_L1   0.867746     roc_auc       0.151232   44.223282                0.151232          44.223282            1       True         54
# 25          CatBoost_r163_BAG_L1   0.867543     roc_auc       0.028560    8.316122                0.028560           8.316122            1       True        102
# 26     NeuralNetTorch_r31_BAG_L1   0.866790     roc_auc       0.174299   32.315205                0.174299          32.315205            1       True         65
# 27               CatBoost_BAG_L1   0.866559     roc_auc       0.035110   10.408109                0.035110          10.408109            1       True          7
# 28            XGBoost_r34_BAG_L1   0.865690     roc_auc       0.040034    2.777995                0.040034           2.777995            1       True        107
# 29           CatBoost_r12_BAG_L1   0.865458     roc_auc       0.023010    5.356591                0.023010           5.356591            1       True         96
# 30           LightGBM_r42_BAG_L1   0.865082     roc_auc       0.020444    4.983204                0.020444           4.983204            1       True        108
# 31            XGBoost_r22_BAG_L1   0.864937     roc_auc       0.037479    2.154949                0.037479           2.154949            1       True         83
# 32           LightGBM_r94_BAG_L1   0.864300     roc_auc       0.018307    2.395324                0.018307           2.395324            1       True         61
# 33       RandomForestEntr_BAG_L1   0.864285     roc_auc       0.137410    0.845658                0.137410           0.845658            1       True          6
# 34    NeuralNetTorch_r121_BAG_L1   0.864068     roc_auc       0.149156   42.707756                0.149156          42.707756            1       True         92
# 35    NeuralNetTorch_r143_BAG_L1   0.863807     roc_auc       0.157377   37.407582                0.157377          37.407582            1       True         62
# 36             LightGBMXT_BAG_L1   0.863634     roc_auc       0.029378    3.170992                0.029378           3.170992            1       True          3
# 37          LightGBMLarge_BAG_L1   0.862649     roc_auc       0.021371    5.192587                0.021371           5.192587            1       True         13
# 38        ExtraTrees_r126_BAG_L1   0.862215     roc_auc       0.165963    1.311074                0.165963           1.311074            1       True         99
# 39          CatBoost_r167_BAG_L1   0.862041     roc_auc       0.034126    7.009516                0.034126           7.009516            1       True         46
# 40            XGBoost_r89_BAG_L1   0.861954     roc_auc       0.033829    4.429726                0.033829           4.429726            1       True         29
# 41        ExtraTrees_r172_BAG_L1   0.861954     roc_auc       0.159562    0.924671                0.159562           0.924671            1       True         36
# 42           CatBoost_r86_BAG_L1   0.861838     roc_auc       0.029457   14.482698                0.029457          14.482698            1       True         52
# 43            XGBoost_r31_BAG_L1   0.861780     roc_auc       0.042543   11.710759                0.042543          11.710759            1       True         77
# 44         ExtraTreesEntr_BAG_L1   0.861491     roc_auc       0.162028    0.854956                0.162028           0.854956            1       True          9
# 45    NeuralNetTorch_r158_BAG_L1   0.861433     roc_auc       0.183542   35.914657                0.183542          35.914657            1       True         51
# 46         NeuralNetTorch_BAG_L1   0.860825     roc_auc       0.141165   28.703299                0.141165          28.703299            1       True         12
# 47          LightGBM_r196_BAG_L1   0.860361     roc_auc       0.132268    7.048127                0.132268           7.048127            1       True         44
# 48   NeuralNetFastAI_r100_BAG_L1   0.860246     roc_auc       0.150160   17.547008                0.150160          17.547008            1       True        101
# 49        ExtraTrees_r197_BAG_L1   0.860202     roc_auc       0.085528    1.055728                0.085528           1.055728            1       True         91
# 50           CatBoost_r13_BAG_L1   0.860159     roc_auc       0.035281   11.704280                0.035281          11.704280            1       True         25
# 51           LightGBM_r96_BAG_L1   0.859985     roc_auc       0.036697    9.182240                0.036697           9.182240            1       True         19
# 52          CatBoost_r128_BAG_L1   0.859840     roc_auc       0.041025   13.342751                0.041025          13.342751            1       True         63
# 53         ExtraTreesGini_BAG_L1   0.859246     roc_auc       0.146539    1.036981                0.146539           1.036981            1       True          8
# 54         ExtraTrees_r49_BAG_L1   0.859246     roc_auc       0.178543    1.520752                0.178543           1.520752            1       True         56
# 55            XGBoost_r95_BAG_L1   0.859116     roc_auc       0.035994    4.781286                0.035994           4.781286            1       True        106
# 56           LightGBM_r30_BAG_L1   0.858190     roc_auc       0.047957    5.992819                0.047957           5.992819            1       True         69
# 57   NeuralNetFastAI_r156_BAG_L1   0.858016     roc_auc       0.124572   13.434972                0.124572          13.434972            1       True         43
# 58        ExtraTrees_r178_BAG_L1   0.857871     roc_auc       0.088787    0.980369                0.088787           0.980369            1       True         75
# 59            XGBoost_r33_BAG_L1   0.857147     roc_auc       0.048061    5.321565                0.048061           5.321565            1       True         21
# 60           XGBoost_r194_BAG_L1   0.856336     roc_auc       0.054695    3.281039                0.054695           3.281039            1       True         35
# 61          LightGBM_r188_BAG_L1   0.856162     roc_auc       0.025259    2.488592                0.025259           2.488592            1       True         27
# 62   NeuralNetFastAI_r187_BAG_L1   0.856104     roc_auc       0.116775   30.952293                0.116775          30.952293            1       True        104
# 63       RandomForest_r15_BAG_L1   0.855786     roc_auc       0.160889    1.224135                0.160889           1.224135            1       True         81
# 64       RandomForest_r39_BAG_L1   0.855409     roc_auc       0.151402    1.085384                0.151402           1.085384            1       True         45
# 65     NeuralNetTorch_r14_BAG_L1   0.855352     roc_auc       0.123010   42.069521                0.123010          42.069521            1       True         39
# 66         ExtraTrees_r42_BAG_L1   0.855134     roc_auc       0.165766    1.081073                0.165766           1.081073            1       True         22
# 67            XGBoost_r49_BAG_L1   0.854917     roc_auc       0.030109    2.067470                0.030109           2.067470            1       True         70
# 68   NeuralNetFastAI_r143_BAG_L1   0.854859     roc_auc       0.139634   16.004000                0.139634          16.004000            1       True         41
# 69    NeuralNetFastAI_r65_BAG_L1   0.854570     roc_auc       0.136601   13.163537                0.136601          13.163537            1       True         67
# 70   NeuralNetFastAI_r138_BAG_L1   0.854570     roc_auc       0.136074   18.012251                0.136074          18.012251            1       True         86
# 71          LightGBM_r130_BAG_L1   0.853614     roc_auc       0.016216    3.293793                0.016216           3.293793            1       True         31
# 72     NeuralNetTorch_r71_BAG_L1   0.853556     roc_auc       0.139783   43.609726                0.139783          43.609726            1       True         73
# 73     NeuralNetTorch_r86_BAG_L1   0.853527     roc_auc       0.138999   42.489991                0.138999          42.489991            1       True         32
# 74     NeuralNetTorch_r76_BAG_L1   0.853267     roc_auc       0.123021   16.318682                0.123021          16.318682            1       True         90
# 75    NeuralNetTorch_r135_BAG_L1   0.852629     roc_auc       0.125870   49.846500                0.125870          49.846500            1       True         97
# 76      RandomForest_r195_BAG_L1   0.852354     roc_auc       0.134338    1.245535                0.134338           1.245535            1       True         26
# 77     NeuralNetTorch_r87_BAG_L1   0.851992     roc_auc       0.164129   34.737717                0.164129          34.737717            1       True         72
# 78     NeuralNetTorch_r36_BAG_L1   0.851992     roc_auc       0.133122   28.799328                0.133122          28.799328            1       True        100
# 79      RandomForest_r127_BAG_L1   0.851790     roc_auc       0.138724    1.368901                0.138724           1.368901            1       True         58
# 80                XGBoost_BAG_L1   0.851500     roc_auc       0.034705    4.510838                0.034705           4.510838            1       True         11
# 81       RandomForest_r16_BAG_L1   0.851457     roc_auc       0.148403    1.746617                0.148403           1.746617            1       True         94
# 82    NeuralNetFastAI_r37_BAG_L1   0.851153     roc_auc       0.184861   16.069109                0.184861          16.069109            1       True         53
# 83   NeuralNetFastAI_r111_BAG_L1   0.848865     roc_auc       0.133456   16.814192                0.133456          16.814192            1       True         64
# 84   NeuralNetFastAI_r172_BAG_L1   0.848170     roc_auc       0.115019   16.689995                0.115019          16.689995            1       True         88
# 85          LightGBM_r135_BAG_L1   0.847793     roc_auc       0.021566    3.445818                0.021566           3.445818            1       True         82
# 86     NeuralNetFastAI_r4_BAG_L1   0.847504     roc_auc       0.097304   10.917397                0.097304          10.917397            1       True         98
# 87     NeuralNetTorch_r30_BAG_L1   0.847446     roc_auc       0.141640   45.437677                0.141640          45.437677            1       True         30
# 88     NeuralNetTorch_r19_BAG_L1   0.847243     roc_auc       0.136286   30.770189                0.136286          30.770189            1       True        105
# 89   NeuralNetFastAI_r191_BAG_L1   0.846925     roc_auc       0.130020   11.703661                0.130020          11.703661            1       True         17
# 90   NeuralNetFastAI_r145_BAG_L1   0.845998     roc_auc       0.116596   10.085957                0.116596          10.085957            1       True         28
# 91    NeuralNetFastAI_r69_BAG_L1   0.845216     roc_auc       0.125814   11.343308                0.125814          11.343308            1       True         84
# 92      NeuralNetTorch_r1_BAG_L1   0.844318     roc_auc       0.147969   21.452756                0.147969          21.452756            1       True        109
# 93   NeuralNetFastAI_r127_BAG_L1   0.842928     roc_auc       0.127997   12.730080                0.127997          12.730080            1       True         93
# 94     NeuralNetTorch_r79_BAG_L1   0.842581     roc_auc       0.141337   30.941964                0.141337          30.941964            1       True         15
# 95    NeuralNetFastAI_r88_BAG_L1   0.842031     roc_auc       0.132317   15.221761                0.132317          15.221761            1       True         68
# 96   NeuralNetFastAI_r103_BAG_L1   0.841538     roc_auc       0.093065   14.612923                0.093065          14.612923            1       True         38
# 97          ExtraTrees_r4_BAG_L1   0.840785     roc_auc       0.141311    0.905305                0.141311           0.905305            1       True         66
# 98   NeuralNetFastAI_r134_BAG_L1   0.840380     roc_auc       0.183105   16.558834                0.183105          16.558834            1       True         59
# 99     NeuralNetTorch_r89_BAG_L1   0.838700     roc_auc       0.166512   37.843611                0.166512          37.843611            1       True        110
# 100  NeuralNetFastAI_r194_BAG_L1   0.838324     roc_auc       0.116085   12.061316                0.116085          12.061316            1       True         95
# 101    NeuralNetTorch_r41_BAG_L1   0.836963     roc_auc       0.141362   18.672664                0.141362          18.672664            1       True         48
# 102   NeuralNetTorch_r185_BAG_L1   0.835891     roc_auc       0.153723   43.330924                0.153723          43.330924            1       True         78
# 103  NeuralNetFastAI_r160_BAG_L1   0.835225     roc_auc       0.113488    9.810658                0.113488           9.810658            1       True         79
# 104       NeuralNetFastAI_BAG_L1   0.834878     roc_auc       0.082977   11.411035                0.082977          11.411035            1       True         10
# 105   NeuralNetFastAI_r95_BAG_L1   0.832648     roc_auc       0.158554   13.667946                0.158554          13.667946            1       True         47
# 106  NeuralNetFastAI_r102_BAG_L1   0.830737     roc_auc       0.152244   12.954036                0.152244          12.954036            1       True         24
# 107   NeuralNetFastAI_r11_BAG_L1   0.820572     roc_auc       0.129228   10.299318                0.129228          10.299318            1       True         34
# 108      RandomForest_r34_BAG_L1   0.815360     roc_auc       0.150403    1.082066                0.150403           1.082066            1       True         60
# 109        KNeighborsDist_BAG_L1   0.795581     roc_auc       0.093415    0.008004                0.093415           0.008004            1       True          2
# 110        KNeighborsUnif_BAG_L1   0.794133     roc_auc       0.422639    0.009001                0.422639           0.009001            1       True          1
# Number of models trained: 111
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# ('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# ('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# Plot summary of models saved to file: AutogluonModels/synthetic/tvaes/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r37_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r160_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetFastAI_r69_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r138_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r172_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r127_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r194_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r4_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r100_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r187_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r19_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r42_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r1_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r89_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7941329781072628,
#   'KNeighborsDist_BAG_L1': 0.7955809104598635,
#   'LightGBMXT_BAG_L1': 0.8636337310320863,
#   'LightGBM_BAG_L1': 0.8719448627360129,
#   'RandomForestGini_BAG_L1': 0.8688897254720259,
#   'RandomForestEntr_BAG_L1': 0.8642853005907564,
#   'CatBoost_BAG_L1': 0.8665585543843392,
#   'ExtraTreesGini_BAG_L1': 0.8592464960037066,
#   'ExtraTreesEntr_BAG_L1': 0.8614907911502374,
#   'NeuralNetFastAI_BAG_L1': 0.8348777945094406,
#   'XGBoost_BAG_L1': 0.8515000579172941,
#   'NeuralNetTorch_BAG_L1': 0.8608247422680411,
#   'LightGBMLarge_BAG_L1': 0.8626491370323179,
#   'CatBoost_r177_BAG_L1': 0.8747248928530058,
#   'NeuralNetTorch_r79_BAG_L1': 0.8425807946252751,
#   'LightGBM_r131_BAG_L1': 0.8701783852658403,
#   'NeuralNetFastAI_r191_BAG_L1': 0.8469245916830765,
#   'CatBoost_r9_BAG_L1': 0.8714815243831808,
#   'LightGBM_r96_BAG_L1': 0.8599849415035331,
#   'NeuralNetTorch_r22_BAG_L1': 0.8708733927950886,
#   'XGBoost_r33_BAG_L1': 0.8571469940924359,
#   'ExtraTrees_r42_BAG_L1': 0.8551343681223214,
#   'CatBoost_r137_BAG_L1': 0.8714815243831809,
#   'NeuralNetFastAI_r102_BAG_L1': 0.8307367079810031,
#   'CatBoost_r13_BAG_L1': 0.8601586933858449,
#   'RandomForest_r195_BAG_L1': 0.8523543380053283,
#   'LightGBM_r188_BAG_L1': 0.8561624000926678,
#   'NeuralNetFastAI_r145_BAG_L1': 0.8459979149774123,
#   'XGBoost_r89_BAG_L1': 0.8619541295030697,
#   'NeuralNetTorch_r30_BAG_L1': 0.8474458473300128,
#   'LightGBM_r130_BAG_L1': 0.8536140391520908,
#   'NeuralNetTorch_r86_BAG_L1': 0.8535271632109348,
#   'CatBoost_r50_BAG_L1': 0.8765782462643346,
#   'NeuralNetFastAI_r11_BAG_L1': 0.8205722228657477,
#   'XGBoost_r194_BAG_L1': 0.8563361519749797,
#   'ExtraTrees_r172_BAG_L1': 0.8619541295030695,
#   'CatBoost_r69_BAG_L1': 0.872379242441793,
#   'NeuralNetFastAI_r103_BAG_L1': 0.8415382833314027,
#   'NeuralNetTorch_r14_BAG_L1': 0.8553515579752113,
#   'LightGBM_r161_BAG_L1': 0.8725819529711571,
#   'NeuralNetFastAI_r143_BAG_L1': 0.8548592609753273,
#   'CatBoost_r70_BAG_L1': 0.8696860882659562,
#   'NeuralNetFastAI_r156_BAG_L1': 0.8580157535039963,
#   'LightGBM_r196_BAG_L1': 0.860361403915209,
#   'RandomForest_r39_BAG_L1': 0.8554094752693154,
#   'CatBoost_r167_BAG_L1': 0.8620410054442258,
#   'NeuralNetFastAI_r95_BAG_L1': 0.8326479786864358,
#   'NeuralNetTorch_r41_BAG_L1': 0.8369628170971851,
#   'XGBoost_r98_BAG_L1': 0.8726688289123132,
#   'LightGBM_r15_BAG_L1': 0.8754778176763581,
#   'NeuralNetTorch_r158_BAG_L1': 0.8614328738561335,
#   'CatBoost_r86_BAG_L1': 0.8618382949148615,
#   'NeuralNetFastAI_r37_BAG_L1': 0.85115255415267,
#   'NeuralNetTorch_r197_BAG_L1': 0.8677458589134716,
#   'CatBoost_r49_BAG_L1': 0.8699467160894243,
#   'ExtraTrees_r49_BAG_L1': 0.8592464960037066,
#   'LightGBM_r143_BAG_L1': 0.8701494266187884,
#   'RandomForest_r127_BAG_L1': 0.8517896443878142,
#   'NeuralNetFastAI_r134_BAG_L1': 0.8403799374493223,
#   'RandomForest_r34_BAG_L1': 0.8153596663963859,
#   'LightGBM_r94_BAG_L1': 0.8642997799142825,
#   'NeuralNetTorch_r143_BAG_L1': 0.8638074829143982,
#   'CatBoost_r128_BAG_L1': 0.8598401482682729,
#   'NeuralNetFastAI_r111_BAG_L1': 0.8488648210355612,
#   'NeuralNetTorch_r31_BAG_L1': 0.8667902235607552,
#   'ExtraTrees_r4_BAG_L1': 0.8407853585080506,
#   'NeuralNetFastAI_r65_BAG_L1': 0.8545696745048071,
#   'NeuralNetFastAI_r88_BAG_L1': 0.8420305803312869,
#   'LightGBM_r30_BAG_L1': 0.8581895053863083,
#   'XGBoost_r49_BAG_L1': 0.8549171782694314,
#   'CatBoost_r5_BAG_L1': 0.8678906521487316,
#   'NeuralNetTorch_r87_BAG_L1': 0.8519923549171783,
#   'NeuralNetTorch_r71_BAG_L1': 0.8535561218579868,
#   'CatBoost_r143_BAG_L1': 0.8745800996177459,
#   'ExtraTrees_r178_BAG_L1': 0.8578709602687363,
#   'RandomForest_r166_BAG_L1': 0.8688897254720259,
#   'XGBoost_r31_BAG_L1': 0.8617803776207575,
#   'NeuralNetTorch_r185_BAG_L1': 0.8358913471562608,
#   'NeuralNetFastAI_r160_BAG_L1': 0.8352252982740647,
#   'CatBoost_r60_BAG_L1': 0.8700046333835283,
#   'RandomForest_r15_BAG_L1': 0.8557859376809915,
#   'LightGBM_r135_BAG_L1': 0.8477933510946367,
#   'XGBoost_r22_BAG_L1': 0.8649368701494267,
#   'NeuralNetFastAI_r69_BAG_L1': 0.845216031507008,
#   'CatBoost_r6_BAG_L1': 0.8741457199119658,
#   'NeuralNetFastAI_r138_BAG_L1': 0.854569674504807,
#   'LightGBM_r121_BAG_L1': 0.8742325958531217,
#   'NeuralNetFastAI_r172_BAG_L1': 0.8481698135063129,
#   'CatBoost_r180_BAG_L1': 0.8712788138538168,
#   'NeuralNetTorch_r76_BAG_L1': 0.8532665353874666,
#   'ExtraTrees_r197_BAG_L1': 0.8602021313564231,
#   'NeuralNetTorch_r121_BAG_L1': 0.8640681107378664,
#   'NeuralNetFastAI_r127_BAG_L1': 0.8429282983898992,
#   'RandomForest_r16_BAG_L1': 0.8514566199467162,
#   'NeuralNetFastAI_r194_BAG_L1': 0.8383238735086297,
#   'CatBoost_r12_BAG_L1': 0.8654581257963629,
#   'NeuralNetTorch_r135_BAG_L1': 0.8526294451523226,
#   'NeuralNetFastAI_r4_BAG_L1': 0.8475037646241168,
#   'ExtraTrees_r126_BAG_L1': 0.8622147573265377,
#   'NeuralNetTorch_r36_BAG_L1': 0.8519923549171782,
#   'NeuralNetFastAI_r100_BAG_L1': 0.860245569327001,
#   'CatBoost_r163_BAG_L1': 0.8675431483841074,
#   'CatBoost_r198_BAG_L1': 0.8680644040310437,
#   'NeuralNetFastAI_r187_BAG_L1': 0.8561044827985637,
#   'NeuralNetTorch_r19_BAG_L1': 0.8472431368006488,
#   'XGBoost_r95_BAG_L1': 0.8591161820919727,
#   'XGBoost_r34_BAG_L1': 0.8656897949727789,
#   'LightGBM_r42_BAG_L1': 0.8650816633846866,
#   'NeuralNetTorch_r1_BAG_L1': 0.8443183134483956,
#   'NeuralNetTorch_r89_BAG_L1': 0.8387003359203058,
#   'WeightedEnsemble_L2': 0.8934900961427082},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetFastAI_r95_BAG_L1': ['NeuralNetFastAI_r95_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetFastAI_r37_BAG_L1': ['NeuralNetFastAI_r37_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'NeuralNetFastAI_r134_BAG_L1': ['NeuralNetFastAI_r134_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetFastAI_r111_BAG_L1': ['NeuralNetFastAI_r111_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'NeuralNetFastAI_r65_BAG_L1': ['NeuralNetFastAI_r65_BAG_L1'],
#   'NeuralNetFastAI_r88_BAG_L1': ['NeuralNetFastAI_r88_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'NeuralNetFastAI_r160_BAG_L1': ['NeuralNetFastAI_r160_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'NeuralNetFastAI_r69_BAG_L1': ['NeuralNetFastAI_r69_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'NeuralNetFastAI_r138_BAG_L1': ['NeuralNetFastAI_r138_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'NeuralNetFastAI_r172_BAG_L1': ['NeuralNetFastAI_r172_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'NeuralNetFastAI_r127_BAG_L1': ['NeuralNetFastAI_r127_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'NeuralNetFastAI_r194_BAG_L1': ['NeuralNetFastAI_r194_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'NeuralNetFastAI_r4_BAG_L1': ['NeuralNetFastAI_r4_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'NeuralNetTorch_r36_BAG_L1': ['NeuralNetTorch_r36_BAG_L1'],
#   'NeuralNetFastAI_r100_BAG_L1': ['NeuralNetFastAI_r100_BAG_L1'],
#   'CatBoost_r163_BAG_L1': ['CatBoost_r163_BAG_L1'],
#   'CatBoost_r198_BAG_L1': ['CatBoost_r198_BAG_L1'],
#   'NeuralNetFastAI_r187_BAG_L1': ['NeuralNetFastAI_r187_BAG_L1'],
#   'NeuralNetTorch_r19_BAG_L1': ['NeuralNetTorch_r19_BAG_L1'],
#   'XGBoost_r95_BAG_L1': ['XGBoost_r95_BAG_L1'],
#   'XGBoost_r34_BAG_L1': ['XGBoost_r34_BAG_L1'],
#   'LightGBM_r42_BAG_L1': ['LightGBM_r42_BAG_L1'],
#   'NeuralNetTorch_r1_BAG_L1': ['NeuralNetTorch_r1_BAG_L1'],
#   'NeuralNetTorch_r89_BAG_L1': ['NeuralNetTorch_r89_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.009001016616821289,
#   'KNeighborsDist_BAG_L1': 0.008003711700439453,
#   'LightGBMXT_BAG_L1': 3.170992136001587,
#   'LightGBM_BAG_L1': 2.0536773204803467,
#   'RandomForestGini_BAG_L1': 1.0088214874267578,
#   'RandomForestEntr_BAG_L1': 0.8456575870513916,
#   'CatBoost_BAG_L1': 10.408109188079834,
#   'ExtraTreesGini_BAG_L1': 1.0369806289672852,
#   'ExtraTreesEntr_BAG_L1': 0.8549559116363525,
#   'NeuralNetFastAI_BAG_L1': 11.411035299301147,
#   'XGBoost_BAG_L1': 4.51083779335022,
#   'NeuralNetTorch_BAG_L1': 28.703299045562744,
#   'LightGBMLarge_BAG_L1': 5.19258713722229,
#   'CatBoost_r177_BAG_L1': 6.010501146316528,
#   'NeuralNetTorch_r79_BAG_L1': 30.94196367263794,
#   'LightGBM_r131_BAG_L1': 4.592811584472656,
#   'NeuralNetFastAI_r191_BAG_L1': 11.70366096496582,
#   'CatBoost_r9_BAG_L1': 20.693989992141724,
#   'LightGBM_r96_BAG_L1': 9.18224024772644,
#   'NeuralNetTorch_r22_BAG_L1': 43.51741003990173,
#   'XGBoost_r33_BAG_L1': 5.321565389633179,
#   'ExtraTrees_r42_BAG_L1': 1.0810725688934326,
#   'CatBoost_r137_BAG_L1': 5.70397424697876,
#   'NeuralNetFastAI_r102_BAG_L1': 12.954035997390747,
#   'CatBoost_r13_BAG_L1': 11.704280138015747,
#   'RandomForest_r195_BAG_L1': 1.245534896850586,
#   'LightGBM_r188_BAG_L1': 2.4885919094085693,
#   'NeuralNetFastAI_r145_BAG_L1': 10.085956573486328,
#   'XGBoost_r89_BAG_L1': 4.429725646972656,
#   'NeuralNetTorch_r30_BAG_L1': 45.43767690658569,
#   'LightGBM_r130_BAG_L1': 3.293793201446533,
#   'NeuralNetTorch_r86_BAG_L1': 42.48999071121216,
#   'CatBoost_r50_BAG_L1': 5.04033088684082,
#   'NeuralNetFastAI_r11_BAG_L1': 10.299317598342896,
#   'XGBoost_r194_BAG_L1': 3.281038999557495,
#   'ExtraTrees_r172_BAG_L1': 0.9246706962585449,
#   'CatBoost_r69_BAG_L1': 7.258073329925537,
#   'NeuralNetFastAI_r103_BAG_L1': 14.612922668457031,
#   'NeuralNetTorch_r14_BAG_L1': 42.06952118873596,
#   'LightGBM_r161_BAG_L1': 5.120521545410156,
#   'NeuralNetFastAI_r143_BAG_L1': 16.004000425338745,
#   'CatBoost_r70_BAG_L1': 8.710349559783936,
#   'NeuralNetFastAI_r156_BAG_L1': 13.434972047805786,
#   'LightGBM_r196_BAG_L1': 7.0481274127960205,
#   'RandomForest_r39_BAG_L1': 1.085383653640747,
#   'CatBoost_r167_BAG_L1': 7.009516000747681,
#   'NeuralNetFastAI_r95_BAG_L1': 13.667945861816406,
#   'NeuralNetTorch_r41_BAG_L1': 18.672663688659668,
#   'XGBoost_r98_BAG_L1': 12.482336521148682,
#   'LightGBM_r15_BAG_L1': 3.2203502655029297,
#   'NeuralNetTorch_r158_BAG_L1': 35.91465735435486,
#   'CatBoost_r86_BAG_L1': 14.4826979637146,
#   'NeuralNetFastAI_r37_BAG_L1': 16.069109439849854,
#   'NeuralNetTorch_r197_BAG_L1': 44.22328209877014,
#   'CatBoost_r49_BAG_L1': 5.310378789901733,
#   'ExtraTrees_r49_BAG_L1': 1.520751953125,
#   'LightGBM_r143_BAG_L1': 3.3829286098480225,
#   'RandomForest_r127_BAG_L1': 1.3689007759094238,
#   'NeuralNetFastAI_r134_BAG_L1': 16.558833837509155,
#   'RandomForest_r34_BAG_L1': 1.0820655822753906,
#   'LightGBM_r94_BAG_L1': 2.3953239917755127,
#   'NeuralNetTorch_r143_BAG_L1': 37.40758204460144,
#   'CatBoost_r128_BAG_L1': 13.342751026153564,
#   'NeuralNetFastAI_r111_BAG_L1': 16.814192295074463,
#   'NeuralNetTorch_r31_BAG_L1': 32.315205097198486,
#   'ExtraTrees_r4_BAG_L1': 0.9053049087524414,
#   'NeuralNetFastAI_r65_BAG_L1': 13.16353702545166,
#   'NeuralNetFastAI_r88_BAG_L1': 15.221760988235474,
#   'LightGBM_r30_BAG_L1': 5.992818832397461,
#   'XGBoost_r49_BAG_L1': 2.067469596862793,
#   'CatBoost_r5_BAG_L1': 6.647022485733032,
#   'NeuralNetTorch_r87_BAG_L1': 34.737717151641846,
#   'NeuralNetTorch_r71_BAG_L1': 43.60972619056702,
#   'CatBoost_r143_BAG_L1': 7.790886878967285,
#   'ExtraTrees_r178_BAG_L1': 0.9803690910339355,
#   'RandomForest_r166_BAG_L1': 1.172318935394287,
#   'XGBoost_r31_BAG_L1': 11.710758924484253,
#   'NeuralNetTorch_r185_BAG_L1': 43.330923557281494,
#   'NeuralNetFastAI_r160_BAG_L1': 9.810657739639282,
#   'CatBoost_r60_BAG_L1': 6.604635715484619,
#   'RandomForest_r15_BAG_L1': 1.224134922027588,
#   'LightGBM_r135_BAG_L1': 3.4458181858062744,
#   'XGBoost_r22_BAG_L1': 2.154949188232422,
#   'NeuralNetFastAI_r69_BAG_L1': 11.343308210372925,
#   'CatBoost_r6_BAG_L1': 5.3624114990234375,
#   'NeuralNetFastAI_r138_BAG_L1': 18.012251138687134,
#   'LightGBM_r121_BAG_L1': 2.819819211959839,
#   'NeuralNetFastAI_r172_BAG_L1': 16.68999457359314,
#   'CatBoost_r180_BAG_L1': 8.294628381729126,
#   'NeuralNetTorch_r76_BAG_L1': 16.318681955337524,
#   'ExtraTrees_r197_BAG_L1': 1.0557284355163574,
#   'NeuralNetTorch_r121_BAG_L1': 42.70775604248047,
#   'NeuralNetFastAI_r127_BAG_L1': 12.730080366134644,
#   'RandomForest_r16_BAG_L1': 1.7466166019439697,
#   'NeuralNetFastAI_r194_BAG_L1': 12.06131625175476,
#   'CatBoost_r12_BAG_L1': 5.356590986251831,
#   'NeuralNetTorch_r135_BAG_L1': 49.84649991989136,
#   'NeuralNetFastAI_r4_BAG_L1': 10.917396545410156,
#   'ExtraTrees_r126_BAG_L1': 1.3110735416412354,
#   'NeuralNetTorch_r36_BAG_L1': 28.799327850341797,
#   'NeuralNetFastAI_r100_BAG_L1': 17.547008275985718,
#   'CatBoost_r163_BAG_L1': 8.31612229347229,
#   'CatBoost_r198_BAG_L1': 7.003796577453613,
#   'NeuralNetFastAI_r187_BAG_L1': 30.952293395996094,
#   'NeuralNetTorch_r19_BAG_L1': 30.770188570022583,
#   'XGBoost_r95_BAG_L1': 4.7812864780426025,
#   'XGBoost_r34_BAG_L1': 2.7779946327209473,
#   'LightGBM_r42_BAG_L1': 4.983204364776611,
#   'NeuralNetTorch_r1_BAG_L1': 21.45275640487671,
#   'NeuralNetTorch_r89_BAG_L1': 37.84361124038696,
#   'WeightedEnsemble_L2': 0.2320554256439209},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.4226391315460205,
#   'KNeighborsDist_BAG_L1': 0.0934150218963623,
#   'LightGBMXT_BAG_L1': 0.029378414154052734,
#   'LightGBM_BAG_L1': 0.016704559326171875,
#   'RandomForestGini_BAG_L1': 0.13555002212524414,
#   'RandomForestEntr_BAG_L1': 0.13741040229797363,
#   'CatBoost_BAG_L1': 0.0351099967956543,
#   'ExtraTreesGini_BAG_L1': 0.14653921127319336,
#   'ExtraTreesEntr_BAG_L1': 0.16202783584594727,
#   'NeuralNetFastAI_BAG_L1': 0.082977294921875,
#   'XGBoost_BAG_L1': 0.034705162048339844,
#   'NeuralNetTorch_BAG_L1': 0.14116477966308594,
#   'LightGBMLarge_BAG_L1': 0.021370649337768555,
#   'CatBoost_r177_BAG_L1': 0.08711075782775879,
#   'NeuralNetTorch_r79_BAG_L1': 0.14133667945861816,
#   'LightGBM_r131_BAG_L1': 0.03324079513549805,
#   'NeuralNetFastAI_r191_BAG_L1': 0.1300201416015625,
#   'CatBoost_r9_BAG_L1': 0.030439376831054688,
#   'LightGBM_r96_BAG_L1': 0.0366969108581543,
#   'NeuralNetTorch_r22_BAG_L1': 0.14142823219299316,
#   'XGBoost_r33_BAG_L1': 0.048061370849609375,
#   'ExtraTrees_r42_BAG_L1': 0.16576600074768066,
#   'CatBoost_r137_BAG_L1': 0.03189396858215332,
#   'NeuralNetFastAI_r102_BAG_L1': 0.15224361419677734,
#   'CatBoost_r13_BAG_L1': 0.03528118133544922,
#   'RandomForest_r195_BAG_L1': 0.1343381404876709,
#   'LightGBM_r188_BAG_L1': 0.025259017944335938,
#   'NeuralNetFastAI_r145_BAG_L1': 0.11659646034240723,
#   'XGBoost_r89_BAG_L1': 0.0338292121887207,
#   'NeuralNetTorch_r30_BAG_L1': 0.14164042472839355,
#   'LightGBM_r130_BAG_L1': 0.016216278076171875,
#   'NeuralNetTorch_r86_BAG_L1': 0.13899946212768555,
#   'CatBoost_r50_BAG_L1': 0.03046274185180664,
#   'NeuralNetFastAI_r11_BAG_L1': 0.1292283535003662,
#   'XGBoost_r194_BAG_L1': 0.05469489097595215,
#   'ExtraTrees_r172_BAG_L1': 0.1595618724822998,
#   'CatBoost_r69_BAG_L1': 0.030081748962402344,
#   'NeuralNetFastAI_r103_BAG_L1': 0.09306478500366211,
#   'NeuralNetTorch_r14_BAG_L1': 0.12300968170166016,
#   'LightGBM_r161_BAG_L1': 0.032619476318359375,
#   'NeuralNetFastAI_r143_BAG_L1': 0.139634370803833,
#   'CatBoost_r70_BAG_L1': 0.03221750259399414,
#   'NeuralNetFastAI_r156_BAG_L1': 0.12457156181335449,
#   'LightGBM_r196_BAG_L1': 0.13226771354675293,
#   'RandomForest_r39_BAG_L1': 0.15140175819396973,
#   'CatBoost_r167_BAG_L1': 0.03412628173828125,
#   'NeuralNetFastAI_r95_BAG_L1': 0.1585540771484375,
#   'NeuralNetTorch_r41_BAG_L1': 0.14136195182800293,
#   'XGBoost_r98_BAG_L1': 0.06444001197814941,
#   'LightGBM_r15_BAG_L1': 0.021159648895263672,
#   'NeuralNetTorch_r158_BAG_L1': 0.18354201316833496,
#   'CatBoost_r86_BAG_L1': 0.02945733070373535,
#   'NeuralNetFastAI_r37_BAG_L1': 0.1848609447479248,
#   'NeuralNetTorch_r197_BAG_L1': 0.1512317657470703,
#   'CatBoost_r49_BAG_L1': 0.0267026424407959,
#   'ExtraTrees_r49_BAG_L1': 0.1785426139831543,
#   'LightGBM_r143_BAG_L1': 0.02975296974182129,
#   'RandomForest_r127_BAG_L1': 0.13872432708740234,
#   'NeuralNetFastAI_r134_BAG_L1': 0.1831049919128418,
#   'RandomForest_r34_BAG_L1': 0.15040326118469238,
#   'LightGBM_r94_BAG_L1': 0.018307209014892578,
#   'NeuralNetTorch_r143_BAG_L1': 0.15737700462341309,
#   'CatBoost_r128_BAG_L1': 0.04102516174316406,
#   'NeuralNetFastAI_r111_BAG_L1': 0.13345646858215332,
#   'NeuralNetTorch_r31_BAG_L1': 0.1742994785308838,
#   'ExtraTrees_r4_BAG_L1': 0.1413114070892334,
#   'NeuralNetFastAI_r65_BAG_L1': 0.13660097122192383,
#   'NeuralNetFastAI_r88_BAG_L1': 0.13231682777404785,
#   'LightGBM_r30_BAG_L1': 0.04795694351196289,
#   'XGBoost_r49_BAG_L1': 0.03010869026184082,
#   'CatBoost_r5_BAG_L1': 0.01941704750061035,
#   'NeuralNetTorch_r87_BAG_L1': 0.16412901878356934,
#   'NeuralNetTorch_r71_BAG_L1': 0.13978338241577148,
#   'CatBoost_r143_BAG_L1': 0.04902505874633789,
#   'ExtraTrees_r178_BAG_L1': 0.08878707885742188,
#   'RandomForest_r166_BAG_L1': 0.0972452163696289,
#   'XGBoost_r31_BAG_L1': 0.04254317283630371,
#   'NeuralNetTorch_r185_BAG_L1': 0.15372347831726074,
#   'NeuralNetFastAI_r160_BAG_L1': 0.11348819732666016,
#   'CatBoost_r60_BAG_L1': 0.03167104721069336,
#   'RandomForest_r15_BAG_L1': 0.160888671875,
#   'LightGBM_r135_BAG_L1': 0.021565675735473633,
#   'XGBoost_r22_BAG_L1': 0.037479400634765625,
#   'NeuralNetFastAI_r69_BAG_L1': 0.12581419944763184,
#   'CatBoost_r6_BAG_L1': 0.0330350399017334,
#   'NeuralNetFastAI_r138_BAG_L1': 0.13607358932495117,
#   'LightGBM_r121_BAG_L1': 0.030977487564086914,
#   'NeuralNetFastAI_r172_BAG_L1': 0.11501932144165039,
#   'CatBoost_r180_BAG_L1': 0.032492876052856445,
#   'NeuralNetTorch_r76_BAG_L1': 0.12302136421203613,
#   'ExtraTrees_r197_BAG_L1': 0.08552837371826172,
#   'NeuralNetTorch_r121_BAG_L1': 0.1491560935974121,
#   'NeuralNetFastAI_r127_BAG_L1': 0.12799668312072754,
#   'RandomForest_r16_BAG_L1': 0.14840292930603027,
#   'NeuralNetFastAI_r194_BAG_L1': 0.11608505249023438,
#   'CatBoost_r12_BAG_L1': 0.02301025390625,
#   'NeuralNetTorch_r135_BAG_L1': 0.1258697509765625,
#   'NeuralNetFastAI_r4_BAG_L1': 0.09730362892150879,
# ...
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                            model  score_val eval_metric  pred_time_val  \
#  0            WeightedEnsemble_L2   0.893490     roc_auc       0.853921
#  1            CatBoost_r50_BAG_L1   0.876578     roc_auc       0.030463
#  2            LightGBM_r15_BAG_L1   0.875478     roc_auc       0.021160
#  3           CatBoost_r177_BAG_L1   0.874725     roc_auc       0.087111
#  4           CatBoost_r143_BAG_L1   0.874580     roc_auc       0.049025
#  ..                           ...        ...         ...            ...
#  106  NeuralNetFastAI_r102_BAG_L1   0.830737     roc_auc       0.152244
#  107   NeuralNetFastAI_r11_BAG_L1   0.820572     roc_auc       0.129228
#  108      RandomForest_r34_BAG_L1   0.815360     roc_auc       0.150403
#  109        KNeighborsDist_BAG_L1   0.795581     roc_auc       0.093415
#  110        KNeighborsUnif_BAG_L1   0.794133     roc_auc       0.422639
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    177.364443                0.000000           0.232055            2
#  1      5.040331                0.030463           5.040331            1
#  2      3.220350                0.021160           3.220350            1
#  3      6.010501                0.087111           6.010501            1
#  4      7.790887                0.049025           7.790887            1
#  ..          ...                     ...                ...          ...
#  106   12.954036                0.152244          12.954036            1
#  107   10.299318                0.129228          10.299318            1
#  108    1.082066                0.150403           1.082066            1
#  109    0.008004                0.093415           0.008004            1
#  110    0.009001                0.422639           0.009001            1
#
#       can_infer  fit_order
#  0         True        111
#  1         True         33
#  2         True         50
#  3         True         14
#  4         True         74
#  ..         ...        ...
#  106       True         24
#  107       True         34
#  108       True         60
#  109       True          2
#  110       True          1
#
#  [111 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.8517482517482516
# Evaluations on test data:
# {
#     "roc_auc": 0.8517482517482516,
#     "accuracy": 0.776595744680851,
#     "balanced_accuracy": 0.7680652680652681,
#     "mcc": 0.5382677750218143,
#     "f1": 0.8108108108108109,
#     "precision": 0.8035714285714286,
#     "recall": 0.8181818181818182
# }
# {'roc_auc': 0.8517482517482516,
#  'accuracy': 0.776595744680851,
#  'balanced_accuracy': 0.7680652680652681,
#  'mcc': 0.5382677750218143,
#  'f1': 0.8108108108108109,
#  'precision': 0.8035714285714286,
#  'recall': 0.8181818181818182}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                            model  score_test  balanced_accuracy        f1  \
# 0          KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 1       RandomForest_r166_BAG_L1    1.000000           1.000000  1.000000
# 2          ExtraTrees_r42_BAG_L1    1.000000           1.000000  1.000000
# 3        RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 4        RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# ..                           ...         ...                ...       ...
# 106  NeuralNetFastAI_r160_BAG_L1    0.888364           0.834414  0.831522
# 107         ExtraTrees_r4_BAG_L1    0.886974           0.806527  0.809399
# 108  NeuralNetFastAI_r103_BAG_L1    0.871192           0.811248  0.802260
# 109      RandomForest_r34_BAG_L1    0.867340           0.788515  0.784741
# 110   NeuralNetFastAI_r11_BAG_L1    0.866327           0.792019  0.791444
#
#      f1_macro  f1_micro   roc_auc  average_precision  precision    recall  \
# 0    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 1    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 2    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 3    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 4    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# ..        ...       ...       ...                ...        ...       ...
# 106  0.833314  0.833333  0.888364           0.869332   0.805263  0.859551
# 107  0.803592  0.803763  0.886974           0.875094   0.756098  0.870787
# 108  0.811386  0.811828  0.871192           0.844512   0.806818  0.797753
# 109  0.787596  0.787634  0.867340           0.861670   0.761905  0.808989
# 110  0.790317  0.790323  0.866327           0.835040   0.755102  0.831461
#
#      ...  eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0    ...      roc_auc        0.046517       0.093415   0.008004
# 1    ...      roc_auc        0.107392       0.097245   1.172319
# 2    ...      roc_auc        0.136714       0.165766   1.081073
# 3    ...      roc_auc        0.136896       0.137410   0.845658
# 4    ...      roc_auc        0.142402       0.135550   1.008821
# ..   ...          ...             ...            ...        ...
# 106  ...      roc_auc        1.421846       0.113488   9.810658
# 107  ...      roc_auc        0.112505       0.141311   0.905305
# 108  ...      roc_auc        1.367365       0.093065  14.612923
# 109  ...      roc_auc        0.293370       0.150403   1.082066
# 110  ...      roc_auc        2.136502       0.129228  10.299318
#
#      pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                   0.046517                0.093415           0.008004
# 1                   0.107392                0.097245           1.172319
# 2                   0.136714                0.165766           1.081073
# 3                   0.136896                0.137410           0.845658
# 4                   0.142402                0.135550           1.008821
# ..                       ...                     ...                ...
# 106                 1.421846                0.113488           9.810658
# 107                 0.112505                0.141311           0.905305
# 108                 1.367365                0.093065          14.612923
# 109                 0.293370                0.150403           1.082066
# 110                 2.136502                0.129228          10.299318
#
#      stack_level  can_infer  fit_order
# 0              1       True          2
# 1              1       True         76
# 2              1       True         22
# 3              1       True          6
# 4              1       True          5
# ..           ...        ...        ...
# 106            1       True         79
# 107            1       True         66
# 108            1       True         38
# 109            1       True         60
# 110            1       True         34
#
# [111 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 372 rows with 5 shuffle sets...
# 	173.28s	= Expected runtime (34.66s per shuffle set)
# 	76.19s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                 importance    stddev  \
# TRV.Stroop.palabras.PD                            0.021748  0.004566
# ISC.resultadosReservaCognitiva.escolaridad        0.019142  0.003858
# TRV.Tavec.05_Rg-Md.PD                             0.018835  0.003023
# TRV.Tavec.24_Discriminabilidad.PD                 0.016454  0.003005
# TRV.Tavec.20_I-RL.PD                              0.015615  0.001861
# ISC.resultadosReservaCognitiva.Total.PD           0.015603  0.003019
# TRV.Tavec.10_RCl-LP.PD                            0.012556  0.002403
# TRV.LeidenNT.PuntoReferencia_total.PD             0.011497  0.002650
# TRV.LeidenNT.UbicacionAlocentrica_total.PD        0.010859  0.001956
# TRV.Stroop.color.PD                               0.007720  0.000922
# TRV.Tavec.12_ESem-RI-B.PD                         0.005409  0.001026
# TRV.Tavec.17_ESer-RL-CP.PD                        0.004436  0.000824
# ISC.resultadosObservacion.alcohol                 0.003927  0.001679
# TRV.Tavec.14_ESem-RL-LP.PD                        0.003099  0.001153
# TRV.LeidenNT.CaminosTopgrafico_total.PD           0.002682  0.000904
# ISC.FPacientes.genero                             0.002392  0.000623
# ISC.resultadosObservacion.enfermedadesDiabetes    0.000678  0.000129
#
#                                                  p_value  n  p99_high  \
# TRV.Stroop.palabras.PD                          0.000220  5  0.031150
# ISC.resultadosReservaCognitiva.escolaridad      0.000188  5  0.027085
# TRV.Tavec.05_Rg-Md.PD                           0.000077  5  0.025059
# TRV.Tavec.24_Discriminabilidad.PD               0.000128  5  0.022643
# TRV.Tavec.20_I-RL.PD                            0.000024  5  0.019446
# ISC.resultadosReservaCognitiva.Total.PD         0.000160  5  0.021819
# TRV.Tavec.10_RCl-LP.PD                          0.000153  5  0.017504
# TRV.LeidenNT.PuntoReferencia_total.PD           0.000316  5  0.016952
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.000121  5  0.014887
# TRV.Stroop.color.PD                             0.000024  5  0.009618
# TRV.Tavec.12_ESem-RI-B.PD                       0.000148  5  0.007522
# TRV.Tavec.17_ESer-RL-CP.PD                      0.000136  5  0.006133
# ISC.resultadosObservacion.alcohol               0.003191  5  0.007383
# TRV.Tavec.14_ESem-RL-LP.PD                      0.001932  5  0.005473
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.001342  5  0.004544
# ISC.FPacientes.genero                           0.000506  5  0.003675
# ISC.resultadosObservacion.enfermedadesDiabetes  0.000150  5  0.000943
#
#                                                  p99_low
# TRV.Stroop.palabras.PD                          0.012346
# ISC.resultadosReservaCognitiva.escolaridad      0.011199
# TRV.Tavec.05_Rg-Md.PD                           0.012611
# TRV.Tavec.24_Discriminabilidad.PD               0.010266
# TRV.Tavec.20_I-RL.PD                            0.011783
# ISC.resultadosReservaCognitiva.Total.PD         0.009387
# TRV.Tavec.10_RCl-LP.PD                          0.007609
# TRV.LeidenNT.PuntoReferencia_total.PD           0.006041
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.006832
# TRV.Stroop.color.PD                             0.005823
# TRV.Tavec.12_ESem-RI-B.PD                       0.003297
# TRV.Tavec.17_ESer-RL-CP.PD                      0.002740
# ISC.resultadosObservacion.alcohol               0.000470
# TRV.Tavec.14_ESem-RL-LP.PD                      0.000724
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.000819
# ISC.FPacientes.genero                           0.001109
# ISC.resultadosObservacion.enfermedadesDiabetes  0.000412
