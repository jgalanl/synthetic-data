# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/trv/synthetic-ctgan.csv')

# %%
VARS = ["ISC.FPacientes.IDUsuario",
"ISC.FPacientes.etiquetaDiagnosticaExpTLP",
"ED_2Clases",
"ISC.FPacientes.etiquetaDiagnostica",
"ED_MMSE_2Clases",
"ISC.FPacientes.genero",
"ISC.FPacientes.Edad",
"ISC.resultadosCovid.numDosis",
"ISC.resultadosCovid.numVecesCovid",
"ISC.resultadosCovid.numVecesCovid_mode",
"ISC.resultadosCovid.pasadoCovid",
"ISC.resultadosCovid.sentimientoAislado",
"ISC.resultadosCovid.sentimientoAislado_mediaFiltro",
"ISC.resultadosCovid.sentimientoAislado_mode",
"ISC.resultadosCovid.sintomaCansancio",
"ISC.resultadosCovid.sintomaDiarrea",
"ISC.resultadosCovid.sintomaDifRespirar",
"ISC.resultadosCovid.sintomaDolCabeza",
"ISC.resultadosCovid.sintomaDolGarganta",
"ISC.resultadosCovid.sintomaDolMuscular",
"ISC.resultadosCovid.sintomaEscalofrios",
"ISC.resultadosCovid.sintomaFiebre",
"ISC.resultadosCovid.sintomaOtro",
"ISC.resultadosCovid.sintomaOtroString",
"ISC.resultadosCovid.sintomaPerGusto",
"ISC.resultadosCovid.sintomaPerOlfato",
"ISC.resultadosCovid.vacunado",
"ISC.resultadosCribaje.Total.PD",
"ISC.resultadosObservacion.alcohol",
"ISC.resultadosObservacion.ansiedad",
"ISC.resultadosObservacion.añosSinFumar",
"ISC.resultadosObservacion.añosSinFumar_Rangos",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal",
"ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn",
"ISC.resultadosObservacion.depresion",
"ISC.resultadosObservacion.enfermedadesAltTiroides",
"ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos",
"ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica",
"ISC.resultadosObservacion.enfermedadesDiabetes",
"ISC.resultadosObservacion.enfermedadesHepatica",
"ISC.resultadosObservacion.enfermedadesHipercolesterolemia",
"ISC.resultadosObservacion.enfermedadesHipertension",
"ISC.resultadosObservacion.enfermedadesNinguna",
"ISC.resultadosObservacion.enfermedadesOtros",
"ISC.resultadosObservacion.enfermedadesOtrosString",
"ISC.resultadosObservacion.enfermedadesRenal",
"ISC.resultadosObservacion.entorno",
"ISC.resultadosObservacion.familiaresAlzheimer",
"ISC.resultadosObservacion.familiaresOtraDemencia",
"ISC.resultadosObservacion.fumador",
"ISC.resultadosObservacion.numCigarros",
"ISC.resultadosObservacion.numCigarrosDia_knn",
"ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad",
"ISC.resultadosObservacion.tratCronico",
"ISC.resultadosObservacion.tratPsicologic",
"ISC.resultadosObservacion.tratPsiquiatrico",
"ISC.resultadosOtros.frecOlvidos",
"ISC.resultadosOtros.frecUsoEmail",
"ISC.resultadosOtros.frecUsoMovil",
"ISC.resultadosOtros.frecUsoOrdenador",
"ISC.resultadosOtros.frecUsoRSociales",
"ISC.resultadosOtros.frecUsoTele",
"ISC.resultadosOtros.nivelActFisica",
"ISC.resultadosOtros.nivelSociabilidad",
"ISC.resultadosReservaCognitiva.Total.PD",
"ISC.resultadosReservaCognitiva.actividadLectora",
"ISC.resultadosReservaCognitiva.cursos",
"ISC.resultadosReservaCognitiva.escolaridad",
"ISC.resultadosReservaCognitiva.escolaridadPadres",
"ISC.resultadosReservaCognitiva.formacionMusical",
"ISC.resultadosReservaCognitiva.idiomas",
"ISC.resultadosReservaCognitiva.juegos",
"ISC.resultadosReservaCognitiva.ocupacion",
"ISC.resultadosWFQ.DE_array",
"ISC.resultadosWFQ.DE_total.PD",
"ISC.resultadosWFQ.NO_array",
"ISC.resultadosWFQ.NO_total.PD",
"ISC.resultadosWFQ.SA_array",
"ISC.resultadosWFQ.SA_total.PD",
"TRV.LeidenNT.CaminosRuta_total.PD",
"TRV.LeidenNT.CaminosTopgrafico_total.PD",
"TRV.LeidenNT.Orden_total.PD",
"TRV.LeidenNT.PuntoReferencia_total.PD",
"TRV.LeidenNT.UbicacionAlocentrica_total.PD",
"TRV.LeidenNT.UbicacionEgocentrico_total.PD",
"TRV.Stroop.color.PD",
"TRV.Stroop.color.PDC",
"TRV.Stroop.interferencia.PD",
"TRV.Stroop.palabras.PD",
"TRV.Stroop.palabras.PDC",
"TRV.Stroop.palabrasColor.PD",
"TRV.Stroop.palabrasColor.PDC",
"TRV.Tavec.00_RI-A1.PD",
"TRV.Tavec.01_RI-A5.PD",
"TRV.Tavec.02_RI-AT.PD",
"TRV.Tavec.03_RI-B.PD",
"TRV.Tavec.04_Rg-Pr.PD",
"TRV.Tavec.05_Rg-Md.PD",
"TRV.Tavec.06_Rg-Rc.PD",
"TRV.Tavec.07_RL-CP.PD",
"TRV.Tavec.08_RCl-CP.PD",
"TRV.Tavec.09_RL-LP.PD",
"TRV.Tavec.10_RCl-LP.PD",
"TRV.Tavec.11_ESem-RI-A.PD",
"TRV.Tavec.12_ESem-RI-B.PD",
"TRV.Tavec.13_ESem-RL-CP.PD",
"TRV.Tavec.14_ESem-RL-LP.PD",
"TRV.Tavec.15_ESer-RI-A.PD",
"TRV.Tavec.16_ESer-RI-B.PD",
"TRV.Tavec.17_ESer-RL-CP.PD",
"TRV.Tavec.18_ESer-RL-LP.PD",
"TRV.Tavec.19_P.PD",
"TRV.Tavec.20_I-RL.PD",
"TRV.Tavec.21_I-RCL.PD",
"TRV.Tavec.22_Recon-Ac.PD",
"TRV.Tavec.23_FP.PD",
"TRV.Tavec.24_Discriminabilidad.PD",
"TRV.Tavec.25_Sesgo.PD",
"TRV.Tavec.26_RI-B_frente_RI-A1.PD",
"TRV.Tavec.27_RL-CP_frente_RI-A5.PD",
"TRV.Tavec.28_RCl-Cp_frente_RCl-LP.PD",
"TRV.Tavec.29_RL-LP_frente_RL-CP.PD",
"TRV.Tavec.30_RCl-LP_frente_RL-LP.PD",
"TRV.Tavec.31_Recon-Ac_frente_RL-LP.PD",
"TRV.Tavec.32_Recon-Ac_frente_RCl-LP.PD"
]

VARS = [
'ISC.resultadosReservaCognitiva.Total.PD',
'ISC.resultadosReservaCognitiva.escolaridad',
'ISC.resultadosObservacion.enfermedadesDiabetes',
'ISC.resultadosObservacion.alcohol',
'TRV.LeidenNT.UbicacionAlocentrica_total.PD',
'TRV.LeidenNT.PuntoReferencia_total.PD',
'TRV.LeidenNT.CaminosTopgrafico_total.PD',
'TRV.Stroop.palabras.PD',
'TRV.Stroop.color.PD',
#'TRV.Stroop.palabras.PDC',
'TRV.Tavec.12_ESem-RI-B.PD',
'TRV.Tavec.10_RCl-LP.PD',
'TRV.Tavec.05_Rg-Md.PD',
'ISC.FPacientes.genero',
'TRV.Tavec.20_I-RL.PD',
'TRV.Tavec.17_ESer-RL-CP.PD',
'TRV.Tavec.14_ESem-RL-LP.PD',
'TRV.Tavec.24_Discriminabilidad.PD']

CLASS = 'ED_2Clases'

drop_columns = []
for v in df.columns:
    if not v in VARS+[CLASS]:
        drop_columns.append(v)

# %%
drop_columns
# Out:
# []

# %%
df.drop(columns=drop_columns, inplace=True)

# %%
categorical_columns = [
    'ED_2Clases'
]

# %%
df[categorical_columns] = df[categorical_columns].astype('object')

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.resultadosObservacion.alcohol  \
# 0          D                      2                              False
# 1          D                      2                              False
# 2          H                      2                              False
# 3          D                      2                              False
# 4          D                      2                              False
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ISC.resultadosReservaCognitiva.Total.PD  \
# 0                                       12
# 1                                        8
# 2                                       11
# 3                                       18
# 4                                       13
#
#    ISC.resultadosReservaCognitiva.escolaridad  \
# 0                                           3
# 1                                           3
# 2                                           4
# 3                                           4
# 4                                           4
#
#    TRV.LeidenNT.CaminosTopgrafico_total.PD  \
# 0                                        2
# 1                                        1
# 2                                        3
# 3                                        4
# 4                                        2
#
#    TRV.LeidenNT.PuntoReferencia_total.PD  \
# 0                                      8
# 1                                      7
# 2                                      8
# 3                                      8
# 4                                      6
#
#    TRV.LeidenNT.UbicacionAlocentrica_total.PD  TRV.Stroop.color.PD  \
# 0                                           1                   27
# 1                                           1                   17
# 2                                           1                   40
# 3                                           3                   46
# 4                                           0                   32
#
#    TRV.Stroop.palabras.PD  TRV.Tavec.05_Rg-Md.PD  TRV.Tavec.10_RCl-LP.PD  \
# 0                      33              50.000000                      12
# 1                      18              45.714286                       8
# 2                      45              50.000000                      13
# 3                      51              48.648649                      12
# 4                      35              46.153846                      15
#
#    TRV.Tavec.12_ESem-RI-B.PD  TRV.Tavec.14_ESem-RL-LP.PD  \
# 0                          0                           1
# 1                          2                           2
# 2                          0                           3
# 3                          3                           2
# 4                          0                           3
#
#    TRV.Tavec.17_ESer-RL-CP.PD  TRV.Tavec.20_I-RL.PD  \
# 0                           1                    10
# 1                           1                    34
# 2                           5                     3
# 3                           1                     3
# 4                           0                     4
#
#    TRV.Tavec.24_Discriminabilidad.PD
# 0                          81.818182
# 1                          68.181818
# 2                          88.636364
# 3                          90.909091
# 4                          93.181818

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((372, 18), (94, 18))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/ctgan/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       8.38 GB / 15.94 GB (52.6%)
# Disk Space Avail:   123.50 GB / 446.36 GB (27.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 16:41:02,140	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# 		Context path: "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=23388) Running DyStack sub-fit ...
# (_dystack pid=23388) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=23388) Beginning AutoGluon training ... Time limit = 895s
# (_dystack pid=23388) AutoGluon will save models to "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=23388) Train Data Rows:    330
# (_dystack pid=23388) Train Data Columns: 17
# (_dystack pid=23388) Label Column:       ED_2Clases
# (_dystack pid=23388) Problem Type:       binary
# (_dystack pid=23388) Preprocessing data ...
# (_dystack pid=23388) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=23388) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=23388) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=23388) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=23388) Using Feature Generators to preprocess the data ...
# (_dystack pid=23388) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=23388) 	Available Memory:                    8024.33 MB
# (_dystack pid=23388) 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=23388) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=23388) 	Stage 1 Generators:
# (_dystack pid=23388) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=23388) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=23388) 	Stage 2 Generators:
# (_dystack pid=23388) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=23388) 	Stage 3 Generators:
# (_dystack pid=23388) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=23388) 	Stage 4 Generators:
# (_dystack pid=23388) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=23388) 	Stage 5 Generators:
# (_dystack pid=23388) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=23388) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=23388) 		('bool', [])  :  2 | ['ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=23388) 		('float', []) :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=23388) 		('int', [])   : 13 | ['ISC.FPacientes.genero', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', ...]
# (_dystack pid=23388) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=23388) 		('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# (_dystack pid=23388) 		('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# (_dystack pid=23388) 		('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# (_dystack pid=23388) 	0.0s = Fit runtime
# (_dystack pid=23388) 	17 features in original data used to generate 17 features in processed data.
# (_dystack pid=23388) 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# (_dystack pid=23388) Data preprocessing and feature engineering runtime = 0.04s ...
# (_dystack pid=23388) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=23388) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=23388) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=23388) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=23388) User-specified model hyperparameters to be fit:
# (_dystack pid=23388) {
# (_dystack pid=23388) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=23388) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=23388) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=23388) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=23388) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=23388) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=23388) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=23388) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=23388) }
# (_dystack pid=23388) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=23388) Fitting 110 L1 models ...
# (_dystack pid=23388) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 596.5s of the 894.95s of remaining time.
# (_dystack pid=23388) 	0.7748	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.0s	 = Training   runtime
# (_dystack pid=23388) 	0.05s	 = Validation runtime
# (_dystack pid=23388) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 594.39s of the 892.84s of remaining time.
# (_dystack pid=23388) 	0.7742	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.01s	 = Training   runtime
# (_dystack pid=23388) 	0.02s	 = Validation runtime
# (_dystack pid=23388) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.35s of the 892.81s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_ray_fit pid=22624) [1000]	valid_set's binary_logloss: 0.403866
# (_dystack pid=23388) 	0.8154	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	1.41s	 = Training   runtime
# (_dystack pid=23388) 	0.04s	 = Validation runtime
# (_dystack pid=23388) Fitting model: LightGBM_BAG_L1 ... Training model for up to 589.69s of the 888.14s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_dystack pid=23388) 	0.8195	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.81s	 = Training   runtime
# (_dystack pid=23388) 	0.02s	 = Validation runtime
# (_dystack pid=23388) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 585.49s of the 883.95s of remaining time.
# (_dystack pid=23388) 	0.8451	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.78s	 = Training   runtime
# (_dystack pid=23388) 	0.1s	 = Validation runtime
# (_dystack pid=23388) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 584.57s of the 883.02s of remaining time.
# (_dystack pid=23388) 	0.8451	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.56s	 = Training   runtime
# (_dystack pid=23388) 	0.08s	 = Validation runtime
# (_dystack pid=23388) Fitting model: CatBoost_BAG_L1 ... Training model for up to 583.88s of the 882.33s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=23388) 	0.8474	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	3.49s	 = Training   runtime
# (_dystack pid=23388) 	0.04s	 = Validation runtime
# (_dystack pid=23388) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 576.94s of the 875.39s of remaining time.
# (_dystack pid=23388) 	0.844	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.57s	 = Training   runtime
# (_dystack pid=23388) 	0.08s	 = Validation runtime
# (_dystack pid=23388) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 576.26s of the 874.71s of remaining time.
# (_dystack pid=23388) 	0.8513	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.53s	 = Training   runtime
# (_dystack pid=23388) 	0.08s	 = Validation runtime
# (_dystack pid=23388) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 575.63s of the 874.09s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=23388) 	0.8336	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	6.35s	 = Training   runtime
# (_dystack pid=23388) 	0.04s	 = Validation runtime
# (_dystack pid=23388) Fitting model: XGBoost_BAG_L1 ... Training model for up to 565.75s of the 864.2s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=23388) 	0.8274	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	1.03s	 = Training   runtime
# (_dystack pid=23388) 	0.03s	 = Validation runtime
# (_dystack pid=23388) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 560.37s of the 858.82s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=27012) Stack (most recent call first):
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=27012)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=27012)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=23388) 	0.8154	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	21.25s	 = Training   runtime
# (_dystack pid=23388) 	0.07s	 = Validation runtime
# (_dystack pid=23388) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 535.26s of the 833.72s of remaining time.
# (_ray_fit pid=15520) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=15520)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# (_dystack pid=23388) 	0.8535	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	0.98s	 = Training   runtime
# (_dystack pid=23388) 	0.04s	 = Validation runtime
# (_dystack pid=23388) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 530.74s of the 829.19s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_dystack pid=23388) 	0.8458	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	2.81s	 = Training   runtime
# (_dystack pid=23388) 	0.03s	 = Validation runtime
# (_dystack pid=23388) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 524.28s of the 822.74s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=8552) Stack (most recent call first):
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=8552)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=8552)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=23388) 	0.8559	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	20.85s	 = Training   runtime
# (_dystack pid=23388) 	0.12s	 = Validation runtime
# (_dystack pid=23388) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 499.83s of the 798.28s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_ray_fit pid=25976) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=25976)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_ray_fit pid=31132) [1000]	valid_set's binary_logloss: 0.430487
# (_dystack pid=23388) 	0.8287	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	1.71s	 = Training   runtime
# (_dystack pid=23388) 	0.01s	 = Validation runtime
# (_dystack pid=23388) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 494.64s of the 793.1s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=23388) 	0.7592	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	6.3s	 = Training   runtime
# (_dystack pid=23388) 	0.1s	 = Validation runtime
# (_dystack pid=23388) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 485.0s of the 783.45s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=23388) 	0.8457	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	7.09s	 = Training   runtime
# (_dystack pid=23388) 	0.02s	 = Validation runtime
# (_dystack pid=23388) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 473.67s of the 772.12s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=30908) [1000]	valid_set's binary_logloss: 0.47911
# (_dystack pid=23388) 	0.8071	 = Validation score   (roc_auc)
# (_dystack pid=23388) 	5.98s	 = Training   runtime
# (_dystack pid=23388) 	0.06s	 = Validation runtime
# (_dystack pid=23388) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 463.8s of the 762.25s of remaining time.
# (_dystack pid=23388) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=21912) Stack (most recent call first):
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=21912)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=21912)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=14456)
# (_ray_fit pid=14456)   File "
# (_ray_fit pid=14456) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=14456)   File "
# ...
# 	15.4s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 801.98s of the 1696.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8713	 = Validation score   (roc_auc)
# 	13.55s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r163_BAG_L1 ... Training model for up to 784.08s of the 1678.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.8625	 = Validation score   (roc_auc)
# 	2.83s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r198_BAG_L1 ... Training model for up to 778.19s of the 1672.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.8585	 = Validation score   (roc_auc)
# 	3.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 771.6s of the 1666.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8656	 = Validation score   (roc_auc)
# 	10.5s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 758.16s of the 1652.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8461	 = Validation score   (roc_auc)
# 	29.03s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_r95_BAG_L1 ... Training model for up to 726.02s of the 1620.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.8466	 = Validation score   (roc_auc)
# 	2.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r34_BAG_L1 ... Training model for up to 721.29s of the 1616.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.8561	 = Validation score   (roc_auc)
# 	1.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L1 ... Training model for up to 716.49s of the 1611.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	0.84	 = Validation score   (roc_auc)
# 	1.94s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 711.71s of the 1606.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.855	 = Validation score   (roc_auc)
# 	25.73s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 679.83s of the 1574.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.8623	 = Validation score   (roc_auc)
# 	29.04s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1541.16s of remaining time.
# 	Ensemble Weights: {'CatBoost_r6_BAG_L1': 0.308, 'NeuralNetTorch_r79_BAG_L1': 0.231, 'NeuralNetFastAI_r102_BAG_L1': 0.231, 'RandomForest_r195_BAG_L1': 0.077, 'NeuralNetTorch_r31_BAG_L1': 0.077, 'NeuralNetTorch_r89_BAG_L1': 0.077}
# 	0.9093	 = Validation score   (roc_auc)
# 	0.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1540.99s of the 1540.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.896	 = Validation score   (roc_auc)
# 	1.91s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1536.44s of the 1535.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.905	 = Validation score   (roc_auc)
# 	2.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1531.13s of the 1530.68s of remaining time.
# 	0.8736	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 1530.24s of the 1529.78s of remaining time.
# 	0.8798	 = Validation score   (roc_auc)
# 	0.56s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1529.53s of the 1529.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.9092	 = Validation score   (roc_auc)
# 	52.72s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 1474.34s of the 1473.89s of remaining time.
# 	0.8774	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 1473.56s of the 1473.11s of remaining time.
# 	0.8803	 = Validation score   (roc_auc)
# 	0.57s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1472.85s of the 1472.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8978	 = Validation score   (roc_auc)
# 	6.45s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1463.44s of the 1462.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	0.8981	 = Validation score   (roc_auc)
# 	3.34s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1453.8s of the 1453.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8727	 = Validation score   (roc_auc)
# 	21.02s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1429.1s of the 1428.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.40%)
# 	0.8812	 = Validation score   (roc_auc)
# 	7.09s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 1416.09s of the 1415.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.9096	 = Validation score   (roc_auc)
# 	36.64s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 1376.12s of the 1375.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8986	 = Validation score   (roc_auc)
# 	15.73s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 1357.67s of the 1357.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.8978	 = Validation score   (roc_auc)
# 	3.76s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 1341.34s of the 1340.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8941	 = Validation score   (roc_auc)
# 	7.09s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 1331.25s of the 1330.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.40%)
# 	0.9002	 = Validation score   (roc_auc)
# 	202.92s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 1124.47s of the 1124.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9026	 = Validation score   (roc_auc)
# 	4.59s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 1117.05s of the 1116.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8832	 = Validation score   (roc_auc)
# 	26.04s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 1088.31s of the 1087.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=5.02%)
# 	0.9001	 = Validation score   (roc_auc)
# 	11.98s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 1073.61s of the 1073.16s of remaining time.
# 	0.8775	 = Validation score   (roc_auc)
# 	0.61s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 1072.84s of the 1072.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9079	 = Validation score   (roc_auc)
# 	16.01s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 1054.14s of the 1053.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.885	 = Validation score   (roc_auc)
# 	10.03s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 1041.2s of the 1040.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.03%)
# 	0.9024	 = Validation score   (roc_auc)
# 	813.95s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 223.93s of the 223.47s of remaining time.
# 	0.8838	 = Validation score   (roc_auc)
# 	1.12s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 222.66s of the 222.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.17%)
# 	0.8917	 = Validation score   (roc_auc)
# 	2.52s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 217.11s of the 216.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8922	 = Validation score   (roc_auc)
# 	7.5s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 206.57s of the 206.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	0.9029	 = Validation score   (roc_auc)
# 	4.02s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 198.58s of the 198.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8761	 = Validation score   (roc_auc)
# 	22.53s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 172.76s of the 172.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.96%)
# 	0.9136	 = Validation score   (roc_auc)
# 	2.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 167.21s of the 166.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8756	 = Validation score   (roc_auc)
# 	28.11s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 136.56s of the 136.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.9079	 = Validation score   (roc_auc)
# 	21.08s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 111.75s of the 111.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8874	 = Validation score   (roc_auc)
# 	8.63s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L2 ... Training model for up to 99.66s of the 99.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.74%)
# 	0.8976	 = Validation score   (roc_auc)
# 	4.34s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L2 ... Training model for up to 91.72s of the 91.27s of remaining time.
# 	0.879	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L2 ... Training model for up to 90.86s of the 90.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.9045	 = Validation score   (roc_auc)
# 	22.57s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 65.35s of the 64.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.8907	 = Validation score   (roc_auc)
# 	57.14s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 3.15s of remaining time.
# 	Ensemble Weights: {'LightGBM_r130_BAG_L2': 0.3, 'NeuralNetTorch_r79_BAG_L2': 0.15, 'NeuralNetTorch_r22_BAG_L2': 0.15, 'CatBoost_BAG_L2': 0.1, 'NeuralNetFastAI_r145_BAG_L2': 0.1, 'CatBoost_r50_BAG_L2': 0.1, 'XGBoost_BAG_L2': 0.05, 'CatBoost_r177_BAG_L2': 0.05}
# 	0.9222	 = Validation score   (roc_auc)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2680.07s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 8.0 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/ctgan/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L3   0.922159     roc_auc       7.206027  1012.403941                0.000000           0.130452            3       True        148
# 1           LightGBM_r130_BAG_L2   0.913558     roc_auc       6.690095   849.224818                0.013798           2.662094            2       True        140
# 2           CatBoost_r177_BAG_L2   0.909577     roc_auc       6.739744   883.200980                0.063446          36.638256            2       True        123
# 3            WeightedEnsemble_L2   0.909302     roc_auc       0.469203    87.692476                0.000621           0.150751            2       True        111
# 4                CatBoost_BAG_L2   0.909244     roc_auc       6.750310   899.286538                0.074013          52.723814            2       True        116
# 5           CatBoost_r137_BAG_L2   0.907912     roc_auc       6.744287   862.576177                0.067989          16.013453            2       True        132
# 6            CatBoost_r50_BAG_L2   0.907883     roc_auc       6.747375   867.642710                0.071078          21.079987            2       True        142
# 7                LightGBM_BAG_L2   0.904958     roc_auc       6.688392   848.862912                0.012095           2.300189            2       True        113
# 8            CatBoost_r69_BAG_L2   0.904494     roc_auc       6.755781   869.130022                0.079483          22.567299            2       True        146
# 9             XGBoost_r89_BAG_L2   0.902902     roc_auc       6.711435   850.581137                0.035137           4.018413            2       True        138
# 10           LightGBM_r96_BAG_L2   0.902583     roc_auc       6.723235   851.153971                0.046937           4.591247            2       True        128
# 11           CatBoost_r13_BAG_L2   0.902380     roc_auc       6.748275  1660.513458                0.071978         813.950734            2       True        134
# 12            CatBoost_r9_BAG_L2   0.900151     roc_auc       6.744951  1049.479178                0.068653         202.916454            2       True        127
# 13            XGBoost_r33_BAG_L2   0.900078     roc_auc       6.703297   858.546627                0.026999          11.983903            2       True        130
# 14     NeuralNetTorch_r79_BAG_L2   0.898616     roc_auc       6.788640   862.289380                0.112342          15.726656            2       True        124
# 15                XGBoost_BAG_L2   0.898066     roc_auc       6.706181   849.903480                0.029883           3.340756            2       True        120
# 16        NeuralNetFastAI_BAG_L2   0.897834     roc_auc       6.760816   853.007744                0.084518           6.445020            2       True        119
# 17          LightGBM_r131_BAG_L2   0.897805     roc_auc       6.692206   850.322315                0.015908           3.759592            2       True        125
# 18           XGBoost_r194_BAG_L2   0.897602     roc_auc       6.813354   850.906995                0.137057           4.344271            2       True        144
# 19             LightGBMXT_BAG_L2   0.896038     roc_auc       6.698761   848.474036                0.022463           1.911312            2       True        112
# 20   NeuralNetFastAI_r191_BAG_L2   0.894127     roc_auc       6.777646   853.652943                0.101349           7.090219            2       True        126
# 21   NeuralNetFastAI_r145_BAG_L2   0.892187     roc_auc       6.725051   854.063740                0.048753           7.501017            2       True        137
# 22          LightGBM_r188_BAG_L2   0.891666     roc_auc       6.706246   849.078967                0.029949           2.516243            2       True        136
# 23   NeuralNetFastAI_r103_BAG_L2   0.890710     roc_auc       6.768427   903.704112                0.092129          57.141388            2       True        147
# 24    NeuralNetFastAI_r11_BAG_L2   0.887351     roc_auc       6.801348   855.192941                0.125051           8.630217            2       True        143
# 25   NeuralNetFastAI_r102_BAG_L2   0.885034     roc_auc       6.793361   856.597512                0.117064          10.034788            2       True        133
# 26      RandomForest_r195_BAG_L2   0.883847     roc_auc       6.758846   847.677843                0.082548           1.115119            2       True        135
# 27     NeuralNetTorch_r22_BAG_L2   0.883239     roc_auc       6.792714   872.600909                0.116416          26.038185            2       True        129
# 28          LightGBMLarge_BAG_L2   0.881241     roc_auc       6.701866   853.655237                0.025568           7.092514            2       True        122
# 29         ExtraTreesEntr_BAG_L2   0.880343     roc_auc       6.760813   847.133605                0.084515           0.570882            2       True        118
# 30            CatBoost_r6_BAG_L1   0.879851     roc_auc       0.021665     3.219072                0.021665           3.219072            1       True         85
# 31       RandomForestEntr_BAG_L2   0.879778     roc_auc       6.759488   847.127274                0.083190           0.564550            2       True        115
# 32        ExtraTrees_r172_BAG_L2   0.879011     roc_auc       6.760019   847.262338                0.083722           0.699615            2       True        145
# 33         ExtraTrees_r42_BAG_L2   0.877476     roc_auc       6.767218   847.171484                0.090921           0.608760            2       True        131
# 34         ExtraTreesGini_BAG_L2   0.877375     roc_auc       6.767815   847.195850                0.091518           0.633126            2       True        117
# 35     NeuralNetTorch_r30_BAG_L2   0.876057     roc_auc       6.776097   869.096340                0.099800          22.533617            2       True        139
# 36     NeuralNetTorch_r79_BAG_L1   0.875623     roc_auc       0.091148    31.568435                0.091148          31.568435            1       True         15
# 37     NeuralNetTorch_r86_BAG_L2   0.875594     roc_auc       6.820472   874.676556                0.144174          28.113832            2       True        141
# 38       RandomForestGini_BAG_L2   0.873596     roc_auc       6.769115   847.304143                0.092818           0.741420            2       True        114
# 39         NeuralNetTorch_BAG_L2   0.872712     roc_auc       6.801832   867.582811                0.125534          21.020087            2       True        121
# 40           CatBoost_r69_BAG_L1   0.871916     roc_auc       0.020180     3.140673                0.020180           3.140673            1       True         37
# 41   NeuralNetFastAI_r100_BAG_L1   0.871337     roc_auc       0.135178    13.549862                0.135178          13.549862            1       True        101
# 42       RandomForestEntr_BAG_L1   0.870685     roc_auc       0.081836     0.517794                0.081836           0.517794            1       True          6
# 43            CatBoost_r5_BAG_L1   0.869773     roc_auc       0.024469     3.046161                0.024469           3.046161            1       True         71
# 44          CatBoost_r128_BAG_L1   0.868122     roc_auc       0.021129     7.551219                0.021129           7.551219            1       True         63
# 45      RandomForest_r166_BAG_L1   0.867514     roc_auc       0.071202     0.804074                0.071202           0.804074            1       True         76
# 46       RandomForestGini_BAG_L1   0.867514     roc_auc       0.077832     0.651193                0.077832           0.651193            1       True          5
# 47          CatBoost_r137_BAG_L1   0.867254     roc_auc       0.023862     3.587264                0.023862           3.587264            1       True         23
# 48      RandomForest_r195_BAG_L1   0.866848     roc_auc       0.077859     0.767514                0.077859           0.767514            1       True         26
# 49           CatBoost_r49_BAG_L1   0.866559     roc_auc       0.019248     6.314510                0.019248           6.314510            1       True         55
# 50         ExtraTreesGini_BAG_L1   0.866226     roc_auc       0.081026     0.650402                0.081026           0.650402            1       True          8
# 51         ExtraTrees_r49_BAG_L1   0.866226     roc_auc       0.081652     0.633347                0.081652           0.633347            1       True         56
# 52     NeuralNetTorch_r87_BAG_L1   0.865632     roc_auc       0.095855    14.252403                0.095855          14.252403            1       True         72
# 53   NeuralNetFastAI_r187_BAG_L1   0.865632     roc_auc       0.105540    10.501986                0.105540          10.501986            1       True        104
# 54    NeuralNetTorch_r143_BAG_L1   0.865516     roc_auc       0.086664    32.692063                0.086664          32.692063            1       True         62
# 55   NeuralNetFastAI_r156_BAG_L1   0.864155     roc_auc       0.100984     8.752476                0.100984           8.752476            1       True         43
# 56           CatBoost_r50_BAG_L1   0.863865     roc_auc       0.021660     3.902653                0.021660           3.902653            1       True         33
# 57           CatBoost_r70_BAG_L1   0.863836     roc_auc       0.020977     4.788169                0.020977           4.788169            1       True         42
# 58          CatBoost_r163_BAG_L1   0.862475     roc_auc       0.034473     2.832536                0.034473           2.832536            1       True        102
# 59   NeuralNetFastAI_r102_BAG_L1   0.862446     roc_auc       0.092797     8.610548                0.092797           8.610548            1       True         24
# 60     NeuralNetTorch_r89_BAG_L1   0.862331     roc_auc       0.089043    29.035402                0.089043          29.035402            1       True        110
# 61           CatBoost_r60_BAG_L1   0.861896     roc_auc       0.016128     2.974359                0.016128           2.974359            1       True         80
# 62     NeuralNetTorch_r31_BAG_L1   0.861882     roc_auc       0.096070    14.340755                0.096070          14.340755            1       True         65
# 63            XGBoost_r89_BAG_L1   0.861867     roc_auc       0.022035     1.713624                0.022035           1.713624            1       True         29
# 64          CatBoost_r167_BAG_L1   0.861346     roc_auc       0.022947     3.530051                0.022947           3.530051            1       True         46
# 65    NeuralNetTorch_r158_BAG_L1   0.861230     roc_auc       0.088793    38.362817                0.088793          38.362817            1       True         51
# 66          CatBoost_r177_BAG_L1   0.860854     roc_auc       0.019920     8.518745                0.019920           8.518745            1       True         14
# 67            XGBoost_r98_BAG_L1   0.860767     roc_auc       0.044356     3.476818                0.044356           3.476818            1       True         49
# 68     NeuralNetTorch_r30_BAG_L1   0.860159     roc_auc       0.088835    25.300450                0.088835          25.300450            1       True         30
# 69         ExtraTrees_r42_BAG_L1   0.859884     roc_auc       0.078610     0.594401                0.078610           0.594401            1       True         22
# 70     NeuralNetTorch_r76_BAG_L1   0.859840     roc_auc       0.071457    20.087356                0.071457          20.087356            1       True         90
# 71         ExtraTreesEntr_BAG_L1   0.859797     roc_auc       0.081739     0.518774                0.081739           0.518774            1       True          9
# 72        ExtraTrees_r197_BAG_L1   0.859464     roc_auc       0.081832     0.884580                0.081832           0.884580            1       True         91
# 73          CatBoost_r143_BAG_L1   0.858682     roc_auc       0.032803     6.881499                0.032803           6.881499            1       True         74
# 74          CatBoost_r198_BAG_L1   0.858537     roc_auc       0.011179     3.523550                0.011179           3.523550            1       True        103
# 75            XGBoost_r33_BAG_L1   0.858218     roc_auc       0.030278     3.371456                0.030278           3.371456            1       True         21
# 76          CatBoost_r180_BAG_L1   0.857176     roc_auc       0.009132     5.914913                0.009132           5.914913            1       True         89
# 77       RandomForest_r16_BAG_L1   0.856857     roc_auc       0.099052     1.277655                0.099052           1.277655            1       True         94
# 78            XGBoost_r22_BAG_L1   0.856452     roc_auc       0.039516     1.949339                0.039516           1.949339            1       True         83
# 79            CatBoost_r9_BAG_L1   0.856336     roc_auc       0.023484     7.690531                0.023484           7.690531            1       True         18
# 80           CatBoost_r12_BAG_L1   0.856307     roc_auc       0.028979     4.720097                0.028979           4.720097            1       True         96
# 81            XGBoost_r31_BAG_L1   0.856191     roc_auc       0.044551     5.794043                0.044551           5.794043            1       True         77
# 82            XGBoost_r34_BAG_L1   0.856104     roc_auc       0.015647     1.902545                0.015647           1.902545            1       True        107
# 83      NeuralNetTorch_r1_BAG_L1   0.855004     roc_auc       0.090052    25.734024                0.090052          25.734024            1       True        109
# 84               CatBoost_BAG_L1   0.855004     roc_auc       0.022446     3.549479                0.022446           3.549479            1       True          7
# 85           LightGBM_r15_BAG_L1   0.854801     roc_auc       0.015150     1.814590                0.015150           1.814590            1       True         50
# 86    NeuralNetTorch_r135_BAG_L1   0.853991     roc_auc       0.101900    22.176825                0.101900          22.176825            1       True         97
# 87            XGBoost_r49_BAG_L1   0.853267     roc_auc       0.024997     2.081295                0.024997           2.081295            1       True         70
# 88       RandomForest_r39_BAG_L1   0.852716     roc_auc       0.075934     0.653152                0.075934           0.653152            1       True         45
# 89   NeuralNetFastAI_r138_BAG_L1   0.852600     roc_auc       0.097131     7.865872                0.097131           7.865872            1       True         86
# 90           CatBoost_r86_BAG_L1   0.852340     roc_auc       0.020202     4.988350                0.020202           4.988350            1       True         52
# 91           CatBoost_r13_BAG_L1   0.851558     roc_auc       0.026121     7.690390                0.026121           7.690390            1       True         25
# 92       RandomForest_r15_BAG_L1   0.850139     roc_auc       0.079152     0.913156                0.079152           0.913156            1       True         81
# 93        ExtraTrees_r126_BAG_L1   0.849936     roc_auc       0.087276     0.797620                0.087276           0.797620            1       True         99
# 94   NeuralNetFastAI_r143_BAG_L1   0.849444     roc_auc       0.086418     9.933863                0.086418           9.933863            1       True         41
# 95        NeuralNetFastAI_BAG_L1   0.848430     roc_auc       0.072475     6.524749                0.072475           6.524749            1       True         10
# 96        ExtraTrees_r172_BAG_L1   0.848112     roc_auc       0.084464     0.697704                0.084464           0.697704            1       True         36
# 97          LightGBM_r161_BAG_L1   0.847011     roc_auc       0.020540     9.716018                0.020540           9.716018            1       True         40
# 98     NeuralNetTorch_r36_BAG_L1   0.846925     roc_auc       0.085528    15.398636                0.085528          15.398636            1       True        100
# 99            XGBoost_r95_BAG_L1   0.846649     roc_auc       0.007747     2.100909                0.007747           2.100909            1       True        106
# 100         LightGBM_r196_BAG_L1   0.846316     roc_auc       0.070381     6.336008                0.070381           6.336008            1       True         44
# 101    NeuralNetTorch_r19_BAG_L1   0.846056     roc_auc       0.115575    29.029436                0.115575          29.029436            1       True        105
# 102   NeuralNetTorch_r121_BAG_L1   0.845911     roc_auc       0.107929    34.839473                0.107929          34.839473            1       True         92
# 103   NeuralNetFastAI_r69_BAG_L1   0.845853     roc_auc       0.105611     6.663462                0.105611           6.663462            1       True         84
# 104         LightGBM_r121_BAG_L1   0.845592     roc_auc       0.033539     2.001019                0.033539           2.001019            1       True         87
# 105  NeuralNetFastAI_r145_BAG_L1   0.845448     roc_auc       0.062723     6.996527                0.062723           6.996527            1       True         28
# 106          XGBoost_r194_BAG_L1   0.844912     roc_auc       0.036264     1.588514                0.036264           1.588514            1       True         35
# 107  NeuralNetFastAI_r127_BAG_L1   0.844637     roc_auc       0.080983     8.162957                0.080983           8.162957            1       True         93
# 108   NeuralNetFastAI_r65_BAG_L1   0.844434     roc_auc       0.083653    13.782773                0.083653          13.782773            1       True         67
# 109  NeuralNetFastAI_r134_BAG_L1   0.844087     roc_auc       0.114579    12.126067                0.114579          12.126067            1       True         59
# 110               XGBoost_BAG_L1   0.843927     roc_auc       0.023000     1.611291                0.023000           1.611291            1       True         11
# 111         LightGBMLarge_BAG_L1   0.840988     roc_auc       0.014269     3.375190                0.014269           3.375190            1       True         13
# 112       ExtraTrees_r178_BAG_L1   0.840988     roc_auc       0.083680     0.632414                0.083680           0.632414            1       True         75
# 113         LightGBM_r188_BAG_L1   0.840670     roc_auc       0.020103     2.152786                0.020103           2.152786            1       True         27
# 114   NeuralNetFastAI_r37_BAG_L1   0.840525     roc_auc       0.104877    10.787080                0.104877          10.787080            1       True         53
# 115    NeuralNetFastAI_r4_BAG_L1   0.840409     roc_auc       0.069821     7.926024                0.069821           7.926024            1       True         98
# 116     RandomForest_r127_BAG_L1   0.840351     roc_auc       0.078731     0.812166                0.078731           0.812166            1       True         58
# 117          LightGBM_r42_BAG_L1   0.840003     roc_auc       0.012050     1.937505                0.012050           1.937505            1       True        108
# 118   NeuralNetTorch_r185_BAG_L1   0.838932     roc_auc       0.155722    26.115937                0.155722          26.115937            1       True         78
# 119  NeuralNetFastAI_r111_BAG_L1   0.837918     roc_auc       0.095925     8.217964                0.095925           8.217964            1       True         64
# 120  NeuralNetFastAI_r172_BAG_L1   0.837803     roc_auc       0.086848     8.941397                0.086848           8.941397            1       True         88
# 121    NeuralNetTorch_r41_BAG_L1   0.837745     roc_auc       0.083422    12.297187                0.083422          12.297187            1       True         48
# 122   NeuralNetFastAI_r95_BAG_L1   0.835081     roc_auc       0.067894     6.822009                0.067894           6.822009            1       True         47
# 123   NeuralNetTorch_r197_BAG_L1   0.834067     roc_auc       0.087526    13.324276                0.087526          13.324276            1       True         54
# 124         LightGBM_r131_BAG_L1   0.833314     roc_auc       0.016999     1.820263                0.016999           1.820263            1       True         16
# 125    NeuralNetTorch_r14_BAG_L1   0.829549     roc_auc       0.089515    12.919412                0.089515          12.919412            1       True         39
# 126    NeuralNetTorch_r22_BAG_L1   0.829463     roc_auc       0.123018    16.624029                0.123018          16.624029            1       True         20
# 127    NeuralNetTorch_r86_BAG_L1   0.827001     roc_auc       0.080692    16.862392                0.080692          16.862392            1       True         32
# 128  NeuralNetFastAI_r194_BAG_L1   0.826567     roc_auc       0.069947     6.801334                0.069947           6.801334            1       True         95
# 129              LightGBM_BAG_L1   0.819588     roc_auc       0.014157     2.128575                0.014157           2.128575            1       True          4
# 130   NeuralNetFastAI_r88_BAG_L1   0.818979     roc_auc       0.085108     9.032129                0.085108           9.032129            1       True         68
# 131        NeuralNetTorch_BAG_L1   0.817807     roc_auc       0.120926    15.549182                0.120926          15.549182            1       True         12
# 132         LightGBM_r143_BAG_L1   0.816257     roc_auc       0.018001     2.955187                0.018001           2.955187            1       True         57
# 133            LightGBMXT_BAG_L1   0.815678     roc_auc       0.015866     1.542957                0.015866           1.542957            1       True          3
# 134          LightGBM_r30_BAG_L1   0.813709     roc_auc       0.032162     3.872770                0.032162           3.872770            1       True         69
# 135          LightGBM_r94_BAG_L1   0.812464     roc_auc       0.015995     1.968265                0.015995           1.968265            1       True         61
# 136         LightGBM_r130_BAG_L1   0.807164     roc_auc       0.015001     1.921558                0.015001           1.921558            1       True         31
# 137    NeuralNetTorch_r71_BAG_L1   0.806875     roc_auc       0.093235    12.361490                0.093235          12.361490            1       True         73
# 138  NeuralNetFastAI_r160_BAG_L1   0.806759     roc_auc       0.076994     8.435867                0.076994           8.435867            1       True         79
# 139          LightGBM_r96_BAG_L1   0.806354     roc_auc       0.028298     3.418727                0.028298           3.418727            1       True         19
# 140         LightGBM_r135_BAG_L1   0.805760     roc_auc       0.004014     2.145892                0.004014           2.145892            1       True         82
# 141         ExtraTrees_r4_BAG_L1   0.798824     roc_auc       0.078797     0.533087                0.078797           0.533087            1       True         66
# 142        KNeighborsDist_BAG_L1   0.798086     roc_auc       0.025112     0.003996                0.025112           0.003996            1       True          2
# 143   NeuralNetFastAI_r11_BAG_L1   0.794365     roc_auc       0.089065     7.519446                0.089065           7.519446            1       True         34
# 144        KNeighborsUnif_BAG_L1   0.787950     roc_auc       0.028258     0.004998                0.028258           0.004998            1       True          1
# 145  NeuralNetFastAI_r191_BAG_L1   0.784026     roc_auc       0.082099     7.071337                0.082099           7.071337            1       True         17
# 146      RandomForest_r34_BAG_L1   0.783302     roc_auc       0.077613     0.610419                0.077613           0.610419            1       True         60
# 147  NeuralNetFastAI_r103_BAG_L1   0.773196     roc_auc       0.079164     6.645206                0.079164           6.645206            1       True         38
# Number of models trained: 148
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     :  2 | ['TRV.Tavec.05_Rg-Md.PD', 'TRV.Tavec.24_Discriminabilidad.PD']
# ('int', [])       : 12 | ['ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'TRV.LeidenNT.CaminosTopgrafico_total.PD', 'TRV.LeidenNT.PuntoReferencia_total.PD', 'TRV.LeidenNT.UbicacionAlocentrica_total.PD', ...]
# ('int', ['bool']) :  3 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.enfermedadesDiabetes']
# Plot summary of models saved to file: AutogluonModels/synthetic/ctgan/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r37_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r160_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetFastAI_r69_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r138_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r172_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r127_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r194_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r4_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r100_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r187_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r19_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r42_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r1_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r89_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L2': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7879503069616588,
#   'KNeighborsDist_BAG_L1': 0.7980858334298622,
#   'LightGBMXT_BAG_L1': 0.815678211513958,
#   'LightGBM_BAG_L1': 0.8195876288659794,
#   'RandomForestGini_BAG_L1': 0.8675141897370554,
#   'RandomForestEntr_BAG_L1': 0.8706851615892506,
#   'CatBoost_BAG_L1': 0.8550040542105872,
#   'ExtraTreesGini_BAG_L1': 0.8662255299432411,
#   'ExtraTreesEntr_BAG_L1': 0.8597967102976949,
#   'NeuralNetFastAI_BAG_L1': 0.8484304413297812,
#   'XGBoost_BAG_L1': 0.8439273717131937,
#   'NeuralNetTorch_BAG_L1': 0.8178066720722809,
#   'LightGBMLarge_BAG_L1': 0.8409880690374145,
#   'CatBoost_r177_BAG_L1': 0.8608537009150933,
#   'NeuralNetTorch_r79_BAG_L1': 0.8756226109116183,
#   'LightGBM_r131_BAG_L1': 0.8333140275686322,
#   'NeuralNetFastAI_r191_BAG_L1': 0.7840264102861115,
#   'CatBoost_r9_BAG_L1': 0.8563361519749797,
#   'LightGBM_r96_BAG_L1': 0.806353527163211,
#   'NeuralNetTorch_r22_BAG_L1': 0.8294625275107147,
#   'XGBoost_r33_BAG_L1': 0.8582184640333603,
#   'ExtraTrees_r42_BAG_L1': 0.8598835862388511,
#   'CatBoost_r137_BAG_L1': 0.8672535619135875,
#   'NeuralNetFastAI_r102_BAG_L1': 0.8624464265029538,
#   'CatBoost_r13_BAG_L1': 0.8515579752113982,
#   'RandomForest_r195_BAG_L1': 0.8668481408548592,
#   'LightGBM_r188_BAG_L1': 0.8406695239198425,
#   'NeuralNetFastAI_r145_BAG_L1': 0.8454477006834239,
#   'XGBoost_r89_BAG_L1': 0.8618672535619136,
#   'NeuralNetTorch_r30_BAG_L1': 0.860158693385845,
#   'LightGBM_r130_BAG_L1': 0.8071643692806673,
#   'NeuralNetTorch_r86_BAG_L1': 0.8270010425112939,
#   'CatBoost_r50_BAG_L1': 0.8638654002085022,
#   'NeuralNetFastAI_r11_BAG_L1': 0.7943646472836788,
#   'XGBoost_r194_BAG_L1': 0.8449119657129619,
#   'ExtraTrees_r172_BAG_L1': 0.8481118962122092,
#   'CatBoost_r69_BAG_L1': 0.8719159040889611,
#   'NeuralNetFastAI_r103_BAG_L1': 0.7731958762886597,
#   'NeuralNetTorch_r14_BAG_L1': 0.8295494034518708,
#   'LightGBM_r161_BAG_L1': 0.8470114676242326,
#   'NeuralNetFastAI_r143_BAG_L1': 0.8494439939766014,
#   'CatBoost_r70_BAG_L1': 0.8638364415614502,
#   'NeuralNetFastAI_r156_BAG_L1': 0.8641549866790224,
#   'LightGBM_r196_BAG_L1': 0.8463164600949843,
#   'RandomForest_r39_BAG_L1': 0.8527163210934785,
#   'CatBoost_r167_BAG_L1': 0.8613459979149775,
#   'NeuralNetFastAI_r95_BAG_L1': 0.8350805050388045,
#   'NeuralNetTorch_r41_BAG_L1': 0.8377447005675895,
#   'XGBoost_r98_BAG_L1': 0.8607668249739372,
#   'LightGBM_r15_BAG_L1': 0.8548013436812232,
#   'NeuralNetTorch_r158_BAG_L1': 0.8612301633267694,
#   'CatBoost_r86_BAG_L1': 0.8523398586818023,
#   'NeuralNetFastAI_r37_BAG_L1': 0.8405247306845824,
#   'NeuralNetTorch_r197_BAG_L1': 0.8340669523919844,
#   'CatBoost_r49_BAG_L1': 0.8665585543843393,
#   'ExtraTrees_r49_BAG_L1': 0.8662255299432411,
#   'LightGBM_r143_BAG_L1': 0.8162573844549983,
#   'RandomForest_r127_BAG_L1': 0.8403509788022704,
#   'NeuralNetFastAI_r134_BAG_L1': 0.8440866442719797,
#   'RandomForest_r34_BAG_L1': 0.7833024441098112,
#   'LightGBM_r94_BAG_L1': 0.8124638016911849,
#   'NeuralNetTorch_r143_BAG_L1': 0.8655160430904667,
#   'CatBoost_r128_BAG_L1': 0.8681223213251477,
#   'NeuralNetFastAI_r111_BAG_L1': 0.8379184524499016,
#   'NeuralNetTorch_r31_BAG_L1': 0.8618817328854396,
#   'ExtraTrees_r4_BAG_L1': 0.7988242789296884,
#   'NeuralNetFastAI_r65_BAG_L1': 0.8444341480366037,
#   'NeuralNetFastAI_r88_BAG_L1': 0.8189794972778872,
#   'LightGBM_r30_BAG_L1': 0.8137090235144214,
#   'XGBoost_r49_BAG_L1': 0.8532665353874668,
#   'CatBoost_r5_BAG_L1': 0.8697729642071124,
#   'NeuralNetTorch_r87_BAG_L1': 0.865631877678675,
#   'NeuralNetTorch_r71_BAG_L1': 0.8068747828101471,
#   'CatBoost_r143_BAG_L1': 0.8586818023861925,
#   'ExtraTrees_r178_BAG_L1': 0.8409880690374145,
#   'RandomForest_r166_BAG_L1': 0.8675141897370554,
#   'XGBoost_r31_BAG_L1': 0.8561913587397199,
#   'NeuralNetTorch_r185_BAG_L1': 0.8389320050967218,
#   'NeuralNetFastAI_r160_BAG_L1': 0.806758948221939,
#   'CatBoost_r60_BAG_L1': 0.8618962122089656,
#   'RandomForest_r15_BAG_L1': 0.8501390015058496,
#   'LightGBM_r135_BAG_L1': 0.8057598748986445,
#   'XGBoost_r22_BAG_L1': 0.8564519865631877,
#   'NeuralNetFastAI_r69_BAG_L1': 0.8458531217421522,
#   'CatBoost_r6_BAG_L1': 0.8798505733812115,
#   'NeuralNetFastAI_r138_BAG_L1': 0.8526004865052704,
#   'LightGBM_r121_BAG_L1': 0.8455924939186842,
#   'NeuralNetFastAI_r172_BAG_L1': 0.8378026178616935,
#   'CatBoost_r180_BAG_L1': 0.857175952739488,
#   'NeuralNetTorch_r76_BAG_L1': 0.8598401482682729,
#   'ExtraTrees_r197_BAG_L1': 0.8594636858565967,
#   'NeuralNetTorch_r121_BAG_L1': 0.8459110390362563,
#   'NeuralNetFastAI_r127_BAG_L1': 0.8446368585659677,
#   'RandomForest_r16_BAG_L1': 0.856857407621916,
#   'NeuralNetFastAI_r194_BAG_L1': 0.8265666628055137,
#   'CatBoost_r12_BAG_L1': 0.8563071933279276,
#   'NeuralNetTorch_r135_BAG_L1': 0.853990501563767,
#   'NeuralNetFastAI_r4_BAG_L1': 0.8404088960963744,
#   'ExtraTrees_r126_BAG_L1': 0.8499362909764856,
#   'NeuralNetTorch_r36_BAG_L1': 0.8469245916830765,
#   'NeuralNetFastAI_r100_BAG_L1': 0.8713367311479208,
#   'CatBoost_r163_BAG_L1': 0.8624753851500058,
#   'CatBoost_r198_BAG_L1': 0.8585370091509325,
#   'NeuralNetFastAI_r187_BAG_L1': 0.8656318776786749,
#   'NeuralNetTorch_r19_BAG_L1': 0.8460558322715164,
#   'XGBoost_r95_BAG_L1': 0.8466494845360826,
#   'XGBoost_r34_BAG_L1': 0.8561044827985638,
#   'LightGBM_r42_BAG_L1': 0.8400034750376462,
#   'NeuralNetTorch_r1_BAG_L1': 0.8550040542105873,
#   'NeuralNetTorch_r89_BAG_L1': 0.8623305919147457,
#   'WeightedEnsemble_L2': 0.9093015174331055,
#   'LightGBMXT_BAG_L2': 0.8960384570832851,
#   'LightGBM_BAG_L2': 0.9049577203753041,
#   'RandomForestGini_BAG_L2': 0.8735955056179776,
#   'RandomForestEntr_BAG_L2': 0.8797781767635816,
#   'CatBoost_BAG_L2': 0.9092436001390014,
#   'ExtraTreesGini_BAG_L2': 0.8773746090582648,
#   'ExtraTreesEntr_BAG_L2': 0.8803428703810958,
#   'NeuralNetFastAI_BAG_L2': 0.8978338932005097,
#   'XGBoost_BAG_L2': 0.8980655623769257,
#   'NeuralNetTorch_BAG_L2': 0.8727122668828912,
#   'LightGBMLarge_BAG_L2': 0.8812405884397081,
#   'CatBoost_r177_BAG_L2': 0.9095766245800996,
#   'NeuralNetTorch_r79_BAG_L2': 0.898615776670914,
#   'LightGBM_r131_BAG_L2': 0.8978049345534577,
#   'NeuralNetFastAI_r191_BAG_L2': 0.8941271863778524,
#   'CatBoost_r9_BAG_L2': 0.9001505849646705,
#   'LightGBM_r96_BAG_L2': 0.9025831113170393,
#   'NeuralNetTorch_r22_BAG_L2': 0.8832387350862967,
#   'XGBoost_r33_BAG_L2': 0.9000781883470403,
#   'ExtraTrees_r42_BAG_L2': 0.8774759643229468,
#   'CatBoost_r137_BAG_L2': 0.9079115023746089,
#   'NeuralNetFastAI_r102_BAG_L2': 0.8850341712035215,
#   'CatBoost_r13_BAG_L2': 0.9023804007876752,
#   'RandomForest_r195_BAG_L2': 0.8838468666743889,
#   'LightGBM_r188_BAG_L2': 0.8916657013784316,
#   'NeuralNetFastAI_r145_BAG_L2': 0.8921869570253678,
#   'XGBoost_r89_BAG_L2': 0.9029016564346113,
#   'NeuralNetTorch_r30_BAG_L2': 0.8760569906173984,
#   'LightGBM_r130_BAG_L2': 0.9135584385497508,
#   'NeuralNetTorch_r86_BAG_L2': 0.8755936522645662,
#   'CatBoost_r50_BAG_L2': 0.9078825437275568,
#   'NeuralNetFastAI_r11_BAG_L2': 0.8873508629676821,
#   'XGBoost_r194_BAG_L2': 0.8976022240240935,
#   'ExtraTrees_r172_BAG_L2': 0.8790107726167034,
#   'CatBoost_r69_BAG_L2': 0.9044943820224718,
#   'NeuralNetFastAI_r103_BAG_L2': 0.8907100660257152,
#   'WeightedEnsemble_L3': 0.9221591567241978},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetFastAI_r95_BAG_L1': ['NeuralNetFastAI_r95_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetFastAI_r37_BAG_L1': ['NeuralNetFastAI_r37_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'NeuralNetFastAI_r134_BAG_L1': ['NeuralNetFastAI_r134_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetFastAI_r111_BAG_L1': ['NeuralNetFastAI_r111_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'NeuralNetFastAI_r65_BAG_L1': ['NeuralNetFastAI_r65_BAG_L1'],
#   'NeuralNetFastAI_r88_BAG_L1': ['NeuralNetFastAI_r88_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'NeuralNetFastAI_r160_BAG_L1': ['NeuralNetFastAI_r160_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'NeuralNetFastAI_r69_BAG_L1': ['NeuralNetFastAI_r69_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'NeuralNetFastAI_r138_BAG_L1': ['NeuralNetFastAI_r138_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'NeuralNetFastAI_r172_BAG_L1': ['NeuralNetFastAI_r172_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'NeuralNetFastAI_r127_BAG_L1': ['NeuralNetFastAI_r127_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'NeuralNetFastAI_r194_BAG_L1': ['NeuralNetFastAI_r194_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'NeuralNetFastAI_r4_BAG_L1': ['NeuralNetFastAI_r4_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'NeuralNetTorch_r36_BAG_L1': ['NeuralNetTorch_r36_BAG_L1'],
#   'NeuralNetFastAI_r100_BAG_L1': ['NeuralNetFastAI_r100_BAG_L1'],
#   'CatBoost_r163_BAG_L1': ['CatBoost_r163_BAG_L1'],
#   'CatBoost_r198_BAG_L1': ['CatBoost_r198_BAG_L1'],
#   'NeuralNetFastAI_r187_BAG_L1': ['NeuralNetFastAI_r187_BAG_L1'],
#   'NeuralNetTorch_r19_BAG_L1': ['NeuralNetTorch_r19_BAG_L1'],
#   'XGBoost_r95_BAG_L1': ['XGBoost_r95_BAG_L1'],
#   'XGBoost_r34_BAG_L1': ['XGBoost_r34_BAG_L1'],
#   'LightGBM_r42_BAG_L1': ['LightGBM_r42_BAG_L1'],
#   'NeuralNetTorch_r1_BAG_L1': ['NeuralNetTorch_r1_BAG_L1'],
#   'NeuralNetTorch_r89_BAG_L1': ['NeuralNetTorch_r89_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
# ...
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                            model  score_val eval_metric  pred_time_val  \
#  0            WeightedEnsemble_L3   0.922159     roc_auc       7.206027
#  1           LightGBM_r130_BAG_L2   0.913558     roc_auc       6.690095
#  2           CatBoost_r177_BAG_L2   0.909577     roc_auc       6.739744
#  3            WeightedEnsemble_L2   0.909302     roc_auc       0.469203
#  4                CatBoost_BAG_L2   0.909244     roc_auc       6.750310
#  ..                           ...        ...         ...            ...
#  143   NeuralNetFastAI_r11_BAG_L1   0.794365     roc_auc       0.089065
#  144        KNeighborsUnif_BAG_L1   0.787950     roc_auc       0.028258
#  145  NeuralNetFastAI_r191_BAG_L1   0.784026     roc_auc       0.082099
#  146      RandomForest_r34_BAG_L1   0.783302     roc_auc       0.077613
#  147  NeuralNetFastAI_r103_BAG_L1   0.773196     roc_auc       0.079164
#
#          fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    1012.403941                0.000000           0.130452            3
#  1     849.224818                0.013798           2.662094            2
#  2     883.200980                0.063446          36.638256            2
#  3      87.692476                0.000621           0.150751            2
#  4     899.286538                0.074013          52.723814            2
#  ..           ...                     ...                ...          ...
#  143     7.519446                0.089065           7.519446            1
#  144     0.004998                0.028258           0.004998            1
#  145     7.071337                0.082099           7.071337            1
#  146     0.610419                0.077613           0.610419            1
#  147     6.645206                0.079164           6.645206            1
#
#       can_infer  fit_order
#  0         True        148
#  1         True        140
#  2         True        123
#  3         True        111
#  4         True        116
#  ..         ...        ...
#  143       True         34
#  144       True          1
#  145       True         17
#  146       True         60
#  147       True         38
#
#  [148 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.8587412587412587
# Evaluations on test data:
# {
#     "roc_auc": 0.8587412587412587,
#     "accuracy": 0.7659574468085106,
#     "balanced_accuracy": 0.7701631701631702,
#     "mcc": 0.5329242599707859,
#     "f1": 0.7884615384615384,
#     "precision": 0.8367346938775511,
#     "recall": 0.7454545454545455
# }
# {'roc_auc': 0.8587412587412587,
#  'accuracy': 0.7659574468085106,
#  'balanced_accuracy': 0.7701631701631702,
#  'mcc': 0.5329242599707859,
#  'f1': 0.7884615384615384,
#  'precision': 0.8367346938775511,
#  'recall': 0.7454545454545455}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                            model  score_test  balanced_accuracy        f1  \
# 0          KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 1          ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 2       RandomForest_r166_BAG_L1    1.000000           1.000000  1.000000
# 3          ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 4        RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# ..                           ...         ...                ...       ...
# 143          LightGBM_r94_BAG_L1    0.910778           0.842639  0.832370
# 144  NeuralNetFastAI_r143_BAG_L1    0.907188           0.841249  0.826347
# 145          LightGBM_r96_BAG_L1    0.898326           0.820862  0.808140
# 146         ExtraTrees_r4_BAG_L1    0.855815           0.761352  0.756164
# 147      RandomForest_r34_BAG_L1    0.832300           0.739141  0.714286
#
#      f1_macro  f1_micro   roc_auc  average_precision  precision    recall  \
# 0    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 1    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 2    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 3    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# 4    1.000000  1.000000  1.000000           1.000000   1.000000  1.000000
# ..        ...       ...       ...                ...        ...       ...
# 143  0.843321  0.844086  0.910778           0.914223   0.857143  0.808989
# 144  0.842442  0.844086  0.907188           0.922977   0.884615  0.775281
# 145  0.821570  0.822581  0.898326           0.902760   0.837349  0.780899
# 146  0.760668  0.760753  0.855815           0.861870   0.737968  0.775281
# 147  0.739496  0.741935  0.832300           0.837136   0.759494  0.674157
#
#      ...  eval_metric  pred_time_test  pred_time_val  fit_time  \
# 0    ...      roc_auc        0.031133       0.025112  0.003996
# 1    ...      roc_auc        0.071514       0.081026  0.650402
# 2    ...      roc_auc        0.077506       0.071202  0.804074
# 3    ...      roc_auc        0.078451       0.081739  0.518774
# 4    ...      roc_auc        0.078700       0.081836  0.517794
# ..   ...          ...             ...            ...       ...
# 143  ...      roc_auc        0.040317       0.015995  1.968265
# 144  ...      roc_auc        0.314040       0.086418  9.933863
# 145  ...      roc_auc        0.125992       0.028298  3.418727
# 146  ...      roc_auc        0.091570       0.078797  0.533087
# 147  ...      roc_auc        0.082407       0.077613  0.610419
#
#      pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                   0.031133                0.025112           0.003996
# 1                   0.071514                0.081026           0.650402
# 2                   0.077506                0.071202           0.804074
# 3                   0.078451                0.081739           0.518774
# 4                   0.078700                0.081836           0.517794
# ..                       ...                     ...                ...
# 143                 0.040317                0.015995           1.968265
# 144                 0.314040                0.086418           9.933863
# 145                 0.125992                0.028298           3.418727
# 146                 0.091570                0.078797           0.533087
# 147                 0.082407                0.077613           0.610419
#
#      stack_level  can_infer  fit_order
# 0              1       True          2
# 1              1       True          8
# 2              1       True         76
# 3              1       True          9
# 4              1       True          6
# ..           ...        ...        ...
# 143            1       True         61
# 144            1       True         41
# 145            1       True         19
# 146            1       True         66
# 147            1       True         60
#
# [148 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 372 rows with 5 shuffle sets...
# 	1086.68s	= Expected runtime (217.34s per shuffle set)
# 	407.51s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                 importance    stddev  \
# TRV.Stroop.palabras.PD                            0.124319  0.014953
# TRV.Stroop.color.PD                               0.019889  0.006036
# TRV.Tavec.24_Discriminabilidad.PD                 0.009713  0.001727
# ISC.resultadosReservaCognitiva.escolaridad        0.009481  0.002352
# TRV.Tavec.05_Rg-Md.PD                             0.004124  0.001298
# TRV.LeidenNT.UbicacionAlocentrica_total.PD        0.003915  0.000774
# TRV.Tavec.14_ESem-RL-LP.PD                        0.003846  0.002243
# TRV.LeidenNT.CaminosTopgrafico_total.PD           0.003660  0.001320
# TRV.Tavec.20_I-RL.PD                              0.002508  0.000761
# ISC.FPacientes.genero                             0.001691  0.000162
# ISC.resultadosObservacion.enfermedadesDiabetes    0.001193  0.000635
# TRV.LeidenNT.PuntoReferencia_total.PD             0.001077  0.000412
# TRV.Tavec.17_ESer-RL-CP.PD                        0.001025  0.000449
# ISC.resultadosReservaCognitiva.Total.PD           0.000996  0.000294
# ISC.resultadosObservacion.alcohol                 0.000834  0.000476
# TRV.Tavec.10_RCl-LP.PD                            0.000822  0.000292
# TRV.Tavec.12_ESem-RI-B.PD                         0.000539  0.000497
#
#                                                  p_value  n  p99_high  \
# TRV.Stroop.palabras.PD                          0.000025  5  0.155108
# TRV.Stroop.color.PD                             0.000904  5  0.032316
# TRV.Tavec.24_Discriminabilidad.PD               0.000115  5  0.013268
# ISC.resultadosReservaCognitiva.escolaridad      0.000419  5  0.014323
# TRV.Tavec.05_Rg-Md.PD                           0.001038  5  0.006797
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.000174  5  0.005509
# TRV.Tavec.14_ESem-RL-LP.PD                      0.009272  5  0.008463
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.001721  5  0.006379
# TRV.Tavec.20_I-RL.PD                            0.000902  5  0.004074
# ISC.FPacientes.genero                           0.000010  5  0.002025
# ISC.resultadosObservacion.enfermedadesDiabetes  0.006849  5  0.002501
# TRV.LeidenNT.PuntoReferencia_total.PD           0.002130  5  0.001925
# TRV.Tavec.17_ESer-RL-CP.PD                      0.003489  5  0.001950
# ISC.resultadosReservaCognitiva.Total.PD         0.000810  5  0.001601
# ISC.resultadosObservacion.alcohol               0.008667  5  0.001815
# TRV.Tavec.10_RCl-LP.PD                          0.001628  5  0.001424
# TRV.Tavec.12_ESem-RI-B.PD                       0.036209  5  0.001562
#
#                                                  p99_low
# TRV.Stroop.palabras.PD                          0.093531
# TRV.Stroop.color.PD                             0.007461
# TRV.Tavec.24_Discriminabilidad.PD               0.006157
# ISC.resultadosReservaCognitiva.escolaridad      0.004639
# TRV.Tavec.05_Rg-Md.PD                           0.001451
# TRV.LeidenNT.UbicacionAlocentrica_total.PD      0.002321
# TRV.Tavec.14_ESem-RL-LP.PD                     -0.000772
# TRV.LeidenNT.CaminosTopgrafico_total.PD         0.000942
# TRV.Tavec.20_I-RL.PD                            0.000942
# ISC.FPacientes.genero                           0.001358
# ISC.resultadosObservacion.enfermedadesDiabetes -0.000115
# TRV.LeidenNT.PuntoReferencia_total.PD           0.000229
# TRV.Tavec.17_ESer-RL-CP.PD                      0.000100
# ISC.resultadosReservaCognitiva.Total.PD         0.000392
# ISC.resultadosObservacion.alcohol              -0.000147
# TRV.Tavec.10_RCl-LP.PD                          0.000221
# TRV.Tavec.12_ESem-RI-B.PD                      -0.000484
