# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-gc.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/gc',
    learner_kwargs = {'positive_class':1}
    )

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 350
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       8.10 GB / 15.71 GB (51.5%)
# Disk Space Avail:   664.97 GB / 933.46 GB (71.2%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 87s of the 350s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-07 23:53:50,358	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/strokes/synthetic/gc\ds_sub_fit\sub_fit_ho"
# (_dystack pid=11060) Running DyStack sub-fit ...
# (_dystack pid=11060) Beginning AutoGluon training ... Time limit = 79s
# (_dystack pid=11060) AutoGluon will save models to "AutogluonModels/strokes/synthetic/gc\ds_sub_fit\sub_fit_ho"
# (_dystack pid=11060) Train Data Rows:    5184
# (_dystack pid=11060) Train Data Columns: 10
# (_dystack pid=11060) Label Column:       stroke
# (_dystack pid=11060) Problem Type:       binary
# (_dystack pid=11060) Preprocessing data ...
# (_dystack pid=11060) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=11060) Using Feature Generators to preprocess the data ...
# (_dystack pid=11060) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=11060) 	Available Memory:                    7588.09 MB
# (_dystack pid=11060) 	Train Data (Original)  Memory Usage: 1.76 MB (0.0% of available memory)
# (_dystack pid=11060) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=11060) 	Stage 1 Generators:
# (_dystack pid=11060) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=11060) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=11060) 	Stage 2 Generators:
# (_dystack pid=11060) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=11060) 	Stage 3 Generators:
# (_dystack pid=11060) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=11060) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=11060) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=11060) 	Stage 4 Generators:
# (_dystack pid=11060) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=11060) 	Stage 5 Generators:
# (_dystack pid=11060) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=11060) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=11060) 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=11060) 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# (_dystack pid=11060) 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# (_dystack pid=11060) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=11060) 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# (_dystack pid=11060) 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=11060) 		('int', [])       : 1 | ['age']
# (_dystack pid=11060) 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# (_dystack pid=11060) 	0.1s = Fit runtime
# (_dystack pid=11060) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=11060) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=11060) Data preprocessing and feature engineering runtime = 0.09s ...
# (_dystack pid=11060) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=11060) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=11060) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=11060) User-specified model hyperparameters to be fit:
# (_dystack pid=11060) {
# (_dystack pid=11060) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=11060) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=11060) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=11060) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=11060) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=11060) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=11060) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=11060) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=11060) }
# (_dystack pid=11060) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=11060) Fitting 110 L1 models ...
# (_dystack pid=11060) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 52.73s of the 79.11s of remaining time.
# (_dystack pid=11060) 	0.6748	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.03s	 = Training   runtime
# (_dystack pid=11060) 	0.07s	 = Validation runtime
# (_dystack pid=11060) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 49.55s of the 75.93s of remaining time.
# (_dystack pid=11060) 	0.6701	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.0s	 = Training   runtime
# (_dystack pid=11060) 	0.08s	 = Validation runtime
# (_dystack pid=11060) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 49.41s of the 75.79s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# (_dystack pid=11060) 	0.773	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.89s	 = Training   runtime
# (_dystack pid=11060) 	0.14s	 = Validation runtime
# (_dystack pid=11060) Fitting model: LightGBM_BAG_L1 ... Training model for up to 44.16s of the 70.54s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# (_dystack pid=11060) 	0.767	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.31s	 = Training   runtime
# (_dystack pid=11060) 	0.06s	 = Validation runtime
# (_dystack pid=11060) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 39.69s of the 66.07s of remaining time.
# (_dystack pid=11060) 	0.7571	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.02s	 = Training   runtime
# (_dystack pid=11060) 	0.44s	 = Validation runtime
# (_dystack pid=11060) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 38.09s of the 64.46s of remaining time.
# (_dystack pid=11060) 	0.7602	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.89s	 = Training   runtime
# (_dystack pid=11060) 	0.31s	 = Validation runtime
# (_dystack pid=11060) Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.77s of the 63.14s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# (_dystack pid=11060) 	0.7697	 = Validation score   (accuracy)
# (_dystack pid=11060) 	29.46s	 = Training   runtime
# (_dystack pid=11060) 	0.05s	 = Validation runtime
# (_dystack pid=11060) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 4.07s of the 30.44s of remaining time.
# (_dystack pid=11060) 	0.7425	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.85s	 = Training   runtime
# (_dystack pid=11060) 	0.27s	 = Validation runtime
# (_dystack pid=11060) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2.79s of the 29.17s of remaining time.
# (_dystack pid=11060) 	0.7434	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.83s	 = Training   runtime
# (_dystack pid=11060) 	0.29s	 = Validation runtime
# (_dystack pid=11060) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1.51s of the 27.88s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# (_dystack pid=11060) 	0.673	 = Validation score   (accuracy)
# (_dystack pid=11060) 	6.31s	 = Training   runtime
# (_dystack pid=11060) 	0.25s	 = Validation runtime
# (_dystack pid=11060) Fitting model: WeightedEnsemble_L2 ... Training model for up to 79.12s of the 18.01s of remaining time.
# (_dystack pid=11060) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=11060) 	0.773	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.28s	 = Training   runtime
# (_dystack pid=11060) 	0.0s	 = Validation runtime
# (_dystack pid=11060) Fitting 108 L2 models ...
# (_dystack pid=11060) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 17.69s of the 17.61s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.12%)
# (_dystack pid=11060) 	0.7739	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.72s	 = Training   runtime
# (_dystack pid=11060) 	0.06s	 = Validation runtime
# (_dystack pid=11060) Fitting model: LightGBM_BAG_L2 ... Training model for up to 12.54s of the 12.47s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# (_dystack pid=11060) 	0.7797	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.26s	 = Training   runtime
# (_dystack pid=11060) 	0.03s	 = Validation runtime
# (_dystack pid=11060) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 8.04s of the 7.96s of remaining time.
# (_dystack pid=11060) 	0.7706	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.01s	 = Training   runtime
# (_dystack pid=11060) 	0.32s	 = Validation runtime
# (_dystack pid=11060) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 6.61s of the 6.54s of remaining time.
# (_dystack pid=11060) 	0.772	 = Validation score   (accuracy)
# (_dystack pid=11060) 	1.05s	 = Training   runtime
# (_dystack pid=11060) 	0.31s	 = Validation runtime
# (_dystack pid=11060) Fitting model: CatBoost_BAG_L2 ... Training model for up to 5.18s of the 5.11s of remaining time.
# (_dystack pid=11060) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# (_dystack pid=11060) 	0.7787	 = Validation score   (accuracy)
# (_dystack pid=11060) 	4.23s	 = Training   runtime
# (_dystack pid=11060) 	0.04s	 = Validation runtime
# (_dystack pid=11060) Fitting model: WeightedEnsemble_L3 ... Training model for up to 79.12s of the -2.87s of remaining time.
# (_dystack pid=11060) 	Ensemble Weights: {'LightGBM_BAG_L2': 0.615, 'RandomForestEntr_BAG_L2': 0.154, 'NeuralNetFastAI_BAG_L1': 0.077, 'RandomForestGini_BAG_L2': 0.077, 'CatBoost_BAG_L2': 0.077}
# (_dystack pid=11060) 	0.7811	 = Validation score   (accuracy)
# (_dystack pid=11060) 	0.25s	 = Training   runtime
# (_dystack pid=11060) 	0.0s	 = Validation runtime
# (_dystack pid=11060) AutoGluon training complete, total runtime = 82.38s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 774.3 rows/s (648 batch size)
# (_dystack pid=11060) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/gc\ds_sub_fit\sub_fit_ho")
# (_dystack pid=11060) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_BAG_L1       0.767334   0.769676    accuracy        0.857583       0.053464  29.461146                 0.857583                0.053464          29.461146            1       True          7
# 1         LightGBMXT_BAG_L2       0.762712   0.773920    accuracy        5.562471       2.043055  44.312968                 0.149553                0.062130           1.718779            2       True         12
# 2           CatBoost_BAG_L2       0.759630   0.778742    accuracy        5.682879       2.019551  46.823785                 0.269961                0.038626           4.229595            2       True         16
# 3   RandomForestEntr_BAG_L2       0.751926   0.771991    accuracy        5.628766       2.286609  43.640743                 0.215848                0.305685           1.046554            2       True         15
# 4   RandomForestGini_BAG_L2       0.751926   0.770640    accuracy        5.643112       2.299979  43.605085                 0.230194                0.319054           1.010896            2       True         14
# 5           LightGBM_BAG_L1       0.750385   0.766975    accuracy        0.177457       0.063974   1.314729                 0.177457                0.063974           1.314729            1       True          4
# 6           LightGBM_BAG_L2       0.750385   0.779707    accuracy        5.563347       2.008408  43.849654                 0.150429                0.027483           1.255465            2       True         13
# 7       WeightedEnsemble_L3       0.750385   0.781057    accuracy        6.305248       2.671772  50.389304                 0.025899                0.000000           0.252604            3       True         17
# 8         LightGBMXT_BAG_L1       0.748844   0.772955    accuracy        0.517750       0.136900   1.891756                 0.517750                0.136900           1.891756            1       True          3
# 9       WeightedEnsemble_L2       0.748844   0.772955    accuracy        0.529215       0.136900   2.174031                 0.011465                0.000000           0.282275            2       True         11
# 10  RandomForestGini_BAG_L1       0.742681   0.757137    accuracy        0.205756       0.439703   1.022085                 0.205756                0.439703           1.022085            1       True          5
# 11  RandomForestEntr_BAG_L1       0.739599   0.760224    accuracy        0.270151       0.312943   0.891812                 0.270151                0.312943           0.891812            1       True          6
# 12    ExtraTreesEntr_BAG_L1       0.733436   0.743441    accuracy        0.275347       0.289339   0.828539                 0.275347                0.289339           0.828539            1       True          9
# 13    ExtraTreesGini_BAG_L1       0.724191   0.742477    accuracy        0.295404       0.273108   0.849666                 0.295404                0.273108           0.849666            1       True          8
# 14   NeuralNetFastAI_BAG_L1       0.674884   0.673032    accuracy        2.602376       0.254288   6.308103                 2.602376                0.254288           6.308103            1       True         10
# 15    KNeighborsUnif_BAG_L1       0.673344   0.674769    accuracy        0.082649       0.072862   0.026355                 0.082649                0.072862           0.026355            1       True          1
# 16    KNeighborsDist_BAG_L1       0.662558   0.670139    accuracy        0.128446       0.084344   0.000000                 0.128446                0.084344           0.000000            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	99s	 = DyStack   runtime |	251s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 251s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/gc"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7794.78 MB
# 	Train Data (Original)  Memory Usage: 1.98 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.1s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 166.87s of the 250.36s of remaining time.
# 	0.6748	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 163.57s of the 247.06s of remaining time.
# 	0.6676	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 163.5s of the 246.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.7744	 = Validation score   (accuracy)
# 	2.03s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 158.07s of the 241.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.7667	 = Validation score   (accuracy)
# 	2.76s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 152.99s of the 236.48s of remaining time.
# 	0.7562	 = Validation score   (accuracy)
# 	0.93s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 151.63s of the 235.12s of remaining time.
# 	0.7543	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 150.27s of the 233.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.7713	 = Validation score   (accuracy)
# 	32.52s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 115.23s of the 198.72s of remaining time.
# 	0.7403	 = Validation score   (accuracy)
# 	0.91s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 113.86s of the 197.35s of remaining time.
# 	0.7449	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 112.61s of the 196.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.7668	 = Validation score   (accuracy)
# 	15.16s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 95.0s of the 178.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.11%)
# 	0.7662	 = Validation score   (accuracy)
# 	2.89s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 89.48s of the 172.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	0.7632	 = Validation score   (accuracy)
# 	55.52s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 31.54s of the 115.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.12%)
# 	0.7626	 = Validation score   (accuracy)
# 	3.74s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 25.07s of the 108.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.7759	 = Validation score   (accuracy)
# 	5.43s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 17.29s of the 100.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1.47s of the 84.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.11%)
# 2025-01-07 23:58:11,728	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-07 23:58:11,752	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-07 23:58:11,756	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-07 23:58:11,762	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.7627	 = Validation score   (accuracy)
# 	3.37s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 250.37s of the 78.48s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 1.0}
# 	0.7759	 = Validation score   (accuracy)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 78.15s of the 78.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# 	0.7821	 = Validation score   (accuracy)
# 	2.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 73.19s of the 73.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.15%)
# 	0.7826	 = Validation score   (accuracy)
# 	3.07s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 67.64s of the 67.58s of remaining time.
# 	0.7754	 = Validation score   (accuracy)
# 	1.15s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 66.1s of the 66.04s of remaining time.
# 	0.774	 = Validation score   (accuracy)
# 	1.21s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 64.5s of the 64.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# 	0.7838	 = Validation score   (accuracy)
# 	33.39s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 28.66s of the 28.6s of remaining time.
# 	0.7703	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 27.39s of the 27.33s of remaining time.
# 	0.7699	 = Validation score   (accuracy)
# 	0.85s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 26.14s of the 26.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	0.7788	 = Validation score   (accuracy)
# 	15.71s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 7.9s of the 7.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.30%)
# 	0.7864	 = Validation score   (accuracy)
# 	3.82s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 250.37s of the 0.8s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L2': 1.0}
# 	0.7864	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 250.27s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 547.8 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/gc")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            XGBoost_BAG_L2   0.786388    accuracy       2.478624  130.806585                0.076924           3.819755            2       True         25
# 1       WeightedEnsemble_L3   0.786388    accuracy       2.478624  131.211007                0.000000           0.404422            3       True         26
# 2           CatBoost_BAG_L2   0.783816    accuracy       2.439869  160.374412                0.038169          33.387582            2       True         21
# 3           LightGBM_BAG_L2   0.782616    accuracy       2.497420  130.061250                0.095720           3.074420            2       True         18
# 4         LightGBMXT_BAG_L2   0.782102    accuracy       2.450650  129.544280                0.048950           2.557450            2       True         17
# 5    NeuralNetFastAI_BAG_L2   0.778845    accuracy       2.581365  142.699659                0.179665          15.712829            2       True         24
# 6       WeightedEnsemble_L2   0.775930    accuracy       0.039967    5.727241                0.000000           0.293262            2       True         16
# 7      CatBoost_r177_BAG_L1   0.775930    accuracy       0.039967    5.433978                0.039967           5.433978            1       True         14
# 8   RandomForestGini_BAG_L2   0.775416    accuracy       2.673597  128.139876                0.271897           1.153046            2       True         19
# 9         LightGBMXT_BAG_L1   0.774387    accuracy       0.135554    2.032754                0.135554           2.032754            1       True          3
# 10  RandomForestEntr_BAG_L2   0.774044    accuracy       2.706755  128.195499                0.305055           1.208669            2       True         20
# 11          CatBoost_BAG_L1   0.771301    accuracy       0.024016   32.518585                0.024016          32.518585            1       True          7
# 12    ExtraTreesGini_BAG_L2   0.770273    accuracy       2.690228  127.844404                0.288528           0.857574            2       True         22
# 13    ExtraTreesEntr_BAG_L2   0.769930    accuracy       2.691895  127.832425                0.290194           0.845595            2       True         23
# 14   NeuralNetFastAI_BAG_L1   0.766844    accuracy       0.209451   15.163861                0.209451          15.163861            1       True         10
# 15          LightGBM_BAG_L1   0.766672    accuracy       0.075952    2.763302                0.075952           2.763302            1       True          4
# 16           XGBoost_BAG_L1   0.766158    accuracy       0.089384    2.888980                0.089384           2.888980            1       True         11
# 17    NeuralNetTorch_BAG_L1   0.763244    accuracy       0.180796   55.522308                0.180796          55.522308            1       True         12
# 18     LightGBM_r131_BAG_L1   0.762729    accuracy       0.197407    3.365595                0.197407           3.365595            1       True         15
# 19     LightGBMLarge_BAG_L1   0.762558    accuracy       0.139235    3.741095                0.139235           3.741095            1       True         13
# 20  RandomForestGini_BAG_L1   0.756215    accuracy       0.303263    0.927060                0.303263           0.927060            1       True          5
# 21  RandomForestEntr_BAG_L1   0.754329    accuracy       0.338248    0.891416                0.338248           0.891416            1       True          6
# 22    ExtraTreesEntr_BAG_L1   0.744900    accuracy       0.280172    0.809603                0.280172           0.809603            1       True          9
# 23    ExtraTreesGini_BAG_L1   0.740271    accuracy       0.285701    0.914918                0.285701           0.914918            1       True          8
# 24    KNeighborsUnif_BAG_L1   0.674781    accuracy       0.059401    0.003747                0.059401           0.003747            1       True          1
# 25    KNeighborsDist_BAG_L1   0.667581    accuracy       0.043153    0.009630                0.043153           0.009630            1       True          2
# Number of models trained: 26
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_TabularNeuralNetTorch'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6747814160809189,
#   'KNeighborsDist_BAG_L1': 0.667581004628836,
#   'LightGBMXT_BAG_L1': 0.7743871078347334,
#   'LightGBM_BAG_L1': 0.7666723812789302,
#   'RandomForestGini_BAG_L1': 0.7562146408366193,
#   'RandomForestEntr_BAG_L1': 0.7543288187896451,
#   'CatBoost_BAG_L1': 0.7713012172124122,
#   'ExtraTreesGini_BAG_L1': 0.7402708726212927,
#   'ExtraTreesEntr_BAG_L1': 0.7448997085547746,
#   'NeuralNetFastAI_BAG_L1': 0.766843819646837,
#   'XGBoost_BAG_L1': 0.76615806617521,
#   'NeuralNetTorch_BAG_L1': 0.7632436139207954,
#   'LightGBMLarge_BAG_L1': 0.7625578604491685,
#   'CatBoost_r177_BAG_L1': 0.775930053145894,
#   'LightGBM_r131_BAG_L1': 0.7627292988170753,
#   'WeightedEnsemble_L2': 0.775930053145894,
#   'LightGBMXT_BAG_L2': 0.7821018343905366,
#   'LightGBM_BAG_L2': 0.7826161494942568,
#   'RandomForestGini_BAG_L2': 0.7754157380421738,
#   'RandomForestEntr_BAG_L2': 0.77404423109892,
#   'CatBoost_BAG_L2': 0.783816218069604,
#   'ExtraTreesGini_BAG_L2': 0.7702725870049717,
#   'ExtraTreesEntr_BAG_L2': 0.7699297102691582,
#   'NeuralNetFastAI_BAG_L2': 0.7788445054003086,
#   'XGBoost_BAG_L2': 0.786387793588205,
#   'WeightedEnsemble_L3': 0.786387793588205},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.003746509552001953,
#   'KNeighborsDist_BAG_L1': 0.00962972640991211,
#   'LightGBMXT_BAG_L1': 2.0327539443969727,
#   'LightGBM_BAG_L1': 2.7633016109466553,
#   'RandomForestGini_BAG_L1': 0.9270598888397217,
#   'RandomForestEntr_BAG_L1': 0.8914158344268799,
#   'CatBoost_BAG_L1': 32.518585205078125,
#   'ExtraTreesGini_BAG_L1': 0.9149179458618164,
#   'ExtraTreesEntr_BAG_L1': 0.8096027374267578,
#   'NeuralNetFastAI_BAG_L1': 15.163860559463501,
#   'XGBoost_BAG_L1': 2.8889803886413574,
#   'NeuralNetTorch_BAG_L1': 55.52230763435364,
#   'LightGBMLarge_BAG_L1': 3.7410950660705566,
#   'CatBoost_r177_BAG_L1': 5.433978319168091,
#   'LightGBM_r131_BAG_L1': 3.3655946254730225,
#   'WeightedEnsemble_L2': 0.293262243270874,
#   'LightGBMXT_BAG_L2': 2.55745005607605,
#   'LightGBM_BAG_L2': 3.074420213699341,
#   'RandomForestGini_BAG_L2': 1.1530461311340332,
#   'RandomForestEntr_BAG_L2': 1.2086694240570068,
#   'CatBoost_BAG_L2': 33.387582302093506,
#   'ExtraTreesGini_BAG_L2': 0.8575739860534668,
#   'ExtraTreesEntr_BAG_L2': 0.8455948829650879,
#   'NeuralNetFastAI_BAG_L2': 15.712828636169434,
#   'XGBoost_BAG_L2': 3.8197548389434814,
#   'WeightedEnsemble_L3': 0.4044218063354492},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.05940127372741699,
#   'KNeighborsDist_BAG_L1': 0.043152570724487305,
#   'LightGBMXT_BAG_L1': 0.13555431365966797,
#   'LightGBM_BAG_L1': 0.07595157623291016,
#   'RandomForestGini_BAG_L1': 0.30326318740844727,
#   'RandomForestEntr_BAG_L1': 0.33824825286865234,
#   'CatBoost_BAG_L1': 0.02401566505432129,
#   'ExtraTreesGini_BAG_L1': 0.28570103645324707,
#   'ExtraTreesEntr_BAG_L1': 0.28017234802246094,
#   'NeuralNetFastAI_BAG_L1': 0.20945096015930176,
#   'XGBoost_BAG_L1': 0.08938384056091309,
#   'NeuralNetTorch_BAG_L1': 0.18079590797424316,
#   'LightGBMLarge_BAG_L1': 0.1392354965209961,
#   'CatBoost_r177_BAG_L1': 0.03996706008911133,
#   'LightGBM_r131_BAG_L1': 0.19740700721740723,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.0489497184753418,
#   'LightGBM_BAG_L2': 0.09571981430053711,
#   'RandomForestGini_BAG_L2': 0.2718966007232666,
#   'RandomForestEntr_BAG_L2': 0.3050549030303955,
#   'CatBoost_BAG_L2': 0.038168907165527344,
#   'ExtraTreesGini_BAG_L2': 0.2885279655456543,
#   'ExtraTreesEntr_BAG_L2': 0.290194034576416,
#   'NeuralNetFastAI_BAG_L2': 0.17966461181640625,
#   'XGBoost_BAG_L2': 0.07692360877990723,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0            XGBoost_BAG_L2   0.786388    accuracy       2.478624  130.806585
#  1       WeightedEnsemble_L3   0.786388    accuracy       2.478624  131.211007
#  2           CatBoost_BAG_L2   0.783816    accuracy       2.439869  160.374412
#  3           LightGBM_BAG_L2   0.782616    accuracy       2.497420  130.061250
#  4         LightGBMXT_BAG_L2   0.782102    accuracy       2.450650  129.544280
#  5    NeuralNetFastAI_BAG_L2   0.778845    accuracy       2.581365  142.699659
#  6       WeightedEnsemble_L2   0.775930    accuracy       0.039967    5.727241
#  7      CatBoost_r177_BAG_L1   0.775930    accuracy       0.039967    5.433978
#  8   RandomForestGini_BAG_L2   0.775416    accuracy       2.673597  128.139876
#  9         LightGBMXT_BAG_L1   0.774387    accuracy       0.135554    2.032754
#  10  RandomForestEntr_BAG_L2   0.774044    accuracy       2.706755  128.195499
#  11          CatBoost_BAG_L1   0.771301    accuracy       0.024016   32.518585
#  12    ExtraTreesGini_BAG_L2   0.770273    accuracy       2.690228  127.844404
#  13    ExtraTreesEntr_BAG_L2   0.769930    accuracy       2.691895  127.832425
#  14   NeuralNetFastAI_BAG_L1   0.766844    accuracy       0.209451   15.163861
#  15          LightGBM_BAG_L1   0.766672    accuracy       0.075952    2.763302
#  16           XGBoost_BAG_L1   0.766158    accuracy       0.089384    2.888980
#  17    NeuralNetTorch_BAG_L1   0.763244    accuracy       0.180796   55.522308
#  18     LightGBM_r131_BAG_L1   0.762729    accuracy       0.197407    3.365595
#  19     LightGBMLarge_BAG_L1   0.762558    accuracy       0.139235    3.741095
#  20  RandomForestGini_BAG_L1   0.756215    accuracy       0.303263    0.927060
#  21  RandomForestEntr_BAG_L1   0.754329    accuracy       0.338248    0.891416
#  22    ExtraTreesEntr_BAG_L1   0.744900    accuracy       0.280172    0.809603
#  23    ExtraTreesGini_BAG_L1   0.740271    accuracy       0.285701    0.914918
#  24    KNeighborsUnif_BAG_L1   0.674781    accuracy       0.059401    0.003747
#  25    KNeighborsDist_BAG_L1   0.667581    accuracy       0.043153    0.009630
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.076924           3.819755            2       True
#  1                 0.000000           0.404422            3       True
#  2                 0.038169          33.387582            2       True
#  3                 0.095720           3.074420            2       True
#  4                 0.048950           2.557450            2       True
#  5                 0.179665          15.712829            2       True
#  6                 0.000000           0.293262            2       True
#  7                 0.039967           5.433978            1       True
#  8                 0.271897           1.153046            2       True
#  9                 0.135554           2.032754            1       True
#  10                0.305055           1.208669            2       True
#  11                0.024016          32.518585            1       True
#  12                0.288528           0.857574            2       True
#  13                0.290194           0.845595            2       True
#  14                0.209451          15.163861            1       True
#  15                0.075952           2.763302            1       True
#  16                0.089384           2.888980            1       True
#  17                0.180796          55.522308            1       True
#  18                0.197407           3.365595            1       True
#  19                0.139235           3.741095            1       True
#  20                0.303263           0.927060            1       True
#  21                0.338248           0.891416            1       True
#  22                0.280172           0.809603            1       True
#  23                0.285701           0.914918            1       True
#  24                0.059401           0.003747            1       True
#  25                0.043153           0.009630            1       True
#
#      fit_order
#  0          25
#  1          26
#  2          21
#  3          18
#  4          17
#  5          24
#  6          16
#  7          14
#  8          19
#  9           3
#  10         20
#  11          7
#  12         22
#  13         23
#  14         10
#  15          4
#  16         11
#  17         12
#  18         15
#  19         13
#  20          5
#  21          6
#  22          9
#  23          8
#  24          1
#  25          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.7732064798148625,
#  'balanced_accuracy': 0.7729109656446627,
#  'mcc': 0.5462864693514804,
#  'roc_auc': 0.8532771220500188,
#  'f1': 0.7660477453580902,
#  'precision': 0.7771797631862217,
#  'recall': 0.7552301255230126}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.667581    accuracy
# 1   RandomForestGini_BAG_L1    1.000000   0.756215    accuracy
# 2   RandomForestEntr_BAG_L1    1.000000   0.754329    accuracy
# 3     ExtraTreesEntr_BAG_L1    1.000000   0.744900    accuracy
# 4     ExtraTreesGini_BAG_L1    1.000000   0.740271    accuracy
# 5      LightGBMLarge_BAG_L1    0.972227   0.762558    accuracy
# 6     ExtraTreesGini_BAG_L2    0.875536   0.770273    accuracy
# 7            XGBoost_BAG_L1    0.874850   0.766158    accuracy
# 8     ExtraTreesEntr_BAG_L2    0.873821   0.769930    accuracy
# 9      LightGBM_r131_BAG_L1    0.860449   0.762729    accuracy
# 10        LightGBMXT_BAG_L2    0.854792   0.782102    accuracy
# 11     CatBoost_r177_BAG_L1    0.853763   0.775930    accuracy
# 12      WeightedEnsemble_L2    0.853763   0.775930    accuracy
# 13          LightGBM_BAG_L1    0.853077   0.766672    accuracy
# 14          CatBoost_BAG_L2    0.849649   0.783816    accuracy
# 15  RandomForestEntr_BAG_L2    0.840048   0.774044    accuracy
# 16  RandomForestGini_BAG_L2    0.834048   0.775416    accuracy
# 17        LightGBMXT_BAG_L1    0.833705   0.774387    accuracy
# 18           XGBoost_BAG_L2    0.829076   0.786388    accuracy
# 19      WeightedEnsemble_L3    0.829076   0.786388    accuracy
# 20   NeuralNetFastAI_BAG_L2    0.814504   0.778845    accuracy
# 21          LightGBM_BAG_L2    0.814161   0.782616    accuracy
# 22    NeuralNetTorch_BAG_L1    0.811761   0.763244    accuracy
# 23          CatBoost_BAG_L1    0.807646   0.771301    accuracy
# 24   NeuralNetFastAI_BAG_L1    0.799931   0.766844    accuracy
# 25    KNeighborsUnif_BAG_L1    0.774901   0.674781    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.039738       0.043153    0.009630                 0.039738
# 1         0.202530       0.303263    0.927060                 0.202530
# 2         0.215250       0.338248    0.891416                 0.215250
# 3         0.241079       0.280172    0.809603                 0.241079
# 4         0.248679       0.285701    0.914918                 0.248679
# 5         0.286237       0.139235    3.741095                 0.286237
# 6         4.121466       2.690228  127.844404                 0.255680
# 7         0.328042       0.089384    2.888980                 0.328042
# 8         4.088714       2.691895  127.832425                 0.222928
# 9         0.330314       0.197407    3.365595                 0.330314
# 10        4.067676       2.450650  129.544280                 0.201890
# 11        0.063641       0.039967    5.433978                 0.063641
# 12        0.065652       0.039967    5.727241                 0.002011
# 13        0.142435       0.075952    2.763302                 0.142435
# 14        4.170732       2.439869  160.374412                 0.304946
# 15        4.049791       2.706755  128.195499                 0.184005
# 16        4.025803       2.673597  128.139876                 0.160017
# 17        0.217905       0.135554    2.032754                 0.217905
# 18        4.124811       2.478624  130.806585                 0.259025
# 19        4.126814       2.478624  131.211007                 0.002003
# 20        5.216056       2.581365  142.699659                 1.350270
# 21        4.119817       2.497420  130.061250                 0.254030
# 22        0.394786       0.180796   55.522308                 0.394786
# 23        0.067340       0.024016   32.518585                 0.067340
# 24        1.026410       0.209451   15.163861                 1.026410
# 25        0.061400       0.059401    0.003747                 0.061400
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.043153           0.009630            1       True
# 1                 0.303263           0.927060            1       True
# 2                 0.338248           0.891416            1       True
# 3                 0.280172           0.809603            1       True
# 4                 0.285701           0.914918            1       True
# 5                 0.139235           3.741095            1       True
# 6                 0.288528           0.857574            2       True
# 7                 0.089384           2.888980            1       True
# 8                 0.290194           0.845595            2       True
# 9                 0.197407           3.365595            1       True
# 10                0.048950           2.557450            2       True
# 11                0.039967           5.433978            1       True
# 12                0.000000           0.293262            2       True
# 13                0.075952           2.763302            1       True
# 14                0.038169          33.387582            2       True
# 15                0.305055           1.208669            2       True
# 16                0.271897           1.153046            2       True
# 17                0.135554           2.032754            1       True
# 18                0.076924           3.819755            2       True
# 19                0.000000           0.404422            3       True
# 20                0.179665          15.712829            2       True
# 21                0.095720           3.074420            2       True
# 22                0.180796          55.522308            1       True
# 23                0.024016          32.518585            1       True
# 24                0.209451          15.163861            1       True
# 25                0.059401           0.003747            1       True
#
#     fit_order
# 0           2
# 1           5
# 2           6
# 3           9
# 4           8
# 5          13
# 6          22
# 7          11
# 8          23
# 9          15
# 10         17
# 11         14
# 12         16
# 13          4
# 14         21
# 15         20
# 16         19
# 17          3
# 18         25
# 19         26
# 20         24
# 21         18
# 22         12
# 23          7
# 24         10
# 25          1

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	224.33s	= Expected runtime (44.87s per shuffle set)
# 	128.75s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# age                   0.19516  0.004251  2.698755e-08  5  0.203912  0.186408
# avg_glucose_level     0.13516  0.006390  5.976015e-07  5  0.148316  0.122004
# work_type             0.12256  0.006511  9.520062e-07  5  0.135965  0.109155
# ever_married          0.09720  0.005963  1.691466e-06  5  0.109478  0.084922
# bmi                   0.06564  0.003025  5.394247e-07  5  0.071868  0.059412
# smoking_status        0.02828  0.004144  5.377412e-05  5  0.036812  0.019748
# hypertension          0.02160  0.002585  2.413646e-05  5  0.026922  0.016278
# heart_disease         0.02028  0.000955  5.883235e-07  5  0.022246  0.018314
# gender                0.01128  0.001753  6.775392e-05  5  0.014889  0.007671
# Residence_type        0.00272  0.000657  3.791366e-04  5  0.004073  0.001367
