# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-gc.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/gc',
    learner_kwargs = {'positive_class':1}
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/strokes/synthetic/gc"

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 900
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       4.62 GB / 15.94 GB (29.0%)
# Disk Space Avail:   117.52 GB / 446.36 GB (26.3%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 		Context path: "AutogluonModels/strokes/synthetic/gc\ds_sub_fit\sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_BAG_L1       0.767334   0.769676    accuracy        1.543808       0.551175   85.241946                 1.543808                0.551175          85.241946            1       True          7
# 1         LightGBMXT_BAG_L2       0.764253   0.773727    accuracy        4.374826       1.976940  104.539596                 0.237370                0.096258           7.149135            2       True          9
# 2           CatBoost_BAG_L2       0.756549   0.778935    accuracy        4.284129       1.927181  110.982034                 0.146673                0.046499          13.591573            2       True         13
# 3           LightGBM_BAG_L1       0.750385   0.766975    accuracy        0.468767       0.120064    4.488903                 0.468767                0.120064           4.488903            1       True          4
# 4           LightGBM_BAG_L2       0.750385   0.780478    accuracy        4.383442       1.935522  105.675317                 0.245986                0.054840           8.284855            2       True         10
# 5       WeightedEnsemble_L3       0.750385   0.780478    accuracy        4.397478       1.937531  106.050785                 0.014036                0.002008           0.375469            3       True         14
# 6         LightGBMXT_BAG_L1       0.748844   0.772955    accuracy        0.996933       0.256153    4.941503                 0.996933                0.256153           4.941503            1       True          3
# 7       WeightedEnsemble_L2       0.748844   0.772955    accuracy        1.011591       0.258162    5.148573                 0.014658                0.002010           0.207070            2       True          8
# 8   RandomForestEntr_BAG_L2       0.747304   0.770255    accuracy        4.404125       2.288688   98.681814                 0.266669                0.408006           1.291353            2       True         12
# 9   RandomForestGini_BAG_L2       0.745763   0.770062    accuracy        4.458157       2.274024   98.671188                 0.320700                0.393342           1.280727            2       True         11
# 10  RandomForestGini_BAG_L1       0.742681   0.757137    accuracy        0.439365       0.378920    1.450689                 0.439365                0.378920           1.450689            1       True          5
# 11  RandomForestEntr_BAG_L1       0.739599   0.760224    accuracy        0.431489       0.356686    1.242254                 0.431489                0.356686           1.242254            1       True          6
# 12    KNeighborsUnif_BAG_L1       0.673344   0.674769    accuracy        0.167507       0.123520    0.013808                 0.167507                0.123520           0.013808            1       True          1
# 13    KNeighborsDist_BAG_L1       0.662558   0.670139    accuracy        0.089588       0.094164    0.011358                 0.089588                0.094164           0.011358            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	258s	 = DyStack   runtime |	642s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 642s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/gc"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5030.02 MB
# 	Train Data (Original)  Memory Usage: 1.98 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.2s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.21s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 427.71s of the 641.7s of remaining time.
# 	0.6748	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 427.56s of the 641.56s of remaining time.
# 	0.6676	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 427.43s of the 641.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7744	 = Validation score   (accuracy)
# 	9.11s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 407.64s of the 621.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.7667	 = Validation score   (accuracy)
# 	24.36s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 367.54s of the 581.54s of remaining time.
# 	0.7562	 = Validation score   (accuracy)
# 	1.97s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 364.9s of the 578.89s of remaining time.
# 	0.7543	 = Validation score   (accuracy)
# 	1.82s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 362.53s of the 576.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.7713	 = Validation score   (accuracy)
# 	76.38s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 264.08s of the 478.07s of remaining time.
# 	0.7403	 = Validation score   (accuracy)
# 	1.87s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 261.37s of the 475.37s of remaining time.
# 	0.7449	 = Validation score   (accuracy)
# 	1.79s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 258.85s of the 472.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7648	 = Validation score   (accuracy)
# 	26.39s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 206.53s of the 420.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.14%)
# 	0.7662	 = Validation score   (accuracy)
# 	12.49s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 169.62s of the 383.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.7643	 = Validation score   (accuracy)
# 	82.58s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 72.18s of the 286.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	0.7626	 = Validation score   (accuracy)
# 	9.98s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 37.93s of the 251.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.7759	 = Validation score   (accuracy)
# 	19.65s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 211.26s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 1.0}
# 	0.7759	 = Validation score   (accuracy)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 210.8s of the 210.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.7814	 = Validation score   (accuracy)
# 	6.8s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 190.02s of the 189.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.7833	 = Validation score   (accuracy)
# 	9.56s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 167.59s of the 167.46s of remaining time.
# 	0.7737	 = Validation score   (accuracy)
# 	1.51s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 165.39s of the 165.26s of remaining time.
# 	0.7739	 = Validation score   (accuracy)
# 	2.1s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 162.62s of the 162.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.7845	 = Validation score   (accuracy)
# 	118.78s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 19.26s of the 19.13s of remaining time.
# 	0.7713	 = Validation score   (accuracy)
# 	1.58s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 16.87s of the 16.74s of remaining time.
# 	0.7691	 = Validation score   (accuracy)
# 	1.26s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 14.92s of the 14.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.7761	 = Validation score   (accuracy)
# 	41.24s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -46.43s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# 	0.7845	 = Validation score   (accuracy)
# 	0.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 689.14s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 299.7 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/gc")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_BAG_L2   0.784502    accuracy       4.242464  387.175457                0.106052         118.776819            2       True         20
# 1       WeightedEnsemble_L3   0.784502    accuracy       4.244473  387.913065                0.002009           0.737608            3       True         24
# 2           LightGBM_BAG_L2   0.783302    accuracy       4.194546  277.954430                0.058135           9.555791            2       True         17
# 3         LightGBMXT_BAG_L2   0.781416    accuracy       4.210449  275.196706                0.074038           6.798067            2       True         16
# 4    NeuralNetFastAI_BAG_L2   0.776101    accuracy       4.514167  309.641247                0.377756          41.242609            2       True         23
# 5      CatBoost_r177_BAG_L1   0.775930    accuracy       0.157503   19.650011                0.157503          19.650011            1       True         14
# 6       WeightedEnsemble_L2   0.775930    accuracy       0.159510   20.084840                0.002007           0.434829            2       True         15
# 7         LightGBMXT_BAG_L1   0.774387    accuracy       0.230477    9.107059                0.230477           9.107059            1       True          3
# 8   RandomForestEntr_BAG_L2   0.773873    accuracy       4.672408  270.503155                0.535996           2.104517            2       True         19
# 9   RandomForestGini_BAG_L2   0.773701    accuracy       4.676715  269.903854                0.540304           1.505216            2       True         18
# 10          CatBoost_BAG_L1   0.771301    accuracy       0.261216   76.383951                0.261216          76.383951            1       True          7
# 11    ExtraTreesGini_BAG_L2   0.771301    accuracy       4.769202  269.974994                0.632791           1.576356            2       True         21
# 12    ExtraTreesEntr_BAG_L2   0.769073    accuracy       4.621682  269.656109                0.485270           1.257471            2       True         22
# 13          LightGBM_BAG_L1   0.766672    accuracy       0.219997   24.362947                0.219997          24.362947            1       True          4
# 14           XGBoost_BAG_L1   0.766158    accuracy       0.251088   12.485688                0.251088          12.485688            1       True         11
# 15   NeuralNetFastAI_BAG_L1   0.764787    accuracy       0.422298   26.385239                0.422298          26.385239            1       True         10
# 16    NeuralNetTorch_BAG_L1   0.764272    accuracy       0.282858   82.577099                0.282858          82.577099            1       True         12
# 17     LightGBMLarge_BAG_L1   0.762558    accuracy       0.245126    9.975126                0.245126           9.975126            1       True         13
# 18  RandomForestGini_BAG_L1   0.756215    accuracy       0.502665    1.966022                0.502665           1.966022            1       True          5
# 19  RandomForestEntr_BAG_L1   0.754329    accuracy       0.392044    1.824010                0.392044           1.824010            1       True          6
# 20    ExtraTreesEntr_BAG_L1   0.744900    accuracy       0.427107    1.790025                0.427107           1.790025            1       True          9
# 21    ExtraTreesGini_BAG_L1   0.740271    accuracy       0.541594    1.865037                0.541594           1.865037            1       True          8
# 22    KNeighborsUnif_BAG_L1   0.674781    accuracy       0.105641    0.015263                0.105641           0.015263            1       True          1
# 23    KNeighborsDist_BAG_L1   0.667581    accuracy       0.096798    0.011160                0.096798           0.011160            1       True          2
# Number of models trained: 24
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6747814160809189,
#   'KNeighborsDist_BAG_L1': 0.667581004628836,
#   'LightGBMXT_BAG_L1': 0.7743871078347334,
#   'LightGBM_BAG_L1': 0.7666723812789302,
#   'RandomForestGini_BAG_L1': 0.7562146408366193,
#   'RandomForestEntr_BAG_L1': 0.7543288187896451,
#   'CatBoost_BAG_L1': 0.7713012172124122,
#   'ExtraTreesGini_BAG_L1': 0.7402708726212927,
#   'ExtraTreesEntr_BAG_L1': 0.7448997085547746,
#   'NeuralNetFastAI_BAG_L1': 0.7647865592319562,
#   'XGBoost_BAG_L1': 0.76615806617521,
#   'NeuralNetTorch_BAG_L1': 0.7642722441282359,
#   'LightGBMLarge_BAG_L1': 0.7625578604491685,
#   'CatBoost_r177_BAG_L1': 0.775930053145894,
#   'WeightedEnsemble_L2': 0.775930053145894,
#   'LightGBMXT_BAG_L2': 0.7814160809189097,
#   'LightGBM_BAG_L2': 0.7833019029658838,
#   'RandomForestGini_BAG_L2': 0.7737013543631065,
#   'RandomForestEntr_BAG_L2': 0.7738727927310132,
#   'CatBoost_BAG_L2': 0.7845019715412309,
#   'ExtraTreesGini_BAG_L2': 0.7713012172124122,
#   'ExtraTreesEntr_BAG_L2': 0.7690725184296245,
#   'NeuralNetFastAI_BAG_L2': 0.7761014915138008,
#   'WeightedEnsemble_L3': 0.7845019715412309},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.015262603759765625,
#   'KNeighborsDist_BAG_L1': 0.011159896850585938,
#   'LightGBMXT_BAG_L1': 9.107059240341187,
#   'LightGBM_BAG_L1': 24.36294722557068,
#   'RandomForestGini_BAG_L1': 1.9660217761993408,
#   'RandomForestEntr_BAG_L1': 1.824009895324707,
#   'CatBoost_BAG_L1': 76.38395071029663,
#   'ExtraTreesGini_BAG_L1': 1.8650367259979248,
#   'ExtraTreesEntr_BAG_L1': 1.7900254726409912,
#   'NeuralNetFastAI_BAG_L1': 26.385239362716675,
#   'XGBoost_BAG_L1': 12.48568844795227,
#   'NeuralNetTorch_BAG_L1': 82.5770993232727,
#   'LightGBMLarge_BAG_L1': 9.975126266479492,
#   'CatBoost_r177_BAG_L1': 19.65001130104065,
#   'WeightedEnsemble_L2': 0.4348287582397461,
#   'LightGBMXT_BAG_L2': 6.798067331314087,
#   'LightGBM_BAG_L2': 9.55579137802124,
#   'RandomForestGini_BAG_L2': 1.5052156448364258,
#   'RandomForestEntr_BAG_L2': 2.1045172214508057,
#   'CatBoost_BAG_L2': 118.7768189907074,
#   'ExtraTreesGini_BAG_L2': 1.5763559341430664,
#   'ExtraTreesEntr_BAG_L2': 1.2574710845947266,
#   'NeuralNetFastAI_BAG_L2': 41.24260878562927,
#   'WeightedEnsemble_L3': 0.7376077175140381},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.10564088821411133,
#   'KNeighborsDist_BAG_L1': 0.09679794311523438,
#   'LightGBMXT_BAG_L1': 0.23047661781311035,
#   'LightGBM_BAG_L1': 0.21999716758728027,
#   'RandomForestGini_BAG_L1': 0.5026648044586182,
#   'RandomForestEntr_BAG_L1': 0.3920435905456543,
#   'CatBoost_BAG_L1': 0.2612161636352539,
#   'ExtraTreesGini_BAG_L1': 0.5415940284729004,
#   'ExtraTreesEntr_BAG_L1': 0.4271070957183838,
#   'NeuralNetFastAI_BAG_L1': 0.4222984313964844,
#   'XGBoost_BAG_L1': 0.25108814239501953,
#   'NeuralNetTorch_BAG_L1': 0.28285789489746094,
#   'LightGBMLarge_BAG_L1': 0.24512624740600586,
#   'CatBoost_r177_BAG_L1': 0.1575026512145996,
#   'WeightedEnsemble_L2': 0.0020074844360351562,
#   'LightGBMXT_BAG_L2': 0.07403755187988281,
#   'LightGBM_BAG_L2': 0.05813455581665039,
#   'RandomForestGini_BAG_L2': 0.5403037071228027,
#   'RandomForestEntr_BAG_L2': 0.5359964370727539,
#   'CatBoost_BAG_L2': 0.10605239868164062,
#   'ExtraTreesGini_BAG_L2': 0.6327905654907227,
#   'ExtraTreesEntr_BAG_L2': 0.48527026176452637,
#   'NeuralNetFastAI_BAG_L2': 0.37775564193725586,
#   'WeightedEnsemble_L3': 0.002008676528930664},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0           CatBoost_BAG_L2   0.784502    accuracy       4.242464  387.175457
#  1       WeightedEnsemble_L3   0.784502    accuracy       4.244473  387.913065
#  2           LightGBM_BAG_L2   0.783302    accuracy       4.194546  277.954430
#  3         LightGBMXT_BAG_L2   0.781416    accuracy       4.210449  275.196706
#  4    NeuralNetFastAI_BAG_L2   0.776101    accuracy       4.514167  309.641247
#  5      CatBoost_r177_BAG_L1   0.775930    accuracy       0.157503   19.650011
#  6       WeightedEnsemble_L2   0.775930    accuracy       0.159510   20.084840
#  7         LightGBMXT_BAG_L1   0.774387    accuracy       0.230477    9.107059
#  8   RandomForestEntr_BAG_L2   0.773873    accuracy       4.672408  270.503155
#  9   RandomForestGini_BAG_L2   0.773701    accuracy       4.676715  269.903854
#  10          CatBoost_BAG_L1   0.771301    accuracy       0.261216   76.383951
#  11    ExtraTreesGini_BAG_L2   0.771301    accuracy       4.769202  269.974994
#  12    ExtraTreesEntr_BAG_L2   0.769073    accuracy       4.621682  269.656109
#  13          LightGBM_BAG_L1   0.766672    accuracy       0.219997   24.362947
#  14           XGBoost_BAG_L1   0.766158    accuracy       0.251088   12.485688
#  15   NeuralNetFastAI_BAG_L1   0.764787    accuracy       0.422298   26.385239
#  16    NeuralNetTorch_BAG_L1   0.764272    accuracy       0.282858   82.577099
#  17     LightGBMLarge_BAG_L1   0.762558    accuracy       0.245126    9.975126
#  18  RandomForestGini_BAG_L1   0.756215    accuracy       0.502665    1.966022
#  19  RandomForestEntr_BAG_L1   0.754329    accuracy       0.392044    1.824010
#  20    ExtraTreesEntr_BAG_L1   0.744900    accuracy       0.427107    1.790025
#  21    ExtraTreesGini_BAG_L1   0.740271    accuracy       0.541594    1.865037
#  22    KNeighborsUnif_BAG_L1   0.674781    accuracy       0.105641    0.015263
#  23    KNeighborsDist_BAG_L1   0.667581    accuracy       0.096798    0.011160
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.106052         118.776819            2       True
#  1                 0.002009           0.737608            3       True
#  2                 0.058135           9.555791            2       True
#  3                 0.074038           6.798067            2       True
#  4                 0.377756          41.242609            2       True
#  5                 0.157503          19.650011            1       True
#  6                 0.002007           0.434829            2       True
#  7                 0.230477           9.107059            1       True
#  8                 0.535996           2.104517            2       True
#  9                 0.540304           1.505216            2       True
#  10                0.261216          76.383951            1       True
#  11                0.632791           1.576356            2       True
#  12                0.485270           1.257471            2       True
#  13                0.219997          24.362947            1       True
#  14                0.251088          12.485688            1       True
#  15                0.422298          26.385239            1       True
#  16                0.282858          82.577099            1       True
#  17                0.245126           9.975126            1       True
#  18                0.502665           1.966022            1       True
#  19                0.392044           1.824010            1       True
#  20                0.427107           1.790025            1       True
#  21                0.541594           1.865037            1       True
#  22                0.105641           0.015263            1       True
#  23                0.096798           0.011160            1       True
#
#      fit_order
#  0          20
#  1          24
#  2          17
#  3          16
#  4          23
#  5          14
#  6          15
#  7           3
#  8          19
#  9          18
#  10          7
#  11         21
#  12         22
#  13          4
#  14         11
#  15         10
#  16         12
#  17         13
#  18          5
#  19          6
#  20          9
#  21          8
#  22          1
#  23          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.7729493443044484,
#  'balanced_accuracy': 0.7727526333166139,
#  'mcc': 0.5457201307306229,
#  'roc_auc': 0.8580588377216651,
#  'f1': 0.7672027418929607,
#  'precision': 0.773524720893142,
#  'recall': 0.7609832635983264}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.667581    accuracy
# 1   RandomForestGini_BAG_L1    1.000000   0.756215    accuracy
# 2     ExtraTreesEntr_BAG_L1    1.000000   0.744900    accuracy
# 3   RandomForestEntr_BAG_L1    1.000000   0.754329    accuracy
# 4     ExtraTreesGini_BAG_L1    1.000000   0.740271    accuracy
# 5      LightGBMLarge_BAG_L1    0.972227   0.762558    accuracy
# 6     ExtraTreesEntr_BAG_L2    0.882393   0.769073    accuracy
# 7     ExtraTreesGini_BAG_L2    0.879136   0.771301    accuracy
# 8            XGBoost_BAG_L1    0.874850   0.766158    accuracy
# 9      CatBoost_r177_BAG_L1    0.853763   0.775930    accuracy
# 10      WeightedEnsemble_L2    0.853763   0.775930    accuracy
# 11          LightGBM_BAG_L1    0.853077   0.766672    accuracy
# 12          CatBoost_BAG_L2    0.850677   0.784502    accuracy
# 13      WeightedEnsemble_L3    0.850677   0.784502    accuracy
# 14  RandomForestEntr_BAG_L2    0.847763   0.773873    accuracy
# 15          LightGBM_BAG_L2    0.847077   0.783302    accuracy
# 16        LightGBMXT_BAG_L2    0.846906   0.781416    accuracy
# 17  RandomForestGini_BAG_L2    0.835248   0.773701    accuracy
# 18        LightGBMXT_BAG_L1    0.833705   0.774387    accuracy
# 19   NeuralNetFastAI_BAG_L2    0.822561   0.776101    accuracy
# 20          CatBoost_BAG_L1    0.807646   0.771301    accuracy
# 21    NeuralNetTorch_BAG_L1    0.805075   0.764272    accuracy
# 22   NeuralNetFastAI_BAG_L1    0.797703   0.764787    accuracy
# 23    KNeighborsUnif_BAG_L1    0.774901   0.674781    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.110563       0.096798    0.011160                 0.110563
# 1         0.263481       0.502665    1.966022                 0.263481
# 2         0.331640       0.427107    1.790025                 0.331640
# 3         0.335858       0.392044    1.824010                 0.335858
# 4         0.373212       0.541594    1.865037                 0.373212
# 5         0.545122       0.245126    9.975126                 0.545122
# 6         6.908089       4.621682  269.656109                 0.315130
# 7         6.848759       4.769202  269.974994                 0.255799
# 8         0.515384       0.251088   12.485688                 0.515384
# 9         0.092854       0.157503   19.650011                 0.092854
# 10        0.096872       0.159510   20.084840                 0.004018
# 11        0.259144       0.219997   24.362947                 0.259144
# 12        6.715702       4.242464  387.175457                 0.122742
# 13        6.719720       4.244473  387.913065                 0.004018
# 14        6.858145       4.672408  270.503155                 0.265185
# 15        6.800522       4.194546  277.954430                 0.207562
# 16        6.832103       4.210449  275.196706                 0.239143
# 17        6.782622       4.676715  269.903854                 0.189662
# 18        0.421330       0.230477    9.107059                 0.421330
# 19        8.809850       4.514167  309.641247                 2.216891
# 20        0.126430       0.261216   76.383951                 0.126430
# 21        1.188699       0.282858   82.577099                 1.188699
# 22        1.935250       0.422298   26.385239                 1.935250
# 23        0.093995       0.105641    0.015263                 0.093995
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.096798           0.011160            1       True
# 1                 0.502665           1.966022            1       True
# 2                 0.427107           1.790025            1       True
# 3                 0.392044           1.824010            1       True
# 4                 0.541594           1.865037            1       True
# 5                 0.245126           9.975126            1       True
# 6                 0.485270           1.257471            2       True
# 7                 0.632791           1.576356            2       True
# 8                 0.251088          12.485688            1       True
# 9                 0.157503          19.650011            1       True
# 10                0.002007           0.434829            2       True
# 11                0.219997          24.362947            1       True
# 12                0.106052         118.776819            2       True
# 13                0.002009           0.737608            3       True
# 14                0.535996           2.104517            2       True
# 15                0.058135           9.555791            2       True
# 16                0.074038           6.798067            2       True
# 17                0.540304           1.505216            2       True
# 18                0.230477           9.107059            1       True
# 19                0.377756          41.242609            2       True
# 20                0.261216          76.383951            1       True
# 21                0.282858          82.577099            1       True
# 22                0.422298          26.385239            1       True
# 23                0.105641           0.015263            1       True
#
#     fit_order
# 0           2
# 1           5
# 2           9
# 3           6
# 4           8
# 5          13
# 6          22
# 7          21
# 8          11
# 9          14
# 10         15
# 11          4
# 12         20
# 13         24
# 14         19
# 15         17
# 16         16
# 17         18
# 18          3
# 19         23
# 20          7
# 21         12
# 22         10
# 23          1

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	405.57s	= Expected runtime (81.11s per shuffle set)
# 	168.67s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# age                   0.21604  0.004629  2.527796e-08  5  0.225571  0.206509
# avg_glucose_level     0.15336  0.007496  6.827125e-07  5  0.168794  0.137926
# work_type             0.13196  0.005029  2.525809e-07  5  0.142314  0.121606
# ever_married          0.10240  0.004532  4.592497e-07  5  0.111732  0.093068
# bmi                   0.08400  0.002227  5.924075e-08  5  0.088586  0.079414
# smoking_status        0.03792  0.003585  9.473086e-06  5  0.045301  0.030539
# hypertension          0.02608  0.002975  1.997721e-05  5  0.032206  0.019954
# heart_disease         0.02132  0.000965  5.031273e-07  5  0.023308  0.019332
# gender                0.01668  0.001591  9.819129e-06  5  0.019956  0.013404
# Residence_type        0.01180  0.000883  3.737710e-06  5  0.013618  0.009982
