# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-ctgan.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/ctgan',
    learner_kwargs = {'positive_class':1}
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/strokes/synthetic/ctgan"

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 350
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       3.98 GB / 15.71 GB (25.4%)
# Disk Space Avail:   660.66 GB / 933.46 GB (70.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 87s of the 350s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-08 00:29:10,302	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/strokes/synthetic/ctgan\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14356) Running DyStack sub-fit ...
# (_dystack pid=14356) Beginning AutoGluon training ... Time limit = 79s
# (_dystack pid=14356) AutoGluon will save models to "AutogluonModels/strokes/synthetic/ctgan\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14356) Train Data Rows:    5184
# (_dystack pid=14356) Train Data Columns: 10
# (_dystack pid=14356) Label Column:       stroke
# (_dystack pid=14356) Problem Type:       binary
# (_dystack pid=14356) Preprocessing data ...
# (_dystack pid=14356) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=14356) Using Feature Generators to preprocess the data ...
# (_dystack pid=14356) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=14356) 	Available Memory:                    4289.05 MB
# (_dystack pid=14356) 	Train Data (Original)  Memory Usage: 1.76 MB (0.0% of available memory)
# (_dystack pid=14356) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=14356) 	Stage 1 Generators:
# (_dystack pid=14356) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=14356) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=14356) 	Stage 2 Generators:
# (_dystack pid=14356) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=14356) 	Stage 3 Generators:
# (_dystack pid=14356) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=14356) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=14356) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=14356) 	Stage 4 Generators:
# (_dystack pid=14356) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=14356) 	Stage 5 Generators:
# (_dystack pid=14356) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=14356) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=14356) 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=14356) 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# (_dystack pid=14356) 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# (_dystack pid=14356) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=14356) 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# (_dystack pid=14356) 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=14356) 		('int', [])       : 1 | ['age']
# (_dystack pid=14356) 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# (_dystack pid=14356) 	0.1s = Fit runtime
# (_dystack pid=14356) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=14356) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=14356) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=14356) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=14356) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=14356) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=14356) User-specified model hyperparameters to be fit:
# (_dystack pid=14356) {
# (_dystack pid=14356) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=14356) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=14356) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=14356) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=14356) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=14356) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14356) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14356) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=14356) }
# (_dystack pid=14356) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=14356) Fitting 110 L1 models ...
# (_dystack pid=14356) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 52.91s of the 79.37s of remaining time.
# (_dystack pid=14356) 	0.7153	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.01s	 = Training   runtime
# (_dystack pid=14356) 	0.05s	 = Validation runtime
# (_dystack pid=14356) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 50.5s of the 76.95s of remaining time.
# (_dystack pid=14356) 	0.7066	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.02s	 = Training   runtime
# (_dystack pid=14356) 	0.04s	 = Validation runtime
# (_dystack pid=14356) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 50.41s of the 76.87s of remaining time.
# (_dystack pid=14356) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# (_dystack pid=14356) 	0.7932	 = Validation score   (accuracy)
# (_dystack pid=14356) 	1.77s	 = Training   runtime
# (_dystack pid=14356) 	0.09s	 = Validation runtime
# (_dystack pid=14356) Fitting model: LightGBM_BAG_L1 ... Training model for up to 44.97s of the 71.43s of remaining time.
# (_dystack pid=14356) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# (_dystack pid=14356) 	0.7944	 = Validation score   (accuracy)
# (_dystack pid=14356) 	1.28s	 = Training   runtime
# (_dystack pid=14356) 	0.06s	 = Validation runtime
# (_dystack pid=14356) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 40.27s of the 66.73s of remaining time.
# (_dystack pid=14356) 	0.7706	 = Validation score   (accuracy)
# (_dystack pid=14356) 	1.04s	 = Training   runtime
# (_dystack pid=14356) 	0.32s	 = Validation runtime
# (_dystack pid=14356) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 38.81s of the 65.27s of remaining time.
# (_dystack pid=14356) 	0.7745	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.85s	 = Training   runtime
# (_dystack pid=14356) 	0.26s	 = Validation runtime
# (_dystack pid=14356) Fitting model: CatBoost_BAG_L1 ... Training model for up to 37.61s of the 64.07s of remaining time.
# (_dystack pid=14356) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# (_dystack pid=14356) 	0.7976	 = Validation score   (accuracy)
# (_dystack pid=14356) 	30.18s	 = Training   runtime
# (_dystack pid=14356) 	0.07s	 = Validation runtime
# (_dystack pid=14356) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 3.98s of the 30.44s of remaining time.
# (_dystack pid=14356) 	0.7625	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.92s	 = Training   runtime
# (_dystack pid=14356) 	0.28s	 = Validation runtime
# (_dystack pid=14356) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2.66s of the 29.12s of remaining time.
# (_dystack pid=14356) 	0.7625	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.87s	 = Training   runtime
# (_dystack pid=14356) 	0.27s	 = Validation runtime
# (_dystack pid=14356) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1.39s of the 27.85s of remaining time.
# (_dystack pid=14356) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# (_dystack pid=14356) 	0.7519	 = Validation score   (accuracy)
# (_dystack pid=14356) 	15.42s	 = Training   runtime
# (_dystack pid=14356) 	0.61s	 = Validation runtime
# (_dystack pid=14356) Fitting model: WeightedEnsemble_L2 ... Training model for up to 79.39s of the 7.51s of remaining time.
# (_dystack pid=14356) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=14356) 	0.7976	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.96s	 = Training   runtime
# (_dystack pid=14356) 	0.0s	 = Validation runtime
# (_dystack pid=14356) Fitting 108 L2 models ...
# (_dystack pid=14356) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 6.46s of the 6.28s of remaining time.
# (_dystack pid=14356) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# (_dystack pid=14356) 	0.8009	 = Validation score   (accuracy)
# (_dystack pid=14356) 	6.35s	 = Training   runtime
# (_dystack pid=14356) 	0.23s	 = Validation runtime
# (_dystack pid=14356) Fitting model: WeightedEnsemble_L3 ... Training model for up to 79.39s of the -12.51s of remaining time.
# (_dystack pid=14356) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# (_dystack pid=14356) 	0.8009	 = Validation score   (accuracy)
# (_dystack pid=14356) 	0.23s	 = Training   runtime
# (_dystack pid=14356) 	0.0s	 = Validation runtime
# (_dystack pid=14356) AutoGluon training complete, total runtime = 92.25s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 536.2 rows/s (648 batch size)
# (_dystack pid=14356) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/ctgan\ds_sub_fit\sub_fit_ho")
# (_dystack pid=14356) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBMXT_BAG_L2       0.813559   0.800926    accuracy        6.347038       2.262187  58.716303                 0.400117                0.233556           6.348252            2       True         12
# 1       WeightedEnsemble_L3       0.813559   0.800926    accuracy        6.382403       2.262187  58.944572                 0.035365                0.000000           0.228269            3       True         13
# 2           LightGBM_BAG_L1       0.801233   0.794367    accuracy        0.369963       0.063098   1.282769                 0.369963                0.063098           1.282769            1       True          4
# 3         LightGBMXT_BAG_L1       0.801233   0.793210    accuracy        0.547572       0.090097   1.770058                 0.547572                0.090097           1.770058            1       True          3
# 4           CatBoost_BAG_L1       0.798151   0.797647    accuracy        1.042535       0.065497  30.180206                 1.042535                0.065497          30.180206            1       True          7
# 5       WeightedEnsemble_L2       0.798151   0.797647    accuracy        1.073821       0.068462  31.143167                 0.031286                0.002964           0.962961            2       True         11
# 6   RandomForestEntr_BAG_L1       0.788906   0.774498    accuracy        0.332394       0.260251   0.851552                 0.332394                0.260251           0.851552            1       True          6
# 7     ExtraTreesEntr_BAG_L1       0.785824   0.762539    accuracy        0.303535       0.265302   0.874834                 0.303535                0.265302           0.874834            1       True          9
# 8   RandomForestGini_BAG_L1       0.784284   0.770640    accuracy        0.466490       0.316331   1.043161                 0.466490                0.316331           1.043161            1       True          5
# 9     ExtraTreesGini_BAG_L1       0.778120   0.762539    accuracy        0.357693       0.275410   0.920718                 0.357693                0.275410           0.920718            1       True          8
# 10   NeuralNetFastAI_BAG_L1       0.750385   0.751929    accuracy        2.264835       0.605781  15.417548                 2.264835                0.605781          15.417548            1       True         10
# 11    KNeighborsUnif_BAG_L1       0.734977   0.715278    accuracy        0.128296       0.049984   0.009062                 0.128296                0.049984           0.009062            1       True          1
# 12    KNeighborsDist_BAG_L1       0.734977   0.706597    accuracy        0.133609       0.036879   0.018143                 0.133609                0.036879           0.018143            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	109s	 = DyStack   runtime |	241s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 241s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/ctgan"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6206.47 MB
# 	Train Data (Original)  Memory Usage: 1.98 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.2s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.31s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 160.32s of the 240.52s of remaining time.
# 	0.7166	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 157.37s of the 237.56s of remaining time.
# 	0.7101	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 157.28s of the 237.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	0.7953	 = Validation score   (accuracy)
# 	7.72s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 136.38s of the 216.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	0.7898	 = Validation score   (accuracy)
# 	8.14s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 119.77s of the 199.96s of remaining time.
# 	0.7771	 = Validation score   (accuracy)
# 	1.96s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 117.27s of the 197.47s of remaining time.
# 	0.7722	 = Validation score   (accuracy)
# 	1.81s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 115.03s of the 195.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	0.7979	 = Validation score   (accuracy)
# 	95.12s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 11.89s of the 92.09s of remaining time.
# 	0.7662	 = Validation score   (accuracy)
# 	2.39s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 9.03s of the 89.23s of remaining time.
# 	0.7641	 = Validation score   (accuracy)
# 	1.46s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 7.11s of the 87.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.7735	 = Validation score   (accuracy)
# 	22.13s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 240.55s of the 55.35s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	0.7979	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 54.36s of the 54.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	0.7998	 = Validation score   (accuracy)
# 	10.78s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 34.7s of the 34.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.11%)
# 	0.8018	 = Validation score   (accuracy)
# 	12.67s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 12.49s of the 12.39s of remaining time.
# 	0.7986	 = Validation score   (accuracy)
# 	3.0s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 8.87s of the 8.77s of remaining time.
# 	0.7972	 = Validation score   (accuracy)
# 	3.16s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4.99s of the 4.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# 	Time limit exceeded... Skipping CatBoost_BAG_L2.
# 2025-01-08 00:35:03,352	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,377	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,410	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,417	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,431	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,443	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-08 00:35:03,466	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 240.55s of the -8.71s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	0.8018	 = Validation score   (accuracy)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 249.92s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 458.5 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/ctgan")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.801817    accuracy       2.881312  153.718169                0.000000           0.286411            3       True         16
# 1           LightGBM_BAG_L2   0.801817    accuracy       2.881312  153.431757                0.138933          12.674199            2       True         13
# 2         LightGBMXT_BAG_L2   0.799760    accuracy       2.878819  151.538030                0.136440          10.780472            2       True         12
# 3   RandomForestGini_BAG_L2   0.798560    accuracy       3.234699  143.753242                0.492319           2.995683            2       True         14
# 4           CatBoost_BAG_L1   0.797874    accuracy       0.165094   95.117848                0.165094          95.117848            1       True          7
# 5       WeightedEnsemble_L2   0.797874    accuracy       0.176889   96.004714                0.011795           0.886866            2       True         11
# 6   RandomForestEntr_BAG_L2   0.797188    accuracy       3.321939  143.922148                0.579560           3.164589            2       True         15
# 7         LightGBMXT_BAG_L1   0.795303    accuracy       0.291953    7.719223                0.291953           7.719223            1       True          3
# 8           LightGBM_BAG_L1   0.789817    accuracy       0.143572    8.138615                0.143572           8.138615            1       True          4
# 9   RandomForestGini_BAG_L1   0.777130    accuracy       0.418488    1.964298                0.418488           1.964298            1       True          5
# 10   NeuralNetFastAI_BAG_L1   0.773530    accuracy       0.668110   22.133547                0.668110          22.133547            1       True         10
# 11  RandomForestEntr_BAG_L1   0.772158    accuracy       0.305472    1.807007                0.305472           1.807007            1       True          6
# 12    ExtraTreesGini_BAG_L1   0.766158    accuracy       0.316954    2.389784                0.316954           2.389784            1       True          8
# 13    ExtraTreesEntr_BAG_L1   0.764101    accuracy       0.304632    1.464530                0.304632           1.464530            1       True          9
# 14    KNeighborsUnif_BAG_L1   0.716612    accuracy       0.074791    0.009308                0.074791           0.009308            1       True          1
# 15    KNeighborsDist_BAG_L1   0.710098    accuracy       0.053313    0.013399                0.053313           0.013399            1       True          2
# Number of models trained: 16
# Types of models trained:
# {'StackerEnsembleModel_KNN', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7166123778501629,
#   'KNeighborsDist_BAG_L1': 0.7100977198697068,
#   'LightGBMXT_BAG_L1': 0.7953025887193554,
#   'LightGBM_BAG_L1': 0.7898165609463398,
#   'RandomForestGini_BAG_L1': 0.7771301217212412,
#   'RandomForestEntr_BAG_L1': 0.7721584090519458,
#   'CatBoost_BAG_L1': 0.7978741642379564,
#   'ExtraTreesGini_BAG_L1': 0.76615806617521,
#   'ExtraTreesEntr_BAG_L1': 0.7641008057603291,
#   'NeuralNetFastAI_BAG_L1': 0.7735299159951997,
#   'WeightedEnsemble_L2': 0.7978741642379564,
#   'LightGBMXT_BAG_L2': 0.7997599862849306,
#   'LightGBM_BAG_L2': 0.8018172466998115,
#   'RandomForestGini_BAG_L2': 0.7985599177095835,
#   'RandomForestEntr_BAG_L2': 0.7971884107663295,
#   'WeightedEnsemble_L3': 0.8018172466998115},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.009308099746704102,
#   'KNeighborsDist_BAG_L1': 0.013398885726928711,
#   'LightGBMXT_BAG_L1': 7.719223499298096,
#   'LightGBM_BAG_L1': 8.138614654541016,
#   'RandomForestGini_BAG_L1': 1.9642975330352783,
#   'RandomForestEntr_BAG_L1': 1.807006597518921,
#   'CatBoost_BAG_L1': 95.11784839630127,
#   'ExtraTreesGini_BAG_L1': 2.3897836208343506,
#   'ExtraTreesEntr_BAG_L1': 1.4645295143127441,
#   'NeuralNetFastAI_BAG_L1': 22.13354730606079,
#   'WeightedEnsemble_L2': 0.8868658542633057,
#   'LightGBMXT_BAG_L2': 10.780472040176392,
#   'LightGBM_BAG_L2': 12.674199342727661,
#   'RandomForestGini_BAG_L2': 2.995683431625366,
#   'RandomForestEntr_BAG_L2': 3.1645894050598145,
#   'WeightedEnsemble_L3': 0.2864112854003906},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.07479143142700195,
#   'KNeighborsDist_BAG_L1': 0.05331277847290039,
#   'LightGBMXT_BAG_L1': 0.29195261001586914,
#   'LightGBM_BAG_L1': 0.14357233047485352,
#   'RandomForestGini_BAG_L1': 0.4184877872467041,
#   'RandomForestEntr_BAG_L1': 0.30547237396240234,
#   'CatBoost_BAG_L1': 0.16509366035461426,
#   'ExtraTreesGini_BAG_L1': 0.3169538974761963,
#   'ExtraTreesEntr_BAG_L1': 0.30463242530822754,
#   'NeuralNetFastAI_BAG_L1': 0.6681098937988281,
#   'WeightedEnsemble_L2': 0.0117950439453125,
#   'LightGBMXT_BAG_L2': 0.13644003868103027,
#   'LightGBM_BAG_L2': 0.1389327049255371,
#   'RandomForestGini_BAG_L2': 0.49231934547424316,
#   'RandomForestEntr_BAG_L2': 0.5795600414276123,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0       WeightedEnsemble_L3   0.801817    accuracy       2.881312  153.718169
#  1           LightGBM_BAG_L2   0.801817    accuracy       2.881312  153.431757
#  2         LightGBMXT_BAG_L2   0.799760    accuracy       2.878819  151.538030
#  3   RandomForestGini_BAG_L2   0.798560    accuracy       3.234699  143.753242
#  4           CatBoost_BAG_L1   0.797874    accuracy       0.165094   95.117848
#  5       WeightedEnsemble_L2   0.797874    accuracy       0.176889   96.004714
#  6   RandomForestEntr_BAG_L2   0.797188    accuracy       3.321939  143.922148
#  7         LightGBMXT_BAG_L1   0.795303    accuracy       0.291953    7.719223
#  8           LightGBM_BAG_L1   0.789817    accuracy       0.143572    8.138615
#  9   RandomForestGini_BAG_L1   0.777130    accuracy       0.418488    1.964298
#  10   NeuralNetFastAI_BAG_L1   0.773530    accuracy       0.668110   22.133547
#  11  RandomForestEntr_BAG_L1   0.772158    accuracy       0.305472    1.807007
#  12    ExtraTreesGini_BAG_L1   0.766158    accuracy       0.316954    2.389784
#  13    ExtraTreesEntr_BAG_L1   0.764101    accuracy       0.304632    1.464530
#  14    KNeighborsUnif_BAG_L1   0.716612    accuracy       0.074791    0.009308
#  15    KNeighborsDist_BAG_L1   0.710098    accuracy       0.053313    0.013399
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.286411            3       True
#  1                 0.138933          12.674199            2       True
#  2                 0.136440          10.780472            2       True
#  3                 0.492319           2.995683            2       True
#  4                 0.165094          95.117848            1       True
#  5                 0.011795           0.886866            2       True
#  6                 0.579560           3.164589            2       True
#  7                 0.291953           7.719223            1       True
#  8                 0.143572           8.138615            1       True
#  9                 0.418488           1.964298            1       True
#  10                0.668110          22.133547            1       True
#  11                0.305472           1.807007            1       True
#  12                0.316954           2.389784            1       True
#  13                0.304632           1.464530            1       True
#  14                0.074791           0.009308            1       True
#  15                0.053313           0.013399            1       True
#
#      fit_order
#  0          16
#  1          13
#  2          12
#  3          14
#  4           7
#  5          11
#  6          15
#  7           3
#  8           4
#  9           5
#  10         10
#  11          6
#  12          8
#  13          9
#  14          1
#  15          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.7814348161481101,
#  'balanced_accuracy': 0.7811587968753637,
#  'mcc': 0.5627457682328826,
#  'roc_auc': 0.8624749472490121,
#  'f1': 0.7747747747747747,
#  'precision': 0.7851772287862513,
#  'recall': 0.7646443514644351}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.710098    accuracy
# 1     ExtraTreesGini_BAG_L1    1.000000   0.766158    accuracy
# 2     ExtraTreesEntr_BAG_L1    1.000000   0.764101    accuracy
# 3   RandomForestEntr_BAG_L1    1.000000   0.772158    accuracy
# 4   RandomForestGini_BAG_L1    1.000000   0.777130    accuracy
# 5           LightGBM_BAG_L1    0.839534   0.789817    accuracy
# 6         LightGBMXT_BAG_L2    0.836105   0.799760    accuracy
# 7       WeightedEnsemble_L3    0.830447   0.801817    accuracy
# 8           LightGBM_BAG_L2    0.830447   0.801817    accuracy
# 9           CatBoost_BAG_L1    0.828562   0.797874    accuracy
# 10      WeightedEnsemble_L2    0.828562   0.797874    accuracy
# 11  RandomForestGini_BAG_L2    0.826847   0.798560    accuracy
# 12  RandomForestEntr_BAG_L2    0.824447   0.797188    accuracy
# 13        LightGBMXT_BAG_L1    0.818447   0.795303    accuracy
# 14    KNeighborsUnif_BAG_L1    0.798388   0.716612    accuracy
# 15   NeuralNetFastAI_BAG_L1    0.783130   0.773530    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.104223       0.053313    0.013399                 0.104223
# 1         0.370002       0.316954    2.389784                 0.370002
# 2         0.383787       0.304632    1.464530                 0.383787
# 3         0.414496       0.305472    1.807007                 0.414496
# 4         0.509830       0.418488    1.964298                 0.509830
# 5         0.362616       0.143572    8.138615                 0.362616
# 6         5.973530       2.878819  151.538030                 0.551261
# 7         5.738121       2.881312  153.718169                 0.000000
# 8         5.738121       2.881312  153.431757                 0.315852
# 9         0.150917       0.165094   95.117848                 0.150917
# 10        0.154697       0.176889   96.004714                 0.003780
# 11        5.789353       3.234699  143.753242                 0.367084
# 12        5.684897       3.321939  143.922148                 0.262628
# 13        0.387259       0.291953    7.719223                 0.387259
# 14        0.146194       0.074791    0.009308                 0.146194
# 15        2.592944       0.668110   22.133547                 2.592944
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.053313           0.013399            1       True
# 1                 0.316954           2.389784            1       True
# 2                 0.304632           1.464530            1       True
# 3                 0.305472           1.807007            1       True
# 4                 0.418488           1.964298            1       True
# 5                 0.143572           8.138615            1       True
# 6                 0.136440          10.780472            2       True
# 7                 0.000000           0.286411            3       True
# 8                 0.138933          12.674199            2       True
# 9                 0.165094          95.117848            1       True
# 10                0.011795           0.886866            2       True
# 11                0.492319           2.995683            2       True
# 12                0.579560           3.164589            2       True
# 13                0.291953           7.719223            1       True
# 14                0.074791           0.009308            1       True
# 15                0.668110          22.133547            1       True
#
#     fit_order
# 0           2
# 1           8
# 2           9
# 3           6
# 4           5
# 5           4
# 6          12
# 7          16
# 8          13
# 9           7
# 10         11
# 11         14
# 12         15
# 13          3
# 14          1
# 15         10

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	285.4s	= Expected runtime (57.08s per shuffle set)
# 	174.68s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# age                   0.17652  0.004989  7.650022e-08  5  0.186793  0.166247
# bmi                   0.05028  0.002129  3.847181e-07  5  0.054663  0.045897
# heart_disease         0.04944  0.002602  9.166139e-07  5  0.054797  0.044083
# hypertension          0.04700  0.003909  5.689075e-06  5  0.055049  0.038951
# work_type             0.03996  0.002414  1.590772e-06  5  0.044931  0.034989
# avg_glucose_level     0.03204  0.004234  3.576261e-05  5  0.040758  0.023322
# gender                0.02188  0.002591  2.315371e-05  5  0.027214  0.016546
# smoking_status        0.01864  0.002685  5.024685e-05  5  0.024168  0.013112
# ever_married          0.01240  0.001435  2.115975e-05  5  0.015355  0.009445
# Residence_type        0.00216  0.000899  2.897451e-03  5  0.004011  0.000309
