# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-ctgan.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/ctgan',
    learner_kwargs = {'positive_class':1}
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/strokes/synthetic/ctgan"

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 900
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       6.13 GB / 15.94 GB (38.5%)
# Disk Space Avail:   117.52 GB / 446.36 GB (26.3%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 		Context path: "AutogluonModels/strokes/synthetic/ctgan\ds_sub_fit\sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBMXT_BAG_L2       0.810478   0.802469    accuracy        4.430963       1.946445  113.303886                 0.483269                0.169688          10.270805            2       True          9
# 1       WeightedEnsemble_L3       0.810478   0.802469    accuracy        4.445272       1.948706  113.647270                 0.014310                0.002261           0.343384            3       True         11
# 2           LightGBM_BAG_L1       0.801233   0.794367    accuracy        0.564799       0.072852    6.062150                 0.564799                0.072852           6.062150            1       True          4
# 3         LightGBMXT_BAG_L1       0.801233   0.793210    accuracy        0.812275       0.123862    3.721935                 0.812275                0.123862           3.721935            1       True          3
# 4           LightGBM_BAG_L2       0.801233   0.801698    accuracy        4.358145       1.874100  110.941646                 0.410452                0.097343           7.908565            2       True         10
# 5           CatBoost_BAG_L1       0.798151   0.797840    accuracy        1.560225       0.737246   90.504575                 1.560225                0.737246          90.504575            1       True          7
# 6       WeightedEnsemble_L2       0.798151   0.797840    accuracy        1.610427       0.739256   90.742812                 0.050202                0.002011           0.238237            2       True          8
# 7   RandomForestEntr_BAG_L1       0.788906   0.774498    accuracy        0.432820       0.382209    1.333358                 0.432820                0.382209           1.333358            1       True          6
# 8   RandomForestGini_BAG_L1       0.784284   0.770640    accuracy        0.430918       0.365743    1.390518                 0.430918                0.365743           1.390518            1       True          5
# 9     KNeighborsUnif_BAG_L1       0.734977   0.715278    accuracy        0.070042       0.037182    0.010545                 0.070042                0.037182           0.010545            1       True          1
# 10    KNeighborsDist_BAG_L1       0.734977   0.706597    accuracy        0.076613       0.057664    0.010000                 0.076613                0.057664           0.010000            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	237s	 = DyStack   runtime |	663s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 663s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/ctgan"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6113.78 MB
# 	Train Data (Original)  Memory Usage: 1.98 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.1s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 441.9s of the 663.0s of remaining time.
# 	0.7166	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 441.77s of the 662.86s of remaining time.
# 	0.7101	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 441.58s of the 662.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7953	 = Validation score   (accuracy)
# 	10.59s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 418.18s of the 639.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.7898	 = Validation score   (accuracy)
# 	5.55s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 402.33s of the 623.43s of remaining time.
# 	0.7771	 = Validation score   (accuracy)
# 	1.36s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 400.14s of the 621.23s of remaining time.
# 	0.7722	 = Validation score   (accuracy)
# 	1.41s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 398.13s of the 619.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.7979	 = Validation score   (accuracy)
# 	86.47s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 299.33s of the 520.43s of remaining time.
# 	0.7662	 = Validation score   (accuracy)
# 	1.62s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 296.93s of the 518.03s of remaining time.
# 	0.7641	 = Validation score   (accuracy)
# 	1.84s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 294.22s of the 515.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7924	 = Validation score   (accuracy)
# 	40.15s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 216.11s of the 437.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.7896	 = Validation score   (accuracy)
# 	9.54s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 188.92s of the 410.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.7888	 = Validation score   (accuracy)
# 	121.28s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 54.12s of the 275.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.7871	 = Validation score   (accuracy)
# 	10.64s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 21.87s of the 242.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.7994	 = Validation score   (accuracy)
# 	15.59s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 204.49s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 1.0}
# 	0.7994	 = Validation score   (accuracy)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 204.03s of the 203.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.8051	 = Validation score   (accuracy)
# 	10.42s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 181.77s of the 181.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.8044	 = Validation score   (accuracy)
# 	12.41s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 156.81s of the 156.68s of remaining time.
# 	0.7967	 = Validation score   (accuracy)
# 	1.52s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 154.64s of the 154.51s of remaining time.
# 	0.8008	 = Validation score   (accuracy)
# 	2.04s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 152.02s of the 151.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.8058	 = Validation score   (accuracy)
# 	88.44s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 37.51s of the 37.38s of remaining time.
# 	0.7958	 = Validation score   (accuracy)
# 	1.76s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 35.07s of the 34.94s of remaining time.
# 	0.7962	 = Validation score   (accuracy)
# 	1.57s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 32.7s of the 32.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.8008	 = Validation score   (accuracy)
# 	29.29s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -11.48s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# 	0.8058	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 675.22s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 314.7 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/ctgan")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.805760    accuracy       4.235032  395.040101                0.000000           0.533263            3       True         24
# 1           CatBoost_BAG_L2   0.805760    accuracy       4.235032  394.506838                0.144034          88.436677            2       True         20
# 2         LightGBMXT_BAG_L2   0.805075    accuracy       4.275296  316.486269                0.184298          10.416107            2       True         16
# 3           LightGBM_BAG_L2   0.804389    accuracy       4.191406  318.484913                0.100407          12.414751            2       True         17
# 4    NeuralNetFastAI_BAG_L2   0.800789    accuracy       4.350373  335.360449                0.259374          29.290288            2       True         23
# 5   RandomForestEntr_BAG_L2   0.800789    accuracy       4.558278  308.108635                0.467280           2.038474            2       True         19
# 6      CatBoost_r177_BAG_L1   0.799417    accuracy       0.300665   15.593118                0.300665          15.593118            1       True         14
# 7       WeightedEnsemble_L2   0.799417    accuracy       0.302672   16.026477                0.002008           0.433358            2       True         15
# 8           CatBoost_BAG_L1   0.797874    accuracy       0.274696   86.472072                0.274696          86.472072            1       True          7
# 9   RandomForestGini_BAG_L2   0.796674    accuracy       4.588991  307.594653                0.497993           1.524491            2       True         18
# 10    ExtraTreesEntr_BAG_L2   0.796160    accuracy       4.700614  307.638859                0.609616           1.568697            2       True         22
# 11    ExtraTreesGini_BAG_L2   0.795817    accuracy       4.584665  307.833184                0.493667           1.763023            2       True         21
# 12        LightGBMXT_BAG_L1   0.795303    accuracy       0.143198   10.589120                0.143198          10.589120            1       True          3
# 13   NeuralNetFastAI_BAG_L1   0.792388    accuracy       0.290427   40.152251                0.290427          40.152251            1       True         10
# 14          LightGBM_BAG_L1   0.789817    accuracy       0.103008    5.550142                0.103008           5.550142            1       True          4
# 15           XGBoost_BAG_L1   0.789645    accuracy       0.486699    9.537416                0.486699           9.537416            1       True         11
# 16    NeuralNetTorch_BAG_L1   0.788788    accuracy       0.197456  121.280946                0.197456         121.280946            1       True         12
# 17     LightGBMLarge_BAG_L1   0.787074    accuracy       0.105324   10.640847                0.105324          10.640847            1       True         13
# 18  RandomForestGini_BAG_L1   0.777130    accuracy       0.392728    1.360018                0.392728           1.360018            1       True          5
# 19  RandomForestEntr_BAG_L1   0.772158    accuracy       0.453597    1.412603                0.453597           1.412603            1       True          6
# 20    ExtraTreesGini_BAG_L1   0.766158    accuracy       0.519539    1.624759                0.519539           1.624759            1       True          8
# 21    ExtraTreesEntr_BAG_L1   0.764101    accuracy       0.575653    1.836291                0.575653           1.836291            1       True          9
# 22    KNeighborsUnif_BAG_L1   0.716612    accuracy       0.100799    0.011306                0.100799           0.011306            1       True          1
# 23    KNeighborsDist_BAG_L1   0.710098    accuracy       0.147210    0.009272                0.147210           0.009272            1       True          2
# Number of models trained: 24
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7166123778501629,
#   'KNeighborsDist_BAG_L1': 0.7100977198697068,
#   'LightGBMXT_BAG_L1': 0.7953025887193554,
#   'LightGBM_BAG_L1': 0.7898165609463398,
#   'RandomForestGini_BAG_L1': 0.7771301217212412,
#   'RandomForestEntr_BAG_L1': 0.7721584090519458,
#   'CatBoost_BAG_L1': 0.7978741642379564,
#   'ExtraTreesGini_BAG_L1': 0.76615806617521,
#   'ExtraTreesEntr_BAG_L1': 0.7641008057603291,
#   'NeuralNetFastAI_BAG_L1': 0.7923881364649409,
#   'XGBoost_BAG_L1': 0.789645122578433,
#   'NeuralNetTorch_BAG_L1': 0.7887879307388994,
#   'LightGBMLarge_BAG_L1': 0.787073547059832,
#   'CatBoost_r177_BAG_L1': 0.799417109549117,
#   'WeightedEnsemble_L2': 0.799417109549117,
#   'LightGBMXT_BAG_L2': 0.8050745756900395,
#   'LightGBM_BAG_L2': 0.8043888222184125,
#   'RandomForestGini_BAG_L2': 0.7966740956626093,
#   'RandomForestEntr_BAG_L2': 0.800788616492371,
#   'CatBoost_BAG_L2': 0.8057603291616664,
#   'ExtraTreesGini_BAG_L2': 0.7958169038230756,
#   'ExtraTreesEntr_BAG_L2': 0.796159780558889,
#   'NeuralNetFastAI_BAG_L2': 0.800788616492371,
#   'WeightedEnsemble_L3': 0.8057603291616664},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.011306285858154297,
#   'KNeighborsDist_BAG_L1': 0.009271621704101562,
#   'LightGBMXT_BAG_L1': 10.589119672775269,
#   'LightGBM_BAG_L1': 5.55014181137085,
#   'RandomForestGini_BAG_L1': 1.360018014907837,
#   'RandomForestEntr_BAG_L1': 1.4126031398773193,
#   'CatBoost_BAG_L1': 86.47207164764404,
#   'ExtraTreesGini_BAG_L1': 1.6247589588165283,
#   'ExtraTreesEntr_BAG_L1': 1.8362913131713867,
#   'NeuralNetFastAI_BAG_L1': 40.15225100517273,
#   'XGBoost_BAG_L1': 9.537416458129883,
#   'NeuralNetTorch_BAG_L1': 121.28094601631165,
#   'LightGBMLarge_BAG_L1': 10.640847206115723,
#   'CatBoost_r177_BAG_L1': 15.59311842918396,
#   'WeightedEnsemble_L2': 0.43335819244384766,
#   'LightGBMXT_BAG_L2': 10.416106939315796,
#   'LightGBM_BAG_L2': 12.414751052856445,
#   'RandomForestGini_BAG_L2': 1.524491310119629,
#   'RandomForestEntr_BAG_L2': 2.038473606109619,
#   'CatBoost_BAG_L2': 88.43667650222778,
#   'ExtraTreesGini_BAG_L2': 1.7630226612091064,
#   'ExtraTreesEntr_BAG_L2': 1.568697214126587,
#   'NeuralNetFastAI_BAG_L2': 29.290287733078003,
#   'WeightedEnsemble_L3': 0.5332632064819336},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.1007993221282959,
#   'KNeighborsDist_BAG_L1': 0.14721012115478516,
#   'LightGBMXT_BAG_L1': 0.14319849014282227,
#   'LightGBM_BAG_L1': 0.10300803184509277,
#   'RandomForestGini_BAG_L1': 0.3927278518676758,
#   'RandomForestEntr_BAG_L1': 0.4535965919494629,
#   'CatBoost_BAG_L1': 0.27469563484191895,
#   'ExtraTreesGini_BAG_L1': 0.5195386409759521,
#   'ExtraTreesEntr_BAG_L1': 0.5756528377532959,
#   'NeuralNetFastAI_BAG_L1': 0.29042696952819824,
#   'XGBoost_BAG_L1': 0.48669910430908203,
#   'NeuralNetTorch_BAG_L1': 0.19745635986328125,
#   'LightGBMLarge_BAG_L1': 0.10532355308532715,
#   'CatBoost_r177_BAG_L1': 0.30066466331481934,
#   'WeightedEnsemble_L2': 0.002007722854614258,
#   'LightGBMXT_BAG_L2': 0.18429827690124512,
#   'LightGBM_BAG_L2': 0.10040736198425293,
#   'RandomForestGini_BAG_L2': 0.49799299240112305,
#   'RandomForestEntr_BAG_L2': 0.46727991104125977,
#   'CatBoost_BAG_L2': 0.14403367042541504,
#   'ExtraTreesGini_BAG_L2': 0.4936668872833252,
#   'ExtraTreesEntr_BAG_L2': 0.6096158027648926,
#   'NeuralNetFastAI_BAG_L2': 0.25937438011169434,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0       WeightedEnsemble_L3   0.805760    accuracy       4.235032  395.040101
#  1           CatBoost_BAG_L2   0.805760    accuracy       4.235032  394.506838
#  2         LightGBMXT_BAG_L2   0.805075    accuracy       4.275296  316.486269
#  3           LightGBM_BAG_L2   0.804389    accuracy       4.191406  318.484913
#  4    NeuralNetFastAI_BAG_L2   0.800789    accuracy       4.350373  335.360449
#  5   RandomForestEntr_BAG_L2   0.800789    accuracy       4.558278  308.108635
#  6      CatBoost_r177_BAG_L1   0.799417    accuracy       0.300665   15.593118
#  7       WeightedEnsemble_L2   0.799417    accuracy       0.302672   16.026477
#  8           CatBoost_BAG_L1   0.797874    accuracy       0.274696   86.472072
#  9   RandomForestGini_BAG_L2   0.796674    accuracy       4.588991  307.594653
#  10    ExtraTreesEntr_BAG_L2   0.796160    accuracy       4.700614  307.638859
#  11    ExtraTreesGini_BAG_L2   0.795817    accuracy       4.584665  307.833184
#  12        LightGBMXT_BAG_L1   0.795303    accuracy       0.143198   10.589120
#  13   NeuralNetFastAI_BAG_L1   0.792388    accuracy       0.290427   40.152251
#  14          LightGBM_BAG_L1   0.789817    accuracy       0.103008    5.550142
#  15           XGBoost_BAG_L1   0.789645    accuracy       0.486699    9.537416
#  16    NeuralNetTorch_BAG_L1   0.788788    accuracy       0.197456  121.280946
#  17     LightGBMLarge_BAG_L1   0.787074    accuracy       0.105324   10.640847
#  18  RandomForestGini_BAG_L1   0.777130    accuracy       0.392728    1.360018
#  19  RandomForestEntr_BAG_L1   0.772158    accuracy       0.453597    1.412603
#  20    ExtraTreesGini_BAG_L1   0.766158    accuracy       0.519539    1.624759
#  21    ExtraTreesEntr_BAG_L1   0.764101    accuracy       0.575653    1.836291
#  22    KNeighborsUnif_BAG_L1   0.716612    accuracy       0.100799    0.011306
#  23    KNeighborsDist_BAG_L1   0.710098    accuracy       0.147210    0.009272
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.533263            3       True
#  1                 0.144034          88.436677            2       True
#  2                 0.184298          10.416107            2       True
#  3                 0.100407          12.414751            2       True
#  4                 0.259374          29.290288            2       True
#  5                 0.467280           2.038474            2       True
#  6                 0.300665          15.593118            1       True
#  7                 0.002008           0.433358            2       True
#  8                 0.274696          86.472072            1       True
#  9                 0.497993           1.524491            2       True
#  10                0.609616           1.568697            2       True
#  11                0.493667           1.763023            2       True
#  12                0.143198          10.589120            1       True
#  13                0.290427          40.152251            1       True
#  14                0.103008           5.550142            1       True
#  15                0.486699           9.537416            1       True
#  16                0.197456         121.280946            1       True
#  17                0.105324          10.640847            1       True
#  18                0.392728           1.360018            1       True
#  19                0.453597           1.412603            1       True
#  20                0.519539           1.624759            1       True
#  21                0.575653           1.836291            1       True
#  22                0.100799           0.011306            1       True
#  23                0.147210           0.009272            1       True
#
#      fit_order
#  0          24
#  1          20
#  2          16
#  3          17
#  4          23
#  5          19
#  6          14
#  7          15
#  8           7
#  9          18
#  10         22
#  11         21
#  12          3
#  13         10
#  14          4
#  15         11
#  16         12
#  17         13
#  18          5
#  19          6
#  20          8
#  21          9
#  22          1
#  23          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.783234764721008,
#  'balanced_accuracy': 0.7830667212694946,
#  'mcc': 0.5663020088212593,
#  'roc_auc': 0.8643558876874856,
#  'f1': 0.7780994998683864,
#  'precision': 0.7832538420773715,
#  'recall': 0.7730125523012552}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.710098    accuracy
# 1   RandomForestGini_BAG_L1    1.000000   0.777130    accuracy
# 2   RandomForestEntr_BAG_L1    1.000000   0.772158    accuracy
# 3     ExtraTreesGini_BAG_L1    1.000000   0.766158    accuracy
# 4     ExtraTreesEntr_BAG_L1    1.000000   0.764101    accuracy
# 5      LightGBMLarge_BAG_L1    0.909481   0.787074    accuracy
# 6            XGBoost_BAG_L1    0.856849   0.789645    accuracy
# 7           LightGBM_BAG_L1    0.839534   0.789817    accuracy
# 8      CatBoost_r177_BAG_L1    0.838162   0.799417    accuracy
# 9       WeightedEnsemble_L2    0.838162   0.799417    accuracy
# 10    ExtraTreesEntr_BAG_L2    0.830105   0.796160    accuracy
# 11          CatBoost_BAG_L1    0.828562   0.797874    accuracy
# 12          CatBoost_BAG_L2    0.824790   0.805760    accuracy
# 13      WeightedEnsemble_L3    0.824790   0.805760    accuracy
# 14  RandomForestGini_BAG_L2    0.822904   0.796674    accuracy
# 15          LightGBM_BAG_L2    0.822733   0.804389    accuracy
# 16    ExtraTreesGini_BAG_L2    0.821876   0.795817    accuracy
# 17  RandomForestEntr_BAG_L2    0.818618   0.800789    accuracy
# 18        LightGBMXT_BAG_L1    0.818447   0.795303    accuracy
# 19        LightGBMXT_BAG_L2    0.816561   0.805075    accuracy
# 20   NeuralNetFastAI_BAG_L2    0.814504   0.800789    accuracy
# 21   NeuralNetFastAI_BAG_L1    0.810046   0.792388    accuracy
# 22    NeuralNetTorch_BAG_L1    0.804046   0.788788    accuracy
# 23    KNeighborsUnif_BAG_L1    0.798388   0.716612    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.335298       0.147210    0.009272                 0.335298
# 1         0.446737       0.392728    1.360018                 0.446737
# 2         0.453140       0.453597    1.412603                 0.453140
# 3         0.487559       0.519539    1.624759                 0.487559
# 4         0.651844       0.575653    1.836291                 0.651844
# 5         0.348701       0.105324   10.640847                 0.348701
# 6         0.453942       0.486699    9.537416                 0.453942
# 7         0.579894       0.103008    5.550142                 0.579894
# 8         0.216489       0.300665   15.593118                 0.216489
# 9         0.218496       0.302672   16.026477                 0.002007
# 10       12.790833       4.700614  307.638859                 0.182792
# 11        0.346807       0.274696   86.472072                 0.346807
# 12       12.653779       4.235032  394.506838                 0.045738
# 13       12.655787       4.235032  395.040101                 0.002008
# 14       12.797452       4.588991  307.594653                 0.189412
# 15       12.924041       4.191406  318.484913                 0.316001
# 16       12.781985       4.584665  307.833184                 0.173945
# 17       13.266937       4.558278  308.108635                 0.658897
# 18        0.631330       0.143198   10.589120                 0.631330
# 19       13.161095       4.275296  316.486269                 0.553055
# 20       14.327214       4.350373  335.360449                 1.719173
# 21        6.648741       0.290427   40.152251                 6.648741
# 22        0.638484       0.197456  121.280946                 0.638484
# 23        0.369074       0.100799    0.011306                 0.369074
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.147210           0.009272            1       True
# 1                 0.392728           1.360018            1       True
# 2                 0.453597           1.412603            1       True
# 3                 0.519539           1.624759            1       True
# 4                 0.575653           1.836291            1       True
# 5                 0.105324          10.640847            1       True
# 6                 0.486699           9.537416            1       True
# 7                 0.103008           5.550142            1       True
# 8                 0.300665          15.593118            1       True
# 9                 0.002008           0.433358            2       True
# 10                0.609616           1.568697            2       True
# 11                0.274696          86.472072            1       True
# 12                0.144034          88.436677            2       True
# 13                0.000000           0.533263            3       True
# 14                0.497993           1.524491            2       True
# 15                0.100407          12.414751            2       True
# 16                0.493667           1.763023            2       True
# 17                0.467280           2.038474            2       True
# 18                0.143198          10.589120            1       True
# 19                0.184298          10.416107            2       True
# 20                0.259374          29.290288            2       True
# 21                0.290427          40.152251            1       True
# 22                0.197456         121.280946            1       True
# 23                0.100799           0.011306            1       True
#
#     fit_order
# 0           2
# 1           5
# 2           6
# 3           8
# 4           9
# 5          13
# 6          11
# 7           4
# 8          14
# 9          15
# 10         22
# 11          7
# 12         20
# 13         24
# 14         18
# 15         17
# 16         21
# 17         19
# 18          3
# 19         16
# 20         23
# 21         10
# 22         12
# 23          1

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	255.63s	= Expected runtime (51.13s per shuffle set)
# 	165.91s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# age                   0.17800  0.006603  2.268181e-07  5  0.191596  0.164404
# hypertension          0.05136  0.004288  5.777293e-06  5  0.060189  0.042531
# heart_disease         0.05076  0.003772  3.632383e-06  5  0.058527  0.042993
# bmi                   0.04204  0.003474  5.544436e-06  5  0.049193  0.034887
# work_type             0.03668  0.002512  2.624739e-06  5  0.041853  0.031507
# avg_glucose_level     0.02640  0.003510  3.662855e-05  5  0.033627  0.019173
# gender                0.02292  0.003681  7.718576e-05  5  0.030500  0.015340
# smoking_status        0.01932  0.001895  1.097169e-05  5  0.023222  0.015418
# ever_married          0.01448  0.001895  3.442897e-05  5  0.018382  0.010578
# Residence_type        0.00320  0.001281  2.516441e-03  5  0.005837  0.000563
