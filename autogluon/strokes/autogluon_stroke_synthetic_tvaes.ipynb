# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-tvaes.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/tvaes',
    learner_kwargs = {'positive_class':1}
    )

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 350
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       5.67 GB / 15.71 GB (36.1%)
# Disk Space Avail:   662.25 GB / 933.46 GB (70.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 87s of the 350s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-08 00:49:07,248	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# 		Context path: "AutogluonModels/strokes/synthetic/tvaes\ds_sub_fit\sub_fit_ho"
# (_dystack pid=21868) Running DyStack sub-fit ...
# (_dystack pid=21868) Beginning AutoGluon training ... Time limit = 66s
# (_dystack pid=21868) AutoGluon will save models to "AutogluonModels/strokes/synthetic/tvaes\ds_sub_fit\sub_fit_ho"
# (_dystack pid=21868) Train Data Rows:    5184
# (_dystack pid=21868) Train Data Columns: 10
# (_dystack pid=21868) Label Column:       stroke
# (_dystack pid=21868) Problem Type:       binary
# (_dystack pid=21868) Preprocessing data ...
# (_dystack pid=21868) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=21868) Using Feature Generators to preprocess the data ...
# (_dystack pid=21868) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=21868) 	Available Memory:                    4922.95 MB
# (_dystack pid=21868) 	Train Data (Original)  Memory Usage: 1.77 MB (0.0% of available memory)
# (_dystack pid=21868) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=21868) 	Stage 1 Generators:
# (_dystack pid=21868) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=21868) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=21868) 	Stage 2 Generators:
# (_dystack pid=21868) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=21868) 	Stage 3 Generators:
# (_dystack pid=21868) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=21868) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=21868) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=21868) 	Stage 4 Generators:
# (_dystack pid=21868) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=21868) 	Stage 5 Generators:
# (_dystack pid=21868) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=21868) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=21868) 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=21868) 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# (_dystack pid=21868) 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# (_dystack pid=21868) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=21868) 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# (_dystack pid=21868) 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# (_dystack pid=21868) 		('int', [])       : 1 | ['age']
# (_dystack pid=21868) 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# (_dystack pid=21868) 	0.3s = Fit runtime
# (_dystack pid=21868) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=21868) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=21868) Data preprocessing and feature engineering runtime = 0.37s ...
# (_dystack pid=21868) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=21868) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=21868) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=21868) User-specified model hyperparameters to be fit:
# (_dystack pid=21868) {
# (_dystack pid=21868) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=21868) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=21868) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=21868) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=21868) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=21868) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=21868) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=21868) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=21868) }
# (_dystack pid=21868) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=21868) Fitting 110 L1 models ...
# (_dystack pid=21868) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 44.07s of the 66.09s of remaining time.
# (_dystack pid=21868) 	0.8245	 = Validation score   (accuracy)
# (_dystack pid=21868) 	0.02s	 = Training   runtime
# (_dystack pid=21868) 	0.09s	 = Validation runtime
# (_dystack pid=21868) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 40.52s of the 62.54s of remaining time.
# (_dystack pid=21868) 	0.8183	 = Validation score   (accuracy)
# (_dystack pid=21868) 	0.01s	 = Training   runtime
# (_dystack pid=21868) 	0.08s	 = Validation runtime
# (_dystack pid=21868) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 40.37s of the 62.39s of remaining time.
# (_dystack pid=21868) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# (_dystack pid=21868) 	0.9167	 = Validation score   (accuracy)
# (_dystack pid=21868) 	9.22s	 = Training   runtime
# (_dystack pid=21868) 	0.43s	 = Validation runtime
# (_dystack pid=21868) Fitting model: LightGBM_BAG_L1 ... Training model for up to 19.15s of the 41.17s of remaining time.
# (_dystack pid=21868) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# (_dystack pid=21868) 	0.9178	 = Validation score   (accuracy)
# (_dystack pid=21868) 	9.77s	 = Training   runtime
# (_dystack pid=21868) 	0.19s	 = Validation runtime
# (_dystack pid=21868) Fitting model: WeightedEnsemble_L2 ... Training model for up to 66.12s of the 12.36s of remaining time.
# (_dystack pid=21868) 	Ensemble Weights: {'LightGBM_BAG_L1': 1.0}
# (_dystack pid=21868) 	0.9178	 = Validation score   (accuracy)
# (_dystack pid=21868) 	0.37s	 = Training   runtime
# (_dystack pid=21868) 	0.01s	 = Validation runtime
# (_dystack pid=21868) Fitting 108 L2 models ...
# (_dystack pid=21868) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 11.92s of the 11.84s of remaining time.
# (_dystack pid=21868) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# (_dystack pid=21868) 	0.9194	 = Validation score   (accuracy)
# (_dystack pid=21868) 	8.7s	 = Training   runtime
# (_dystack pid=21868) 	0.31s	 = Validation runtime
# (_dystack pid=21868) Fitting model: WeightedEnsemble_L3 ... Training model for up to 66.12s of the -18.78s of remaining time.
# (_dystack pid=21868) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# (_dystack pid=21868) 	0.9194	 = Validation score   (accuracy)
# (_dystack pid=21868) 	0.19s	 = Training   runtime
# (_dystack pid=21868) 	0.0s	 = Validation runtime
# (_dystack pid=21868) AutoGluon training complete, total runtime = 85.5s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 681.1 rows/s (648 batch size)
# (_dystack pid=21868) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/tvaes\ds_sub_fit\sub_fit_ho")
# (_dystack pid=21868) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                    model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBMXT_BAG_L1       0.924499   0.916667    accuracy        0.825498       0.434095   9.217804                 0.825498                0.434095           9.217804            1       True          3
# 1        LightGBM_BAG_L1       0.916795   0.917824    accuracy        0.527579       0.189265   9.767209                 0.527579                0.189265           9.767209            1       True          4
# 2    WeightedEnsemble_L2       0.916795   0.917824    accuracy        0.559875       0.195666  10.138560                 0.032297                0.006400           0.371351            2       True          5
# 3      LightGBMXT_BAG_L2       0.915254   0.919367    accuracy        1.940228       1.102824  27.709491                 0.418730                0.306169           8.695491            2       True          6
# 4    WeightedEnsemble_L3       0.915254   0.919367    accuracy        1.974581       1.104835  27.895989                 0.034353                0.002011           0.186498            3       True          7
# 5  KNeighborsUnif_BAG_L1       0.812018   0.824460    accuracy        0.079527       0.089960   0.016400                 0.079527                0.089960           0.016400            1       True          1
# 6  KNeighborsDist_BAG_L1       0.804314   0.818287    accuracy        0.088893       0.083335   0.012589                 0.088893                0.083335           0.012589            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	116s	 = DyStack   runtime |	234s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 234s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/tvaes"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4426.76 MB
# 	Train Data (Original)  Memory Usage: 1.99 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.2s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.28s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 234.1s of the 234.02s of remaining time.
# 	0.8215	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 224.92s of the 224.84s of remaining time.
# 	0.8155	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 224.77s of the 224.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.9217	 = Validation score   (accuracy)
# 	15.85s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 185.56s of the 185.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.9203	 = Validation score   (accuracy)
# 	10.94s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 164.75s of the 164.67s of remaining time.
# 	0.9103	 = Validation score   (accuracy)
# 	2.61s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 161.7s of the 161.63s of remaining time.
# 	0.9095	 = Validation score   (accuracy)
# 	1.84s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 159.39s of the 159.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.11%)
# 	0.9198	 = Validation score   (accuracy)
# 	94.64s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 54.74s of the 54.66s of remaining time.
# 	0.9071	 = Validation score   (accuracy)
# 	1.79s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 52.36s of the 52.29s of remaining time.
# 	0.9062	 = Validation score   (accuracy)
# 	1.43s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 50.46s of the 50.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# 	0.9211	 = Validation score   (accuracy)
# 	59.06s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 234.11s of the -19.07s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	0.9217	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 254.46s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1666.6 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/tvaes")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L2   0.921653    accuracy       0.438014  16.704042                0.000000           0.858314            2       True         11
# 1         LightGBMXT_BAG_L1   0.921653    accuracy       0.438014  15.845728                0.438014          15.845728            1       True          3
# 2    NeuralNetFastAI_BAG_L1   0.921138    accuracy       0.730428  59.057975                0.730428          59.057975            1       True         10
# 3           LightGBM_BAG_L1   0.920281    accuracy       0.212258  10.940136                0.212258          10.940136            1       True          4
# 4           CatBoost_BAG_L1   0.919767    accuracy       0.114933  94.644258                0.114933          94.644258            1       True          7
# 5   RandomForestGini_BAG_L1   0.910338    accuracy       0.310573   2.606370                0.310573           2.606370            1       True          5
# 6   RandomForestEntr_BAG_L1   0.909481    accuracy       0.360063   1.835466                0.360063           1.835466            1       True          6
# 7     ExtraTreesGini_BAG_L1   0.907080    accuracy       0.434293   1.792452                0.434293           1.792452            1       True          8
# 8     ExtraTreesEntr_BAG_L1   0.906223    accuracy       0.343642   1.430076                0.343642           1.430076            1       True          9
# 9     KNeighborsUnif_BAG_L1   0.821533    accuracy       0.122238   0.015793                0.122238           0.015793            1       True          1
# 10    KNeighborsDist_BAG_L1   0.815532    accuracy       0.071277   0.012658                0.071277           0.012658            1       True          2
# Number of models trained: 11
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.8215326590090862,
#   'KNeighborsDist_BAG_L1': 0.8155323161323504,
#   'LightGBMXT_BAG_L1': 0.921652665866621,
#   'LightGBM_BAG_L1': 0.920281158923367,
#   'RandomForestGini_BAG_L1': 0.9103377335847763,
#   'RandomForestEntr_BAG_L1': 0.9094805417452426,
#   'CatBoost_BAG_L1': 0.9197668438196468,
#   'ExtraTreesGini_BAG_L1': 0.9070804045945483,
#   'ExtraTreesEntr_BAG_L1': 0.9062232127550146,
#   'NeuralNetFastAI_BAG_L1': 0.9211383507629007,
#   'WeightedEnsemble_L2': 0.921652665866621},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0157928466796875,
#   'KNeighborsDist_BAG_L1': 0.012657642364501953,
#   'LightGBMXT_BAG_L1': 15.845728158950806,
#   'LightGBM_BAG_L1': 10.940136194229126,
#   'RandomForestGini_BAG_L1': 2.606370210647583,
#   'RandomForestEntr_BAG_L1': 1.835465669631958,
#   'CatBoost_BAG_L1': 94.64425802230835,
#   'ExtraTreesGini_BAG_L1': 1.7924518585205078,
#   'ExtraTreesEntr_BAG_L1': 1.4300763607025146,
#   'NeuralNetFastAI_BAG_L1': 59.05797457695007,
#   'WeightedEnsemble_L2': 0.8583135604858398},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.1222379207611084,
#   'KNeighborsDist_BAG_L1': 0.07127737998962402,
#   'LightGBMXT_BAG_L1': 0.43801379203796387,
#   'LightGBM_BAG_L1': 0.21225810050964355,
#   'RandomForestGini_BAG_L1': 0.31057286262512207,
#   'RandomForestEntr_BAG_L1': 0.3600625991821289,
#   'CatBoost_BAG_L1': 0.11493349075317383,
#   'ExtraTreesGini_BAG_L1': 0.4342925548553467,
#   'ExtraTreesEntr_BAG_L1': 0.3436417579650879,
#   'NeuralNetFastAI_BAG_L1': 0.7304282188415527,
#   'WeightedEnsemble_L2': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val   fit_time  \
#  0       WeightedEnsemble_L2   0.921653    accuracy       0.438014  16.704042
#  1         LightGBMXT_BAG_L1   0.921653    accuracy       0.438014  15.845728
#  2    NeuralNetFastAI_BAG_L1   0.921138    accuracy       0.730428  59.057975
#  3           LightGBM_BAG_L1   0.920281    accuracy       0.212258  10.940136
#  4           CatBoost_BAG_L1   0.919767    accuracy       0.114933  94.644258
#  5   RandomForestGini_BAG_L1   0.910338    accuracy       0.310573   2.606370
#  6   RandomForestEntr_BAG_L1   0.909481    accuracy       0.360063   1.835466
#  7     ExtraTreesGini_BAG_L1   0.907080    accuracy       0.434293   1.792452
#  8     ExtraTreesEntr_BAG_L1   0.906223    accuracy       0.343642   1.430076
#  9     KNeighborsUnif_BAG_L1   0.821533    accuracy       0.122238   0.015793
#  10    KNeighborsDist_BAG_L1   0.815532    accuracy       0.071277   0.012658
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.858314            2       True
#  1                 0.438014          15.845728            1       True
#  2                 0.730428          59.057975            1       True
#  3                 0.212258          10.940136            1       True
#  4                 0.114933          94.644258            1       True
#  5                 0.310573           2.606370            1       True
#  6                 0.360063           1.835466            1       True
#  7                 0.434293           1.792452            1       True
#  8                 0.343642           1.430076            1       True
#  9                 0.122238           0.015793            1       True
#  10                0.071277           0.012658            1       True
#
#      fit_order
#  0          11
#  1           3
#  2          10
#  3           4
#  4           7
#  5           5
#  6           6
#  7           8
#  8           9
#  9           1
#  10          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.9107739778863461,
#  'balanced_accuracy': 0.9106329748170912,
#  'mcc': 0.8215359255131873,
#  'roc_auc': 0.9720057332969315,
#  'f1': 0.9086120621543323,
#  'precision': 0.9151193633952255,
#  'recall': 0.9021966527196653}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     ExtraTreesGini_BAG_L1    1.000000   0.907080    accuracy
# 1     ExtraTreesEntr_BAG_L1    1.000000   0.906223    accuracy
# 2     KNeighborsDist_BAG_L1    1.000000   0.815532    accuracy
# 3   RandomForestEntr_BAG_L1    1.000000   0.909481    accuracy
# 4   RandomForestGini_BAG_L1    1.000000   0.910338    accuracy
# 5           LightGBM_BAG_L1    0.965027   0.920281    accuracy
# 6       WeightedEnsemble_L2    0.947711   0.921653    accuracy
# 7         LightGBMXT_BAG_L1    0.947711   0.921653    accuracy
# 8    NeuralNetFastAI_BAG_L1    0.929539   0.921138    accuracy
# 9           CatBoost_BAG_L1    0.927824   0.919767    accuracy
# 10    KNeighborsUnif_BAG_L1    0.867478   0.821533    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.215098       0.434293   1.792452                 0.215098
# 1         0.241144       0.343642   1.430076                 0.241144
# 2         0.245850       0.071277   0.012658                 0.245850
# 3         0.269598       0.360063   1.835466                 0.269598
# 4         0.339155       0.310573   2.606370                 0.339155
# 5         0.705587       0.212258  10.940136                 0.705587
# 6         0.793147       0.438014  16.704042                 0.000000
# 7         0.793147       0.438014  15.845728                 0.793147
# 8         3.639561       0.730428  59.057975                 3.639561
# 9         0.373879       0.114933  94.644258                 0.373879
# 10        0.143187       0.122238   0.015793                 0.143187
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.434293           1.792452            1       True
# 1                 0.343642           1.430076            1       True
# 2                 0.071277           0.012658            1       True
# 3                 0.360063           1.835466            1       True
# 4                 0.310573           2.606370            1       True
# 5                 0.212258          10.940136            1       True
# 6                 0.000000           0.858314            2       True
# 7                 0.438014          15.845728            1       True
# 8                 0.730428          59.057975            1       True
# 9                 0.114933          94.644258            1       True
# 10                0.122238           0.015793            1       True
#
#     fit_order
# 0           8
# 1           9
# 2           2
# 3           6
# 4           5
# 5           4
# 6          11
# 7           3
# 8          10
# 9           7
# 10          1

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	54.97s	= Expected runtime (10.99s per shuffle set)
# 	31.78s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# heart_disease         0.13132  0.004516  1.675301e-07  5  0.140618  0.122022
# age                   0.06668  0.002841  3.945578e-07  5  0.072530  0.060830
# hypertension          0.04700  0.002421  8.414930e-07  5  0.051984  0.042016
# bmi                   0.04408  0.002344  9.550828e-07  5  0.048905  0.039255
# smoking_status        0.04084  0.002142  9.046779e-07  5  0.045250  0.036430
# avg_glucose_level     0.03232  0.001853  1.289705e-06  5  0.036134  0.028506
# work_type             0.02636  0.001081  3.383082e-07  5  0.028585  0.024135
# Residence_type        0.01656  0.001244  3.795074e-06  5  0.019122  0.013998
# gender                0.01392  0.001932  4.339465e-05  5  0.017898  0.009942
# ever_married          0.01004  0.001479  5.493832e-05  5  0.013086  0.006994
