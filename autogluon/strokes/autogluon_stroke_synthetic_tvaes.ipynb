# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-tvaes.csv')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1  Female   61             0              0          Yes  Self-employed
# 2    Male   80             0              1          Yes        Private
# 3  Female   49             0              0          Yes        Private
# 4  Female   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df,test_size=0.4, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5833, 11), (3889, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/synthetic/tvaes',
    learner_kwargs = {'positive_class':1}
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/strokes/synthetic/tvaes"

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    time_limit = 900
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       3.96 GB / 15.94 GB (24.8%)
# Disk Space Avail:   117.52 GB / 446.36 GB (26.3%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 		Context path: "AutogluonModels/strokes/synthetic/tvaes\ds_sub_fit\sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBMXT_BAG_L1       0.924499   0.916667    accuracy        0.887306       0.221330    6.545300                 0.887306                0.221330           6.545300            1       True          3
# 1   RandomForestGini_BAG_L2       0.924499   0.917052    accuracy        5.053842       1.633221  112.999419                 0.465078                0.337630           1.304095            2       True         11
# 2           CatBoost_BAG_L1       0.922958   0.916474    accuracy        2.653970       0.115566   91.396595                 2.653970                0.115566          91.396595            1       True          7
# 3         LightGBMXT_BAG_L2       0.921418   0.920718    accuracy        4.945426       1.418473  117.727216                 0.356662                0.122881           6.031892            2       True          9
# 4           LightGBM_BAG_L2       0.919877   0.922840    accuracy        5.090324       1.392892  118.160104                 0.501561                0.097301           6.464780            2       True         10
# 5       WeightedEnsemble_L3       0.919877   0.922840    accuracy        5.105723       1.394517  118.510469                 0.015399                0.001625           0.350365            3       True         13
# 6   RandomForestEntr_BAG_L2       0.918336   0.917631    accuracy        5.056149       1.625130  112.957321                 0.467386                0.329539           1.261997            2       True         12
# 7           LightGBM_BAG_L1       0.916795   0.917824    accuracy        0.312048       0.089764   10.210681                 0.312048                0.089764          10.210681            1       True          4
# 8       WeightedEnsemble_L2       0.916795   0.917824    accuracy        0.337986       0.091765   10.461554                 0.025938                0.002001           0.250873            2       True          8
# 9   RandomForestGini_BAG_L1       0.915254   0.909336    accuracy        0.256073       0.323311    1.780049                 0.256073                0.323311           1.780049            1       True          5
# 10  RandomForestEntr_BAG_L1       0.912173   0.907793    accuracy        0.248053       0.341409    1.743727                 0.248053                0.341409           1.743727            1       True          6
# 11    KNeighborsUnif_BAG_L1       0.812018   0.824460    accuracy        0.131309       0.131015    0.010937                 0.131309                0.131015           0.010937            1       True          1
# 12    KNeighborsDist_BAG_L1       0.804314   0.818287    accuracy        0.100003       0.073196    0.008034                 0.100003                0.073196           0.008034            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	257s	 = DyStack   runtime |	643s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 643s
# AutoGluon will save models to "AutogluonModels/strokes/synthetic/tvaes"
# Train Data Rows:    5833
# Train Data Columns: 10
# Label Column:       stroke
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6116.85 MB
# 	Train Data (Original)  Memory Usage: 1.99 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['age', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# 		('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.2s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 428.17s of the 642.4s of remaining time.
# 	0.8215	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 427.41s of the 641.64s of remaining time.
# 	0.8155	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 427.11s of the 641.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.9217	 = Validation score   (accuracy)
# 	6.07s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 407.29s of the 621.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.9203	 = Validation score   (accuracy)
# 	11.44s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 350.59s of the 564.82s of remaining time.
# 	0.9103	 = Validation score   (accuracy)
# 	1.38s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 348.23s of the 562.46s of remaining time.
# 	0.9095	 = Validation score   (accuracy)
# 	1.25s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 345.86s of the 560.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.9198	 = Validation score   (accuracy)
# 	87.0s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 229.79s of the 444.01s of remaining time.
# 	0.9071	 = Validation score   (accuracy)
# 	1.94s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 226.99s of the 441.21s of remaining time.
# 	0.9062	 = Validation score   (accuracy)
# 	2.01s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 223.96s of the 438.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.9213	 = Validation score   (accuracy)
# 	38.64s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 165.09s of the 379.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.9205	 = Validation score   (accuracy)
# 	3.29s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 134.69s of the 348.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9232	 = Validation score   (accuracy)
# 	92.77s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 13.15s of the 227.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9148	 = Validation score   (accuracy)
# 	7.46s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 205.83s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_BAG_L1': 0.667, 'LightGBM_BAG_L1': 0.111, 'CatBoost_BAG_L1': 0.111, 'NeuralNetFastAI_BAG_L1': 0.111}
# 	0.9246	 = Validation score   (accuracy)
# 	0.42s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 205.38s of the 205.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.9258	 = Validation score   (accuracy)
# 	5.17s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 185.9s of the 185.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.9292	 = Validation score   (accuracy)
# 	7.74s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 165.38s of the 165.26s of remaining time.
# 	0.9242	 = Validation score   (accuracy)
# 	1.63s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 163.15s of the 163.03s of remaining time.
# 	0.9253	 = Validation score   (accuracy)
# 	1.6s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 161.04s of the 160.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.9304	 = Validation score   (accuracy)
# 	107.58s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 31.06s of the 30.94s of remaining time.
# 	0.9223	 = Validation score   (accuracy)
# 	1.63s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 28.82s of the 28.69s of remaining time.
# 	0.9235	 = Validation score   (accuracy)
# 	1.86s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 26.28s of the 26.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.9271	 = Validation score   (accuracy)
# 	41.19s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -36.0s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# 	0.9304	 = Validation score   (accuracy)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 679.33s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 360.0 rows/s (730 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/strokes/synthetic/tvaes")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_BAG_L2   0.930396    accuracy       4.379873  360.870367                0.189133         107.584434            2       True         19
# 1       WeightedEnsemble_L3   0.930396    accuracy       4.381881  361.524220                0.002008           0.653853            3       True         23
# 2           LightGBM_BAG_L2   0.929196    accuracy       4.287360  261.023348                0.096620           7.737415            2       True         16
# 3    NeuralNetFastAI_BAG_L2   0.927139    accuracy       4.540671  294.480728                0.349931          41.194796            2       True         22
# 4         LightGBMXT_BAG_L2   0.925767    accuracy       4.297746  258.458261                0.107006           5.172328            2       True         15
# 5   RandomForestEntr_BAG_L2   0.925253    accuracy       4.617476  254.889429                0.426736           1.603497            2       True         18
# 6       WeightedEnsemble_L2   0.924567    accuracy       1.013778  230.265186                0.002012           0.416558            2       True         14
# 7   RandomForestGini_BAG_L2   0.924224    accuracy       4.682751  254.915147                0.492011           1.629215            2       True         17
# 8     ExtraTreesEntr_BAG_L2   0.923538    accuracy       4.724099  255.144968                0.533359           1.859035            2       True         21
# 9     NeuralNetTorch_BAG_L1   0.923196    accuracy       0.285090   92.773110                0.285090          92.773110            1       True         12
# 10    ExtraTreesGini_BAG_L2   0.922338    accuracy       4.681434  254.914228                0.490694           1.628295            2       True         20
# 11        LightGBMXT_BAG_L1   0.921653    accuracy       0.226432    6.073853                0.226432           6.073853            1       True          3
# 12   NeuralNetFastAI_BAG_L1   0.921310    accuracy       0.344442   38.641588                0.344442          38.641588            1       True         10
# 13           XGBoost_BAG_L1   0.920453    accuracy       0.111394    3.289947                0.111394           3.289947            1       True         11
# 14          LightGBM_BAG_L1   0.920281    accuracy       0.156677   11.437438                0.156677          11.437438            1       True          4
# 15          CatBoost_BAG_L1   0.919767    accuracy       0.225558   86.996493                0.225558          86.996493            1       True          7
# 16     LightGBMLarge_BAG_L1   0.914795    accuracy       0.152054    7.457189                0.152054           7.457189            1       True         13
# 17  RandomForestGini_BAG_L1   0.910338    accuracy       0.383769    1.379496                0.383769           1.379496            1       True          5
# 18  RandomForestEntr_BAG_L1   0.909481    accuracy       0.329140    1.253065                0.329140           1.253065            1       True          6
# 19    ExtraTreesGini_BAG_L1   0.907080    accuracy       0.654035    1.942020                0.654035           1.942020            1       True          8
# 20    ExtraTreesEntr_BAG_L1   0.906223    accuracy       0.664323    2.006908                0.664323           2.006908            1       True          9
# 21    KNeighborsUnif_BAG_L1   0.821533    accuracy       0.388118    0.023827                0.388118           0.023827            1       True          1
# 22    KNeighborsDist_BAG_L1   0.815532    accuracy       0.269709    0.011000                0.269709           0.011000            1       True          2
# Number of models trained: 23
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['gender', 'work_type', 'smoking_status']
# ('float', [])     : 2 | ['avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['age']
# ('int', ['bool']) : 4 | ['hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.8215326590090862,
#   'KNeighborsDist_BAG_L1': 0.8155323161323504,
#   'LightGBMXT_BAG_L1': 0.921652665866621,
#   'LightGBM_BAG_L1': 0.920281158923367,
#   'RandomForestGini_BAG_L1': 0.9103377335847763,
#   'RandomForestEntr_BAG_L1': 0.9094805417452426,
#   'CatBoost_BAG_L1': 0.9197668438196468,
#   'ExtraTreesGini_BAG_L1': 0.9070804045945483,
#   'ExtraTreesEntr_BAG_L1': 0.9062232127550146,
#   'NeuralNetFastAI_BAG_L1': 0.9213097891308075,
#   'XGBoost_BAG_L1': 0.9204525972912738,
#   'NeuralNetTorch_BAG_L1': 0.9231956111777816,
#   'LightGBMLarge_BAG_L1': 0.9147951311503515,
#   'WeightedEnsemble_L2': 0.9245671181210355,
#   'LightGBMXT_BAG_L2': 0.9257671866963827,
#   'LightGBM_BAG_L2': 0.9291959540545174,
#   'RandomForestGini_BAG_L2': 0.924224241385222,
#   'RandomForestEntr_BAG_L2': 0.9252528715926625,
#   'CatBoost_BAG_L2': 0.9303960226298645,
#   'ExtraTreesGini_BAG_L2': 0.9223384193382479,
#   'ExtraTreesEntr_BAG_L2': 0.923538487913595,
#   'NeuralNetFastAI_BAG_L2': 0.9271386936396365,
#   'WeightedEnsemble_L3': 0.9303960226298645},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.02382683753967285,
#   'KNeighborsDist_BAG_L1': 0.010999679565429688,
#   'LightGBMXT_BAG_L1': 6.073853015899658,
#   'LightGBM_BAG_L1': 11.437437534332275,
#   'RandomForestGini_BAG_L1': 1.3794958591461182,
#   'RandomForestEntr_BAG_L1': 1.2530653476715088,
#   'CatBoost_BAG_L1': 86.99649286270142,
#   'ExtraTreesGini_BAG_L1': 1.9420199394226074,
#   'ExtraTreesEntr_BAG_L1': 2.0069079399108887,
#   'NeuralNetFastAI_BAG_L1': 38.64158797264099,
#   'XGBoost_BAG_L1': 3.2899465560913086,
#   'NeuralNetTorch_BAG_L1': 92.77310991287231,
#   'LightGBMLarge_BAG_L1': 7.457189321517944,
#   'WeightedEnsemble_L2': 0.41655802726745605,
#   'LightGBMXT_BAG_L2': 5.172327995300293,
#   'LightGBM_BAG_L2': 7.737414836883545,
#   'RandomForestGini_BAG_L2': 1.6292145252227783,
#   'RandomForestEntr_BAG_L2': 1.6034965515136719,
#   'CatBoost_BAG_L2': 107.58443403244019,
#   'ExtraTreesGini_BAG_L2': 1.6282949447631836,
#   'ExtraTreesEntr_BAG_L2': 1.8590350151062012,
#   'NeuralNetFastAI_BAG_L2': 41.19479560852051,
#   'WeightedEnsemble_L3': 0.6538534164428711},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.38811802864074707,
#   'KNeighborsDist_BAG_L1': 0.26970934867858887,
#   'LightGBMXT_BAG_L1': 0.22643184661865234,
#   'LightGBM_BAG_L1': 0.1566767692565918,
#   'RandomForestGini_BAG_L1': 0.38376927375793457,
#   'RandomForestEntr_BAG_L1': 0.32913970947265625,
#   'CatBoost_BAG_L1': 0.22555804252624512,
#   'ExtraTreesGini_BAG_L1': 0.6540353298187256,
#   'ExtraTreesEntr_BAG_L1': 0.6643226146697998,
#   'NeuralNetFastAI_BAG_L1': 0.34444212913513184,
#   'XGBoost_BAG_L1': 0.11139369010925293,
#   'NeuralNetTorch_BAG_L1': 0.28508973121643066,
#   'LightGBMLarge_BAG_L1': 0.1520535945892334,
#   'WeightedEnsemble_L2': 0.002011537551879883,
#   'LightGBMXT_BAG_L2': 0.10700583457946777,
#   'LightGBM_BAG_L2': 0.09662008285522461,
#   'RandomForestGini_BAG_L2': 0.49201059341430664,
#   'RandomForestEntr_BAG_L2': 0.42673587799072266,
#   'CatBoost_BAG_L2': 0.1891326904296875,
#   'ExtraTreesGini_BAG_L2': 0.4906940460205078,
#   'ExtraTreesEntr_BAG_L2': 0.5333592891693115,
#   'NeuralNetFastAI_BAG_L2': 0.349931001663208,
#   'WeightedEnsemble_L3': 0.002008199691772461},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0           CatBoost_BAG_L2   0.930396    accuracy       4.379873  360.870367
#  1       WeightedEnsemble_L3   0.930396    accuracy       4.381881  361.524220
#  2           LightGBM_BAG_L2   0.929196    accuracy       4.287360  261.023348
#  3    NeuralNetFastAI_BAG_L2   0.927139    accuracy       4.540671  294.480728
#  4         LightGBMXT_BAG_L2   0.925767    accuracy       4.297746  258.458261
#  5   RandomForestEntr_BAG_L2   0.925253    accuracy       4.617476  254.889429
#  6       WeightedEnsemble_L2   0.924567    accuracy       1.013778  230.265186
#  7   RandomForestGini_BAG_L2   0.924224    accuracy       4.682751  254.915147
#  8     ExtraTreesEntr_BAG_L2   0.923538    accuracy       4.724099  255.144968
#  9     NeuralNetTorch_BAG_L1   0.923196    accuracy       0.285090   92.773110
#  10    ExtraTreesGini_BAG_L2   0.922338    accuracy       4.681434  254.914228
#  11        LightGBMXT_BAG_L1   0.921653    accuracy       0.226432    6.073853
#  12   NeuralNetFastAI_BAG_L1   0.921310    accuracy       0.344442   38.641588
#  13           XGBoost_BAG_L1   0.920453    accuracy       0.111394    3.289947
#  14          LightGBM_BAG_L1   0.920281    accuracy       0.156677   11.437438
#  15          CatBoost_BAG_L1   0.919767    accuracy       0.225558   86.996493
#  16     LightGBMLarge_BAG_L1   0.914795    accuracy       0.152054    7.457189
#  17  RandomForestGini_BAG_L1   0.910338    accuracy       0.383769    1.379496
#  18  RandomForestEntr_BAG_L1   0.909481    accuracy       0.329140    1.253065
#  19    ExtraTreesGini_BAG_L1   0.907080    accuracy       0.654035    1.942020
#  20    ExtraTreesEntr_BAG_L1   0.906223    accuracy       0.664323    2.006908
#  21    KNeighborsUnif_BAG_L1   0.821533    accuracy       0.388118    0.023827
#  22    KNeighborsDist_BAG_L1   0.815532    accuracy       0.269709    0.011000
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.189133         107.584434            2       True
#  1                 0.002008           0.653853            3       True
#  2                 0.096620           7.737415            2       True
#  3                 0.349931          41.194796            2       True
#  4                 0.107006           5.172328            2       True
#  5                 0.426736           1.603497            2       True
#  6                 0.002012           0.416558            2       True
#  7                 0.492011           1.629215            2       True
#  8                 0.533359           1.859035            2       True
#  9                 0.285090          92.773110            1       True
#  10                0.490694           1.628295            2       True
#  11                0.226432           6.073853            1       True
#  12                0.344442          38.641588            1       True
#  13                0.111394           3.289947            1       True
#  14                0.156677          11.437438            1       True
#  15                0.225558          86.996493            1       True
#  16                0.152054           7.457189            1       True
#  17                0.383769           1.379496            1       True
#  18                0.329140           1.253065            1       True
#  19                0.654035           1.942020            1       True
#  20                0.664323           2.006908            1       True
#  21                0.388118           0.023827            1       True
#  22                0.269709           0.011000            1       True
#
#      fit_order
#  0          19
#  1          23
#  2          16
#  3          22
#  4          15
#  5          18
#  6          14
#  7          17
#  8          21
#  9          12
#  10         20
#  11          3
#  12         10
#  13         11
#  14          4
#  15          7
#  16         13
#  17          5
#  18          6
#  19          8
#  20          9
#  21          1
#  22          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.913345332990486,
#  'balanced_accuracy': 0.9129815048793342,
#  'mcc': 0.8272086919101839,
#  'roc_auc': 0.9734766234288459,
#  'f1': 0.9100133511348465,
#  'precision': 0.9296235679214403,
#  'recall': 0.891213389121339}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.815532    accuracy
# 1   RandomForestGini_BAG_L1    1.000000   0.910338    accuracy
# 2     ExtraTreesGini_BAG_L1    1.000000   0.907080    accuracy
# 3   RandomForestEntr_BAG_L1    1.000000   0.909481    accuracy
# 4     ExtraTreesEntr_BAG_L1    1.000000   0.906223    accuracy
# 5      LightGBMLarge_BAG_L1    0.992971   0.914795    accuracy
# 6           LightGBM_BAG_L1    0.965027   0.920281    accuracy
# 7            XGBoost_BAG_L1    0.950111   0.920453    accuracy
# 8         LightGBMXT_BAG_L1    0.947711   0.921653    accuracy
# 9         LightGBMXT_BAG_L2    0.939482   0.925767    accuracy
# 10      WeightedEnsemble_L2    0.939139   0.924567    accuracy
# 11    NeuralNetTorch_BAG_L1    0.936568   0.923196    accuracy
# 12    ExtraTreesGini_BAG_L2    0.935025   0.922338    accuracy
# 13    ExtraTreesEntr_BAG_L2    0.932282   0.923538    accuracy
# 14   NeuralNetFastAI_BAG_L1    0.930739   0.921310    accuracy
# 15          CatBoost_BAG_L2    0.929025   0.930396    accuracy
# 16      WeightedEnsemble_L3    0.929025   0.930396    accuracy
# 17   NeuralNetFastAI_BAG_L2    0.928339   0.927139    accuracy
# 18          CatBoost_BAG_L1    0.927824   0.919767    accuracy
# 19  RandomForestEntr_BAG_L2    0.926110   0.925253    accuracy
# 20          LightGBM_BAG_L2    0.925081   0.929196    accuracy
# 21  RandomForestGini_BAG_L2    0.924739   0.924224    accuracy
# 22    KNeighborsUnif_BAG_L1    0.867478   0.821533    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.075982       0.269709    0.011000                 0.075982
# 1         0.171080       0.383769    1.379496                 0.171080
# 2         0.191578       0.654035    1.942020                 0.191578
# 3         0.195623       0.329140    1.253065                 0.195623
# 4         0.288993       0.664323    2.006908                 0.288993
# 5         0.379035       0.152054    7.457189                 0.379035
# 6         0.270595       0.156677   11.437438                 0.270595
# 7         0.379371       0.111394    3.289947                 0.379371
# 8         0.438813       0.226432    6.073853                 0.438813
# 9         6.273701       4.297746  258.458261                 0.404838
# 10        3.680598       1.013778  230.265186                 0.002005
# 11        0.703032       0.285090   92.773110                 0.703032
# 12        6.090001       4.681434  254.914228                 0.221138
# 13        6.058403       4.724099  255.144968                 0.189540
# 14        2.606451       0.344442   38.641588                 2.606451
# 15        5.983497       4.379873  360.870367                 0.114634
# 16        5.985504       4.381881  361.524220                 0.002007
# 17        7.808772       4.540671  294.480728                 1.939909
# 18        0.098516       0.225558   86.996493                 0.098516
# 19        6.047590       4.617476  254.889429                 0.178727
# 20        6.232111       4.287360  261.023348                 0.363248
# 21        6.061181       4.682751  254.915147                 0.192318
# 22        0.069795       0.388118    0.023827                 0.069795
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.269709           0.011000            1       True
# 1                 0.383769           1.379496            1       True
# 2                 0.654035           1.942020            1       True
# 3                 0.329140           1.253065            1       True
# 4                 0.664323           2.006908            1       True
# 5                 0.152054           7.457189            1       True
# 6                 0.156677          11.437438            1       True
# 7                 0.111394           3.289947            1       True
# 8                 0.226432           6.073853            1       True
# 9                 0.107006           5.172328            2       True
# 10                0.002012           0.416558            2       True
# 11                0.285090          92.773110            1       True
# 12                0.490694           1.628295            2       True
# 13                0.533359           1.859035            2       True
# 14                0.344442          38.641588            1       True
# 15                0.189133         107.584434            2       True
# 16                0.002008           0.653853            3       True
# 17                0.349931          41.194796            2       True
# 18                0.225558          86.996493            1       True
# 19                0.426736           1.603497            2       True
# 20                0.096620           7.737415            2       True
# 21                0.492011           1.629215            2       True
# 22                0.388118           0.023827            1       True
#
#     fit_order
# 0           2
# 1           5
# 2           8
# 3           6
# 4           9
# 5          13
# 6           4
# 7          11
# 8           3
# 9          15
# 10         14
# 11         12
# 12         20
# 13         21
# 14         10
# 15         19
# 16         23
# 17         22
# 18          7
# 19         18
# 20         16
# 21         17
# 22          1

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	252.37s	= Expected runtime (50.47s per shuffle set)
# 	157.24s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev       p_value  n  p99_high   p99_low
# heart_disease         0.11044  0.003318  9.762703e-08  5  0.117271  0.103609
# age                   0.10424  0.003254  1.137909e-07  5  0.110940  0.097540
# smoking_status        0.04116  0.002224  1.019647e-06  5  0.045740  0.036580
# work_type             0.03600  0.000970  6.306771e-08  5  0.037996  0.034004
# bmi                   0.03532  0.002287  2.098985e-06  5  0.040030  0.030610
# hypertension          0.03196  0.001004  1.167089e-07  5  0.034027  0.029893
# avg_glucose_level     0.01832  0.002038  1.806609e-05  5  0.022516  0.014124
# Residence_type        0.00696  0.001152  8.698218e-05  5  0.009333  0.004587
# ever_married          0.00600  0.001503  4.358009e-04  5  0.009095  0.002905
# gender                0.00232  0.001671  1.802879e-02  5  0.005760 -0.001120
