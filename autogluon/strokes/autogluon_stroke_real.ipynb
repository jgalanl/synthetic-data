# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/10/beginners-guide-to-automl-with-an-easy-autogluon-example/

# %%
import pandas as pd

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/strokes/stroke-real.csv')

# %%
df.drop(columns='id', inplace=True)
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_train, df_test=train_test_split(df, test_size=0.4, random_state=42)
df_train.shape,df_test.shape
# Out:
# ((3066, 11), (2044, 11))

# %%
predictor= TabularPredictor(
    label='stroke',
    problem_type='binary',
    eval_metric='accuracy',
    path='AutogluonModels/strokes/real/v1',
    learner_kwargs = {'positive_class':1}
    )

# %%
predictor.fit(
    train_data = df_train,
    verbosity = 2,
    presets=['best_quality'],
    num_gpus=1
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       7.10 GB / 15.71 GB (45.2%)
# Disk Space Avail:   670.61 GB / 933.46 GB (71.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-07 20:13:56,624	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/stroke-real\ds_sub_fit\sub_fit_ho"
# (_dystack pid=18864) Running DyStack sub-fit ...
# (_dystack pid=18864) Beginning AutoGluon training ... Time limit = 893s
# (_dystack pid=18864) AutoGluon will save models to "AutogluonModels/stroke-real\ds_sub_fit\sub_fit_ho"
# (_dystack pid=18864) Train Data Rows:    2725
# (_dystack pid=18864) Train Data Columns: 10
# (_dystack pid=18864) Label Column:       stroke
# (_dystack pid=18864) Problem Type:       binary
# (_dystack pid=18864) Preprocessing data ...
# (_dystack pid=18864) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=18864) Using Feature Generators to preprocess the data ...
# (_dystack pid=18864) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=18864) 	Available Memory:                    6733.39 MB
# (_dystack pid=18864) 	Train Data (Original)  Memory Usage: 0.93 MB (0.0% of available memory)
# (_dystack pid=18864) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=18864) 	Stage 1 Generators:
# (_dystack pid=18864) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=18864) 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=18864) 	Stage 2 Generators:
# (_dystack pid=18864) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=18864) 	Stage 3 Generators:
# (_dystack pid=18864) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=18864) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=18864) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=18864) 	Stage 4 Generators:
# (_dystack pid=18864) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=18864) 	Stage 5 Generators:
# (_dystack pid=18864) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=18864) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=18864) 		('float', [])  : 3 | ['age', 'avg_glucose_level', 'bmi']
# (_dystack pid=18864) 		('int', [])    : 2 | ['hypertension', 'heart_disease']
# (_dystack pid=18864) 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# (_dystack pid=18864) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=18864) 		('category', [])  : 2 | ['work_type', 'smoking_status']
# (_dystack pid=18864) 		('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# (_dystack pid=18864) 		('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# (_dystack pid=18864) 	0.0s = Fit runtime
# (_dystack pid=18864) 	10 features in original data used to generate 10 features in processed data.
# (_dystack pid=18864) 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=18864) Data preprocessing and feature engineering runtime = 0.05s ...
# (_dystack pid=18864) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=18864) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=18864) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=18864) User-specified model hyperparameters to be fit:
# (_dystack pid=18864) {
# (_dystack pid=18864) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=18864) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=18864) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=18864) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=18864) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=18864) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=18864) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=18864) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=18864) }
# (_dystack pid=18864) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=18864) Fitting 110 L1 models ...
# (_dystack pid=18864) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 595.23s of the 893.06s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.9516	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.0s	 = Training   runtime
# (_dystack pid=18864) 	0.05s	 = Validation runtime
# (_dystack pid=18864) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 593.21s of the 891.05s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.9512	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.01s	 = Training   runtime
# (_dystack pid=18864) 	0.02s	 = Validation runtime
# (_dystack pid=18864) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 593.16s of the 891.0s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# (_dystack pid=18864) 	0.9578	 = Validation score   (accuracy)
# (_dystack pid=18864) 	1.02s	 = Training   runtime
# (_dystack pid=18864) 	0.04s	 = Validation runtime
# (_dystack pid=18864) Fitting model: LightGBM_BAG_L1 ... Training model for up to 589.72s of the 887.56s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.05%)
# (_dystack pid=18864) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.69s	 = Training   runtime
# (_dystack pid=18864) 	0.02s	 = Validation runtime
# (_dystack pid=18864) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 586.49s of the 884.32s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.956	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.75s	 = Training   runtime
# (_dystack pid=18864) 	0.08s	 = Validation runtime
# (_dystack pid=18864) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 585.61s of the 883.45s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.9556	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.57s	 = Training   runtime
# (_dystack pid=18864) 	0.09s	 = Validation runtime
# (_dystack pid=18864) Fitting model: CatBoost_BAG_L1 ... Training model for up to 584.91s of the 882.75s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# (_dystack pid=18864) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=18864) 	23.8s	 = Training   runtime
# (_dystack pid=18864) 	0.0s	 = Validation runtime
# (_dystack pid=18864) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 558.74s of the 856.57s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.9541	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.56s	 = Training   runtime
# (_dystack pid=18864) 	0.09s	 = Validation runtime
# (_dystack pid=18864) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 558.03s of the 855.86s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	0.9556	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.55s	 = Training   runtime
# (_dystack pid=18864) 	0.08s	 = Validation runtime
# (_dystack pid=18864) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 557.34s of the 855.18s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# (_dystack pid=18864) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=18864) 	9.38s	 = Training   runtime
# (_dystack pid=18864) 	0.12s	 = Validation runtime
# (_dystack pid=18864) Fitting model: XGBoost_BAG_L1 ... Training model for up to 545.51s of the 843.35s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# (_dystack pid=18864) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=18864) 	1.45s	 = Training   runtime
# (_dystack pid=18864) 	0.04s	 = Validation runtime
# (_dystack pid=18864) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 541.14s of the 838.98s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# (_ray_fit pid=15740) Stack (most recent call first):
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=15740)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=15740)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=18864) 	0.956	 = Validation score   (accuracy)
# (_dystack pid=18864) 	19.15s	 = Training   runtime
# (_dystack pid=18864) 	0.12s	 = Validation runtime
# (_dystack pid=18864) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 519.18s of the 817.02s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# (_ray_fit pid=14092) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=14092)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=18864) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=18864) 	1.85s	 = Training   runtime
# (_dystack pid=18864) 	0.03s	 = Validation runtime
# (_dystack pid=18864) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 513.64s of the 811.47s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# (_dystack pid=18864) 	0.9571	 = Validation score   (accuracy)
# (_dystack pid=18864) 	2.07s	 = Training   runtime
# (_dystack pid=18864) 	0.07s	 = Validation runtime
# (_dystack pid=18864) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 508.73s of the 806.56s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# (_ray_fit pid=18240) Stack (most recent call first):
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=18240)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=18240)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=18864) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=18864) 	20.38s	 = Training   runtime
# (_dystack pid=18864) 	0.15s	 = Validation runtime
# (_dystack pid=18864) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 485.26s of the 783.1s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_ray_fit pid=15008) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=15008)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# (_dystack pid=18864) 	0.9567	 = Validation score   (accuracy)
# (_dystack pid=18864) 	1.2s	 = Training   runtime
# (_dystack pid=18864) 	0.04s	 = Validation runtime
# (_dystack pid=18864) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 480.82s of the 778.66s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# (_dystack pid=18864) 	0.9578	 = Validation score   (accuracy)
# (_dystack pid=18864) 	15.56s	 = Training   runtime
# (_dystack pid=18864) 	0.18s	 = Validation runtime
# (_dystack pid=18864) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 462.32s of the 760.16s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.27%)
# (_dystack pid=18864) 	0.9574	 = Validation score   (accuracy)
# (_dystack pid=18864) 	23.35s	 = Training   runtime
# (_dystack pid=18864) 	0.04s	 = Validation runtime
# (_dystack pid=18864) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 435.97s of the 733.81s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# (_dystack pid=18864) 	0.956	 = Validation score   (accuracy)
# (_dystack pid=18864) 	0.72s	 = Training   runtime
# (_dystack pid=18864) 	0.04s	 = Validation runtime
# (_dystack pid=18864) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 432.44s of the 730.28s of remaining time.
# (_dystack pid=18864) Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# (_dystack pid=18864) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# (_ray_fit pid=17732) Stack (most recent call first):
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17732)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# ...
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1714.12s of the 2608.18s of remaining time.
# 	0.954	 = Validation score   (accuracy)
# 	0.57s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1713.39s of the 2607.45s of remaining time.
# 	0.9543	 = Validation score   (accuracy)
# 	0.55s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1712.61s of the 2606.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9556	 = Validation score   (accuracy)
# 	36.93s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1673.64s of the 2567.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.09%)
# 	0.9573	 = Validation score   (accuracy)
# 	19.62s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1651.67s of the 2545.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.01%)
# 	0.956	 = Validation score   (accuracy)
# 	175.22s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1473.35s of the 2367.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.15%)
# 	0.9566	 = Validation score   (accuracy)
# 	1.53s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1468.87s of the 2362.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.09%)
# 	0.9569	 = Validation score   (accuracy)
# 	11.59s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1455.25s of the 2349.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.01%)
# 	0.9566	 = Validation score   (accuracy)
# 	209.95s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1243.4s of the 2137.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.07%)
# 	0.956	 = Validation score   (accuracy)
# 	1.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1239.44s of the 2133.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.03%)
# 	0.9563	 = Validation score   (accuracy)
# 	64.6s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1172.67s of the 2066.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.27%)
# 	0.9566	 = Validation score   (accuracy)
# 	60.14s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1110.35s of the 2004.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.956	 = Validation score   (accuracy)
# 	1.18s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1102.04s of the 1996.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.01%)
# 	0.9569	 = Validation score   (accuracy)
# 	212.16s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 885.81s of the 1779.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.55%)
# 	0.9569	 = Validation score   (accuracy)
# 	11.45s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 872.22s of the 1766.27s of remaining time.
# 	0.9537	 = Validation score   (accuracy)
# 	0.68s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 871.37s of the 1765.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.03%)
# 	0.9563	 = Validation score   (accuracy)
# 	46.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 822.84s of the 1716.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	21.52s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 799.29s of the 1693.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.29%)
# 	0.9566	 = Validation score   (accuracy)
# 	14.48s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 782.71s of the 1676.77s of remaining time.
# 	0.9524	 = Validation score   (accuracy)
# 	0.98s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 781.58s of the 1675.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# 	0.9569	 = Validation score   (accuracy)
# 	1.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 776.85s of the 1670.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	91.44s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 683.09s of the 1577.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.08%)
# 	0.9573	 = Validation score   (accuracy)
# 	10.51s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 669.18s of the 1563.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.01%)
# 	0.9566	 = Validation score   (accuracy)
# 	286.61s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 380.71s of the 1274.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.11%)
# 	0.9576	 = Validation score   (accuracy)
# 	1.23s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 376.29s of the 1270.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.02%)
# 	0.9563	 = Validation score   (accuracy)
# 	211.61s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 162.66s of the 1056.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.03%)
# 	0.9573	 = Validation score   (accuracy)
# 	62.66s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 97.64s of the 991.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9566	 = Validation score   (accuracy)
# 	66.4s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 28.26s of the 922.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.15%)
# 	0.9573	 = Validation score   (accuracy)
# 	14.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 10.98s of the 905.03s of remaining time.
# 	0.956	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 10.03s of the 904.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.956	 = Validation score   (accuracy)
# 	15.87s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 884.89s of remaining time.
# 	Ensemble Weights: {'LightGBM_r130_BAG_L1': 1.0}
# 	0.9576	 = Validation score   (accuracy)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 884.56s of the 884.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.19%)
# 	0.9569	 = Validation score   (accuracy)
# 	1.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 879.5s of the 879.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# 	0.9576	 = Validation score   (accuracy)
# 	2.04s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 874.14s of the 874.0s of remaining time.
# 	0.956	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 872.95s of the 872.81s of remaining time.
# 	0.9563	 = Validation score   (accuracy)
# 	0.83s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 871.88s of the 871.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.34%)
# 	0.956	 = Validation score   (accuracy)
# 	60.96s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 808.09s of the 807.95s of remaining time.
# 	0.9556	 = Validation score   (accuracy)
# 	0.78s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 807.1s of the 806.96s of remaining time.
# 	0.956	 = Validation score   (accuracy)
# 	0.78s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 806.11s of the 805.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.10%)
# 	0.9556	 = Validation score   (accuracy)
# 	48.12s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 754.93s of the 754.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.43%)
# 	0.9576	 = Validation score   (accuracy)
# 	16.12s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 735.99s of the 735.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.06%)
# 	0.9563	 = Validation score   (accuracy)
# 	220.57s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 512.62s of the 512.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.74%)
# 	0.9566	 = Validation score   (accuracy)
# 	3.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 505.2s of the 505.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.38%)
# 	0.9569	 = Validation score   (accuracy)
# 	21.14s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 481.24s of the 481.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.06%)
# 	0.9579	 = Validation score   (accuracy)
# 	272.81s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 205.73s of the 205.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.32%)
# 	0.956	 = Validation score   (accuracy)
# 	1.76s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 199.94s of the 199.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=0.12%)
# 	0.9579	 = Validation score   (accuracy)
# 	57.98s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 139.05s of the 138.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=10, gpus=0, memory=1.36%)
# 	0.9563	 = Validation score   (accuracy)
# 	111.95s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 24.34s of the 24.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.13%)
# 	0.956	 = Validation score   (accuracy)
# 	0.92s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 20.1s of the 19.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=14, gpus=0, memory=0.06%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r22_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 0.76s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r79_BAG_L2': 1.0}
# 	0.9579	 = Validation score   (accuracy)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2680.59s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 122.2 rows/s (384 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/stroke-real")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   NeuralNetFastAI_r191_BAG_L2   0.957926    accuracy       3.728564  1772.997116                0.185516          57.975660            2       True         53
# 1           WeightedEnsemble_L3   0.957926    accuracy       3.889835  1988.088516                0.000000           0.260479            3       True         56
# 2     NeuralNetTorch_r79_BAG_L2   0.957926    accuracy       3.889835  1987.828037                0.346787         272.806581            2       True         51
# 3           WeightedEnsemble_L2   0.957599    accuracy       0.068066     1.517360                0.000000           0.286325            2       True         38
# 4          LightGBM_r130_BAG_L1   0.957599    accuracy       0.068066     1.231036                0.068066           1.231036            1       True         31
# 5               LightGBM_BAG_L2   0.957599    accuracy       3.587562  1717.057630                0.044514           2.036174            2       True         40
# 6                XGBoost_BAG_L2   0.957599    accuracy       3.595341  1731.139680                0.052293          16.118224            2       True         47
# 7           CatBoost_r50_BAG_L1   0.957273    accuracy       0.031476    62.661524                0.031476          62.661524            1       True         33
# 8            XGBoost_r89_BAG_L1   0.957273    accuracy       0.044610    10.509672                0.044610          10.509672            1       True         29
# 9           XGBoost_r194_BAG_L1   0.957273    accuracy       0.045549    14.557563                0.045549          14.557563            1       True         35
# 10               XGBoost_BAG_L1   0.957273    accuracy       0.054514    19.622996                0.054514          19.622996            1       True         11
# 11            LightGBMXT_BAG_L1   0.957273    accuracy       0.072045     1.235614                0.072045           1.235614            1       True          3
# 12              CatBoost_BAG_L1   0.956947    accuracy       0.005884    57.272533                0.005884          57.272533            1       True          7
# 13         LightGBM_r188_BAG_L1   0.956947    accuracy       0.026886     1.652376                0.026886           1.652376            1       True         27
# 14         CatBoost_r177_BAG_L1   0.956947    accuracy       0.042932    11.591946                0.042932          11.591946            1       True         14
# 15           XGBoost_r33_BAG_L1   0.956947    accuracy       0.050019    11.448325                0.050019          11.448325            1       True         21
# 16    NeuralNetTorch_r22_BAG_L1   0.956947    accuracy       0.175355   212.158566                0.175355         212.158566            1       True         20
# 17         CatBoost_r177_BAG_L2   0.956947    accuracy       3.561214  1736.164538                0.018166          21.143082            2       True         50
# 18            LightGBMXT_BAG_L2   0.956947    accuracy       3.590819  1716.702652                0.047771           1.681196            2       True         39
# 19           CatBoost_r9_BAG_L1   0.956621    accuracy       0.018091    60.139861                0.018091          60.139861            1       True         18
# 20         LightGBMLarge_BAG_L1   0.956621    accuracy       0.030723     1.529773                0.030723           1.529773            1       True         13
# 21              LightGBM_BAG_L1   0.956621    accuracy       0.032486     0.939840                0.032486           0.939840            1       True          4
# 22          CatBoost_r13_BAG_L1   0.956621    accuracy       0.051726    14.478398                0.051726          14.478398            1       True         25
# 23  NeuralNetFastAI_r102_BAG_L1   0.956621    accuracy       0.118414    21.519759                0.118414          21.519759            1       True         24
# 24    NeuralNetTorch_r79_BAG_L1   0.956621    accuracy       0.154377   209.954798                0.154377         209.954798            1       True         15
# 25   NeuralNetFastAI_r11_BAG_L1   0.956621    accuracy       0.229155    66.399940                0.229155          66.399940            1       True         34
# 26    NeuralNetTorch_r30_BAG_L1   0.956621    accuracy       0.232747   286.610262                0.232747         286.610262            1       True         30
# 27  NeuralNetFastAI_r145_BAG_L1   0.956621    accuracy       0.308046    91.436257                0.308046          91.436257            1       True         28
# 28         LightGBMLarge_BAG_L2   0.956621    accuracy       3.564216  1718.987031                0.021168           3.965575            2       True         49
# 29         CatBoost_r137_BAG_L1   0.956295    accuracy       0.003944    46.471291                0.003944          46.471291            1       True         23
# 30    NeuralNetTorch_r86_BAG_L1   0.956295    accuracy       0.138199   211.613456                0.138199         211.613456            1       True         32
# 31  NeuralNetFastAI_r191_BAG_L1   0.956295    accuracy       0.280712    64.601139                0.280712          64.601139            1       True         17
# 32           CatBoost_r9_BAG_L2   0.956295    accuracy       3.584578  1826.970260                0.041530         111.948804            2       True         54
# 33      RandomForestEntr_BAG_L2   0.956295    accuracy       3.724293  1715.849766                0.181245           0.828310            2       True         42
# 34        NeuralNetTorch_BAG_L2   0.956295    accuracy       3.869676  1935.592017                0.326628         220.570561            2       True         48
# 35         LightGBM_r131_BAG_L1   0.955969    accuracy       0.024927     0.997195                0.024927           0.997195            1       True         16
# 36          CatBoost_r69_BAG_L1   0.955969    accuracy       0.029903    15.868154                0.029903          15.868154            1       True         37
# 37          LightGBM_r96_BAG_L1   0.955969    accuracy       0.110643     1.179296                0.110643           1.179296            1       True         19
# 38       ExtraTrees_r172_BAG_L1   0.955969    accuracy       0.135422     0.761929                0.135422           0.761929            1       True         36
# 39        NeuralNetTorch_BAG_L1   0.955969    accuracy       0.150964   175.215553                0.150964         175.215553            1       True         12
# 40          LightGBM_r96_BAG_L2   0.955969    accuracy       3.551724  1715.943354                0.008676           0.921898            2       True         55
# 41         LightGBM_r131_BAG_L2   0.955969    accuracy       3.569788  1716.778537                0.026740           1.757081            2       True         52
# 42              CatBoost_BAG_L2   0.955969    accuracy       3.593244  1775.979770                0.050196          60.958314            2       True         43
# 43        ExtraTreesEntr_BAG_L2   0.955969    accuracy       3.698832  1715.798578                0.155784           0.777122            2       True         45
# 44      RandomForestGini_BAG_L2   0.955969    accuracy       3.752168  1715.957544                0.209120           0.936088            2       True         41
# 45       NeuralNetFastAI_BAG_L1   0.955643    accuracy       0.156115    36.934671                0.156115          36.934671            1       True         10
# 46        ExtraTreesGini_BAG_L2   0.955643    accuracy       3.697236  1715.800431                0.154188           0.778975            2       True         44
# 47       NeuralNetFastAI_BAG_L2   0.955643    accuracy       3.716138  1763.140601                0.173090          48.119145            2       True         46
# 48      RandomForestEntr_BAG_L1   0.955316    accuracy       0.100333     0.592280                0.100333           0.592280            1       True          6
# 49      RandomForestGini_BAG_L1   0.954664    accuracy       0.118347     1.057970                0.118347           1.057970            1       True          5
# 50        ExtraTreesEntr_BAG_L1   0.954338    accuracy       0.099566     0.546892                0.099566           0.546892            1       True          9
# 51        ExtraTreesGini_BAG_L1   0.954012    accuracy       0.090709     0.572472                0.090709           0.572472            1       True          8
# 52        ExtraTrees_r42_BAG_L1   0.953686    accuracy       0.114018     0.679440                0.114018           0.679440            1       True         22
# 53        KNeighborsUnif_BAG_L1   0.953033    accuracy       0.051343     0.000000                0.051343           0.000000            1       True          1
# 54     RandomForest_r195_BAG_L1   0.952381    accuracy       0.100924     0.978678                0.100924           0.978678            1       True         26
# 55        KNeighborsDist_BAG_L1   0.951729    accuracy       0.043877     0.000000                0.043877           0.000000            1       True          2
# Number of models trained: 56
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 2 | ['work_type', 'smoking_status']
# ('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# ('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.9530332681017613,
#   'KNeighborsDist_BAG_L1': 0.9517286366601435,
#   'LightGBMXT_BAG_L1': 0.957273320287019,
#   'LightGBM_BAG_L1': 0.95662100456621,
#   'RandomForestGini_BAG_L1': 0.9546640574037835,
#   'RandomForestEntr_BAG_L1': 0.9553163731245923,
#   'CatBoost_BAG_L1': 0.9569471624266145,
#   'ExtraTreesGini_BAG_L1': 0.9540117416829745,
#   'ExtraTreesEntr_BAG_L1': 0.954337899543379,
#   'NeuralNetFastAI_BAG_L1': 0.9556425309849967,
#   'XGBoost_BAG_L1': 0.957273320287019,
#   'NeuralNetTorch_BAG_L1': 0.9559686888454012,
#   'LightGBMLarge_BAG_L1': 0.95662100456621,
#   'CatBoost_r177_BAG_L1': 0.9569471624266145,
#   'NeuralNetTorch_r79_BAG_L1': 0.95662100456621,
#   'LightGBM_r131_BAG_L1': 0.9559686888454012,
#   'NeuralNetFastAI_r191_BAG_L1': 0.9562948467058056,
#   'CatBoost_r9_BAG_L1': 0.95662100456621,
#   'LightGBM_r96_BAG_L1': 0.9559686888454012,
#   'NeuralNetTorch_r22_BAG_L1': 0.9569471624266145,
#   'XGBoost_r33_BAG_L1': 0.9569471624266145,
#   'ExtraTrees_r42_BAG_L1': 0.9536855838225701,
#   'CatBoost_r137_BAG_L1': 0.9562948467058056,
#   'NeuralNetFastAI_r102_BAG_L1': 0.95662100456621,
#   'CatBoost_r13_BAG_L1': 0.95662100456621,
#   'RandomForest_r195_BAG_L1': 0.9523809523809523,
#   'LightGBM_r188_BAG_L1': 0.9569471624266145,
#   'NeuralNetFastAI_r145_BAG_L1': 0.95662100456621,
#   'XGBoost_r89_BAG_L1': 0.957273320287019,
#   'NeuralNetTorch_r30_BAG_L1': 0.95662100456621,
#   'LightGBM_r130_BAG_L1': 0.9575994781474233,
#   'NeuralNetTorch_r86_BAG_L1': 0.9562948467058056,
#   'CatBoost_r50_BAG_L1': 0.957273320287019,
#   'NeuralNetFastAI_r11_BAG_L1': 0.95662100456621,
#   'XGBoost_r194_BAG_L1': 0.957273320287019,
#   'ExtraTrees_r172_BAG_L1': 0.9559686888454012,
#   'CatBoost_r69_BAG_L1': 0.9559686888454012,
#   'WeightedEnsemble_L2': 0.9575994781474233,
#   'LightGBMXT_BAG_L2': 0.9569471624266145,
#   'LightGBM_BAG_L2': 0.9575994781474233,
#   'RandomForestGini_BAG_L2': 0.9559686888454012,
#   'RandomForestEntr_BAG_L2': 0.9562948467058056,
#   'CatBoost_BAG_L2': 0.9559686888454012,
#   'ExtraTreesGini_BAG_L2': 0.9556425309849967,
#   'ExtraTreesEntr_BAG_L2': 0.9559686888454012,
#   'NeuralNetFastAI_BAG_L2': 0.9556425309849967,
#   'XGBoost_BAG_L2': 0.9575994781474233,
#   'NeuralNetTorch_BAG_L2': 0.9562948467058056,
#   'LightGBMLarge_BAG_L2': 0.95662100456621,
#   'CatBoost_r177_BAG_L2': 0.9569471624266145,
#   'NeuralNetTorch_r79_BAG_L2': 0.9579256360078278,
#   'LightGBM_r131_BAG_L2': 0.9559686888454012,
#   'NeuralNetFastAI_r191_BAG_L2': 0.9579256360078278,
#   'CatBoost_r9_BAG_L2': 0.9562948467058056,
#   'LightGBM_r96_BAG_L2': 0.9559686888454012,
#   'WeightedEnsemble_L3': 0.9579256360078278},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'NeuralNetFastAI_r191_BAG_L2': ['NeuralNetFastAI_r191_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'LightGBM_r96_BAG_L2': ['LightGBM_r96_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.0,
#   'LightGBMXT_BAG_L1': 1.2356140613555908,
#   'LightGBM_BAG_L1': 0.9398400783538818,
#   'RandomForestGini_BAG_L1': 1.0579702854156494,
#   'RandomForestEntr_BAG_L1': 0.5922801494598389,
#   'CatBoost_BAG_L1': 57.27253341674805,
#   'ExtraTreesGini_BAG_L1': 0.572472333908081,
#   'ExtraTreesEntr_BAG_L1': 0.5468924045562744,
#   'NeuralNetFastAI_BAG_L1': 36.9346706867218,
#   'XGBoost_BAG_L1': 19.62299633026123,
#   'NeuralNetTorch_BAG_L1': 175.2155532836914,
#   'LightGBMLarge_BAG_L1': 1.529773473739624,
#   'CatBoost_r177_BAG_L1': 11.591946125030518,
#   'NeuralNetTorch_r79_BAG_L1': 209.9547975063324,
#   'LightGBM_r131_BAG_L1': 0.9971945285797119,
#   'NeuralNetFastAI_r191_BAG_L1': 64.60113859176636,
#   'CatBoost_r9_BAG_L1': 60.13986110687256,
#   'LightGBM_r96_BAG_L1': 1.179295539855957,
#   'NeuralNetTorch_r22_BAG_L1': 212.15856623649597,
#   'XGBoost_r33_BAG_L1': 11.448325395584106,
#   'ExtraTrees_r42_BAG_L1': 0.6794395446777344,
#   'CatBoost_r137_BAG_L1': 46.471290588378906,
#   'NeuralNetFastAI_r102_BAG_L1': 21.51975917816162,
#   'CatBoost_r13_BAG_L1': 14.478397607803345,
#   'RandomForest_r195_BAG_L1': 0.9786779880523682,
#   'LightGBM_r188_BAG_L1': 1.652376413345337,
#   'NeuralNetFastAI_r145_BAG_L1': 91.43625712394714,
#   'XGBoost_r89_BAG_L1': 10.509672403335571,
#   'NeuralNetTorch_r30_BAG_L1': 286.6102616786957,
#   'LightGBM_r130_BAG_L1': 1.2310357093811035,
#   'NeuralNetTorch_r86_BAG_L1': 211.61345648765564,
#   'CatBoost_r50_BAG_L1': 62.661524295806885,
#   'NeuralNetFastAI_r11_BAG_L1': 66.39993977546692,
#   'XGBoost_r194_BAG_L1': 14.557562828063965,
#   'ExtraTrees_r172_BAG_L1': 0.7619287967681885,
#   'CatBoost_r69_BAG_L1': 15.868154048919678,
#   'WeightedEnsemble_L2': 0.28632450103759766,
#   'LightGBMXT_BAG_L2': 1.6811959743499756,
#   'LightGBM_BAG_L2': 2.0361740589141846,
#   'RandomForestGini_BAG_L2': 0.9360883235931396,
#   'RandomForestEntr_BAG_L2': 0.8283100128173828,
#   'CatBoost_BAG_L2': 60.958313941955566,
#   'ExtraTreesGini_BAG_L2': 0.778975248336792,
#   'ExtraTreesEntr_BAG_L2': 0.7771217823028564,
#   'NeuralNetFastAI_BAG_L2': 48.11914539337158,
#   'XGBoost_BAG_L2': 16.118224143981934,
#   'NeuralNetTorch_BAG_L2': 220.570561170578,
#   'LightGBMLarge_BAG_L2': 3.9655754566192627,
#   'CatBoost_r177_BAG_L2': 21.1430823802948,
#   'NeuralNetTorch_r79_BAG_L2': 272.80658054351807,
#   'LightGBM_r131_BAG_L2': 1.7570810317993164,
#   'NeuralNetFastAI_r191_BAG_L2': 57.97566032409668,
#   'CatBoost_r9_BAG_L2': 111.94880414009094,
#   'LightGBM_r96_BAG_L2': 0.921898365020752,
#   'WeightedEnsemble_L3': 0.260479211807251},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.05134296417236328,
#   'KNeighborsDist_BAG_L1': 0.04387664794921875,
#   'LightGBMXT_BAG_L1': 0.07204484939575195,
#   'LightGBM_BAG_L1': 0.0324864387512207,
#   'RandomForestGini_BAG_L1': 0.1183474063873291,
#   'RandomForestEntr_BAG_L1': 0.10033273696899414,
#   'CatBoost_BAG_L1': 0.005884408950805664,
#   'ExtraTreesGini_BAG_L1': 0.09070873260498047,
#   'ExtraTreesEntr_BAG_L1': 0.09956574440002441,
#   'NeuralNetFastAI_BAG_L1': 0.15611481666564941,
#   'XGBoost_BAG_L1': 0.05451393127441406,
#   'NeuralNetTorch_BAG_L1': 0.15096402168273926,
#   'LightGBMLarge_BAG_L1': 0.03072333335876465,
#   'CatBoost_r177_BAG_L1': 0.04293227195739746,
#   'NeuralNetTorch_r79_BAG_L1': 0.15437674522399902,
#   'LightGBM_r131_BAG_L1': 0.02492690086364746,
#   'NeuralNetFastAI_r191_BAG_L1': 0.2807121276855469,
#   'CatBoost_r9_BAG_L1': 0.01809072494506836,
#   'LightGBM_r96_BAG_L1': 0.11064338684082031,
#   'NeuralNetTorch_r22_BAG_L1': 0.1753554344177246,
#   'XGBoost_r33_BAG_L1': 0.0500187873840332,
#   'ExtraTrees_r42_BAG_L1': 0.11401820182800293,
#   'CatBoost_r137_BAG_L1': 0.00394439697265625,
#   'NeuralNetFastAI_r102_BAG_L1': 0.11841368675231934,
#   'CatBoost_r13_BAG_L1': 0.05172610282897949,
#   'RandomForest_r195_BAG_L1': 0.10092353820800781,
#   'LightGBM_r188_BAG_L1': 0.0268862247467041,
#   'NeuralNetFastAI_r145_BAG_L1': 0.3080463409423828,
#   'XGBoost_r89_BAG_L1': 0.04460954666137695,
#   'NeuralNetTorch_r30_BAG_L1': 0.23274707794189453,
#   'LightGBM_r130_BAG_L1': 0.06806588172912598,
#   'NeuralNetTorch_r86_BAG_L1': 0.1381990909576416,
#   'CatBoost_r50_BAG_L1': 0.03147625923156738,
#   'NeuralNetFastAI_r11_BAG_L1': 0.2291545867919922,
#   'XGBoost_r194_BAG_L1': 0.04554891586303711,
#   'ExtraTrees_r172_BAG_L1': 0.1354222297668457,
#   'CatBoost_r69_BAG_L1': 0.029903411865234375,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.04777073860168457,
#   'LightGBM_BAG_L2': 0.04451441764831543,
#   'RandomForestGini_BAG_L2': 0.2091200351715088,
#   'RandomForestEntr_BAG_L2': 0.1812453269958496,
#   'CatBoost_BAG_L2': 0.05019640922546387,
#   'ExtraTreesGini_BAG_L2': 0.1541883945465088,
#   'ExtraTreesEntr_BAG_L2': 0.15578436851501465,
#   'NeuralNetFastAI_BAG_L2': 0.17308998107910156,
#   'XGBoost_BAG_L2': 0.05229306221008301,
#   'NeuralNetTorch_BAG_L2': 0.3266284465789795,
#   'LightGBMLarge_BAG_L2': 0.021167993545532227,
#   'CatBoost_r177_BAG_L2': 0.018166065216064453,
#   'NeuralNetTorch_r79_BAG_L2': 0.3467872142791748,
#   'LightGBM_r131_BAG_L2': 0.026739835739135742,
#   'NeuralNetFastAI_r191_BAG_L2': 0.1855156421661377,
#   'CatBoost_r9_BAG_L2': 0.04152965545654297,
#   'LightGBM_r96_BAG_L2': 0.008675813674926758,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0   NeuralNetFastAI_r191_BAG_L2   0.957926    accuracy       3.728564
#  1           WeightedEnsemble_L3   0.957926    accuracy       3.889835
#  2     NeuralNetTorch_r79_BAG_L2   0.957926    accuracy       3.889835
#  3           WeightedEnsemble_L2   0.957599    accuracy       0.068066
#  4          LightGBM_r130_BAG_L1   0.957599    accuracy       0.068066
#  5               LightGBM_BAG_L2   0.957599    accuracy       3.587562
#  6                XGBoost_BAG_L2   0.957599    accuracy       3.595341
#  7           CatBoost_r50_BAG_L1   0.957273    accuracy       0.031476
#  8            XGBoost_r89_BAG_L1   0.957273    accuracy       0.044610
#  9           XGBoost_r194_BAG_L1   0.957273    accuracy       0.045549
#  10               XGBoost_BAG_L1   0.957273    accuracy       0.054514
#  11            LightGBMXT_BAG_L1   0.957273    accuracy       0.072045
#  12              CatBoost_BAG_L1   0.956947    accuracy       0.005884
#  13         LightGBM_r188_BAG_L1   0.956947    accuracy       0.026886
#  14         CatBoost_r177_BAG_L1   0.956947    accuracy       0.042932
#  15           XGBoost_r33_BAG_L1   0.956947    accuracy       0.050019
#  16    NeuralNetTorch_r22_BAG_L1   0.956947    accuracy       0.175355
#  17         CatBoost_r177_BAG_L2   0.956947    accuracy       3.561214
#  18            LightGBMXT_BAG_L2   0.956947    accuracy       3.590819
#  19           CatBoost_r9_BAG_L1   0.956621    accuracy       0.018091
#  20         LightGBMLarge_BAG_L1   0.956621    accuracy       0.030723
#  21              LightGBM_BAG_L1   0.956621    accuracy       0.032486
#  22          CatBoost_r13_BAG_L1   0.956621    accuracy       0.051726
#  23  NeuralNetFastAI_r102_BAG_L1   0.956621    accuracy       0.118414
#  24    NeuralNetTorch_r79_BAG_L1   0.956621    accuracy       0.154377
#  25   NeuralNetFastAI_r11_BAG_L1   0.956621    accuracy       0.229155
#  26    NeuralNetTorch_r30_BAG_L1   0.956621    accuracy       0.232747
#  27  NeuralNetFastAI_r145_BAG_L1   0.956621    accuracy       0.308046
#  28         LightGBMLarge_BAG_L2   0.956621    accuracy       3.564216
#  29         CatBoost_r137_BAG_L1   0.956295    accuracy       0.003944
#  30    NeuralNetTorch_r86_BAG_L1   0.956295    accuracy       0.138199
#  31  NeuralNetFastAI_r191_BAG_L1   0.956295    accuracy       0.280712
#  32           CatBoost_r9_BAG_L2   0.956295    accuracy       3.584578
#  33      RandomForestEntr_BAG_L2   0.956295    accuracy       3.724293
#  34        NeuralNetTorch_BAG_L2   0.956295    accuracy       3.869676
#  35         LightGBM_r131_BAG_L1   0.955969    accuracy       0.024927
#  36          CatBoost_r69_BAG_L1   0.955969    accuracy       0.029903
#  37          LightGBM_r96_BAG_L1   0.955969    accuracy       0.110643
#  38       ExtraTrees_r172_BAG_L1   0.955969    accuracy       0.135422
#  39        NeuralNetTorch_BAG_L1   0.955969    accuracy       0.150964
#  40          LightGBM_r96_BAG_L2   0.955969    accuracy       3.551724
#  41         LightGBM_r131_BAG_L2   0.955969    accuracy       3.569788
#  42              CatBoost_BAG_L2   0.955969    accuracy       3.593244
#  43        ExtraTreesEntr_BAG_L2   0.955969    accuracy       3.698832
#  44      RandomForestGini_BAG_L2   0.955969    accuracy       3.752168
#  45       NeuralNetFastAI_BAG_L1   0.955643    accuracy       0.156115
#  46        ExtraTreesGini_BAG_L2   0.955643    accuracy       3.697236
#  47       NeuralNetFastAI_BAG_L2   0.955643    accuracy       3.716138
#  48      RandomForestEntr_BAG_L1   0.955316    accuracy       0.100333
#  49      RandomForestGini_BAG_L1   0.954664    accuracy       0.118347
#  50        ExtraTreesEntr_BAG_L1   0.954338    accuracy       0.099566
#  51        ExtraTreesGini_BAG_L1   0.954012    accuracy       0.090709
#  52        ExtraTrees_r42_BAG_L1   0.953686    accuracy       0.114018
#  53        KNeighborsUnif_BAG_L1   0.953033    accuracy       0.051343
#  54     RandomForest_r195_BAG_L1   0.952381    accuracy       0.100924
#  55        KNeighborsDist_BAG_L1   0.951729    accuracy       0.043877
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   1772.997116                0.185516          57.975660            2
#  1   1988.088516                0.000000           0.260479            3
#  2   1987.828037                0.346787         272.806581            2
#  3      1.517360                0.000000           0.286325            2
#  4      1.231036                0.068066           1.231036            1
#  5   1717.057630                0.044514           2.036174            2
#  6   1731.139680                0.052293          16.118224            2
#  7     62.661524                0.031476          62.661524            1
#  8     10.509672                0.044610          10.509672            1
#  9     14.557563                0.045549          14.557563            1
#  10    19.622996                0.054514          19.622996            1
#  11     1.235614                0.072045           1.235614            1
#  12    57.272533                0.005884          57.272533            1
#  13     1.652376                0.026886           1.652376            1
#  14    11.591946                0.042932          11.591946            1
#  15    11.448325                0.050019          11.448325            1
#  16   212.158566                0.175355         212.158566            1
#  17  1736.164538                0.018166          21.143082            2
#  18  1716.702652                0.047771           1.681196            2
#  19    60.139861                0.018091          60.139861            1
#  20     1.529773                0.030723           1.529773            1
#  21     0.939840                0.032486           0.939840            1
#  22    14.478398                0.051726          14.478398            1
#  23    21.519759                0.118414          21.519759            1
#  24   209.954798                0.154377         209.954798            1
#  25    66.399940                0.229155          66.399940            1
#  26   286.610262                0.232747         286.610262            1
#  27    91.436257                0.308046          91.436257            1
#  28  1718.987031                0.021168           3.965575            2
#  29    46.471291                0.003944          46.471291            1
#  30   211.613456                0.138199         211.613456            1
#  31    64.601139                0.280712          64.601139            1
#  32  1826.970260                0.041530         111.948804            2
#  33  1715.849766                0.181245           0.828310            2
#  34  1935.592017                0.326628         220.570561            2
#  35     0.997195                0.024927           0.997195            1
#  36    15.868154                0.029903          15.868154            1
#  37     1.179296                0.110643           1.179296            1
#  38     0.761929                0.135422           0.761929            1
#  39   175.215553                0.150964         175.215553            1
#  40  1715.943354                0.008676           0.921898            2
#  41  1716.778537                0.026740           1.757081            2
#  42  1775.979770                0.050196          60.958314            2
#  43  1715.798578                0.155784           0.777122            2
#  44  1715.957544                0.209120           0.936088            2
#  45    36.934671                0.156115          36.934671            1
#  46  1715.800431                0.154188           0.778975            2
#  47  1763.140601                0.173090          48.119145            2
#  48     0.592280                0.100333           0.592280            1
#  49     1.057970                0.118347           1.057970            1
#  50     0.546892                0.099566           0.546892            1
#  51     0.572472                0.090709           0.572472            1
#  52     0.679440                0.114018           0.679440            1
#  53     0.000000                0.051343           0.000000            1
#  54     0.978678                0.100924           0.978678            1
#  55     0.000000                0.043877           0.000000            1
#
#      can_infer  fit_order
#  0        True         53
#  1        True         56
#  2        True         51
#  3        True         38
#  4        True         31
#  5        True         40
#  6        True         47
#  7        True         33
#  8        True         29
#  9        True         35
#  10       True         11
#  11       True          3
#  12       True          7
#  13       True         27
#  14       True         14
#  15       True         21
#  16       True         20
#  17       True         50
#  18       True         39
#  19       True         18
#  20       True         13
#  21       True          4
#  22       True         25
#  23       True         24
#  24       True         15
#  25       True         34
#  26       True         30
#  27       True         28
#  28       True         49
#  29       True         23
#  30       True         32
#  31       True         17
#  32       True         54
#  33       True         42
#  34       True         48
#  35       True         16
#  36       True         37
#  37       True         19
#  38       True         36
#  39       True         12
#  40       True         55
#  41       True         52
#  42       True         43
#  43       True         45
#  44       True         41
#  45       True         10
#  46       True         44
#  47       True         46
#  48       True          6
#  49       True          5
#  50       True          9
#  51       True          8
#  52       True         22
#  53       True          1
#  54       True         26
#  55       True          2  }

# %%
predictor.evaluate(df_test)
# Out:
# {'accuracy': 0.9452054794520548,
#  'balanced_accuracy': 0.5087719298245614,
#  'mcc': 0.12876960330741333,
#  'roc_auc': 0.8265157712935188,
#  'f1': 0.034482758620689655,
#  'precision': 1.0,
#  'recall': 0.017543859649122806}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                           model  score_test  score_val eval_metric  \
# 0         KNeighborsDist_BAG_L1    1.000000   0.951729    accuracy
# 1         ExtraTreesEntr_BAG_L1    1.000000   0.954338    accuracy
# 2       RandomForestEntr_BAG_L1    1.000000   0.955316    accuracy
# 3       RandomForestGini_BAG_L1    1.000000   0.954664    accuracy
# 4      RandomForest_r195_BAG_L1    1.000000   0.952381    accuracy
# 5         ExtraTrees_r42_BAG_L1    1.000000   0.953686    accuracy
# 6         ExtraTreesGini_BAG_L1    1.000000   0.954012    accuracy
# 7            CatBoost_r9_BAG_L1    0.962492   0.956621    accuracy
# 8           CatBoost_r13_BAG_L1    0.960535   0.956621    accuracy
# 9         KNeighborsUnif_BAG_L1    0.960535   0.953033    accuracy
# 10          WeightedEnsemble_L3    0.958578   0.957926    accuracy
# 11    NeuralNetTorch_r79_BAG_L2    0.958578   0.957926    accuracy
# 12          CatBoost_r50_BAG_L1    0.957926   0.957273    accuracy
# 13      RandomForestGini_BAG_L2    0.957926   0.955969    accuracy
# 14              CatBoost_BAG_L1    0.957273   0.956947    accuracy
# 15         CatBoost_r177_BAG_L1    0.957273   0.956947    accuracy
# 16           CatBoost_r9_BAG_L2    0.957273   0.956295    accuracy
# 17         CatBoost_r177_BAG_L2    0.956947   0.956947    accuracy
# 18       ExtraTrees_r172_BAG_L1    0.956621   0.955969    accuracy
# 19    NeuralNetTorch_r86_BAG_L1    0.956621   0.956295    accuracy
# 20      RandomForestEntr_BAG_L2    0.956621   0.956295    accuracy
# 21    NeuralNetTorch_r22_BAG_L1    0.956295   0.956947    accuracy
# 22        ExtraTreesGini_BAG_L2    0.956295   0.955643    accuracy
# 23         CatBoost_r137_BAG_L1    0.955969   0.956295    accuracy
# 24          CatBoost_r69_BAG_L1    0.955969   0.955969    accuracy
# 25          LightGBM_r96_BAG_L1    0.955969   0.955969    accuracy
# 26         LightGBM_r131_BAG_L1    0.955969   0.955969    accuracy
# 27              LightGBM_BAG_L1    0.955969   0.956621    accuracy
# 28         LightGBMLarge_BAG_L1    0.955969   0.956621    accuracy
# 29          WeightedEnsemble_L2    0.955969   0.957599    accuracy
# 30         LightGBM_r130_BAG_L1    0.955969   0.957599    accuracy
# 31            LightGBMXT_BAG_L1    0.955969   0.957273    accuracy
# 32         LightGBM_r188_BAG_L1    0.955969   0.956947    accuracy
# 33          XGBoost_r194_BAG_L1    0.955969   0.957273    accuracy
# 34           XGBoost_r89_BAG_L1    0.955969   0.957273    accuracy
# 35               XGBoost_BAG_L1    0.955969   0.957273    accuracy
# 36           XGBoost_r33_BAG_L1    0.955969   0.956947    accuracy
# 37  NeuralNetFastAI_r102_BAG_L1    0.955969   0.956621    accuracy
# 38        NeuralNetTorch_BAG_L1    0.955969   0.955969    accuracy
# 39    NeuralNetTorch_r79_BAG_L1    0.955969   0.956621    accuracy
# 40    NeuralNetTorch_r30_BAG_L1    0.955969   0.956621    accuracy
# 41       NeuralNetFastAI_BAG_L1    0.955969   0.955643    accuracy
# 42  NeuralNetFastAI_r191_BAG_L1    0.955969   0.956295    accuracy
# 43  NeuralNetFastAI_r145_BAG_L1    0.955969   0.956621    accuracy
# 44   NeuralNetFastAI_r11_BAG_L1    0.955969   0.956621    accuracy
# 45        ExtraTreesEntr_BAG_L2    0.955969   0.955969    accuracy
# 46         LightGBM_r131_BAG_L2    0.955969   0.955969    accuracy
# 47          LightGBM_r96_BAG_L2    0.955969   0.955969    accuracy
# 48              LightGBM_BAG_L2    0.955969   0.957599    accuracy
# 49         LightGBMLarge_BAG_L2    0.955969   0.956621    accuracy
# 50            LightGBMXT_BAG_L2    0.955969   0.956947    accuracy
# 51              CatBoost_BAG_L2    0.955969   0.955969    accuracy
# 52               XGBoost_BAG_L2    0.955969   0.957599    accuracy
# 53        NeuralNetTorch_BAG_L2    0.955643   0.956295    accuracy
# 54  NeuralNetFastAI_r191_BAG_L2    0.955316   0.957926    accuracy
# 55       NeuralNetFastAI_BAG_L2    0.953033   0.955643    accuracy
#
#     pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0         0.038627       0.043877     0.000000                 0.038627
# 1         0.110981       0.099566     0.546892                 0.110981
# 2         0.119904       0.100333     0.592280                 0.119904
# 3         0.124974       0.118347     1.057970                 0.124974
# 4         0.126321       0.100924     0.978678                 0.126321
# 5         0.128382       0.114018     0.679440                 0.128382
# 6         0.134038       0.090709     0.572472                 0.134038
# 7         0.047792       0.018091    60.139861                 0.047792
# 8         0.031563       0.051726    14.478398                 0.031563
# 9         0.032932       0.051343     0.000000                 0.032932
# 10        8.781173       3.889835  1988.088516                 0.000000
# 11        8.781173       3.889835  1987.828037                 0.776759
# 12        0.049294       0.031476    62.661524                 0.049294
# 13        8.147058       3.752168  1715.957544                 0.142645
# 14        0.020100       0.005884    57.272533                 0.020100
# 15        0.035977       0.042932    11.591946                 0.035977
# 16        8.141735       3.584578  1826.970260                 0.137321
# 17        8.148469       3.561214  1736.164538                 0.144056
# 18        0.125886       0.135422     0.761929                 0.125886
# 19        0.258056       0.138199   211.613456                 0.258056
# 20        8.142438       3.724293  1715.849766                 0.138025
# 21        0.437691       0.175355   212.158566                 0.437691
# 22        8.172269       3.697236  1715.800431                 0.167855
# 23        0.015635       0.003944    46.471291                 0.015635
# 24        0.016031       0.029903    15.868154                 0.016031
# 25        0.025874       0.110643     1.179296                 0.025874
# 26        0.032357       0.024927     0.997195                 0.032357
# 27        0.044246       0.032486     0.939840                 0.044246
# 28        0.051335       0.030723     1.529773                 0.051335
# 29        0.073415       0.068066     1.517360                 0.000000
# 30        0.073415       0.068066     1.231036                 0.073415
# 31        0.087994       0.072045     1.235614                 0.087994
# 32        0.092925       0.026886     1.652376                 0.092925
# 33        0.152498       0.045549    14.557563                 0.152498
# 34        0.166248       0.044610    10.509672                 0.166248
# 35        0.174694       0.054514    19.622996                 0.174694
# 36        0.223597       0.050019    11.448325                 0.223597
# 37        0.252264       0.118414    21.519759                 0.252264
# 38        0.263199       0.150964   175.215553                 0.263199
# 39        0.458179       0.154377   209.954798                 0.458179
# 40        0.530836       0.232747   286.610262                 0.530836
# 41        0.633834       0.156115    36.934671                 0.633834
# 42        0.730299       0.280712    64.601139                 0.730299
# 43        1.068233       0.308046    91.436257                 1.068233
# 44        1.088201       0.229155    66.399940                 1.088201
# 45        8.115096       3.698832  1715.798578                 0.110683
# 46        8.160697       3.569788  1716.778537                 0.156284
# 47        8.171088       3.551724  1715.943354                 0.166675
# 48        8.178444       3.587562  1717.057630                 0.174031
# 49        8.214111       3.564216  1718.987031                 0.209698
# 50        8.241127       3.590819  1716.702652                 0.236713
# 51        8.286607       3.593244  1775.979770                 0.282193
# 52        8.603435       3.595341  1731.139680                 0.599021
# 53        8.747865       3.869676  1935.592017                 0.743451
# 54        9.084112       3.728564  1772.997116                 1.079699
# 55        8.934695       3.716138  1763.140601                 0.930281
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.043877           0.000000            1       True
# 1                 0.099566           0.546892            1       True
# 2                 0.100333           0.592280            1       True
# 3                 0.118347           1.057970            1       True
# 4                 0.100924           0.978678            1       True
# 5                 0.114018           0.679440            1       True
# 6                 0.090709           0.572472            1       True
# 7                 0.018091          60.139861            1       True
# 8                 0.051726          14.478398            1       True
# 9                 0.051343           0.000000            1       True
# 10                0.000000           0.260479            3       True
# 11                0.346787         272.806581            2       True
# 12                0.031476          62.661524            1       True
# 13                0.209120           0.936088            2       True
# 14                0.005884          57.272533            1       True
# 15                0.042932          11.591946            1       True
# 16                0.041530         111.948804            2       True
# 17                0.018166          21.143082            2       True
# 18                0.135422           0.761929            1       True
# 19                0.138199         211.613456            1       True
# 20                0.181245           0.828310            2       True
# 21                0.175355         212.158566            1       True
# 22                0.154188           0.778975            2       True
# 23                0.003944          46.471291            1       True
# 24                0.029903          15.868154            1       True
# 25                0.110643           1.179296            1       True
# 26                0.024927           0.997195            1       True
# 27                0.032486           0.939840            1       True
# 28                0.030723           1.529773            1       True
# 29                0.000000           0.286325            2       True
# 30                0.068066           1.231036            1       True
# 31                0.072045           1.235614            1       True
# 32                0.026886           1.652376            1       True
# 33                0.045549          14.557563            1       True
# 34                0.044610          10.509672            1       True
# 35                0.054514          19.622996            1       True
# 36                0.050019          11.448325            1       True
# 37                0.118414          21.519759            1       True
# 38                0.150964         175.215553            1       True
# 39                0.154377         209.954798            1       True
# 40                0.232747         286.610262            1       True
# 41                0.156115          36.934671            1       True
# 42                0.280712          64.601139            1       True
# 43                0.308046          91.436257            1       True
# 44                0.229155          66.399940            1       True
# 45                0.155784           0.777122            2       True
# 46                0.026740           1.757081            2       True
# 47                0.008676           0.921898            2       True
# 48                0.044514           2.036174            2       True
# 49                0.021168           3.965575            2       True
# 50                0.047771           1.681196            2       True
# 51                0.050196          60.958314            2       True
# 52                0.052293          16.118224            2       True
# 53                0.326628         220.570561            2       True
# 54                0.185516          57.975660            2       True
# 55                0.173090          48.119145            2       True
#
#     fit_order
# 0           2
# 1           9
# 2           6
# 3           5
# 4          26
# 5          22
# 6           8
# 7          18
# 8          25
# 9           1
# 10         56
# 11         51
# 12         33
# 13         41
# 14          7
# 15         14
# 16         54
# 17         50
# 18         36
# 19         32
# 20         42
# 21         20
# 22         44
# 23         23
# 24         37
# 25         19
# 26         16
# 27          4
# 28         13
# 29         38
# 30         31
# 31          3
# 32         27
# 33         35
# 34         29
# 35         11
# 36         21
# 37         24
# 38         12
# 39         15
# 40         30
# 41         10
# 42         17
# 43         28
# 44         34
# 45         45
# 46         52
# 47         55
# 48         40
# 49         49
# 50         39
# 51         43
# 52         47
# 53         48
# 54         53
# 55         46

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 3066 rows with 5 shuffle sets...
# 	478.66s	= Expected runtime (95.73s per shuffle set)
# 	285.46s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance    stddev   p_value  n  p99_high   p99_low
# age                  0.002414  0.000592  0.000403  5  0.003634  0.001194
# bmi                  0.002348  0.000425  0.000124  5  0.003224  0.001473
# avg_glucose_level    0.001957  0.000231  0.000023  5  0.002432  0.001482
# smoking_status       0.001239  0.000536  0.003323  5  0.002343  0.000136
# Residence_type       0.001174  0.000438  0.001941  5  0.002075  0.000273
# ever_married         0.000783  0.000292  0.001941  5  0.001383  0.000182
# gender               0.000783  0.000592  0.020897  5  0.002003 -0.000437
# hypertension         0.000522  0.000179  0.001419  5  0.000890  0.000154
# work_type            0.000522  0.000592  0.060122  5  0.001742 -0.000698
# heart_disease        0.000196  0.000292  0.104000  5  0.000796 -0.000405
