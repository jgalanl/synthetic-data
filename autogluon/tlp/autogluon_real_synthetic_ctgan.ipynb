# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/real/synthetic-ctgan.csv')

# %%
drop_columns = [
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]
pz_columns = [column for column in df.columns if 'PZ' in column ]
pdc_columns = [column for column in df.columns if 'PDC' in column]
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD  TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                             33.333333
# 1                           12.500000                              0.000000
# 2                           75.000000                             25.000000
# 3                           16.666667                              0.000000
# 4                           66.666667                              0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD  TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                           -33.333333
# 1                            0.000000                             0.000000
# 2                          -20.000000                             0.000000
# 3                           50.000000                           -20.000000
# 4                          -33.333333                             0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 68 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((376, 68), (94, 68))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/ctgan/v1'
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/synthetic/ctgan/v1"

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 300,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       9.08 GB / 15.71 GB (57.8%)
# Disk Space Avail:   669.61 GB / 933.46 GB (71.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-16 23:51:27,967	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=7128) Running DyStack sub-fit ...
# (_dystack pid=7128) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=7128) Beginning AutoGluon training ... Time limit = 68s
# (_dystack pid=7128) AutoGluon will save models to "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=7128) Train Data Rows:    334
# (_dystack pid=7128) Train Data Columns: 67
# (_dystack pid=7128) Label Column:       ED_2Clases
# (_dystack pid=7128) Problem Type:       binary
# (_dystack pid=7128) Preprocessing data ...
# (_dystack pid=7128) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=7128) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=7128) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=7128) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=7128) Using Feature Generators to preprocess the data ...
# (_dystack pid=7128) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=7128) 	Available Memory:                    8778.46 MB
# (_dystack pid=7128) 	Train Data (Original)  Memory Usage: 0.17 MB (0.0% of available memory)
# (_dystack pid=7128) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=7128) 	Stage 1 Generators:
# (_dystack pid=7128) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=7128) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=7128) 	Stage 2 Generators:
# (_dystack pid=7128) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=7128) 	Stage 3 Generators:
# (_dystack pid=7128) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=7128) 	Stage 4 Generators:
# (_dystack pid=7128) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=7128) 	Stage 5 Generators:
# (_dystack pid=7128) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=7128) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=7128) 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=7128) 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=7128) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=7128) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=7128) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=7128) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=7128) 	0.1s = Fit runtime
# (_dystack pid=7128) 	67 features in original data used to generate 67 features in processed data.
# (_dystack pid=7128) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=7128) Data preprocessing and feature engineering runtime = 0.07s ...
# (_dystack pid=7128) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=7128) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=7128) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=7128) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=7128) User-specified model hyperparameters to be fit:
# (_dystack pid=7128) {
# (_dystack pid=7128) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=7128) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=7128) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=7128) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=7128) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=7128) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=7128) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=7128) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=7128) }
# (_dystack pid=7128) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=7128) Fitting 110 L1 models ...
# (_dystack pid=7128) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 45.06s of the 67.59s of remaining time.
# (_dystack pid=7128) 	0.8466	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.0s	 = Training   runtime
# (_dystack pid=7128) 	0.12s	 = Validation runtime
# (_dystack pid=7128) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 42.51s of the 65.03s of remaining time.
# (_dystack pid=7128) 	0.8507	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.01s	 = Training   runtime
# (_dystack pid=7128) 	0.03s	 = Validation runtime
# (_dystack pid=7128) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 42.45s of the 64.97s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.16%)
# (_ray_fit pid=22868) [1000]	valid_set's binary_logloss: 0.139355
# (_dystack pid=7128) 	0.9619	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	1.39s	 = Training   runtime
# (_dystack pid=7128) 	0.03s	 = Validation runtime
# (_dystack pid=7128) Fitting model: LightGBM_BAG_L1 ... Training model for up to 38.0s of the 60.53s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# (_dystack pid=7128) 	0.9652	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	1.29s	 = Training   runtime
# (_dystack pid=7128) 	0.02s	 = Validation runtime
# (_dystack pid=7128) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 33.53s of the 56.06s of remaining time.
# (_dystack pid=7128) 	0.9362	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.76s	 = Training   runtime
# (_dystack pid=7128) 	0.09s	 = Validation runtime
# (_dystack pid=7128) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 32.64s of the 55.17s of remaining time.
# (_dystack pid=7128) 	0.9392	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.68s	 = Training   runtime
# (_dystack pid=7128) 	0.07s	 = Validation runtime
# (_dystack pid=7128) Fitting model: CatBoost_BAG_L1 ... Training model for up to 31.82s of the 54.35s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.32%)
# (_dystack pid=7128) 	0.9591	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	16.86s	 = Training   runtime
# (_dystack pid=7128) 	0.05s	 = Validation runtime
# (_dystack pid=7128) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 11.75s of the 34.27s of remaining time.
# (_dystack pid=7128) 	0.9343	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.69s	 = Training   runtime
# (_dystack pid=7128) 	0.07s	 = Validation runtime
# (_dystack pid=7128) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 10.93s of the 33.46s of remaining time.
# (_dystack pid=7128) 	0.9316	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.66s	 = Training   runtime
# (_dystack pid=7128) 	0.07s	 = Validation runtime
# (_dystack pid=7128) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 10.14s of the 32.67s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# (_dystack pid=7128) 	0.9455	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	6.84s	 = Training   runtime
# (_dystack pid=7128) 	0.09s	 = Validation runtime
# (_dystack pid=7128) Fitting model: XGBoost_BAG_L1 ... Training model for up to 0.02s of the 22.54s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.49%)
# (_dystack pid=7128) 	0.9023	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	1.2s	 = Training   runtime
# (_dystack pid=7128) 	0.0s	 = Validation runtime
# (_dystack pid=7128) Fitting model: WeightedEnsemble_L2 ... Training model for up to 67.6s of the 17.56s of remaining time.
# (_dystack pid=7128) 	Ensemble Weights: {'XGBoost_BAG_L1': 0.32, 'LightGBM_BAG_L1': 0.28, 'LightGBMXT_BAG_L1': 0.16, 'NeuralNetFastAI_BAG_L1': 0.16, 'CatBoost_BAG_L1': 0.08}
# (_dystack pid=7128) 	0.9672	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.06s	 = Training   runtime
# (_dystack pid=7128) 	0.0s	 = Validation runtime
# (_dystack pid=7128) Fitting 108 L2 models ...
# (_dystack pid=7128) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 17.46s of the 17.4s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# (_dystack pid=7128) 	0.9627	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.87s	 = Training   runtime
# (_dystack pid=7128) 	0.01s	 = Validation runtime
# (_dystack pid=7128) Fitting model: LightGBM_BAG_L2 ... Training model for up to 13.32s of the 13.26s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# (_dystack pid=7128) 	0.9536	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	1.23s	 = Training   runtime
# (_dystack pid=7128) 	0.02s	 = Validation runtime
# (_dystack pid=7128) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 8.85s of the 8.79s of remaining time.
# (_dystack pid=7128) 	0.9561	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.69s	 = Training   runtime
# (_dystack pid=7128) 	0.17s	 = Validation runtime
# (_dystack pid=7128) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 7.94s of the 7.88s of remaining time.
# (_dystack pid=7128) 	0.9604	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.66s	 = Training   runtime
# (_dystack pid=7128) 	0.07s	 = Validation runtime
# (_dystack pid=7128) Fitting model: CatBoost_BAG_L2 ... Training model for up to 7.17s of the 7.11s of remaining time.
# (_dystack pid=7128) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.36%)
# (_dystack pid=7128) 	0.9631	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	5.83s	 = Training   runtime
# (_dystack pid=7128) 	0.07s	 = Validation runtime
# (_dystack pid=7128) Fitting model: WeightedEnsemble_L3 ... Training model for up to 67.6s of the -2.35s of remaining time.
# (_dystack pid=7128) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.318, 'XGBoost_BAG_L1': 0.318, 'LightGBMXT_BAG_L1': 0.091, 'NeuralNetFastAI_BAG_L1': 0.091, 'LightGBMXT_BAG_L2': 0.091, 'ExtraTreesGini_BAG_L1': 0.045, 'CatBoost_BAG_L2': 0.045}
# (_dystack pid=7128) 	0.9673	 = Validation score   (roc_auc)
# (_dystack pid=7128) 	0.07s	 = Training   runtime
# (_dystack pid=7128) 	0.0s	 = Validation runtime
# (_dystack pid=7128) AutoGluon training complete, total runtime = 70.13s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 125.6 rows/s (42 batch size)
# (_dystack pid=7128) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho")
# (_dystack pid=7128) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestGini_BAG_L2       0.950113   0.956146     roc_auc        5.228321       0.821808  31.068452                 0.089861                0.169928           0.694774            2       True         15
# 1           CatBoost_BAG_L2       0.947846   0.963067     roc_auc        5.462402       0.719334  36.205774                 0.323942                0.067453           5.832096            2       True         17
# 2           LightGBM_BAG_L2       0.943311   0.953636     roc_auc        5.264900       0.669168  31.600558                 0.126441                0.017287           1.226880            2       True         14
# 3         LightGBMXT_BAG_L2       0.938776   0.962672     roc_auc        5.648538       0.664697  31.247366                 0.510078                0.012817           0.873689            2       True         13
# 4           LightGBM_BAG_L1       0.934240   0.965218     roc_auc        0.208225       0.020952   1.289205                 0.208225                0.020952           1.289205            1       True          4
# 5   RandomForestEntr_BAG_L2       0.934240   0.960449     roc_auc        5.209240       0.723391  31.035154                 0.070781                0.071511           0.661476            2       True         16
# 6       WeightedEnsemble_L3       0.931973   0.967298     roc_auc        6.004818       0.732151  37.149516                 0.032338                0.000000           0.070054            3       True         18
# 7   RandomForestEntr_BAG_L1       0.922902   0.939167     roc_auc        0.134963       0.072682   0.683049                 0.134963                0.072682           0.683049            1       True          6
# 8         LightGBMXT_BAG_L1       0.922902   0.961883     roc_auc        0.533198       0.026703   1.385652                 0.533198                0.026703           1.385652            1       True          3
# 9       WeightedEnsemble_L2       0.922902   0.967154     roc_auc        4.328214       0.196998  27.638232                 0.007227                0.000000           0.060546            2       True         12
# 10   NeuralNetFastAI_BAG_L1       0.918367   0.945460     roc_auc        2.406604       0.091091   6.835485                 2.406604                0.091091           6.835485            1       True         10
# 11          CatBoost_BAG_L1       0.913832   0.959086     roc_auc        0.990373       0.054228  16.863503                 0.990373                0.054228          16.863503            1       True          7
# 12           XGBoost_BAG_L1       0.905896   0.902270     roc_auc        0.182587       0.004024   1.203840                 0.182587                0.004024           1.203840            1       True         11
# 13  RandomForestGini_BAG_L1       0.900227   0.936191     roc_auc        0.117616       0.089432   0.755165                 0.117616                0.089432           0.755165            1       True          5
# 14    ExtraTreesEntr_BAG_L1       0.899093   0.931601     roc_auc        0.280638       0.074564   0.657412                 0.280638                0.074564           0.657412            1       True          9
# 15    ExtraTreesGini_BAG_L1       0.891156   0.934255     roc_auc        0.177544       0.072335   0.693894                 0.177544                0.072335           0.693894            1       True          8
# 16    KNeighborsDist_BAG_L1       0.816327   0.850724     roc_auc        0.066521       0.029963   0.006011                 0.066521                0.029963           0.006011            1       True          2
# 17    KNeighborsUnif_BAG_L1       0.806122   0.846583     roc_auc        0.040190       0.115907   0.000462                 0.040190                0.115907           0.000462            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	86s	 = DyStack   runtime |	214s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 214s
# AutoGluon will save models to "AutogluonModels/synthetic/ctgan/v1"
# Train Data Rows:    376
# Train Data Columns: 67
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8287.83 MB
# 	Train Data (Original)  Memory Usage: 0.19 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# 	0.1s = Fit runtime
# 	67 features in original data used to generate 67 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 142.32s of the 213.52s of remaining time.
# 	0.8515	 = Validation score   (roc_auc)
# 	0.0s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 138.87s of the 210.07s of remaining time.
# 	0.8555	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 138.8s of the 210.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.16%)
# 	0.9565	 = Validation score   (roc_auc)
# 	1.17s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 134.47s of the 205.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# 	0.956	 = Validation score   (roc_auc)
# 	1.88s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 130.17s of the 201.37s of remaining time.
# 	0.9382	 = Validation score   (roc_auc)
# 	0.82s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 129.18s of the 200.38s of remaining time.
# 	0.9416	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 128.38s of the 199.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.31%)
# 	0.9557	 = Validation score   (roc_auc)
# 	56.47s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 69.49s of the 140.69s of remaining time.
# 	0.9249	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 68.61s of the 139.81s of remaining time.
# 	0.9272	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 67.83s of the 139.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	0.9344	 = Validation score   (roc_auc)
# 	6.31s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 59.04s of the 130.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.48%)
# 	0.9531	 = Validation score   (roc_auc)
# 	3.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 53.34s of the 124.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.9309	 = Validation score   (roc_auc)
# 	20.94s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 29.96s of the 101.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.69%)
# 	0.9397	 = Validation score   (roc_auc)
# 	2.19s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 25.25s of the 96.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.37%)
# 	0.9572	 = Validation score   (roc_auc)
# 	11.34s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 11.49s of the 82.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 213.53s of the 65.52s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.25, 'LightGBM_BAG_L1': 0.25, 'NeuralNetTorch_BAG_L1': 0.25, 'XGBoost_BAG_L1': 0.15, 'CatBoost_BAG_L1': 0.05, 'CatBoost_r177_BAG_L1': 0.05}
# 	0.9649	 = Validation score   (roc_auc)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 65.42s of the 65.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.25%)
# 	0.9608	 = Validation score   (roc_auc)
# 	2.7s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 60.04s of the 59.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.24%)
# 	0.9596	 = Validation score   (roc_auc)
# 	2.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 55.38s of the 55.31s of remaining time.
# 	0.9578	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 54.43s of the 54.36s of remaining time.
# 	0.9541	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 53.64s of the 53.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.46%)
# 	0.963	 = Validation score   (roc_auc)
# 	10.61s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 40.48s of the 40.41s of remaining time.
# 	0.9578	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 39.63s of the 39.56s of remaining time.
# 	0.9568	 = Validation score   (roc_auc)
# 	0.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 38.86s of the 38.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.9527	 = Validation score   (roc_auc)
# 	6.74s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 29.55s of the 29.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.77%)
# 	0.9597	 = Validation score   (roc_auc)
# 	2.96s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 23.57s of the 23.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L2.
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 5.92s of the 5.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.13%)
# 	0.9504	 = Validation score   (roc_auc)
# 	3.32s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 213.53s of the -0.76s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.211, 'CatBoost_BAG_L2': 0.211, 'LightGBMXT_BAG_L1': 0.158, 'NeuralNetTorch_BAG_L1': 0.158, 'LightGBM_BAG_L1': 0.105, 'XGBoost_BAG_L1': 0.053, 'CatBoost_r177_BAG_L1': 0.053, 'XGBoost_BAG_L2': 0.053}
# 	0.9656	 = Validation score   (roc_auc)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 214.61s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 67.1 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/ctgan/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.965594     roc_auc       1.179916  122.023889                0.000000           0.121772            3       True         26
# 1       WeightedEnsemble_L2   0.964915     roc_auc       0.378642   94.907425                0.000000           0.072172            2       True         15
# 2           CatBoost_BAG_L2   0.963020     roc_auc       1.109909  116.849052                0.085239          10.608530            2       True         20
# 3         LightGBMXT_BAG_L2   0.960841     roc_auc       1.028064  108.939557                0.003394           2.699035            2       True         16
# 4            XGBoost_BAG_L2   0.959723     roc_auc       1.066440  109.196379                0.041770           2.955857            2       True         24
# 5           LightGBM_BAG_L2   0.959624     roc_auc       1.052907  108.337731                0.028237           2.097208            2       True         17
# 6     ExtraTreesGini_BAG_L2   0.957799     roc_auc       1.114051  106.950859                0.089381           0.710336            2       True         21
# 7   RandomForestGini_BAG_L2   0.957771     roc_auc       1.113831  107.018053                0.089161           0.777530            2       True         18
# 8      CatBoost_r177_BAG_L1   0.957163     roc_auc       0.045618   11.339912                0.045618          11.339912            1       True         14
# 9     ExtraTreesEntr_BAG_L2   0.956767     roc_auc       1.113978  106.900832                0.089308           0.660310            2       True         22
# 10        LightGBMXT_BAG_L1   0.956484     roc_auc       0.019824    1.166521                0.019824           1.166521            1       True          3
# 11          LightGBM_BAG_L1   0.955974     roc_auc       0.016135    1.884612                0.016135           1.884612            1       True          4
# 12          CatBoost_BAG_L1   0.955720     roc_auc       0.066914   56.472995                0.066914          56.472995            1       True          7
# 13  RandomForestEntr_BAG_L2   0.954050     roc_auc       1.104809  106.907416                0.080139           0.666893            2       True         19
# 14           XGBoost_BAG_L1   0.953060     roc_auc       0.075301    3.032843                0.075301           3.032843            1       True         11
# 15   NeuralNetFastAI_BAG_L2   0.952749     roc_auc       1.154773  112.984662                0.130102           6.744139            2       True         23
# 16     LightGBMLarge_BAG_L2   0.950400     roc_auc       1.033124  109.559541                0.008454           3.319019            2       True         25
# 17  RandomForestEntr_BAG_L1   0.941615     roc_auc       0.081313    0.679474                0.081313           0.679474            1       True          6
# 18     LightGBMLarge_BAG_L1   0.939733     roc_auc       0.018776    2.193935                0.018776           2.193935            1       True         13
# 19  RandomForestGini_BAG_L1   0.938220     roc_auc       0.089982    0.816531                0.089982           0.816531            1       True          5
# 20   NeuralNetFastAI_BAG_L1   0.934414     roc_auc       0.079381    6.305017                0.079381           6.305017            1       True         10
# 21    NeuralNetTorch_BAG_L1   0.930934     roc_auc       0.154850   20.938371                0.154850          20.938371            1       True         12
# 22    ExtraTreesEntr_BAG_L1   0.927227     roc_auc       0.074161    0.658794                0.074161           0.658794            1       True          9
# 23    ExtraTreesGini_BAG_L1   0.924879     roc_auc       0.074361    0.741500                0.074361           0.741500            1       True          8
# 24    KNeighborsDist_BAG_L1   0.855530     roc_auc       0.025453    0.010018                0.025453           0.010018            1       True          2
# 25    KNeighborsUnif_BAG_L1   0.851512     roc_auc       0.202600    0.000000                0.202600           0.000000            1       True          1
# Number of models trained: 26
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.8515123221005575,
#   'KNeighborsDist_BAG_L1': 0.8555300908242085,
#   'LightGBMXT_BAG_L1': 0.956483603542427,
#   'LightGBM_BAG_L1': 0.9559743089154855,
#   'RandomForestGini_BAG_L1': 0.9382197323373794,
#   'RandomForestEntr_BAG_L1': 0.9416150298503241,
#   'CatBoost_BAG_L1': 0.9557196616020146,
#   'ExtraTreesGini_BAG_L1': 0.9248790425261013,
#   'ExtraTreesEntr_BAG_L1': 0.9272274566392213,
#   'NeuralNetFastAI_BAG_L1': 0.9344141697082875,
#   'XGBoost_BAG_L1': 0.9530600118835413,
#   'NeuralNetTorch_BAG_L1': 0.9309339897575193,
#   'LightGBMLarge_BAG_L1': 0.9397334691452338,
#   'CatBoost_r177_BAG_L1': 0.957162663045016,
#   'WeightedEnsemble_L2': 0.9649152590329061,
#   'LightGBMXT_BAG_L2': 0.9608409020173725,
#   'LightGBM_BAG_L2': 0.9596242537419009,
#   'RandomForestGini_BAG_L2': 0.9577709871827519,
#   'RandomForestEntr_BAG_L2': 0.9540503069914835,
#   'CatBoost_BAG_L2': 0.9630195512548453,
#   'ExtraTreesGini_BAG_L2': 0.9577992813286931,
#   'ExtraTreesEntr_BAG_L2': 0.9567665450018391,
#   'NeuralNetFastAI_BAG_L2': 0.9527487762781881,
#   'XGBoost_BAG_L2': 0.959723283252695,
#   'LightGBMLarge_BAG_L2': 0.9504003621650681,
#   'WeightedEnsemble_L3': 0.9655943185354949},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.010018110275268555,
#   'LightGBMXT_BAG_L1': 1.1665213108062744,
#   'LightGBM_BAG_L1': 1.8846118450164795,
#   'RandomForestGini_BAG_L1': 0.8165309429168701,
#   'RandomForestEntr_BAG_L1': 0.6794741153717041,
#   'CatBoost_BAG_L1': 56.472994565963745,
#   'ExtraTreesGini_BAG_L1': 0.7414999008178711,
#   'ExtraTreesEntr_BAG_L1': 0.6587941646575928,
#   'NeuralNetFastAI_BAG_L1': 6.305016994476318,
#   'XGBoost_BAG_L1': 3.0328431129455566,
#   'NeuralNetTorch_BAG_L1': 20.93837070465088,
#   'LightGBMLarge_BAG_L1': 2.193934679031372,
#   'CatBoost_r177_BAG_L1': 11.339912176132202,
#   'WeightedEnsemble_L2': 0.07217168807983398,
#   'LightGBMXT_BAG_L2': 2.6990346908569336,
#   'LightGBM_BAG_L2': 2.097208023071289,
#   'RandomForestGini_BAG_L2': 0.7775299549102783,
#   'RandomForestEntr_BAG_L2': 0.6668932437896729,
#   'CatBoost_BAG_L2': 10.608529806137085,
#   'ExtraTreesGini_BAG_L2': 0.7103362083435059,
#   'ExtraTreesEntr_BAG_L2': 0.6603097915649414,
#   'NeuralNetFastAI_BAG_L2': 6.744138956069946,
#   'XGBoost_BAG_L2': 2.9558568000793457,
#   'LightGBMLarge_BAG_L2': 3.319018602371216,
#   'WeightedEnsemble_L3': 0.12177181243896484},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.20260024070739746,
#   'KNeighborsDist_BAG_L1': 0.02545309066772461,
#   'LightGBMXT_BAG_L1': 0.01982426643371582,
#   'LightGBM_BAG_L1': 0.01613473892211914,
#   'RandomForestGini_BAG_L1': 0.0899817943572998,
#   'RandomForestEntr_BAG_L1': 0.0813133716583252,
#   'CatBoost_BAG_L1': 0.06691360473632812,
#   'ExtraTreesGini_BAG_L1': 0.07436060905456543,
#   'ExtraTreesEntr_BAG_L1': 0.07416105270385742,
#   'NeuralNetFastAI_BAG_L1': 0.07938146591186523,
#   'XGBoost_BAG_L1': 0.0753011703491211,
#   'NeuralNetTorch_BAG_L1': 0.15485024452209473,
#   'LightGBMLarge_BAG_L1': 0.018776416778564453,
#   'CatBoost_r177_BAG_L1': 0.04561805725097656,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.0033936500549316406,
#   'LightGBM_BAG_L2': 0.028236865997314453,
#   'RandomForestGini_BAG_L2': 0.08916091918945312,
#   'RandomForestEntr_BAG_L2': 0.0801386833190918,
#   'CatBoost_BAG_L2': 0.08523917198181152,
#   'ExtraTreesGini_BAG_L2': 0.08938074111938477,
#   'ExtraTreesEntr_BAG_L2': 0.08930754661560059,
#   'NeuralNetFastAI_BAG_L2': 0.13010239601135254,
#   'XGBoost_BAG_L2': 0.041770219802856445,
#   'LightGBMLarge_BAG_L2': 0.008453607559204102,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0       WeightedEnsemble_L3   0.965594     roc_auc       1.179916  122.023889
#  1       WeightedEnsemble_L2   0.964915     roc_auc       0.378642   94.907425
#  2           CatBoost_BAG_L2   0.963020     roc_auc       1.109909  116.849052
#  3         LightGBMXT_BAG_L2   0.960841     roc_auc       1.028064  108.939557
#  4            XGBoost_BAG_L2   0.959723     roc_auc       1.066440  109.196379
#  5           LightGBM_BAG_L2   0.959624     roc_auc       1.052907  108.337731
#  6     ExtraTreesGini_BAG_L2   0.957799     roc_auc       1.114051  106.950859
#  7   RandomForestGini_BAG_L2   0.957771     roc_auc       1.113831  107.018053
#  8      CatBoost_r177_BAG_L1   0.957163     roc_auc       0.045618   11.339912
#  9     ExtraTreesEntr_BAG_L2   0.956767     roc_auc       1.113978  106.900832
#  10        LightGBMXT_BAG_L1   0.956484     roc_auc       0.019824    1.166521
#  11          LightGBM_BAG_L1   0.955974     roc_auc       0.016135    1.884612
#  12          CatBoost_BAG_L1   0.955720     roc_auc       0.066914   56.472995
#  13  RandomForestEntr_BAG_L2   0.954050     roc_auc       1.104809  106.907416
#  14           XGBoost_BAG_L1   0.953060     roc_auc       0.075301    3.032843
#  15   NeuralNetFastAI_BAG_L2   0.952749     roc_auc       1.154773  112.984662
#  16     LightGBMLarge_BAG_L2   0.950400     roc_auc       1.033124  109.559541
#  17  RandomForestEntr_BAG_L1   0.941615     roc_auc       0.081313    0.679474
#  18     LightGBMLarge_BAG_L1   0.939733     roc_auc       0.018776    2.193935
#  19  RandomForestGini_BAG_L1   0.938220     roc_auc       0.089982    0.816531
#  20   NeuralNetFastAI_BAG_L1   0.934414     roc_auc       0.079381    6.305017
#  21    NeuralNetTorch_BAG_L1   0.930934     roc_auc       0.154850   20.938371
#  22    ExtraTreesEntr_BAG_L1   0.927227     roc_auc       0.074161    0.658794
#  23    ExtraTreesGini_BAG_L1   0.924879     roc_auc       0.074361    0.741500
#  24    KNeighborsDist_BAG_L1   0.855530     roc_auc       0.025453    0.010018
#  25    KNeighborsUnif_BAG_L1   0.851512     roc_auc       0.202600    0.000000
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.121772            3       True
#  1                 0.000000           0.072172            2       True
#  2                 0.085239          10.608530            2       True
#  3                 0.003394           2.699035            2       True
#  4                 0.041770           2.955857            2       True
#  5                 0.028237           2.097208            2       True
#  6                 0.089381           0.710336            2       True
#  7                 0.089161           0.777530            2       True
#  8                 0.045618          11.339912            1       True
#  9                 0.089308           0.660310            2       True
#  10                0.019824           1.166521            1       True
#  11                0.016135           1.884612            1       True
#  12                0.066914          56.472995            1       True
#  13                0.080139           0.666893            2       True
#  14                0.075301           3.032843            1       True
#  15                0.130102           6.744139            2       True
#  16                0.008454           3.319019            2       True
#  17                0.081313           0.679474            1       True
#  18                0.018776           2.193935            1       True
#  19                0.089982           0.816531            1       True
#  20                0.079381           6.305017            1       True
#  21                0.154850          20.938371            1       True
#  22                0.074161           0.658794            1       True
#  23                0.074361           0.741500            1       True
#  24                0.025453           0.010018            1       True
#  25                0.202600           0.000000            1       True
#
#      fit_order
#  0          26
#  1          15
#  2          20
#  3          16
#  4          24
#  5          17
#  6          21
#  7          18
#  8          14
#  9          22
#  10          3
#  11          4
#  12          7
#  13         19
#  14         11
#  15         23
#  16         25
#  17          6
#  18         13
#  19          5
#  20         10
#  21         12
#  22          9
#  23          8
#  24          2
#  25          1  }

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9637681159420289
# Evaluations on test data:
# {
#     "roc_auc": 0.9637681159420289,
#     "accuracy": 0.851063829787234,
#     "balanced_accuracy": 0.850090579710145,
#     "mcc": 0.7040177972327167,
#     "f1": 0.86,
#     "precision": 0.8269230769230769,
#     "recall": 0.8958333333333334
# }
# {'roc_auc': 0.9637681159420289,
#  'accuracy': 0.851063829787234,
#  'balanced_accuracy': 0.850090579710145,
#  'mcc': 0.7040177972327167,
#  'f1': 0.86,
#  'precision': 0.8269230769230769,
#  'recall': 0.8958333333333334}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                       model  score_test  balanced_accuracy        f1  \
# 0           LightGBM_BAG_L1    1.000000           1.000000  1.000000
# 1     KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 2      LightGBMLarge_BAG_L1    1.000000           1.000000  1.000000
# 3         LightGBMXT_BAG_L1    1.000000           1.000000  1.000000
# 4      CatBoost_r177_BAG_L1    1.000000           1.000000  1.000000
# 5     ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 6   RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 7           CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 8     ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 9   RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# 10           XGBoost_BAG_L1    1.000000           1.000000  1.000000
# 11    NeuralNetTorch_BAG_L1    1.000000           0.991979  0.991914
# 12      WeightedEnsemble_L2    1.000000           1.000000  1.000000
# 13          LightGBM_BAG_L2    1.000000           1.000000  1.000000
# 14          CatBoost_BAG_L2    1.000000           1.000000  1.000000
# 15    ExtraTreesEntr_BAG_L2    1.000000           1.000000  1.000000
# 16  RandomForestGini_BAG_L2    1.000000           1.000000  1.000000
# 17           XGBoost_BAG_L2    1.000000           1.000000  1.000000
# 18    ExtraTreesGini_BAG_L2    1.000000           1.000000  1.000000
# 19        LightGBMXT_BAG_L2    1.000000           1.000000  1.000000
# 20      WeightedEnsemble_L3    1.000000           1.000000  1.000000
# 21  RandomForestEntr_BAG_L2    1.000000           1.000000  1.000000
# 22     LightGBMLarge_BAG_L2    1.000000           1.000000  1.000000
# 23   NeuralNetFastAI_BAG_L2    1.000000           1.000000  1.000000
# 24   NeuralNetFastAI_BAG_L1    0.999547           0.986744  0.986737
# 25    KNeighborsUnif_BAG_L1    0.936565           0.864117  0.857143
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 5   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 6   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 7   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 8   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 9   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 10  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 11  0.992020  0.992021  1.000000           1.000000   1.000000  0.983957  ...
# 12  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 13  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 14  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 15  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 16  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 17  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 18  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 19  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 20  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 21  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 22  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 23  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 24  0.986702  0.986702  0.999547           0.999546   0.978947  0.994652  ...
# 25  0.864014  0.864362  0.936565           0.920774   0.900000  0.818182  ...
#
#     eval_metric  pred_time_test  pred_time_val    fit_time  \
# 0       roc_auc        0.028651       0.016135    1.884612
# 1       roc_auc        0.028673       0.025453    0.010018
# 2       roc_auc        0.052878       0.018776    2.193935
# 3       roc_auc        0.065609       0.019824    1.166521
# 4       roc_auc        0.072348       0.045618   11.339912
# 5       roc_auc        0.078974       0.074161    0.658794
# 6       roc_auc        0.080205       0.081313    0.679474
# 7       roc_auc        0.090302       0.066914   56.472995
# 8       roc_auc        0.095718       0.074361    0.741500
# 9       roc_auc        0.117865       0.089982    0.816531
# 10      roc_auc        0.133481       0.075301    3.032843
# 11      roc_auc        0.280559       0.154850   20.938371
# 12      roc_auc        0.670951       0.378642   94.907425
# 13      roc_auc        1.351803       1.052907  108.337731
# 14      roc_auc        1.403919       1.109909  116.849052
# 15      roc_auc        1.425020       1.113978  106.900832
# 16      roc_auc        1.478111       1.113831  107.018053
# 17      roc_auc        1.482204       1.066440  109.196379
# 18      roc_auc        1.514802       1.114051  106.950859
# 19      roc_auc        1.540425       1.028064  108.939557
# 20      roc_auc        1.580901       1.179916  122.023889
# 21      roc_auc        1.581980       1.104809  106.907416
# 22      roc_auc        1.641368       1.033124  109.559541
# 23      roc_auc        1.723743       1.154773  112.984662
# 24      roc_auc        0.141849       0.079381    6.305017
# 25      roc_auc        0.065264       0.202600    0.000000
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.028651                0.016135           1.884612
# 1                  0.028673                0.025453           0.010018
# 2                  0.052878                0.018776           2.193935
# 3                  0.065609                0.019824           1.166521
# 4                  0.072348                0.045618          11.339912
# 5                  0.078974                0.074161           0.658794
# 6                  0.080205                0.081313           0.679474
# 7                  0.090302                0.066914          56.472995
# 8                  0.095718                0.074361           0.741500
# 9                  0.117865                0.089982           0.816531
# 10                 0.133481                0.075301           3.032843
# 11                 0.280559                0.154850          20.938371
# 12                 0.000000                0.000000           0.072172
# 13                 0.019427                0.028237           2.097208
# 14                 0.071543                0.085239          10.608530
# 15                 0.092644                0.089308           0.660310
# 16                 0.145735                0.089161           0.777530
# 17                 0.149828                0.041770           2.955857
# 18                 0.182426                0.089381           0.710336
# 19                 0.208049                0.003394           2.699035
# 20                 0.007726                0.000000           0.121772
# 21                 0.249604                0.080139           0.666893
# 22                 0.308993                0.008454           3.319019
# 23                 0.391367                0.130102           6.744139
# 24                 0.141849                0.079381           6.305017
# 25                 0.065264                0.202600           0.000000
#
#     stack_level  can_infer  fit_order
# 0             1       True          4
# 1             1       True          2
# 2             1       True         13
# 3             1       True          3
# 4             1       True         14
# 5             1       True          9
# 6             1       True          6
# 7             1       True          7
# 8             1       True          8
# 9             1       True          5
# 10            1       True         11
# 11            1       True         12
# 12            2       True         15
# 13            2       True         17
# 14            2       True         20
# 15            2       True         22
# 16            2       True         18
# 17            2       True         24
# 18            2       True         21
# 19            2       True         16
# 20            3       True         26
# 21            2       True         19
# 22            2       True         25
# 23            2       True         23
# 24            1       True         10
# 25            1       True          1
#
# [26 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 67 features using 376 rows with 5 shuffle sets...
# 	510.45s	= Expected runtime (102.09s per shuffle set)
# 	60.65s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.Stroop.color.PD                       0.003588  0.000942  0.000521  5
# TLP.Tavec.27_RL-CP_frente_RI-A5.PD        0.000481  0.000410  0.029303  5
# ISC.FPacientes.Edad                       0.000323  0.000217  0.014630  5
# TLP.Stroop.palabras.PD                    0.000062  0.000099  0.115893  5
# TLP.CubCorsi.Directos.PD                  0.000006  0.000013  0.186950  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Memoria.PD                       0.000000  0.000000  0.500000  5
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.Stroop.color.PD                     0.005527  0.001649
# TLP.Tavec.27_RL-CP_frente_RI-A5.PD      0.001325 -0.000363
# ISC.FPacientes.Edad                     0.000769 -0.000124
# TLP.Stroop.palabras.PD                  0.000266 -0.000141
# TLP.CubCorsi.Directos.PD                0.000032 -0.000020
# ...                                          ...       ...
# TLP.MMSE.Memoria.PD                     0.000000  0.000000
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [67 rows x 6 columns]
# 2025-01-17 00:02:18,775	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:02:18,821	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:02:18,866	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:03:19,358	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:03:19,390	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:03:19,421	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
