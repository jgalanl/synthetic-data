# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('../../data/tlp/TLP_Identia.xlsx')

# %%
drop_columns = [
    'ISC.FPacientes.IDUsuario',
    'ISC.FPacientes.etiquetaDiagnosticaExpTLP',
    'ISC.FPacientes.etiquetaDiagnostica',
    'ED_MMSE_2Clases',
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos',
    'ISC.resultadosWFQ.DE_array'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]

# %%
pz_columns = [column for column in df.columns if 'PZ' in column ]

# %%
pdc_columns = [column for column in df.columns if 'PDC' in column]

# %%
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                            33.333333
# 1                           12.500000                             0.000000
# 2                           75.000000                            25.000000
# 3                           16.666667                             0.000000
# 4                           66.666667                             0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                          -33.333333
# 1                            0.000000                            0.000000
# 2                          -20.000000                            0.000000
# 3                           50.000000                          -20.000000
# 4                          -33.333333                            0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 70 columns]

# %%
df_train, df_test=train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((247, 70), (62, 70))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/real/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       9.60 GB / 15.94 GB (60.2%)
# Disk Space Avail:   137.77 GB / 446.36 GB (30.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 13:00:00,752	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/real/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14028) Running DyStack sub-fit ...
# (_dystack pid=14028) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=14028) Beginning AutoGluon training ... Time limit = 894s
# (_dystack pid=14028) AutoGluon will save models to "AutogluonModels/real/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14028) Train Data Rows:    219
# (_dystack pid=14028) Train Data Columns: 69
# (_dystack pid=14028) Label Column:       ED_2Clases
# (_dystack pid=14028) Problem Type:       binary
# (_dystack pid=14028) Preprocessing data ...
# (_dystack pid=14028) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=14028) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=14028) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=14028) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=14028) Using Feature Generators to preprocess the data ...
# (_dystack pid=14028) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=14028) 	Available Memory:                    9190.89 MB
# (_dystack pid=14028) 	Train Data (Original)  Memory Usage: 0.14 MB (0.0% of available memory)
# (_dystack pid=14028) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=14028) 	Stage 1 Generators:
# (_dystack pid=14028) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=14028) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=14028) 	Stage 2 Generators:
# (_dystack pid=14028) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=14028) 	Stage 3 Generators:
# (_dystack pid=14028) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=14028) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=14028) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=14028) 	Stage 4 Generators:
# (_dystack pid=14028) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=14028) 	Stage 5 Generators:
# (_dystack pid=14028) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=14028) 	Unused Original Features (Count: 1): ['ISC.resultadosWFQ.NO_array']
# (_dystack pid=14028) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=14028) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=14028) 		These features do not need to be present at inference time.
# (_dystack pid=14028) 		('object', []) : 1 | ['ISC.resultadosWFQ.NO_array']
# (_dystack pid=14028) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=14028) 		('float', [])  : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=14028) 		('int', [])    : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=14028) 		('object', []) :  1 | ['ISC.resultadosWFQ.SA_array']
# (_dystack pid=14028) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=14028) 		('category', [])  :  1 | ['ISC.resultadosWFQ.SA_array']
# (_dystack pid=14028) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=14028) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=14028) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=14028) 	0.1s = Fit runtime
# (_dystack pid=14028) 	68 features in original data used to generate 68 features in processed data.
# (_dystack pid=14028) 	Train Data (Processed) Memory Usage: 0.10 MB (0.0% of available memory)
# (_dystack pid=14028) Data preprocessing and feature engineering runtime = 0.15s ...
# (_dystack pid=14028) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=14028) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=14028) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=14028) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=14028) User-specified model hyperparameters to be fit:
# (_dystack pid=14028) {
# (_dystack pid=14028) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=14028) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=14028) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=14028) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=14028) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=14028) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14028) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14028) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=14028) }
# (_dystack pid=14028) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=14028) Fitting 110 L1 models ...
# (_dystack pid=14028) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 595.57s of the 893.56s of remaining time.
# (_dystack pid=14028) 	0.7209	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.01s	 = Training   runtime
# (_dystack pid=14028) 	0.1s	 = Validation runtime
# (_dystack pid=14028) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 593.22s of the 891.21s of remaining time.
# (_dystack pid=14028) 	0.7187	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.0s	 = Training   runtime
# (_dystack pid=14028) 	0.02s	 = Validation runtime
# (_dystack pid=14028) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 593.18s of the 891.17s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=14028) 	0.9294	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.33s	 = Training   runtime
# (_dystack pid=14028) 	0.03s	 = Validation runtime
# (_dystack pid=14028) Fitting model: LightGBM_BAG_L1 ... Training model for up to 588.68s of the 886.67s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=14028) 	0.92	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.79s	 = Training   runtime
# (_dystack pid=14028) 	0.03s	 = Validation runtime
# (_dystack pid=14028) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 584.45s of the 882.45s of remaining time.
# (_dystack pid=14028) 	0.9003	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.82s	 = Training   runtime
# (_dystack pid=14028) 	0.08s	 = Validation runtime
# (_dystack pid=14028) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 583.52s of the 881.51s of remaining time.
# (_dystack pid=14028) 	0.8976	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.51s	 = Training   runtime
# (_dystack pid=14028) 	0.08s	 = Validation runtime
# (_dystack pid=14028) Fitting model: CatBoost_BAG_L1 ... Training model for up to 582.9s of the 880.89s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=14028) 	0.9353	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	468.72s	 = Training   runtime
# (_dystack pid=14028) 	0.71s	 = Validation runtime
# (_dystack pid=14028) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 107.74s of the 405.73s of remaining time.
# (_dystack pid=14028) 	0.8545	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.46s	 = Training   runtime
# (_dystack pid=14028) 	0.49s	 = Validation runtime
# (_dystack pid=14028) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 103.44s of the 401.43s of remaining time.
# (_dystack pid=14028) 	0.8589	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.34s	 = Training   runtime
# (_dystack pid=14028) 	0.08s	 = Validation runtime
# (_dystack pid=14028) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 100.86s of the 398.85s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=14028) 	0.9078	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	21.76s	 = Training   runtime
# (_dystack pid=14028) 	0.15s	 = Validation runtime
# (_dystack pid=14028) Fitting model: XGBoost_BAG_L1 ... Training model for up to 60.13s of the 358.12s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.88%)
# (_dystack pid=14028) 	0.9173	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	6.31s	 = Training   runtime
# (_dystack pid=14028) 	0.06s	 = Validation runtime
# (_dystack pid=14028) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 30.45s of the 328.44s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=22692) Stack (most recent call first):
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=22692)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=22692)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=22928)   File "<frozen importlib._bootstrap>", line 1027 in
# (_ray_fit pid=22928) _find_and_load
# (_ray_fit pid=22928)   File
# (_ray_fit pid=22928) "<frozen importlib._bootstrap>
# (_ray_fit pid=22928) ", line
# (_ray_fit pid=22928) 241 in _call_with_frames_removed
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>
# (_ray_fit pid=22928) ", line
# (_ray_fit pid=22928) 992 in
# (_ray_fit pid=22928) _find_and_load_unlocked
# (_ray_fit pid=22928)   File
# (_ray_fit pid=22928) "<frozen importlib._bootstrap>", line 1027 in
# (_ray_fit pid=22928) _find_and_load
# (_ray_fit pid=22928)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py"
# (_ray_fit pid=22928) , line 13
# (_ray_fit pid=22928)  in <module>
# (_ray_fit pid=22928)
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>"
# (_ray_fit pid=22928) , line 241
# (_ray_fit pid=22928)  in _call_with_frames_removed
# (_ray_fit pid=22928)
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap_external>"
# (_ray_fit pid=22928) , line 883
# (_ray_fit pid=22928)  in exec_module
# (_ray_fit pid=22928)
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>"
# (_ray_fit pid=22928) , line 688
# (_ray_fit pid=22928)  in _load_unlocked
# (_ray_fit pid=22928)
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>"
# (_ray_fit pid=22928) , line 1006
# (_ray_fit pid=22928)  in _find_and_load_unlocked
# (_ray_fit pid=22928)   File "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>"
# (_ray_fit pid=22928) , line
# (_ray_fit pid=22928) 1027 in
# (_ray_fit pid=22928) _find_and_load
# (_ray_fit pid=22928)   File
# (_ray_fit pid=22928) "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34
# (_ray_fit pid=22928)  in
# (_ray_fit pid=22928) <module>
# (_ray_fit pid=22928)
# (_ray_fit pid=22928)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=22928) , line 241
# (_ray_fit pid=22928)  in _call_with_frames_removed
# (_ray_fit pid=22928)   File "<frozen importlib._bootstrap_external>"
# (_ray_fit pid=22928) , line 883
# (_ray_fit pid=22928)  in exec_module
# (_ray_fit pid=22928)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=22928) ", line
# (_ray_fit pid=22928) 688 in
# (_ray_fit pid=22928) _load_unlocked
# (_ray_fit pid=22928)   File
# (_ray_fit pid=22928) "
# (_ray_fit pid=22928) <frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_dystack pid=14028) 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# (_ray_fit pid=15656) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 81x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 61x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 67x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 67x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 54x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 6x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 6x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=15656)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_dystack pid=14028) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 257.48s of remaining time.
# (_dystack pid=14028) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.471, 'NeuralNetFastAI_BAG_L1': 0.294, 'XGBoost_BAG_L1': 0.118, 'LightGBM_BAG_L1': 0.059, 'CatBoost_BAG_L1': 0.059}
# (_dystack pid=14028) 	0.9538	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.16s	 = Training   runtime
# (_dystack pid=14028) 	0.0s	 = Validation runtime
# (_dystack pid=14028) Fitting 108 L2 models ...
# (_dystack pid=14028) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 257.3s of the 257.17s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_ray_fit pid=11160) [1000]	valid_set's binary_logloss: 0.0412275
# (_dystack pid=14028) 	0.9535	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	8.16s	 = Training   runtime
# (_dystack pid=14028) 	0.04s	 = Validation runtime
# (_dystack pid=14028) Fitting model: LightGBM_BAG_L2 ... Training model for up to 214.7s of the 214.57s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# (_dystack pid=14028) 	0.9345	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	4.43s	 = Training   runtime
# (_dystack pid=14028) 	0.04s	 = Validation runtime
# (_dystack pid=14028) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 194.74s of the 194.61s of remaining time.
# (_dystack pid=14028) 	0.9314	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.05s	 = Training   runtime
# (_dystack pid=14028) 	0.16s	 = Validation runtime
# (_dystack pid=14028) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 193.47s of the 193.35s of remaining time.
# (_dystack pid=14028) 	0.9208	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.05s	 = Training   runtime
# (_dystack pid=14028) 	0.16s	 = Validation runtime
# (_dystack pid=14028) Fitting model: CatBoost_BAG_L2 ... Training model for up to 192.19s of the 192.06s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=14028) 	0.9453	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	86.29s	 = Training   runtime
# (_dystack pid=14028) 	0.08s	 = Validation runtime
# (_dystack pid=14028) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 96.11s of the 95.98s of remaining time.
# (_dystack pid=14028) 	0.9193	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.01s	 = Training   runtime
# (_dystack pid=14028) 	0.21s	 = Validation runtime
# (_dystack pid=14028) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 94.82s of the 94.7s of remaining time.
# (_dystack pid=14028) 	0.9304	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	1.12s	 = Training   runtime
# (_dystack pid=14028) 	0.21s	 = Validation runtime
# (_dystack pid=14028) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 93.43s of the 93.3s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=14028) 	0.9263	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	24.44s	 = Training   runtime
# (_dystack pid=14028) 	0.17s	 = Validation runtime
# (_dystack pid=14028) Fitting model: XGBoost_BAG_L2 ... Training model for up to 55.89s of the 55.77s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# (_dystack pid=14028) 	0.9263	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	10.3s	 = Training   runtime
# (_dystack pid=14028) 	0.07s	 = Validation runtime
# (_dystack pid=14028) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 32.04s of the 31.91s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=14028) 	Warning: Exception caused NeuralNetTorch_BAG_L2 to fail during training... Skipping this model.
# (_dystack pid=14028) 		ray::_ray_fit() (pid=19500, ip=127.0.0.1)
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=14028)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=14028)     out = self._fit(**kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 147, in _fit
# (_dystack pid=14028)     try_import_torch()
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\common\utils\try_import.py", line 127, in try_import_torch
# (_dystack pid=14028)     import torch
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\__init__.py", line 132, in <module>
# (_dystack pid=14028)     raise err
# (_dystack pid=14028) OSError: [WinError 1455] El archivo de paginación es demasiado pequeño para completar la operación. Error loading "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\lib\cudnn_adv_infer64_8.dll" or one of its dependencies.
# (_dystack pid=14028) Detailed Traceback:
# (_dystack pid=14028) Traceback (most recent call last):
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=14028)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=14028)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=14028)     out = self._fit(**kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 165, in _fit
# (_dystack pid=14028)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 288, in _fit
# (_dystack pid=14028)     self._fit_folds(
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 714, in _fit_folds
# (_dystack pid=14028)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
# (_dystack pid=14028)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 610, in _run_parallel
# (_dystack pid=14028)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 572, in _process_fold_results
# (_dystack pid=14028)     raise processed_exception
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 537, in _process_fold_results
# (_dystack pid=14028)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=14028)     return fn(*args, **kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=14028)     return func(*args, **kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 2667, in get
# (_dystack pid=14028)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
# (_dystack pid=14028)     raise value.as_instanceof_cause()
# (_dystack pid=14028) ray.exceptions.RayTaskError(OSError): ray::_ray_fit() (pid=19500, ip=127.0.0.1)
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=14028)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=14028)     out = self._fit(**kwargs)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 147, in _fit
# (_dystack pid=14028)     try_import_torch()
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\common\utils\try_import.py", line 127, in try_import_torch
# (_dystack pid=14028)     import torch
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\__init__.py", line 132, in <module>
# (_dystack pid=14028)     raise err
# (_dystack pid=14028) OSError: [WinError 1455] El archivo de paginación es demasiado pequeño para completar la operación. Error loading "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\lib\cudnn_adv_infer64_8.dll" or one of its dependencies.
# (_ray_fit pid=30756) Unable to allocate internal buffer.
# (_ray_fit pid=30756)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
# (_ray_fit pid=30756)     obj = self._deserialize_object(data, metadata, object_ref)
# (_ray_fit pid=30756)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
# (_ray_fit pid=30756)     return self._deserialize_msgpack_data(data, metadata_fields)
# (_ray_fit pid=30756)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
# (_ray_fit pid=30756)     msgpack_data, pickle5_data = split_buffer(data)
# (_ray_fit pid=30756)   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
# (_ray_fit pid=30756)   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# (_ray_fit pid=30756) MemoryError: Unable to allocate internal buffer.
# (_dystack pid=14028) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 11.84s of the 11.71s of remaining time.
# (_dystack pid=14028) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.43%)
# (_dystack pid=14028) 	0.9341	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	7.57s	 = Training   runtime
# (_dystack pid=14028) 	0.05s	 = Validation runtime
# (_ray_fit pid=24664) Traceback (most recent call last): [repeated 2x across cluster]
# (_ray_fit pid=24664) Unable to allocate internal buffer.
# (_ray_fit pid=24664)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
# (_ray_fit pid=24664)     obj = self._deserialize_object(data, metadata, object_ref)
# (_ray_fit pid=24664)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
# (_ray_fit pid=24664)     return self._deserialize_msgpack_data(data, metadata_fields)
# (_ray_fit pid=24664)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
# (_ray_fit pid=24664)     msgpack_data, pickle5_data = split_buffer(data)
# (_ray_fit pid=24664)   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
# (_ray_fit pid=24664)   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# (_ray_fit pid=24664) MemoryError: Unable to allocate internal buffer.
# (_dystack pid=14028) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -14.64s of remaining time.
# (_dystack pid=14028) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.409, 'LightGBMLarge_BAG_L2': 0.273, 'LightGBMXT_BAG_L1': 0.182, 'NeuralNetFastAI_BAG_L1': 0.136}
# (_dystack pid=14028) 	0.9605	 = Validation score   (roc_auc)
# (_dystack pid=14028) 	0.22s	 = Training   runtime
# (_dystack pid=14028) 	0.0s	 = Validation runtime
# (_dystack pid=14028) AutoGluon training complete, total runtime = 908.61s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 23.8 rows/s (28 batch size)
# (_dystack pid=14028) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/real/v1\ds_sub_fit\sub_fit_ho")
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=24664, ip=127.0.0.1)
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1836, in ray._raylet.execute_task
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1870, in ray._raylet.execute_task
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 968, in ray._raylet.raise_if_dependency_failed
# (_dystack pid=14028) ray.exceptions.RaySystemError: System error: Unable to allocate internal buffer.
# (_dystack pid=14028) traceback: Traceback (most recent call last):
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
# (_dystack pid=14028)     obj = self._deserialize_object(data, metadata, object_ref)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
# (_dystack pid=14028)     return self._deserialize_msgpack_data(data, metadata_fields)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
# (_dystack pid=14028)     msgpack_data, pickle5_data = split_buffer(data)
# (_dystack pid=14028)   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
# (_dystack pid=14028)   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# (_dystack pid=14028) MemoryError: Unable to allocate internal buffer.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=14028) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=30756, ip=127.0.0.1)
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1836, in ray._raylet.execute_task
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 1870, in ray._raylet.execute_task
# (_dystack pid=14028)   File "python\ray\_raylet.pyx", line 968, in ray._raylet.raise_if_dependency_failed
# (_dystack pid=14028) ray.exceptions.RaySystemError: System error: Unable to allocate internal buffer.
# (_dystack pid=14028) traceback: Traceback (most recent call last):
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
# (_dystack pid=14028)     obj = self._deserialize_object(data, metadata, object_ref)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
# (_dystack pid=14028)     return self._deserialize_msgpack_data(data, metadata_fields)
# (_dystack pid=14028)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
# (_dystack pid=14028)     msgpack_data, pickle5_data = split_buffer(data)
# (_dystack pid=14028)   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
# (_dystack pid=14028)   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# (_dystack pid=14028) MemoryError: Unable to allocate internal buffer.
# (_dystack pid=14028) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L1       0.972789   0.919956     roc_auc        0.289471       0.026913    0.789211                 0.289471                0.026913           0.789211            1       True          4
# ...
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2662.17s of the 2662.14s of remaining time.
# 	0.7163	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2650.51s of the 2650.48s of remaining time.
# 	0.7133	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2650.3s of the 2650.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	0.9476	 = Validation score   (roc_auc)
# 	5.67s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2627.2s of the 2627.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	0.9373	 = Validation score   (roc_auc)
# 	7.49s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2605.11s of the 2605.09s of remaining time.
# 	0.9075	 = Validation score   (roc_auc)
# 	1.15s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2603.73s of the 2603.7s of remaining time.
# 	0.8991	 = Validation score   (roc_auc)
# 	1.16s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2602.34s of the 2602.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.9466	 = Validation score   (roc_auc)
# 	179.22s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2415.14s of the 2415.11s of remaining time.
# 	0.8659	 = Validation score   (roc_auc)
# 	1.09s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2413.79s of the 2413.76s of remaining time.
# 	0.8573	 = Validation score   (roc_auc)
# 	1.16s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2412.4s of the 2412.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.8907	 = Validation score   (roc_auc)
# 	18.45s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2381.29s of the 2381.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.02%)
# 	0.9384	 = Validation score   (roc_auc)
# 	12.02s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2353.42s of the 2353.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8174	 = Validation score   (roc_auc)
# 	38.33s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2305.51s of the 2305.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.9496	 = Validation score   (roc_auc)
# 	12.87s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2280.2s of the 2280.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.93%)
# 	0.9449	 = Validation score   (roc_auc)
# 	44.32s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2217.8s of the 2217.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=15948, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1836, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1870, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 968, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error: Unable to allocate internal buffer.
# traceback: Traceback (most recent call last):
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
#     msgpack_data, pickle5_data = split_buffer(data)
#   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
#   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# MemoryError: Unable to allocate internal buffer.
# Detailed Traceback:
# Traceback (most recent call last):
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 165, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 288, in _fit
#     self._fit_folds(
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 714, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 610, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 572, in _process_fold_results
#     raise processed_exception
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 537, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RaySystemError): ray::_ray_fit() (pid=15948, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1836, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1870, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 968, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error: Unable to allocate internal buffer.
# traceback: Traceback (most recent call last):
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 404, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 270, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\serialization.py", line 222, in _deserialize_msgpack_data
#     msgpack_data, pickle5_data = split_buffer(data)
#   File "python\ray\includes/serialization.pxi", line 206, in ray._raylet.split_buffer
#   File "msgpack\\_unpacker.pyx", line 372, in msgpack._cmsgpack.Unpacker.__init__
# MemoryError: Unable to allocate internal buffer.
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2181.78s of the 2181.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 2025-01-20 13:23:43,065	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9423	 = Validation score   (roc_auc)
# 	18.37s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2141.36s of the 2141.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.8717	 = Validation score   (roc_auc)
# 	30.62s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2090.88s of the 2090.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.86%)
# 2025-01-20 13:30:41,406	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-20 13:31:01,732	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-20 13:31:01,737	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9426	 = Validation score   (roc_auc)
# 	1543.81s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 517.34s of the 517.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.9275	 = Validation score   (roc_auc)
# 	22.02s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 478.23s of the 478.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8599	 = Validation score   (roc_auc)
# 	64.21s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 404.29s of the 404.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.22%)
# 	0.9375	 = Validation score   (roc_auc)
# 	36.19s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 349.19s of the 349.16s of remaining time.
# 	0.9111	 = Validation score   (roc_auc)
# 	1.56s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 347.29s of the 347.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.9521	 = Validation score   (roc_auc)
# 	78.66s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 240.21s of the 240.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9172	 = Validation score   (roc_auc)
# 	47.46s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 143.39s of the 143.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.47%)
# 	0.9453	 = Validation score   (roc_auc)
# 	115.58s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 13.06s of the 13.03s of remaining time.
# 	0.927	 = Validation score   (roc_auc)
# 	1.41s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 10.9s of the 10.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.9348	 = Validation score   (roc_auc)
# 	22.23s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -23.12s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 0.364, 'NeuralNetFastAI_r102_BAG_L1': 0.273, 'LightGBMXT_BAG_L1': 0.091, 'CatBoost_BAG_L1': 0.091, 'NeuralNetFastAI_r191_BAG_L1': 0.091, 'CatBoost_r137_BAG_L1': 0.091}
# 	0.9664	 = Validation score   (roc_auc)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2686.11s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 17.6 rows/s (31 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/real/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L2   0.966434     roc_auc       1.764247   354.796013                0.000463           0.305275            2       True         27
# 1          CatBoost_r137_BAG_L1   0.952136     roc_auc       0.166600    78.655468                0.166600          78.655468            1       True         22
# 2          LightGBMLarge_BAG_L1   0.949608     roc_auc       0.043363    12.870209                0.043363          12.870209            1       True         13
# 3             LightGBMXT_BAG_L1   0.947602     roc_auc       0.050711     5.674621                0.050711           5.674621            1       True          3
# 4               CatBoost_BAG_L1   0.946556     roc_auc       1.060780   179.215376                1.060780         179.215376            1       True          7
# 5           CatBoost_r13_BAG_L1   0.945336     roc_auc       0.143562   115.584292                0.143562         115.584292            1       True         24
# 6          CatBoost_r177_BAG_L1   0.944900     roc_auc       0.081652    44.323394                0.081652          44.323394            1       True         14
# 7            CatBoost_r9_BAG_L1   0.942633     roc_auc       0.976792  1543.812660                0.976792        1543.812660            1       True         17
# 8          LightGBM_r131_BAG_L1   0.942284     roc_auc       0.065678    18.365473                0.065678          18.365473            1       True         15
# 9                XGBoost_BAG_L1   0.938361     roc_auc       0.070683    12.024254                0.070683          12.024254            1       True         11
# 10           XGBoost_r33_BAG_L1   0.937489     roc_auc       0.171471    36.186223                0.171471          36.186223            1       True         20
# 11              LightGBM_BAG_L1   0.937315     roc_auc       0.093751     7.487059                0.093751           7.487059            1       True          4
# 12         LightGBM_r188_BAG_L1   0.934786     roc_auc       0.129597    22.231583                0.129597          22.231583            1       True         26
# 13          LightGBM_r96_BAG_L1   0.927463     roc_auc       0.056375    22.017865                0.056375          22.017865            1       True         18
# 14     RandomForest_r195_BAG_L1   0.926983     roc_auc       0.252709     1.412029                0.252709           1.412029            1       True         25
# 15  NeuralNetFastAI_r102_BAG_L1   0.917175     roc_auc       0.231614    47.455028                0.231614          47.455028            1       True         23
# 16        ExtraTrees_r42_BAG_L1   0.911116     roc_auc       0.237418     1.563015                0.237418           1.563015            1       True         21
# 17      RandomForestGini_BAG_L1   0.907454     roc_auc       0.153074     1.146324                0.153074           1.146324            1       True          5
# 18      RandomForestEntr_BAG_L1   0.899085     roc_auc       0.164037     1.155476                0.164037           1.155476            1       True          6
# 19       NeuralNetFastAI_BAG_L1   0.890671     roc_auc       0.169164    18.445887                0.169164          18.445887            1       True         10
# 20  NeuralNetFastAI_r191_BAG_L1   0.871665     roc_auc       0.210716    30.620035                0.210716          30.620035            1       True         16
# 21        ExtraTreesGini_BAG_L1   0.865867     roc_auc       0.175278     1.094590                0.175278           1.094590            1       True          8
# 22    NeuralNetTorch_r22_BAG_L1   0.859895     roc_auc       0.364471    64.212892                0.364471          64.212892            1       True         19
# 23        ExtraTreesEntr_BAG_L1   0.857280     roc_auc       0.158429     1.160655                0.158429           1.160655            1       True          9
# 24        NeuralNetTorch_BAG_L1   0.817437     roc_auc       0.322680    38.334469                0.322680          38.334469            1       True         12
# 25        KNeighborsUnif_BAG_L1   0.716260     roc_auc       0.630815     0.013509                0.630815           0.013509            1       True          1
# 26        KNeighborsDist_BAG_L1   0.713252     roc_auc       0.079064     0.014068                0.079064           0.014068            1       True          2
# Number of models trained: 27
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  :  2 | ['ISC.resultadosWFQ.NO_array', 'ISC.resultadosWFQ.SA_array']
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# Plot summary of models saved to file: AutogluonModels/real/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.716259808195292,
#   'KNeighborsDist_BAG_L1': 0.7132519616390585,
#   'LightGBMXT_BAG_L1': 0.9476024411508283,
#   'LightGBM_BAG_L1': 0.9373147340889276,
#   'RandomForestGini_BAG_L1': 0.9074542284219703,
#   'RandomForestEntr_BAG_L1': 0.8990845684394072,
#   'CatBoost_BAG_L1': 0.9465562336530078,
#   'ExtraTreesGini_BAG_L1': 0.8658674803836094,
#   'ExtraTreesEntr_BAG_L1': 0.8572798605056668,
#   'NeuralNetFastAI_BAG_L1': 0.890671316477768,
#   'XGBoost_BAG_L1': 0.938360941586748,
#   'NeuralNetTorch_BAG_L1': 0.81743679163034,
#   'LightGBMLarge_BAG_L1': 0.9496076721883173,
#   'CatBoost_r177_BAG_L1': 0.9448997384481255,
#   'LightGBM_r131_BAG_L1': 0.9422842197035746,
#   'NeuralNetFastAI_r191_BAG_L1': 0.8716652136006975,
#   'CatBoost_r9_BAG_L1': 0.9426329555361812,
#   'LightGBM_r96_BAG_L1': 0.9274629468177855,
#   'NeuralNetTorch_r22_BAG_L1': 0.859895379250218,
#   'XGBoost_r33_BAG_L1': 0.937489102005231,
#   'ExtraTrees_r42_BAG_L1': 0.9111159546643417,
#   'CatBoost_r137_BAG_L1': 0.9521360069747167,
#   'NeuralNetFastAI_r102_BAG_L1': 0.917175239755885,
#   'CatBoost_r13_BAG_L1': 0.9453356582388841,
#   'RandomForest_r195_BAG_L1': 0.9269834350479511,
#   'LightGBM_r188_BAG_L1': 0.9347863993025283,
#   'WeightedEnsemble_L2': 0.9664341761115955},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.013509035110473633,
#   'KNeighborsDist_BAG_L1': 0.014068365097045898,
#   'LightGBMXT_BAG_L1': 5.674621343612671,
#   'LightGBM_BAG_L1': 7.487059116363525,
#   'RandomForestGini_BAG_L1': 1.1463241577148438,
#   'RandomForestEntr_BAG_L1': 1.1554756164550781,
#   'CatBoost_BAG_L1': 179.2153763771057,
#   'ExtraTreesGini_BAG_L1': 1.094590425491333,
#   'ExtraTreesEntr_BAG_L1': 1.1606545448303223,
#   'NeuralNetFastAI_BAG_L1': 18.445886850357056,
#   'XGBoost_BAG_L1': 12.024254322052002,
#   'NeuralNetTorch_BAG_L1': 38.334468841552734,
#   'LightGBMLarge_BAG_L1': 12.870208978652954,
#   'CatBoost_r177_BAG_L1': 44.32339429855347,
#   'LightGBM_r131_BAG_L1': 18.365472555160522,
#   'NeuralNetFastAI_r191_BAG_L1': 30.620035409927368,
#   'CatBoost_r9_BAG_L1': 1543.8126604557037,
#   'LightGBM_r96_BAG_L1': 22.017865419387817,
#   'NeuralNetTorch_r22_BAG_L1': 64.21289157867432,
#   'XGBoost_r33_BAG_L1': 36.18622326850891,
#   'ExtraTrees_r42_BAG_L1': 1.5630154609680176,
#   'CatBoost_r137_BAG_L1': 78.65546751022339,
#   'NeuralNetFastAI_r102_BAG_L1': 47.45502829551697,
#   'CatBoost_r13_BAG_L1': 115.58429193496704,
#   'RandomForest_r195_BAG_L1': 1.4120287895202637,
#   'LightGBM_r188_BAG_L1': 22.23158311843872,
#   'WeightedEnsemble_L2': 0.30527520179748535},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.630814790725708,
#   'KNeighborsDist_BAG_L1': 0.07906389236450195,
#   'LightGBMXT_BAG_L1': 0.05071115493774414,
#   'LightGBM_BAG_L1': 0.0937509536743164,
#   'RandomForestGini_BAG_L1': 0.15307378768920898,
#   'RandomForestEntr_BAG_L1': 0.16403746604919434,
#   'CatBoost_BAG_L1': 1.0607802867889404,
#   'ExtraTreesGini_BAG_L1': 0.1752781867980957,
#   'ExtraTreesEntr_BAG_L1': 0.15842866897583008,
#   'NeuralNetFastAI_BAG_L1': 0.16916441917419434,
#   'XGBoost_BAG_L1': 0.07068300247192383,
#   'NeuralNetTorch_BAG_L1': 0.3226804733276367,
#   'LightGBMLarge_BAG_L1': 0.04336285591125488,
#   'CatBoost_r177_BAG_L1': 0.08165192604064941,
#   'LightGBM_r131_BAG_L1': 0.06567764282226562,
#   'NeuralNetFastAI_r191_BAG_L1': 0.21071600914001465,
#   'CatBoost_r9_BAG_L1': 0.9767920970916748,
#   'LightGBM_r96_BAG_L1': 0.056374549865722656,
#   'NeuralNetTorch_r22_BAG_L1': 0.364471435546875,
#   'XGBoost_r33_BAG_L1': 0.17147088050842285,
#   'ExtraTrees_r42_BAG_L1': 0.23741793632507324,
#   'CatBoost_r137_BAG_L1': 0.16659975051879883,
#   'NeuralNetFastAI_r102_BAG_L1': 0.2316138744354248,
#   'CatBoost_r13_BAG_L1': 0.14356207847595215,
#   'RandomForest_r195_BAG_L1': 0.25270938873291016,
#   'LightGBM_r188_BAG_L1': 0.12959742546081543,
#   'WeightedEnsemble_L2': 0.0004630088806152344},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.966434     roc_auc       1.764247
#  1          CatBoost_r137_BAG_L1   0.952136     roc_auc       0.166600
#  2          LightGBMLarge_BAG_L1   0.949608     roc_auc       0.043363
#  3             LightGBMXT_BAG_L1   0.947602     roc_auc       0.050711
#  4               CatBoost_BAG_L1   0.946556     roc_auc       1.060780
#  5           CatBoost_r13_BAG_L1   0.945336     roc_auc       0.143562
#  6          CatBoost_r177_BAG_L1   0.944900     roc_auc       0.081652
#  7            CatBoost_r9_BAG_L1   0.942633     roc_auc       0.976792
#  8          LightGBM_r131_BAG_L1   0.942284     roc_auc       0.065678
#  9                XGBoost_BAG_L1   0.938361     roc_auc       0.070683
#  10           XGBoost_r33_BAG_L1   0.937489     roc_auc       0.171471
#  11              LightGBM_BAG_L1   0.937315     roc_auc       0.093751
#  12         LightGBM_r188_BAG_L1   0.934786     roc_auc       0.129597
#  13          LightGBM_r96_BAG_L1   0.927463     roc_auc       0.056375
#  14     RandomForest_r195_BAG_L1   0.926983     roc_auc       0.252709
#  15  NeuralNetFastAI_r102_BAG_L1   0.917175     roc_auc       0.231614
#  16        ExtraTrees_r42_BAG_L1   0.911116     roc_auc       0.237418
#  17      RandomForestGini_BAG_L1   0.907454     roc_auc       0.153074
#  18      RandomForestEntr_BAG_L1   0.899085     roc_auc       0.164037
#  19       NeuralNetFastAI_BAG_L1   0.890671     roc_auc       0.169164
#  20  NeuralNetFastAI_r191_BAG_L1   0.871665     roc_auc       0.210716
#  21        ExtraTreesGini_BAG_L1   0.865867     roc_auc       0.175278
#  22    NeuralNetTorch_r22_BAG_L1   0.859895     roc_auc       0.364471
#  23        ExtraTreesEntr_BAG_L1   0.857280     roc_auc       0.158429
#  24        NeuralNetTorch_BAG_L1   0.817437     roc_auc       0.322680
#  25        KNeighborsUnif_BAG_L1   0.716260     roc_auc       0.630815
#  26        KNeighborsDist_BAG_L1   0.713252     roc_auc       0.079064
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    354.796013                0.000463           0.305275            2
#  1     78.655468                0.166600          78.655468            1
#  2     12.870209                0.043363          12.870209            1
#  3      5.674621                0.050711           5.674621            1
#  4    179.215376                1.060780         179.215376            1
#  5    115.584292                0.143562         115.584292            1
#  6     44.323394                0.081652          44.323394            1
#  7   1543.812660                0.976792        1543.812660            1
#  8     18.365473                0.065678          18.365473            1
#  9     12.024254                0.070683          12.024254            1
#  10    36.186223                0.171471          36.186223            1
#  11     7.487059                0.093751           7.487059            1
#  12    22.231583                0.129597          22.231583            1
#  13    22.017865                0.056375          22.017865            1
#  14     1.412029                0.252709           1.412029            1
#  15    47.455028                0.231614          47.455028            1
#  16     1.563015                0.237418           1.563015            1
#  17     1.146324                0.153074           1.146324            1
#  18     1.155476                0.164037           1.155476            1
#  19    18.445887                0.169164          18.445887            1
#  20    30.620035                0.210716          30.620035            1
#  21     1.094590                0.175278           1.094590            1
#  22    64.212892                0.364471          64.212892            1
#  23     1.160655                0.158429           1.160655            1
#  24    38.334469                0.322680          38.334469            1
#  25     0.013509                0.630815           0.013509            1
#  26     0.014068                0.079064           0.014068            1
#
#      can_infer  fit_order
#  0        True         27
#  1        True         22
#  2        True         13
#  3        True          3
#  4        True          7
#  5        True         24
#  6        True         14
#  7        True         17
#  8        True         15
#  9        True         11
#  10       True         20
#  11       True          4
#  12       True         26
#  13       True         18
#  14       True         25
#  15       True         23
#  16       True         21
#  17       True          5
#  18       True          6
#  19       True         10
#  20       True         16
#  21       True          8
#  22       True         19
#  23       True          9
#  24       True         12
#  25       True          1
#  26       True          2  }

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.88
# Evaluations on test data:
# {
#     "roc_auc": 0.88,
#     "accuracy": 0.8548387096774194,
#     "balanced_accuracy": 0.815,
#     "mcc": 0.5811946610581976,
#     "f1": 0.6666666666666666,
#     "precision": 0.6,
#     "recall": 0.75
# }
# {'roc_auc': 0.88,
#  'accuracy': 0.8548387096774194,
#  'balanced_accuracy': 0.815,
#  'mcc': 0.5811946610581976,
#  'f1': 0.6666666666666666,
#  'precision': 0.6,
#  'recall': 0.75}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                           model  score_test  balanced_accuracy        f1  \
# 0          CatBoost_r137_BAG_L1    1.000000           1.000000  1.000000
# 1      RandomForest_r195_BAG_L1    1.000000           1.000000  1.000000
# 2         KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 3               CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 4          CatBoost_r177_BAG_L1    1.000000           1.000000  1.000000
# 5             LightGBMXT_BAG_L1    1.000000           0.991892  0.976378
# 6         ExtraTrees_r42_BAG_L1    1.000000           1.000000  1.000000
# 7           CatBoost_r13_BAG_L1    1.000000           1.000000  1.000000
# 8       RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 9         ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 10           CatBoost_r9_BAG_L1    1.000000           1.000000  1.000000
# 11        ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 12      RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# 13         LightGBMLarge_BAG_L1    1.000000           1.000000  1.000000
# 14         LightGBM_r131_BAG_L1    1.000000           1.000000  1.000000
# 15              LightGBM_BAG_L1    1.000000           0.997297  0.992000
# 16               XGBoost_BAG_L1    1.000000           1.000000  1.000000
# 17           XGBoost_r33_BAG_L1    1.000000           1.000000  1.000000
# 18         LightGBM_r188_BAG_L1    1.000000           1.000000  1.000000
# 19        NeuralNetTorch_BAG_L1    1.000000           0.983871  0.983607
# 20  NeuralNetFastAI_r102_BAG_L1    1.000000           1.000000  1.000000
# 21  NeuralNetFastAI_r191_BAG_L1    1.000000           0.991892  0.976378
# 22          WeightedEnsemble_L2    1.000000           1.000000  1.000000
# 23       NeuralNetFastAI_BAG_L1    1.000000           0.997297  0.992000
# 24    NeuralNetTorch_r22_BAG_L1    0.998344           0.981168  0.975610
# 25          LightGBM_r96_BAG_L1    0.997733           0.962206  0.910448
# 26        KNeighborsUnif_BAG_L1    0.874237           0.798126  0.699187
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 5   0.984102  0.987854  1.000000           1.000000   0.953846  1.000000  ...
# 6   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 7   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 8   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 9   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 10  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 11  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 12  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 13  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 14  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 15  0.994645  0.995951  1.000000           1.000000   0.984127  1.000000  ...
# 16  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 17  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 18  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 19  0.989115  0.991903  1.000000           1.000000   1.000000  0.967742  ...
# 20  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 21  0.984102  0.987854  1.000000           1.000000   0.953846  1.000000  ...
# 22  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 23  0.994645  0.995951  1.000000           1.000000   0.984127  1.000000  ...
# 24  0.983762  0.987854  0.998344           0.995629   0.983607  0.967742  ...
# 25  0.938557  0.951417  0.997733           0.993640   0.847222  0.983871  ...
# 26  0.799728  0.850202  0.874237           0.648725   0.704918  0.693548  ...
#
#     eval_metric  pred_time_test  pred_time_val     fit_time  \
# 0       roc_auc        0.075109       0.166600    78.655468
# 1       roc_auc        0.219317       0.252709     1.412029
# 2       roc_auc        0.232579       0.079064     0.014068
# 3       roc_auc        0.233387       1.060780   179.215376
# 4       roc_auc        0.253207       0.081652    44.323394
# 5       roc_auc        0.304948       0.050711     5.674621
# 6       roc_auc        0.436787       0.237418     1.563015
# 7       roc_auc        0.507984       0.143562   115.584292
# 8       roc_auc        0.686919       0.164037     1.155476
# 9       roc_auc        0.712228       0.175278     1.094590
# 10      roc_auc        0.718451       0.976792  1543.812660
# 11      roc_auc        0.721844       0.158429     1.160655
# 12      roc_auc        0.734437       0.153074     1.146324
# 13      roc_auc        0.784629       0.043363    12.870209
# 14      roc_auc        0.807938       0.065678    18.365473
# 15      roc_auc        0.838614       0.093751     7.487059
# 16      roc_auc        0.897091       0.070683    12.024254
# 17      roc_auc        0.908211       0.171471    36.186223
# 18      roc_auc        0.959962       0.129597    22.231583
# 19      roc_auc        2.142104       0.322680    38.334469
# 20      roc_auc        2.677378       0.231614    47.455028
# 21      roc_auc        5.363007       0.210716    30.620035
# 22      roc_auc        9.443973       1.764247   354.796013
# 23      roc_auc        9.585199       0.169164    18.445887
# 24      roc_auc        1.325348       0.364471    64.212892
# 25      roc_auc        0.904879       0.056375    22.017865
# 26      roc_auc        0.336769       0.630815     0.013509
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.075109                0.166600          78.655468
# 1                  0.219317                0.252709           1.412029
# 2                  0.232579                0.079064           0.014068
# 3                  0.233387                1.060780         179.215376
# 4                  0.253207                0.081652          44.323394
# 5                  0.304948                0.050711           5.674621
# 6                  0.436787                0.237418           1.563015
# 7                  0.507984                0.143562         115.584292
# 8                  0.686919                0.164037           1.155476
# 9                  0.712228                0.175278           1.094590
# 10                 0.718451                0.976792        1543.812660
# 11                 0.721844                0.158429           1.160655
# 12                 0.734437                0.153074           1.146324
# 13                 0.784629                0.043363          12.870209
# 14                 0.807938                0.065678          18.365473
# 15                 0.838614                0.093751           7.487059
# 16                 0.897091                0.070683          12.024254
# 17                 0.908211                0.171471          36.186223
# 18                 0.959962                0.129597          22.231583
# 19                 2.142104                0.322680          38.334469
# 20                 2.677378                0.231614          47.455028
# 21                 5.363007                0.210716          30.620035
# 22                 0.005515                0.000463           0.305275
# 23                 9.585199                0.169164          18.445887
# 24                 1.325348                0.364471          64.212892
# 25                 0.904879                0.056375          22.017865
# 26                 0.336769                0.630815           0.013509
#
#     stack_level  can_infer  fit_order
# 0             1       True         22
# 1             1       True         25
# 2             1       True          2
# 3             1       True          7
# 4             1       True         14
# 5             1       True          3
# 6             1       True         21
# 7             1       True         24
# 8             1       True          6
# 9             1       True          8
# 10            1       True         17
# 11            1       True          9
# 12            1       True          5
# 13            1       True         13
# 14            1       True         15
# 15            1       True          4
# 16            1       True         11
# 17            1       True         20
# 18            1       True         26
# 19            1       True         12
# 20            1       True         23
# 21            1       True         16
# 22            2       True         27
# 23            1       True         10
# 24            1       True         19
# 25            1       True         18
# 26            1       True          1
#
# [27 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 69 features using 247 rows with 5 shuffle sets...
# 	1608.51s	= Expected runtime (321.7s per shuffle set)
# 	341.07s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.Stroop.color.PD                       0.070584  0.009882  0.000045  5
# TLP.CubCorsi.Directos.PD                  0.008701  0.002063  0.000352  5
# TLP.Stroop.palabras.PD                    0.002581  0.000860  0.001284  5
# TLP.FigRey.Memoria.PD                     0.002110  0.001277  0.010481  5
# ISC.FPacientes.Edad                       0.001360  0.000731  0.007070  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Memoria.PD                       0.000000  0.000000  0.500000  5
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.Stroop.color.PD                     0.090931  0.050237
# TLP.CubCorsi.Directos.PD                0.012948  0.004454
# TLP.Stroop.palabras.PD                  0.004351  0.000810
# TLP.FigRey.Memoria.PD                   0.004740 -0.000520
# ISC.FPacientes.Edad                     0.002865 -0.000145
# ...                                          ...       ...
# TLP.MMSE.Memoria.PD                     0.000000  0.000000
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [69 rows x 6 columns]
