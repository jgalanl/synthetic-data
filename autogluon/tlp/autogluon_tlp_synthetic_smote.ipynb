# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-smote.csv')

# %%
df.head()
# Out:
#    demo-genero demo-fechaEvaluacion demo-fechaNacimiento demo-rangoEdad  \
# 0            2  2024-02-22T00:00:00  1942-05-08T00:00:00         Rango3
# 1            2  2024-06-26T00:00:00  1948-10-07T00:00:00         Rango3
# 2            2  2024-05-14T00:00:00  1952-05-08T00:00:00         Rango2
# 3            2  2024-04-10T00:00:00  1964-01-27T00:00:00         Rango1
# 4            2  2024-05-14T00:00:00  1959-09-16T00:00:00         Rango1
#
#    demo-edad  clin-reservaCognitiva_total  clin-reservaCognitiva_idiomas  \
# 0         81                           12                              0
# 1         75                            8                              0
# 2         72                           11                              0
# 3         60                           18                              2
# 4         64                           13                              0
#
#    clin-reservaCognitiva_ocupacion  clin-reservaCognitiva_escolaridad  \
# 0                                1                                  3
# 1                                1                                  3
# 2                                0                                  4
# 3                                1                                  4
# 4                                1                                  4
#
#    clin-ansiedad  ...  eval-TLP-Tavec-25_Discriminabilidad-PD  \
# 0          False  ...                                   84.09
# 1           True  ...                                   79.55
# 2          False  ...                                   88.64
# 3          False  ...                                   90.91
# 4          False  ...                                   86.36
#
#    eval-TLP-Tavec-26_Sesgo-PD  eval-TLP-Tavec-27_RI_B_frente_RI_A1-PD  \
# 0                        0.14                                  -20.00
# 1                       -0.33                                  -71.43
# 2                       -0.60                                  -14.29
# 3                        0.60                                   60.00
# 4                       -0.71                                    0.00
#
#    eval-TLP-Tavec-28_RL_CP_frente_RI_A5-PD  \
# 0                                     0.00
# 1                                    12.50
# 2                                    75.00
# 3                                    16.67
# 4                                    66.67
#
#    eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD  \
# 0                                      33.33
# 1                                       0.00
# 2                                      25.00
# 3                                       0.00
# 4                                       0.00
#
#    eval-TLP-Tavec-30_RL_LP_frente_RL_CP-PD  \
# 0                                    37.50
# 1                                     0.00
# 2                                   -20.00
# 3                                    50.00
# 4                                   -33.33
#
#    eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD  \
# 0                                    -33.33
# 1                                      0.00
# 2                                      0.00
# 3                                    -20.00
# 4                                      0.00
#
#    eval-TLP-Tavec-32_Recon_Ac_frente_RL_LP-PD  \
# 0                                      -38.46
# 1                                      -20.00
# 2                                      -16.67
# 3                                      -50.00
# 4                                      -10.00
#
#    eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  ED_2Clases
# 0                                        -7.69           D
# 1                                       -20.00           D
# 2                                       -16.67           D
# 3                                       -37.50           D
# 4                                       -10.00           D
#
# [5 rows x 77 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((396, 77), (100, 77))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/smote/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['high_quality'],
    time_limit = 2 * 3600,
    auto_stack = True,
    # excluded_model_types=['KNN','RF','XT', 'LR'],
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       8.09 GB / 15.94 GB (50.8%)
# Disk Space Avail:   84.64 GB / 446.36 GB (19.0%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-02 21:06:05,290	INFO worker.py:1762 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\smote\v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=16216) Running DyStack sub-fit ...
# (_dystack pid=16216) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=16216) Beginning AutoGluon training ... Time limit = 1792s
# (_dystack pid=16216) AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\smote\v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=16216) Train Data Rows:    352
# (_dystack pid=16216) Train Data Columns: 76
# (_dystack pid=16216) Label Column:       ED_2Clases
# (_dystack pid=16216) Problem Type:       binary
# (_dystack pid=16216) Preprocessing data ...
# (_dystack pid=16216) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=16216) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=16216) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=16216) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=16216) Using Feature Generators to preprocess the data ...
# (_dystack pid=16216) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=16216) 	Available Memory:                    7695.06 MB
# (_dystack pid=16216) 	Train Data (Original)  Memory Usage: 0.25 MB (0.0% of available memory)
# (_dystack pid=16216) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=16216) 	Stage 1 Generators:
# (_dystack pid=16216) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=16216) 			Note: Converting 10 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=16216) 	Stage 2 Generators:
# (_dystack pid=16216) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=16216) 	Stage 3 Generators:
# (_dystack pid=16216) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=16216) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=16216) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=16216) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=16216) 	Stage 4 Generators:
# (_dystack pid=16216) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=16216) 	Stage 5 Generators:
# (_dystack pid=16216) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=16216) 	Useless Original Features (Count: 1): ['clin-Covid_sintomaSarpullido']
# (_dystack pid=16216) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=16216) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=16216) 		These features do not need to be present at inference time.
# (_dystack pid=16216) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=16216) 		('bool', [])                       :  8 | ['clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', 'clin-Hipercolesterolemia', ...]
# (_dystack pid=16216) 		('float', [])                      : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=16216) 		('int', [])                        : 49 | ['demo-genero', 'demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', ...]
# (_dystack pid=16216) 		('object', [])                     :  1 | ['demo-rangoEdad']
# (_dystack pid=16216) 		('object', ['datetime_as_object']) :  2 | ['demo-fechaEvaluacion', 'demo-fechaNacimiento']
# (_dystack pid=16216) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=16216) 		('category', [])             :  1 | ['demo-rangoEdad']
# (_dystack pid=16216) 		('float', [])                : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=16216) 		('int', [])                  : 47 | ['demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', 'clin-reservaCognitiva_escolaridad', ...]
# (_dystack pid=16216) 		('int', ['bool'])            : 10 | ['demo-genero', 'clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', ...]
# (_dystack pid=16216) 		('int', ['datetime_as_int']) :  9 | ['demo-fechaEvaluacion', 'demo-fechaEvaluacion.month', 'demo-fechaEvaluacion.day', 'demo-fechaEvaluacion.dayofweek', 'demo-fechaNacimiento', ...]
# (_dystack pid=16216) 	0.1s = Fit runtime
# (_dystack pid=16216) 	75 features in original data used to generate 82 features in processed data.
# (_dystack pid=16216) 	Train Data (Processed) Memory Usage: 0.19 MB (0.0% of available memory)
# (_dystack pid=16216) Data preprocessing and feature engineering runtime = 0.12s ...
# (_dystack pid=16216) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=16216) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=16216) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=16216) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=16216) User-specified model hyperparameters to be fit:
# (_dystack pid=16216) {
# (_dystack pid=16216) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=16216) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=16216) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=16216) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=16216) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=16216) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=16216) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=16216) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=16216) }
# (_dystack pid=16216) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=16216) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1194.06s of the 1791.53s of remaining time.
# (_dystack pid=16216) 	0.6858	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.01s	 = Training   runtime
# (_dystack pid=16216) 	0.1s	 = Validation runtime
# (_dystack pid=16216) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1191.63s of the 1789.09s of remaining time.
# (_dystack pid=16216) 	0.8091	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.01s	 = Training   runtime
# (_dystack pid=16216) 	0.01s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1191.59s of the 1789.05s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_ray_fit pid=18960) [1000]	valid_set's binary_logloss: 0.0100993
# (_dystack pid=16216) 	0.9866	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.99s	 = Training   runtime
# (_dystack pid=16216) 	0.05s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1185.40s of the 1782.87s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_ray_fit pid=11588) [1000]	valid_set's binary_logloss: 0.100904
# (_ray_fit pid=11588) [2000]	valid_set's binary_logloss: 0.0964312
# (_dystack pid=16216) 	0.9818	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.06s	 = Training   runtime
# (_dystack pid=16216) 	0.01s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1178.88s of the 1776.35s of remaining time.
# (_dystack pid=16216) 	0.9809	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.61s	 = Training   runtime
# (_dystack pid=16216) 	0.09s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1178.15s of the 1775.62s of remaining time.
# (_dystack pid=16216) 	0.9795	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1177.49s of the 1774.96s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# (_dystack pid=16216) 	0.9839	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	112.33s	 = Training   runtime
# (_dystack pid=16216) 	0.05s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1060.78s of the 1658.25s of remaining time.
# (_dystack pid=16216) 	0.9732	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.56s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1060.11s of the 1657.58s of remaining time.
# (_dystack pid=16216) 	0.975	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1059.45s of the 1656.92s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_dystack pid=16216) 	0.9659	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.64s	 = Training   runtime
# (_dystack pid=16216) 	0.13s	 = Validation runtime
# (_dystack pid=16216) Fitting model: XGBoost_BAG_L1 ... Training model for up to 1048.60s of the 1646.06s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# (_dystack pid=16216) 	0.9826	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	3.14s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1040.03s of the 1637.50s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=16216) 	0.9531	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	9.19s	 = Training   runtime
# (_dystack pid=16216) 	0.18s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1026.66s of the 1624.13s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.01%)
# (_ray_fit pid=15964) [1000]	valid_set's binary_logloss: 0.0186563
# (_ray_fit pid=2676) [1000]	valid_set's binary_logloss: 0.0207553
# (_dystack pid=16216) 	0.9806	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.88s	 = Training   runtime
# (_dystack pid=16216) 	0.05s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1019.37s of the 1616.84s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# (_dystack pid=16216) 	0.9858	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	156.13s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 858.75s of the 1456.22s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=16216) 	0.964	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	9.74s	 = Training   runtime
# (_dystack pid=16216) 	0.22s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 844.94s of the 1442.41s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# (_ray_fit pid=10280) [1000]	valid_set's binary_logloss: 0.122033 [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=16216) 	0.9845	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.64s	 = Training   runtime
# (_dystack pid=16216) 	0.04s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 838.23s of the 1435.69s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=10908) No improvement since epoch 9: early stopping
# (_dystack pid=16216) 	0.9661	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.78s	 = Training   runtime
# (_dystack pid=16216) 	0.16s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 827.26s of the 1424.73s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.95%)
# (_ray_fit pid=4064) 	Ran out of time, early stopping on iteration 6235.
# (_ray_fit pid=18924) No improvement since epoch 19: early stopping [repeated 7x across cluster]
# (_dystack pid=16216) 	0.9844	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	662.64s	 = Training   runtime
# (_dystack pid=16216) 	0.06s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 159.91s of the 757.37s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_ray_fit pid=18860) [1000]	valid_set's binary_logloss: 0.235109 [repeated 5x across cluster]
# (_dystack pid=16216) 	0.9795	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.02s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 149.82s of the 747.29s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=16216) 	0.9506	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	10.25s	 = Training   runtime
# (_dystack pid=16216) 	0.2s	 = Validation runtime
# (_dystack pid=16216) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 135.48s of the 732.94s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.06%)
# (_dystack pid=16216) 	0.9839	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.48s	 = Training   runtime
# (_dystack pid=16216) 	0.06s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 124.80s of the 722.27s of remaining time.
# (_dystack pid=16216) 	0.9816	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.57s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 124.11s of the 721.58s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=10096) 	Ran out of time, early stopping on iteration 4479.
# (_dystack pid=16216) 	0.9809	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	99.37s	 = Training   runtime
# (_dystack pid=16216) 	0.06s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 20.72s of the 618.19s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=18572) No improvement since epoch 1: early stopping
# (_ray_fit pid=14644) 	Ran out of time, early stopping on iteration 4483.
# (_dystack pid=16216) 	0.97	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	7.43s	 = Training   runtime
# (_dystack pid=16216) 	0.13s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 9.19s of the 606.66s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.97%)
# (_ray_fit pid=19988) 	Ran out of time, early stopping on iteration 178.
# (_ray_fit pid=11960) No improvement since epoch 6: early stopping [repeated 3x across cluster]
# (_dystack pid=16216) 	0.9764	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	7.48s	 = Training   runtime
# (_dystack pid=16216) 	0.06s	 = Validation runtime
# (_dystack pid=16216) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 594.09s of remaining time.
# (_dystack pid=16216) 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.316, 'LightGBMXT_BAG_L1': 0.158, 'NeuralNetTorch_r79_BAG_L1': 0.158, 'XGBoost_r33_BAG_L1': 0.158, 'NeuralNetFastAI_r102_BAG_L1': 0.105, 'KNeighborsDist_BAG_L1': 0.053, 'ExtraTrees_r42_BAG_L1': 0.053}
# (_dystack pid=16216) 	0.9897	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.07s	 = Training   runtime
# (_dystack pid=16216) 	0.0s	 = Validation runtime
# (_dystack pid=16216) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 593.99s of the 593.83s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=16216) 	0.987	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.05s	 = Training   runtime
# (_dystack pid=16216) 	0.03s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_BAG_L2 ... Training model for up to 588.60s of the 588.45s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_ray_fit pid=10808) 	Ran out of time, early stopping on iteration 181. [repeated 7x across cluster]
# (_dystack pid=16216) 	0.9843	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.13s	 = Training   runtime
# (_dystack pid=16216) 	0.02s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 583.07s of the 582.91s of remaining time.
# (_dystack pid=16216) 	0.9853	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.7s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 582.26s of the 582.11s of remaining time.
# (_dystack pid=16216) 	0.9854	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.55s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_BAG_L2 ... Training model for up to 581.62s of the 581.46s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_dystack pid=16216) 	0.9847	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	45.85s	 = Training   runtime
# (_dystack pid=16216) 	0.05s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 531.62s of the 531.46s of remaining time.
# (_dystack pid=16216) 	0.9858	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 530.96s of the 530.81s of remaining time.
# (_dystack pid=16216) 	0.986	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.53s	 = Training   runtime
# (_dystack pid=16216) 	0.09s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 530.31s of the 530.16s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=2972) No improvement since epoch 9: early stopping
# (_dystack pid=16216) 	0.9808	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	5.54s	 = Training   runtime
# (_dystack pid=16216) 	0.11s	 = Validation runtime
# (_dystack pid=16216) Fitting model: XGBoost_BAG_L2 ... Training model for up to 520.75s of the 520.60s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# (_dystack pid=16216) 	0.9823	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.79s	 = Training   runtime
# (_dystack pid=16216) 	0.05s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 514.15s of the 514.00s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=16216) 	0.9782	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	8.5s	 = Training   runtime
# (_dystack pid=16216) 	0.23s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 501.30s of the 501.14s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.07%)
# (_dystack pid=16216) 	0.9729	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.83s	 = Training   runtime
# (_dystack pid=16216) 	0.03s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 495.08s of the 494.91s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# (_dystack pid=16216) 	0.9849	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	9.56s	 = Training   runtime
# (_dystack pid=16216) 	0.04s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 480.97s of the 480.80s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=16216) 	0.9777	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	8.04s	 = Training   runtime
# (_dystack pid=16216) 	0.23s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 468.86s of the 468.70s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# (_ray_fit pid=13000) [1000]	valid_set's binary_logloss: 0.0299039 [repeated 35x across cluster]
# (_dystack pid=16216) 	0.9839	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.23s	 = Training   runtime
# (_dystack pid=16216) 	0.03s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 462.40s of the 462.24s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=3236) No improvement since epoch 8: early stopping
# (_dystack pid=16216) 	0.9808	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.42s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 451.75s of the 451.60s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.65%)
# (_dystack pid=16216) 	0.9818	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	84.68s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 362.17s of the 362.01s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=6512) No improvement since epoch 6: early stopping [repeated 7x across cluster]
# (_ray_fit pid=9140) [1000]	valid_set's binary_logloss: 0.0762416
# (_ray_fit pid=9140) [2000]	valid_set's binary_logloss: 0.0588694
# (_ray_fit pid=9140) [3000]	valid_set's binary_logloss: 0.0520539
# (_ray_fit pid=9140) [4000]	valid_set's binary_logloss: 0.0418907
# (_ray_fit pid=9140) [5000]	valid_set's binary_logloss: 0.0366929
# (_ray_fit pid=9140) [6000]	valid_set's binary_logloss: 0.0373411
# (_dystack pid=16216) 	0.9889	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	3.78s	 = Training   runtime
# (_dystack pid=16216) 	0.06s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 354.31s of the 354.16s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=16216) 	0.9742	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	7.04s	 = Training   runtime
# (_dystack pid=16216) 	0.22s	 = Validation runtime
# (_dystack pid=16216) Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 343.19s of the 343.04s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=5.01%)
# (_dystack pid=16216) 	0.9822	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	4.46s	 = Training   runtime
# (_dystack pid=16216) 	0.04s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 334.01s of the 333.86s of remaining time.
# (_dystack pid=16216) 	0.9834	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.57s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 333.33s of the 333.18s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=16216) 	0.9859	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	151.22s	 = Training   runtime
# (_dystack pid=16216) 	0.04s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 178.09s of the 177.94s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=14676) No improvement since epoch 0: early stopping
# (_dystack pid=16216) 	0.9807	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	7.62s	 = Training   runtime
# (_dystack pid=16216) 	0.14s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 166.39s of the 166.24s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.14%)
# (_dystack pid=16216) 	0.9835	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	81.0s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 80.89s of the 80.73s of remaining time.
# (_ray_fit pid=17020) No improvement since epoch 4: early stopping [repeated 3x across cluster]
# (_dystack pid=16216) 	0.9811	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.79s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 79.99s of the 79.84s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# (_ray_fit pid=16880) [1000]	valid_set's binary_logloss: 0.0329832
# (_dystack pid=16216) 	0.9875	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	1.54s	 = Training   runtime
# (_dystack pid=16216) 	0.03s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 74.38s of the 74.23s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=12076) No improvement since epoch 5: early stopping
# (_dystack pid=16216) 	0.9855	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	6.2s	 = Training   runtime
# (_dystack pid=16216) 	0.12s	 = Validation runtime
# (_dystack pid=16216) Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 64.04s of the 63.89s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# (_dystack pid=16216) 	0.9818	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.14s	 = Training   runtime
# (_dystack pid=16216) 	0.04s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 57.15s of the 56.99s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=20784) No improvement since epoch 8: early stopping [repeated 6x across cluster]
# (_dystack pid=16216) 	0.9836	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	9.43s	 = Training   runtime
# (_dystack pid=16216) 	0.21s	 = Validation runtime
# (_dystack pid=16216) Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 43.24s of the 43.08s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.69%)
# (_ray_fit pid=20652) [1000]	valid_set's binary_logloss: 0.0135484
# (_dystack pid=16216) 	0.9872	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	2.73s	 = Training   runtime
# (_dystack pid=16216) 	0.03s	 = Validation runtime
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 37.81s of the 37.66s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=16216) 	0.9749	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	9.3s	 = Training   runtime
# (_dystack pid=16216) 	0.25s	 = Validation runtime
# (_dystack pid=16216) Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 24.11s of the 23.95s of remaining time.
# (_dystack pid=16216) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=2248) 	Ran out of time, early stopping on iteration 704.
# (_dystack pid=16216) 	0.9848	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	19.33s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 0.13s of remaining time.
# (_dystack pid=16216) 	Ensemble Weights: {'LightGBM_r96_BAG_L2': 0.476, 'NeuralNetTorch_r30_BAG_L2': 0.238, 'NeuralNetFastAI_r145_BAG_L2': 0.19, 'KNeighborsDist_BAG_L1': 0.048, 'XGBoost_r33_BAG_L1': 0.048}
# (_dystack pid=16216) 	0.9902	 = Validation score   (roc_auc)
# (_dystack pid=16216) 	0.05s	 = Training   runtime
# (_dystack pid=16216) 	0.0s	 = Validation runtime
# (_dystack pid=16216) AutoGluon training complete, total runtime = 1791.59s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 46.7 rows/s (44 batch size)
# (_dystack pid=16216) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=16216) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=16216) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=16216) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=16216) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=16216) Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.01s	 = Training   runtime
# (_dystack pid=16216) 	0.1s	 = Validation runtime
# (_dystack pid=16216) Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.01s	 = Training   runtime
# (_dystack pid=16216) 	0.01s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.5s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.18s	 = Training   runtime
# (_dystack pid=16216) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.61s	 = Training   runtime
# (_dystack pid=16216) 	0.09s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=16216) 	15.32s	 = Training   runtime
# (_dystack pid=16216) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.56s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 16.
# (_dystack pid=16216) 	0.4s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.32s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=16216) 	2.66s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBMLarge_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.62s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r177_BAG_L1_FULL ...
# (_dystack pid=16216) 	6.35s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# (_dystack pid=16216) 	1.31s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_r131_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.42s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 10.
# (_dystack pid=16216) 	0.33s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r9_BAG_L1_FULL ...
# (_dystack pid=16216) 	61.38s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_r96_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.57s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# (_dystack pid=16216) 	1.15s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: XGBoost_r33_BAG_L1_FULL ...
# (_dystack pid=16216) 	0.74s	 = Training   runtime
# (_dystack pid=16216) Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.57s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r137_BAG_L1_FULL ...
# (_dystack pid=16216) 	17.12s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 10.
# (_dystack pid=16216) 	0.9s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r13_BAG_L1_FULL ...
# (_dystack pid=16216) 	1.76s	 = Training   runtime
# (_dystack pid=16216) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.316, 'LightGBMXT_BAG_L1': 0.158, 'NeuralNetTorch_r79_BAG_L1': 0.158, 'XGBoost_r33_BAG_L1': 0.158, 'NeuralNetFastAI_r102_BAG_L1': 0.105, 'KNeighborsDist_BAG_L1': 0.053, 'ExtraTrees_r42_BAG_L1': 0.053}
# (_dystack pid=16216) 	0.07s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.15s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.16s	 = Training   runtime
# (_dystack pid=16216) Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.7s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.55s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_BAG_L2_FULL ...
# (_dystack pid=16216) 	4.18s	 = Training   runtime
# (_dystack pid=16216) Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.54s	 = Training   runtime
# (_dystack pid=16216) 	0.07s	 = Validation runtime
# (_dystack pid=16216) Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.53s	 = Training   runtime
# (_dystack pid=16216) 	0.09s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 10.
# (_dystack pid=16216) 	0.26s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: XGBoost_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.1s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.78s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBMLarge_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.31s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r177_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.29s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.44s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_r131_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.29s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 6.
# (_dystack pid=16216) 	0.26s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r9_BAG_L2_FULL ...
# (_dystack pid=16216) 	7.75s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: LightGBM_r96_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.24s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.39s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: XGBoost_r33_BAG_L2_FULL ...
# (_dystack pid=16216) 	0.34s	 = Training   runtime
# (_dystack pid=16216) Fitting model: ExtraTrees_r42_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=16216) 	0.57s	 = Training   runtime
# (_dystack pid=16216) 	0.08s	 = Validation runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r137_BAG_L2_FULL ...
# (_dystack pid=16216) 	9.95s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: NeuralNetFastAI_r102_BAG_L2_FULL ...
# (_dystack pid=16216) 	Stopping at the best epoch learned earlier - 6.
# (_dystack pid=16216) 	0.65s	 = Training   runtime
# (_dystack pid=16216) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=16216) Fitting model: CatBoost_r13_BAG_L2_FULL ...
# ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	1.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	14.96s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	1.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_BAG_L1_FULL ...
# 	0.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_BAG_L1_FULL ...
# 	0.47s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.64s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_BAG_L1_FULL ...
# 	0.42s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.8s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.74s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.57s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_BAG_L1_FULL ...
# 	2.92s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_BAG_L1_FULL ...
# 	15.65s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_BAG_L1_FULL ...
# 	0.7s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.62s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 23.
# 	1.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_BAG_L1_FULL ...
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_BAG_L1_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_BAG_L1_FULL ...
# 	0.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_BAG_L1_FULL ...
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_BAG_L1_FULL ...
# 	0.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_BAG_L1_FULL ...
# 	4.31s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.63s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.83s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_BAG_L1_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_BAG_L1_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r160_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r60_BAG_L1_FULL ...
# 	22.4s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.78s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r135_BAG_L1_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r22_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r69_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r6_BAG_L1_FULL ...
# 	2.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r138_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r121_BAG_L1_FULL ...
# 	0.8s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r172_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r180_BAG_L1_FULL ...
# 	3.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r76_BAG_L1_FULL ...
# 	0.46s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.81s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r121_BAG_L1_FULL ...
# 	1.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r127_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	1.17s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.2s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r194_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r12_BAG_L1_FULL ...
# 	3.98s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r135_BAG_L1_FULL ...
# 	2.27s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'ExtraTrees_r197_BAG_L1': 0.5, 'NeuralNetTorch_r41_BAG_L1': 0.25, 'KNeighborsDist_BAG_L1': 0.083, 'RandomForestGini_BAG_L1': 0.083, 'NeuralNetFastAI_r134_BAG_L1': 0.083}
# 	0.05s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.16s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.67s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.52s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	2.54s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.55s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.52s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	0.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.1s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	1.08s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	0.7s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	0.93s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	33.51s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	0.29s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	3.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.74s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	4.91s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.8s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L2_FULL ...
# 	1.42s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L2_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L2_FULL ...
# 	0.66s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L2_FULL ...
# 	1.03s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.22s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L2_FULL ...
# 	0.12s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.7s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L2_FULL ...
# 	1.43s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.19s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L2_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.14s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L2_FULL ...
# 	2.73s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.63s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_BAG_L2_FULL ...
# 	0.84s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.75s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_BAG_L2_FULL ...
# 	32.08s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.31s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_BAG_L2_FULL ...
# 	0.73s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_BAG_L2_FULL ...
# 	0.6s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_BAG_L2_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L2_FULL ...
# 	1.02s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L2_FULL ...
# 	10.04s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.7s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_BAG_L2_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_BAG_L2_FULL ...
# 	0.35s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.68s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.97s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.78s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.59s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_BAG_L2_FULL ...
# 	0.19s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_BAG_L2_FULL ...
# 	0.91s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_r156_BAG_L2': 0.32, 'LightGBMXT_BAG_L2': 0.24, 'CatBoost_r69_BAG_L2': 0.2, 'NeuralNetTorch_r143_BAG_L2': 0.2, 'KNeighborsDist_BAG_L1': 0.04}
# 	0.05s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 344.61s ... Best model: "WeightedEnsemble_L3_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\smote\v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                 WeightedEnsemble_L3   0.992519     roc_auc       1.216882  143.951586                0.000999           0.053863            3      False        159
# 1                 WeightedEnsemble_L2   0.991702     roc_auc       0.529387   27.945843                0.000997           0.050997            2      False         98
# 2                   LightGBMXT_BAG_L2   0.991294     roc_auc       0.856257  105.803207                0.026136           2.346170            2      False         99
# 3                 LightGBM_r94_BAG_L2   0.991013     roc_auc       0.865969  106.040373                0.035848           2.583336            2      False        157
# 4                LightGBM_r196_BAG_L2   0.990809     roc_auc       0.935463  108.209626                0.105342           4.752589            2      False        140
# 5                LightGBM_r188_BAG_L2   0.990758     roc_auc       0.870219  106.464625                0.040099           3.007588            2      False        123
# 6                 CatBoost_r69_BAG_L2   0.990605     roc_auc       0.898738  121.191364                0.068617          17.734327            2      False        133
# 7                CatBoost_r177_BAG_L2   0.990528     roc_auc       0.887053  125.035488                0.056932          21.578451            2      False        110
# 8                 CatBoost_r49_BAG_L2   0.990502     roc_auc       0.908437  109.925838                0.078316           6.468801            2      False        151
# 9         NeuralNetFastAI_r156_BAG_L2   0.990502     roc_auc       0.927313  113.317126                0.097192           9.860089            2      False        139
# 10        NeuralNetFastAI_r134_BAG_L2   0.990477     roc_auc       0.972512  116.834458                0.142391          13.377421            2      False        155
# 11                LightGBM_r96_BAG_L2   0.990196     roc_auc       0.871161  106.364867                0.041040           2.907830            2      False        115
# 12               CatBoost_r137_BAG_L2   0.989992     roc_auc       0.884073  122.709416                0.053952          19.252379            2      False        119
# 13               LightGBM_r130_BAG_L2   0.989839     roc_auc       0.861437  105.838032                0.031316           2.380996            2      False        127
# 14                CatBoost_r50_BAG_L2   0.989737     roc_auc       0.911700  118.837944                0.081579          15.380907            2      False        129
# 15               CatBoost_r167_BAG_L2   0.989456     roc_auc       0.901478  616.851955                0.071357         513.394918            2      False        142
# 16        NeuralNetFastAI_r143_BAG_L2   0.989379     roc_auc       0.945276  114.322195                0.115156          10.865158            2      False        137
# 17               LightGBM_r143_BAG_L2   0.989379     roc_auc       0.869321  106.444355                0.039201           2.987318            2      False        153
# 18                CatBoost_r13_BAG_L2   0.989277     roc_auc       0.875017  184.489244                0.044896          81.032207            2      False        121
# 19               LightGBM_r161_BAG_L2   0.989251     roc_auc       0.854827  106.773772                0.024706           3.316735            2      False        136
# 20                    LightGBM_BAG_L2   0.989175     roc_auc       0.855746  105.766914                0.025625           2.309877            2      False        100
# 21            RandomForestEntr_BAG_L2   0.988996     roc_auc       0.914427  103.976412                0.084306           0.519375            2      False        102
# 22         NeuralNetFastAI_r37_BAG_L2   0.988945     roc_auc       0.928531  113.890441                0.098410          10.433404            2      False        149
# 23                    CatBoost_BAG_L2   0.988868     roc_auc       0.886358  127.155034                0.056237          23.697997            2      False        103
# 24        NeuralNetFastAI_r102_BAG_L2   0.988817     roc_auc       0.942967  112.860107                0.112846           9.403070            2      False        120
# 25              ExtraTrees_r49_BAG_L2   0.988741     roc_auc       0.903621  104.133076                0.073500           0.676039            2      False        152
# 26              ExtraTreesGini_BAG_L2   0.988741     roc_auc       0.914509  104.004511                0.084388           0.547474            2      False        104
# 27                CatBoost_r86_BAG_L2   0.988511     roc_auc       0.866091  256.609927                0.035971         153.152890            2      False        148
# 28                 XGBoost_r98_BAG_L2   0.988383     roc_auc       1.116656  108.444534                0.286535           4.987497            2      False        145
# 29               LightGBM_r131_BAG_L2   0.988154     roc_auc       0.870351  106.746795                0.040230           3.289758            2      False        112
# 30            RandomForestGini_BAG_L2   0.987911     roc_auc       0.934360  104.131208                0.104239           0.674171            2      False        101
# 31              ExtraTreesEntr_BAG_L2   0.987554     roc_auc       0.915312  103.977908                0.085191           0.520871            2      False        105
# 32                CatBoost_r70_BAG_L2   0.987234     roc_auc       0.900719  136.790850                0.070598          33.333813            2      False        138
# 33                XGBoost_r194_BAG_L2   0.987234     roc_auc       1.091834  106.587177                0.261713           3.130140            2      False        131
# 34              ExtraTrees_r42_BAG_L2   0.987005     roc_auc       0.915347  104.119883                0.085226           0.662846            2      False        118
# 35             ExtraTrees_r172_BAG_L2   0.986877     roc_auc       0.929799  104.155095                0.099678           0.698058            2      False        132
# 36        NeuralNetFastAI_r191_BAG_L2   0.986877     roc_auc       0.939645  111.635118                0.109524           8.178081            2      False        113
# 37            RandomForest_r34_BAG_L2   0.986622     roc_auc       0.905181  104.049191                0.075060           0.592154            2      False        156
# 38                 CatBoost_r9_BAG_L2   0.986520     roc_auc       0.890921  562.565205                0.060800         459.108168            2      False        114
# 39                     XGBoost_BAG_L2   0.985907     roc_auc       0.869580  106.400785                0.039459           2.943748            2      False        107
# 40                LightGBM_r15_BAG_L2   0.985830     roc_auc       0.884463  106.242846                0.054342           2.785809            2      False        146
# 41                 XGBoost_r33_BAG_L2   0.985728     roc_auc       0.879568  107.346713                0.049447           3.889676            2      False        117
# 42         NeuralNetTorch_r143_BAG_L2   0.985447     roc_auc       1.023937  113.957138                0.193816          10.500101            2      False        158
# 43             ExtraTrees_r197_BAG_L1   0.985396     roc_auc       0.086795    0.814530                0.086795           0.814530            1       True         91
# 44                 XGBoost_r89_BAG_L2   0.985320     roc_auc       0.874939  106.473768                0.044818           3.016731            2      False        125
# 45          NeuralNetTorch_r14_BAG_L2   0.985269     roc_auc       1.038145  111.276455                0.208024           7.819418            2      False        135
# 46         NeuralNetFastAI_r11_BAG_L2   0.984988     roc_auc       0.930553  111.666578                0.100432           8.209541            2      False        130
# 47          NeuralNetTorch_r30_BAG_L2   0.984375     roc_auc       1.014578  115.087978                0.184457          11.630941            2      False        126
# 48              NeuralNetTorch_BAG_L2   0.983839     roc_auc       1.048602  113.094878                0.218481           9.637841            2      False        108
# 49              ExtraTrees_r42_BAG_L1   0.983686     roc_auc       0.086413    0.557111                0.086413           0.557111            1       True         22
# 50             NeuralNetFastAI_BAG_L2   0.983584     roc_auc       0.910602  110.751909                0.080481           7.294872            2      False        106
# 51          NeuralNetTorch_r41_BAG_L2   0.983354     roc_auc       1.014994  112.338551                0.184873           8.881514            2      False        144
# 52          NeuralNetTorch_r79_BAG_L2   0.983303     roc_auc       1.067604  113.183498                0.237483           9.726461            2      False        111
# 53          NeuralNetTorch_r22_BAG_L2   0.983290     roc_auc       1.047485  113.902856                0.217364          10.445819            2      False        116
# 54        NeuralNetFastAI_r145_BAG_L2   0.983175     roc_auc       0.906914  110.823803                0.076794           7.366766            2      False        124
# 55                  LightGBMXT_BAG_L1   0.983150     roc_auc       0.033310    2.249491                0.033310           2.249491            1      False          3
# 56               LightGBM_r188_BAG_L1   0.983098     roc_auc       0.039220    4.123987                0.039220           4.123987            1      False         27
# 57               LightGBM_r196_BAG_L1   0.983073     roc_auc       0.152511    9.583039                0.152511           9.583039            1      False         44
# 58           RandomForest_r195_BAG_L2   0.982996     roc_auc       0.906116  104.256351                0.075996           0.799314            2      False        122
# 59           RandomForest_r127_BAG_L2   0.982920     roc_auc       0.905110  104.429873                0.074989           0.972836            2      False        154
# 60            RandomForestGini_BAG_L1   0.982447     roc_auc       0.080980    0.584848                0.080980           0.584848            1       True          5
# 61            RandomForestEntr_BAG_L1   0.981911     roc_auc       0.079995    0.520529                0.079995           0.520529            1       True          6
# 62                LightGBM_r30_BAG_L1   0.981873     roc_auc       0.080921    7.170498                0.080921           7.170498            1      False         69
# 63            RandomForest_r39_BAG_L2   0.981784     roc_auc       0.914426  104.208551                0.084305           0.751514            2      False        141
# 64           RandomForest_r166_BAG_L1   0.981133     roc_auc       0.095644    0.834207                0.095644           0.834207            1       True         76
# 65         NeuralNetTorch_r158_BAG_L2   0.980992     roc_auc       1.051558  114.708764                0.221437          11.251727            2      False        147
# 66                LightGBM_r94_BAG_L1   0.980596     roc_auc       0.045636    4.962008                0.045636           4.962008            1      False         61
# 67         NeuralNetFastAI_r95_BAG_L2   0.980596     roc_auc       0.929569  110.756099                0.099449           7.299062            2      False        143
# 68              ExtraTreesEntr_BAG_L1   0.979665     roc_auc       0.077401    0.532488                0.077401           0.532488            1       True          9
# 69          NeuralNetTorch_r86_BAG_L2   0.979511     roc_auc       1.030503  113.232079                0.200382           9.775042            2      False        128
# 70         NeuralNetTorch_r197_BAG_L2   0.979077     roc_auc       1.027203  111.242163                0.197083           7.785126            2      False        150
# 71              ExtraTrees_r49_BAG_L1   0.978158     roc_auc       0.085535    0.643893                0.085535           0.643893            1       True         56
# 72              ExtraTreesGini_BAG_L1   0.978158     roc_auc       0.086606    0.541715                0.086606           0.541715            1       True          8
# 73           RandomForest_r195_BAG_L1   0.976435     roc_auc       0.085459    0.780407                0.085459           0.780407            1       True         26
# 74               CatBoost_r180_BAG_L1   0.976026     roc_auc       0.049820   60.348915                0.049820          60.348915            1      False         89
# 75                CatBoost_r86_BAG_L1   0.975797     roc_auc       0.052593  209.121932                0.052593         209.121932            1      False         52
# 76        NeuralNetFastAI_r103_BAG_L2   0.975771     roc_auc       0.925508  110.909130                0.095387           7.452093            2      False        134
# 77                    CatBoost_BAG_L1   0.975643     roc_auc       0.038481  357.077584                0.038481         357.077584            1      False          7
# 78               CatBoost_r128_BAG_L1   0.975311     roc_auc       0.066685  366.125787                0.066685         366.125787            1      False         63
# 79                CatBoost_r13_BAG_L1   0.975260     roc_auc       0.051695  132.564484                0.051695         132.564484            1      False         25
# 80               CatBoost_r177_BAG_L1   0.975260     roc_auc       0.062905   26.653640                0.062905          26.653640            1      False         14
# 81                 CatBoost_r9_BAG_L1   0.975056     roc_auc       0.063527  716.581419                0.063527         716.581419            1      False         18
# 82               CatBoost_r167_BAG_L1   0.974673     roc_auc       0.046963   48.048510                0.046963          48.048510            1      False         46
# 83                CatBoost_r50_BAG_L1   0.974546     roc_auc       0.051635   40.427807                0.051635          40.427807            1      False         33
# 84             ExtraTrees_r172_BAG_L1   0.974520     roc_auc       0.083412    0.518437                0.083412           0.518437            1       True         36
# 85                CatBoost_r12_BAG_L1   0.974443     roc_auc       0.055242  109.580560                0.055242         109.580560            1      False         96
# 86               LightGBM_r161_BAG_L1   0.974214     roc_auc       0.051058    6.633835                0.051058           6.633835            1      False         40
# 87               LightGBMLarge_BAG_L2   0.974137     roc_auc       0.862515  106.916209                0.032395           3.459172            2      False        109
# 88                LightGBM_r96_BAG_L1   0.974009     roc_auc       0.071542    7.197356                0.071542           7.197356            1      False         19
# 89            RandomForest_r16_BAG_L1   0.973958     roc_auc       0.084178    1.197353                0.084178           1.197353            1       True         94
# 90               LightGBM_r121_BAG_L1   0.973652     roc_auc       0.049578    6.554243                0.049578           6.554243            1      False         87
# 91                CatBoost_r69_BAG_L1   0.973550     roc_auc       0.054479   40.743582                0.054479          40.743582            1      False         37
# 92                CatBoost_r49_BAG_L1   0.973550     roc_auc       0.051452    8.089144                0.051452           8.089144            1      False         55
# 93          NeuralNetTorch_r41_BAG_L1   0.973524     roc_auc       0.206294   13.717101                0.206294          13.717101            1      False         48
# 94                CatBoost_r60_BAG_L1   0.973218     roc_auc       0.050127  277.684236                0.050127         277.684236            1      False         80
# 95                 CatBoost_r6_BAG_L1   0.973192     roc_auc       0.053488   32.398104                0.053488          32.398104            1      False         85
# 96               LightGBM_r131_BAG_L1   0.973039     roc_auc       0.049331    6.587693                0.049331           6.587693            1      False         16
# 97                LightGBM_r15_BAG_L1   0.972988     roc_auc       0.034441    2.652288                0.034441           2.652288            1      False         50
# 98                CatBoost_r70_BAG_L1   0.972937     roc_auc       0.055213   55.040353                0.055213          55.040353            1      False         42
# 99                 XGBoost_r98_BAG_L1   0.972478     roc_auc       0.218600   12.963785                0.218600          12.963785            1      False         49
# 100            ExtraTrees_r178_BAG_L1   0.972452     roc_auc       0.083637    0.634721                0.083637           0.634721            1       True         75
# 101              CatBoost_r143_BAG_L1   0.972426     roc_auc       0.057111  202.741122                0.057111         202.741122            1      False         74
# 102           RandomForest_r39_BAG_L1   0.972273     roc_auc       0.083704    0.666595                0.083704           0.666595            1       True         45
# 103              LightGBM_r143_BAG_L1   0.971584     roc_auc       0.040288    5.034235                0.040288           5.034235            1      False         57
# 104       NeuralNetFastAI_r134_BAG_L1   0.971303     roc_auc       0.143871   12.776066                0.143871          12.776066            1      False         59
# 105           RandomForest_r15_BAG_L1   0.971099     roc_auc       0.085228    0.777589                0.085228           0.777589            1       True         81
# 106        NeuralNetTorch_r185_BAG_L1   0.971099     roc_auc       0.199924   10.108679                0.199924          10.108679            1      False         78
# 107                   LightGBM_BAG_L1   0.970844     roc_auc       0.016486    3.063430                0.016486           3.063430            1      False          4
# 108              LightGBM_r135_BAG_L1   0.970792     roc_auc       0.034671    3.623403                0.034671           3.623403            1      False         82
# 109              LightGBM_r130_BAG_L1   0.970639     roc_auc       0.033499    3.312700                0.033499           3.312700            1      False         31
# 110                XGBoost_r33_BAG_L1   0.970435     roc_auc       0.051032    6.091329                0.051032           6.091329            1      False         21
# 111              CatBoost_r137_BAG_L1   0.970282     roc_auc       0.049059   39.332142                0.049059          39.332142            1      False         23
# 112                XGBoost_r89_BAG_L1   0.970256     roc_auc       0.046528    3.480311                0.046528           3.480311            1      False         29
# 113                CatBoost_r5_BAG_L1   0.970027     roc_auc       0.052726   12.532493                0.052726          12.532493            1      False         71
# 114                XGBoost_r49_BAG_L1   0.969107     roc_auc       0.042494    4.434530                0.042494           4.434530            1      False         70
# 115                XGBoost_r31_BAG_L1   0.969107     roc_auc       0.060320    9.712589                0.060320           9.712589            1      False         77
# 116       NeuralNetFastAI_r156_BAG_L1   0.968980     roc_auc       0.099481    9.784666                0.099481           9.784666            1      False         43
# 117               XGBoost_r194_BAG_L1   0.968622     roc_auc       0.203178    4.444662                0.203178           4.444662            1      False         35
# 118       NeuralNetFastAI_r138_BAG_L1   0.968290     roc_auc       0.102153    8.077231                0.102153           8.077231            1      False         86
# 119                XGBoost_r22_BAG_L1   0.967729     roc_auc       0.041309    3.438735                0.041309           3.438735            1      False         83
# 120       NeuralNetFastAI_r194_BAG_L1   0.967244     roc_auc       0.091318    7.236156                0.091318           7.236156            1      False         95
# 121       NeuralNetFastAI_r143_BAG_L1   0.966376     roc_auc       0.108161   10.424623                0.108161          10.424623            1      False         41
# 122          RandomForest_r127_BAG_L1   0.965571     roc_auc       0.091067    0.802614                0.091067           0.802614            1       True         58
# 123        NeuralNetFastAI_r65_BAG_L1   0.965252     roc_auc       0.090239   10.323426                0.090239          10.323426            1      False         67
# 124       NeuralNetFastAI_r102_BAG_L1   0.965150     roc_auc       0.098004    8.929751                0.098004           8.929751            1      False         24
# 125                    XGBoost_BAG_L1   0.965099     roc_auc       0.066925    3.479603                0.066925           3.479603            1      False         11
# 126            NeuralNetFastAI_BAG_L1   0.963746     roc_auc       0.047988    6.887562                0.047988           6.887562            1      False         10
# 127              LightGBMLarge_BAG_L1   0.963567     roc_auc       0.024327    3.239443                0.024327           3.239443            1      False         13
# 128       NeuralNetFastAI_r172_BAG_L1   0.962469     roc_auc       0.104088    9.337219                0.104088           9.337219            1      False         88
# 129         NeuralNetTorch_r86_BAG_L1   0.961640     roc_auc       0.229371   21.154406                0.229371          21.154406            1      False         32
# 130        NeuralNetFastAI_r37_BAG_L1   0.960708     roc_auc       0.098241   10.806826                0.098241          10.806826            1      False         53
# 131       NeuralNetFastAI_r127_BAG_L1   0.959278     roc_auc       0.106527    8.896854                0.106527           8.896854            1      False         93
# 132       NeuralNetFastAI_r145_BAG_L1   0.958410     roc_auc       0.089632    7.405201                0.089632           7.405201            1      False         28
# 133             NeuralNetTorch_BAG_L1   0.958027     roc_auc       0.194257   12.704340                0.194257          12.704340            1      False         12
# 134         NeuralNetTorch_r87_BAG_L1   0.957670     roc_auc       0.190837    9.797439                0.190837           9.797439            1      False         72
# 135        NeuralNetTorch_r158_BAG_L1   0.956789     roc_auc       0.188787   12.875044                0.188787          12.875044            1      False         51
# 136         NeuralNetTorch_r14_BAG_L1   0.956546     roc_auc       0.186030   11.402324                0.186030          11.402324            1      False         39
# 137         NeuralNetTorch_r76_BAG_L1   0.956546     roc_auc       0.198760    8.943837                0.198760           8.943837            1      False         90
# 138        NeuralNetTorch_r121_BAG_L1   0.955499     roc_auc       0.230989   14.987942                0.230989          14.987942            1      False         92
# 139       NeuralNetFastAI_r191_BAG_L1   0.955065     roc_auc       0.153588    7.821981                0.153588           7.821981            1      False         17
# 140       NeuralNetFastAI_r160_BAG_L1   0.954248     roc_auc       0.082063    7.303713                0.082063           7.303713            1      False         79
# 141       NeuralNetFastAI_r111_BAG_L1   0.953074     roc_auc       0.105845    8.627561                0.105845           8.627561            1      False         64
# 142         NeuralNetTorch_r71_BAG_L1   0.952359     roc_auc       0.193150    8.180568                0.193150           8.180568            1      False         73
# 143        NeuralNetFastAI_r95_BAG_L1   0.951542     roc_auc       0.081803    7.077620                0.081803           7.077620            1      False         47
# 144         NeuralNetTorch_r79_BAG_L1   0.951006     roc_auc       0.196222   21.269646                0.196222          21.269646            1      False         15
# 145        NeuralNetFastAI_r88_BAG_L1   0.950648     roc_auc       0.106509    8.449970                0.106509           8.449970            1      False         68
# 146       NeuralNetFastAI_r103_BAG_L1   0.949321     roc_auc       0.078687    6.789310                0.078687           6.789310            1      False         38
# 147         NeuralNetTorch_r22_BAG_L1   0.948785     roc_auc       0.223840   10.094174                0.223840          10.094174            1      False         20
# 148        NeuralNetTorch_r143_BAG_L1   0.947789     roc_auc       0.199009   19.351918                0.199009          19.351918            1      False         62
# 149        NeuralNetFastAI_r69_BAG_L1   0.947661     roc_auc       0.081277    7.022923                0.081277           7.022923            1      False         84
# 150        NeuralNetFastAI_r11_BAG_L1   0.947049     roc_auc       0.100035    7.549260                0.100035           7.549260            1      False         34
# 151         NeuralNetTorch_r31_BAG_L1   0.944815     roc_auc       0.186863    9.179254                0.186863           9.179254            1      False         65
# 152         NeuralNetTorch_r30_BAG_L1   0.943423     roc_auc       0.211150   12.630495                0.211150          12.630495            1      False         30
# 153        NeuralNetTorch_r135_BAG_L1   0.940142     roc_auc       0.189011   20.326426                0.189011          20.326426            1      False         97
# 154        NeuralNetTorch_r197_BAG_L1   0.932815     roc_auc       0.189971    7.753782                0.189971           7.753782            1      False         54
# 155              ExtraTrees_r4_BAG_L1   0.932521     roc_auc       0.084471    0.615742                0.084471           0.615742            1       True         66
# 156           RandomForest_r34_BAG_L1   0.924837     roc_auc       0.083014    0.566567                0.083014           0.566567            1       True         60
# 157             KNeighborsDist_BAG_L1   0.824908     roc_auc       0.010450    0.002301                0.010450           0.002301            1       True          2
# 158             KNeighborsUnif_BAG_L1   0.717984     roc_auc       0.195307    0.016649                0.195307           0.016649            1       True          1
# 159        KNeighborsDist_BAG_L1_FULL        NaN     roc_auc       0.010450    0.002301                0.010450           0.002301            1       True        161
# 160        ExtraTreesEntr_BAG_L1_FULL        NaN     roc_auc       0.077401    0.532488                0.077401           0.532488            1       True        168
# 161      RandomForestEntr_BAG_L1_FULL        NaN     roc_auc       0.079995    0.520529                0.079995           0.520529            1       True        165
# 162      RandomForestGini_BAG_L1_FULL        NaN     roc_auc       0.080980    0.584848                0.080980           0.584848            1       True        164
# 163      RandomForest_r34_BAG_L1_FULL        NaN     roc_auc       0.083014    0.566567                0.083014           0.566567            1       True        219
# 164       ExtraTrees_r172_BAG_L1_FULL        NaN     roc_auc       0.083412    0.518437                0.083412           0.518437            1       True        195
# 165       ExtraTrees_r178_BAG_L1_FULL        NaN     roc_auc       0.083637    0.634721                0.083637           0.634721            1       True        234
# 166      RandomForest_r39_BAG_L1_FULL        NaN     roc_auc       0.083704    0.666595                0.083704           0.666595            1       True        204
# 167      RandomForest_r16_BAG_L1_FULL        NaN     roc_auc       0.084178    1.197353                0.084178           1.197353            1       True        253
# 168         ExtraTrees_r4_BAG_L1_FULL        NaN     roc_auc       0.084471    0.615742                0.084471           0.615742            1       True        225
# 169      RandomForest_r15_BAG_L1_FULL        NaN     roc_auc       0.085228    0.777589                0.085228           0.777589            1       True        240
# 170     RandomForest_r195_BAG_L1_FULL        NaN     roc_auc       0.085459    0.780407                0.085459           0.780407            1       True        185
# 171        ExtraTrees_r49_BAG_L1_FULL        NaN     roc_auc       0.085535    0.643893                0.085535           0.643893            1       True        215
# 172        ExtraTrees_r42_BAG_L1_FULL        NaN     roc_auc       0.086413    0.557111                0.086413           0.557111            1       True        181
# 173        ExtraTreesGini_BAG_L1_FULL        NaN     roc_auc       0.086606    0.541715                0.086606           0.541715            1       True        167
# 174       ExtraTrees_r197_BAG_L1_FULL        NaN     roc_auc       0.086795    0.814530                0.086795           0.814530            1       True        250
# 175     RandomForest_r127_BAG_L1_FULL        NaN     roc_auc       0.091067    0.802614                0.091067           0.802614            1       True        217
# 176     RandomForest_r166_BAG_L1_FULL        NaN     roc_auc       0.095644    0.834207                0.095644           0.834207            1       True        235
# 177        KNeighborsUnif_BAG_L1_FULL        NaN     roc_auc       0.195307    0.016649                0.195307           0.016649            1       True        160
# 178           XGBoost_r98_BAG_L2_FULL        NaN     roc_auc            NaN    9.031783                     NaN           0.597170            2       True        304
# 179           XGBoost_r98_BAG_L1_FULL        NaN     roc_auc            NaN    1.360269                     NaN           1.360269            1       True        208
# 180           XGBoost_r89_BAG_L2_FULL        NaN     roc_auc            NaN    8.523205                     NaN           0.088591            2       True        284
# 181           XGBoost_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.160373                     NaN           0.160373            1       True        188
# 182           XGBoost_r49_BAG_L1_FULL        NaN     roc_auc            NaN    0.250998                     NaN           0.250998            1       True        229
# 183           XGBoost_r33_BAG_L2_FULL        NaN     roc_auc            NaN    8.724916                     NaN           0.290303            2       True        276
# 184           XGBoost_r33_BAG_L1_FULL        NaN     roc_auc            NaN    0.491746                     NaN           0.491746            1       True        180
# 185           XGBoost_r31_BAG_L1_FULL        NaN     roc_auc            NaN    0.805382                     NaN           0.805382            1       True        236
# 186           XGBoost_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.145599                     NaN           0.145599            1       True        242
# 187          XGBoost_r194_BAG_L2_FULL        NaN     roc_auc            NaN    8.556081                     NaN           0.121468            2       True        290
# 188          XGBoost_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.229610                     NaN           0.229610            1       True        194
# 189               XGBoost_BAG_L2_FULL        NaN     roc_auc            NaN    8.538674                     NaN           0.104061            2       True        266
# 190               XGBoost_BAG_L1_FULL        NaN     roc_auc            NaN    0.283379                     NaN           0.283379            1       True        170
# 191          WeightedEnsemble_L3_FULL        NaN     roc_auc            NaN   11.635528                     NaN           0.053863            3       True        318
# 192          WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN    3.428941                     NaN           0.050997            2       True        257
# 193      RandomForest_r39_BAG_L2_FULL        NaN     roc_auc            NaN    9.186127                0.084305           0.751514            2       True        300
# 194      RandomForest_r34_BAG_L2_FULL        NaN     roc_auc            NaN    9.026767                0.075060           0.592154            2       True        315
# 195     RandomForest_r195_BAG_L2_FULL        NaN     roc_auc            NaN    9.233928                0.075996           0.799314            2       True        281
# 196     RandomForest_r127_BAG_L2_FULL        NaN     roc_auc            NaN    9.407449                0.074989           0.972836            2       True        313
# 197      RandomForestGini_BAG_L2_FULL        NaN     roc_auc            NaN    9.108785                0.104239           0.674171            2       True        260
# 198      RandomForestEntr_BAG_L2_FULL        NaN     roc_auc            NaN    8.953988                0.084306           0.519375            2       True        261
# 199    NeuralNetTorch_r87_BAG_L1_FULL        NaN     roc_auc            NaN    0.663818                     NaN           0.663818            1       True        231
# 200    NeuralNetTorch_r86_BAG_L2_FULL        NaN     roc_auc            NaN    9.093286                     NaN           0.658673            2       True        287
# 201    NeuralNetTorch_r86_BAG_L1_FULL        NaN     roc_auc            NaN    1.683994                     NaN           1.683994            1       True        191
# 202    NeuralNetTorch_r79_BAG_L2_FULL        NaN     roc_auc            NaN    9.367536                     NaN           0.932923            2       True        270
# 203    NeuralNetTorch_r79_BAG_L1_FULL        NaN     roc_auc            NaN    4.217252                     NaN           4.217252            1       True        174
# 204    NeuralNetTorch_r76_BAG_L1_FULL        NaN     roc_auc            NaN    0.459468                     NaN           0.459468            1       True        249
# 205    NeuralNetTorch_r71_BAG_L1_FULL        NaN     roc_auc            NaN    0.378890                     NaN           0.378890            1       True        232
# 206    NeuralNetTorch_r41_BAG_L2_FULL        NaN     roc_auc            NaN    9.160861                     NaN           0.726248            2       True        303
# 207    NeuralNetTorch_r41_BAG_L1_FULL        NaN     roc_auc            NaN    1.233212                     NaN           1.233212            1       True        207
# 208    NeuralNetTorch_r31_BAG_L1_FULL        NaN     roc_auc            NaN    0.702193                     NaN           0.702193            1       True        224
# 209    NeuralNetTorch_r30_BAG_L2_FULL        NaN     roc_auc            NaN    9.851427                     NaN           1.416814            2       True        285
# 210    NeuralNetTorch_r30_BAG_L1_FULL        NaN     roc_auc            NaN    1.434008                     NaN           1.434008            1       True        189
# 211    NeuralNetTorch_r22_BAG_L2_FULL        NaN     roc_auc            NaN    9.043549                     NaN           0.608936            2       True        275
# 212    NeuralNetTorch_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.861467                     NaN           0.861467            1       True        179
# 213   NeuralNetTorch_r197_BAG_L2_FULL        NaN     roc_auc            NaN    8.567626                     NaN           0.133012            2       True        309
# 214   NeuralNetTorch_r197_BAG_L1_FULL        NaN     roc_auc            NaN    0.433317                     NaN           0.433317            1       True        213
# 215   NeuralNetTorch_r185_BAG_L1_FULL        NaN     roc_auc            NaN    0.813844                     NaN           0.813844            1       True        237
# 216   NeuralNetTorch_r158_BAG_L2_FULL        NaN     roc_auc            NaN    9.459103                     NaN           1.024490            2       True        306
# 217   NeuralNetTorch_r158_BAG_L1_FULL        NaN     roc_auc            NaN    1.316420                     NaN           1.316420            1       True        210
# 218    NeuralNetTorch_r14_BAG_L2_FULL        NaN     roc_auc            NaN    8.846205                     NaN           0.411592            2       True        294
# 219    NeuralNetTorch_r14_BAG_L1_FULL        NaN     roc_auc            NaN    1.331342                     NaN           1.331342            1       True        198
# 220   NeuralNetTorch_r143_BAG_L2_FULL        NaN     roc_auc            NaN    9.343524                     NaN           0.908911            2       True        317
# 221   NeuralNetTorch_r143_BAG_L1_FULL        NaN     roc_auc            NaN    2.916774                     NaN           2.916774            1       True        221
# 222   NeuralNetTorch_r135_BAG_L1_FULL        NaN     roc_auc            NaN    2.266784                     NaN           2.266784            1       True        256
# 223   NeuralNetTorch_r121_BAG_L1_FULL        NaN     roc_auc            NaN    1.177395                     NaN           1.177395            1       True        251
# 224        NeuralNetTorch_BAG_L2_FULL        NaN     roc_auc            NaN    9.516990                     NaN           1.082377            2       True        267
# 225        NeuralNetTorch_BAG_L1_FULL        NaN     roc_auc            NaN    3.516580                     NaN           3.516580            1       True        171
# 226   NeuralNetFastAI_r95_BAG_L2_FULL        NaN     roc_auc            NaN    8.741208                     NaN           0.306594            2       True        302
# 227   NeuralNetFastAI_r95_BAG_L1_FULL        NaN     roc_auc            NaN    0.258173                     NaN           0.258173            1       True        206
# 228   NeuralNetFastAI_r88_BAG_L1_FULL        NaN     roc_auc            NaN    0.246868                     NaN           0.246868            1       True        227
# 229   NeuralNetFastAI_r69_BAG_L1_FULL        NaN     roc_auc            NaN    0.273827                     NaN           0.273827            1       True        243
# 230   NeuralNetFastAI_r65_BAG_L1_FULL        NaN     roc_auc            NaN    1.833911                     NaN           1.833911            1       True        226
# 231   NeuralNetFastAI_r37_BAG_L2_FULL        NaN     roc_auc            NaN    9.132195                     NaN           0.697582            2       True        308
# 232   NeuralNetFastAI_r37_BAG_L1_FULL        NaN     roc_auc            NaN    1.445267                     NaN           1.445267            1       True        212
# 233  NeuralNetFastAI_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.375124                     NaN           0.375124            1       True        254
# 234  NeuralNetFastAI_r191_BAG_L2_FULL        NaN     roc_auc            NaN    8.719316                     NaN           0.284703            2       True        272
# 235  NeuralNetFastAI_r191_BAG_L1_FULL        NaN     roc_auc            NaN    0.317787                     NaN           0.317787            1       True        176
# 236  NeuralNetFastAI_r172_BAG_L1_FULL        NaN     roc_auc            NaN    0.659333                     NaN           0.659333            1       True        247
# 237  NeuralNetFastAI_r160_BAG_L1_FULL        NaN     roc_auc            NaN    0.273633                     NaN           0.273633            1       True        238
# 238  NeuralNetFastAI_r156_BAG_L2_FULL        NaN     roc_auc            NaN    9.066038                     NaN           0.631425            2       True        298
# 239  NeuralNetFastAI_r156_BAG_L1_FULL        NaN     roc_auc            NaN    1.274247                     NaN           1.274247            1       True        202
# 240  NeuralNetFastAI_r145_BAG_L2_FULL        NaN     roc_auc            NaN    8.783808                     NaN           0.349195            2       True        283
# 241  NeuralNetFastAI_r145_BAG_L1_FULL        NaN     roc_auc            NaN    0.384487                     NaN           0.384487            1       True        187
# 242  NeuralNetFastAI_r143_BAG_L2_FULL        NaN     roc_auc            NaN    9.573206                     NaN           1.138592            2       True        296
# 243  NeuralNetFastAI_r143_BAG_L1_FULL        NaN     roc_auc            NaN    1.491161                     NaN           1.491161            1       True        200
# 244  NeuralNetFastAI_r138_BAG_L1_FULL        NaN     roc_auc            NaN    0.535993                     NaN           0.535993            1       True        245
# 245  NeuralNetFastAI_r134_BAG_L2_FULL        NaN     roc_auc            NaN    9.214017                     NaN           0.779404            2       True        314
# 246  NeuralNetFastAI_r134_BAG_L1_FULL        NaN     roc_auc            NaN    0.743053                     NaN           0.743053            1       True        218
# 247  NeuralNetFastAI_r127_BAG_L1_FULL        NaN     roc_auc            NaN    1.173530                     NaN           1.173530            1       True        252
# 248   NeuralNetFastAI_r11_BAG_L2_FULL        NaN     roc_auc            NaN    8.656561                     NaN           0.221948            2       True        289
# 249   NeuralNetFastAI_r11_BAG_L1_FULL        NaN     roc_auc            NaN    0.234279                     NaN           0.234279            1       True        193
# 250  NeuralNetFastAI_r111_BAG_L1_FULL        NaN     roc_auc            NaN    0.873799                     NaN           0.873799            1       True        223
# 251  NeuralNetFastAI_r103_BAG_L2_FULL        NaN     roc_auc            NaN    8.627063                     NaN           0.192450            2       True        293
# 252  NeuralNetFastAI_r103_BAG_L1_FULL        NaN     roc_auc            NaN    0.181475                     NaN           0.181475            1       True        197
# 253  NeuralNetFastAI_r102_BAG_L2_FULL        NaN     roc_auc            NaN    9.170141                     NaN           0.735528            2       True        279
# 254  NeuralNetFastAI_r102_BAG_L1_FULL        NaN     roc_auc            NaN    0.998035                     NaN           0.998035            1       True        183
# 255       NeuralNetFastAI_BAG_L2_FULL        NaN     roc_auc            NaN    8.707343                     NaN           0.272730            2       True        265
# 256       NeuralNetFastAI_BAG_L1_FULL        NaN     roc_auc            NaN    0.379051                     NaN           0.379051            1       True        169
# 257          LightGBM_r96_BAG_L2_FULL        NaN     roc_auc            NaN    8.670063                     NaN           0.235449            2       True        274
# 258          LightGBM_r96_BAG_L1_FULL        NaN     roc_auc            NaN    0.484914                     NaN           0.484914            1       True        178
# 259          LightGBM_r94_BAG_L2_FULL        NaN     roc_auc            NaN    8.629262                     NaN           0.194649            2       True        316
# 260          LightGBM_r94_BAG_L1_FULL        NaN     roc_auc            NaN    0.316566                     NaN           0.316566            1       True        220
# 261          LightGBM_r30_BAG_L1_FULL        NaN     roc_auc            NaN    0.717634                     NaN           0.717634            1       True        228
# 262         LightGBM_r196_BAG_L2_FULL        NaN     roc_auc            NaN    9.272797                     NaN           0.838184            2       True        299
# 263         LightGBM_r196_BAG_L1_FULL        NaN     roc_auc            NaN    1.868278                     NaN           1.868278            1       True        203
# 264         LightGBM_r188_BAG_L2_FULL        NaN     roc_auc            NaN    8.665897                     NaN           0.231284            2       True        282
# 265         LightGBM_r188_BAG_L1_FULL        NaN     roc_auc            NaN    0.433162                     NaN           0.433162            1       True        186
# 266         LightGBM_r161_BAG_L2_FULL        NaN     roc_auc            NaN    8.801274                     NaN           0.366661            2       True        295
# 267         LightGBM_r161_BAG_L1_FULL        NaN     roc_auc            NaN    0.766749                     NaN           0.766749            1       True        199
# 268          LightGBM_r15_BAG_L2_FULL        NaN     roc_auc            NaN    8.659523                     NaN           0.224910            2       True        305
# 269          LightGBM_r15_BAG_L1_FULL        NaN     roc_auc            NaN    0.197470                     NaN           0.197470            1       True        209
# 270         LightGBM_r143_BAG_L2_FULL        NaN     roc_auc            NaN    8.697381                     NaN           0.262768            2       True        312
# 271         LightGBM_r143_BAG_L1_FULL        NaN     roc_auc            NaN    0.424375                     NaN           0.424375            1       True        216
# 272         LightGBM_r135_BAG_L1_FULL        NaN     roc_auc            NaN    0.230081                     NaN           0.230081            1       True        241
# 273         LightGBM_r131_BAG_L2_FULL        NaN     roc_auc            NaN    8.760013                     NaN           0.325399            2       True        271
# 274         LightGBM_r131_BAG_L1_FULL        NaN     roc_auc            NaN    0.675791                     NaN           0.675791            1       True        175
# 275         LightGBM_r130_BAG_L2_FULL        NaN     roc_auc            NaN    8.585103                     NaN           0.150489            2       True        286
# 276         LightGBM_r130_BAG_L1_FULL        NaN     roc_auc            NaN    0.216052                     NaN           0.216052            1       True        190
# 277         LightGBM_r121_BAG_L1_FULL        NaN     roc_auc            NaN    0.802033                     NaN           0.802033            1       True        246
# 278              LightGBM_BAG_L2_FULL        NaN     roc_auc            NaN    8.597608                     NaN           0.162995            2       True        259
# 279              LightGBM_BAG_L1_FULL        NaN     roc_auc            NaN    0.168414                     NaN           0.168414            1       True        163
# 280            LightGBMXT_BAG_L2_FULL        NaN     roc_auc            NaN    8.612718                     NaN           0.178105            2       True        258
# 281            LightGBMXT_BAG_L1_FULL        NaN     roc_auc            NaN    0.466606                     NaN           0.466606            1       True        162
# 282         LightGBMLarge_BAG_L2_FULL        NaN     roc_auc            NaN    8.803333                     NaN           0.368720            2       True        268
# 283         LightGBMLarge_BAG_L1_FULL        NaN     roc_auc            NaN    0.357141                     NaN           0.357141            1       True        172
# 284        ExtraTrees_r49_BAG_L2_FULL        NaN     roc_auc            NaN    9.110653                0.073500           0.676039            2       True        311
# 285        ExtraTrees_r42_BAG_L2_FULL        NaN     roc_auc            NaN    9.097459                0.085226           0.662846            2       True        277
# 286       ExtraTrees_r172_BAG_L2_FULL        NaN     roc_auc            NaN    9.132671                0.099678           0.698058            2       True        291
# ...
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2_FULL': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3_FULL': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L3   0.992519     roc_auc       1.216882
#  1          WeightedEnsemble_L2   0.991702     roc_auc       0.529387
#  2            LightGBMXT_BAG_L2   0.991294     roc_auc       0.856257
#  3          LightGBM_r94_BAG_L2   0.991013     roc_auc       0.865969
#  4         LightGBM_r196_BAG_L2   0.990809     roc_auc       0.935463
#  ..                         ...        ...         ...            ...
#  313  CatBoost_r137_BAG_L1_FULL        NaN     roc_auc            NaN
#  314   CatBoost_r12_BAG_L1_FULL        NaN     roc_auc            NaN
#  315  CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN
#  316       CatBoost_BAG_L2_FULL        NaN     roc_auc            NaN
#  317       CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    143.951586                0.000999           0.053863            3
#  1     27.945843                0.000997           0.050997            2
#  2    105.803207                0.026136           2.346170            2
#  3    106.040373                0.035848           2.583336            2
#  4    108.209626                0.105342           4.752589            2
#  ..          ...                     ...                ...          ...
#  313    4.429530                     NaN           4.429530            1
#  314    3.975440                     NaN           3.975440            1
#  315   15.650287                     NaN          15.650287            1
#  316   10.979349                     NaN           2.544736            2
#  317   25.942566                     NaN          25.942566            1
#
#       can_infer  fit_order
#  0        False        159
#  1        False         98
#  2        False         99
#  3        False        157
#  4        False        140
#  ..         ...        ...
#  313       True        182
#  314       True        255
#  315       True        222
#  316       True        262
#  317       True        166
#
#  [318 rows x 10 columns]}

# %%
auxiliary_metrics = ['accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 1.0
# Evaluations on test data:
# {
#     "roc_auc": 1.0,
#     "accuracy": 0.98,
#     "balanced_accuracy": 0.9772727272727273,
#     "mcc": 0.9600156738532383,
#     "f1": 0.9824561403508771,
#     "precision": 0.9655172413793104,
#     "recall": 1.0
# }
# {'roc_auc': 1.0,
#  'accuracy': 0.98,
#  'balanced_accuracy': 0.9772727272727273,
#  'mcc': 0.9600156738532383,
#  'f1': 0.9824561403508771,
#  'precision': 0.9655172413793104,
#  'recall': 1.0}

# %%
predictors = predictor.leaderboard(
    df_test,
    extra_metrics = auxiliary_metrics,
    extra_info=True,
    silent=True
)

# %%
predictors[['model', 'roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall', 'num_features']]
# Out:
#                           model  roc_auc  accuracy  balanced_accuracy  \
# 0      CatBoost_r49_BAG_L1_FULL      1.0      0.99           0.988636
# 1          CatBoost_BAG_L1_FULL      1.0      0.98           0.977273
# 2     CatBoost_r177_BAG_L1_FULL      1.0      0.98           0.977273
# 3      CatBoost_r12_BAG_L1_FULL      1.0      0.98           0.977273
# 4       CatBoost_r5_BAG_L1_FULL      1.0      0.98           0.977273
# ..                          ...      ...       ...                ...
# 313  NeuralNetFastAI_r11_BAG_L1      NaN       NaN                NaN
# 314   NeuralNetTorch_r31_BAG_L1      NaN       NaN                NaN
# 315   NeuralNetTorch_r30_BAG_L1      NaN       NaN                NaN
# 316  NeuralNetTorch_r135_BAG_L1      NaN       NaN                NaN
# 317  NeuralNetTorch_r197_BAG_L1      NaN       NaN                NaN
#
#            f1  precision  recall  num_features
# 0    0.991150   0.982456     1.0            82
# 1    0.982456   0.965517     1.0            82
# 2    0.982456   0.965517     1.0            82
# 3    0.982456   0.965517     1.0            82
# 4    0.982456   0.965517     1.0            82
# ..        ...        ...     ...           ...
# 313       NaN        NaN     NaN            82
# 314       NaN        NaN     NaN            82
# 315       NaN        NaN     NaN            82
# 316       NaN        NaN     NaN            82
# 317       NaN        NaN     NaN            82
#
# [318 rows x 8 columns]

# %%
predictors.to_excel(
    '../../data/tlp/predictors-smote.xlsx',
    index=False
)

# %%
predictor.feature_importance(data=df_train)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['clin-Covid_sintomaSarpullido']
# Computing feature importance via permutation shuffling for 75 features using 396 rows with 5 shuffle sets...
# 	185.97s	= Expected runtime (37.19s per shuffle set)
# 	30.47s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                importance        stddev  \
# eval-TLP-Stroop-color-PD                     2.471405e-03  1.134538e-03
# eval-TLP-Tavec-23_Recon_Ac-PD                4.440892e-17  6.080942e-17
# eval-TLP-FigRey-tipoCopia-PD                 4.440892e-17  6.080942e-17
# clin-ansiedad                                4.440892e-17  6.080942e-17
# ques-Sus-totalPar-PD                         2.220446e-17  4.965068e-17
# ...                                                   ...           ...
# eval-TLP-CubCorsi-total-PD                   0.000000e+00  0.000000e+00
# eval-TLP-FigRey-totalCopia-PD                0.000000e+00  0.000000e+00
# demo-fechaEvaluacion                         0.000000e+00  0.000000e+00
# eval-TLP-Stroop-palabras-PD                  0.000000e+00  0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.000000e+00  0.000000e+00
#
#                                               p_value  n      p99_high  \
# eval-TLP-Stroop-color-PD                     0.004107  5  4.807435e-03
# eval-TLP-Tavec-23_Recon_Ac-PD                0.088904  5  1.696164e-16
# eval-TLP-FigRey-tipoCopia-PD                 0.088904  5  1.696164e-16
# clin-ansiedad                                0.088904  5  1.696164e-16
# ques-Sus-totalPar-PD                         0.186950  5  1.244359e-16
# ...                                               ... ..           ...
# eval-TLP-CubCorsi-total-PD                   0.500000  5  0.000000e+00
# eval-TLP-FigRey-totalCopia-PD                0.500000  5  0.000000e+00
# demo-fechaEvaluacion                         0.500000  5  0.000000e+00
# eval-TLP-Stroop-palabras-PD                  0.500000  5  0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.500000  5  0.000000e+00
#
#                                                   p99_low
# eval-TLP-Stroop-color-PD                     1.353752e-04
# eval-TLP-Tavec-23_Recon_Ac-PD               -8.079851e-17
# eval-TLP-FigRey-tipoCopia-PD                -8.079851e-17
# clin-ansiedad                               -8.079851e-17
# ques-Sus-totalPar-PD                        -8.002698e-17
# ...                                                   ...
# eval-TLP-CubCorsi-total-PD                   0.000000e+00
# eval-TLP-FigRey-totalCopia-PD                0.000000e+00
# demo-fechaEvaluacion                         0.000000e+00
# eval-TLP-Stroop-palabras-PD                  0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.000000e+00
#
# [75 rows x 6 columns]
