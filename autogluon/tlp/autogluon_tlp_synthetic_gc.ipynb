# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-gc.csv')

# %%
df.head()
# Out:
#    demo-genero demo-fechaEvaluacion demo-fechaNacimiento demo-rangoEdad  \
# 0            2  2024-02-22T00:00:00  1942-05-08T00:00:00         Rango3
# 1            2  2024-06-26T00:00:00  1948-10-07T00:00:00         Rango3
# 2            2  2024-05-14T00:00:00  1952-05-08T00:00:00         Rango2
# 3            2  2024-04-10T00:00:00  1964-01-27T00:00:00         Rango1
# 4            2  2024-05-14T00:00:00  1959-09-16T00:00:00         Rango1
#
#    demo-edad  clin-reservaCognitiva_total  clin-reservaCognitiva_idiomas  \
# 0         81                           12                              0
# 1         75                            8                              0
# 2         72                           11                              0
# 3         60                           18                              2
# 4         64                           13                              0
#
#    clin-reservaCognitiva_ocupacion  clin-reservaCognitiva_escolaridad  \
# 0                                1                                  3
# 1                                1                                  3
# 2                                0                                  4
# 3                                1                                  4
# 4                                1                                  4
#
#    clin-ansiedad  ...  eval-TLP-Tavec-25_Discriminabilidad-PD  \
# 0          False  ...                                   84.09
# 1           True  ...                                   79.55
# 2          False  ...                                   88.64
# 3          False  ...                                   90.91
# 4          False  ...                                   86.36
#
#    eval-TLP-Tavec-26_Sesgo-PD  eval-TLP-Tavec-27_RI_B_frente_RI_A1-PD  \
# 0                        0.14                                  -20.00
# 1                       -0.33                                  -71.43
# 2                       -0.60                                  -14.29
# 3                        0.60                                   60.00
# 4                       -0.71                                    0.00
#
#    eval-TLP-Tavec-28_RL_CP_frente_RI_A5-PD  \
# 0                                     0.00
# 1                                    12.50
# 2                                    75.00
# 3                                    16.67
# 4                                    66.67
#
#    eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD  \
# 0                                      33.33
# 1                                       0.00
# 2                                      25.00
# 3                                       0.00
# 4                                       0.00
#
#    eval-TLP-Tavec-30_RL_LP_frente_RL_CP-PD  \
# 0                                    37.50
# 1                                     0.00
# 2                                   -20.00
# 3                                    50.00
# 4                                   -33.33
#
#    eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD  \
# 0                                    -33.33
# 1                                      0.00
# 2                                      0.00
# 3                                    -20.00
# 4                                      0.00
#
#    eval-TLP-Tavec-32_Recon_Ac_frente_RL_LP-PD  \
# 0                                      -38.46
# 1                                      -20.00
# 2                                      -16.67
# 3                                      -50.00
# 4                                      -10.00
#
#    eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  ED_2Clases
# 0                                        -7.69           D
# 1                                       -20.00           D
# 2                                       -16.67           D
# 3                                       -37.50           D
# 4                                       -10.00           D
#
# [5 rows x 77 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((396, 77), (100, 77))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/gc/v2'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['high_quality'],
    time_limit = 2 * 3600,
    auto_stack = True,
    # excluded_model_types=['KNN','RF','XT', 'LR'],
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       9.10 GB / 15.94 GB (57.1%)
# Disk Space Avail:   81.82 GB / 446.36 GB (18.3%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-03 14:59:26,461	INFO worker.py:1762 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\gc\v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=20244) Running DyStack sub-fit ...
# (_dystack pid=20244) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=20244) Beginning AutoGluon training ... Time limit = 1792s
# (_dystack pid=20244) AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\gc\v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=20244) Train Data Rows:    352
# (_dystack pid=20244) Train Data Columns: 76
# (_dystack pid=20244) Label Column:       ED_2Clases
# (_dystack pid=20244) Problem Type:       binary
# (_dystack pid=20244) Preprocessing data ...
# (_dystack pid=20244) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=20244) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=20244) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=20244) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=20244) Using Feature Generators to preprocess the data ...
# (_dystack pid=20244) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=20244) 	Available Memory:                    8678.49 MB
# (_dystack pid=20244) 	Train Data (Original)  Memory Usage: 0.25 MB (0.0% of available memory)
# (_dystack pid=20244) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=20244) 	Stage 1 Generators:
# (_dystack pid=20244) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=20244) 			Note: Converting 10 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=20244) 	Stage 2 Generators:
# (_dystack pid=20244) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=20244) 	Stage 3 Generators:
# (_dystack pid=20244) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=20244) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=20244) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=20244) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=20244) 	Stage 4 Generators:
# (_dystack pid=20244) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=20244) 	Stage 5 Generators:
# (_dystack pid=20244) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=20244) 	Useless Original Features (Count: 1): ['clin-Covid_sintomaSarpullido']
# (_dystack pid=20244) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=20244) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=20244) 		These features do not need to be present at inference time.
# (_dystack pid=20244) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=20244) 		('bool', [])                       :  8 | ['clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', 'clin-Hipercolesterolemia', ...]
# (_dystack pid=20244) 		('float', [])                      : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=20244) 		('int', [])                        : 49 | ['demo-genero', 'demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', ...]
# (_dystack pid=20244) 		('object', [])                     :  1 | ['demo-rangoEdad']
# (_dystack pid=20244) 		('object', ['datetime_as_object']) :  2 | ['demo-fechaEvaluacion', 'demo-fechaNacimiento']
# (_dystack pid=20244) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=20244) 		('category', [])             :  1 | ['demo-rangoEdad']
# (_dystack pid=20244) 		('float', [])                : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=20244) 		('int', [])                  : 47 | ['demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', 'clin-reservaCognitiva_escolaridad', ...]
# (_dystack pid=20244) 		('int', ['bool'])            : 10 | ['demo-genero', 'clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', ...]
# (_dystack pid=20244) 		('int', ['datetime_as_int']) :  9 | ['demo-fechaEvaluacion', 'demo-fechaEvaluacion.month', 'demo-fechaEvaluacion.day', 'demo-fechaEvaluacion.dayofweek', 'demo-fechaNacimiento', ...]
# (_dystack pid=20244) 	0.1s = Fit runtime
# (_dystack pid=20244) 	75 features in original data used to generate 82 features in processed data.
# (_dystack pid=20244) 	Train Data (Processed) Memory Usage: 0.19 MB (0.0% of available memory)
# (_dystack pid=20244) Data preprocessing and feature engineering runtime = 0.13s ...
# (_dystack pid=20244) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=20244) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=20244) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=20244) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=20244) User-specified model hyperparameters to be fit:
# (_dystack pid=20244) {
# (_dystack pid=20244) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=20244) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=20244) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=20244) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=20244) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=20244) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=20244) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=20244) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=20244) }
# (_dystack pid=20244) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=20244) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=20244) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1194.58s of the 1792.31s of remaining time.
# (_dystack pid=20244) 	0.4458	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.0s	 = Training   runtime
# (_dystack pid=20244) 	0.12s	 = Validation runtime
# (_dystack pid=20244) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1191.77s of the 1789.50s of remaining time.
# (_dystack pid=20244) 	0.4514	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.01s	 = Training   runtime
# (_dystack pid=20244) 	0.0s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1191.72s of the 1789.45s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=20244) 	0.9737	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.17s	 = Training   runtime
# (_dystack pid=20244) 	0.03s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1186.08s of the 1783.82s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=20244) 	0.9677	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.33s	 = Training   runtime
# (_dystack pid=20244) 	0.03s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1179.52s of the 1777.26s of remaining time.
# (_dystack pid=20244) 	0.9612	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.91s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1178.48s of the 1776.22s of remaining time.
# (_dystack pid=20244) 	0.9642	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.54s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1177.83s of the 1775.56s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=20244) 	0.9702	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	33.56s	 = Training   runtime
# (_dystack pid=20244) 	0.06s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1139.52s of the 1737.26s of remaining time.
# (_dystack pid=20244) 	0.9524	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.58s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1138.82s of the 1736.56s of remaining time.
# (_dystack pid=20244) 	0.9554	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.55s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1138.17s of the 1735.91s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=18652) No improvement since epoch 9: early stopping
# (_dystack pid=20244) 	0.9574	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.63s	 = Training   runtime
# (_dystack pid=20244) 	0.1s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_BAG_L1 ... Training model for up to 1127.17s of the 1724.91s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# (_dystack pid=20244) 	0.9546	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.78s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1118.72s of the 1716.46s of remaining time.
# (_ray_fit pid=16004) No improvement since epoch 9: early stopping
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9594	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	10.09s	 = Training   runtime
# (_dystack pid=20244) 	0.23s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1104.05s of the 1701.79s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# (_ray_fit pid=22852) [1000]	valid_set's binary_logloss: 0.114948
# (_ray_fit pid=22852) [2000]	valid_set's binary_logloss: 0.0976436
# (_ray_fit pid=22852) [3000]	valid_set's binary_logloss: 0.0933506
# (_ray_fit pid=22852) [4000]	valid_set's binary_logloss: 0.0924288
# (_dystack pid=20244) 	0.9641	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	3.81s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1095.40s of the 1693.13s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=20244) 	0.9701	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	11.93s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1078.95s of the 1676.68s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9654	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.4s	 = Training   runtime
# (_dystack pid=20244) 	0.23s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1065.02s of the 1662.75s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_ray_fit pid=20992) [1000]	valid_set's binary_logloss: 0.122181
# (_dystack pid=20244) 	0.9673	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.35s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1057.83s of the 1655.56s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=1588) No improvement since epoch 5: early stopping
# (_dystack pid=20244) 	0.9663	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.77s	 = Training   runtime
# (_dystack pid=20244) 	0.13s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1045.30s of the 1643.04s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.01%)
# (_dystack pid=20244) 	0.9693	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	73.37s	 = Training   runtime
# (_dystack pid=20244) 	0.09s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 966.64s of the 1564.38s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_ray_fit pid=9196) No improvement since epoch 15: early stopping [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=13012) [1000]	valid_set's binary_logloss: 0.166098
# (_dystack pid=20244) 	0.9683	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	4.36s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 957.98s of the 1555.71s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9651	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.02s	 = Training   runtime
# (_dystack pid=20244) 	0.23s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 944.77s of the 1542.50s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.11%)
# (_dystack pid=20244) 	0.9589	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	3.57s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 936.77s of the 1534.50s of remaining time.
# (_dystack pid=20244) 	0.9594	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.57s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 936.09s of the 1533.82s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_dystack pid=20244) 	0.9682	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	17.38s	 = Training   runtime
# (_dystack pid=20244) 	0.06s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 914.59s of the 1512.32s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=20760) No improvement since epoch 1: early stopping
# (_dystack pid=20244) 	0.9664	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	8.42s	 = Training   runtime
# (_dystack pid=20244) 	0.12s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 901.96s of the 1499.69s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.90%)
# (_dystack pid=20244) 	0.9689	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	91.15s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 805.76s of the 1403.50s of remaining time.
# (_ray_fit pid=12636) No improvement since epoch 6: early stopping [repeated 4x across cluster]
# (_dystack pid=20244) 	0.9627	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.82s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 804.80s of the 1402.54s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# (_dystack pid=20244) 	0.9712	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.2s	 = Training   runtime
# (_dystack pid=20244) 	0.02s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 799.41s of the 1397.14s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=15880) No improvement since epoch 6: early stopping
# (_dystack pid=20244) 	0.961	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.79s	 = Training   runtime
# (_dystack pid=20244) 	0.13s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 788.09s of the 1385.83s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# (_dystack pid=20244) 	0.9627	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.26s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 775.79s of the 1373.52s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=23400) No improvement since epoch 6: early stopping [repeated 5x across cluster]
# (_dystack pid=20244) 	0.9702	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	13.74s	 = Training   runtime
# (_dystack pid=20244) 	0.23s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 757.79s of the 1355.52s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# (_ray_fit pid=5484) [1000]	valid_set's binary_logloss: 0.113049 [repeated 14x across cluster]
# (_dystack pid=20244) 	0.9665	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.59s	 = Training   runtime
# (_dystack pid=20244) 	0.02s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 751.96s of the 1349.69s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.948	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	8.5s	 = Training   runtime
# (_dystack pid=20244) 	0.23s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 738.94s of the 1336.67s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=20244) 	0.9689	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	14.75s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 719.57s of the 1317.31s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=1608) No improvement since epoch 0: early stopping
# (_dystack pid=20244) 	0.9442	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.05s	 = Training   runtime
# (_dystack pid=20244) 	0.15s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 708.14s of the 1305.88s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.01%)
# (_dystack pid=20244) 	0.9659	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.36s	 = Training   runtime
# (_dystack pid=20244) 	0.21s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 696.62s of the 1294.35s of remaining time.
# (_ray_fit pid=12044) No improvement since epoch 0: early stopping [repeated 6x across cluster]
# (_dystack pid=20244) 	0.957	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.54s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 695.97s of the 1293.70s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=20244) 	0.9658	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	19.63s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 672.20s of the 1269.93s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=23480) No improvement since epoch 3: early stopping
# (_dystack pid=20244) 	0.9529	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.4s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 661.59s of the 1259.33s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=20244) 	0.9479	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	8.17s	 = Training   runtime
# (_dystack pid=20244) 	0.17s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 648.30s of the 1246.04s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.46%)
# (_ray_fit pid=7180) No improvement since epoch 5: early stopping [repeated 6x across cluster]
# (_ray_fit pid=23472) [1000]	valid_set's binary_logloss: 0.118225
# (_dystack pid=20244) 	0.9696	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.16s	 = Training   runtime
# (_dystack pid=20244) 	0.02s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 641.61s of the 1239.34s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=1028) No improvement since epoch 2: early stopping
# (_dystack pid=20244) 	0.9699	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.69s	 = Training   runtime
# (_dystack pid=20244) 	0.12s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 627.45s of the 1225.19s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=20244) 	0.9722	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	31.84s	 = Training   runtime
# (_dystack pid=20244) 	0.06s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 590.84s of the 1188.58s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=4688) No improvement since epoch 17: early stopping [repeated 5x across cluster]
# (_ray_fit pid=22472) No improvement since epoch 6: early stopping
# (_ray_fit pid=21248) No improvement since epoch 3: early stopping
# (_dystack pid=20244) 	0.9712	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	8.9s	 = Training   runtime
# (_dystack pid=20244) 	0.1s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 577.70s of the 1175.44s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# (_ray_fit pid=5252) [1000]	valid_set's binary_logloss: 0.261616
# (_dystack pid=20244) 	0.9691	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	3.96s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 569.15s of the 1166.89s of remaining time.
# (_ray_fit pid=21520) No improvement since epoch 16: early stopping [repeated 6x across cluster]
# (_dystack pid=20244) 	0.9635	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.65s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 568.38s of the 1166.12s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=20244) 	0.971	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	35.31s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 528.65s of the 1126.39s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=19940) No improvement since epoch 5: early stopping
# (_dystack pid=20244) 	0.9645	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.47s	 = Training   runtime
# (_dystack pid=20244) 	0.09s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 517.91s of the 1115.65s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=20244) 	0.9787	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	8.43s	 = Training   runtime
# (_dystack pid=20244) 	0.19s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 504.34s of the 1102.07s of remaining time.
# (_ray_fit pid=20884) No improvement since epoch 10: early stopping [repeated 5x across cluster]
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.54%)
# (_dystack pid=20244) 	0.9657	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.86s	 = Training   runtime
# (_dystack pid=20244) 	0.22s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 489.95s of the 1087.68s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.14%)
# (_ray_fit pid=8832) [1000]	valid_set's binary_logloss: 0.125835 [repeated 9x across cluster]
# (_dystack pid=20244) 	0.9674	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.7s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 484.06s of the 1081.79s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9707	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	11.26s	 = Training   runtime
# (_dystack pid=20244) 	0.2s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 468.43s of the 1066.17s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.48%)
# (_dystack pid=20244) 	0.968	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	67.46s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 396.68s of the 994.42s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=18260) No improvement since epoch 1: early stopping
# (_dystack pid=20244) 	0.9669	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.88s	 = Training   runtime
# (_dystack pid=20244) 	0.14s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 382.55s of the 980.29s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=20244) 	0.9574	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.62s	 = Training   runtime
# (_dystack pid=20244) 	0.17s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 371.21s of the 968.95s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_ray_fit pid=22916) No improvement since epoch 20: early stopping [repeated 5x across cluster]
# (_dystack pid=20244) 	0.971	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	4.64s	 = Training   runtime
# (_dystack pid=20244) 	0.06s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 361.40s of the 959.14s of remaining time.
# (_dystack pid=20244) 	0.9524	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.67s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 360.60s of the 958.34s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.00%)
# (_ray_fit pid=4252) [1000]	valid_set's binary_logloss: 0.111602
# (_dystack pid=20244) 	0.9681	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.81s	 = Training   runtime
# (_dystack pid=20244) 	0.02s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 354.37s of the 952.10s of remaining time.
# (_dystack pid=20244) 	0.9654	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.82s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 353.43s of the 951.16s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=12488) No improvement since epoch 1: early stopping
# (_dystack pid=20244) 	0.9625	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	11.81s	 = Training   runtime
# (_dystack pid=20244) 	0.13s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 337.19s of the 934.93s of remaining time.
# (_dystack pid=20244) 	0.9625	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.6s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 336.48s of the 934.22s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=1072) [1000]	valid_set's binary_logloss: 0.185406
# (_dystack pid=20244) 	0.9674	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.0s	 = Training   runtime
# (_dystack pid=20244) 	0.03s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 330.06s of the 927.80s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=22396) No improvement since epoch 16: early stopping [repeated 7x across cluster]
# (_dystack pid=20244) 	0.9596	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	12.53s	 = Training   runtime
# (_dystack pid=20244) 	0.22s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 312.99s of the 910.72s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.48%)
# (_dystack pid=20244) 	0.973	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	79.83s	 = Training   runtime
# (_dystack pid=20244) 	0.09s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 228.88s of the 826.62s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=6364) No improvement since epoch 0: early stopping
# (_dystack pid=20244) 	0.9657	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.54s	 = Training   runtime
# (_dystack pid=20244) 	0.13s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 217.14s of the 814.88s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=20244) 	0.953	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.38s	 = Training   runtime
# (_dystack pid=20244) 	0.19s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 204.63s of the 802.37s of remaining time.
# (_ray_fit pid=13408) No improvement since epoch 0: early stopping
# (_dystack pid=20244) 	0.9552	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.85s	 = Training   runtime
# (_dystack pid=20244) 	0.11s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 203.63s of the 801.37s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=8128) No improvement since epoch 11: early stopping
# (_dystack pid=20244) 	0.9557	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.09s	 = Training   runtime
# (_dystack pid=20244) 	0.12s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 190.02s of the 787.75s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=12252) No improvement since epoch 0: early stopping [repeated 2x across cluster]
# (_dystack pid=20244) 	0.9478	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	7.79s	 = Training   runtime
# (_dystack pid=20244) 	0.13s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 177.24s of the 774.97s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# (_ray_fit pid=6108) [1000]	valid_set's binary_logloss: 0.230271 [repeated 3x across cluster]
# (_dystack pid=20244) 	0.9735	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.25s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 169.95s of the 767.67s of remaining time.
# (_ray_fit pid=14108) No improvement since epoch 8: early stopping [repeated 7x across cluster]
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# (_dystack pid=20244) 	0.9588	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	2.53s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 162.86s of the 760.59s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=20244) 	0.9679	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	4.2s	 = Training   runtime
# (_dystack pid=20244) 	0.04s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 154.25s of the 751.99s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=20244) 	0.9705	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.44s	 = Training   runtime
# (_dystack pid=20244) 	0.18s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 140.08s of the 737.82s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9651	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.72s	 = Training   runtime
# (_dystack pid=20244) 	0.21s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 128.77s of the 726.51s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.02%)
# (_dystack pid=20244) 	0.97	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	12.68s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 110.74s of the 708.47s of remaining time.
# (_dystack pid=20244) 	0.9611	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.67s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 109.97s of the 707.70s of remaining time.
# (_dystack pid=20244) 	0.9564	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.8s	 = Training   runtime
# (_dystack pid=20244) 	0.08s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 109.05s of the 706.78s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=20244) 	0.96	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	4.11s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 100.63s of the 698.37s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=20244) 	0.9666	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	9.74s	 = Training   runtime
# (_dystack pid=20244) 	0.25s	 = Validation runtime
# (_dystack pid=20244) Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 86.77s of the 684.50s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_dystack pid=20244) 	0.9467	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	6.27s	 = Training   runtime
# (_dystack pid=20244) 	0.11s	 = Validation runtime
# (_dystack pid=20244) Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 76.01s of the 673.75s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=20244) 	0.967	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	23.15s	 = Training   runtime
# (_dystack pid=20244) 	0.05s	 = Validation runtime
# (_dystack pid=20244) Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 47.70s of the 645.43s of remaining time.
# (_dystack pid=20244) 	0.9656	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	0.76s	 = Training   runtime
# (_dystack pid=20244) 	0.07s	 = Validation runtime
# (_dystack pid=20244) Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 46.82s of the 644.55s of remaining time.
# (_dystack pid=20244) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.18%)
# (_dystack pid=20244) 	0.963	 = Validation score   (roc_auc)
# (_dystack pid=20244) 	1.03s	 = Training   runtime
# (_dystack pid=20244) 	0.03s	 = Validation runtime
# (_dystack pid=20244) Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 41.62s of the 639.35s of remaining time.
# ...
# 	0.01s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.48s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.14s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.77s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.53s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	3.67s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.54s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.52s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	2.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	11.48s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	0.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	0.51s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.56s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	4.8s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	12.01s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.78s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	0.98s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	1.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	0.2s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.53s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	3.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	1.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	4.77s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.89s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_BAG_L1_FULL ...
# 	0.93s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.66s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_BAG_L1_FULL ...
# 	3.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_BAG_L1_FULL ...
# 	0.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_BAG_L1_FULL ...
# 	0.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_BAG_L1_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	0.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	9.06s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	1.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_BAG_L1_FULL ...
# 	0.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_BAG_L1_FULL ...
# 	0.37s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.65s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.88s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.83s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.62s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_BAG_L1_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_BAG_L1_FULL ...
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_BAG_L1_FULL ...
# 	2.4s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_BAG_L1_FULL ...
# 	0.37s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.62s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 21.
# 	1.74s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_BAG_L1_FULL ...
# 	0.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_BAG_L1_FULL ...
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_BAG_L1_FULL ...
# 	0.6s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.66s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.82s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_BAG_L1_FULL ...
# 	0.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r160_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r60_BAG_L1_FULL ...
# 	3.54s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.77s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r135_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r22_BAG_L1_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r69_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r6_BAG_L1_FULL ...
# 	1.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r138_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.48s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r121_BAG_L1_FULL ...
# 	0.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r172_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r180_BAG_L1_FULL ...
# 	1.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r76_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.83s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r121_BAG_L1_FULL ...
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r127_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.86s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.25s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r194_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r12_BAG_L1_FULL ...
# 	4.49s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r135_BAG_L1_FULL ...
# 	0.76s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r4_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.2s	 = Training   runtime
# Fitting model: ExtraTrees_r126_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.92s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r36_BAG_L1_FULL ...
# 	0.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r100_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	1.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r163_BAG_L1_FULL ...
# 	2.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r198_BAG_L1_FULL ...
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r187_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r19_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r95_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r34_BAG_L1_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r42_BAG_L1_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r1_BAG_L1_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r89_BAG_L1_FULL ...
# 	0.73s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_r42_BAG_L1': 0.556, 'NeuralNetTorch_r19_BAG_L1': 0.222, 'CatBoost_r50_BAG_L1': 0.167, 'KNeighborsUnif_BAG_L1': 0.056}
# 	0.05s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 119.31s ... Best model: "WeightedEnsemble_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\gc\v2")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                 WeightedEnsemble_L2   0.982945     roc_auc       0.554326   27.472278                0.001003           0.048950            2      False        111
# 1                 LightGBM_r42_BAG_L1   0.981311     roc_auc       0.027292    2.578658                0.027292           2.578658            1      False        108
# 2                   LightGBMXT_BAG_L1   0.980622     roc_auc       0.034270    1.253230                0.034270           1.253230            1      False          3
# 3                 CatBoost_r50_BAG_L1   0.977686     roc_auc       0.059578   16.662794                0.059578          16.662794            1      False         33
# 4                 LightGBM_r30_BAG_L1   0.977558     roc_auc       0.059601    5.274924                0.059601           5.274924            1      False         69
# 5                LightGBM_r188_BAG_L1   0.976460     roc_auc       0.038349    2.992787                0.038349           2.992787            1      False         27
# 6                 LightGBM_r94_BAG_L1   0.976282     roc_auc       0.034014    3.133142                0.034014           3.133142            1      False         61
# 7                LightGBM_r196_BAG_L1   0.975567     roc_auc       0.103982    6.301224                0.103982           6.301224            1      False         44
# 8                LightGBM_r121_BAG_L1   0.975465     roc_auc       0.042851    3.576999                0.042851           3.576999            1      False         87
# 9                  CatBoost_r5_BAG_L1   0.974316     roc_auc       0.061390    6.142241                0.061390           6.142241            1      False         71
# 10               LightGBM_r143_BAG_L1   0.974239     roc_auc       0.033450    3.328364                0.033450           3.328364            1      False         57
# 11                CatBoost_r70_BAG_L1   0.974137     roc_auc       0.055039   42.091611                0.055039          42.091611            1      False         42
# 12               CatBoost_r163_BAG_L1   0.974112     roc_auc       0.052525   20.566913                0.052525          20.566913            1      False        102
# 13                LightGBM_r96_BAG_L1   0.974060     roc_auc       0.048324    4.604901                0.048324           4.604901            1      False         19
# 14                    LightGBM_BAG_L1   0.973703     roc_auc       0.026650    2.529780                0.026650           2.529780            1      False          4
# 15               LightGBM_r161_BAG_L1   0.973550     roc_auc       0.045282    3.595365                0.045282           3.595365            1      False         40
# 16                 CatBoost_r6_BAG_L1   0.973218     roc_auc       0.054467   16.828625                0.054467          16.828625            1      False         85
# 17                CatBoost_r86_BAG_L1   0.973192     roc_auc       0.051991   74.507638                0.051991          74.507638            1      False         52
# 18                CatBoost_r13_BAG_L1   0.973141     roc_auc       0.054276  363.348903                0.054276         363.348903            1      False         25
# 19                CatBoost_r49_BAG_L1   0.972809     roc_auc       0.056308    7.701940                0.056308           7.701940            1      False         55
# 20                XGBoost_r194_BAG_L1   0.972733     roc_auc       0.247523    4.028141                0.247523           4.028141            1      False         35
# 21               CatBoost_r198_BAG_L1   0.972631     roc_auc       0.060952   10.459542                0.060952          10.459542            1      False        103
# 22               CatBoost_r143_BAG_L1   0.972605     roc_auc       0.053137   16.319222                0.053137          16.319222            1      False         74
# 23                    CatBoost_BAG_L1   0.972529     roc_auc       0.053718   29.600030                0.053718          29.600030            1      False          7
# 24                 CatBoost_r9_BAG_L1   0.972375     roc_auc       0.061894  119.264987                0.061894         119.264987            1      False         18
# 25               CatBoost_r137_BAG_L1   0.972350     roc_auc       0.055698   31.875490                0.055698          31.875490            1      False         23
# 26               LightGBM_r131_BAG_L1   0.972324     roc_auc       0.041968    3.207989                0.041968           3.207989            1      False         16
# 27                CatBoost_r12_BAG_L1   0.972171     roc_auc       0.053824  168.899284                0.053824         168.899284            1      False         96
# 28                 XGBoost_r98_BAG_L1   0.972171     roc_auc       0.218124   10.565964                0.218124          10.565964            1      False         49
# 29                CatBoost_r69_BAG_L1   0.971992     roc_auc       0.057451   26.651531                0.057451          26.651531            1      False         37
# 30               CatBoost_r128_BAG_L1   0.971941     roc_auc       0.051486   44.020567                0.051486          44.020567            1      False         63
# 31               LightGBM_r135_BAG_L1   0.971916     roc_auc       0.031003    2.501577                0.031003           2.501577            1      False         82
# 32                LightGBM_r15_BAG_L1   0.971763     roc_auc       0.029437    2.918761                0.029437           2.918761            1      False         50
# 33               LightGBM_r130_BAG_L1   0.971737     roc_auc       0.027514    2.707933                0.027514           2.707933            1      False         31
# 34               CatBoost_r167_BAG_L1   0.971686     roc_auc       0.052121   32.989821                0.052121          32.989821            1      False         46
# 35                CatBoost_r60_BAG_L1   0.971431     roc_auc       0.049266   25.886026                0.049266          25.886026            1      False         80
# 36          NeuralNetTorch_r19_BAG_L1   0.971227     roc_auc       0.208326    8.173750                0.208326           8.173750            1      False        105
# 37         NeuralNetFastAI_r37_BAG_L1   0.970946     roc_auc       0.128284   11.590983                0.128284          11.590983            1      False         53
# 38                 XGBoost_r22_BAG_L1   0.970895     roc_auc       0.046008    3.524827                0.046008           3.524827            1      False         83
# 39                 XGBoost_r34_BAG_L1   0.970869     roc_auc       0.048114    4.818580                0.048114           4.818580            1      False        107
# 40               CatBoost_r180_BAG_L1   0.970001     roc_auc       0.054876   37.692339                0.054876          37.692339            1      False         89
# 41               CatBoost_r177_BAG_L1   0.970001     roc_auc       0.058854    9.585815                0.058854           9.585815            1      False         14
# 42                 XGBoost_r31_BAG_L1   0.969873     roc_auc       0.052171    4.417949                0.052171           4.417949            1      False         77
# 43                 XGBoost_r95_BAG_L1   0.969746     roc_auc       0.043006    3.734549                0.043006           3.734549            1      False        106
# 44                 XGBoost_r49_BAG_L1   0.969695     roc_auc       0.046850    5.140054                0.046850           5.140054            1      False         70
# 45                 XGBoost_r33_BAG_L1   0.969261     roc_auc       0.051709    7.087701                0.051709           7.087701            1      False         21
# 46                 XGBoost_r89_BAG_L1   0.968903     roc_auc       0.044490    3.610725                0.044490           3.610725            1      False         29
# 47          NeuralNetTorch_r41_BAG_L1   0.968878     roc_auc       0.188741   10.327452                0.188741          10.327452            1      False         48
# 48          NeuralNetTorch_r14_BAG_L1   0.968444     roc_auc       0.180313    8.659966                0.180313           8.659966            1      False         39
# 49          NeuralNetTorch_r76_BAG_L1   0.968265     roc_auc       0.187468    9.094428                0.187468           9.094428            1      False         90
# 50         NeuralNetTorch_r143_BAG_L1   0.967627     roc_auc       0.194812   10.558036                0.194812          10.558036            1      False         62
# 51           RandomForest_r127_BAG_L1   0.966708     roc_auc       0.083135    0.877996                0.083135           0.877996            1       True         58
# 52                     XGBoost_BAG_L1   0.966491     roc_auc       0.045688    4.280315                0.045688           4.280315            1      False         11
# 53            RandomForest_r15_BAG_L1   0.966273     roc_auc       0.082425    0.774995                0.082425           0.774995            1       True         81
# 54            RandomForestEntr_BAG_L1   0.966018     roc_auc       0.081630    0.534338                0.081630           0.534338            1       True          6
# 55          NeuralNetTorch_r79_BAG_L1   0.965891     roc_auc       0.198026   10.495720                0.198026          10.495720            1      False         15
# 56            RandomForest_r39_BAG_L1   0.965814     roc_auc       0.083741    0.658429                0.083741           0.658429            1       True         45
# 57          NeuralNetTorch_r30_BAG_L1   0.965763     roc_auc       0.206785   12.517650                0.206785          12.517650            1      False         30
# 58          NeuralNetTorch_r71_BAG_L1   0.965508     roc_auc       0.215696    8.429103                0.215696           8.429103            1      False         73
# 59           RandomForest_r195_BAG_L1   0.965086     roc_auc       0.084313    0.775371                0.084313           0.775371            1       True         26
# 60             ExtraTrees_r197_BAG_L1   0.964703     roc_auc       0.093189    0.832770                0.093189           0.832770            1       True         91
# 61          NeuralNetTorch_r36_BAG_L1   0.964691     roc_auc       0.212945    9.588867                0.212945           9.588867            1      False        100
# 62            RandomForest_r16_BAG_L1   0.964563     roc_auc       0.082886    1.253622                0.082886           1.253622            1       True         94
# 63         NeuralNetTorch_r158_BAG_L1   0.964537     roc_auc       0.192820   10.236940                0.192820          10.236940            1      False         51
# 64             ExtraTrees_r172_BAG_L1   0.964001     roc_auc       0.081944    0.529266                0.081944           0.529266            1       True         36
# 65             ExtraTrees_r178_BAG_L1   0.963363     roc_auc       0.081484    0.661036                0.081484           0.661036            1       True         75
# 66         NeuralNetTorch_r197_BAG_L1   0.963235     roc_auc       0.180459    7.826723                0.180459           7.826723            1      False         54
# 67          NeuralNetTorch_r86_BAG_L1   0.963159     roc_auc       0.209793   10.420013                0.209793          10.420013            1      False         32
# 68              ExtraTrees_r42_BAG_L1   0.962137     roc_auc       0.081508    0.564880                0.081508           0.564880            1       True         22
# 69          NeuralNetTorch_r89_BAG_L1   0.961525     roc_auc       0.208459   12.719622                0.208459          12.719622            1      False        110
# 70         NeuralNetTorch_r185_BAG_L1   0.961218     roc_auc       0.178573   10.392943                0.178573          10.392943            1      False         78
# 71        NeuralNetFastAI_r156_BAG_L1   0.961142     roc_auc       0.114075   10.091161                0.114075          10.091161            1      False         43
# 72        NeuralNetFastAI_r102_BAG_L1   0.961014     roc_auc       0.117189    9.608409                0.117189           9.608409            1      False         24
# 73         NeuralNetTorch_r135_BAG_L1   0.960938     roc_auc       0.195427   10.333000                0.195427          10.333000            1      False         97
# 74        NeuralNetFastAI_r187_BAG_L1   0.960503     roc_auc       0.109595   11.360604                0.109595          11.360604            1      False        104
# 75               LightGBMLarge_BAG_L1   0.959942     roc_auc       0.035129    3.480280                0.035129           3.480280            1      False         13
# 76        NeuralNetFastAI_r111_BAG_L1   0.959686     roc_auc       0.104122    9.526106                0.104122           9.526106            1      False         64
# 77            RandomForest_r34_BAG_L1   0.959661     roc_auc       0.083691    0.621352                0.083691           0.621352            1       True         60
# 78        NeuralNetFastAI_r191_BAG_L1   0.959355     roc_auc       0.097139    8.244980                0.097139           8.244980            1      False         17
# 79         NeuralNetTorch_r121_BAG_L1   0.959304     roc_auc       0.246510   11.844530                0.246510          11.844530            1      False         92
# 80        NeuralNetFastAI_r100_BAG_L1   0.958895     roc_auc       0.127333   14.095166                0.127333          14.095166            1      False        101
# 81           RandomForest_r166_BAG_L1   0.958601     roc_auc       0.084046    0.821483                0.084046           0.821483            1       True         76
# 82           NeuralNetTorch_r1_BAG_L1   0.958512     roc_auc       0.204466   11.336739                0.204466          11.336739            1      False        109
# 83         NeuralNetFastAI_r65_BAG_L1   0.958282     roc_auc       0.110544   10.915470                0.110544          10.915470            1      False         67
# 84        NeuralNetFastAI_r143_BAG_L1   0.958104     roc_auc       0.133682   11.260338                0.133682          11.260338            1      False         41
# 85            RandomForestGini_BAG_L1   0.957478     roc_auc       0.081901    0.765928                0.081901           0.765928            1       True          5
# 86             NeuralNetFastAI_BAG_L1   0.956955     roc_auc       0.093646    7.515187                0.093646           7.515187            1      False         10
# 87          NeuralNetTorch_r31_BAG_L1   0.955423     roc_auc       0.197721    9.293328                0.197721           9.293328            1      False         65
# 88               ExtraTrees_r4_BAG_L1   0.955372     roc_auc       0.086532    0.618907                0.086532           0.618907            1       True         66
# 89        NeuralNetFastAI_r127_BAG_L1   0.955014     roc_auc       0.118199    9.795943                0.118199           9.795943            1      False         93
# 90          NeuralNetTorch_r87_BAG_L1   0.954861     roc_auc       0.225696   12.085539                0.225696          12.085539            1      False         72
# 91        NeuralNetFastAI_r145_BAG_L1   0.954606     roc_auc       0.083025    8.033776                0.083025           8.033776            1      False         28
# 92              ExtraTreesGini_BAG_L1   0.953738     roc_auc       0.085404    0.538246                0.085404           0.538246            1       True          8
# 93              ExtraTrees_r49_BAG_L1   0.953738     roc_auc       0.086053    0.651364                0.086053           0.651364            1       True         56
# 94        NeuralNetFastAI_r194_BAG_L1   0.952895     roc_auc       0.087354    7.958936                0.087354           7.958936            1      False         95
# 95        NeuralNetFastAI_r134_BAG_L1   0.952614     roc_auc       0.152158   14.050031                0.152158          14.050031            1      False         59
# 96          NeuralNetTorch_r22_BAG_L1   0.952155     roc_auc       0.190411   10.751798                0.190411          10.751798            1      False         20
# 97        NeuralNetFastAI_r138_BAG_L1   0.951848     roc_auc       0.095810    8.684466                0.095810           8.684466            1      False         86
# 98             ExtraTrees_r126_BAG_L1   0.951414     roc_auc       0.091745    0.919505                0.091745           0.919505            1       True         99
# 99        NeuralNetFastAI_r160_BAG_L1   0.950393     roc_auc       0.077996    7.918858                0.077996           7.918858            1      False         79
# 100        NeuralNetFastAI_r69_BAG_L1   0.949576     roc_auc       0.089568    7.492697                0.089568           7.492697            1      False         84
# 101        NeuralNetFastAI_r88_BAG_L1   0.949066     roc_auc       0.106434   10.964294                0.106434          10.964294            1      False         68
# 102             ExtraTreesEntr_BAG_L1   0.948593     roc_auc       0.083147    0.524418                0.083147           0.524418            1       True          9
# 103        NeuralNetFastAI_r95_BAG_L1   0.947993     roc_auc       0.084690    8.085353                0.084690           8.085353            1      False         47
# 104         NeuralNetFastAI_r4_BAG_L1   0.945083     roc_auc       0.099707    7.672183                0.099707           7.672183            1      False         98
# 105        NeuralNetFastAI_r11_BAG_L1   0.943040     roc_auc       0.107251    8.584810                0.107251           8.584810            1      False         34
# 106       NeuralNetFastAI_r172_BAG_L1   0.938777     roc_auc       0.106025    9.190934                0.106025           9.190934            1      False         88
# 107             NeuralNetTorch_BAG_L1   0.936223     roc_auc       0.209253   12.200433                0.209253          12.200433            1      False         12
# 108       NeuralNetFastAI_r103_BAG_L1   0.926394     roc_auc       0.084845    7.318642                0.084845           7.318642            1      False         38
# 109             KNeighborsUnif_BAG_L1   0.474533     roc_auc       0.258127    0.008126                0.258127           0.008126            1       True          1
# 110             KNeighborsDist_BAG_L1   0.470295     roc_auc       0.006107    0.008511                0.006107           0.008511            1       True          2
# 111        KNeighborsDist_BAG_L1_FULL        NaN     roc_auc       0.006107    0.008511                0.006107           0.008511            1       True        113
# 112       ExtraTrees_r178_BAG_L1_FULL        NaN     roc_auc       0.081484    0.661036                0.081484           0.661036            1       True        186
# 113        ExtraTrees_r42_BAG_L1_FULL        NaN     roc_auc       0.081508    0.564880                0.081508           0.564880            1       True        133
# 114      RandomForestEntr_BAG_L1_FULL        NaN     roc_auc       0.081630    0.534338                0.081630           0.534338            1       True        117
# 115      RandomForestGini_BAG_L1_FULL        NaN     roc_auc       0.081901    0.765928                0.081901           0.765928            1       True        116
# 116       ExtraTrees_r172_BAG_L1_FULL        NaN     roc_auc       0.081944    0.529266                0.081944           0.529266            1       True        147
# 117      RandomForest_r15_BAG_L1_FULL        NaN     roc_auc       0.082425    0.774995                0.082425           0.774995            1       True        192
# 118      RandomForest_r16_BAG_L1_FULL        NaN     roc_auc       0.082886    1.253622                0.082886           1.253622            1       True        205
# 119     RandomForest_r127_BAG_L1_FULL        NaN     roc_auc       0.083135    0.877996                0.083135           0.877996            1       True        169
# 120        ExtraTreesEntr_BAG_L1_FULL        NaN     roc_auc       0.083147    0.524418                0.083147           0.524418            1       True        120
# 121      RandomForest_r34_BAG_L1_FULL        NaN     roc_auc       0.083691    0.621352                0.083691           0.621352            1       True        171
# 122      RandomForest_r39_BAG_L1_FULL        NaN     roc_auc       0.083741    0.658429                0.083741           0.658429            1       True        156
# 123     RandomForest_r166_BAG_L1_FULL        NaN     roc_auc       0.084046    0.821483                0.084046           0.821483            1       True        187
# 124     RandomForest_r195_BAG_L1_FULL        NaN     roc_auc       0.084313    0.775371                0.084313           0.775371            1       True        137
# 125        ExtraTreesGini_BAG_L1_FULL        NaN     roc_auc       0.085404    0.538246                0.085404           0.538246            1       True        119
# 126        ExtraTrees_r49_BAG_L1_FULL        NaN     roc_auc       0.086053    0.651364                0.086053           0.651364            1       True        167
# 127         ExtraTrees_r4_BAG_L1_FULL        NaN     roc_auc       0.086532    0.618907                0.086532           0.618907            1       True        177
# 128       ExtraTrees_r126_BAG_L1_FULL        NaN     roc_auc       0.091745    0.919505                0.091745           0.919505            1       True        210
# 129       ExtraTrees_r197_BAG_L1_FULL        NaN     roc_auc       0.093189    0.832770                0.093189           0.832770            1       True        202
# 130        KNeighborsUnif_BAG_L1_FULL        NaN     roc_auc       0.258127    0.008126                0.258127           0.008126            1       True        112
# 131           XGBoost_r98_BAG_L1_FULL        NaN     roc_auc            NaN    0.900071                     NaN           0.900071            1       True        160
# 132           XGBoost_r95_BAG_L1_FULL        NaN     roc_auc            NaN    0.149471                     NaN           0.149471            1       True        217
# 133           XGBoost_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.131676                     NaN           0.131676            1       True        140
# 134           XGBoost_r49_BAG_L1_FULL        NaN     roc_auc            NaN    0.262430                     NaN           0.262430            1       True        181
# 135           XGBoost_r34_BAG_L1_FULL        NaN     roc_auc            NaN    0.243097                     NaN           0.243097            1       True        218
# 136           XGBoost_r33_BAG_L1_FULL        NaN     roc_auc            NaN    0.512763                     NaN           0.512763            1       True        132
# 137           XGBoost_r31_BAG_L1_FULL        NaN     roc_auc            NaN    0.296820                     NaN           0.296820            1       True        188
# 138           XGBoost_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.109076                     NaN           0.109076            1       True        194
# 139          XGBoost_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.202727                     NaN           0.202727            1       True        146
# 140               XGBoost_BAG_L1_FULL        NaN     roc_auc            NaN    0.301910                     NaN           0.301910            1       True        122
# 141          WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN    1.877164                     NaN           0.048950            2       True        222
# 142    NeuralNetTorch_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.725775                     NaN           0.725775            1       True        221
# 143    NeuralNetTorch_r87_BAG_L1_FULL        NaN     roc_auc            NaN    0.595481                     NaN           0.595481            1       True        183
# 144    NeuralNetTorch_r86_BAG_L1_FULL        NaN     roc_auc            NaN    0.630063                     NaN           0.630063            1       True        143
# 145    NeuralNetTorch_r79_BAG_L1_FULL        NaN     roc_auc            NaN    0.660165                     NaN           0.660165            1       True        126
# 146    NeuralNetTorch_r76_BAG_L1_FULL        NaN     roc_auc            NaN    0.346795                     NaN           0.346795            1       True        201
# 147    NeuralNetTorch_r71_BAG_L1_FULL        NaN     roc_auc            NaN    0.183739                     NaN           0.183739            1       True        184
# 148    NeuralNetTorch_r41_BAG_L1_FULL        NaN     roc_auc            NaN    0.637159                     NaN           0.637159            1       True        159
# 149    NeuralNetTorch_r36_BAG_L1_FULL        NaN     roc_auc            NaN    0.376135                     NaN           0.376135            1       True        211
# 150    NeuralNetTorch_r31_BAG_L1_FULL        NaN     roc_auc            NaN    0.367618                     NaN           0.367618            1       True        176
# 151    NeuralNetTorch_r30_BAG_L1_FULL        NaN     roc_auc            NaN    0.976251                     NaN           0.976251            1       True        141
# 152    NeuralNetTorch_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.450532                     NaN           0.450532            1       True        131
# 153     NeuralNetTorch_r1_BAG_L1_FULL        NaN     roc_auc            NaN    0.812584                     NaN           0.812584            1       True        220
# 154    NeuralNetTorch_r19_BAG_L1_FULL        NaN     roc_auc            NaN    0.175642                     NaN           0.175642            1       True        216
# 155   NeuralNetTorch_r197_BAG_L1_FULL        NaN     roc_auc            NaN    0.125628                     NaN           0.125628            1       True        165
# 156   NeuralNetTorch_r185_BAG_L1_FULL        NaN     roc_auc            NaN    0.462797                     NaN           0.462797            1       True        189
# 157   NeuralNetTorch_r158_BAG_L1_FULL        NaN     roc_auc            NaN    0.451581                     NaN           0.451581            1       True        162
# 158    NeuralNetTorch_r14_BAG_L1_FULL        NaN     roc_auc            NaN    0.331990                     NaN           0.331990            1       True        150
# 159   NeuralNetTorch_r143_BAG_L1_FULL        NaN     roc_auc            NaN    0.716211                     NaN           0.716211            1       True        173
# 160   NeuralNetTorch_r135_BAG_L1_FULL        NaN     roc_auc            NaN    0.760409                     NaN           0.760409            1       True        208
# 161   NeuralNetTorch_r121_BAG_L1_FULL        NaN     roc_auc            NaN    0.610351                     NaN           0.610351            1       True        203
# 162        NeuralNetTorch_BAG_L1_FULL        NaN     roc_auc            NaN    2.277211                     NaN           2.277211            1       True        123
# 163   NeuralNetFastAI_r95_BAG_L1_FULL        NaN     roc_auc            NaN    0.298119                     NaN           0.298119            1       True        158
# 164   NeuralNetFastAI_r88_BAG_L1_FULL        NaN     roc_auc            NaN    0.661333                     NaN           0.661333            1       True        179
# 165   NeuralNetFastAI_r69_BAG_L1_FULL        NaN     roc_auc            NaN    0.296092                     NaN           0.296092            1       True        195
# 166   NeuralNetFastAI_r65_BAG_L1_FULL        NaN     roc_auc            NaN    1.743177                     NaN           1.743177            1       True        178
# 167    NeuralNetFastAI_r4_BAG_L1_FULL        NaN     roc_auc            NaN    0.200432                     NaN           0.200432            1       True        209
# 168   NeuralNetFastAI_r37_BAG_L1_FULL        NaN     roc_auc            NaN    1.455049                     NaN           1.455049            1       True        164
# 169  NeuralNetFastAI_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.407630                     NaN           0.407630            1       True        206
# 170  NeuralNetFastAI_r191_BAG_L1_FULL        NaN     roc_auc            NaN    0.272542                     NaN           0.272542            1       True        128
# 171  NeuralNetFastAI_r187_BAG_L1_FULL        NaN     roc_auc            NaN    1.111491                     NaN           1.111491            1       True        215
# 172  NeuralNetFastAI_r172_BAG_L1_FULL        NaN     roc_auc            NaN    0.262771                     NaN           0.262771            1       True        199
# 173  NeuralNetFastAI_r160_BAG_L1_FULL        NaN     roc_auc            NaN    0.271590                     NaN           0.271590            1       True        190
# 174  NeuralNetFastAI_r156_BAG_L1_FULL        NaN     roc_auc            NaN    0.887057                     NaN           0.887057            1       True        154
# 175  NeuralNetFastAI_r145_BAG_L1_FULL        NaN     roc_auc            NaN    0.544311                     NaN           0.544311            1       True        139
# 176  NeuralNetFastAI_r143_BAG_L1_FULL        NaN     roc_auc            NaN    1.593329                     NaN           1.593329            1       True        152
# 177  NeuralNetFastAI_r138_BAG_L1_FULL        NaN     roc_auc            NaN    0.479867                     NaN           0.479867            1       True        197
# 178  NeuralNetFastAI_r134_BAG_L1_FULL        NaN     roc_auc            NaN    0.827306                     NaN           0.827306            1       True        170
# 179  NeuralNetFastAI_r127_BAG_L1_FULL        NaN     roc_auc            NaN    0.857021                     NaN           0.857021            1       True        204
# 180   NeuralNetFastAI_r11_BAG_L1_FULL        NaN     roc_auc            NaN    0.211975                     NaN           0.211975            1       True        145
# 181  NeuralNetFastAI_r111_BAG_L1_FULL        NaN     roc_auc            NaN    1.074387                     NaN           1.074387            1       True        175
# 182  NeuralNetFastAI_r103_BAG_L1_FULL        NaN     roc_auc            NaN    0.175891                     NaN           0.175891            1       True        149
# 183  NeuralNetFastAI_r102_BAG_L1_FULL        NaN     roc_auc            NaN    1.006177                     NaN           1.006177            1       True        135
# 184  NeuralNetFastAI_r100_BAG_L1_FULL        NaN     roc_auc            NaN    1.173061                     NaN           1.173061            1       True        212
# 185       NeuralNetFastAI_BAG_L1_FULL        NaN     roc_auc            NaN    0.414650                     NaN           0.414650            1       True        121
# 186          LightGBM_r96_BAG_L1_FULL        NaN     roc_auc            NaN    0.321491                     NaN           0.321491            1       True        130
# 187          LightGBM_r94_BAG_L1_FULL        NaN     roc_auc            NaN    0.229785                     NaN           0.229785            1       True        172
# 188          LightGBM_r42_BAG_L1_FULL        NaN     roc_auc            NaN    0.196017                     NaN           0.196017            1       True        219
# 189          LightGBM_r30_BAG_L1_FULL        NaN     roc_auc            NaN    0.430337                     NaN           0.430337            1       True        180
# 190         LightGBM_r196_BAG_L1_FULL        NaN     roc_auc            NaN    0.930207                     NaN           0.930207            1       True        155
# 191         LightGBM_r188_BAG_L1_FULL        NaN     roc_auc            NaN    0.276019                     NaN           0.276019            1       True        138
# 192         LightGBM_r161_BAG_L1_FULL        NaN     roc_auc            NaN    0.395305                     NaN           0.395305            1       True        151
# 193          LightGBM_r15_BAG_L1_FULL        NaN     roc_auc            NaN    0.220845                     NaN           0.220845            1       True        161
# 194         LightGBM_r143_BAG_L1_FULL        NaN     roc_auc            NaN    0.257472                     NaN           0.257472            1       True        168
# 195         LightGBM_r135_BAG_L1_FULL        NaN     roc_auc            NaN    0.179080                     NaN           0.179080            1       True        193
# 196         LightGBM_r131_BAG_L1_FULL        NaN     roc_auc            NaN    0.320016                     NaN           0.320016            1       True        127
# 197         LightGBM_r130_BAG_L1_FULL        NaN     roc_auc            NaN    0.177429                     NaN           0.177429            1       True        142
# 198         LightGBM_r121_BAG_L1_FULL        NaN     roc_auc            NaN    0.359859                     NaN           0.359859            1       True        198
# 199              LightGBM_BAG_L1_FULL        NaN     roc_auc            NaN    0.138109                     NaN           0.138109            1       True        115
# 200            LightGBMXT_BAG_L1_FULL        NaN     roc_auc            NaN    0.475572                     NaN           0.475572            1       True        114
# 201         LightGBMLarge_BAG_L1_FULL        NaN     roc_auc            NaN    0.318019                     NaN           0.318019            1       True        124
# 202           CatBoost_r9_BAG_L1_FULL        NaN     roc_auc            NaN   11.484597                     NaN          11.484597            1       True        129
# 203          CatBoost_r86_BAG_L1_FULL        NaN     roc_auc            NaN    9.061475                     NaN           9.061475            1       True        163
# 204          CatBoost_r70_BAG_L1_FULL        NaN     roc_auc            NaN    4.766429                     NaN           4.766429            1       True        153
# 205           CatBoost_r6_BAG_L1_FULL        NaN     roc_auc            NaN    1.308176                     NaN           1.308176            1       True        196
# 206          CatBoost_r69_BAG_L1_FULL        NaN     roc_auc            NaN    3.312348                     NaN           3.312348            1       True        148
# 207          CatBoost_r60_BAG_L1_FULL        NaN     roc_auc            NaN    3.535100                     NaN           3.535100            1       True        191
# 208           CatBoost_r5_BAG_L1_FULL        NaN     roc_auc            NaN    0.261261                     NaN           0.261261            1       True        182
# 209          CatBoost_r50_BAG_L1_FULL        NaN     roc_auc            NaN    1.448429                     NaN           1.448429            1       True        144
# 210          CatBoost_r49_BAG_L1_FULL        NaN     roc_auc            NaN    0.367914                     NaN           0.367914            1       True        166
# 211         CatBoost_r198_BAG_L1_FULL        NaN     roc_auc            NaN    0.597210                     NaN           0.597210            1       True        214
# 212         CatBoost_r180_BAG_L1_FULL        NaN     roc_auc            NaN    1.544316                     NaN           1.544316            1       True        200
# 213         CatBoost_r177_BAG_L1_FULL        NaN     roc_auc            NaN    0.348409                     NaN           0.348409            1       True        125
# 214         CatBoost_r167_BAG_L1_FULL        NaN     roc_auc            NaN    3.106863                     NaN           3.106863            1       True        157
# 215         CatBoost_r163_BAG_L1_FULL        NaN     roc_auc            NaN    2.146242                     NaN           2.146242            1       True        213
# 216         CatBoost_r143_BAG_L1_FULL        NaN     roc_auc            NaN    0.600882                     NaN           0.600882            1       True        185
# 217          CatBoost_r13_BAG_L1_FULL        NaN     roc_auc            NaN   12.008144                     NaN          12.008144            1       True        136
# 218         CatBoost_r137_BAG_L1_FULL        NaN     roc_auc            NaN    4.798921                     NaN           4.798921            1       True        134
# 219          CatBoost_r12_BAG_L1_FULL        NaN     roc_auc            NaN    4.487797                     NaN           4.487797            1       True        207
# 220         CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN    2.396586                     NaN           2.396586            1       True        174
# 221              CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN    3.665610                     NaN           3.665610            1       True        118
# Number of models trained: 222
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             :  1 | ['demo-rangoEdad']
# ('float', [])                : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# ('int', [])                  : 47 | ['demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', 'clin-reservaCognitiva_escolaridad', ...]
# ('int', ['bool'])            : 10 | ['demo-genero', 'clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', ...]
# ('int', ['datetime_as_int']) :  9 | ['demo-fechaEvaluacion', 'demo-fechaEvaluacion.month', 'demo-fechaEvaluacion.day', 'demo-fechaEvaluacion.dayofweek', 'demo-fechaNacimiento', ...]
# *** End of fit() summary ***
# c:\Users\jgala\uned\tfm\synthetic-data\.conda\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r37_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r160_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetFastAI_r69_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r138_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r172_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r127_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'NeuralNetFastAI_r194_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r4_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r100_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r187_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r19_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r42_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r1_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r89_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'KNeighborsUnif_BAG_L1_FULL': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1_FULL': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1_FULL': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1_FULL': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1_FULL': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1_FULL': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1_FULL': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1_FULL': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1_FULL': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1_FULL': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1_FULL': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1_FULL': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1_FULL': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1_FULL': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1_FULL': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1_FULL': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1_FULL': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1_FULL': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1_FULL': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1_FULL': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1_FULL': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1_FULL': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1_FULL': 'StackerEnsembleModel_NNFastAiTabular',
# ...
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L1_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2_FULL': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L2   0.982945     roc_auc       0.554326
#  1          LightGBM_r42_BAG_L1   0.981311     roc_auc       0.027292
#  2            LightGBMXT_BAG_L1   0.980622     roc_auc       0.034270
#  3          CatBoost_r50_BAG_L1   0.977686     roc_auc       0.059578
#  4          LightGBM_r30_BAG_L1   0.977558     roc_auc       0.059601
#  ..                         ...        ...         ...            ...
#  217   CatBoost_r13_BAG_L1_FULL        NaN     roc_auc            NaN
#  218  CatBoost_r137_BAG_L1_FULL        NaN     roc_auc            NaN
#  219   CatBoost_r12_BAG_L1_FULL        NaN     roc_auc            NaN
#  220  CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN
#  221       CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    27.472278                0.001003           0.048950            2
#  1     2.578658                0.027292           2.578658            1
#  2     1.253230                0.034270           1.253230            1
#  3    16.662794                0.059578          16.662794            1
#  4     5.274924                0.059601           5.274924            1
#  ..         ...                     ...                ...          ...
#  217  12.008144                     NaN          12.008144            1
#  218   4.798921                     NaN           4.798921            1
#  219   4.487797                     NaN           4.487797            1
#  220   2.396586                     NaN           2.396586            1
#  221   3.665610                     NaN           3.665610            1
#
#       can_infer  fit_order
#  0        False        111
#  1        False        108
#  2        False          3
#  3        False         33
#  4        False         69
#  ..         ...        ...
#  217       True        136
#  218       True        134
#  219       True        207
#  220       True        174
#  221       True        118
#
#  [222 rows x 10 columns]}

# %%
auxiliary_metrics = ['accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9894480519480519
# Evaluations on test data:
# {
#     "roc_auc": 0.9894480519480519,
#     "accuracy": 0.93,
#     "balanced_accuracy": 0.9326298701298701,
#     "mcc": 0.8605576800937125,
#     "f1": 0.9357798165137615,
#     "precision": 0.9622641509433962,
#     "recall": 0.9107142857142857
# }
# {'roc_auc': 0.9894480519480519,
#  'accuracy': 0.93,
#  'balanced_accuracy': 0.9326298701298701,
#  'mcc': 0.8605576800937125,
#  'f1': 0.9357798165137615,
#  'precision': 0.9622641509433962,
#  'recall': 0.9107142857142857}

# %%
predictor.model_best
# Out:
# 'WeightedEnsemble_L2_FULL'

# %%
predictors = predictor.leaderboard(
    df_test,
    extra_metrics = auxiliary_metrics,
    extra_info=True,
    silent=True
)

# %%
predictors[['model', 'roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall', 'num_features']]
# Out:
#                            model   roc_auc  accuracy  balanced_accuracy  \
# 0      LightGBM_r135_BAG_L1_FULL  0.994724      0.95           0.952922
# 1      LightGBM_r130_BAG_L1_FULL  0.993912      0.93           0.935065
# 2       CatBoost_r13_BAG_L1_FULL  0.993912      0.94           0.941558
# 3      LightGBM_r161_BAG_L1_FULL  0.993506      0.96           0.959416
# 4      LightGBM_r121_BAG_L1_FULL  0.993506      0.96           0.961851
# ..                           ...       ...       ...                ...
# 217    NeuralNetFastAI_r4_BAG_L1       NaN       NaN                NaN
# 218   NeuralNetFastAI_r11_BAG_L1       NaN       NaN                NaN
# 219  NeuralNetFastAI_r172_BAG_L1       NaN       NaN                NaN
# 220        NeuralNetTorch_BAG_L1       NaN       NaN                NaN
# 221  NeuralNetFastAI_r103_BAG_L1       NaN       NaN                NaN
#
#            f1  precision    recall  num_features
# 0    0.954128   0.981132  0.928571            82
# 1    0.934579   0.980392  0.892857            82
# 2    0.945455   0.962963  0.928571            82
# 3    0.964286   0.964286  0.964286            82
# 4    0.963636   0.981481  0.946429            82
# ..        ...        ...       ...           ...
# 217       NaN        NaN       NaN            82
# 218       NaN        NaN       NaN            82
# 219       NaN        NaN       NaN            82
# 220       NaN        NaN       NaN            82
# 221       NaN        NaN       NaN            82
#
# [222 rows x 8 columns]

# %%
predictors.to_excel(
    '../../data/tlp/predictors-gc.xlsx',
    index=False
)

# %%
predictor.feature_importance(data=df_train)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['clin-Covid_sintomaSarpullido']
# Computing feature importance via permutation shuffling for 75 features using 396 rows with 5 shuffle sets...
# 	28.72s	= Expected runtime (5.74s per shuffle set)
# 	2.62s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                              importance   stddev   p_value  n  \
# eval-TLP-Stroop-color-PD                       0.000133  0.00015  0.059817  5
# eval-TLP-Tavec-15_ESem_RL_LP-PD                0.000000  0.00000  0.500000  5
# eval-TLP-Tavec-13_ESem_RI_B-PD                 0.000000  0.00000  0.500000  5
# eval-TLP-Tavec-12_ESem_RI_A-PD                 0.000000  0.00000  0.500000  5
# eval-TLP-Tavec-11_RCl_LP-PD                    0.000000  0.00000  0.500000  5
# ...                                                 ...      ...       ... ..
# ques-Sus-total-PD                              0.000000  0.00000  0.500000  5
# ques-Sus-totalImpar-PD                         0.000000  0.00000  0.500000  5
# ques-Sus-totalPar-PD                           0.000000  0.00000  0.500000  5
# ques-NavEspacial-resultadosWFQ_DE-PD           0.000000  0.00000  0.500000  5
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD    0.000000  0.00000  0.500000  5
#
#                                              p99_high   p99_low
# eval-TLP-Stroop-color-PD                     0.000442 -0.000177
# eval-TLP-Tavec-15_ESem_RL_LP-PD              0.000000  0.000000
# eval-TLP-Tavec-13_ESem_RI_B-PD               0.000000  0.000000
# eval-TLP-Tavec-12_ESem_RI_A-PD               0.000000  0.000000
# eval-TLP-Tavec-11_RCl_LP-PD                  0.000000  0.000000
# ...                                               ...       ...
# ques-Sus-total-PD                            0.000000  0.000000
# ques-Sus-totalImpar-PD                       0.000000  0.000000
# ques-Sus-totalPar-PD                         0.000000  0.000000
# ques-NavEspacial-resultadosWFQ_DE-PD         0.000000  0.000000
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.000000  0.000000
#
# [75 rows x 6 columns]
