# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-gc.csv')

# %%
drop_columns = [
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]
pz_columns = [column for column in df.columns if 'PZ' in column ]
pdc_columns = [column for column in df.columns if 'PDC' in column]
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD  TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                             33.333333
# 1                           12.500000                              0.000000
# 2                           75.000000                             25.000000
# 3                           16.666667                              0.000000
# 4                           66.666667                              0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD  TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                           -33.333333
# 1                            0.000000                             0.000000
# 2                          -20.000000                             0.000000
# 3                           50.000000                           -20.000000
# 4                          -33.333333                             0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 68 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((376, 68), (94, 68))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/gc/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       6.36 GB / 15.94 GB (39.9%)
# Disk Space Avail:   130.93 GB / 446.36 GB (29.3%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 13:01:11,356	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8267
# 		Context path: "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=7276) Running DyStack sub-fit ...
# (_dystack pid=7276) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=7276) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=7276) AutoGluon will save models to "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=7276) Train Data Rows:    334
# (_dystack pid=7276) Train Data Columns: 67
# (_dystack pid=7276) Label Column:       ED_2Clases
# (_dystack pid=7276) Problem Type:       binary
# (_dystack pid=7276) Preprocessing data ...
# (_dystack pid=7276) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=7276) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=7276) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=7276) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=7276) Using Feature Generators to preprocess the data ...
# (_dystack pid=7276) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=7276) 	Available Memory:                    5857.82 MB
# (_dystack pid=7276) 	Train Data (Original)  Memory Usage: 0.17 MB (0.0% of available memory)
# (_dystack pid=7276) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=7276) 	Stage 1 Generators:
# (_dystack pid=7276) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=7276) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=7276) 	Stage 2 Generators:
# (_dystack pid=7276) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=7276) 	Stage 3 Generators:
# (_dystack pid=7276) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=7276) 	Stage 4 Generators:
# (_dystack pid=7276) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=7276) 	Stage 5 Generators:
# (_dystack pid=7276) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=7276) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=7276) 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=7276) 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=7276) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=7276) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=7276) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=7276) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=7276) 	0.1s = Fit runtime
# (_dystack pid=7276) 	67 features in original data used to generate 67 features in processed data.
# (_dystack pid=7276) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=7276) Data preprocessing and feature engineering runtime = 0.13s ...
# (_dystack pid=7276) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=7276) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=7276) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=7276) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=7276) User-specified model hyperparameters to be fit:
# (_dystack pid=7276) {
# (_dystack pid=7276) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=7276) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=7276) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=7276) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=7276) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=7276) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=7276) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=7276) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=7276) }
# (_dystack pid=7276) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=7276) Fitting 110 L1 models ...
# (_dystack pid=7276) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.23s of the 891.55s of remaining time.
# (_dystack pid=7276) 	0.6882	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	0.01s	 = Training   runtime
# (_dystack pid=7276) 	0.24s	 = Validation runtime
# (_dystack pid=7276) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 590.39s of the 887.71s of remaining time.
# (_dystack pid=7276) 	0.7035	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	0.01s	 = Training   runtime
# (_dystack pid=7276) 	0.01s	 = Validation runtime
# (_dystack pid=7276) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 590.34s of the 887.67s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# (_dystack pid=7276) 	0.9776	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	1.29s	 = Training   runtime
# (_dystack pid=7276) 	0.01s	 = Validation runtime
# (_dystack pid=7276) Fitting model: LightGBM_BAG_L1 ... Training model for up to 584.36s of the 881.69s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# (_dystack pid=7276) 	0.9817	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	1.18s	 = Training   runtime
# (_dystack pid=7276) 	0.03s	 = Validation runtime
# (_dystack pid=7276) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 579.07s of the 876.4s of remaining time.
# (_dystack pid=7276) 	0.9533	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	0.85s	 = Training   runtime
# (_dystack pid=7276) 	0.11s	 = Validation runtime
# (_dystack pid=7276) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 578.07s of the 875.39s of remaining time.
# (_dystack pid=7276) 	0.9598	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	0.55s	 = Training   runtime
# (_dystack pid=7276) 	0.08s	 = Validation runtime
# (_dystack pid=7276) Fitting model: CatBoost_BAG_L1 ... Training model for up to 577.4s of the 874.73s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=7276) 	0.9774	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	10.59s	 = Training   runtime
# (_dystack pid=7276) 	0.08s	 = Validation runtime
# (_dystack pid=7276) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 563.0s of the 860.33s of remaining time.
# (_dystack pid=7276) 	0.9461	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	0.94s	 = Training   runtime
# (_dystack pid=7276) 	0.15s	 = Validation runtime
# (_dystack pid=7276) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 561.85s of the 859.18s of remaining time.
# (_dystack pid=7276) 	0.9415	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	1.21s	 = Training   runtime
# (_dystack pid=7276) 	0.16s	 = Validation runtime
# (_dystack pid=7276) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 560.42s of the 857.74s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=7276) 	0.9597	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	9.98s	 = Training   runtime
# (_dystack pid=7276) 	0.14s	 = Validation runtime
# (_dystack pid=7276) Fitting model: XGBoost_BAG_L1 ... Training model for up to 541.53s of the 838.85s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.70%)
# (_dystack pid=7276) 	0.975	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	4.64s	 = Training   runtime
# (_dystack pid=7276) 	0.04s	 = Validation runtime
# (_dystack pid=7276) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 529.66s of the 826.98s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=440) Stack (most recent call first):
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=440)
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=29424) Stack (most recent call first):
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 10x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=29424)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=29424)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 8x across cluster]
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 9x across cluster]
# (_ray_fit pid=12216) Stack (most recent call first):
# (_ray_fit pid=12216)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=12216)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=12216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=29424)   File "<frozen importlib._bootstrap_external>", line 883 in
# (_ray_fit pid=29324)   File
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=440)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=440)  [repeated 2x across cluster]
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 10x across cluster]
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 7x across cluster]
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 2x across cluster]
# (_ray_fit pid=29424)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 17x across cluster]
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 7x across cluster]
# (_ray_fit pid=440)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 8x across cluster]
# (_ray_fit pid=30272) Stack (most recent call first): [repeated 5x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 5x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 4x across cluster]
# (_ray_fit pid=32972)   File "<frozen importlib._bootstrap>", line 674
# (_ray_fit pid=12216) , line 674 in _load_unlocked
# (_ray_fit pid=31692) 674 in _load_unlocked
# (_ray_fit pid=29424) exec_module
# (_ray_fit pid=29324) "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=30272) ", line 674 in _load_unlocked
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=12216)   File "
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 1006 in
# (_ray_fit pid=24868)   File "<frozen importlib._bootstrap>", line 992
# (_ray_fit pid=12216) <frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=12216)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=31692) _find_and_load_unlocked
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap_external>", line 883
# (_ray_fit pid=32972)   File "<frozen importlib._bootstrap_external>"
# (_ray_fit pid=24868)  in _find_and_load_unlocked
# (_ray_fit pid=24868)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=29324)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in
# (_ray_fit pid=30272) _load_unlocked
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=31692)  in exec_module
# (_ray_fit pid=32972) , line 883
# (_ray_fit pid=29324) <module>
# (_ray_fit pid=31692) , line 1006 in _find_and_load_unlocked
# (_ray_fit pid=24868) <frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=7276) 	0.9409	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	33.5s	 = Training   runtime
# (_dystack pid=7276) 	0.24s	 = Validation runtime
# (_dystack pid=7276) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 486.25s of the 783.57s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.01%)
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 7x across cluster]
# (_ray_fit pid=29324)  [repeated 7x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 62x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 47x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 13x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 67x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 47x across cluster]
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 59x across cluster]
# (_ray_fit pid=24868)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=30272) 688 in _load_unlocked [repeated 2x across cluster]
# (_ray_fit pid=24868) ", line 688 in _load_unlocked
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 5x across cluster]
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 5x across cluster]
# (_ray_fit pid=29324)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 5x across cluster]
# (_ray_fit pid=24868)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 4x across cluster]
# (_ray_fit pid=29324)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 5x across cluster]
# (_ray_fit pid=29324)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 5x across cluster]
# (_ray_fit pid=24868)   File "
# (_ray_fit pid=30272)   File "<frozen importlib._bootstrap>", line 688 in
# (_ray_fit pid=30272)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 5x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=32972)  in exec_module
# (_ray_fit pid=30272) , line
# (_dystack pid=7276) 	0.9759	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	4.08s	 = Training   runtime
# (_dystack pid=7276) 	0.02s	 = Validation runtime
# (_dystack pid=7276) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 476.5s of the 773.83s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# (_dystack pid=7276) 	0.9781	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	10.06s	 = Training   runtime
# (_dystack pid=7276) 	0.07s	 = Validation runtime
# (_dystack pid=7276) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 457.18s of the 754.5s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=5500) Stack (most recent call first):
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=5500)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=5500)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=17080)   File "
# (_ray_fit pid=17080) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22
# (_ray_fit pid=17080)  in inner
# (_ray_fit pid=17080)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py"
# (_ray_fit pid=17080) , line 284
# (_ray_fit pid=17080)  in __init__
# (_ray_fit pid=17080)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py"
# (_ray_fit pid=17080) , line 45
# (_ray_fit pid=17080)  in __init__
# (_ray_fit pid=17080)
# (_ray_fit pid=17080)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py"
# (_ray_fit pid=17080) , line 561
# (_ray_fit pid=17080)  in _init_optimizer
# (_ray_fit pid=17080)
# (_ray_fit pid=17080)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line
# (_ray_fit pid=17080) 196 in
# (_ray_fit pid=17080) _fit
# (_ray_fit pid=17080)   File
# (_ray_fit pid=17080) "
# (_ray_fit pid=17080) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py"
# (_ray_fit pid=17080) , line 856 in fit
# (_ray_fit pid=17080)   File "
# (_ray_fit pid=17080) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py"
# (_ray_fit pid=17080) , line
# (_ray_fit pid=17080) 402 in
# (_ray_fit pid=17080) _ray_fit
# (_ray_fit pid=17080)
# (_ray_fit pid=17080)   File
# (_ray_fit pid=17080) "
# (_ray_fit pid=17080) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py"
# (_ray_fit pid=17080) , line
# (_ray_fit pid=17080) 879 in main_loop
# (_ray_fit pid=17080)   File "
# (_ray_fit pid=17080) c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py"
# (_ray_fit pid=17080) , line
# (_ray_fit pid=17080) 282 in
# (_ray_fit pid=17080) <module>
# (_ray_fit pid=17080)
# (_dystack pid=7276) 	0.9698	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	37.43s	 = Training   runtime
# (_dystack pid=7276) 	0.31s	 = Validation runtime
# (_dystack pid=7276) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 408.83s of the 706.16s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_ray_fit pid=8968) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 7x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 6x across cluster]
# (_ray_fit pid=8968)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 6x across cluster]
# (_ray_fit pid=14044) [1000]	valid_set's binary_logloss: 0.16984
# (_dystack pid=7276) 	0.98	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	10.61s	 = Training   runtime
# (_dystack pid=7276) 	0.08s	 = Validation runtime
# (_dystack pid=7276) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 384.91s of the 682.23s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_dystack pid=7276) 	0.9643	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	27.27s	 = Training   runtime
# (_dystack pid=7276) 	0.24s	 = Validation runtime
# (_dystack pid=7276) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 331.45s of the 628.77s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.35%)
# (_dystack pid=7276) 	0.976	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	75.67s	 = Training   runtime
# (_dystack pid=7276) 	0.09s	 = Validation runtime
# (_dystack pid=7276) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 245.2s of the 542.52s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_ray_fit pid=22472) [3000]	valid_set's binary_logloss: 0.184926 [repeated 3x across cluster]
# (_dystack pid=7276) 	0.9776	 = Validation score   (roc_auc)
# (_dystack pid=7276) 	12.72s	 = Training   runtime
# (_dystack pid=7276) 	0.11s	 = Validation runtime
# (_dystack pid=7276) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 221.51s of the 518.83s of remaining time.
# (_dystack pid=7276) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=30920) Stack (most recent call first):
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=30920)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=30920)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=30920)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=30920)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=30920)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# ...
# 	0.9697	 = Validation score   (roc_auc)
# 	1.61s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 769.1s of the 1632.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.9739	 = Validation score   (roc_auc)
# 	13.62s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 752.23s of the 1615.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9577	 = Validation score   (roc_auc)
# 	13.52s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 731.34s of the 1594.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.9685	 = Validation score   (roc_auc)
# 	5.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 718.04s of the 1581.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9651	 = Validation score   (roc_auc)
# 	45.2s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 664.26s of the 1527.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.9726	 = Validation score   (roc_auc)
# 	2.41s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 651.86s of the 1515.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9439	 = Validation score   (roc_auc)
# 	40.5s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 603.91s of the 1467.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.9747	 = Validation score   (roc_auc)
# 	15.59s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 581.43s of the 1444.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9364	 = Validation score   (roc_auc)
# 	19.12s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 554.38s of the 1417.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.9677	 = Validation score   (roc_auc)
# 	12.83s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 535.79s of the 1398.94s of remaining time.
# 	0.9591	 = Validation score   (roc_auc)
# 	1.29s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 534.25s of the 1397.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.9729	 = Validation score   (roc_auc)
# 	8.83s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 516.95s of the 1380.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9344	 = Validation score   (roc_auc)
# 	12.62s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 492.55s of the 1355.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9597	 = Validation score   (roc_auc)
# 	59.57s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 423.69s of the 1286.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.63%)
# 	0.9716	 = Validation score   (roc_auc)
# 	12.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 401.33s of the 1264.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9728	 = Validation score   (roc_auc)
# 	28.99s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 364.37s of the 1227.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.9756	 = Validation score   (roc_auc)
# 	34.26s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 321.7s of the 1184.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9683	 = Validation score   (roc_auc)
# 	31.11s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 275.85s of the 1139.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.9678	 = Validation score   (roc_auc)
# 	13.97s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 252.62s of the 1115.77s of remaining time.
# 	0.9693	 = Validation score   (roc_auc)
# 	1.7s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 250.68s of the 1113.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.9735	 = Validation score   (roc_auc)
# 	21.16s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 215.17s of the 1078.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.9551	 = Validation score   (roc_auc)
# 	18.13s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 191.75s of the 1054.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9594	 = Validation score   (roc_auc)
# 	57.65s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 124.58s of the 987.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.59%)
# 	0.9683	 = Validation score   (roc_auc)
# 	19.41s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 91.35s of the 954.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.9704	 = Validation score   (roc_auc)
# 	10.91s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 68.2s of the 931.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9615	 = Validation score   (roc_auc)
# 	64.67s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 861.37s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.211, 'NeuralNetFastAI_r102_BAG_L1': 0.158, 'NeuralNetFastAI_r143_BAG_L1': 0.158, 'CatBoost_BAG_L1': 0.105, 'NeuralNetTorch_r79_BAG_L1': 0.105, 'NeuralNetTorch_r22_BAG_L1': 0.105, 'CatBoost_r9_BAG_L1': 0.053, 'NeuralNetFastAI_r156_BAG_L1': 0.053, 'NeuralNetTorch_r158_BAG_L1': 0.053}
# 	0.9868	 = Validation score   (roc_auc)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 861.07s of the 860.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.9839	 = Validation score   (roc_auc)
# 	7.42s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 842.25s of the 841.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.9776	 = Validation score   (roc_auc)
# 	10.9s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 822.59s of the 822.21s of remaining time.
# 	0.9753	 = Validation score   (roc_auc)
# 	1.61s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 820.69s of the 820.31s of remaining time.
# 	0.9791	 = Validation score   (roc_auc)
# 	1.74s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 818.67s of the 818.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	0.9798	 = Validation score   (roc_auc)
# 	91.28s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 711.28s of the 710.9s of remaining time.
# 	0.9786	 = Validation score   (roc_auc)
# 	1.06s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 709.96s of the 709.59s of remaining time.
# 	0.9794	 = Validation score   (roc_auc)
# 	0.96s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 708.74s of the 708.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9778	 = Validation score   (roc_auc)
# 	20.91s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 676.5s of the 676.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.9753	 = Validation score   (roc_auc)
# 	5.81s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 661.7s of the 661.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9463	 = Validation score   (roc_auc)
# 	60.14s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 585.15s of the 584.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.35%)
# 	0.9708	 = Validation score   (roc_auc)
# 	14.77s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 549.36s of the 548.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.9799	 = Validation score   (roc_auc)
# 	51.51s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 487.13s of the 486.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9651	 = Validation score   (roc_auc)
# 	68.38s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 411.01s of the 410.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.9775	 = Validation score   (roc_auc)
# 	15.19s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 369.23s of the 368.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9791	 = Validation score   (roc_auc)
# 	17.83s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 327.64s of the 327.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.27%)
# 	0.9782	 = Validation score   (roc_auc)
# 	128.26s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 187.86s of the 187.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.9837	 = Validation score   (roc_auc)
# 	19.25s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 145.32s of the 144.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.97	 = Validation score   (roc_auc)
# 	35.74s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 95.1s of the 94.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=5.05%)
# 	0.9751	 = Validation score   (roc_auc)
# 	26.22s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 58.62s of the 58.25s of remaining time.
# 	0.9769	 = Validation score   (roc_auc)
# 	2.24s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 56.07s of the 55.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9822	 = Validation score   (roc_auc)
# 	36.79s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -8.54s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.4, 'LightGBM_r96_BAG_L2': 0.3, 'NeuralNetFastAI_r143_BAG_L1': 0.15, 'NeuralNetTorch_r22_BAG_L2': 0.1, 'CatBoost_r137_BAG_L2': 0.05}
# 	0.9849	 = Validation score   (roc_auc)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2597.72s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 29.1 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/gc/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L2   0.986815     roc_auc       1.612785   398.906407                0.000000           0.256816            2       True         51
# 1           WeightedEnsemble_L3   0.984919     roc_auc       9.186918  1311.907180                0.000826           0.241399            3       True         73
# 2             LightGBMXT_BAG_L2   0.983929     roc_auc       8.641962  1219.883083                0.032906           7.419566            2       True         52
# 3           LightGBM_r96_BAG_L2   0.983731     roc_auc       8.701528  1231.718372                0.092472          19.254854            2       True         68
# 4          CatBoost_r137_BAG_L2   0.982231     roc_auc       8.692556  1249.251539                0.083499          36.788021            2       True         72
# 5          CatBoost_r177_BAG_L2   0.979911     roc_auc       8.701964  1263.974263                0.092908          51.510746            2       True         63
# 6               CatBoost_BAG_L2   0.979798     roc_auc       8.737160  1303.747763                0.128104          91.284246            2       True         56
# 7         ExtraTreesEntr_BAG_L2   0.979430     roc_auc       8.783013  1213.426184                0.173956           0.962666            2       True         58
# 8   NeuralNetFastAI_r191_BAG_L2   0.979147     roc_auc       8.729854  1230.293208                0.120798          17.829690            2       True         66
# 9       RandomForestEntr_BAG_L2   0.979076     roc_auc       8.807888  1214.198861                0.198832           1.735343            2       True         55
# 10        ExtraTreesGini_BAG_L2   0.978553     roc_auc       8.783634  1213.519457                0.174578           1.055939            2       True         57
# 11           CatBoost_r9_BAG_L2   0.978185     roc_auc       8.697517  1340.722944                0.088461         128.259426            2       True         67
# 12       NeuralNetFastAI_BAG_L2   0.977789     roc_auc       8.737090  1233.375355                0.128034          20.911838            2       True         59
# 13              LightGBM_BAG_L2   0.977619     roc_auc       8.640033  1223.364323                0.030977          10.900805            2       True         53
# 14         LightGBM_r131_BAG_L2   0.977506     roc_auc       8.643751  1227.653536                0.034695          15.190018            2       True         65
# 15              CatBoost_BAG_L1   0.977082     roc_auc       0.069608    15.974716                0.069608          15.974716            1       True          7
# 16        ExtraTrees_r42_BAG_L2   0.976870     roc_auc       8.797624  1214.707203                0.188567           2.243685            2       True         71
# 17          CatBoost_r70_BAG_L1   0.975639     roc_auc       0.067559    34.261559                0.067559          34.261559            1       True         41
# 18      RandomForestGini_BAG_L2   0.975313     roc_auc       8.813923  1214.070758                0.204867           1.607240            2       True         54
# 19               XGBoost_BAG_L2   0.975285     roc_auc       8.649969  1218.278262                0.040913           5.814745            2       True         60
# 20           XGBoost_r33_BAG_L2   0.975087     roc_auc       8.707078  1238.686787                0.098022          26.223269            2       True         70
# 21           CatBoost_r9_BAG_L1   0.974875     roc_auc       0.075447   103.433060                0.075447         103.433060            1       True         17
# 22          CatBoost_r50_BAG_L1   0.974677     roc_auc       0.090106    15.588584                0.090106          15.588584            1       True         32
# 23         CatBoost_r137_BAG_L1   0.974394     roc_auc       0.074189    21.814415                0.074189          21.814415            1       True         22
# 24         CatBoost_r177_BAG_L1   0.974167     roc_auc       0.066773    22.275766                0.066773          22.275766            1       True         14
# 25         LightGBM_r188_BAG_L1   0.973856     roc_auc       0.027897    13.623425                0.027897          13.623425            1       True         26
# 26          LightGBM_r96_BAG_L1   0.973715     roc_auc       0.071599    16.058937                0.071599          16.058937            1       True         18
# 27            LightGBMXT_BAG_L1   0.973545     roc_auc       0.028860     3.337215                0.028860           3.337215            1       True          3
# 28         CatBoost_r167_BAG_L1   0.973545     roc_auc       0.064826    21.164403                0.064826          21.164403            1       True         45
# 29          CatBoost_r69_BAG_L1   0.972923     roc_auc       0.168880     8.832170                0.168880           8.832170            1       True         36
# 30  NeuralNetFastAI_r143_BAG_L1   0.972838     roc_auc       0.177309    28.987737                0.177309          28.987737            1       True         40
# 31              LightGBM_BAG_L1   0.972838     roc_auc       0.019608     5.065003                0.019608           5.065003            1       True          4
# 32         LightGBM_r130_BAG_L1   0.972611     roc_auc       0.025167     2.406623                0.025167           2.406623            1       True         30
# 33          CatBoost_r13_BAG_L1   0.971706     roc_auc       0.065946   171.340328                0.065946         171.340328            1       True         24
# 34         LightGBM_r161_BAG_L1   0.971649     roc_auc       0.038040    12.760269                0.038040          12.760269            1       True         39
# 35         LightGBMLarge_BAG_L2   0.970800     roc_auc       8.647174  1227.235845                0.038117          14.772327            2       True         62
# 36          LightGBM_r15_BAG_L1   0.970404     roc_auc       0.019505    10.909498                0.019505          10.909498            1       True         49
# 37    NeuralNetTorch_r22_BAG_L2   0.970036     roc_auc       8.977215  1248.203340                0.368159          35.739822            2       True         69
# 38     RandomForest_r195_BAG_L1   0.969739     roc_auc       0.086899     1.612212                0.086899           1.612212            1       True         25
# 39      RandomForest_r39_BAG_L1   0.969301     roc_auc       0.153579     1.703662                0.153579           1.703662            1       True         44
# 40         LightGBMLarge_BAG_L1   0.969018     roc_auc       0.023169     8.370451                0.023169           8.370451            1       True         13
# 41    NeuralNetTorch_r79_BAG_L1   0.968707     roc_auc       0.296306    46.143189                0.296306          46.143189            1       True         15
# 42           XGBoost_r89_BAG_L1   0.968480     roc_auc       0.033821     5.098328                0.033821           5.098328            1       True         28
# 43           XGBoost_r98_BAG_L1   0.968311     roc_auc       0.132021    19.413429                0.132021          19.413429            1       True         48
# 44  NeuralNetFastAI_r156_BAG_L1   0.968282     roc_auc       0.185993    31.108752                0.185993          31.108752            1       True         42
# 45         LightGBM_r196_BAG_L1   0.967801     roc_auc       0.128469    13.970286                0.128469          13.970286            1       True         43
# 46          XGBoost_r194_BAG_L1   0.967745     roc_auc       0.133564    12.833863                0.133564          12.833863            1       True         34
# 47           XGBoost_r33_BAG_L1   0.967518     roc_auc       0.047349     7.432546                0.047349           7.432546            1       True         20
# 48  NeuralNetFastAI_r102_BAG_L1   0.967150     roc_auc       0.203882    21.864320                0.203882          21.864320            1       True         23
# 49               XGBoost_BAG_L1   0.965297     roc_auc       0.035303     4.005185                0.035303           4.005185            1       True         11
# 50    NeuralNetTorch_r79_BAG_L2   0.965142     roc_auc       8.912258  1280.844348                0.303202          68.380831            2       True         64
# 51    NeuralNetTorch_r30_BAG_L1   0.965113     roc_auc       0.279577    45.202000                0.279577          45.202000            1       True         29
# 52   NeuralNetTorch_r158_BAG_L1   0.961492     roc_auc       0.293467    64.668137                0.293467          64.668137            1       True         50
# 53      RandomForestEntr_BAG_L1   0.961265     roc_auc       0.164367     0.997953                0.164367           0.997953            1       True          6
# 54    NeuralNetTorch_r22_BAG_L1   0.961011     roc_auc       0.291164    81.404675                0.291164          81.404675            1       True         19
# 55    NeuralNetTorch_r14_BAG_L1   0.959737     roc_auc       0.283241    59.566779                0.283241          59.566779            1       True         38
# 56    NeuralNetTorch_r41_BAG_L1   0.959398     roc_auc       0.270302    57.650502                0.270302          57.650502            1       True         47
# 57       ExtraTrees_r172_BAG_L1   0.959087     roc_auc       0.182902     1.288292                0.182902           1.288292            1       True         35
# 58  NeuralNetFastAI_r191_BAG_L1   0.958294     roc_auc       0.123699    36.101866                0.123699          36.101866            1       True         16
# 59  NeuralNetFastAI_r145_BAG_L1   0.957729     roc_auc       0.124553    13.521187                0.124553          13.521187            1       True         27
# 60        ExtraTrees_r42_BAG_L1   0.956950     roc_auc       0.153361     1.123441                0.153361           1.123441            1       True         21
# 61   NeuralNetFastAI_r95_BAG_L1   0.955097     roc_auc       0.128828    18.134835                0.128828          18.134835            1       True         46
# 62       NeuralNetFastAI_BAG_L1   0.953598     roc_auc       0.123538    14.999296                0.123538          14.999296            1       True         10
# 63      RandomForestGini_BAG_L1   0.952310     roc_auc       0.170692     1.024500                0.170692           1.024500            1       True          5
# 64        NeuralNetTorch_BAG_L1   0.951334     roc_auc       0.294409    61.099256                0.294409          61.099256            1       True         12
# 65        NeuralNetTorch_BAG_L2   0.946269     roc_auc       8.911470  1272.607828                0.302414          60.144310            2       True         61
# 66        ExtraTreesEntr_BAG_L1   0.945788     roc_auc       0.170166     0.975977                0.170166           0.975977            1       True          9
# 67    NeuralNetTorch_r86_BAG_L1   0.943921     roc_auc       0.429775    40.495269                0.429775          40.495269            1       True         31
# 68        ExtraTreesGini_BAG_L1   0.943327     roc_auc       0.161425     1.054440                0.161425           1.054440            1       True          8
# 69   NeuralNetFastAI_r11_BAG_L1   0.936395     roc_auc       0.128396    19.119739                0.128396          19.119739            1       True         33
# 70  NeuralNetFastAI_r103_BAG_L1   0.934414     roc_auc       0.117511    12.619819                0.117511          12.619819            1       True         37
# 71        KNeighborsDist_BAG_L1   0.697705     roc_auc       0.091418     0.011779                0.091418           0.011779            1       True          2
# 72        KNeighborsUnif_BAG_L1   0.684478     roc_auc       2.014591     0.013841                2.014591           0.013841            1       True          1
# Number of models trained: 73
# Types of models trained:
# {'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# Plot summary of models saved to file: AutogluonModels/synthetic/gc/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r95_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6844778315366552,
#   'KNeighborsDist_BAG_L1': 0.6977053447641683,
#   'LightGBMXT_BAG_L1': 0.9735449735449736,
#   'LightGBM_BAG_L1': 0.9728376198964434,
#   'RandomForestGini_BAG_L1': 0.9523102170160993,
#   'RandomForestEntr_BAG_L1': 0.9612653142064908,
#   'CatBoost_BAG_L1': 0.9770817417876241,
#   'ExtraTreesGini_BAG_L1': 0.9433268256797669,
#   'ExtraTreesEntr_BAG_L1': 0.9457884163766517,
#   'NeuralNetFastAI_BAG_L1': 0.9535976006564243,
#   'XGBoost_BAG_L1': 0.9652972300031124,
#   'NeuralNetTorch_BAG_L1': 0.9513340689811279,
#   'LightGBMLarge_BAG_L1': 0.9690179101943807,
#   'CatBoost_r177_BAG_L1': 0.97416744475568,
#   'NeuralNetTorch_r79_BAG_L1': 0.9687066745890275,
#   'NeuralNetFastAI_r191_BAG_L1': 0.9582944288826643,
#   'CatBoost_r9_BAG_L1': 0.9748747984042101,
#   'LightGBM_r96_BAG_L1': 0.9737147384206207,
#   'NeuralNetTorch_r22_BAG_L1': 0.9610106668930198,
#   'XGBoost_r33_BAG_L1': 0.9675183204594969,
#   'ExtraTrees_r42_BAG_L1': 0.956950456950457,
#   'CatBoost_r137_BAG_L1': 0.9743937979232098,
#   'NeuralNetFastAI_r102_BAG_L1': 0.9671504965622612,
#   'CatBoost_r13_BAG_L1': 0.9717058540587953,
#   'RandomForest_r195_BAG_L1': 0.9697394109158815,
#   'LightGBM_r188_BAG_L1': 0.9738562091503269,
#   'NeuralNetFastAI_r145_BAG_L1': 0.95772854596384,
#   'XGBoost_r89_BAG_L1': 0.9684803214214979,
#   'NeuralNetTorch_r30_BAG_L1': 0.9651133180544946,
#   'LightGBM_r130_BAG_L1': 0.9726112667289138,
#   'NeuralNetTorch_r86_BAG_L1': 0.9439210027445323,
#   'CatBoost_r50_BAG_L1': 0.9746767393826218,
#   'NeuralNetFastAI_r11_BAG_L1': 0.9363947599241718,
#   'XGBoost_r194_BAG_L1': 0.9677446736270267,
#   'ExtraTrees_r172_BAG_L1': 0.9590866649690178,
#   'CatBoost_r69_BAG_L1': 0.972922502334267,
#   'NeuralNetFastAI_r103_BAG_L1': 0.9344141697082875,
#   'NeuralNetTorch_r14_BAG_L1': 0.9597374303256657,
#   'LightGBM_r161_BAG_L1': 0.9716492657669128,
#   'NeuralNetFastAI_r143_BAG_L1': 0.9728376198964436,
#   'CatBoost_r70_BAG_L1': 0.9756387403446226,
#   'NeuralNetFastAI_r156_BAG_L1': 0.9682822623999094,
#   'LightGBM_r196_BAG_L1': 0.9678012619189089,
#   'RandomForest_r39_BAG_L1': 0.9693008516537929,
#   'CatBoost_r167_BAG_L1': 0.9735449735449736,
#   'NeuralNetFastAI_r95_BAG_L1': 0.9550971903913079,
#   'NeuralNetTorch_r41_BAG_L1': 0.9593979005743711,
#   'XGBoost_r98_BAG_L1': 0.9683105565458506,
#   'LightGBM_r15_BAG_L1': 0.9704043233454999,
#   'NeuralNetTorch_r158_BAG_L1': 0.9614916673740204,
#   'WeightedEnsemble_L2': 0.9868149279913986,
#   'LightGBMXT_BAG_L2': 0.9839289251053956,
#   'LightGBM_BAG_L2': 0.9776193305605071,
#   'RandomForestGini_BAG_L2': 0.9753133576662989,
#   'RandomForestEntr_BAG_L2': 0.9790764790764791,
#   'CatBoost_BAG_L2': 0.9797979797979797,
#   'ExtraTreesGini_BAG_L2': 0.978553037376567,
#   'ExtraTreesEntr_BAG_L2': 0.9794301559007441,
#   'NeuralNetFastAI_BAG_L2': 0.9777890954361542,
#   'XGBoost_BAG_L2': 0.9752850635203576,
#   'NeuralNetTorch_BAG_L2': 0.9462694168576521,
#   'LightGBMLarge_BAG_L2': 0.9708004413886768,
#   'CatBoost_r177_BAG_L2': 0.9799111563817446,
#   'NeuralNetTorch_r79_BAG_L2': 0.9651416122004357,
#   'LightGBM_r131_BAG_L2': 0.9775061539767422,
#   'NeuralNetFastAI_r191_BAG_L2': 0.979147214441332,
#   'CatBoost_r9_BAG_L2': 0.9781852134793312,
#   'LightGBM_r96_BAG_L2': 0.9837308660838073,
#   'NeuralNetTorch_r22_BAG_L2': 0.9700364994482641,
#   'XGBoost_r33_BAG_L2': 0.9750870044987692,
#   'ExtraTrees_r42_BAG_L2': 0.9768695356930652,
#   'CatBoost_r137_BAG_L2': 0.9822312763489234,
#   'WeightedEnsemble_L3': 0.9849192202133378},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetFastAI_r95_BAG_L1': ['NeuralNetFastAI_r95_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'NeuralNetFastAI_r191_BAG_L2': ['NeuralNetFastAI_r191_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'LightGBM_r96_BAG_L2': ['LightGBM_r96_BAG_L2'],
#   'NeuralNetTorch_r22_BAG_L2': ['NeuralNetTorch_r22_BAG_L2'],
#   'XGBoost_r33_BAG_L2': ['XGBoost_r33_BAG_L2'],
#   'ExtraTrees_r42_BAG_L2': ['ExtraTrees_r42_BAG_L2'],
#   'CatBoost_r137_BAG_L2': ['CatBoost_r137_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.013840675354003906,
#   'KNeighborsDist_BAG_L1': 0.011779308319091797,
#   'LightGBMXT_BAG_L1': 3.3372154235839844,
#   'LightGBM_BAG_L1': 5.065002918243408,
#   'RandomForestGini_BAG_L1': 1.0245001316070557,
#   'RandomForestEntr_BAG_L1': 0.9979534149169922,
#   'CatBoost_BAG_L1': 15.974716186523438,
#   'ExtraTreesGini_BAG_L1': 1.0544400215148926,
#   'ExtraTreesEntr_BAG_L1': 0.9759774208068848,
#   'NeuralNetFastAI_BAG_L1': 14.999296426773071,
#   'XGBoost_BAG_L1': 4.005185127258301,
#   'NeuralNetTorch_BAG_L1': 61.09925627708435,
#   'LightGBMLarge_BAG_L1': 8.370450973510742,
#   'CatBoost_r177_BAG_L1': 22.275765657424927,
#   'NeuralNetTorch_r79_BAG_L1': 46.14318919181824,
#   'NeuralNetFastAI_r191_BAG_L1': 36.101866006851196,
#   'CatBoost_r9_BAG_L1': 103.43306016921997,
#   'LightGBM_r96_BAG_L1': 16.058936834335327,
#   'NeuralNetTorch_r22_BAG_L1': 81.40467548370361,
#   'XGBoost_r33_BAG_L1': 7.432546377182007,
#   'ExtraTrees_r42_BAG_L1': 1.1234407424926758,
#   'CatBoost_r137_BAG_L1': 21.814414739608765,
#   'NeuralNetFastAI_r102_BAG_L1': 21.864320278167725,
#   'CatBoost_r13_BAG_L1': 171.34032773971558,
#   'RandomForest_r195_BAG_L1': 1.6122117042541504,
#   'LightGBM_r188_BAG_L1': 13.623424530029297,
#   'NeuralNetFastAI_r145_BAG_L1': 13.521186828613281,
#   'XGBoost_r89_BAG_L1': 5.098328113555908,
#   'NeuralNetTorch_r30_BAG_L1': 45.2020001411438,
#   'LightGBM_r130_BAG_L1': 2.406623363494873,
#   'NeuralNetTorch_r86_BAG_L1': 40.49526882171631,
#   'CatBoost_r50_BAG_L1': 15.588583946228027,
#   'NeuralNetFastAI_r11_BAG_L1': 19.119738817214966,
#   'XGBoost_r194_BAG_L1': 12.833862543106079,
#   'ExtraTrees_r172_BAG_L1': 1.288292407989502,
#   'CatBoost_r69_BAG_L1': 8.832170009613037,
#   'NeuralNetFastAI_r103_BAG_L1': 12.619819164276123,
#   'NeuralNetTorch_r14_BAG_L1': 59.566778898239136,
#   'LightGBM_r161_BAG_L1': 12.760269403457642,
#   'NeuralNetFastAI_r143_BAG_L1': 28.98773741722107,
#   'CatBoost_r70_BAG_L1': 34.26155877113342,
#   'NeuralNetFastAI_r156_BAG_L1': 31.10875177383423,
#   'LightGBM_r196_BAG_L1': 13.970286130905151,
#   'RandomForest_r39_BAG_L1': 1.7036621570587158,
#   'CatBoost_r167_BAG_L1': 21.164403200149536,
#   'NeuralNetFastAI_r95_BAG_L1': 18.134835481643677,
#   'NeuralNetTorch_r41_BAG_L1': 57.65050220489502,
#   'XGBoost_r98_BAG_L1': 19.413429498672485,
#   'LightGBM_r15_BAG_L1': 10.9094979763031,
#   'NeuralNetTorch_r158_BAG_L1': 64.66813683509827,
#   'WeightedEnsemble_L2': 0.25681638717651367,
#   'LightGBMXT_BAG_L2': 7.419565677642822,
#   'LightGBM_BAG_L2': 10.900804996490479,
#   'RandomForestGini_BAG_L2': 1.6072404384613037,
#   'RandomForestEntr_BAG_L2': 1.7353429794311523,
#   'CatBoost_BAG_L2': 91.28424572944641,
#   'ExtraTreesGini_BAG_L2': 1.0559394359588623,
#   'ExtraTreesEntr_BAG_L2': 0.9626662731170654,
#   'NeuralNetFastAI_BAG_L2': 20.911837577819824,
#   'XGBoost_BAG_L2': 5.814744710922241,
#   'NeuralNetTorch_BAG_L2': 60.14431023597717,
#   'LightGBMLarge_BAG_L2': 14.772326946258545,
#   'CatBoost_r177_BAG_L2': 51.51074552536011,
#   'NeuralNetTorch_r79_BAG_L2': 68.38083076477051,
#   'LightGBM_r131_BAG_L2': 15.190017938613892,
#   'NeuralNetFastAI_r191_BAG_L2': 17.82969045639038,
#   'CatBoost_r9_BAG_L2': 128.25942587852478,
#   'LightGBM_r96_BAG_L2': 19.254854440689087,
#   'NeuralNetTorch_r22_BAG_L2': 35.739821910858154,
#   'XGBoost_r33_BAG_L2': 26.22326922416687,
#   'ExtraTrees_r42_BAG_L2': 2.243685245513916,
#   'CatBoost_r137_BAG_L2': 36.788020849227905,
#   'WeightedEnsemble_L3': 0.24139904975891113},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 2.0145914554595947,
#   'KNeighborsDist_BAG_L1': 0.09141755104064941,
#   'LightGBMXT_BAG_L1': 0.028859615325927734,
#   'LightGBM_BAG_L1': 0.019608259201049805,
#   'RandomForestGini_BAG_L1': 0.17069220542907715,
#   'RandomForestEntr_BAG_L1': 0.1643671989440918,
#   'CatBoost_BAG_L1': 0.06960844993591309,
#   'ExtraTreesGini_BAG_L1': 0.16142535209655762,
#   'ExtraTreesEntr_BAG_L1': 0.1701655387878418,
#   'NeuralNetFastAI_BAG_L1': 0.12353849411010742,
#   'XGBoost_BAG_L1': 0.03530287742614746,
#   'NeuralNetTorch_BAG_L1': 0.29440879821777344,
#   'LightGBMLarge_BAG_L1': 0.023168563842773438,
#   'CatBoost_r177_BAG_L1': 0.0667731761932373,
#   'NeuralNetTorch_r79_BAG_L1': 0.29630613327026367,
#   'NeuralNetFastAI_r191_BAG_L1': 0.12369894981384277,
#   'CatBoost_r9_BAG_L1': 0.07544660568237305,
#   'LightGBM_r96_BAG_L1': 0.07159900665283203,
#   'NeuralNetTorch_r22_BAG_L1': 0.2911641597747803,
#   'XGBoost_r33_BAG_L1': 0.047348737716674805,
#   'ExtraTrees_r42_BAG_L1': 0.15336084365844727,
#   'CatBoost_r137_BAG_L1': 0.0741889476776123,
#   'NeuralNetFastAI_r102_BAG_L1': 0.20388221740722656,
#   'CatBoost_r13_BAG_L1': 0.06594634056091309,
#   'RandomForest_r195_BAG_L1': 0.0868988037109375,
#   'LightGBM_r188_BAG_L1': 0.027896881103515625,
#   'NeuralNetFastAI_r145_BAG_L1': 0.12455296516418457,
#   'XGBoost_r89_BAG_L1': 0.03382134437561035,
#   'NeuralNetTorch_r30_BAG_L1': 0.27957725524902344,
#   'LightGBM_r130_BAG_L1': 0.025167226791381836,
#   'NeuralNetTorch_r86_BAG_L1': 0.4297749996185303,
#   'CatBoost_r50_BAG_L1': 0.09010553359985352,
#   'NeuralNetFastAI_r11_BAG_L1': 0.12839555740356445,
#   'XGBoost_r194_BAG_L1': 0.13356375694274902,
#   'ExtraTrees_r172_BAG_L1': 0.18290162086486816,
#   'CatBoost_r69_BAG_L1': 0.16888022422790527,
#   'NeuralNetFastAI_r103_BAG_L1': 0.11751079559326172,
#   'NeuralNetTorch_r14_BAG_L1': 0.28324127197265625,
#   'LightGBM_r161_BAG_L1': 0.0380399227142334,
#   'NeuralNetFastAI_r143_BAG_L1': 0.1773090362548828,
#   'CatBoost_r70_BAG_L1': 0.06755900382995605,
#   'NeuralNetFastAI_r156_BAG_L1': 0.18599343299865723,
#   'LightGBM_r196_BAG_L1': 0.12846922874450684,
#   'RandomForest_r39_BAG_L1': 0.153578519821167,
#   'CatBoost_r167_BAG_L1': 0.06482577323913574,
#   'NeuralNetFastAI_r95_BAG_L1': 0.1288282871246338,
#   'NeuralNetTorch_r41_BAG_L1': 0.27030205726623535,
#   'XGBoost_r98_BAG_L1': 0.13202142715454102,
#   'LightGBM_r15_BAG_L1': 0.019505023956298828,
#   'NeuralNetTorch_r158_BAG_L1': 0.29346680641174316,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.03290581703186035,
#   'LightGBM_BAG_L2': 0.030977249145507812,
#   'RandomForestGini_BAG_L2': 0.20486712455749512,
#   'RandomForestEntr_BAG_L2': 0.19883179664611816,
#   'CatBoost_BAG_L2': 0.12810373306274414,
#   'ExtraTreesGini_BAG_L2': 0.1745777130126953,
#   'ExtraTreesEntr_BAG_L2': 0.17395639419555664,
#   'NeuralNetFastAI_BAG_L2': 0.12803363800048828,
#   'XGBoost_BAG_L2': 0.040912628173828125,
#   'NeuralNetTorch_BAG_L2': 0.3024141788482666,
#   'LightGBMLarge_BAG_L2': 0.038117408752441406,
#   'CatBoost_r177_BAG_L2': 0.09290790557861328,
#   'NeuralNetTorch_r79_BAG_L2': 0.30320215225219727,
#   'LightGBM_r131_BAG_L2': 0.03469491004943848,
#   'NeuralNetFastAI_r191_BAG_L2': 0.12079763412475586,
#   'CatBoost_r9_BAG_L2': 0.08846092224121094,
#   'LightGBM_r96_BAG_L2': 0.09247183799743652,
#   'NeuralNetTorch_r22_BAG_L2': 0.36815881729125977,
#   'XGBoost_r33_BAG_L2': 0.0980222225189209,
#   'ExtraTrees_r42_BAG_L2': 0.1885673999786377,
#   'CatBoost_r137_BAG_L2': 0.08349943161010742,
#   'WeightedEnsemble_L3': 0.0008261203765869141},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.986815     roc_auc       1.612785
#  1           WeightedEnsemble_L3   0.984919     roc_auc       9.186918
#  2             LightGBMXT_BAG_L2   0.983929     roc_auc       8.641962
#  3           LightGBM_r96_BAG_L2   0.983731     roc_auc       8.701528
#  4          CatBoost_r137_BAG_L2   0.982231     roc_auc       8.692556
#  ..                          ...        ...         ...            ...
#  68        ExtraTreesGini_BAG_L1   0.943327     roc_auc       0.161425
#  69   NeuralNetFastAI_r11_BAG_L1   0.936395     roc_auc       0.128396
#  70  NeuralNetFastAI_r103_BAG_L1   0.934414     roc_auc       0.117511
#  71        KNeighborsDist_BAG_L1   0.697705     roc_auc       0.091418
#  72        KNeighborsUnif_BAG_L1   0.684478     roc_auc       2.014591
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    398.906407                0.000000           0.256816            2
#  1   1311.907180                0.000826           0.241399            3
#  2   1219.883083                0.032906           7.419566            2
#  3   1231.718372                0.092472          19.254854            2
#  4   1249.251539                0.083499          36.788021            2
#  ..          ...                     ...                ...          ...
#  68     1.054440                0.161425           1.054440            1
#  69    19.119739                0.128396          19.119739            1
#  70    12.619819                0.117511          12.619819            1
#  71     0.011779                0.091418           0.011779            1
#  72     0.013841                2.014591           0.013841            1
#
#      can_infer  fit_order
#  0        True         51
#  1        True         73
#  2        True         52
#  3        True         68
#  4        True         72
#  ..        ...        ...
#  68       True          8
#  69       True         33
#  70       True         37
#  71       True          2
#  72       True          1
#
#  [73 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9719202898550724
# Evaluations on test data:
# {
#     "roc_auc": 0.9719202898550724,
#     "accuracy": 0.9148936170212766,
#     "balanced_accuracy": 0.9153079710144928,
#     "mcc": 0.8306159420289855,
#     "f1": 0.9148936170212766,
#     "precision": 0.9347826086956522,
#     "recall": 0.8958333333333334
# }
# {'roc_auc': 0.9719202898550724,
#  'accuracy': 0.9148936170212766,
#  'balanced_accuracy': 0.9153079710144928,
#  'mcc': 0.8306159420289855,
#  'f1': 0.9148936170212766,
#  'precision': 0.9347826086956522,
#  'recall': 0.8958333333333334}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                           model  score_test  balanced_accuracy        f1  \
# 0               CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 1               LightGBM_BAG_L1    1.000000           1.000000  1.000000
# 2         KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 3           CatBoost_r69_BAG_L1    1.000000           1.000000  1.000000
# 4           CatBoost_r50_BAG_L1    1.000000           1.000000  1.000000
# ..                          ...         ...                ...       ...
# 68       ExtraTrees_r172_BAG_L1    0.999689           0.975936  0.975342
# 69   NeuralNetFastAI_r11_BAG_L1    0.997991           0.967943  0.967033
# 70  NeuralNetFastAI_r103_BAG_L1    0.995784           0.970815  0.970976
# 71  NeuralNetFastAI_r143_BAG_L1    0.995473           0.962765  0.962567
# 72        KNeighborsUnif_BAG_L1    0.849320           0.771214  0.767568
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# ..       ...       ...       ...                ...        ...       ...  ...
# 68  0.976043  0.976064  0.999689           0.999689   1.000000  0.951872  ...
# 69  0.968053  0.968085  0.997991           0.998033   0.994350  0.941176  ...
# 70  0.970743  0.970745  0.995784           0.995917   0.958333  0.983957  ...
# 71  0.962765  0.962766  0.995473           0.995515   0.962567  0.962567  ...
# 72  0.771218  0.771277  0.849320           0.814780   0.775956  0.759358  ...
#
#     eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0       roc_auc        0.073770       0.069608  15.974716
# 1       roc_auc        0.122541       0.019608   5.065003
# 2       roc_auc        0.129793       0.091418   0.011779
# 3       roc_auc        0.149379       0.168880   8.832170
# 4       roc_auc        0.154035       0.090106  15.588584
# ..          ...             ...            ...        ...
# 68      roc_auc        0.156336       0.182902   1.288292
# 69      roc_auc        1.817575       0.128396  19.119739
# 70      roc_auc        1.099746       0.117511  12.619819
# 71      roc_auc        2.647899       0.177309  28.987737
# 72      roc_auc        0.126067       2.014591   0.013841
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.073770                0.069608          15.974716
# 1                  0.122541                0.019608           5.065003
# 2                  0.129793                0.091418           0.011779
# 3                  0.149379                0.168880           8.832170
# 4                  0.154035                0.090106          15.588584
# ..                      ...                     ...                ...
# 68                 0.156336                0.182902           1.288292
# 69                 1.817575                0.128396          19.119739
# 70                 1.099746                0.117511          12.619819
# 71                 2.647899                0.177309          28.987737
# 72                 0.126067                2.014591           0.013841
#
#     stack_level  can_infer  fit_order
# 0             1       True          7
# 1             1       True          4
# 2             1       True          2
# 3             1       True         36
# 4             1       True         32
# ..          ...        ...        ...
# 68            1       True         35
# 69            1       True         33
# 70            1       True         37
# 71            1       True         40
# 72            1       True          1
#
# [73 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 67 features using 376 rows with 5 shuffle sets...
# 	4184.61s	= Expected runtime (836.92s per shuffle set)
# 	472.92s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.CubCorsi.Inversos.PD                  0.022782  0.004164  0.000128  5
# TLP.Stroop.color.PD                       0.019331  0.001985  0.000013  5
# TLP.Tavec.01_RI-A5.PD                     0.012008  0.002707  0.000290  5
# ISC.FPacientes.Edad                       0.001285  0.000272  0.000227  5
# TLP.CubCorsi.Directos.PD                  0.001137  0.000347  0.000920  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Tavec.00_RI-A1.PD                     0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.CubCorsi.Inversos.PD                0.031357  0.014208
# TLP.Stroop.color.PD                     0.023417  0.015244
# TLP.Tavec.01_RI-A5.PD                   0.017583  0.006433
# ISC.FPacientes.Edad                     0.001844  0.000725
# TLP.CubCorsi.Directos.PD                0.001851  0.000423
# ...                                          ...       ...
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Tavec.00_RI-A1.PD                   0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [67 rows x 6 columns]
