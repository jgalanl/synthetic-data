# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/real/synthetic-gc.csv')

# %%
drop_columns = [
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]
pz_columns = [column for column in df.columns if 'PZ' in column ]
pdc_columns = [column for column in df.columns if 'PDC' in column]
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD  TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                             33.333333
# 1                           12.500000                              0.000000
# 2                           75.000000                             25.000000
# 3                           16.666667                              0.000000
# 4                           66.666667                              0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD  TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                           -33.333333
# 1                            0.000000                             0.000000
# 2                          -20.000000                             0.000000
# 3                           50.000000                           -20.000000
# 4                          -33.333333                             0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 68 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((376, 68), (94, 68))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/gc/v1'
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/synthetic/gc/v1"

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 300,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       8.30 GB / 15.71 GB (52.9%)
# Disk Space Avail:   669.33 GB / 933.46 GB (71.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-16 23:38:41,057	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=18924) Running DyStack sub-fit ...
# (_dystack pid=18924) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=18924) Beginning AutoGluon training ... Time limit = 66s
# (_dystack pid=18924) AutoGluon will save models to "AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=18924) Train Data Rows:    334
# (_dystack pid=18924) Train Data Columns: 67
# (_dystack pid=18924) Label Column:       ED_2Clases
# (_dystack pid=18924) Problem Type:       binary
# (_dystack pid=18924) Preprocessing data ...
# (_dystack pid=18924) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=18924) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=18924) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=18924) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=18924) Using Feature Generators to preprocess the data ...
# (_dystack pid=18924) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=18924) 	Available Memory:                    7662.10 MB
# (_dystack pid=18924) 	Train Data (Original)  Memory Usage: 0.17 MB (0.0% of available memory)
# (_dystack pid=18924) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=18924) 	Stage 1 Generators:
# (_dystack pid=18924) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=18924) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=18924) 	Stage 2 Generators:
# (_dystack pid=18924) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=18924) 	Stage 3 Generators:
# (_dystack pid=18924) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=18924) 	Stage 4 Generators:
# (_dystack pid=18924) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=18924) 	Stage 5 Generators:
# (_dystack pid=18924) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=18924) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=18924) 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=18924) 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=18924) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=18924) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=18924) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=18924) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=18924) 	0.1s = Fit runtime
# (_dystack pid=18924) 	67 features in original data used to generate 67 features in processed data.
# (_dystack pid=18924) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=18924) Data preprocessing and feature engineering runtime = 0.1s ...
# (_dystack pid=18924) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=18924) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=18924) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=18924) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=18924) User-specified model hyperparameters to be fit:
# (_dystack pid=18924) {
# (_dystack pid=18924) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=18924) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=18924) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=18924) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=18924) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=18924) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=18924) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=18924) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=18924) }
# (_dystack pid=18924) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=18924) Fitting 110 L1 models ...
# (_dystack pid=18924) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 43.74s of the 65.62s of remaining time.
# (_dystack pid=18924) 	0.647	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.02s	 = Training   runtime
# (_dystack pid=18924) 	0.22s	 = Validation runtime
# (_dystack pid=18924) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 35.63s of the 57.5s of remaining time.
# (_dystack pid=18924) 	0.6465	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.01s	 = Training   runtime
# (_dystack pid=18924) 	0.03s	 = Validation runtime
# (_dystack pid=18924) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 35.55s of the 57.42s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# (_dystack pid=18924) 	0.9781	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	1.32s	 = Training   runtime
# (_dystack pid=18924) 	0.02s	 = Validation runtime
# (_dystack pid=18924) Fitting model: LightGBM_BAG_L1 ... Training model for up to 31.12s of the 52.99s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.21%)
# (_dystack pid=18924) 	0.9818	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.86s	 = Training   runtime
# (_dystack pid=18924) 	0.02s	 = Validation runtime
# (_dystack pid=18924) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 27.0s of the 48.88s of remaining time.
# (_dystack pid=18924) 	0.9509	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	1.22s	 = Training   runtime
# (_dystack pid=18924) 	0.08s	 = Validation runtime
# (_dystack pid=18924) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 25.66s of the 47.53s of remaining time.
# (_dystack pid=18924) 	0.9568	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.69s	 = Training   runtime
# (_dystack pid=18924) 	0.08s	 = Validation runtime
# (_dystack pid=18924) Fitting model: CatBoost_BAG_L1 ... Training model for up to 24.82s of the 46.7s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.35%)
# (_dystack pid=18924) 	0.9777	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	14.24s	 = Training   runtime
# (_dystack pid=18924) 	0.07s	 = Validation runtime
# (_dystack pid=18924) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 7.39s of the 29.25s of remaining time.
# (_dystack pid=18924) 	0.9392	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.7s	 = Training   runtime
# (_dystack pid=18924) 	0.08s	 = Validation runtime
# (_dystack pid=18924) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 6.53s of the 28.41s of remaining time.
# (_dystack pid=18924) 	0.9411	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.68s	 = Training   runtime
# (_dystack pid=18924) 	0.07s	 = Validation runtime
# (_dystack pid=18924) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 5.73s of the 27.61s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# (_dystack pid=18924) 	0.9589	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	8.39s	 = Training   runtime
# (_dystack pid=18924) 	0.09s	 = Validation runtime
# (_dystack pid=18924) Fitting model: WeightedEnsemble_L2 ... Training model for up to 65.63s of the 15.58s of remaining time.
# (_dystack pid=18924) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.64, 'CatBoost_BAG_L1': 0.2, 'LightGBMXT_BAG_L1': 0.12, 'NeuralNetFastAI_BAG_L1': 0.04}
# (_dystack pid=18924) 	0.9834	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.08s	 = Training   runtime
# (_dystack pid=18924) 	0.0s	 = Validation runtime
# (_dystack pid=18924) Fitting 108 L2 models ...
# (_dystack pid=18924) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 15.45s of the 15.37s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.31%)
# (_dystack pid=18924) 	0.9772	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.8s	 = Training   runtime
# (_dystack pid=18924) 	0.02s	 = Validation runtime
# (_dystack pid=18924) Fitting model: LightGBM_BAG_L2 ... Training model for up to 11.36s of the 11.29s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.23%)
# (_dystack pid=18924) 	0.9727	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.82s	 = Training   runtime
# (_dystack pid=18924) 	0.02s	 = Validation runtime
# (_dystack pid=18924) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 7.31s of the 7.23s of remaining time.
# (_dystack pid=18924) 	0.9663	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.81s	 = Training   runtime
# (_dystack pid=18924) 	0.08s	 = Validation runtime
# (_dystack pid=18924) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 6.38s of the 6.31s of remaining time.
# (_dystack pid=18924) 	0.9753	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.71s	 = Training   runtime
# (_dystack pid=18924) 	0.07s	 = Validation runtime
# (_dystack pid=18924) Fitting model: CatBoost_BAG_L2 ... Training model for up to 5.55s of the 5.48s of remaining time.
# (_dystack pid=18924) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.39%)
# (_dystack pid=18924) 	0.9772	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	4.63s	 = Training   runtime
# (_dystack pid=18924) 	0.03s	 = Validation runtime
# (_dystack pid=18924) Fitting model: WeightedEnsemble_L3 ... Training model for up to 65.63s of the -2.89s of remaining time.
# (_dystack pid=18924) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.64, 'CatBoost_BAG_L1': 0.2, 'LightGBMXT_BAG_L1': 0.12, 'NeuralNetFastAI_BAG_L1': 0.04}
# (_dystack pid=18924) 	0.9834	 = Validation score   (roc_auc)
# (_dystack pid=18924) 	0.07s	 = Training   runtime
# (_dystack pid=18924) 	0.0s	 = Validation runtime
# (_dystack pid=18924) AutoGluon training complete, total runtime = 68.7s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 219.4 rows/s (42 batch size)
# (_dystack pid=18924) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/gc/v1\ds_sub_fit\sub_fit_ho")
# (_dystack pid=18924) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestGini_BAG_L2       0.961451   0.966276     roc_auc        4.680561       0.830453  28.932830                 0.090856                0.079139           0.806535            2       True         14
# 1           LightGBM_BAG_L2       0.961451   0.972712     roc_auc        4.762790       0.774360  28.949118                 0.173085                0.023046           0.822823            2       True         13
# 2   RandomForestEntr_BAG_L2       0.959184   0.975294     roc_auc        4.676183       0.823555  28.835298                 0.086478                0.072241           0.709002            2       True         15
# 3         LightGBMXT_BAG_L2       0.959184   0.977230     roc_auc        4.733156       0.768144  28.930279                 0.143451                0.016829           0.803984            2       True         12
# 4           LightGBM_BAG_L1       0.956916   0.981820     roc_auc        0.237796       0.016044   0.863291                 0.237796                0.016044           0.863291            1       True          4
# 5       WeightedEnsemble_L2       0.954649   0.983398     roc_auc        3.915489       0.191409  24.894886                 0.013246                0.000000           0.084286            2       True         11
# 6       WeightedEnsemble_L3       0.954649   0.983398     roc_auc        3.931987       0.191409  24.885074                 0.029744                0.000000           0.074475            3       True         17
# 7           CatBoost_BAG_L2       0.954649   0.977159     roc_auc        4.878245       0.783515  32.758717                 0.288540                0.032201           4.632421            2       True         16
# 8    NeuralNetFastAI_BAG_L1       0.952381   0.958943     roc_auc        2.348717       0.087119   8.389884                 2.348717                0.087119           8.389884            1       True         10
# 9           CatBoost_BAG_L1       0.950113   0.977661     roc_auc        0.832369       0.070249  14.241264                 0.832369                0.070249          14.241264            1       True          7
# 10        LightGBMXT_BAG_L1       0.943311   0.978055     roc_auc        0.483361       0.017997   1.316161                 0.483361                0.017997           1.316161            1       True          3
# 11  RandomForestEntr_BAG_L1       0.935374   0.956809     roc_auc        0.154915       0.082441   0.691411                 0.154915                0.082441           0.691411            1       True          6
# 12  RandomForestGini_BAG_L1       0.927438   0.950857     roc_auc        0.124960       0.078614   1.216035                 0.124960                0.078614           1.216035            1       True          5
# 13    ExtraTreesGini_BAG_L1       0.919501   0.939185     roc_auc        0.183220       0.079228   0.703902                 0.183220                0.079228           0.703902            1       True          8
# 14    ExtraTreesEntr_BAG_L1       0.910431   0.941122     roc_auc        0.109954       0.073499   0.676310                 0.109954                0.073499           0.676310            1       True          9
# 15    KNeighborsDist_BAG_L1       0.643991   0.646515     roc_auc        0.049849       0.025736   0.011019                 0.049849                0.025736           0.011019            1       True          2
# 16    KNeighborsUnif_BAG_L1       0.626984   0.646999     roc_auc        0.064564       0.220388   0.017018                 0.064564                0.220388           0.017018            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	86s	 = DyStack   runtime |	214s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 214s
# AutoGluon will save models to "AutogluonModels/synthetic/gc/v1"
# Train Data Rows:    376
# Train Data Columns: 67
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7564.12 MB
# 	Train Data (Original)  Memory Usage: 0.19 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# 	0.1s = Fit runtime
# 	67 features in original data used to generate 67 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 142.51s of the 213.8s of remaining time.
# 	0.6587	 = Validation score   (roc_auc)
# 	0.0s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 138.86s of the 210.15s of remaining time.
# 	0.6613	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 138.79s of the 210.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# 	0.9733	 = Validation score   (roc_auc)
# 	1.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 134.36s of the 205.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.19%)
# 	0.9713	 = Validation score   (roc_auc)
# 	1.73s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 130.34s of the 201.63s of remaining time.
# 	0.9503	 = Validation score   (roc_auc)
# 	0.86s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 129.32s of the 200.61s of remaining time.
# 	0.9563	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 128.53s of the 199.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.34%)
# 	0.9765	 = Validation score   (roc_auc)
# 	6.52s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 119.67s of the 190.96s of remaining time.
# 	0.9424	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 118.84s of the 190.14s of remaining time.
# 	0.9465	 = Validation score   (roc_auc)
# 	0.68s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 118.01s of the 189.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.9564	 = Validation score   (roc_auc)
# 	6.08s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 109.46s of the 180.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.54%)
# 	0.9658	 = Validation score   (roc_auc)
# 	2.54s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 104.24s of the 175.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.9492	 = Validation score   (roc_auc)
# 	20.74s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 81.11s of the 152.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.91%)
# 	0.9672	 = Validation score   (roc_auc)
# 	2.19s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 76.39s of the 147.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.41%)
# 	0.9745	 = Validation score   (roc_auc)
# 	6.27s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 67.72s of the 139.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.9711	 = Validation score   (roc_auc)
# 	22.06s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 43.22s of the 114.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.33%)
# 	0.9723	 = Validation score   (roc_auc)
# 	2.58s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 38.14s of the 109.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.9587	 = Validation score   (roc_auc)
# 	6.87s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 28.94s of the 100.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=2.17%)
# 	0.97	 = Validation score   (roc_auc)
# 	24.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 2.17s of the 73.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	0.9722	 = Validation score   (roc_auc)
# 	3.04s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 213.82s of the 67.48s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.353, 'NeuralNetTorch_r79_BAG_L1': 0.294, 'LightGBMLarge_BAG_L1': 0.118, 'LightGBM_r131_BAG_L1': 0.118, 'NeuralNetTorch_BAG_L1': 0.059, 'LightGBM_r96_BAG_L1': 0.059}
# 	0.9816	 = Validation score   (roc_auc)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 67.36s of the 67.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.22%)
# 	0.9785	 = Validation score   (roc_auc)
# 	1.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 62.99s of the 62.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.24%)
# 	0.9731	 = Validation score   (roc_auc)
# 	2.49s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 58.08s of the 57.98s of remaining time.
# 	0.9721	 = Validation score   (roc_auc)
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 57.26s of the 57.16s of remaining time.
# 	0.9745	 = Validation score   (roc_auc)
# 	0.69s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 56.44s of the 56.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.43%)
# 	0.9758	 = Validation score   (roc_auc)
# 	46.04s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 8.02s of the 7.92s of remaining time.
# 	0.9741	 = Validation score   (roc_auc)
# 	0.71s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 7.19s of the 7.09s of remaining time.
# 	0.9741	 = Validation score   (roc_auc)
# 	0.65s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 6.42s of the 6.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	0.977	 = Validation score   (roc_auc)
# 	6.49s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 213.82s of the -3.38s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.211, 'NeuralNetTorch_r79_BAG_L1': 0.211, 'LightGBMXT_BAG_L1': 0.105, 'XGBoost_BAG_L1': 0.105, 'NeuralNetTorch_BAG_L1': 0.105, 'LightGBM_r96_BAG_L1': 0.105, 'LightGBM_r131_BAG_L1': 0.053, 'LightGBMXT_BAG_L2': 0.053, 'NeuralNetFastAI_BAG_L2': 0.053}
# 	0.9812	 = Validation score   (roc_auc)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 217.53s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 101.9 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/gc/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L2   0.981552     roc_auc       0.461391   57.239456                0.000000           0.100137            2       True         20
# 1           WeightedEnsemble_L3   0.981213     roc_auc       1.532058  117.421115                0.000000           0.123616            3       True         29
# 2             LightGBMXT_BAG_L2   0.978496     roc_auc       1.413046  110.810300                0.024751           1.897905            2       True         21
# 3        NeuralNetFastAI_BAG_L2   0.977025     roc_auc       1.507307  115.399594                0.119012           6.487199            2       True         28
# 4               CatBoost_BAG_L1   0.976459     roc_auc       0.068091    6.523740                0.068091           6.523740            1       True          7
# 5               CatBoost_BAG_L2   0.975809     roc_auc       1.460133  154.953095                0.071838          46.040700            2       True         25
# 6          CatBoost_r177_BAG_L1   0.974507     roc_auc       0.050559    6.274853                0.050559           6.274853            1       True         14
# 7       RandomForestEntr_BAG_L2   0.974450     roc_auc       1.461579  109.606176                0.073284           0.693781            2       True         24
# 8         ExtraTreesEntr_BAG_L2   0.974097     roc_auc       1.466951  109.557601                0.078655           0.645206            2       True         27
# 9         ExtraTreesGini_BAG_L2   0.974083     roc_auc       1.462871  109.618982                0.074575           0.706587            2       True         26
# 10            LightGBMXT_BAG_L1   0.973290     roc_auc       0.013573    1.258840                0.013573           1.258840            1       True          3
# 11              LightGBM_BAG_L2   0.973149     roc_auc       1.410347  111.399053                0.022051           2.486658            2       True         22
# 12         LightGBM_r131_BAG_L1   0.972328     roc_auc       0.026031    2.583066                0.026031           2.583066            1       True         16
# 13          LightGBM_r96_BAG_L1   0.972159     roc_auc       0.053144    3.043334                0.053144           3.043334            1       True         19
# 14      RandomForestGini_BAG_L2   0.972130     roc_auc       1.467644  109.613086                0.079349           0.700691            2       True         23
# 15              LightGBM_BAG_L1   0.971310     roc_auc       0.029937    1.731863                0.029937           1.731863            1       True          4
# 16    NeuralNetTorch_r79_BAG_L1   0.971083     roc_auc       0.154438   22.063158                0.154438          22.063158            1       True         15
# 17           CatBoost_r9_BAG_L1   0.969980     roc_auc       0.030780   24.100328                0.030780          24.100328            1       True         18
# 18         LightGBMLarge_BAG_L1   0.967235     roc_auc       0.008531    2.188956                0.008531           2.188956            1       True         13
# 19               XGBoost_BAG_L1   0.965807     roc_auc       0.027025    2.544211                0.027025           2.544211            1       True         11
# 20  NeuralNetFastAI_r191_BAG_L1   0.958691     roc_auc       0.089529    6.872006                0.089529           6.872006            1       True         17
# 21       NeuralNetFastAI_BAG_L1   0.956370     roc_auc       0.082139    6.075857                0.082139           6.075857            1       True         10
# 22      RandomForestEntr_BAG_L1   0.956286     roc_auc       0.080066    0.665504                0.080066           0.665504            1       True          6
# 23      RandomForestGini_BAG_L1   0.950330     roc_auc       0.089975    0.862456                0.089975           0.862456            1       True          5
# 24        NeuralNetTorch_BAG_L1   0.949212     roc_auc       0.151157   20.737066                0.151157          20.737066            1       True         12
# 25        ExtraTreesEntr_BAG_L1   0.946510     roc_auc       0.093268    0.679659                0.093268           0.679659            1       True          9
# 26        ExtraTreesGini_BAG_L1   0.942393     roc_auc       0.080336    0.696637                0.080336           0.696637            1       True          8
# 27        KNeighborsDist_BAG_L1   0.661333     roc_auc       0.025587    0.010863                0.025587           0.010863            1       True          2
# 28        KNeighborsUnif_BAG_L1   0.658716     roc_auc       0.234130    0.000000                0.234130           0.000000            1       True          1
# Number of models trained: 29
# Types of models trained:
# {'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6587160116571881,
#   'KNeighborsDist_BAG_L1': 0.6613332201567497,
#   'LightGBMXT_BAG_L1': 0.9732903262315029,
#   'LightGBM_BAG_L1': 0.9713097360156183,
#   'RandomForestGini_BAG_L1': 0.9503296268002152,
#   'RandomForestEntr_BAG_L1': 0.9562855445208387,
#   'CatBoost_BAG_L1': 0.9764592705769177,
#   'ExtraTreesGini_BAG_L1': 0.9423931188637072,
#   'ExtraTreesEntr_BAG_L1': 0.9465099170981525,
#   'NeuralNetFastAI_BAG_L1': 0.9563704269586623,
#   'XGBoost_BAG_L1': 0.965806524630054,
#   'NeuralNetTorch_BAG_L1': 0.9492120080355375,
#   'LightGBMLarge_BAG_L1': 0.967235379000085,
#   'CatBoost_r177_BAG_L1': 0.9745069745069747,
#   'NeuralNetTorch_r79_BAG_L1': 0.9710833828480888,
#   'LightGBM_r131_BAG_L1': 0.9723283252695017,
#   'NeuralNetFastAI_r191_BAG_L1': 0.9586905469258411,
#   'CatBoost_r9_BAG_L1': 0.9699799111563818,
#   'LightGBM_r96_BAG_L1': 0.9721585603938545,
#   'WeightedEnsemble_L2': 0.9815522168463344,
#   'LightGBMXT_BAG_L2': 0.9784964490846845,
#   'LightGBM_BAG_L2': 0.9731488555017968,
#   'RandomForestGini_BAG_L2': 0.9721302662479132,
#   'RandomForestEntr_BAG_L2': 0.9744503862150922,
#   'CatBoost_BAG_L2': 0.9758085052202699,
#   'ExtraTreesGini_BAG_L2': 0.9740825623178565,
#   'ExtraTreesEntr_BAG_L2': 0.974096709390827,
#   'NeuralNetFastAI_BAG_L2': 0.9770251534957417,
#   'WeightedEnsemble_L3': 0.9812126870950401},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.010862588882446289,
#   'LightGBMXT_BAG_L1': 1.2588400840759277,
#   'LightGBM_BAG_L1': 1.7318627834320068,
#   'RandomForestGini_BAG_L1': 0.8624558448791504,
#   'RandomForestEntr_BAG_L1': 0.6655035018920898,
#   'CatBoost_BAG_L1': 6.523739814758301,
#   'ExtraTreesGini_BAG_L1': 0.6966366767883301,
#   'ExtraTreesEntr_BAG_L1': 0.6796586513519287,
#   'NeuralNetFastAI_BAG_L1': 6.075857400894165,
#   'XGBoost_BAG_L1': 2.544210910797119,
#   'NeuralNetTorch_BAG_L1': 20.73706603050232,
#   'LightGBMLarge_BAG_L1': 2.188955545425415,
#   'CatBoost_r177_BAG_L1': 6.274852514266968,
#   'NeuralNetTorch_r79_BAG_L1': 22.0631582736969,
#   'LightGBM_r131_BAG_L1': 2.5830657482147217,
#   'NeuralNetFastAI_r191_BAG_L1': 6.872006416320801,
#   'CatBoost_r9_BAG_L1': 24.10032820701599,
#   'LightGBM_r96_BAG_L1': 3.0433340072631836,
#   'WeightedEnsemble_L2': 0.10013675689697266,
#   'LightGBMXT_BAG_L2': 1.8979051113128662,
#   'LightGBM_BAG_L2': 2.4866578578948975,
#   'RandomForestGini_BAG_L2': 0.700690746307373,
#   'RandomForestEntr_BAG_L2': 0.6937808990478516,
#   'CatBoost_BAG_L2': 46.04069995880127,
#   'ExtraTreesGini_BAG_L2': 0.7065873146057129,
#   'ExtraTreesEntr_BAG_L2': 0.6452059745788574,
#   'NeuralNetFastAI_BAG_L2': 6.487199068069458,
#   'WeightedEnsemble_L3': 0.12361550331115723},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.2341296672821045,
#   'KNeighborsDist_BAG_L1': 0.02558732032775879,
#   'LightGBMXT_BAG_L1': 0.013573408126831055,
#   'LightGBM_BAG_L1': 0.029937267303466797,
#   'RandomForestGini_BAG_L1': 0.08997488021850586,
#   'RandomForestEntr_BAG_L1': 0.08006644248962402,
#   'CatBoost_BAG_L1': 0.06809067726135254,
#   'ExtraTreesGini_BAG_L1': 0.08033561706542969,
#   'ExtraTreesEntr_BAG_L1': 0.09326815605163574,
#   'NeuralNetFastAI_BAG_L1': 0.0821387767791748,
#   'XGBoost_BAG_L1': 0.027024507522583008,
#   'NeuralNetTorch_BAG_L1': 0.15115666389465332,
#   'LightGBMLarge_BAG_L1': 0.008530616760253906,
#   'CatBoost_r177_BAG_L1': 0.050559043884277344,
#   'NeuralNetTorch_r79_BAG_L1': 0.15443825721740723,
#   'LightGBM_r131_BAG_L1': 0.0260312557220459,
#   'NeuralNetFastAI_r191_BAG_L1': 0.08952903747558594,
#   'CatBoost_r9_BAG_L1': 0.030779600143432617,
#   'LightGBM_r96_BAG_L1': 0.053143978118896484,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.024750947952270508,
#   'LightGBM_BAG_L2': 0.022051334381103516,
#   'RandomForestGini_BAG_L2': 0.07934927940368652,
#   'RandomForestEntr_BAG_L2': 0.07328391075134277,
#   'CatBoost_BAG_L2': 0.0718379020690918,
#   'ExtraTreesGini_BAG_L2': 0.07457542419433594,
#   'ExtraTreesEntr_BAG_L2': 0.07865548133850098,
#   'NeuralNetFastAI_BAG_L2': 0.11901164054870605,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.981552     roc_auc       0.461391
#  1           WeightedEnsemble_L3   0.981213     roc_auc       1.532058
#  2             LightGBMXT_BAG_L2   0.978496     roc_auc       1.413046
#  3        NeuralNetFastAI_BAG_L2   0.977025     roc_auc       1.507307
#  4               CatBoost_BAG_L1   0.976459     roc_auc       0.068091
#  5               CatBoost_BAG_L2   0.975809     roc_auc       1.460133
#  6          CatBoost_r177_BAG_L1   0.974507     roc_auc       0.050559
#  7       RandomForestEntr_BAG_L2   0.974450     roc_auc       1.461579
#  8         ExtraTreesEntr_BAG_L2   0.974097     roc_auc       1.466951
#  9         ExtraTreesGini_BAG_L2   0.974083     roc_auc       1.462871
#  10            LightGBMXT_BAG_L1   0.973290     roc_auc       0.013573
#  11              LightGBM_BAG_L2   0.973149     roc_auc       1.410347
#  12         LightGBM_r131_BAG_L1   0.972328     roc_auc       0.026031
#  13          LightGBM_r96_BAG_L1   0.972159     roc_auc       0.053144
#  14      RandomForestGini_BAG_L2   0.972130     roc_auc       1.467644
#  15              LightGBM_BAG_L1   0.971310     roc_auc       0.029937
#  16    NeuralNetTorch_r79_BAG_L1   0.971083     roc_auc       0.154438
#  17           CatBoost_r9_BAG_L1   0.969980     roc_auc       0.030780
#  18         LightGBMLarge_BAG_L1   0.967235     roc_auc       0.008531
#  19               XGBoost_BAG_L1   0.965807     roc_auc       0.027025
#  20  NeuralNetFastAI_r191_BAG_L1   0.958691     roc_auc       0.089529
#  21       NeuralNetFastAI_BAG_L1   0.956370     roc_auc       0.082139
#  22      RandomForestEntr_BAG_L1   0.956286     roc_auc       0.080066
#  23      RandomForestGini_BAG_L1   0.950330     roc_auc       0.089975
#  24        NeuralNetTorch_BAG_L1   0.949212     roc_auc       0.151157
#  25        ExtraTreesEntr_BAG_L1   0.946510     roc_auc       0.093268
#  26        ExtraTreesGini_BAG_L1   0.942393     roc_auc       0.080336
#  27        KNeighborsDist_BAG_L1   0.661333     roc_auc       0.025587
#  28        KNeighborsUnif_BAG_L1   0.658716     roc_auc       0.234130
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    57.239456                0.000000           0.100137            2
#  1   117.421115                0.000000           0.123616            3
#  2   110.810300                0.024751           1.897905            2
#  3   115.399594                0.119012           6.487199            2
#  4     6.523740                0.068091           6.523740            1
#  5   154.953095                0.071838          46.040700            2
#  6     6.274853                0.050559           6.274853            1
#  7   109.606176                0.073284           0.693781            2
#  8   109.557601                0.078655           0.645206            2
#  9   109.618982                0.074575           0.706587            2
#  10    1.258840                0.013573           1.258840            1
#  11  111.399053                0.022051           2.486658            2
#  12    2.583066                0.026031           2.583066            1
#  13    3.043334                0.053144           3.043334            1
#  14  109.613086                0.079349           0.700691            2
#  15    1.731863                0.029937           1.731863            1
#  16   22.063158                0.154438          22.063158            1
#  17   24.100328                0.030780          24.100328            1
#  18    2.188956                0.008531           2.188956            1
#  19    2.544211                0.027025           2.544211            1
#  20    6.872006                0.089529           6.872006            1
#  21    6.075857                0.082139           6.075857            1
#  22    0.665504                0.080066           0.665504            1
#  23    0.862456                0.089975           0.862456            1
#  24   20.737066                0.151157          20.737066            1
#  25    0.679659                0.093268           0.679659            1
#  26    0.696637                0.080336           0.696637            1
#  27    0.010863                0.025587           0.010863            1
#  28    0.000000                0.234130           0.000000            1
#
#      can_infer  fit_order
#  0        True         20
#  1        True         29
#  2        True         21
#  3        True         28
#  4        True          7
#  5        True         25
#  6        True         14
#  7        True         24
#  8        True         27
#  9        True         26
#  10       True          3
#  11       True         22
#  12       True         16
#  13       True         19
#  14       True         23
#  15       True          4
#  16       True         15
#  17       True         18
#  18       True         13
#  19       True         11
#  20       True         17
#  21       True         10
#  22       True          6
#  23       True          5
#  24       True         12
#  25       True          9
#  26       True          8
#  27       True          2
#  28       True          1  }

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9791666666666666
# Evaluations on test data:
# {
#     "roc_auc": 0.9791666666666666,
#     "accuracy": 0.9148936170212766,
#     "balanced_accuracy": 0.9153079710144928,
#     "mcc": 0.8306159420289855,
#     "f1": 0.9148936170212766,
#     "precision": 0.9347826086956522,
#     "recall": 0.8958333333333334
# }
# {'roc_auc': 0.9791666666666666,
#  'accuracy': 0.9148936170212766,
#  'balanced_accuracy': 0.9153079710144928,
#  'mcc': 0.8306159420289855,
#  'f1': 0.9148936170212766,
#  'precision': 0.9347826086956522,
#  'recall': 0.8958333333333334}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                           model  score_test  balanced_accuracy        f1  \
# 0         KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 1          LightGBMLarge_BAG_L1    1.000000           1.000000  1.000000
# 2          LightGBM_r131_BAG_L1    1.000000           1.000000  1.000000
# 3               CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 4         ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 5       RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# 6               LightGBM_BAG_L1    1.000000           0.994652  0.994624
# 7          CatBoost_r177_BAG_L1    1.000000           1.000000  1.000000
# 8         ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 9            CatBoost_r9_BAG_L1    1.000000           1.000000  1.000000
# 10      RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 11          LightGBM_r96_BAG_L1    1.000000           1.000000  1.000000
# 12               XGBoost_BAG_L1    1.000000           1.000000  1.000000
# 13        NeuralNetTorch_BAG_L1    1.000000           1.000000  1.000000
# 14            LightGBMXT_BAG_L1    1.000000           1.000000  1.000000
# 15       NeuralNetFastAI_BAG_L1    1.000000           0.994709  0.994681
# 16          WeightedEnsemble_L2    1.000000           1.000000  1.000000
# 17        ExtraTreesEntr_BAG_L2    1.000000           1.000000  1.000000
# 18        ExtraTreesGini_BAG_L2    1.000000           1.000000  1.000000
# 19      RandomForestGini_BAG_L2    1.000000           1.000000  1.000000
# 20              LightGBM_BAG_L2    1.000000           1.000000  1.000000
# 21      RandomForestEntr_BAG_L2    1.000000           1.000000  1.000000
# 22            LightGBMXT_BAG_L2    1.000000           1.000000  1.000000
# 23              CatBoost_BAG_L2    1.000000           1.000000  1.000000
# 24       NeuralNetFastAI_BAG_L2    1.000000           1.000000  1.000000
# 25          WeightedEnsemble_L3    1.000000           1.000000  1.000000
# 26  NeuralNetFastAI_r191_BAG_L1    0.999972           0.994681  0.994652
# 27    NeuralNetTorch_r79_BAG_L1    0.999519           0.981368  0.981233
# 28        KNeighborsUnif_BAG_L1    0.835993           0.773689  0.761905
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 5   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 6   0.994680  0.994681  1.000000           1.000000   1.000000  0.989305  ...
# 7   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 8   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 9   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 10  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 11  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 12  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 13  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 14  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 15  0.994681  0.994681  1.000000           1.000000   0.989418  1.000000  ...
# 16  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 17  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 18  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 19  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 20  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 21  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 22  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 23  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 24  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 25  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 26  0.994681  0.994681  0.999972           0.999972   0.994652  0.994652  ...
# 27  0.981382  0.981383  0.999519           0.999521   0.983871  0.978610  ...
# 28  0.773357  0.773936  0.835993           0.801252   0.800000  0.727273  ...
#
#     eval_metric  pred_time_test  pred_time_val    fit_time  \
# 0       roc_auc        0.045908       0.025587    0.010863
# 1       roc_auc        0.048157       0.008531    2.188956
# 2       roc_auc        0.054676       0.026031    2.583066
# 3       roc_auc        0.073775       0.068091    6.523740
# 4       roc_auc        0.092265       0.093268    0.679659
# 5       roc_auc        0.126608       0.089975    0.862456
# 6       roc_auc        0.143184       0.029937    1.731863
# 7       roc_auc        0.143941       0.050559    6.274853
# 8       roc_auc        0.149678       0.080336    0.696637
# 9       roc_auc        0.161019       0.030780   24.100328
# 10      roc_auc        0.167808       0.080066    0.665504
# 11      roc_auc        0.195265       0.053144    3.043334
# 12      roc_auc        0.267368       0.027025    2.544211
# 13      roc_auc        0.277788       0.151157   20.737066
# 14      roc_auc        0.298697       0.013573    1.258840
# 15      roc_auc        0.802797       0.082139    6.075857
# 16      roc_auc        0.951643       0.461391   57.239456
# 17      roc_auc        3.894765       1.466951  109.557601
# 18      roc_auc        3.912750       1.462871  109.618982
# 19      roc_auc        3.941535       1.467644  109.613086
# 20      roc_auc        3.969034       1.410347  111.399053
# 21      roc_auc        3.992350       1.461579  109.606176
# 22      roc_auc        4.033853       1.413046  110.810300
# 23      roc_auc        4.117665       1.460133  154.953095
# 24      roc_auc        4.204113       1.507307  115.399594
# 25      roc_auc        4.443711       1.532058  117.421115
# 26      roc_auc        0.417411       0.089529    6.872006
# 27      roc_auc        0.299979       0.154438   22.063158
# 28      roc_auc        0.033807       0.234130    0.000000
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.045908                0.025587           0.010863
# 1                  0.048157                0.008531           2.188956
# 2                  0.054676                0.026031           2.583066
# 3                  0.073775                0.068091           6.523740
# 4                  0.092265                0.093268           0.679659
# 5                  0.126608                0.089975           0.862456
# 6                  0.143184                0.029937           1.731863
# 7                  0.143941                0.050559           6.274853
# 8                  0.149678                0.080336           0.696637
# 9                  0.161019                0.030780          24.100328
# 10                 0.167808                0.080066           0.665504
# 11                 0.195265                0.053144           3.043334
# 12                 0.267368                0.027025           2.544211
# 13                 0.277788                0.151157          20.737066
# 14                 0.298697                0.013573           1.258840
# 15                 0.802797                0.082139           6.075857
# 16                 0.002003                0.000000           0.100137
# 17                 0.094635                0.078655           0.645206
# 18                 0.112620                0.074575           0.706587
# 19                 0.141405                0.079349           0.700691
# 20                 0.168905                0.022051           2.486658
# 21                 0.192221                0.073284           0.693781
# 22                 0.233724                0.024751           1.897905
# 23                 0.317535                0.071838          46.040700
# 24                 0.403983                0.119012           6.487199
# 25                 0.005875                0.000000           0.123616
# 26                 0.417411                0.089529           6.872006
# 27                 0.299979                0.154438          22.063158
# 28                 0.033807                0.234130           0.000000
#
#     stack_level  can_infer  fit_order
# 0             1       True          2
# 1             1       True         13
# 2             1       True         16
# 3             1       True          7
# 4             1       True          9
# 5             1       True          5
# 6             1       True          4
# 7             1       True         14
# 8             1       True          8
# 9             1       True         18
# 10            1       True          6
# 11            1       True         19
# 12            1       True         11
# 13            1       True         12
# 14            1       True          3
# 15            1       True         10
# 16            2       True         20
# 17            2       True         27
# 18            2       True         26
# 19            2       True         23
# 20            2       True         22
# 21            2       True         24
# 22            2       True         21
# 23            2       True         25
# 24            2       True         28
# 25            3       True         29
# 26            1       True         17
# 27            1       True         15
# 28            1       True          1
#
# [29 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 67 features using 376 rows with 5 shuffle sets...
# 	289.64s	= Expected runtime (57.93s per shuffle set)
# 	44.92s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.CubCorsi.Inversos.PD                  0.041830  0.004261  0.000013  5
# TLP.Stroop.color.PD                       0.018187  0.002860  0.000071  5
# TLP.Tavec.01_RI-A5.PD                     0.006394  0.001524  0.000360  5
# ISC.FPacientes.Edad                       0.000685  0.000171  0.000434  5
# TLP.CubCorsi.Directos.PD                  0.000175  0.000197  0.058953  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Stroop.palabras.PD                    0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.CubCorsi.Inversos.PD                0.050603  0.033057
# TLP.Stroop.color.PD                     0.024077  0.012298
# TLP.Tavec.01_RI-A5.PD                   0.009533  0.003256
# ISC.FPacientes.Edad                     0.001038  0.000332
# TLP.CubCorsi.Directos.PD                0.000582 -0.000231
# ...                                          ...       ...
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Stroop.palabras.PD                  0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [67 rows x 6 columns]
