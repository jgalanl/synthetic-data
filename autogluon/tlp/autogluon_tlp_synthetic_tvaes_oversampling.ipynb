# %%
import pandas as pd

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-oversampling-tvaes.csv')

# %%
df.head()
# Out:
#    demo-genero demo-fechaEvaluacion demo-fechaNacimiento demo-rangoEdad  \
# 0            2  2024-02-22T00:00:00  1942-05-08T00:00:00         Rango3
# 1            2  2024-06-26T00:00:00  1948-10-07T00:00:00         Rango3
# 2            2  2024-05-14T00:00:00  1952-05-08T00:00:00         Rango2
# 3            2  2024-04-10T00:00:00  1964-01-27T00:00:00         Rango1
# 4            2  2024-05-14T00:00:00  1959-09-16T00:00:00         Rango1
#
#    demo-edad  clin-reservaCognitiva_total  clin-reservaCognitiva_idiomas  \
# 0         81                           12                              0
# 1         75                            8                              0
# 2         72                           11                              0
# 3         60                           18                              2
# 4         64                           13                              0
#
#    clin-reservaCognitiva_ocupacion  clin-reservaCognitiva_escolaridad  \
# 0                                1                                  3
# 1                                1                                  3
# 2                                0                                  4
# 3                                1                                  4
# 4                                1                                  4
#
#    clin-ansiedad  ...  eval-TLP-Tavec-25_Discriminabilidad-PD  \
# 0          False  ...                                   84.09
# 1           True  ...                                   79.55
# 2          False  ...                                   88.64
# 3          False  ...                                   90.91
# 4          False  ...                                   86.36
#
#    eval-TLP-Tavec-26_Sesgo-PD  eval-TLP-Tavec-27_RI_B_frente_RI_A1-PD  \
# 0                        0.14                                  -20.00
# 1                       -0.33                                  -71.43
# 2                       -0.60                                  -14.29
# 3                        0.60                                   60.00
# 4                       -0.71                                    0.00
#
#    eval-TLP-Tavec-28_RL_CP_frente_RI_A5-PD  \
# 0                                     0.00
# 1                                    12.50
# 2                                    75.00
# 3                                    16.67
# 4                                    66.67
#
#    eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD  \
# 0                                      33.33
# 1                                       0.00
# 2                                      25.00
# 3                                       0.00
# 4                                       0.00
#
#    eval-TLP-Tavec-30_RL_LP_frente_RL_CP-PD  \
# 0                                    37.50
# 1                                     0.00
# 2                                   -20.00
# 3                                    50.00
# 4                                   -33.33
#
#    eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD  \
# 0                                    -33.33
# 1                                      0.00
# 2                                      0.00
# 3                                    -20.00
# 4                                      0.00
#
#    eval-TLP-Tavec-32_Recon_Ac_frente_RL_LP-PD  \
# 0                                      -38.46
# 1                                      -20.00
# 2                                      -16.67
# 3                                      -50.00
# 4                                      -10.00
#
#    eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  ED_2Clases
# 0                                        -7.69           D
# 1                                       -20.00           D
# 2                                       -16.67           D
# 3                                       -37.50           D
# 4                                       -10.00           D
#
# [5 rows x 77 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((5196, 77), (1300, 77))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/tvaes/v4'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['high_quality'],
    time_limit = 2 * 3600,
    auto_stack = True,
    # excluded_model_types=['KNN','RF','XT', 'LR'],
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       8.28 GB / 15.94 GB (51.9%)
# Disk Space Avail:   81.28 GB / 446.36 GB (18.2%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-03 21:34:19,188	INFO worker.py:1762 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\tvaes\v4\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14912) Running DyStack sub-fit ...
# (_dystack pid=14912) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=14912) Beginning AutoGluon training ... Time limit = 1791s
# (_dystack pid=14912) AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\tvaes\v4\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14912) Train Data Rows:    4618
# (_dystack pid=14912) Train Data Columns: 76
# (_dystack pid=14912) Label Column:       ED_2Clases
# (_dystack pid=14912) Problem Type:       binary
# (_dystack pid=14912) Preprocessing data ...
# (_dystack pid=14912) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=14912) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=14912) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=14912) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=14912) Using Feature Generators to preprocess the data ...
# (_dystack pid=14912) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=14912) 	Available Memory:                    7820.66 MB
# (_dystack pid=14912) 	Train Data (Original)  Memory Usage: 3.24 MB (0.0% of available memory)
# (_dystack pid=14912) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=14912) 	Stage 1 Generators:
# (_dystack pid=14912) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=14912) 			Note: Converting 10 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=14912) 	Stage 2 Generators:
# (_dystack pid=14912) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=14912) 	Stage 3 Generators:
# (_dystack pid=14912) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=14912) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=14912) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=14912) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=14912) 	Stage 4 Generators:
# (_dystack pid=14912) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=14912) 	Stage 5 Generators:
# (_dystack pid=14912) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=14912) 	Useless Original Features (Count: 1): ['clin-Covid_sintomaSarpullido']
# (_dystack pid=14912) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=14912) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=14912) 		These features do not need to be present at inference time.
# (_dystack pid=14912) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=14912) 		('bool', [])                       :  8 | ['clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', 'clin-Hipercolesterolemia', ...]
# (_dystack pid=14912) 		('float', [])                      : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=14912) 		('int', [])                        : 49 | ['demo-genero', 'demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', ...]
# (_dystack pid=14912) 		('object', [])                     :  1 | ['demo-rangoEdad']
# (_dystack pid=14912) 		('object', ['datetime_as_object']) :  2 | ['demo-fechaEvaluacion', 'demo-fechaNacimiento']
# (_dystack pid=14912) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=14912) 		('category', [])             :  1 | ['demo-rangoEdad']
# (_dystack pid=14912) 		('float', [])                : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=14912) 		('int', [])                  : 47 | ['demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', 'clin-reservaCognitiva_escolaridad', ...]
# (_dystack pid=14912) 		('int', ['bool'])            : 10 | ['demo-genero', 'clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', ...]
# (_dystack pid=14912) 		('int', ['datetime_as_int']) :  9 | ['demo-fechaEvaluacion', 'demo-fechaEvaluacion.month', 'demo-fechaEvaluacion.day', 'demo-fechaEvaluacion.dayofweek', 'demo-fechaNacimiento', ...]
# (_dystack pid=14912) 	0.2s = Fit runtime
# (_dystack pid=14912) 	75 features in original data used to generate 82 features in processed data.
# (_dystack pid=14912) 	Train Data (Processed) Memory Usage: 2.55 MB (0.0% of available memory)
# (_dystack pid=14912) Data preprocessing and feature engineering runtime = 0.19s ...
# (_dystack pid=14912) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=14912) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=14912) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=14912) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=14912) User-specified model hyperparameters to be fit:
# (_dystack pid=14912) {
# (_dystack pid=14912) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=14912) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=14912) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=14912) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=14912) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=14912) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14912) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14912) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=14912) }
# (_dystack pid=14912) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=14912) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14912) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1193.83s of the 1791.18s of remaining time.
# (_dystack pid=14912) 	0.5182	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.02s	 = Training   runtime
# (_dystack pid=14912) 	0.17s	 = Validation runtime
# (_dystack pid=14912) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1190.65s of the 1788.00s of remaining time.
# (_dystack pid=14912) 	0.5254	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.02s	 = Training   runtime
# (_dystack pid=14912) 	0.04s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1190.55s of the 1787.90s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# (_dystack pid=14912) 	0.9048	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	4.07s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1182.52s of the 1779.87s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_dystack pid=14912) 	0.9045	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	4.1s	 = Training   runtime
# (_dystack pid=14912) 	0.14s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1173.88s of the 1771.23s of remaining time.
# (_dystack pid=14912) 	0.8749	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.37s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1172.20s of the 1769.55s of remaining time.
# (_dystack pid=14912) 	0.8763	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.89s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1171.02s of the 1768.37s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.63%)
# (_dystack pid=14912) 	0.9045	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	63.82s	 = Training   runtime
# (_dystack pid=14912) 	0.07s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1103.12s of the 1700.47s of remaining time.
# (_dystack pid=14912) 	0.8713	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.7s	 = Training   runtime
# (_dystack pid=14912) 	0.23s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1102.10s of the 1699.44s of remaining time.
# (_dystack pid=14912) 	0.8749	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.67s	 = Training   runtime
# (_dystack pid=14912) 	0.23s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1101.12s of the 1698.47s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_ray_fit pid=11036) No improvement since epoch 2: early stopping
# (_dystack pid=14912) 	0.876	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	10.67s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_BAG_L1 ... Training model for up to 1086.48s of the 1683.83s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# (_dystack pid=14912) 	0.9037	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.77s	 = Training   runtime
# (_dystack pid=14912) 	0.09s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1076.37s of the 1673.72s of remaining time.
# (_ray_fit pid=14012) No improvement since epoch 8: early stopping [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=14912) 	0.8742	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	17.65s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1054.42s of the 1651.78s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.14%)
# (_dystack pid=14912) 	0.8909	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	9.21s	 = Training   runtime
# (_dystack pid=14912) 	0.14s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1041.08s of the 1638.43s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_dystack pid=14912) 	0.9055	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	18.52s	 = Training   runtime
# (_dystack pid=14912) 	0.08s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1018.28s of the 1615.63s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=14912) 	0.8836	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	21.19s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 993.08s of the 1590.43s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# (_ray_fit pid=23528) [1000]	valid_set's binary_logloss: 0.358346
# (_dystack pid=14912) 	0.9053	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	8.32s	 = Training   runtime
# (_dystack pid=14912) 	0.42s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 980.76s of the 1578.11s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_ray_fit pid=1124) No improvement since epoch 0: early stopping
# (_dystack pid=14912) 	0.8657	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	17.57s	 = Training   runtime
# (_dystack pid=14912) 	0.28s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 958.83s of the 1556.18s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.74%)
# (_dystack pid=14912) 	0.9032	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	163.78s	 = Training   runtime
# (_dystack pid=14912) 	0.1s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 790.45s of the 1387.80s of remaining time.
# (_ray_fit pid=1856) No improvement since epoch 2: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# (_ray_fit pid=9124) [1000]	valid_set's binary_logloss: 0.430241 [repeated 8x across cluster]
# (_ray_fit pid=14692) [3000]	valid_set's binary_logloss: 0.371764 [repeated 21x across cluster]
# (_dystack pid=14912) 	0.908	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	9.23s	 = Training   runtime
# (_dystack pid=14912) 	1.31s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 777.17s of the 1374.52s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=14912) 	0.8771	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	23.6s	 = Training   runtime
# (_dystack pid=14912) 	0.21s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 749.38s of the 1346.73s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.67%)
# (_dystack pid=14912) 	0.8955	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	23.88s	 = Training   runtime
# (_dystack pid=14912) 	0.48s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 721.46s of the 1318.81s of remaining time.
# (_dystack pid=14912) 	0.8816	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.05s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 720.11s of the 1317.47s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_dystack pid=14912) 	0.9047	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	74.19s	 = Training   runtime
# (_dystack pid=14912) 	0.06s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 641.81s of the 1239.16s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_ray_fit pid=10304) No improvement since epoch 2: early stopping
# (_dystack pid=14912) 	0.8582	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	6.46s	 = Training   runtime
# (_dystack pid=14912) 	0.11s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 631.39s of the 1228.74s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.73%)
# (_dystack pid=14912) 	0.9065	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	120.56s	 = Training   runtime
# (_dystack pid=14912) 	0.07s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 506.26s of the 1103.61s of remaining time.
# (_ray_fit pid=12468) No improvement since epoch 3: early stopping
# (_dystack pid=14912) 	0.8727	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	3.41s	 = Training   runtime
# (_dystack pid=14912) 	0.21s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 502.56s of the 1099.91s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# (_dystack pid=14912) 	0.8979	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.59s	 = Training   runtime
# (_dystack pid=14912) 	0.19s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 493.01s of the 1090.35s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# (_ray_fit pid=8308) No improvement since epoch 0: early stopping
# (_dystack pid=14912) 	0.8726	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	18.11s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 470.45s of the 1067.80s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.69%)
# (_dystack pid=14912) 	0.9063	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.13s	 = Training   runtime
# (_dystack pid=14912) 	0.14s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 461.15s of the 1058.48s of remaining time.
# (_ray_fit pid=13452) No improvement since epoch 8: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=14912) 	0.88	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	29.01s	 = Training   runtime
# (_dystack pid=14912) 	0.23s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 427.81s of the 1025.16s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# (_dystack pid=14912) 	0.9053	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	3.45s	 = Training   runtime
# (_dystack pid=14912) 	0.15s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 420.28s of the 1017.63s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=14912) 	0.8755	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	16.31s	 = Training   runtime
# (_dystack pid=14912) 	0.21s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 399.68s of the 997.03s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_dystack pid=14912) 	0.9047	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	34.0s	 = Training   runtime
# (_dystack pid=14912) 	0.09s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 361.44s of the 958.80s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=10796) No improvement since epoch 10: early stopping
# (_dystack pid=14912) 	0.887	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	30.77s	 = Training   runtime
# (_dystack pid=14912) 	0.24s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 326.61s of the 923.96s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.53%)
# (_dystack pid=14912) 	0.8996	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	6.51s	 = Training   runtime
# (_dystack pid=14912) 	0.24s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 315.21s of the 912.56s of remaining time.
# (_ray_fit pid=8540) No improvement since epoch 10: early stopping
# (_dystack pid=14912) 	0.8805	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.06s	 = Training   runtime
# (_dystack pid=14912) 	0.24s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 313.85s of the 911.20s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# (_dystack pid=14912) 	0.9057	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	59.55s	 = Training   runtime
# (_dystack pid=14912) 	0.08s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 250.25s of the 847.60s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_ray_fit pid=10208) No improvement since epoch 0: early stopping
# (_dystack pid=14912) 	0.863	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	12.26s	 = Training   runtime
# (_dystack pid=14912) 	0.17s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 234.00s of the 831.35s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=14912) 	0.8912	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	10.42s	 = Training   runtime
# (_dystack pid=14912) 	0.19s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 219.36s of the 816.71s of remaining time.
# (_ray_fit pid=16308) No improvement since epoch 9: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.33%)
# (_dystack pid=14912) 	0.8937	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	14.99s	 = Training   runtime
# (_dystack pid=14912) 	0.47s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 199.88s of the 797.24s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=17100) No improvement since epoch 3: early stopping
# (_dystack pid=14912) 	0.8858	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	8.7s	 = Training   runtime
# (_dystack pid=14912) 	0.14s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 187.01s of the 784.36s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.80%)
# (_dystack pid=14912) 	0.9075	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	70.85s	 = Training   runtime
# (_dystack pid=14912) 	0.11s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 111.46s of the 708.81s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=14912) 	0.8869	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	8.64s	 = Training   runtime
# (_dystack pid=14912) 	0.1s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 98.22s of the 695.57s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.19%)
# (_ray_fit pid=16228) [1000]	valid_set's binary_logloss: 0.445681 [repeated 2x across cluster]
# (_ray_fit pid=16228) [2000]	valid_set's binary_logloss: 0.434876 [repeated 8x across cluster]
# (_ray_fit pid=4880) [3000]	valid_set's binary_logloss: 0.354462 [repeated 8x across cluster]
# (_dystack pid=14912) 	0.9017	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	21.85s	 = Training   runtime
# (_dystack pid=14912) 	2.37s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 71.82s of the 669.18s of remaining time.
# (_dystack pid=14912) 	0.8738	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	3.39s	 = Training   runtime
# (_dystack pid=14912) 	0.21s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 68.16s of the 665.51s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# (_dystack pid=14912) 	0.9028	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	46.75s	 = Training   runtime
# (_dystack pid=14912) 	0.09s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 17.24s of the 614.59s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=20920) No improvement since epoch 0: early stopping
# (_dystack pid=14912) 	0.8619	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	16.38s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 593.49s of remaining time.
# (_dystack pid=14912) 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.273, 'XGBoost_r89_BAG_L1': 0.182, 'XGBoost_BAG_L1': 0.136, 'NeuralNetTorch_r79_BAG_L1': 0.136, 'NeuralNetFastAI_r11_BAG_L1': 0.091, 'CatBoost_r70_BAG_L1': 0.091, 'KNeighborsDist_BAG_L1': 0.045, 'NeuralNetTorch_r14_BAG_L1': 0.045}
# (_dystack pid=14912) 	0.9155	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.26s	 = Training   runtime
# (_dystack pid=14912) 	0.0s	 = Validation runtime
# (_dystack pid=14912) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14912) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 593.22s of the 593.05s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# (_dystack pid=14912) 	0.9107	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	2.32s	 = Training   runtime
# (_dystack pid=14912) 	0.05s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_BAG_L2 ... Training model for up to 586.85s of the 586.68s of remaining time.
# (_ray_fit pid=6896) No improvement since epoch 5: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_dystack pid=14912) 	0.9067	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	3.28s	 = Training   runtime
# (_dystack pid=14912) 	0.04s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 579.00s of the 578.83s of remaining time.
# (_dystack pid=14912) 	0.9089	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.17s	 = Training   runtime
# (_dystack pid=14912) 	0.26s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 577.49s of the 577.32s of remaining time.
# (_dystack pid=14912) 	0.9112	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.0s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_BAG_L2 ... Training model for up to 576.18s of the 576.01s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# (_dystack pid=14912) 	0.9125	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	30.06s	 = Training   runtime
# (_dystack pid=14912) 	0.07s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 541.97s of the 541.80s of remaining time.
# (_dystack pid=14912) 	0.9104	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.68s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 540.97s of the 540.79s of remaining time.
# (_dystack pid=14912) 	0.9111	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.68s	 = Training   runtime
# (_dystack pid=14912) 	0.23s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 539.98s of the 539.81s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# (_ray_fit pid=4448) No improvement since epoch 1: early stopping
# (_dystack pid=14912) 	0.8978	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	9.88s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_BAG_L2 ... Training model for up to 526.13s of the 525.96s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.35%)
# (_dystack pid=14912) 	0.9064	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.53s	 = Training   runtime
# (_dystack pid=14912) 	0.05s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 515.75s of the 515.58s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_ray_fit pid=18548) No improvement since epoch 2: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	0.9047	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	13.36s	 = Training   runtime
# (_dystack pid=14912) 	0.23s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 498.00s of the 497.83s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.01%)
# (_dystack pid=14912) 	0.9035	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	10.3s	 = Training   runtime
# (_dystack pid=14912) 	0.05s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 483.14s of the 482.97s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.03%)
# (_dystack pid=14912) 	0.9109	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	12.35s	 = Training   runtime
# (_dystack pid=14912) 	0.06s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 466.30s of the 466.13s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=14912) 	0.9027	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	14.99s	 = Training   runtime
# (_dystack pid=14912) 	0.21s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 447.07s of the 446.89s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# (_dystack pid=14912) 	0.9078	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.97s	 = Training   runtime
# (_dystack pid=14912) 	0.14s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 436.67s of the 436.50s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.49%)
# (_ray_fit pid=17504) No improvement since epoch 1: early stopping
# (_dystack pid=14912) 	0.8932	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	18.21s	 = Training   runtime
# (_dystack pid=14912) 	0.25s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 414.17s of the 414.00s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.96%)
# (_dystack pid=14912) 	0.9118	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	125.03s	 = Training   runtime
# (_dystack pid=14912) 	0.07s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 284.20s of the 284.03s of remaining time.
# (_ray_fit pid=9204) No improvement since epoch 1: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=14912) 	0.9123	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	2.34s	 = Training   runtime
# (_dystack pid=14912) 	0.15s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 277.85s of the 277.68s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=14912) 	0.902	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	15.62s	 = Training   runtime
# (_dystack pid=14912) 	0.29s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 258.04s of the 257.87s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=7.46%)
# (_dystack pid=14912) 	0.9072	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	20.38s	 = Training   runtime
# (_dystack pid=14912) 	0.18s	 = Validation runtime
# (_dystack pid=14912) Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 233.13s of the 232.96s of remaining time.
# (_dystack pid=14912) 	0.9097	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	1.08s	 = Training   runtime
# (_dystack pid=14912) 	0.25s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 231.75s of the 231.58s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_dystack pid=14912) 	0.9126	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	17.75s	 = Training   runtime
# (_dystack pid=14912) 	0.07s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 209.80s of the 209.63s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_ray_fit pid=8088) No improvement since epoch 1: early stopping
# (_dystack pid=14912) 	0.8913	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	7.02s	 = Training   runtime
# (_dystack pid=14912) 	0.09s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 198.62s of the 198.44s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.88%)
# (_dystack pid=14912) 	0.9125	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	56.23s	 = Training   runtime
# (_dystack pid=14912) 	0.08s	 = Validation runtime
# (_dystack pid=14912) Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 137.56s of the 137.39s of remaining time.
# (_ray_fit pid=14716) No improvement since epoch 1: early stopping
# (_dystack pid=14912) 	0.9055	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	5.16s	 = Training   runtime
# (_dystack pid=14912) 	0.22s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 132.12s of the 131.94s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.46%)
# (_dystack pid=14912) 	0.9129	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	4.8s	 = Training   runtime
# (_dystack pid=14912) 	0.11s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 123.09s of the 122.92s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# (_ray_fit pid=1676) No improvement since epoch 0: early stopping
# (_dystack pid=14912) 	0.9006	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	15.88s	 = Training   runtime
# (_dystack pid=14912) 	0.24s	 = Validation runtime
# (_dystack pid=14912) Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 102.73s of the 102.55s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.37%)
# (_dystack pid=14912) 	0.9096	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	4.34s	 = Training   runtime
# (_dystack pid=14912) 	0.11s	 = Validation runtime
# (_ray_fit pid=12800) No improvement since epoch 1: early stopping [repeated 7x across cluster]
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 93.63s of the 93.46s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# (_dystack pid=14912) 	0.905	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	20.29s	 = Training   runtime
# (_dystack pid=14912) 	0.27s	 = Validation runtime
# (_dystack pid=14912) Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 68.95s of the 68.78s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.15%)
# (_dystack pid=14912) 	0.908	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	3.2s	 = Training   runtime
# (_dystack pid=14912) 	0.08s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 61.63s of the 61.46s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=14912) 	0.9049	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	13.72s	 = Training   runtime
# (_dystack pid=14912) 	0.25s	 = Validation runtime
# (_dystack pid=14912) Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 43.31s of the 43.14s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# (_dystack pid=14912) 	0.9119	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	19.71s	 = Training   runtime
# (_dystack pid=14912) 	0.11s	 = Validation runtime
# (_dystack pid=14912) Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 19.22s of the 19.04s of remaining time.
# (_dystack pid=14912) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_ray_fit pid=1636) 	Ran out of time, stopping training early. (Stopping on epoch 16)
# (_dystack pid=14912) 	0.8933	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	20.12s	 = Training   runtime
# (_dystack pid=14912) 	0.28s	 = Validation runtime
# (_dystack pid=14912) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -6.03s of remaining time.
# (_dystack pid=14912) 	Ensemble Weights: {'LightGBM_r188_BAG_L2': 0.4, 'CatBoost_BAG_L2': 0.16, 'CatBoost_r137_BAG_L2': 0.16, 'RandomForestEntr_BAG_L2': 0.12, 'ExtraTreesEntr_BAG_L2': 0.08, 'NeuralNetTorch_r30_BAG_L2': 0.08}
# (_dystack pid=14912) 	0.9141	 = Validation score   (roc_auc)
# (_dystack pid=14912) 	0.29s	 = Training   runtime
# (_dystack pid=14912) 	0.0s	 = Validation runtime
# (_dystack pid=14912) AutoGluon training complete, total runtime = 1797.71s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 254.8 rows/s (578 batch size)
# (_dystack pid=14912) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=14912) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=14912) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=14912) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=14912) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=14912) Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14912) 	0.02s	 = Training   runtime
# (_dystack pid=14912) 	0.17s	 = Validation runtime
# ...
# 	0.4s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.32s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.26s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.22s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	4.57s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.72s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.69s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	0.32s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	1.02s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	0.76s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	0.5s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	0.77s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	0.79s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.67s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	10.57s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	0.71s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	2.63s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.31s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	2.66s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.32s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	6.27s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	6.79s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	0.49s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	0.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L2_FULL ...
# 	1.31s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L2_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L2_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L2_FULL ...
# 	1.91s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	4.41s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L2_FULL ...
# 	0.33s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.35s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L2_FULL ...
# 	3.01s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.5s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L2_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L2_FULL ...
# 	2.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.97s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L2_FULL ...
# 	5.17s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.57s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_BAG_L2_FULL ...
# 	2.4s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	6.79s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_BAG_L2_FULL ...
# 	2.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.83s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_BAG_L2_FULL ...
# 	0.42s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_BAG_L2_FULL ...
# 	4.12s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_BAG_L2_FULL ...
# 	0.43s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L2_FULL ...
# 	9.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L2_FULL ...
# 	7.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.76s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_BAG_L2_FULL ...
# 	0.39s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_BAG_L2_FULL ...
# 	0.5s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.88s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_BAG_L2_FULL ...
# 	1.73s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	8.64s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.75s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	4.14s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_BAG_L2_FULL ...
# 	1.46s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_BAG_L2_FULL ...
# 	3.1s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 17.
# 	0.99s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_BAG_L2_FULL ...
# 	0.56s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.04s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 26.
# 	1.66s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_BAG_L2_FULL ...
# 	1.21s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_BAG_L2_FULL ...
# 	0.64s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_BAG_L2_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_BAG_L2_FULL ...
# 	1.06s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_BAG_L2_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_BAG_L2_FULL ...
# 	1.03s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.18s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.18s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_BAG_L2_FULL ...
# 	0.84s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_BAG_L2_FULL ...
# 	0.45s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r160_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	2.64s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r60_BAG_L2_FULL ...
# 	3.33s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	5.81s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r135_BAG_L2_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r22_BAG_L2_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r69_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.79s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r6_BAG_L2_FULL ...
# 	1.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r138_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.95s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r121_BAG_L2_FULL ...
# 	1.99s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r172_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.3s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r180_BAG_L2_FULL ...
# 	1.44s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r76_BAG_L2_FULL ...
# 	0.41s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	2.09s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r121_BAG_L2_FULL ...
# 	0.81s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r127_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.34s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	10.58s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r194_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 1.
# 	0.56s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r12_BAG_L2_FULL ...
# 	2.03s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r135_BAG_L2_FULL ...
# 	0.92s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r4_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	1.39s	 = Training   runtime
# Fitting model: ExtraTrees_r126_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.98s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r36_BAG_L2_FULL ...
# 	0.86s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r100_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	1.03s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r163_BAG_L2_FULL ...
# 	1.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r198_BAG_L2_FULL ...
# 	0.82s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r187_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r19_BAG_L2_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r95_BAG_L2_FULL ...
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r34_BAG_L2_FULL ...
# 	1.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r42_BAG_L2_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r1_BAG_L2_FULL ...
# 	0.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r89_BAG_L2_FULL ...
# 	1.02s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_r177_BAG_L2': 0.333, 'LightGBMXT_BAG_L2': 0.167, 'CatBoost_r12_BAG_L2': 0.167, 'XGBoost_r22_BAG_L2': 0.125, 'ExtraTreesEntr_BAG_L2': 0.083, 'CatBoost_r13_BAG_L2': 0.083, 'NeuralNetTorch_r87_BAG_L2': 0.042}
# 	0.4s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 545.65s ... Best model: "WeightedEnsemble_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\tvaes\v4")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                 WeightedEnsemble_L2   0.919472     roc_auc       2.756765  236.724258                0.000000           0.401107            2      False        111
# 1                 WeightedEnsemble_L3   0.919195     roc_auc       7.100462  541.890947                0.000000           0.399814            3      False        220
# 2                 CatBoost_r12_BAG_L2   0.918341     roc_auc       6.313657  413.874296                0.076711          40.364775            2      False        205
# 3                 CatBoost_r13_BAG_L2   0.918335     roc_auc       6.320304  455.220077                0.083358          81.710555            2      False        134
# 4                CatBoost_r177_BAG_L2   0.918316     roc_auc       6.295930  389.046456                0.058985          15.536935            2      False        123
# 5                 CatBoost_r60_BAG_L2   0.918156     roc_auc       6.280358  404.420829                0.043413          30.911308            2      False        189
# 6                CatBoost_r198_BAG_L2   0.918087     roc_auc       6.317836  390.826187                0.080890          17.316665            2      False        212
# 7                  CatBoost_r5_BAG_L2   0.918082     roc_auc       6.312251  383.533433                0.075305          10.023912            2      False        180
# 8                CatBoost_r137_BAG_L2   0.918068     roc_auc       6.294695  397.343282                0.057750          23.833761            2      False        132
# 9                CatBoost_r163_BAG_L2   0.918045     roc_auc       6.325611  394.593463                0.088665          21.083942            2      False        211
# 10               CatBoost_r143_BAG_L2   0.917896     roc_auc       6.334041  403.716340                0.097095          30.206819            2      False        183
# 11                    CatBoost_BAG_L2   0.917854     roc_auc       6.289966  414.007875                0.053020          40.498354            2      False        116
# 12                CatBoost_r49_BAG_L2   0.917841     roc_auc       6.310249  383.824239                0.073303          10.314718            2      False        164
# 13                CatBoost_r69_BAG_L2   0.917789     roc_auc       6.276373  403.120754                0.039427          29.611233            2      False        146
# 14                LightGBM_r96_BAG_L2   0.917713     roc_auc       6.403581  377.191095                0.166636           3.681573            2      False        128
# 15               CatBoost_r167_BAG_L2   0.917690     roc_auc       6.311529  416.777739                0.074583          43.268218            2      False        155
# 16               ExtraTrees_r4_BAG_L2   0.917672     roc_auc       6.482326  374.550129                0.245381           1.040607            2      False        175
# 17                CatBoost_r86_BAG_L2   0.917646     roc_auc       6.305447  456.859946                0.068501          83.350425            2      False        161
# 18                  LightGBMXT_BAG_L2   0.917602     roc_auc       6.298760  377.643157                0.061814           4.133636            2      False        112
# 19                CatBoost_r50_BAG_L2   0.917601     roc_auc       6.314754  399.553662                0.077808          26.044140            2      False        142
# 20                CatBoost_r70_BAG_L2   0.917423     roc_auc       6.300041  439.424449                0.063095          65.914927            2      False        151
# 21                 CatBoost_r9_BAG_L2   0.917408     roc_auc       6.329012  512.589169                0.092067         139.079648            2      False        127
# 22                LightGBM_r94_BAG_L2   0.917408     roc_auc       6.311764  376.884592                0.074819           3.375071            2      False        170
# 23               LightGBM_r196_BAG_L2   0.917324     roc_auc       6.900654  384.469388                0.663708          10.959867            2      False        153
# 24               CatBoost_r180_BAG_L2   0.917249     roc_auc       6.312572  420.596565                0.075626          47.087043            2      False        198
# 25            RandomForest_r34_BAG_L2   0.916992     roc_auc       6.475976  377.648505                0.239031           4.138984            2      False        169
# 26               CatBoost_r128_BAG_L2   0.916817     roc_auc       6.328796  458.057033                0.091851          84.547511            2      False        172
# 27                 XGBoost_r31_BAG_L2   0.916809     roc_auc       6.429096  383.706928                0.192151          10.197407            2      False        186
# 28                 CatBoost_r6_BAG_L2   0.916678     roc_auc       6.330254  396.763608                0.093308          23.254087            2      False        194
# 29                 XGBoost_r89_BAG_L2   0.916634     roc_auc       6.334250  379.466528                0.097304           5.957007            2      False        138
# 30                LightGBM_r15_BAG_L2   0.916346     roc_auc       6.333053  378.670663                0.096107           5.161141            2      False        159
# 31              ExtraTreesEntr_BAG_L2   0.916309     roc_auc       6.488129  374.197404                0.251183           0.687882            2      False        118
# 32                LightGBM_r42_BAG_L2   0.916176     roc_auc       6.303879  378.281414                0.066933           4.771892            2      False        217
# 33                 XGBoost_r22_BAG_L2   0.915966     roc_auc       6.333390  381.260535                0.096444           7.751013            2      False        192
# 34              ExtraTreesGini_BAG_L2   0.915829     roc_auc       6.479259  374.232107                0.242314           0.722586            2      False        117
# 35              ExtraTrees_r49_BAG_L2   0.915829     roc_auc       6.505555  374.390010                0.268609           0.880489            2      False        165
# 36             ExtraTrees_r126_BAG_L2   0.915809     roc_auc       6.476158  374.490925                0.239212           0.981404            2      False        208
# 37                LightGBM_r30_BAG_L2   0.915802     roc_auc       6.514060  382.495713                0.277114           8.986191            2      False        178
# 38                 XGBoost_r95_BAG_L2   0.915691     roc_auc       6.325881  380.560069                0.088936           7.050548            2      False        215
# 39                 XGBoost_r98_BAG_L2   0.915588     roc_auc       6.717097  402.923957                0.480151          29.414436            2      False        158
# 40               LightGBM_r130_BAG_L2   0.915497     roc_auc       6.301483  379.056333                0.064537           5.546812            2      False        140
# 41             ExtraTrees_r178_BAG_L2   0.915355     roc_auc       6.495704  374.689482                0.258758           1.179961            2      False        184
# 42            RandomForestEntr_BAG_L2   0.915236     roc_auc       6.481925  374.726587                0.244980           1.217066            2      False        115
# 43               LightGBM_r135_BAG_L2   0.915187     roc_auc       6.309447  381.400005                0.072501           7.890484            2      False        191
# 44                 XGBoost_r49_BAG_L2   0.915168     roc_auc       6.359234  385.396394                0.122288          11.886872            2      False        179
# 45               LightGBM_r188_BAG_L2   0.915166     roc_auc       6.290991  380.211371                0.054045           6.701850            2      False        136
# 46             ExtraTrees_r172_BAG_L2   0.915119     roc_auc       6.477209  374.860416                0.240263           1.350894            2      False        145
# 47           RandomForest_r166_BAG_L2   0.915068     roc_auc       6.514650  374.685916                0.277704           1.176395            2      False        185
# 48               LightGBM_r131_BAG_L2   0.914956     roc_auc       6.384787  381.934649                0.147841           8.425128            2      False        125
# 49            RandomForestGini_BAG_L2   0.914810     roc_auc       6.475692  374.765536                0.238746           1.256015            2      False        114
# 50             ExtraTrees_r197_BAG_L2   0.914720     roc_auc       6.497574  375.595720                0.260628           2.086199            2      False        200
# 51                 XGBoost_r34_BAG_L2   0.914697     roc_auc       6.377202  390.569210                0.140256          17.059689            2      False        216
# 52               LightGBM_r161_BAG_L2   0.914682     roc_auc       6.533782  392.509398                0.296836          18.999876            2      False        149
# 53                     XGBoost_BAG_L2   0.914516     roc_auc       6.348956  381.183420                0.112010           7.673899            2      False        120
# 54                    LightGBM_BAG_L2   0.914363     roc_auc       6.277745  378.926553                0.040799           5.417032            2      False        113
# 55               LightGBM_r121_BAG_L2   0.914222     roc_auc       6.483507  390.718008                0.246561          17.208487            2      False        196
# 56                 XGBoost_r33_BAG_L2   0.913831     roc_auc       6.418082  399.756409                0.181137          26.246888            2      False        130
# 57                XGBoost_r194_BAG_L2   0.913470     roc_auc       6.540004  382.565146                0.303058           9.055624            2      False        144
# 58           RandomForest_r127_BAG_L2   0.913358     roc_auc       6.492905  382.148945                0.255959           8.639424            2      False        167
# 59            RandomForest_r15_BAG_L2   0.913034     roc_auc       6.462408  379.323715                0.225462           5.814194            2      False        190
# 60          NeuralNetTorch_r87_BAG_L2   0.912998     roc_auc       6.471967  391.306336                0.235021          17.796815            2      False        181
# 61               LightGBM_r143_BAG_L2   0.912814     roc_auc       6.450838  394.596137                0.213892          21.086616            2      False        166
# 62                LightGBM_r96_BAG_L1   0.912613     roc_auc       1.249466   10.633429                1.249466          10.633429            1      False         19
# 63              ExtraTrees_r42_BAG_L2   0.912453     roc_auc       6.475752  374.818111                0.238806           1.308590            2      False        131
# 64          NeuralNetTorch_r14_BAG_L2   0.912396     roc_auc       6.472511  384.575965                0.235565          11.066443            2      False        148
# 65            RandomForest_r39_BAG_L2   0.912347     roc_auc       6.487514  380.297532                0.250568           6.788010            2      False        154
# 66               LightGBMLarge_BAG_L2   0.912317     roc_auc       6.317467  387.610403                0.080521          14.100882            2      False        122
# 67               CatBoost_r137_BAG_L1   0.911966     roc_auc       0.063214   83.288901                0.063214          83.288901            1      False         23
# 68        NeuralNetFastAI_r100_BAG_L2   0.911908     roc_auc       6.465180  394.161835                0.228234          20.652314            2      False        210
# 69                LightGBM_r94_BAG_L1   0.911812     roc_auc       0.458215    5.392070                0.458215           5.392070            1      False         61
# 70               CatBoost_r198_BAG_L1   0.911718     roc_auc       0.067609   28.978811                0.067609          28.978811            1      False        103
# 71           RandomForest_r195_BAG_L2   0.911580     roc_auc       6.480641  380.302382                0.243696           6.792861            2      False        135
# 72                CatBoost_r12_BAG_L1   0.911575     roc_auc       0.063330   51.881366                0.063330          51.881366            1      False         96
# 73        NeuralNetFastAI_r187_BAG_L2   0.911351     roc_auc       6.393081  383.221513                0.156136           9.711992            2      False        213
# 74        NeuralNetFastAI_r160_BAG_L2   0.911034     roc_auc       6.509601  391.660619                0.272655          18.151098            2      False        188
# 75           NeuralNetTorch_r1_BAG_L2   0.910811     roc_auc       6.521365  392.523546                0.284420          19.014025            2      False        218
# 76            RandomForest_r16_BAG_L2   0.910703     roc_auc       6.491318  384.092389                0.254372          10.582868            2      False        203
# 77                CatBoost_r49_BAG_L1   0.910630     roc_auc       0.078525   18.666705                0.078525          18.666705            1      False         55
# 78                 CatBoost_r5_BAG_L1   0.910610     roc_auc       0.054065   22.716133                0.054065          22.716133            1      False         71
# 79                CatBoost_r60_BAG_L1   0.910522     roc_auc       0.087243   65.398889                0.087243          65.398889            1      False         80
# 80              NeuralNetTorch_BAG_L2   0.910275     roc_auc       6.464208  389.273793                0.227263          15.764272            2      False        121
# 81                CatBoost_r69_BAG_L1   0.910120     roc_auc       0.081163   69.935800                0.081163          69.935800            1      False         37
# 82        NeuralNetFastAI_r143_BAG_L2   0.910055     roc_auc       6.358350  384.457757                0.121404          10.948236            2      False        150
# 83                    CatBoost_BAG_L1   0.909962     roc_auc       0.027615   66.888726                0.027615          66.888726            1      False          7
# 84          NeuralNetTorch_r41_BAG_L2   0.909808     roc_auc       6.456602  387.916022                0.219656          14.406501            2      False        157
# 85               CatBoost_r177_BAG_L1   0.909666     roc_auc       0.060149   21.651502                0.060149          21.651502            1      False         14
# 86                 CatBoost_r6_BAG_L1   0.909416     roc_auc       0.100333   34.764684                0.100333          34.764684            1      False         85
# 87                CatBoost_r13_BAG_L1   0.909383     roc_auc       0.069515  124.901051                0.069515         124.901051            1      False         25
# 88          NeuralNetTorch_r89_BAG_L2   0.909296     roc_auc       6.531877  395.665284                0.294931          22.155763            2      False        219
# 89               CatBoost_r163_BAG_L1   0.909188     roc_auc       0.055594   42.866894                0.055594          42.866894            1      False        102
# 90                CatBoost_r50_BAG_L1   0.909017     roc_auc       0.094150   39.200237                0.094150          39.200237            1      False         33
# 91                 XGBoost_r31_BAG_L1   0.908925     roc_auc       0.725731   28.611040                0.725731          28.611040            1      False         77
# 92         NeuralNetTorch_r185_BAG_L2   0.908732     roc_auc       6.446483  391.466781                0.209537          17.957259            2      False        187
# 93        NeuralNetFastAI_r103_BAG_L2   0.908627     roc_auc       6.438514  387.723471                0.201569          14.213949            2      False        147
# 94               CatBoost_r143_BAG_L1   0.908601     roc_auc       0.092499   28.405471                0.092499          28.405471            1      False         74
# 95          NeuralNetFastAI_r4_BAG_L2   0.908599     roc_auc       6.395676  386.715063                0.158731          13.205541            2      False        207
# 96         NeuralNetFastAI_r65_BAG_L2   0.908391     roc_auc       6.382977  385.966985                0.146032          12.457464            2      False        176
# 97        NeuralNetFastAI_r134_BAG_L2   0.908372     roc_auc       6.456232  393.032500                0.219286          19.522979            2      False        168
# 98                  LightGBMXT_BAG_L1   0.908357     roc_auc       0.237307    4.164191                0.237307           4.164191            1      False          3
# 99                LightGBM_r15_BAG_L1   0.908304     roc_auc       0.432128    8.285567                0.432128           8.285567            1      False         50
# 100                XGBoost_r89_BAG_L1   0.908273     roc_auc       0.117282    6.629622                0.117282           6.629622            1      False         29
# 101        NeuralNetTorch_r158_BAG_L2   0.908247     roc_auc       6.458951  421.706930                0.222005          48.197408            2      False        160
# 102       NeuralNetFastAI_r111_BAG_L2   0.908231     roc_auc       6.397765  384.741994                0.160819          11.232473            2      False        173
# 103        NeuralNetFastAI_r69_BAG_L2   0.908230     roc_auc       6.439993  389.637473                0.203048          16.127952            2      False        193
# 104         NeuralNetTorch_r36_BAG_L2   0.908213     roc_auc       6.461512  388.542835                0.224566          15.033314            2      False        209
# 105              CatBoost_r180_BAG_L1   0.907752     roc_auc       0.120440   47.853536                0.120440          47.853536            1      False         89
# 106        NeuralNetFastAI_r11_BAG_L2   0.907727     roc_auc       6.552378  407.639298                0.315433          34.129777            2      False        143
# 107              LightGBM_r131_BAG_L1   0.907718     roc_auc       0.497113   10.550071                0.497113          10.550071            1      False         16
# 108               CatBoost_r70_BAG_L1   0.907681     roc_auc       0.118206   80.300312                0.118206          80.300312            1      False         42
# 109                XGBoost_r22_BAG_L1   0.907622     roc_auc       0.140907    7.425091                0.140907           7.425091            1      False         83
# 110                CatBoost_r9_BAG_L1   0.907471     roc_auc       0.131711  171.745291                0.131711         171.745291            1      False         18
# 111               CatBoost_r86_BAG_L1   0.907391     roc_auc       0.083426  123.844661                0.083426         123.844661            1      False         52
# 112       NeuralNetFastAI_r156_BAG_L2   0.907357     roc_auc       6.389280  383.906123                0.152334          10.396602            2      False        152
# 113              CatBoost_r167_BAG_L1   0.907331     roc_auc       0.062413   57.630443                0.062413          57.630443            1      False         46
# 114         NeuralNetTorch_r30_BAG_L2   0.907171     roc_auc       6.494794  396.885990                0.257848          23.376469            2      False        139
# 115              CatBoost_r128_BAG_L1   0.906996     roc_auc       0.078034   89.113654                0.078034          89.113654            1      False         63
# 116         NeuralNetTorch_r79_BAG_L2   0.906981     roc_auc       6.457583  390.056340                0.220637          16.546818            2      False        124
# 117        NeuralNetTorch_r143_BAG_L2   0.906961     roc_auc       6.554923  401.927002                0.317977          28.417481            2      False        171
# 118              LightGBM_r130_BAG_L1   0.906961     roc_auc       0.173969    5.291632                0.173969           5.291632            1      False         31
# 119         NeuralNetTorch_r22_BAG_L2   0.906628     roc_auc       6.517282  393.220411                0.280336          19.710890            2      False        129
# 120                   LightGBM_BAG_L1   0.906601     roc_auc       0.168357    5.608344                0.168357           5.608344            1      False          4
# 121       NeuralNetFastAI_r145_BAG_L2   0.906497     roc_auc       6.522975  392.164603                0.286030          18.655082            2      False        137
# 122       NeuralNetFastAI_r194_BAG_L2   0.906366     roc_auc       6.382257  387.759423                0.145311          14.249902            2      False        204
# 123            NeuralNetFastAI_BAG_L2   0.906365     roc_auc       6.384567  385.075562                0.147622          11.566041            2      False        119
# 124         NeuralNetTorch_r86_BAG_L2   0.906331     roc_auc       6.493092  389.217218                0.256146          15.707696            2      False        141
# 125        NeuralNetTorch_r135_BAG_L2   0.906288     roc_auc       6.488514  393.501997                0.251568          19.992476            2      False        206
# 126        NeuralNetTorch_r121_BAG_L2   0.906119     roc_auc       6.550342  402.509589                0.313397          29.000068            2      False        201
# 127                XGBoost_r95_BAG_L1   0.905904     roc_auc       0.186651    7.604901                0.186651           7.604901            1      False        106
# 128        NeuralNetFastAI_r88_BAG_L2   0.905578     roc_auc       6.387830  383.357748                0.150884           9.848227            2      False        177
# 129         NeuralNetTorch_r31_BAG_L2   0.905574     roc_auc       6.477316  389.734891                0.240370          16.225370            2      False        174
# 130         NeuralNetTorch_r19_BAG_L2   0.905513     roc_auc       6.413650  384.767416                0.176705          11.257895            2      False        214
# 131        NeuralNetFastAI_r37_BAG_L2   0.905506     roc_auc       6.426192  388.037529                0.189246          14.528008            2      False        162
# 132              LightGBM_r196_BAG_L1   0.905472     roc_auc       3.154360   24.902352                3.154360          24.902352            1      False         44
# 133              LightGBM_r135_BAG_L1   0.905424     roc_auc       0.222655    6.784781                0.222655           6.784781            1      False         82
# 134       NeuralNetFastAI_r172_BAG_L2   0.905012     roc_auc       6.390045  383.812068                0.153099          10.302547            2      False        197
# 135         NeuralNetTorch_r71_BAG_L2   0.904706     roc_auc       6.508916  385.051628                0.271971          11.542107            2      False        182
# 136        NeuralNetFastAI_r95_BAG_L2   0.904555     roc_auc       6.517178  393.696833                0.280232          20.187312            2      False        156
# 137               LightGBM_r30_BAG_L1   0.904401     roc_auc       0.972709   15.051819                0.972709          15.051819            1      False         69
# 138                XGBoost_r49_BAG_L1   0.904028     roc_auc       0.192275   11.990973                0.192275          11.990973            1      False         70
# 139                XGBoost_r98_BAG_L1   0.903593     roc_auc       0.700598   45.489384                0.700598          45.489384            1      False         49
# 140         NeuralNetTorch_r76_BAG_L2   0.903432     roc_auc       6.454765  385.600924                0.217819          12.091403            2      False        199
# 141                    XGBoost_BAG_L1   0.903268     roc_auc       0.143004    7.620477                0.143004           7.620477            1      False         11
# 142       NeuralNetFastAI_r138_BAG_L2   0.903024     roc_auc       6.642748  402.008601                0.405802          28.499080            2      False        195
# 143              LightGBM_r188_BAG_L1   0.902327     roc_auc       0.261304    8.002394                0.261304           8.002394            1      False         27
# 144                XGBoost_r34_BAG_L1   0.901948     roc_auc       0.406684   16.852137                0.406684          16.852137            1      False        107
# 145       NeuralNetFastAI_r191_BAG_L2   0.901874     roc_auc       6.523631  395.256784                0.286685          21.747263            2      False        126
# 146        NeuralNetTorch_r197_BAG_L2   0.901185     roc_auc       6.494785  385.846254                0.257839          12.336733            2      False        163
# 147               XGBoost_r194_BAG_L1   0.900367     roc_auc       0.258740    7.610815                0.258740           7.610815            1      False         35
# 148                XGBoost_r33_BAG_L1   0.899254     roc_auc       0.597452   27.587072                0.597452          27.587072            1      False         21
# 149              LightGBM_r143_BAG_L1   0.898782     roc_auc       0.378993   15.221269                0.378993          15.221269            1      False         57
# 150              LightGBM_r121_BAG_L1   0.897233     roc_auc       0.565540   15.916666                0.565540          15.916666            1      False         87
# 151              LightGBM_r161_BAG_L1   0.896275     roc_auc       0.637604   17.450469                0.637604          17.450469            1      False         40
# 152       NeuralNetFastAI_r143_BAG_L1   0.895580     roc_auc       0.112685   10.923144                0.112685          10.923144            1      False         41
# 153       NeuralNetFastAI_r127_BAG_L2   0.895554     roc_auc       6.391075  382.645657                0.154130           9.136136            2      False        202
# 154               LightGBM_r42_BAG_L1   0.895455     roc_auc       0.150105    5.084504                0.150105           5.084504            1      False        108
# 155         NeuralNetTorch_r14_BAG_L1   0.894868     roc_auc       0.230294   13.088911                0.230294          13.088911            1      False         39
# 156         NeuralNetTorch_r87_BAG_L1   0.894665     roc_auc       0.171259   37.734231                0.171259          37.734231            1      False         72
# 157              LightGBMLarge_BAG_L1   0.893772     roc_auc       0.112077   10.831208                0.112077          10.831208            1      False         13
# 158       NeuralNetFastAI_r102_BAG_L2   0.893742     roc_auc       6.370869  382.605274                0.133924           9.095753            2      False        133
# 159       NeuralNetFastAI_r100_BAG_L1   0.893128     roc_auc       0.206149   22.818506                0.206149          22.818506            1      False        101
# 160       NeuralNetFastAI_r156_BAG_L1   0.892860     roc_auc       0.103636   11.033692                0.103636          11.033692            1      False         43
# 161        NeuralNetTorch_r143_BAG_L1   0.891780     roc_auc       0.258519   43.152085                0.258519          43.152085            1      False         62
# 162         NeuralNetTorch_r36_BAG_L1   0.891764     roc_auc       0.162252   23.062568                0.162252          23.062568            1      False        100
# 163         NeuralNetTorch_r79_BAG_L1   0.890631     roc_auc       0.239867   20.486135                0.239867          20.486135            1      False         15
# 164         NeuralNetTorch_r89_BAG_L1   0.889872     roc_auc       0.246512   25.133983                0.246512          25.133983            1      False        110
# 165         NeuralNetTorch_r30_BAG_L1   0.887676     roc_auc       0.244648   27.766774                0.244648          27.766774            1      False         30
# 166         NeuralNetTorch_r41_BAG_L1   0.887643     roc_auc       0.208956   17.867480                0.208956          17.867480            1      False         48
# 167         NeuralNetTorch_r19_BAG_L1   0.887090     roc_auc       0.232076   11.900025                0.232076          11.900025            1      False        105
# 168        NeuralNetTorch_r135_BAG_L1   0.887087     roc_auc       0.261257   23.946909                0.261257          23.946909            1      False         97
# 169       NeuralNetFastAI_r160_BAG_L1   0.886431     roc_auc       0.226722   17.397933                0.226722          17.397933            1      False         79
# 170         NeuralNetFastAI_r4_BAG_L1   0.886292     roc_auc       0.164172   13.714572                0.164172          13.714572            1      False         98
# 171         NeuralNetTorch_r76_BAG_L1   0.886174     roc_auc       0.208350   12.016557                0.208350          12.016557            1      False         90
# 172          NeuralNetTorch_r1_BAG_L1   0.884358     roc_auc       0.276816   24.099575                0.276816          24.099575            1      False        109
# 173         NeuralNetTorch_r71_BAG_L1   0.884099     roc_auc       0.229153   11.124984                0.229153          11.124984            1      False         73
# 174         NeuralNetTorch_r22_BAG_L1   0.883574     roc_auc       0.271640   29.885484                0.271640          29.885484            1      False         20
# 175       NeuralNetFastAI_r187_BAG_L1   0.883262     roc_auc       0.086929   10.412566                0.086929          10.412566            1      False        104
# 176        NeuralNetTorch_r197_BAG_L1   0.883081     roc_auc       0.273115   11.899079                0.273115          11.899079            1      False         54
# 177            ExtraTrees_r197_BAG_L1   0.883047     roc_auc       0.248990    2.044422                0.248990           2.044422            1       True         91
# 178             ExtraTrees_r42_BAG_L1   0.882825     roc_auc       0.247468    1.198399                0.247468           1.198399            1       True         22
# 179            ExtraTrees_r172_BAG_L1   0.882657     roc_auc       0.222702    1.319585                0.222702           1.319585            1       True         36
# 180       NeuralNetFastAI_r134_BAG_L1   0.882246     roc_auc       0.212857   19.548813                0.212857          19.548813            1      False         59
# 181            ExtraTrees_r178_BAG_L1   0.881521     roc_auc       0.236247    1.081567                0.236247           1.081567            1       True         75
# 182        NeuralNetTorch_r121_BAG_L1   0.880685     roc_auc       0.235817   34.846045                0.235817          34.846045            1      False         92
# 183        NeuralNetFastAI_r11_BAG_L1   0.880013     roc_auc       0.360397   34.657793                0.360397          34.657793            1      False         34
# 184       NeuralNetFastAI_r138_BAG_L1   0.879521     roc_auc       0.355342   28.110550                0.355342          28.110550            1      False         86
# 185       NeuralNetFastAI_r194_BAG_L1   0.879070     roc_auc       0.169349   14.053221                0.169349          14.053221            1      False         95
# 186        NeuralNetFastAI_r65_BAG_L1   0.878871     roc_auc       0.094574   11.433632                0.094574          11.433632            1      False         67
# 187             NeuralNetTorch_BAG_L1   0.878367     roc_auc       0.264351   18.595189                0.264351          18.595189            1      False         12
# 188           RandomForestEntr_BAG_L1   0.878337     roc_auc       0.278063    1.003040                0.278063           1.003040            1       True          6
# 189           RandomForestGini_BAG_L1   0.878000     roc_auc       0.269894    1.076370                0.269894           1.076370            1       True          5
# 190        NeuralNetTorch_r185_BAG_L1   0.877799     roc_auc       0.249209   26.150457                0.249209          26.150457            1      False         78
# 191         NeuralNetTorch_r31_BAG_L1   0.877727     roc_auc       0.217679   17.731112                0.217679          17.731112            1      False         65
# 192        NeuralNetFastAI_r37_BAG_L1   0.877367     roc_auc       0.172211   13.989241                0.172211          13.989241            1      False         53
# 193       NeuralNetFastAI_r111_BAG_L1   0.877231     roc_auc       0.106615   10.229863                0.106615          10.229863            1      False         64
# 194         NeuralNetTorch_r86_BAG_L1   0.877109     roc_auc       0.227216   19.796156                0.227216          19.796156            1      False         32
# 195        NeuralNetTorch_r158_BAG_L1   0.876819     roc_auc       0.236924   27.794993                0.236924          27.794993            1      False         51
# 196        NeuralNetFastAI_r69_BAG_L1   0.876508     roc_auc       0.190389   15.611173                0.190389          15.611173            1      False         84
# 197       NeuralNetFastAI_r102_BAG_L1   0.875448     roc_auc       0.129328    8.588439                0.129328           8.588439            1      False         24
# 198       NeuralNetFastAI_r145_BAG_L1   0.875350     roc_auc       0.262942   20.796398                0.262942          20.796398            1      False         28
# 199          RandomForest_r166_BAG_L1   0.875142     roc_auc       0.239937    1.062403                0.239937           1.062403            1       True         76
# 200             ExtraTreesEntr_BAG_L1   0.874846     roc_auc       0.238664    0.684362                0.238664           0.684362            1       True          9
# 201       NeuralNetFastAI_r172_BAG_L1   0.873404     roc_auc       0.142384    9.994749                0.142384           9.994749            1      False         88
# 202            ExtraTrees_r126_BAG_L1   0.872926     roc_auc       0.271184    1.029004                0.271184           1.029004            1       True         99
# 203            NeuralNetFastAI_BAG_L1   0.872045     roc_auc       0.158726   12.348397                0.158726          12.348397            1      False         10
# 204       NeuralNetFastAI_r191_BAG_L1   0.871875     roc_auc       0.253673   23.410695                0.253673          23.410695            1      False         17
# 205       NeuralNetFastAI_r127_BAG_L1   0.871180     roc_auc       0.120921    9.123521                0.120921           9.123521            1      False         93
# 206           RandomForest_r39_BAG_L1   0.871030     roc_auc       0.229371    3.836800                0.229371           3.836800            1       True         45
# 207        NeuralNetFastAI_r88_BAG_L1   0.870873     roc_auc       0.071980    9.471956                0.071980           9.471956            1      False         68
# 208             ExtraTreesGini_BAG_L1   0.870861     roc_auc       0.232699    0.709110                0.232699           0.709110            1       True          8
# 209             ExtraTrees_r49_BAG_L1   0.870861     roc_auc       0.235629    0.876134                0.235629           0.876134            1       True         56
# 210          RandomForest_r195_BAG_L1   0.870354     roc_auc       0.241189    3.903375                0.241189           3.903375            1       True         26
# 211        NeuralNetFastAI_r95_BAG_L1   0.870009     roc_auc       0.281679   17.972782                0.281679          17.972782            1      False         47
# 212       NeuralNetFastAI_r103_BAG_L1   0.869890     roc_auc       0.216473   12.877488                0.216473          12.877488            1      False         38
# 213           RandomForest_r15_BAG_L1   0.869593     roc_auc       0.233025    3.362018                0.233025           3.362018            1       True         81
# 214              ExtraTrees_r4_BAG_L1   0.869499     roc_auc       0.216688    0.901977                0.216688           0.901977            1       True         66
# 215          RandomForest_r127_BAG_L1   0.868596     roc_auc       0.224837    4.541658                0.224837           4.541658            1       True         58
# 216           RandomForest_r16_BAG_L1   0.868096     roc_auc       0.247603    6.191916                0.247603           6.191916            1       True         94
# 217           RandomForest_r34_BAG_L1   0.853267     roc_auc       0.225985    2.088207                0.225985           2.088207            1       True         60
# 218             KNeighborsDist_BAG_L1   0.508479     roc_auc       0.064372    0.016845                0.064372           0.016845            1       True          2
# 219             KNeighborsUnif_BAG_L1   0.506642     roc_auc       0.459918    0.033367                0.459918           0.033367            1       True          1
# 220        KNeighborsDist_BAG_L1_FULL        NaN     roc_auc       0.064372    0.016845                0.064372           0.016845            1       True        222
# 221         ExtraTrees_r4_BAG_L1_FULL        NaN     roc_auc       0.216688    0.901977                0.216688           0.901977            1       True        286
# 222       ExtraTrees_r172_BAG_L1_FULL        NaN     roc_auc       0.222702    1.319585                0.222702           1.319585            1       True        256
# 223     RandomForest_r127_BAG_L1_FULL        NaN     roc_auc       0.224837    4.541658                0.224837           4.541658            1       True        278
# 224      RandomForest_r34_BAG_L1_FULL        NaN     roc_auc       0.225985    2.088207                0.225985           2.088207            1       True        280
# 225      RandomForest_r39_BAG_L1_FULL        NaN     roc_auc       0.229371    3.836800                0.229371           3.836800            1       True        265
# 226        ExtraTreesGini_BAG_L1_FULL        NaN     roc_auc       0.232699    0.709110                0.232699           0.709110            1       True        228
# 227      RandomForest_r15_BAG_L1_FULL        NaN     roc_auc       0.233025    3.362018                0.233025           3.362018            1       True        301
# 228        ExtraTrees_r49_BAG_L1_FULL        NaN     roc_auc       0.235629    0.876134                0.235629           0.876134            1       True        276
# 229       ExtraTrees_r178_BAG_L1_FULL        NaN     roc_auc       0.236247    1.081567                0.236247           1.081567            1       True        295
# 230        ExtraTreesEntr_BAG_L1_FULL        NaN     roc_auc       0.238664    0.684362                0.238664           0.684362            1       True        229
# 231     RandomForest_r166_BAG_L1_FULL        NaN     roc_auc       0.239937    1.062403                0.239937           1.062403            1       True        296
# 232     RandomForest_r195_BAG_L1_FULL        NaN     roc_auc       0.241189    3.903375                0.241189           3.903375            1       True        246
# 233        ExtraTrees_r42_BAG_L1_FULL        NaN     roc_auc       0.247468    1.198399                0.247468           1.198399            1       True        242
# 234      RandomForest_r16_BAG_L1_FULL        NaN     roc_auc       0.247603    6.191916                0.247603           6.191916            1       True        314
# 235       ExtraTrees_r197_BAG_L1_FULL        NaN     roc_auc       0.248990    2.044422                0.248990           2.044422            1       True        311
# 236      RandomForestGini_BAG_L1_FULL        NaN     roc_auc       0.269894    1.076370                0.269894           1.076370            1       True        225
# 237       ExtraTrees_r126_BAG_L1_FULL        NaN     roc_auc       0.271184    1.029004                0.271184           1.029004            1       True        319
# 238      RandomForestEntr_BAG_L1_FULL        NaN     roc_auc       0.278063    1.003040                0.278063           1.003040            1       True        226
# 239        KNeighborsUnif_BAG_L1_FULL        NaN     roc_auc       0.459918    0.033367                0.459918           0.033367            1       True        221
# 240           XGBoost_r98_BAG_L2_FULL        NaN     roc_auc            NaN   75.564816                     NaN           4.116927            2       True        378
# 241           XGBoost_r98_BAG_L1_FULL        NaN     roc_auc            NaN    7.660960                     NaN           7.660960            1       True        269
# 242           XGBoost_r95_BAG_L2_FULL        NaN     roc_auc            NaN   71.723581                     NaN           0.275693            2       True        435
# 243           XGBoost_r95_BAG_L1_FULL        NaN     roc_auc            NaN    0.676721                     NaN           0.676721            1       True        326
# 244           XGBoost_r89_BAG_L2_FULL        NaN     roc_auc            NaN   71.682211                     NaN           0.234322            2       True        358
# 245           XGBoost_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.534260                     NaN           0.534260            1       True        249
# 246           XGBoost_r49_BAG_L2_FULL        NaN     roc_auc            NaN   72.092485                     NaN           0.644597            2       True        399
# 247           XGBoost_r49_BAG_L1_FULL        NaN     roc_auc            NaN    1.204436                     NaN           1.204436            1       True        290
# 248           XGBoost_r34_BAG_L2_FULL        NaN     roc_auc            NaN   72.821193                     NaN           1.373305            2       True        436
# 249           XGBoost_r34_BAG_L1_FULL        NaN     roc_auc            NaN    2.286829                     NaN           2.286829            1       True        327
# 250           XGBoost_r33_BAG_L2_FULL        NaN     roc_auc            NaN   74.074200                     NaN           2.626312            2       True        350
# 251           XGBoost_r33_BAG_L1_FULL        NaN     roc_auc            NaN    4.399263                     NaN           4.399263            1       True        241
# 252           XGBoost_r31_BAG_L2_FULL        NaN     roc_auc            NaN   72.284853                     NaN           0.836965            2       True        406
# 253           XGBoost_r31_BAG_L1_FULL        NaN     roc_auc            NaN    3.684691                     NaN           3.684691            1       True        297
# 254           XGBoost_r22_BAG_L2_FULL        NaN     roc_auc            NaN   71.731452                     NaN           0.283564            2       True        412
# 255           XGBoost_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.537760                     NaN           0.537760            1       True        303
# 256          XGBoost_r194_BAG_L2_FULL        NaN     roc_auc            NaN   71.782199                     NaN           0.334311            2       True        364
# 257          XGBoost_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.554699                     NaN           0.554699            1       True        255
# 258               XGBoost_BAG_L2_FULL        NaN     roc_auc            NaN   71.726414                     NaN           0.278526            2       True        340
# 259               XGBoost_BAG_L1_FULL        NaN     roc_auc            NaN    0.693469                     NaN           0.693469            1       True        231
# 260          WeightedEnsemble_L3_FULL        NaN     roc_auc            NaN   82.970808                     NaN           0.399814            3       True        440
# 261          WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN   48.129128                     NaN           0.401107            2       True        331
# 262      RandomForest_r39_BAG_L2_FULL        NaN     roc_auc            NaN   78.235899                0.250568           6.788010            2       True        374
# 263      RandomForest_r34_BAG_L2_FULL        NaN     roc_auc            NaN   75.586873                0.239031           4.138984            2       True        389
# 264     RandomForest_r195_BAG_L2_FULL        NaN     roc_auc            NaN   78.240749                0.243696           6.792861            2       True        355
# 265      RandomForest_r16_BAG_L2_FULL        NaN     roc_auc            NaN   82.030756                0.254372          10.582868            2       True        423
# 266     RandomForest_r166_BAG_L2_FULL        NaN     roc_auc            NaN   72.624283                0.277704           1.176395            2       True        405
# 267      RandomForest_r15_BAG_L2_FULL        NaN     roc_auc            NaN   77.262082                0.225462           5.814194            2       True        410
# 268     RandomForest_r127_BAG_L2_FULL        NaN     roc_auc            NaN   80.087312                0.255959           8.639424            2       True        387
# 269      RandomForestGini_BAG_L2_FULL        NaN     roc_auc            NaN   72.703903                0.238746           1.256015            2       True        334
# 270      RandomForestEntr_BAG_L2_FULL        NaN     roc_auc            NaN   72.664954                0.244980           1.217066            2       True        335
# 271    NeuralNetTorch_r89_BAG_L2_FULL        NaN     roc_auc            NaN   72.472610                     NaN           1.024722            2       True        439
# 272    NeuralNetTorch_r89_BAG_L1_FULL        NaN     roc_auc            NaN    2.155893                     NaN           2.155893            1       True        330
# 273    NeuralNetTorch_r87_BAG_L2_FULL        NaN     roc_auc            NaN   72.509970                     NaN           1.062082            2       True        401
# 274    NeuralNetTorch_r87_BAG_L1_FULL        NaN     roc_auc            NaN    5.903068                     NaN           5.903068            1       True        292
# 275    NeuralNetTorch_r86_BAG_L2_FULL        NaN     roc_auc            NaN   71.862742                     NaN           0.414854            2       True        361
# 276    NeuralNetTorch_r86_BAG_L1_FULL        NaN     roc_auc            NaN    1.380073                     NaN           1.380073            1       True        252
# 277    NeuralNetTorch_r79_BAG_L2_FULL        NaN     roc_auc            NaN   72.216692                     NaN           0.768804            2       True        344
# 278    NeuralNetTorch_r79_BAG_L1_FULL        NaN     roc_auc            NaN    2.516644                     NaN           2.516644            1       True        235
# 279    NeuralNetTorch_r76_BAG_L2_FULL        NaN     roc_auc            NaN   71.854493                     NaN           0.406604            2       True        419
# 280    NeuralNetTorch_r76_BAG_L1_FULL        NaN     roc_auc            NaN    0.642148                     NaN           0.642148            1       True        310
# 281    NeuralNetTorch_r71_BAG_L2_FULL        NaN     roc_auc            NaN   71.695244                     NaN           0.247355            2       True        402
# 282    NeuralNetTorch_r71_BAG_L1_FULL        NaN     roc_auc            NaN    0.577408                     NaN           0.577408            1       True        293
# 283    NeuralNetTorch_r41_BAG_L2_FULL        NaN     roc_auc            NaN   71.865299                     NaN           0.417411            2       True        377
# 284    NeuralNetTorch_r41_BAG_L1_FULL        NaN     roc_auc            NaN    1.969422                     NaN           1.969422            1       True        268
# 285    NeuralNetTorch_r36_BAG_L2_FULL        NaN     roc_auc            NaN   72.304824                     NaN           0.856936            2       True        429
# 286    NeuralNetTorch_r36_BAG_L1_FULL        NaN     roc_auc            NaN    4.127214                     NaN           4.127214            1       True        320
# ...
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3_FULL': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L2   0.919472     roc_auc       2.756765
#  1          WeightedEnsemble_L3   0.919195     roc_auc       7.100462
#  2          CatBoost_r12_BAG_L2   0.918341     roc_auc       6.313657
#  3          CatBoost_r13_BAG_L2   0.918335     roc_auc       6.320304
#  4         CatBoost_r177_BAG_L2   0.918316     roc_auc       6.295930
#  ..                         ...        ...         ...            ...
#  435   CatBoost_r12_BAG_L1_FULL        NaN     roc_auc            NaN
#  436  CatBoost_r128_BAG_L2_FULL        NaN     roc_auc            NaN
#  437  CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN
#  438       CatBoost_BAG_L2_FULL        NaN     roc_auc            NaN
#  439       CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    236.724258                0.000000           0.401107            2
#  1    541.890947                0.000000           0.399814            3
#  2    413.874296                0.076711          40.364775            2
#  3    455.220077                0.083358          81.710555            2
#  4    389.046456                0.058985          15.536935            2
#  ..          ...                     ...                ...          ...
#  435    6.879847                     NaN           6.879847            1
#  436   74.544274                     NaN           3.096385            2
#  437    8.855392                     NaN           8.855392            1
#  438   76.022411                     NaN           4.574523            2
#  439   20.407590                     NaN          20.407590            1
#
#       can_infer  fit_order
#  0        False        111
#  1        False        220
#  2        False        205
#  3        False        134
#  4        False        123
#  ..         ...        ...
#  435       True        316
#  436       True        392
#  437       True        283
#  438       True        336
#  439       True        227
#
#  [440 rows x 10 columns]}

# %%
auxiliary_metrics = ['accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9174161257527176
# Evaluations on test data:
# {
#     "roc_auc": 0.9174161257527176,
#     "accuracy": 0.8476923076923077,
#     "balanced_accuracy": 0.8482644541923497,
#     "mcc": 0.6961133153549074,
#     "f1": 0.8455538221528861,
#     "precision": 0.8274809160305343,
#     "recall": 0.8644338118022329
# }
# {'roc_auc': 0.9174161257527176,
#  'accuracy': 0.8476923076923077,
#  'balanced_accuracy': 0.8482644541923497,
#  'mcc': 0.6961133153549074,
#  'f1': 0.8455538221528861,
#  'precision': 0.8274809160305343,
#  'recall': 0.8644338118022329}

# %%
predictor.model_best
# Out:
# 'WeightedEnsemble_L2_FULL'

# %%
predictors = predictor.leaderboard(
    df_test,
    extra_metrics = auxiliary_metrics,
    extra_info=True,
    silent=True
)

# %%
predictors[['model', 'roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall', 'num_features']]
# Out:
#                                model   roc_auc  accuracy  balanced_accuracy  \
# 0          LightGBM_r188_BAG_L2_FULL  0.918639  0.842308           0.843391
# 1    NeuralNetTorch_r158_BAG_L2_FULL  0.918054  0.840000           0.838873
# 2           LightGBM_r96_BAG_L2_FULL  0.917781  0.843846           0.844768
# 3          LightGBM_r196_BAG_L2_FULL  0.917764  0.845385           0.846581
# 4           LightGBM_r30_BAG_L2_FULL  0.917722  0.846154           0.847215
# ..                               ...       ...       ...                ...
# 435      NeuralNetFastAI_r191_BAG_L1       NaN       NaN                NaN
# 436      NeuralNetFastAI_r127_BAG_L1       NaN       NaN                NaN
# 437       NeuralNetFastAI_r88_BAG_L1       NaN       NaN                NaN
# 438       NeuralNetFastAI_r95_BAG_L1       NaN       NaN                NaN
# 439      NeuralNetFastAI_r103_BAG_L1       NaN       NaN                NaN
#
#            f1  precision    recall  num_features
# 0    0.842429   0.813056  0.874003           105
# 1    0.829508   0.853288  0.807018           105
# 2    0.843243   0.817365  0.870813           105
# 3    0.845977   0.814159  0.880383           105
# 4    0.846154   0.817236  0.877193           105
# ..        ...        ...       ...           ...
# 435       NaN        NaN       NaN            82
# 436       NaN        NaN       NaN            82
# 437       NaN        NaN       NaN            82
# 438       NaN        NaN       NaN            82
# 439       NaN        NaN       NaN            82
#
# [440 rows x 8 columns]

# %%
predictors.to_excel(
    '../../data/tlp/predictors-tvaes-oversampling.xlsx',
    index=False
)

# %%
predictor.feature_importance(data=df_train)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['clin-Covid_sintomaSarpullido']
# Computing feature importance via permutation shuffling for 75 features using 5000 rows with 5 shuffle sets...
# 	235.53s	= Expected runtime (47.11s per shuffle set)
# 	141.95s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                           importance    stddev       p_value  \
# eval-TLP-Stroop-palabrasColor-PD            0.010526  0.000507  6.420991e-07
# demo-fechaNacimiento                        0.006954  0.000478  2.667325e-06
# eval-TLP-CubCorsi-total-PD                  0.006881  0.000340  7.098903e-07
# eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD    0.004070  0.000500  2.684887e-05
# eval-TLP-Tavec-4_RI_B-PD                    0.003078  0.000334  1.632316e-05
# ...                                              ...       ...           ...
# eval-TLP-Tavec-3_RI_AT-PD                   0.000090  0.000007  4.466569e-06
# eval-TLP-Tavec-11_RCl_LP-PD                 0.000081  0.000040  5.337618e-03
# ques-MMSE-orientacion-PD                    0.000063  0.000027  3.025087e-03
# clin-cardiopatiaIsquemica                   0.000060  0.000010  8.205060e-05
# ques-MMSE-fijacion-PD                      -0.000003  0.000003  9.629596e-01
#
#                                           n  p99_high   p99_low
# eval-TLP-Stroop-palabrasColor-PD          5  0.011569  0.009483
# demo-fechaNacimiento                      5  0.007939  0.005969
# eval-TLP-CubCorsi-total-PD                5  0.007580  0.006181
# eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD  5  0.005100  0.003040
# eval-TLP-Tavec-4_RI_B-PD                  5  0.003765  0.002391
# ...                                      ..       ...       ...
# eval-TLP-Tavec-3_RI_AT-PD                 5  0.000104  0.000075
# eval-TLP-Tavec-11_RCl_LP-PD               5  0.000163 -0.000002
# ques-MMSE-orientacion-PD                  5  0.000118  0.000008
# clin-cardiopatiaIsquemica                 5  0.000080  0.000040
# ques-MMSE-fijacion-PD                     5  0.000003 -0.000009
#
# [75 rows x 6 columns]
