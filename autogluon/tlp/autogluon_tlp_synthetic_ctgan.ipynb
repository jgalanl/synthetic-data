# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-ctgan.csv')

# %%
drop_columns = [
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]
pz_columns = [column for column in df.columns if 'PZ' in column ]
pdc_columns = [column for column in df.columns if 'PDC' in column]
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD  TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                             33.333333
# 1                           12.500000                              0.000000
# 2                           75.000000                             25.000000
# 3                           16.666667                              0.000000
# 4                           66.666667                              0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD  TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                           -33.333333
# 1                            0.000000                             0.000000
# 2                          -20.000000                             0.000000
# 3                           50.000000                           -20.000000
# 4                          -33.333333                             0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 68 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((376, 68), (94, 68))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/ctgan/v1'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 3600,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       4.98 GB / 15.94 GB (31.3%)
# Disk Space Avail:   120.24 GB / 446.36 GB (26.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-20 13:03:21,102	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8268
# 		Context path: "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=3540) Running DyStack sub-fit ...
# (_dystack pid=3540) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=3540) Beginning AutoGluon training ... Time limit = 882s
# (_dystack pid=3540) AutoGluon will save models to "AutogluonModels/synthetic/ctgan/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=3540) Train Data Rows:    334
# (_dystack pid=3540) Train Data Columns: 67
# (_dystack pid=3540) Label Column:       ED_2Clases
# (_dystack pid=3540) Problem Type:       binary
# (_dystack pid=3540) Preprocessing data ...
# (_dystack pid=3540) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=3540) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=3540) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=3540) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=3540) Using Feature Generators to preprocess the data ...
# (_dystack pid=3540) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=3540) 	Available Memory:                    4398.44 MB
# (_dystack pid=3540) 	Train Data (Original)  Memory Usage: 0.17 MB (0.0% of available memory)
# (_dystack pid=3540) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=3540) 	Stage 1 Generators:
# (_dystack pid=3540) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=3540) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=3540) 	Stage 2 Generators:
# (_dystack pid=3540) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=3540) 	Stage 3 Generators:
# (_dystack pid=3540) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=3540) 	Stage 4 Generators:
# (_dystack pid=3540) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=3540) 	Stage 5 Generators:
# (_dystack pid=3540) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=3540) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=3540) 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=3540) 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=3540) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=3540) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=3540) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=3540) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=3540) 	0.2s = Fit runtime
# (_dystack pid=3540) 	67 features in original data used to generate 67 features in processed data.
# (_dystack pid=3540) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=3540) Data preprocessing and feature engineering runtime = 0.24s ...
# (_dystack pid=3540) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=3540) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=3540) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=3540) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=3540) User-specified model hyperparameters to be fit:
# (_dystack pid=3540) {
# (_dystack pid=3540) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=3540) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=3540) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=3540) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=3540) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=3540) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=3540) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=3540) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=3540) }
# (_dystack pid=3540) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=3540) Fitting 110 L1 models ...
# (_dystack pid=3540) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 587.82s of the 881.92s of remaining time.
# (_dystack pid=3540) 	0.7859	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.02s	 = Training   runtime
# (_dystack pid=3540) 	0.49s	 = Validation runtime
# (_dystack pid=3540) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 581.81s of the 875.91s of remaining time.
# (_dystack pid=3540) 	0.7905	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.01s	 = Training   runtime
# (_dystack pid=3540) 	0.29s	 = Validation runtime
# (_dystack pid=3540) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 581.47s of the 875.57s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=3540) 	0.9428	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	3.24s	 = Training   runtime
# (_dystack pid=3540) 	0.03s	 = Validation runtime
# (_dystack pid=3540) Fitting model: LightGBM_BAG_L1 ... Training model for up to 569.01s of the 863.11s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_dystack pid=3540) 	0.9484	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	2.71s	 = Training   runtime
# (_dystack pid=3540) 	0.02s	 = Validation runtime
# (_dystack pid=3540) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 557.57s of the 851.66s of remaining time.
# (_dystack pid=3540) 	0.9275	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.99s	 = Training   runtime
# (_dystack pid=3540) 	0.14s	 = Validation runtime
# (_dystack pid=3540) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 556.37s of the 850.46s of remaining time.
# (_dystack pid=3540) 	0.9308	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.6s	 = Training   runtime
# (_dystack pid=3540) 	0.08s	 = Validation runtime
# (_dystack pid=3540) Fitting model: CatBoost_BAG_L1 ... Training model for up to 550.07s of the 844.17s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# (_dystack pid=3540) 	0.9464	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	19.32s	 = Training   runtime
# (_dystack pid=3540) 	0.17s	 = Validation runtime
# (_dystack pid=3540) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 507.18s of the 801.28s of remaining time.
# (_dystack pid=3540) 	0.9162	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.56s	 = Training   runtime
# (_dystack pid=3540) 	0.08s	 = Validation runtime
# (_dystack pid=3540) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 505.73s of the 799.83s of remaining time.
# (_dystack pid=3540) 	0.9254	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	0.55s	 = Training   runtime
# (_dystack pid=3540) 	0.08s	 = Validation runtime
# (_dystack pid=3540) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 502.6s of the 796.7s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=3540) 	0.9389	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	27.87s	 = Training   runtime
# (_dystack pid=3540) 	0.19s	 = Validation runtime
# (_dystack pid=3540) Fitting model: XGBoost_BAG_L1 ... Training model for up to 459.69s of the 753.79s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=3540) 	0.9297	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	7.31s	 = Training   runtime
# (_dystack pid=3540) 	0.04s	 = Validation runtime
# (_dystack pid=3540) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 441.8s of the 735.9s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=17084) Stack (most recent call first):
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=17084)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=17084)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=28896) Stack (most recent call first): [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 48x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 36x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 40x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 40x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 32x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 8x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 4x across cluster]
# (_ray_fit pid=28896)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 4x across cluster]
# (_dystack pid=3540) 	0.8989	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	64.37s	 = Training   runtime
# (_dystack pid=3540) 	0.25s	 = Validation runtime
# (_dystack pid=3540) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 351.21s of the 645.31s of remaining time.
# (_ray_fit pid=25256) Stack (most recent call first): [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 36x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 27x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 30x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 30x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 24x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 6x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 3x across cluster]
# (_ray_fit pid=25256)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 3x across cluster]
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# (_dystack pid=3540) 	0.9355	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	4.26s	 = Training   runtime
# (_dystack pid=3540) 	0.02s	 = Validation runtime
# (_dystack pid=3540) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 340.08s of the 634.18s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_dystack pid=3540) 	0.9443	 = Validation score   (roc_auc)
# (_dystack pid=3540) 	10.16s	 = Training   runtime
# (_dystack pid=3540) 	0.57s	 = Validation runtime
# (_dystack pid=3540) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 309.41s of the 603.51s of remaining time.
# (_dystack pid=3540) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=26904) Stack (most recent call first):
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 674 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 992 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked
# (_ray_fit pid=26904)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=26904)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=20268) Stack (most recent call first):
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 12x across cluster]
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 9x across cluster]
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 10x across cluster]
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 10x across cluster]
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 8x across cluster]
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=20268)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 2x across cluster]
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=20268)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=23856) Stack (most recent call first):
# (_ray_fit pid=23856)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module
# (_ray_fit pid=23856)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=23856)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 36x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 688 in _load_unlocked [repeated 27x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 1006 in _find_and_load_unlocked [repeated 30x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 1027 in _find_and_load [repeated 30x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap_external>", line 883 in exec_module [repeated 24x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 1078 in _handle_fromlist [repeated 6x across cluster]
# (_ray_fit pid=22660) Stack (most recent call first): [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap_external>", line 1176 in create_module [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "<frozen importlib._bootstrap>", line 571 in module_from_spec [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\onnx\__init__.py", line 77 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\onnx\__init__.py", line 59 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module> [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\_compile.py", line 22 in inner [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\optimizer.py", line 284 in __init__ [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 2x across cluster]
# (_ray_fit pid=22660)   File "c:\Users\jgala\uned\tfm\synthetic-data\.venv\lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 2x across cluster]
# ...
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1176.23s of the 2065.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.15%)
# 	0.9379	 = Validation score   (roc_auc)
# 	9.18s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1155.02s of the 2044.2s of remaining time.
# 	0.9346	 = Validation score   (roc_auc)
# 	1.22s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1153.54s of the 2042.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.9426	 = Validation score   (roc_auc)
# 	9.38s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1129.28s of the 2018.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9305	 = Validation score   (roc_auc)
# 	21.16s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 1099.46s of the 1988.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.68%)
# 2025-01-20 13:30:38,210	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9381	 = Validation score   (roc_auc)
# 	507.59s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 575.11s of the 1464.3s of remaining time.
# 	0.922	 = Validation score   (roc_auc)
# 	1.77s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 573.11s of the 1462.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	0.9441	 = Validation score   (roc_auc)
# 	5.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 551.96s of the 1441.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9325	 = Validation score   (roc_auc)
# 	29.62s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 500.29s of the 1389.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.9453	 = Validation score   (roc_auc)
# 	4.57s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 483.38s of the 1372.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9442	 = Validation score   (roc_auc)
# 	22.81s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 447.72s of the 1336.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.9468	 = Validation score   (roc_auc)
# 	7.17s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 429.0s of the 1318.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9265	 = Validation score   (roc_auc)
# 	52.04s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 368.28s of the 1257.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.9459	 = Validation score   (roc_auc)
# 	16.71s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 342.96s of the 1232.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9207	 = Validation score   (roc_auc)
# 	23.19s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 301.76s of the 1190.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	0.9471	 = Validation score   (roc_auc)
# 	16.53s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 280.29s of the 1169.47s of remaining time.
# 	0.9328	 = Validation score   (roc_auc)
# 	1.3s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 278.67s of the 1167.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	0.9411	 = Validation score   (roc_auc)
# 	13.59s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 241.55s of the 1130.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.927	 = Validation score   (roc_auc)
# 	22.66s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 192.27s of the 1081.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9363	 = Validation score   (roc_auc)
# 	52.99s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 131.69s of the 1020.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.87%)
# 	0.9457	 = Validation score   (roc_auc)
# 	6.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 116.93s of the 1006.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.944	 = Validation score   (roc_auc)
# 	35.92s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 77.04s of the 966.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.9421	 = Validation score   (roc_auc)
# 	33.36s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 33.73s of the 922.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.933	 = Validation score   (roc_auc)
# 	26.33s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 873.96s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r143_BAG_L1': 0.261, 'LightGBM_BAG_L1': 0.174, 'NeuralNetTorch_r22_BAG_L1': 0.174, 'NeuralNetTorch_r30_BAG_L1': 0.174, 'LightGBMLarge_BAG_L1': 0.13, 'XGBoost_r89_BAG_L1': 0.087}
# 	0.9658	 = Validation score   (roc_auc)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 873.65s of the 873.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.9619	 = Validation score   (roc_auc)
# 	3.8s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 859.66s of the 859.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.9506	 = Validation score   (roc_auc)
# 	3.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 846.55s of the 846.22s of remaining time.
# 	0.9519	 = Validation score   (roc_auc)
# 	1.02s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 845.26s of the 844.94s of remaining time.
# 	0.9553	 = Validation score   (roc_auc)
# 	0.98s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 844.03s of the 843.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.9594	 = Validation score   (roc_auc)
# 	29.34s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 798.35s of the 798.03s of remaining time.
# 	0.9553	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 796.5s of the 796.17s of remaining time.
# 	0.9546	 = Validation score   (roc_auc)
# 	0.98s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 794.31s of the 793.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9521	 = Validation score   (roc_auc)
# 	15.41s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 768.1s of the 767.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.9467	 = Validation score   (roc_auc)
# 	13.52s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 742.59s of the 742.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9263	 = Validation score   (roc_auc)
# 	30.12s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 701.94s of the 701.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.62%)
# 	0.9406	 = Validation score   (roc_auc)
# 	5.76s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 669.81s of the 669.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	0.9575	 = Validation score   (roc_auc)
# 	47.39s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 614.36s of the 614.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9445	 = Validation score   (roc_auc)
# 	61.78s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 544.0s of the 543.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.9531	 = Validation score   (roc_auc)
# 	12.46s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 502.17s of the 501.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.9533	 = Validation score   (roc_auc)
# 	18.84s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 459.63s of the 459.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.79%)
# 	0.9584	 = Validation score   (roc_auc)
# 	130.96s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 314.18s of the 313.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9617	 = Validation score   (roc_auc)
# 	11.0s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 278.86s of the 278.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9364	 = Validation score   (roc_auc)
# 	51.92s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 212.74s of the 212.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.79%)
# 	0.947	 = Validation score   (roc_auc)
# 	19.3s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 181.86s of the 181.53s of remaining time.
# 	0.9502	 = Validation score   (roc_auc)
# 	1.6s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 179.95s of the 179.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.9619	 = Validation score   (roc_auc)
# 	37.1s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 117.67s of the 117.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9501	 = Validation score   (roc_auc)
# 	22.83s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 81.79s of the 81.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.87%)
# 	0.9569	 = Validation score   (roc_auc)
# 	67.1s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 0.87s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.227, 'NeuralNetFastAI_r102_BAG_L2': 0.182, 'LightGBM_BAG_L1': 0.136, 'NeuralNetFastAI_r143_BAG_L1': 0.136, 'XGBoost_r89_BAG_L1': 0.091, 'LightGBM_r96_BAG_L2': 0.091, 'CatBoost_r137_BAG_L2': 0.091, 'NeuralNetTorch_r30_BAG_L1': 0.045}
# 	0.9659	 = Validation score   (roc_auc)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2666.14s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 10.6 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/ctgan/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L3   0.965906     roc_auc       6.199577  1372.724869                0.002004           0.260475            3       True         67
# 1           WeightedEnsemble_L2   0.965821     roc_auc       0.834682   103.016458                0.000000           0.269783            2       True         43
# 2             LightGBMXT_BAG_L2   0.961944     roc_auc       5.915790  1301.526915                0.026163           3.798155            2       True         44
# 3          CatBoost_r137_BAG_L2   0.961944     roc_auc       5.972153  1334.832291                0.082527          37.103532            2       True         64
# 4           LightGBM_r96_BAG_L2   0.961718     roc_auc       5.927488  1308.731840                0.037862          11.003080            2       True         60
# 5               CatBoost_BAG_L2   0.959398     roc_auc       5.965011  1327.067734                0.075384          29.338974            2       True         48
# 6            CatBoost_r9_BAG_L2   0.958379     roc_auc       5.977185  1428.688928                0.087558         130.960168            2       True         59
# 7          CatBoost_r177_BAG_L2   0.957502     roc_auc       5.968373  1345.114187                0.078746          47.385427            2       True         55
# 8           CatBoost_r13_BAG_L2   0.956880     roc_auc       5.980958  1364.833756                0.091331          67.104996            2       True         66
# 9         ExtraTreesGini_BAG_L2   0.955309     roc_auc       6.048084  1299.147293                0.158458           1.418533            2       True         49
# 10      RandomForestEntr_BAG_L2   0.955309     roc_auc       6.060829  1298.712100                0.171202           0.983340            2       True         47
# 11        ExtraTreesEntr_BAG_L2   0.954630     roc_auc       6.056733  1298.710527                0.167106           0.981767            2       True         50
# 12  NeuralNetFastAI_r191_BAG_L2   0.953258     roc_auc       6.030935  1316.571453                0.141308          18.842693            2       True         58
# 13         LightGBM_r131_BAG_L2   0.953088     roc_auc       5.921328  1310.192898                0.031701          12.464138            2       True         57
# 14       NeuralNetFastAI_BAG_L2   0.952070     roc_auc       6.006181  1313.141494                0.116554          15.412734            2       True         51
# 15      RandomForestGini_BAG_L2   0.951942     roc_auc       6.063310  1298.753643                0.173683           1.024883            2       True         46
# 16              LightGBM_BAG_L2   0.950627     roc_auc       5.913043  1301.043879                0.023416           3.315120            2       True         45
# 17        ExtraTrees_r42_BAG_L2   0.950188     roc_auc       6.092387  1299.323764                0.202760           1.595004            2       True         63
# 18  NeuralNetFastAI_r102_BAG_L2   0.950061     roc_auc       6.051022  1320.559626                0.161395          22.830867            2       True         65
# 19              LightGBM_BAG_L1   0.950004     roc_auc       0.025542     3.776440                0.025542           3.776440            1       True          4
# 20         LightGBM_r131_BAG_L1   0.948590     roc_auc       0.036035    30.953341                0.036035          30.953341            1       True         15
# 21         LightGBMLarge_BAG_L1   0.948165     roc_auc       0.026199     9.641758                0.026199           9.641758            1       True         13
# 22            LightGBMXT_BAG_L1   0.947090     roc_auc       0.054683     7.364151                0.054683           7.364151            1       True          3
# 23          XGBoost_r194_BAG_L1   0.947062     roc_auc       0.107321    16.529706                0.107321          16.529706            1       True         34
# 24           XGBoost_r33_BAG_L2   0.947033     roc_auc       5.935928  1317.027412                0.046301          19.298653            2       True         62
# 25          LightGBM_r96_BAG_L1   0.946892     roc_auc       0.076879     7.745995                0.076879           7.745995            1       True         18
# 26         LightGBM_r130_BAG_L1   0.946807     roc_auc       0.027539     7.173043                0.027539           7.173043            1       True         30
# 27               XGBoost_BAG_L2   0.946708     roc_auc       5.967036  1311.245106                0.077409          13.516346            2       True         52
# 28          CatBoost_r50_BAG_L1   0.945873     roc_auc       0.075088    16.713972                0.075088          16.713972            1       True         32
# 29         LightGBM_r161_BAG_L1   0.945704     roc_auc       0.043702     6.756521                0.043702           6.756521            1       True         39
# 30           XGBoost_r89_BAG_L1   0.945251     roc_auc       0.037273     4.574943                0.037273           4.574943            1       True         28
# 31    NeuralNetTorch_r79_BAG_L2   0.944515     roc_auc       6.193119  1359.513513                0.303492          61.784753            2       True         56
# 32    NeuralNetTorch_r30_BAG_L1   0.944232     roc_auc       0.321451    22.807230                0.321451          22.807230            1       True         29
# 33         LightGBM_r188_BAG_L1   0.944119     roc_auc       0.027680     5.318755                0.027680           5.318755            1       True         26
# 34  NeuralNetFastAI_r143_BAG_L1   0.944034     roc_auc       0.151613    35.924191                0.151613          35.924191            1       True         40
# 35           CatBoost_r9_BAG_L1   0.943525     roc_auc       0.129960   139.840584                0.129960         139.840584            1       True         17
# 36         CatBoost_r137_BAG_L1   0.942619     roc_auc       0.075392     9.382068                0.075392           9.382068            1       True         22
# 37          CatBoost_r70_BAG_L1   0.942138     roc_auc       0.074846    33.361310                0.074846          33.361310            1       True         41
# 38         CatBoost_r177_BAG_L1   0.941940     roc_auc       0.056418    10.898676                0.056418          10.898676            1       True         14
# 39          CatBoost_r69_BAG_L1   0.941063     roc_auc       0.066422    13.588467                0.066422          13.588467            1       True         36
# 40              CatBoost_BAG_L1   0.940724     roc_auc       0.078504    18.772839                0.078504          18.772839            1       True          7
# 41         LightGBMLarge_BAG_L2   0.940582     roc_auc       5.911237  1303.489097                0.021611           5.760337            2       True         54
# 42               XGBoost_BAG_L1   0.939337     roc_auc       0.030145    10.944944                0.030145          10.944944            1       True         11
# 43          CatBoost_r13_BAG_L1   0.938064     roc_auc       0.090909   507.593933                0.090909         507.593933            1       True         24
# 44           XGBoost_r33_BAG_L1   0.937866     roc_auc       0.054701     9.175807                0.054701           9.175807            1       True         20
# 45    NeuralNetTorch_r22_BAG_L2   0.936409     roc_auc       6.185732  1349.646600                0.296105          51.917841            2       True         61
# 46    NeuralNetTorch_r14_BAG_L1   0.936338     roc_auc       0.270364    52.987066                0.270364          52.987066            1       True         38
# 47    NeuralNetTorch_r22_BAG_L1   0.935489     roc_auc       0.272603    26.022113                0.272603          26.022113            1       True         19
# 48        ExtraTrees_r42_BAG_L1   0.934598     roc_auc       0.170692     1.223699                0.170692           1.223699            1       True         21
# 49      RandomForestGini_BAG_L1   0.933070     roc_auc       0.171515     1.134173                0.171515           1.134173            1       True          5
# 50  NeuralNetFastAI_r156_BAG_L1   0.932971     roc_auc       0.227277    26.334232                0.227277          26.334232            1       True         42
# 51       ExtraTrees_r172_BAG_L1   0.932773     roc_auc       0.154482     1.301560                0.154482           1.301560            1       True         35
# 52  NeuralNetFastAI_r145_BAG_L1   0.932547     roc_auc       0.178065    29.621804                0.178065          29.621804            1       True         27
# 53      RandomForestEntr_BAG_L1   0.931542     roc_auc       0.170458     1.019254                0.170458           1.019254            1       True          6
# 54  NeuralNetFastAI_r191_BAG_L1   0.930594     roc_auc       0.156460    23.382831                0.156460          23.382831            1       True         16
# 55  NeuralNetFastAI_r102_BAG_L1   0.930538     roc_auc       0.198803    21.164887                0.198803          21.164887            1       True         23
# 56       NeuralNetFastAI_BAG_L1   0.929463     roc_auc       0.114326    21.050575                0.114326          21.050575            1       True         10
# 57  NeuralNetFastAI_r103_BAG_L1   0.927001     roc_auc       0.153995    22.660923                0.153995          22.660923            1       True         37
# 58    NeuralNetTorch_r86_BAG_L1   0.926548     roc_auc       0.250851    52.043599                0.250851          52.043599            1       True         31
# 59        NeuralNetTorch_BAG_L2   0.926265     roc_auc       6.163232  1327.853112                0.273605          30.124352            2       True         53
# 60        ExtraTreesEntr_BAG_L1   0.925006     roc_auc       0.182643     1.221985                0.182643           1.221985            1       True          9
# 61        ExtraTreesGini_BAG_L1   0.923875     roc_auc       0.183713     1.022855                0.183713           1.022855            1       True          8
# 62     RandomForest_r195_BAG_L1   0.922035     roc_auc       0.155745     1.765805                0.155745           1.765805            1       True         25
# 63        NeuralNetTorch_BAG_L1   0.921540     roc_auc       0.249884    61.720069                0.249884          61.720069            1       True         12
# 64   NeuralNetFastAI_r11_BAG_L1   0.920663     roc_auc       0.113517    23.189014                0.113517          23.189014            1       True         33
# 65        KNeighborsDist_BAG_L1   0.797626     roc_auc       0.156243     0.011134                0.156243           0.011134            1       True          2
# 66        KNeighborsUnif_BAG_L1   0.793156     roc_auc       0.689685     0.012507                0.689685           0.012507            1       True          1
# Number of models trained: 67
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_NNFastAiTabular', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# Plot summary of models saved to file: AutogluonModels/synthetic/ctgan/v1SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r11_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r103_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7931556460968225,
#   'KNeighborsDist_BAG_L1': 0.7976261211555329,
#   'LightGBMXT_BAG_L1': 0.9470899470899471,
#   'LightGBM_BAG_L1': 0.9500042441218911,
#   'RandomForestGini_BAG_L1': 0.93307019777608,
#   'RandomForestEntr_BAG_L1': 0.9315423138952551,
#   'CatBoost_BAG_L1': 0.940723764253176,
#   'ExtraTreesGini_BAG_L1': 0.9238746003451886,
#   'ExtraTreesEntr_BAG_L1': 0.9250063661828367,
#   'NeuralNetFastAI_BAG_L1': 0.9294626941685766,
#   'XGBoost_BAG_L1': 0.939337351102057,
#   'NeuralNetTorch_BAG_L1': 0.9215403333050393,
#   'LightGBMLarge_BAG_L1': 0.948165124635713,
#   'CatBoost_r177_BAG_L1': 0.9419404125286478,
#   'LightGBM_r131_BAG_L1': 0.9485895368248309,
#   'NeuralNetFastAI_r191_BAG_L1': 0.9305944600062247,
#   'CatBoost_r9_BAG_L1': 0.9435248847013553,
#   'LightGBM_r96_BAG_L1': 0.9468918880683586,
#   'NeuralNetTorch_r22_BAG_L1': 0.9354893472540531,
#   'XGBoost_r33_BAG_L1': 0.9378660555131144,
#   'ExtraTrees_r42_BAG_L1': 0.9345980816569052,
#   'CatBoost_r137_BAG_L1': 0.9426194720312367,
#   'NeuralNetFastAI_r102_BAG_L1': 0.9305378717143423,
#   'CatBoost_r13_BAG_L1': 0.9380641145347027,
#   'RandomForest_r195_BAG_L1': 0.9220354808590102,
#   'LightGBM_r188_BAG_L1': 0.9441190617661205,
#   'NeuralNetFastAI_r145_BAG_L1': 0.9325467560761679,
#   'XGBoost_r89_BAG_L1': 0.9452508276037688,
#   'NeuralNetTorch_r30_BAG_L1': 0.9442322383498855,
#   'LightGBM_r130_BAG_L1': 0.946807005630535,
#   'NeuralNetTorch_r86_BAG_L1': 0.9265483971366324,
#   'CatBoost_r50_BAG_L1': 0.9458732988144752,
#   'NeuralNetFastAI_r11_BAG_L1': 0.9206632147808618,
#   'XGBoost_r194_BAG_L1': 0.9470616529440059,
#   'ExtraTrees_r172_BAG_L1': 0.9327731092436975,
#   'CatBoost_r69_BAG_L1': 0.9410632940044705,
#   'NeuralNetFastAI_r103_BAG_L1': 0.9270011034716917,
#   'NeuralNetTorch_r14_BAG_L1': 0.9363381716322893,
#   'LightGBM_r161_BAG_L1': 0.945703533938828,
#   'NeuralNetFastAI_r143_BAG_L1': 0.9440341793282969,
#   'CatBoost_r70_BAG_L1': 0.9421384715502362,
#   'NeuralNetFastAI_r156_BAG_L1': 0.9329711682652859,
#   'WeightedEnsemble_L2': 0.9658206717030247,
#   'LightGBMXT_BAG_L2': 0.9619443737090796,
#   'LightGBM_BAG_L2': 0.9506267153325976,
#   'RandomForestGini_BAG_L2': 0.9519423931188636,
#   'RandomForestEntr_BAG_L2': 0.955309396485867,
#   'CatBoost_BAG_L2': 0.9593979005743711,
#   'ExtraTreesGini_BAG_L2': 0.9553093964858671,
#   'ExtraTreesEntr_BAG_L2': 0.9546303369832781,
#   'NeuralNetFastAI_BAG_L2': 0.952069716775599,
#   'XGBoost_BAG_L2': 0.9467079761197408,
#   'NeuralNetTorch_BAG_L2': 0.9262654556772205,
#   'LightGBMLarge_BAG_L2': 0.94058229352347,
#   'CatBoost_r177_BAG_L2': 0.9575021927963105,
#   'NeuralNetTorch_r79_BAG_L2': 0.9445151798092974,
#   'LightGBM_r131_BAG_L2': 0.9530883060294825,
#   'NeuralNetFastAI_r191_BAG_L2': 0.9532580709051297,
#   'CatBoost_r9_BAG_L2': 0.9583793113204877,
#   'LightGBM_r96_BAG_L2': 0.9617180205415501,
#   'NeuralNetTorch_r22_BAG_L2': 0.9364089069971423,
#   'XGBoost_r33_BAG_L2': 0.9470333587980647,
#   'ExtraTrees_r42_BAG_L2': 0.950188156070509,
#   'CatBoost_r137_BAG_L2': 0.9619443737090796,
#   'NeuralNetFastAI_r102_BAG_L2': 0.9500608324137737,
#   'CatBoost_r13_BAG_L2': 0.956879721585604,
#   'WeightedEnsemble_L3': 0.9659055541408483},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'NeuralNetFastAI_r11_BAG_L1': ['NeuralNetFastAI_r11_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetFastAI_r103_BAG_L1': ['NeuralNetFastAI_r103_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'NeuralNetFastAI_r143_BAG_L1': ['NeuralNetFastAI_r143_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'NeuralNetFastAI_r156_BAG_L1': ['NeuralNetFastAI_r156_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'NeuralNetFastAI_r191_BAG_L2': ['NeuralNetFastAI_r191_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'LightGBM_r96_BAG_L2': ['LightGBM_r96_BAG_L2'],
#   'NeuralNetTorch_r22_BAG_L2': ['NeuralNetTorch_r22_BAG_L2'],
#   'XGBoost_r33_BAG_L2': ['XGBoost_r33_BAG_L2'],
#   'ExtraTrees_r42_BAG_L2': ['ExtraTrees_r42_BAG_L2'],
#   'CatBoost_r137_BAG_L2': ['CatBoost_r137_BAG_L2'],
#   'NeuralNetFastAI_r102_BAG_L2': ['NeuralNetFastAI_r102_BAG_L2'],
#   'CatBoost_r13_BAG_L2': ['CatBoost_r13_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.012507200241088867,
#   'KNeighborsDist_BAG_L1': 0.011133909225463867,
#   'LightGBMXT_BAG_L1': 7.364150762557983,
#   'LightGBM_BAG_L1': 3.776440143585205,
#   'RandomForestGini_BAG_L1': 1.1341729164123535,
#   'RandomForestEntr_BAG_L1': 1.0192537307739258,
#   'CatBoost_BAG_L1': 18.772839307785034,
#   'ExtraTreesGini_BAG_L1': 1.0228548049926758,
#   'ExtraTreesEntr_BAG_L1': 1.221984624862671,
#   'NeuralNetFastAI_BAG_L1': 21.05057454109192,
#   'XGBoost_BAG_L1': 10.94494366645813,
#   'NeuralNetTorch_BAG_L1': 61.72006916999817,
#   'LightGBMLarge_BAG_L1': 9.641758441925049,
#   'CatBoost_r177_BAG_L1': 10.89867639541626,
#   'LightGBM_r131_BAG_L1': 30.953341484069824,
#   'NeuralNetFastAI_r191_BAG_L1': 23.38283085823059,
#   'CatBoost_r9_BAG_L1': 139.8405842781067,
#   'LightGBM_r96_BAG_L1': 7.745995283126831,
#   'NeuralNetTorch_r22_BAG_L1': 26.02211332321167,
#   'XGBoost_r33_BAG_L1': 9.175806999206543,
#   'ExtraTrees_r42_BAG_L1': 1.2236993312835693,
#   'CatBoost_r137_BAG_L1': 9.382068157196045,
#   'NeuralNetFastAI_r102_BAG_L1': 21.16488742828369,
#   'CatBoost_r13_BAG_L1': 507.59393286705017,
#   'RandomForest_r195_BAG_L1': 1.7658045291900635,
#   'LightGBM_r188_BAG_L1': 5.31875467300415,
#   'NeuralNetFastAI_r145_BAG_L1': 29.621803998947144,
#   'XGBoost_r89_BAG_L1': 4.574942588806152,
#   'NeuralNetTorch_r30_BAG_L1': 22.807230472564697,
#   'LightGBM_r130_BAG_L1': 7.1730427742004395,
#   'NeuralNetTorch_r86_BAG_L1': 52.043599367141724,
#   'CatBoost_r50_BAG_L1': 16.713971853256226,
#   'NeuralNetFastAI_r11_BAG_L1': 23.189014196395874,
#   'XGBoost_r194_BAG_L1': 16.52970600128174,
#   'ExtraTrees_r172_BAG_L1': 1.301560401916504,
#   'CatBoost_r69_BAG_L1': 13.588466882705688,
#   'NeuralNetFastAI_r103_BAG_L1': 22.66092300415039,
#   'NeuralNetTorch_r14_BAG_L1': 52.98706555366516,
#   'LightGBM_r161_BAG_L1': 6.756521463394165,
#   'NeuralNetFastAI_r143_BAG_L1': 35.92419075965881,
#   'CatBoost_r70_BAG_L1': 33.36130952835083,
#   'NeuralNetFastAI_r156_BAG_L1': 26.334232091903687,
#   'WeightedEnsemble_L2': 0.26978254318237305,
#   'LightGBMXT_BAG_L2': 3.7981553077697754,
#   'LightGBM_BAG_L2': 3.315119504928589,
#   'RandomForestGini_BAG_L2': 1.0248827934265137,
#   'RandomForestEntr_BAG_L2': 0.983339786529541,
#   'CatBoost_BAG_L2': 29.33897376060486,
#   'ExtraTreesGini_BAG_L2': 1.4185333251953125,
#   'ExtraTreesEntr_BAG_L2': 0.9817671775817871,
#   'NeuralNetFastAI_BAG_L2': 15.412734031677246,
#   'XGBoost_BAG_L2': 13.516345739364624,
#   'NeuralNetTorch_BAG_L2': 30.124351739883423,
#   'LightGBMLarge_BAG_L2': 5.7603373527526855,
#   'CatBoost_r177_BAG_L2': 47.38542675971985,
#   'NeuralNetTorch_r79_BAG_L2': 61.78475308418274,
#   'LightGBM_r131_BAG_L2': 12.46413803100586,
#   'NeuralNetFastAI_r191_BAG_L2': 18.842693090438843,
#   'CatBoost_r9_BAG_L2': 130.96016812324524,
#   'LightGBM_r96_BAG_L2': 11.003080368041992,
#   'NeuralNetTorch_r22_BAG_L2': 51.91784071922302,
#   'XGBoost_r33_BAG_L2': 19.29865264892578,
#   'ExtraTrees_r42_BAG_L2': 1.5950043201446533,
#   'CatBoost_r137_BAG_L2': 37.1035315990448,
#   'NeuralNetFastAI_r102_BAG_L2': 22.83086657524109,
#   'CatBoost_r13_BAG_L2': 67.10499620437622,
#   'WeightedEnsemble_L3': 0.26047492027282715},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.6896853446960449,
#   'KNeighborsDist_BAG_L1': 0.15624332427978516,
#   'LightGBMXT_BAG_L1': 0.05468273162841797,
#   'LightGBM_BAG_L1': 0.025542497634887695,
#   'RandomForestGini_BAG_L1': 0.17151522636413574,
#   'RandomForestEntr_BAG_L1': 0.17045831680297852,
#   'CatBoost_BAG_L1': 0.07850432395935059,
#   'ExtraTreesGini_BAG_L1': 0.18371319770812988,
#   'ExtraTreesEntr_BAG_L1': 0.18264341354370117,
#   'NeuralNetFastAI_BAG_L1': 0.11432623863220215,
#   'XGBoost_BAG_L1': 0.030144929885864258,
#   'NeuralNetTorch_BAG_L1': 0.24988365173339844,
#   'LightGBMLarge_BAG_L1': 0.026198863983154297,
#   'CatBoost_r177_BAG_L1': 0.05641770362854004,
#   'LightGBM_r131_BAG_L1': 0.036034584045410156,
#   'NeuralNetFastAI_r191_BAG_L1': 0.15645980834960938,
#   'CatBoost_r9_BAG_L1': 0.1299600601196289,
#   'LightGBM_r96_BAG_L1': 0.07687854766845703,
#   'NeuralNetTorch_r22_BAG_L1': 0.27260327339172363,
#   'XGBoost_r33_BAG_L1': 0.05470132827758789,
#   'ExtraTrees_r42_BAG_L1': 0.17069196701049805,
#   'CatBoost_r137_BAG_L1': 0.07539224624633789,
#   'NeuralNetFastAI_r102_BAG_L1': 0.19880294799804688,
#   'CatBoost_r13_BAG_L1': 0.09090900421142578,
#   'RandomForest_r195_BAG_L1': 0.155745267868042,
#   'LightGBM_r188_BAG_L1': 0.027680397033691406,
#   'NeuralNetFastAI_r145_BAG_L1': 0.17806529998779297,
#   'XGBoost_r89_BAG_L1': 0.03727316856384277,
#   'NeuralNetTorch_r30_BAG_L1': 0.32145071029663086,
#   'LightGBM_r130_BAG_L1': 0.02753901481628418,
#   'NeuralNetTorch_r86_BAG_L1': 0.2508513927459717,
#   'CatBoost_r50_BAG_L1': 0.0750882625579834,
#   'NeuralNetFastAI_r11_BAG_L1': 0.11351728439331055,
#   'XGBoost_r194_BAG_L1': 0.10732102394104004,
#   'ExtraTrees_r172_BAG_L1': 0.15448212623596191,
#   'CatBoost_r69_BAG_L1': 0.0664215087890625,
#   'NeuralNetFastAI_r103_BAG_L1': 0.15399527549743652,
#   'NeuralNetTorch_r14_BAG_L1': 0.27036428451538086,
#   'LightGBM_r161_BAG_L1': 0.0437016487121582,
#   'NeuralNetFastAI_r143_BAG_L1': 0.1516132354736328,
#   'CatBoost_r70_BAG_L1': 0.07484602928161621,
#   'NeuralNetFastAI_r156_BAG_L1': 0.22727727890014648,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.026163339614868164,
#   'LightGBM_BAG_L2': 0.02341604232788086,
#   'RandomForestGini_BAG_L2': 0.17368292808532715,
#   'RandomForestEntr_BAG_L2': 0.1712019443511963,
#   'CatBoost_BAG_L2': 0.07538414001464844,
#   'ExtraTreesGini_BAG_L2': 0.15845775604248047,
#   'ExtraTreesEntr_BAG_L2': 0.16710638999938965,
#   'NeuralNetFastAI_BAG_L2': 0.11655426025390625,
#   'XGBoost_BAG_L2': 0.07740902900695801,
#   'NeuralNetTorch_BAG_L2': 0.2736048698425293,
#   'LightGBMLarge_BAG_L2': 0.021610736846923828,
#   'CatBoost_r177_BAG_L2': 0.07874608039855957,
#   'NeuralNetTorch_r79_BAG_L2': 0.30349206924438477,
#   'LightGBM_r131_BAG_L2': 0.031701087951660156,
#   'NeuralNetFastAI_r191_BAG_L2': 0.14130783081054688,
#   'CatBoost_r9_BAG_L2': 0.08755803108215332,
#   'LightGBM_r96_BAG_L2': 0.03786158561706543,
#   'NeuralNetTorch_r22_BAG_L2': 0.29610490798950195,
#   'XGBoost_r33_BAG_L2': 0.04630136489868164,
#   'ExtraTrees_r42_BAG_L2': 0.2027604579925537,
#   'CatBoost_r137_BAG_L2': 0.08252668380737305,
#   'NeuralNetFastAI_r102_BAG_L2': 0.16139507293701172,
#   'CatBoost_r13_BAG_L2': 0.09133100509643555,
#   'WeightedEnsemble_L3': 0.002003908157348633},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r11_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L3   0.965906     roc_auc       6.199577
#  1          WeightedEnsemble_L2   0.965821     roc_auc       0.834682
#  2            LightGBMXT_BAG_L2   0.961944     roc_auc       5.915790
#  3         CatBoost_r137_BAG_L2   0.961944     roc_auc       5.972153
#  4          LightGBM_r96_BAG_L2   0.961718     roc_auc       5.927488
#  ..                         ...        ...         ...            ...
#  62    RandomForest_r195_BAG_L1   0.922035     roc_auc       0.155745
#  63       NeuralNetTorch_BAG_L1   0.921540     roc_auc       0.249884
#  64  NeuralNetFastAI_r11_BAG_L1   0.920663     roc_auc       0.113517
#  65       KNeighborsDist_BAG_L1   0.797626     roc_auc       0.156243
#  66       KNeighborsUnif_BAG_L1   0.793156     roc_auc       0.689685
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   1372.724869                0.002004           0.260475            3
#  1    103.016458                0.000000           0.269783            2
#  2   1301.526915                0.026163           3.798155            2
#  3   1334.832291                0.082527          37.103532            2
#  4   1308.731840                0.037862          11.003080            2
#  ..          ...                     ...                ...          ...
#  62     1.765805                0.155745           1.765805            1
#  63    61.720069                0.249884          61.720069            1
#  64    23.189014                0.113517          23.189014            1
#  65     0.011134                0.156243           0.011134            1
#  66     0.012507                0.689685           0.012507            1
#
#      can_infer  fit_order
#  0        True         67
#  1        True         43
#  2        True         44
#  3        True         64
#  4        True         60
#  ..        ...        ...
#  62       True         25
#  63       True         12
#  64       True         33
#  65       True          2
#  66       True          1
#
#  [67 rows x 10 columns]}

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9692028985507247
# Evaluations on test data:
# {
#     "roc_auc": 0.9692028985507247,
#     "accuracy": 0.9148936170212766,
#     "balanced_accuracy": 0.9153079710144928,
#     "mcc": 0.8306159420289855,
#     "f1": 0.9148936170212766,
#     "precision": 0.9347826086956522,
#     "recall": 0.8958333333333334
# }
# {'roc_auc': 0.9692028985507247,
#  'accuracy': 0.9148936170212766,
#  'balanced_accuracy': 0.9153079710144928,
#  'mcc': 0.8306159420289855,
#  'f1': 0.9148936170212766,
#  'precision': 0.9347826086956522,
#  'recall': 0.8958333333333334}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                           model  score_test  balanced_accuracy        f1  \
# 0         KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 1               LightGBM_BAG_L1    1.000000           1.000000  1.000000
# 2           CatBoost_r69_BAG_L1    1.000000           1.000000  1.000000
# 3          CatBoost_r137_BAG_L1    1.000000           1.000000  1.000000
# 4               CatBoost_BAG_L1    1.000000           1.000000  1.000000
# ..                          ...         ...                ...       ...
# 62    NeuralNetTorch_r22_BAG_L1    0.986956           0.936055  0.934426
# 63  NeuralNetFastAI_r143_BAG_L1    0.986362           0.933410  0.931880
# 64   NeuralNetFastAI_r11_BAG_L1    0.985344           0.946779  0.946237
# 65  NeuralNetFastAI_r156_BAG_L1    0.979289           0.922686  0.919668
# 66        KNeighborsUnif_BAG_L1    0.908242           0.821506  0.810198
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# ..       ...       ...       ...                ...        ...       ...  ...
# 62  0.936125  0.936170  0.986956           0.989149   0.955307  0.914439  ...
# 63  0.933473  0.933511  0.986362           0.987407   0.950000  0.914439  ...
# 64  0.946802  0.946809  0.985344           0.986828   0.951351  0.941176  ...
# 65  0.922749  0.922872  0.979289           0.982292   0.954023  0.887701  ...
# 66  0.821139  0.821809  0.908242           0.874820   0.861446  0.764706  ...
#
#     eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0       roc_auc        0.019310       0.156243   0.011134
# 1       roc_auc        0.049927       0.025542   3.776440
# 2       roc_auc        0.061401       0.066422  13.588467
# 3       roc_auc        0.062003       0.075392   9.382068
# 4       roc_auc        0.063987       0.078504  18.772839
# ..          ...             ...            ...        ...
# 62      roc_auc        0.333305       0.272603  26.022113
# 63      roc_auc        0.518764       0.151613  35.924191
# 64      roc_auc        0.254530       0.113517  23.189014
# 65      roc_auc        0.453646       0.227277  26.334232
# 66      roc_auc        0.026754       0.689685   0.012507
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.019310                0.156243           0.011134
# 1                  0.049927                0.025542           3.776440
# 2                  0.061401                0.066422          13.588467
# 3                  0.062003                0.075392           9.382068
# 4                  0.063987                0.078504          18.772839
# ..                      ...                     ...                ...
# 62                 0.333305                0.272603          26.022113
# 63                 0.518764                0.151613          35.924191
# 64                 0.254530                0.113517          23.189014
# 65                 0.453646                0.227277          26.334232
# 66                 0.026754                0.689685           0.012507
#
#     stack_level  can_infer  fit_order
# 0             1       True          2
# 1             1       True          4
# 2             1       True         36
# 3             1       True         22
# 4             1       True          7
# ..          ...        ...        ...
# 62            1       True         19
# 63            1       True         40
# 64            1       True         33
# 65            1       True         42
# 66            1       True          1
#
# [67 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 67 features using 376 rows with 5 shuffle sets...
# 	2935.94s	= Expected runtime (587.19s per shuffle set)
# 	720.77s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                     importance    stddev  \
# TLP.Stroop.color.PD                                   0.005268  0.001146
# ISC.FPacientes.Edad                                   0.000866  0.000240
# TLP.CubCorsi.Directos.PD                              0.000622  0.000191
# TLP.Stroop.palabras.PD                                0.000577  0.000289
# TLP.Tavec.15_ESer-RI-A.PD                             0.000419  0.000187
# ...                                                        ...       ...
# TLP.FigRey.Duracion.PD                                0.000000  0.000000
# ISC.resultadosReservaCognitiva.escolaridad            0.000000  0.000000
# ISC.resultadosObservacion.enfermedadesHipertension    0.000000  0.000000
# ISC.resultadosCribaje.Total.PD                        0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD                0.000000  0.000000
#
#                                                      p_value  n  p99_high  \
# TLP.Stroop.color.PD                                 0.000252  5  0.007628
# ISC.FPacientes.Edad                                 0.000639  5  0.001359
# TLP.CubCorsi.Directos.PD                            0.000940  5  0.001015
# TLP.Stroop.palabras.PD                              0.005552  5  0.001172
# TLP.Tavec.15_ESer-RI-A.PD                           0.003729  5  0.000804
# ...                                                      ... ..       ...
# TLP.FigRey.Duracion.PD                              0.500000  5  0.000000
# ISC.resultadosReservaCognitiva.escolaridad          0.500000  5  0.000000
# ISC.resultadosObservacion.enfermedadesHipertension  0.500000  5  0.000000
# ISC.resultadosCribaje.Total.PD                      0.500000  5  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD              0.500000  5  0.000000
#
#                                                      p99_low
# TLP.Stroop.color.PD                                 0.002909
# ISC.FPacientes.Edad                                 0.000372
# TLP.CubCorsi.Directos.PD                            0.000229
# TLP.Stroop.palabras.PD                             -0.000018
# TLP.Tavec.15_ESer-RI-A.PD                           0.000034
# ...                                                      ...
# TLP.FigRey.Duracion.PD                              0.000000
# ISC.resultadosReservaCognitiva.escolaridad          0.000000
# ISC.resultadosObservacion.enfermedadesHipertension  0.000000
# ISC.resultadosCribaje.Total.PD                      0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD              0.000000
#
# [67 rows x 6 columns]
