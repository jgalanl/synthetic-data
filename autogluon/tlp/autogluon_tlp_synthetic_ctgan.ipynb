# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/tlp/synthetic-ctgan.csv')

# %%
df.head()
# Out:
#    demo-genero demo-fechaEvaluacion demo-fechaNacimiento demo-rangoEdad  \
# 0            2  2024-02-22T00:00:00  1942-05-08T00:00:00         Rango3
# 1            2  2024-06-26T00:00:00  1948-10-07T00:00:00         Rango3
# 2            2  2024-05-14T00:00:00  1952-05-08T00:00:00         Rango2
# 3            2  2024-04-10T00:00:00  1964-01-27T00:00:00         Rango1
# 4            2  2024-05-14T00:00:00  1959-09-16T00:00:00         Rango1
#
#    demo-edad  clin-reservaCognitiva_total  clin-reservaCognitiva_idiomas  \
# 0         81                           12                              0
# 1         75                            8                              0
# 2         72                           11                              0
# 3         60                           18                              2
# 4         64                           13                              0
#
#    clin-reservaCognitiva_ocupacion  clin-reservaCognitiva_escolaridad  \
# 0                                1                                  3
# 1                                1                                  3
# 2                                0                                  4
# 3                                1                                  4
# 4                                1                                  4
#
#    clin-ansiedad  ...  eval-TLP-Tavec-25_Discriminabilidad-PD  \
# 0          False  ...                                   84.09
# 1           True  ...                                   79.55
# 2          False  ...                                   88.64
# 3          False  ...                                   90.91
# 4          False  ...                                   86.36
#
#    eval-TLP-Tavec-26_Sesgo-PD  eval-TLP-Tavec-27_RI_B_frente_RI_A1-PD  \
# 0                        0.14                                  -20.00
# 1                       -0.33                                  -71.43
# 2                       -0.60                                  -14.29
# 3                        0.60                                   60.00
# 4                       -0.71                                    0.00
#
#    eval-TLP-Tavec-28_RL_CP_frente_RI_A5-PD  \
# 0                                     0.00
# 1                                    12.50
# 2                                    75.00
# 3                                    16.67
# 4                                    66.67
#
#    eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD  \
# 0                                      33.33
# 1                                       0.00
# 2                                      25.00
# 3                                       0.00
# 4                                       0.00
#
#    eval-TLP-Tavec-30_RL_LP_frente_RL_CP-PD  \
# 0                                    37.50
# 1                                     0.00
# 2                                   -20.00
# 3                                    50.00
# 4                                   -33.33
#
#    eval-TLP-Tavec-31_RCl_LP_frente_RL_LP-PD  \
# 0                                    -33.33
# 1                                      0.00
# 2                                      0.00
# 3                                    -20.00
# 4                                      0.00
#
#    eval-TLP-Tavec-32_Recon_Ac_frente_RL_LP-PD  \
# 0                                      -38.46
# 1                                      -20.00
# 2                                      -16.67
# 3                                      -50.00
# 4                                      -10.00
#
#    eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  ED_2Clases
# 0                                        -7.69           D
# 1                                       -20.00           D
# 2                                       -16.67           D
# 3                                       -37.50           D
# 4                                       -10.00           D
#
# [5 rows x 77 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((396, 77), (100, 77))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/ctgan/v2'
    )

# %%
predictor.fit(
    train_data = df_train,
    presets = ['high_quality'],
    time_limit = 2 * 3600,
    auto_stack = True,
    # excluded_model_types=['KNN','RF','XT', 'LR'],
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       10.08 GB / 15.94 GB (63.3%)
# Disk Space Avail:   83.69 GB / 446.36 GB (18.7%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-03 09:45:29,297	INFO worker.py:1762 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\ctgan\v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=9988) Running DyStack sub-fit ...
# (_dystack pid=9988) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=9988) Beginning AutoGluon training ... Time limit = 1792s
# (_dystack pid=9988) AutoGluon will save models to "c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\ctgan\v2\ds_sub_fit\sub_fit_ho"
# (_dystack pid=9988) Train Data Rows:    352
# (_dystack pid=9988) Train Data Columns: 76
# (_dystack pid=9988) Label Column:       ED_2Clases
# (_dystack pid=9988) Problem Type:       binary
# (_dystack pid=9988) Preprocessing data ...
# (_dystack pid=9988) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=9988) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=9988) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=9988) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=9988) Using Feature Generators to preprocess the data ...
# (_dystack pid=9988) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=9988) 	Available Memory:                    9754.67 MB
# (_dystack pid=9988) 	Train Data (Original)  Memory Usage: 0.25 MB (0.0% of available memory)
# (_dystack pid=9988) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=9988) 	Stage 1 Generators:
# (_dystack pid=9988) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=9988) 			Note: Converting 10 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=9988) 	Stage 2 Generators:
# (_dystack pid=9988) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=9988) 	Stage 3 Generators:
# (_dystack pid=9988) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=9988) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=9988) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=9988) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=9988) 	Stage 4 Generators:
# (_dystack pid=9988) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=9988) 	Stage 5 Generators:
# (_dystack pid=9988) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=9988) 	Useless Original Features (Count: 1): ['clin-Covid_sintomaSarpullido']
# (_dystack pid=9988) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=9988) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=9988) 		These features do not need to be present at inference time.
# (_dystack pid=9988) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=9988) 		('bool', [])                       :  8 | ['clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', 'clin-Hipercolesterolemia', ...]
# (_dystack pid=9988) 		('float', [])                      : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=9988) 		('int', [])                        : 49 | ['demo-genero', 'demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', ...]
# (_dystack pid=9988) 		('object', [])                     :  1 | ['demo-rangoEdad']
# (_dystack pid=9988) 		('object', ['datetime_as_object']) :  2 | ['demo-fechaEvaluacion', 'demo-fechaNacimiento']
# (_dystack pid=9988) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=9988) 		('category', [])             :  1 | ['demo-rangoEdad']
# (_dystack pid=9988) 		('float', [])                : 15 | ['ques-Sus-total-PD', 'eval-TLP-FigRey-totalCopia-PD', 'eval-TLP-FigRey-totalMemoria-PD', 'eval-TLP-Tavec-5_Rg_Pr-PD', 'eval-TLP-Tavec-6_Rg_Md-PD', ...]
# (_dystack pid=9988) 		('int', [])                  : 47 | ['demo-edad', 'clin-reservaCognitiva_total', 'clin-reservaCognitiva_idiomas', 'clin-reservaCognitiva_ocupacion', 'clin-reservaCognitiva_escolaridad', ...]
# (_dystack pid=9988) 		('int', ['bool'])            : 10 | ['demo-genero', 'clin-ansiedad', 'clin-depresion', 'clin-cardiopatiaIsquemica', 'clin-diabetes', ...]
# (_dystack pid=9988) 		('int', ['datetime_as_int']) :  9 | ['demo-fechaEvaluacion', 'demo-fechaEvaluacion.month', 'demo-fechaEvaluacion.day', 'demo-fechaEvaluacion.dayofweek', 'demo-fechaNacimiento', ...]
# (_dystack pid=9988) 	0.1s = Fit runtime
# (_dystack pid=9988) 	75 features in original data used to generate 82 features in processed data.
# (_dystack pid=9988) 	Train Data (Processed) Memory Usage: 0.19 MB (0.0% of available memory)
# (_dystack pid=9988) Data preprocessing and feature engineering runtime = 0.13s ...
# (_dystack pid=9988) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=9988) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=9988) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=9988) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=9988) User-specified model hyperparameters to be fit:
# (_dystack pid=9988) {
# (_dystack pid=9988) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=9988) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=9988) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=9988) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=9988) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=9988) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=9988) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=9988) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=9988) }
# (_dystack pid=9988) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=9988) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=9988) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1194.11s of the 1791.59s of remaining time.
# (_dystack pid=9988) 	0.5063	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.01s	 = Training   runtime
# (_dystack pid=9988) 	0.16s	 = Validation runtime
# (_dystack pid=9988) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1190.30s of the 1787.80s of remaining time.
# (_dystack pid=9988) 	0.546	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.01s	 = Training   runtime
# (_dystack pid=9988) 	0.0s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1190.26s of the 1787.76s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_ray_fit pid=8196) [1000]	valid_set's binary_logloss: 0.0576025
# (_ray_fit pid=8196) [2000]	valid_set's binary_logloss: 0.0461842
# (_dystack pid=9988) 	0.9694	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.6s	 = Training   runtime
# (_dystack pid=9988) 	0.04s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1183.46s of the 1780.96s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=9988) 	0.971	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.26s	 = Training   runtime
# (_dystack pid=9988) 	0.03s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1177.74s of the 1775.24s of remaining time.
# (_dystack pid=9988) 	0.9586	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.03s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1176.59s of the 1774.09s of remaining time.
# (_dystack pid=9988) 	0.963	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.53s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1175.94s of the 1773.44s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# (_dystack pid=9988) 	0.9673	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	33.22s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1138.37s of the 1735.88s of remaining time.
# (_dystack pid=9988) 	0.9414	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.58s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1137.67s of the 1735.17s of remaining time.
# (_dystack pid=9988) 	0.9422	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.52s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1137.04s of the 1734.54s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=18464) No improvement since epoch 8: early stopping
# (_dystack pid=9988) 	0.9325	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	5.98s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_BAG_L1 ... Training model for up to 1127.12s of the 1724.62s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# (_dystack pid=9988) 	0.9653	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.41s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1119.76s of the 1717.26s of remaining time.
# (_ray_fit pid=12032) No improvement since epoch 9: early stopping [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=9988) 	0.8996	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	10.02s	 = Training   runtime
# (_dystack pid=9988) 	0.18s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1105.71s of the 1703.19s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# (_dystack pid=9988) 	0.9613	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.7s	 = Training   runtime
# (_dystack pid=9988) 	0.01s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1099.86s of the 1697.36s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=9988) 	0.971	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	34.31s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1061.01s of the 1658.52s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=9988) 	0.9181	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.41s	 = Training   runtime
# (_dystack pid=9988) 	0.19s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1048.54s of the 1646.04s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_ray_fit pid=11320) [1000]	valid_set's binary_logloss: 0.139842
# (_dystack pid=9988) 	0.9698	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.13s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1041.45s of the 1638.95s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=9152) No improvement since epoch 5: early stopping
# (_dystack pid=9988) 	0.9227	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.57s	 = Training   runtime
# (_dystack pid=9988) 	0.15s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1029.44s of the 1626.94s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.76%)
# (_dystack pid=9988) 	0.9677	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	122.61s	 = Training   runtime
# (_dystack pid=9988) 	0.1s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 901.71s of the 1499.21s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=5172) No improvement since epoch 9: early stopping [repeated 7x across cluster]
# (_ray_fit pid=3252) [1000]	valid_set's binary_logloss: 0.346647
# (_dystack pid=9988) 	0.9574	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	5.17s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 892.53s of the 1490.03s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=9988) 	0.9139	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.19s	 = Training   runtime
# (_dystack pid=9988) 	0.25s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 880.11s of the 1477.61s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.38%)
# (_dystack pid=9988) 	0.9691	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.38s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 869.17s of the 1466.67s of remaining time.
# (_dystack pid=9988) 	0.9553	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.61s	 = Training   runtime
# (_dystack pid=9988) 	0.09s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 868.44s of the 1465.94s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=9988) 	0.9675	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	21.65s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 842.71s of the 1440.21s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=16452) No improvement since epoch 1: early stopping
# (_dystack pid=9988) 	0.9267	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.4s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 829.66s of the 1427.16s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.48%)
# (_dystack pid=9988) 	0.9668	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	294.38s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 531.00s of the 1128.50s of remaining time.
# (_ray_fit pid=20576) No improvement since epoch 3: early stopping [repeated 4x across cluster]
# (_dystack pid=9988) 	0.9625	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.76s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 530.12s of the 1127.62s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# (_dystack pid=9988) 	0.9683	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.23s	 = Training   runtime
# (_dystack pid=9988) 	0.03s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 524.92s of the 1122.42s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=17092) No improvement since epoch 7: early stopping
# (_dystack pid=9988) 	0.9267	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.51s	 = Training   runtime
# (_dystack pid=9988) 	0.1s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 513.97s of the 1111.47s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# (_dystack pid=9988) 	0.9684	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.66s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 506.45s of the 1103.96s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=17472) No improvement since epoch 6: early stopping [repeated 5x across cluster]
# (_dystack pid=9988) 	0.9308	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	11.42s	 = Training   runtime
# (_dystack pid=9988) 	0.19s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 491.03s of the 1088.53s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.49%)
# (_ray_fit pid=20080) [1000]	valid_set's binary_logloss: 0.141381 [repeated 16x across cluster]
# (_dystack pid=9988) 	0.9616	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.78s	 = Training   runtime
# (_dystack pid=9988) 	0.04s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 485.07s of the 1082.57s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=9988) 	0.902	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.37s	 = Training   runtime
# (_dystack pid=9988) 	0.21s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 472.32s of the 1069.82s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_dystack pid=9988) 	0.9702	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	21.08s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 446.86s of the 1044.36s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=15220) No improvement since epoch 2: early stopping
# (_dystack pid=9988) 	0.9101	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.86s	 = Training   runtime
# (_dystack pid=9988) 	0.12s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 435.86s of the 1033.36s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.92%)
# (_dystack pid=9988) 	0.9684	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	3.35s	 = Training   runtime
# (_dystack pid=9988) 	0.25s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 427.36s of the 1024.86s of remaining time.
# (_ray_fit pid=15500) No improvement since epoch 3: early stopping [repeated 7x across cluster]
# (_dystack pid=9988) 	0.9552	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.57s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 426.67s of the 1024.17s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=9988) 	0.966	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	22.52s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 400.34s of the 997.84s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=1252) No improvement since epoch 3: early stopping
# (_dystack pid=9988) 	0.913	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.9s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 384.03s of the 981.53s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.9264	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.11s	 = Training   runtime
# (_dystack pid=9988) 	0.2s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 372.07s of the 969.57s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.69%)
# (_ray_fit pid=21180) No improvement since epoch 7: early stopping [repeated 7x across cluster]
# (_ray_fit pid=14660) [1000]	valid_set's binary_logloss: 0.149682 [repeated 3x across cluster]
# (_dystack pid=9988) 	0.9714	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.0s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 365.63s of the 963.13s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=16680) No improvement since epoch 5: early stopping
# (_dystack pid=9988) 	0.9424	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.85s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 352.15s of the 949.66s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=9988) 	0.9708	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	33.84s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 313.87s of the 911.37s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=17840) No improvement since epoch 16: early stopping [repeated 4x across cluster]
# (_ray_fit pid=15848) No improvement since epoch 3: early stopping
# (_ray_fit pid=6636) No improvement since epoch 4: early stopping
# (_dystack pid=9988) 	0.9305	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	9.26s	 = Training   runtime
# (_dystack pid=9988) 	0.13s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 300.42s of the 897.92s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.80%)
# (_ray_fit pid=14800) [1000]	valid_set's binary_logloss: 0.14485 [repeated 2x across cluster]
# (_dystack pid=9988) 	0.9679	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	4.7s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 291.28s of the 888.79s of remaining time.
# (_ray_fit pid=13164) No improvement since epoch 16: early stopping [repeated 6x across cluster]
# (_dystack pid=9988) 	0.965	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.64s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 290.53s of the 888.03s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# (_dystack pid=9988) 	0.9684	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	45.33s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 239.07s of the 836.57s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=4712) No improvement since epoch 4: early stopping
# (_dystack pid=9988) 	0.9143	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	12.33s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 222.09s of the 819.59s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.9302	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	8.84s	 = Training   runtime
# (_dystack pid=9988) 	0.19s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 208.11s of the 805.61s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.43%)
# (_ray_fit pid=14660) No improvement since epoch 4: early stopping [repeated 6x across cluster]
# (_dystack pid=9988) 	0.9712	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	14.51s	 = Training   runtime
# (_dystack pid=9988) 	0.28s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 188.16s of the 785.66s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=9988) 	0.971	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.23s	 = Training   runtime
# (_dystack pid=9988) 	0.02s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 182.96s of the 780.46s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=9988) 	0.9151	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	10.68s	 = Training   runtime
# (_dystack pid=9988) 	0.17s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 167.93s of the 765.43s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.36%)
# (_dystack pid=9988) 	0.9667	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	94.87s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 68.90s of the 666.40s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=3584) No improvement since epoch 2: early stopping
# (_dystack pid=9988) 	0.9421	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	9.39s	 = Training   runtime
# (_dystack pid=9988) 	0.1s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 55.44s of the 652.94s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.923	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.09s	 = Training   runtime
# (_dystack pid=9988) 	0.18s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 44.46s of the 641.96s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=13360) No improvement since epoch 17: early stopping [repeated 5x across cluster]
# (_dystack pid=9988) 	0.9653	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.84s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 31.31s of the 628.81s of remaining time.
# (_dystack pid=9988) 	0.9414	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.67s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 30.53s of the 628.03s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# (_ray_fit pid=1004) [1000]	valid_set's binary_logloss: 0.131803 [repeated 13x across cluster]
# (_dystack pid=9988) 	0.9727	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	4.88s	 = Training   runtime
# (_dystack pid=9988) 	0.02s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 21.16s of the 618.66s of remaining time.
# (_dystack pid=9988) 	0.9643	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.82s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 20.22s of the 617.71s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_ray_fit pid=5124) No improvement since epoch 1: early stopping
# (_dystack pid=9988) 	0.9364	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	11.41s	 = Training   runtime
# (_dystack pid=9988) 	0.12s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 4.71s of the 602.21s of remaining time.
# (_dystack pid=9988) 	0.9479	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.62s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 3.96s of the 601.46s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=16700) [1000]	valid_set's binary_logloss: 0.080142 [repeated 8x across cluster]
# (_dystack pid=9988) 	0.9636	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	3.0s	 = Training   runtime
# (_dystack pid=9988) 	0.04s	 = Validation runtime
# (_ray_fit pid=18340) No improvement since epoch 16: early stopping [repeated 7x across cluster]
# (_dystack pid=9988) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 593.73s of remaining time.
# (_dystack pid=9988) 	Ensemble Weights: {'LightGBM_r143_BAG_L1': 0.565, 'CatBoost_r177_BAG_L1': 0.304, 'XGBoost_r98_BAG_L1': 0.087, 'NeuralNetTorch_r30_BAG_L1': 0.043}
# (_dystack pid=9988) 	0.9745	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.05s	 = Training   runtime
# (_dystack pid=9988) 	0.0s	 = Validation runtime
# (_dystack pid=9988) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=9988) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 593.66s of the 593.46s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=9988) 	0.9716	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.86s	 = Training   runtime
# (_dystack pid=9988) 	0.03s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_BAG_L2 ... Training model for up to 588.76s of the 588.55s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=9988) 	0.9689	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.09s	 = Training   runtime
# (_dystack pid=9988) 	0.02s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 583.19s of the 582.98s of remaining time.
# (_dystack pid=9988) 	0.9664	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.7s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 582.37s of the 582.16s of remaining time.
# (_dystack pid=9988) 	0.9694	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.52s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_BAG_L2 ... Training model for up to 581.72s of the 581.52s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# (_dystack pid=9988) 	0.9705	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	22.65s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 554.93s of the 554.72s of remaining time.
# (_dystack pid=9988) 	0.9666	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.56s	 = Training   runtime
# (_dystack pid=9988) 	0.08s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 554.27s of the 554.06s of remaining time.
# (_dystack pid=9988) 	0.9668	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.55s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 553.61s of the 553.40s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# (_ray_fit pid=17796) No improvement since epoch 8: early stopping
# (_dystack pid=9988) 	0.9589	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	5.74s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_BAG_L2 ... Training model for up to 543.87s of the 543.67s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.79%)
# (_dystack pid=9988) 	0.9699	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.9s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 537.27s of the 537.07s of remaining time.
# (_ray_fit pid=10860) No improvement since epoch 8: early stopping [repeated 4x across cluster]
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.954	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.2s	 = Training   runtime
# (_dystack pid=9988) 	0.21s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 525.75s of the 525.55s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.56%)
# (_dystack pid=9988) 	0.9644	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	2.08s	 = Training   runtime
# (_dystack pid=9988) 	0.04s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 519.08s of the 518.88s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_dystack pid=9988) 	0.9721	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.29s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 507.14s of the 506.93s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.9579	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.49s	 = Training   runtime
# (_dystack pid=9988) 	0.18s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 495.22s of the 495.01s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_dystack pid=9988) 	0.9659	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.48s	 = Training   runtime
# (_dystack pid=9988) 	0.04s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 489.12s of the 488.91s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_ray_fit pid=2564) No improvement since epoch 5: early stopping
# (_dystack pid=9988) 	0.961	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	6.38s	 = Training   runtime
# (_dystack pid=9988) 	0.11s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 478.24s of the 478.03s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.11%)
# (_dystack pid=9988) 	0.9654	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	86.87s	 = Training   runtime
# (_dystack pid=9988) 	0.07s	 = Validation runtime
# (_dystack pid=9988) Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 386.55s of the 386.35s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_ray_fit pid=17784) No improvement since epoch 9: early stopping [repeated 7x across cluster]
# (_dystack pid=9988) 	0.9704	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	1.02s	 = Training   runtime
# (_dystack pid=9988) 	0.02s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 381.25s of the 381.04s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=9988) 	0.9658	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.04s	 = Training   runtime
# (_dystack pid=9988) 	0.22s	 = Validation runtime
# (_dystack pid=9988) Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 369.70s of the 369.48s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=6.97%)
# (_dystack pid=9988) 	0.9694	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	3.22s	 = Training   runtime
# (_dystack pid=9988) 	0.06s	 = Validation runtime
# (_dystack pid=9988) Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 361.40s of the 361.20s of remaining time.
# (_dystack pid=9988) 	0.9666	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	0.6s	 = Training   runtime
# (_dystack pid=9988) 	0.1s	 = Validation runtime
# (_dystack pid=9988) Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 360.64s of the 360.43s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=9988) 	0.9706	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	17.8s	 = Training   runtime
# (_dystack pid=9988) 	0.05s	 = Validation runtime
# (_dystack pid=9988) Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 338.68s of the 338.47s of remaining time.
# (_dystack pid=9988) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_ray_fit pid=21412) No improvement since epoch 0: early stopping
# (_dystack pid=9988) 	0.9625	 = Validation score   (roc_auc)
# (_dystack pid=9988) 	7.87s	 = Training   runtime
# (_dystack pid=9988) 	0.12s	 = Validation runtime
# ...
# 	0.05s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.19s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.53s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	2.26s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.53s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.51s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.08s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	0.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	0.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	0.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	11.62s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	0.27s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.63s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	2.47s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.59s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	4.05s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.78s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	0.1s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L2_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L2_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L2_FULL ...
# 	0.46s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L2_FULL ...
# 	1.18s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.24s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L2_FULL ...
# 	0.11s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.58s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L2_FULL ...
# 	1.57s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.18s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L2_FULL ...
# 	0.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L2_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.84s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L2_FULL ...
# 	2.46s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_BAG_L2_FULL ...
# 	0.63s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.7s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_BAG_L2_FULL ...
# 	1.89s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.32s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_BAG_L2_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_BAG_L2_FULL ...
# 	0.63s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_BAG_L2_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L2_FULL ...
# 	1.19s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L2_FULL ...
# 	5.42s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r37_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.77s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r197_BAG_L2_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r49_BAG_L2_FULL ...
# 	0.3s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.81s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r143_BAG_L2_FULL ...
# 	0.25s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.94s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r134_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.42s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.69s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r94_BAG_L2_FULL ...
# 	0.17s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r143_BAG_L2_FULL ...
# 	0.19s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r128_BAG_L2_FULL ...
# 	1.41s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r111_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.68s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r31_BAG_L2_FULL ...
# 	0.32s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.66s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r65_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	1.01s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r88_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 3.
# 	0.4s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r30_BAG_L2_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r49_BAG_L2_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r5_BAG_L2_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r87_BAG_L2_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r71_BAG_L2_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r143_BAG_L2_FULL ...
# 	0.42s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.67s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.81s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r31_BAG_L2_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r185_BAG_L2_FULL ...
# 	0.53s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r160_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	0.2s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r60_BAG_L2_FULL ...
# 	2.34s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.82s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r135_BAG_L2_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r22_BAG_L2_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r69_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.26s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r6_BAG_L2_FULL ...
# 	0.8s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r138_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r121_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r172_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r180_BAG_L2_FULL ...
# 	0.9s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r76_BAG_L2_FULL ...
# 	0.32s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.88s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r121_BAG_L2_FULL ...
# 	0.44s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r127_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.71s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.21s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r194_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	0.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r12_BAG_L2_FULL ...
# 	1.04s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r135_BAG_L2_FULL ...
# 	0.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r4_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.16s	 = Training   runtime
# Fitting model: ExtraTrees_r126_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.91s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r36_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r100_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	0.67s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r163_BAG_L2_FULL ...
# 	1.32s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r198_BAG_L2_FULL ...
# 	0.55s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r187_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	1.11s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r19_BAG_L2_FULL ...
# 	0.18s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r95_BAG_L2_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r34_BAG_L2_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r42_BAG_L2_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r1_BAG_L2_FULL ...
# 	0.4s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r89_BAG_L2_FULL ...
# 	0.41s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_r49_BAG_L2': 0.4, 'LightGBM_r188_BAG_L1': 0.28, 'NeuralNetTorch_r36_BAG_L2': 0.16, 'RandomForest_r34_BAG_L2': 0.08, 'KNeighborsDist_BAG_L1': 0.04, 'NeuralNetFastAI_r65_BAG_L2': 0.04}
# 	0.05s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 217.69s ... Best model: "WeightedEnsemble_L3_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\jgala\uned\tfm\synthetic-data\autogluon\tlp\AutogluonModels\synthetic\ctgan\v2")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                 WeightedEnsemble_L3   0.978733     roc_auc       1.179322  106.422245                0.001034           0.051333            3      False        220
# 1                 WeightedEnsemble_L2   0.978222     roc_auc       0.417389   70.324866                0.000000           0.050179            2      False        111
# 2                 CatBoost_r49_BAG_L2   0.976920     roc_auc       0.776401   85.434185                0.075465           6.982262            2      False        164
# 3                LightGBM_r188_BAG_L1   0.976869     roc_auc       0.031758    2.765587                0.031758           2.765587            1      False         27
# 4                  CatBoost_r5_BAG_L2   0.976205     roc_auc       0.759235   86.394897                0.058299           7.942975            2      False        180
# 5                 CatBoost_r69_BAG_L2   0.975235     roc_auc       0.754816   95.909612                0.053880          17.457689            2      False        146
# 6                 LightGBM_r96_BAG_L2   0.975184     roc_auc       0.713098   81.577702                0.012162           3.125779            2      False        128
# 7             RandomForest_r34_BAG_L2   0.974699     roc_auc       0.787249   79.145720                0.086313           0.693797            2      False        169
# 8                CatBoost_r143_BAG_L2   0.974494     roc_auc       0.762574   93.451071                0.061638          14.999148            2      False        183
# 9                 CatBoost_r70_BAG_L2   0.974367     roc_auc       0.738686  112.537141                0.037750          34.085218            2      False        151
# 10                CatBoost_r60_BAG_L2   0.974341     roc_auc       0.748469   99.856281                0.047534          21.404358            2      False        189
# 11               CatBoost_r163_BAG_L2   0.974290     roc_auc       0.755937   98.574839                0.055001          20.122916            2      False        211
# 12               LightGBM_r135_BAG_L2   0.974265     roc_auc       0.729492   80.915018                0.028557           2.463095            2      False        191
# 13               ExtraTrees_r4_BAG_L2   0.974214     roc_auc       0.784409   79.115515                0.083473           0.663592            2      False        175
# 14               CatBoost_r137_BAG_L2   0.974137     roc_auc       0.748133   96.081157                0.047198          17.629235            2      False        132
# 15                    CatBoost_BAG_L2   0.974086     roc_auc       0.777754  102.823391                0.076818          24.371469            2      False        116
# 16                CatBoost_r50_BAG_L2   0.973958     roc_auc       0.774904   94.902809                0.073969          16.450886            2      False        142
# 17                LightGBM_r42_BAG_L2   0.973933     roc_auc       0.725839   80.891400                0.024903           2.439477            2      False        217
# 18               CatBoost_r180_BAG_L1   0.973882     roc_auc       0.029568   46.052970                0.029568          46.052970            1      False         89
# 19                  LightGBMXT_BAG_L1   0.973831     roc_auc       0.034688    1.324326                0.034688           1.324326            1      False          3
# 20                LightGBM_r30_BAG_L2   0.973780     roc_auc       0.731199   81.530821                0.030263           3.078898            2      False        178
# 21               LightGBM_r130_BAG_L2   0.973601     roc_auc       0.722581   80.820245                0.021646           2.368322            2      False        140
# 22                  LightGBMXT_BAG_L2   0.973499     roc_auc       0.731731   81.040285                0.030796           2.588362            2      False        112
# 23               LightGBM_r196_BAG_L2   0.973397     roc_auc       0.759094   82.858235                0.058159           4.406312            2      False        153
# 24                LightGBM_r30_BAG_L1   0.973243     roc_auc       0.066464    4.485117                0.066464           4.485117            1      False         69
# 25                 CatBoost_r6_BAG_L2   0.973141     roc_auc       0.761012   94.604341                0.060076          16.152418            2      False        194
# 26               CatBoost_r167_BAG_L2   0.973065     roc_auc       0.763977  110.718227                0.063041          32.266304            2      False        155
# 27               LightGBM_r188_BAG_L2   0.972963     roc_auc       0.764017   81.139861                0.063081           2.687938            2      False        136
# 28          NeuralNetTorch_r36_BAG_L2   0.972912     roc_auc       0.896131   88.310840                0.195195           9.858917            2      False        209
# 29               CatBoost_r128_BAG_L2   0.972860     roc_auc       0.753180  114.762468                0.052244          36.310545            2      False        172
# 30                CatBoost_r13_BAG_L2   0.972860     roc_auc       0.748602  136.369064                0.047667          57.917141            2      False        134
# 31              ExtraTreesEntr_BAG_L2   0.972541     roc_auc       0.775349   78.965396                0.074413           0.513473            2      False        118
# 32               CatBoost_r198_BAG_L2   0.972426     roc_auc       0.757475   92.163901                0.056539          13.711978            2      False        212
# 33                CatBoost_r12_BAG_L2   0.972401     roc_auc       0.755857  100.853562                0.054921          22.401639            2      False        205
# 34               LightGBM_r121_BAG_L1   0.972324     roc_auc       0.034082    3.179998                0.034082           3.179998            1      False         87
# 35                 CatBoost_r9_BAG_L1   0.972324     roc_auc       0.048361  114.161121                0.048361         114.161121            1      False         18
# 36               LightGBM_r196_BAG_L1   0.972299     roc_auc       0.083901    7.286980                0.083901           7.286980            1      False         44
# 37                 XGBoost_r98_BAG_L1   0.972222     roc_auc       0.208006    7.608588                0.208006           7.608588            1      False         49
# 38                 XGBoost_r34_BAG_L1   0.972197     roc_auc       0.017425    6.591903                0.017425           6.591903            1      False        107
# 39                CatBoost_r49_BAG_L1   0.972197     roc_auc       0.051027   10.338769                0.051027          10.338769            1      False         55
# 40                XGBoost_r194_BAG_L1   0.972120     roc_auc       0.210004    3.259690                0.210004           3.259690            1      False         35
# 41                CatBoost_r70_BAG_L1   0.972120     roc_auc       0.058455   56.578084                0.058455          56.578084            1      False         42
# 42                LightGBM_r42_BAG_L1   0.972018     roc_auc       0.027762    2.531402                0.027762           2.531402            1      False        108
# 43               LightGBM_r143_BAG_L1   0.971992     roc_auc       0.033194    3.418173                0.033194           3.418173            1      False         57
# 44               LightGBM_r161_BAG_L1   0.971941     roc_auc       0.029756    2.878825                0.029756           2.878825            1      False         40
# 45                LightGBM_r94_BAG_L2   0.971737     roc_auc       0.731021   81.115496                0.030085           2.663574            2      False        170
# 46             ExtraTrees_r172_BAG_L2   0.971533     roc_auc       0.785221   79.028864                0.084285           0.576941            2      False        145
# 47                CatBoost_r86_BAG_L2   0.971482     roc_auc       0.762320  150.387851                0.061384          71.935929            2      False        161
# 48               LightGBM_r131_BAG_L1   0.971354     roc_auc       0.020776    2.974065                0.020776           2.974065            1      False         16
# 49                 CatBoost_r9_BAG_L2   0.971278     roc_auc       0.758684  189.040557                0.057748         110.588634            2      False        127
# 50                    LightGBM_BAG_L1   0.971252     roc_auc       0.013701    2.459587                0.013701           2.459587            1      False          4
# 51                CatBoost_r50_BAG_L1   0.971175     roc_auc       0.063029   17.378298                0.063029          17.378298            1      False         33
# 52                 CatBoost_r6_BAG_L1   0.971124     roc_auc       0.055549   17.567270                0.055549          17.567270            1      False         85
# 53            RandomForestEntr_BAG_L2   0.971099     roc_auc       0.793692   78.979897                0.092756           0.527974            2      False        115
# 54               LightGBM_r121_BAG_L2   0.970971     roc_auc       0.749059   81.666799                0.048123           3.214876            2      False        196
# 55               CatBoost_r128_BAG_L1   0.970946     roc_auc       0.049262   40.579992                0.049262          40.579992            1      False         63
# 56               LightGBM_r161_BAG_L2   0.970946     roc_auc       0.723036   81.391705                0.022100           2.939782            2      False        149
# 57               CatBoost_r177_BAG_L2   0.970895     roc_auc       0.740293   89.321661                0.039357          10.869738            2      False        123
# 58            RandomForestGini_BAG_L2   0.970805     roc_auc       0.776844   79.150085                0.075908           0.698162            2      False        114
# 59               CatBoost_r180_BAG_L2   0.970741     roc_auc       0.775558  103.842188                0.074623          25.390265            2      False        198
# 60               CatBoost_r167_BAG_L1   0.970716     roc_auc       0.037354   60.220189                0.037354          60.220189            1      False         46
# 61                CatBoost_r13_BAG_L1   0.970588     roc_auc       0.051852  402.398344                0.051852         402.398344            1      False         25
# 62                 CatBoost_r5_BAG_L1   0.970461     roc_auc       0.045776    9.116979                0.045776           9.116979            1      False         71
# 63                 XGBoost_r22_BAG_L1   0.970103     roc_auc       0.055080    4.169599                0.055080           4.169599            1      False         83
# 64             ExtraTrees_r178_BAG_L2   0.970078     roc_auc       0.780893   79.120991                0.079957           0.669068            2      False        184
# 65              ExtraTreesGini_BAG_L2   0.970078     roc_auc       0.786819   78.985727                0.085883           0.533804            2      False        117
# 66              ExtraTrees_r49_BAG_L2   0.970078     roc_auc       0.790880   79.258221                0.089944           0.806298            2      False        165
# 67             ExtraTrees_r126_BAG_L2   0.970052     roc_auc       0.817742   79.364259                0.116807           0.912336            2      False        208
# 68                CatBoost_r12_BAG_L1   0.969899     roc_auc       0.069983   30.937306                0.069983          30.937306            1      False         96
# 69                CatBoost_r69_BAG_L1   0.969771     roc_auc       0.049070   32.656737                0.049070          32.656737            1      False         37
# 70               CatBoost_r177_BAG_L1   0.969644     roc_auc       0.059143   10.691508                0.059143          10.691508            1      False         14
# 71                LightGBM_r15_BAG_L1   0.969618     roc_auc       0.008875    2.645207                0.008875           2.645207            1      False         50
# 72                CatBoost_r86_BAG_L1   0.969593     roc_auc       0.056409   95.511239                0.056409          95.511239            1      False         52
# 73               CatBoost_r143_BAG_L1   0.969567     roc_auc       0.040084   15.832544                0.040084          15.832544            1      False         74
# 74                 XGBoost_r49_BAG_L1   0.969541     roc_auc       0.054344    6.532693                0.054344           6.532693            1      False         70
# 75                 XGBoost_r33_BAG_L1   0.969363     roc_auc       0.057550   10.676315                0.057550          10.676315            1      False         21
# 76               CatBoost_r198_BAG_L1   0.969312     roc_auc       0.055200   28.412123                0.055200          28.412123            1      False        103
# 77                 XGBoost_r98_BAG_L2   0.969133     roc_auc       0.959188   84.691451                0.258252           6.239528            2      False        158
# 78                    CatBoost_BAG_L1   0.969082     roc_auc       0.049675   34.270249                0.049675          34.270249            1      False          7
# 79               CatBoost_r137_BAG_L1   0.969056     roc_auc       0.045252   39.568199                0.045252          39.568199            1      False         23
# 80         NeuralNetFastAI_r65_BAG_L2   0.968903     roc_auc       0.821315   88.835937                0.120379          10.384014            2      False        176
# 81                CatBoost_r60_BAG_L1   0.968827     roc_auc       0.050517   28.349861                0.050517          28.349861            1      False         80
# 82        NeuralNetFastAI_r172_BAG_L2   0.968393     roc_auc       0.836420   88.286263                0.135484           9.834340            2      False        197
# 83               LightGBM_r135_BAG_L1   0.968316     roc_auc       0.027670    2.492462                0.027670           2.492462            1      False         82
# 84               LightGBM_r143_BAG_L2   0.968010     roc_auc       0.718489   81.610566                0.017553           3.158643            2      False        166
# 85                 XGBoost_r89_BAG_L1   0.967984     roc_auc       0.058994    2.743694                0.058994           2.743694            1      False         29
# 86               LightGBM_r131_BAG_L2   0.967984     roc_auc       0.727050   81.575406                0.026114           3.123483            2      False        125
# 87                 XGBoost_r31_BAG_L1   0.967959     roc_auc       0.065236    4.988796                0.065236           4.988796            1      False         77
# 88             ExtraTrees_r197_BAG_L2   0.967537     roc_auc       0.783269   79.333151                0.082333           0.881228            2      False        200
# 89               CatBoost_r163_BAG_L1   0.967473     roc_auc       0.063034   25.543326                0.063034          25.543326            1      False        102
# 90                 XGBoost_r34_BAG_L2   0.967295     roc_auc       0.742288   81.886834                0.041353           3.434911            2      False        216
# 91              ExtraTrees_r42_BAG_L2   0.967295     roc_auc       0.785354   79.085423                0.084418           0.633500            2      False        131
# 92        NeuralNetFastAI_r187_BAG_L2   0.967090     roc_auc       0.833885   89.684890                0.132949          11.232967            2      False        213
# 93                 XGBoost_r95_BAG_L1   0.966988     roc_auc       0.033433    3.408101                0.033433           3.408101            1      False        106
# 94           RandomForest_r166_BAG_L2   0.966861     roc_auc       0.782335   79.261944                0.081399           0.810021            2      False        185
# 95                LightGBM_r94_BAG_L1   0.966682     roc_auc       0.033163    2.997785                0.033163           2.997785            1      False         61
# 96                     XGBoost_BAG_L1   0.966631     roc_auc       0.028594    3.784471                0.028594           3.784471            1      False         11
# 97                 XGBoost_r22_BAG_L2   0.966580     roc_auc       0.731051   81.542824                0.030115           3.090901            2      False        192
# 98                    LightGBM_BAG_L2   0.966554     roc_auc       0.741028   80.997167                0.040092           2.545244            2      False        113
# 99                XGBoost_r194_BAG_L2   0.966452     roc_auc       0.960248   81.522171                0.259312           3.070249            2      False        144
# 100       NeuralNetFastAI_r156_BAG_L2   0.966325     roc_auc       0.805786   88.207313                0.104850           9.755390            2      False        152
# 101                XGBoost_r31_BAG_L2   0.966031     roc_auc       0.764273   82.741532                0.063338           4.289609            2      False        186
# 102         NeuralNetTorch_r76_BAG_L2   0.965482     roc_auc       0.893711   87.323544                0.192775           8.871621            2      False        199
# 103                XGBoost_r95_BAG_L2   0.965393     roc_auc       0.746993   81.661037                0.046057           3.209115            2      False        215
# 104         NeuralNetTorch_r19_BAG_L2   0.965329     roc_auc       0.891596   87.093944                0.190660           8.642021            2      False        214
# 105         NeuralNetTorch_r79_BAG_L2   0.965099     roc_auc       0.925668   88.076288                0.224732           9.624365            2      False        124
# 106                XGBoost_r33_BAG_L2   0.964793     roc_auc       0.746465   82.552414                0.045530           4.100491            2      False        130
# 107                    XGBoost_BAG_L2   0.964537     roc_auc       0.769430   81.144032                0.068495           2.692109            2      False        120
# 108                XGBoost_r49_BAG_L2   0.964193     roc_auc       0.746779   82.243985                0.045843           3.792063            2      False        179
# 109        NeuralNetFastAI_r37_BAG_L2   0.964154     roc_auc       0.817958   89.549577                0.117022          11.097655            2      False        162
# 110         NeuralNetTorch_r30_BAG_L2   0.963874     roc_auc       0.851254   89.324408                0.150318          10.872485            2      False        139
# 111       NeuralNetFastAI_r143_BAG_L2   0.963848     roc_auc       0.791547   88.527453                0.090611          10.075530            2      False        150
# 112           RandomForest_r39_BAG_L1   0.963695     roc_auc       0.078501    0.664582                0.078501           0.664582            1       True         45
# 113          RandomForest_r127_BAG_L2   0.963567     roc_auc       0.783662   79.393250                0.082726           0.941327            2      False        167
# 114                XGBoost_r89_BAG_L2   0.963529     roc_auc       0.747175   81.256206                0.046239           2.804283            2      False        138
# 115       NeuralNetFastAI_r100_BAG_L2   0.963516     roc_auc       0.835785   91.254713                0.134849          12.802790            2      False        210
# 116              LightGBM_r130_BAG_L1   0.963491     roc_auc       0.010291    2.636127                0.010291           2.636127            1      False         31
# 117           RandomForest_r16_BAG_L1   0.963388     roc_auc       0.083400    1.186044                0.083400           1.186044            1       True         94
# 118               LightGBM_r15_BAG_L2   0.963337     roc_auc       0.739180   81.349902                0.038244           2.897979            2      False        159
# 119       NeuralNetFastAI_r134_BAG_L2   0.963312     roc_auc       0.877743   91.443191                0.176808          12.991268            2      False        168
# 120        NeuralNetTorch_r158_BAG_L2   0.963069     roc_auc       0.896412   92.418824                0.195476          13.966901            2      False        160
# 121        NeuralNetFastAI_r88_BAG_L2   0.963057     roc_auc       0.805059   88.454261                0.104124          10.002338            2      False        177
# 122         NeuralNetTorch_r89_BAG_L2   0.962801     roc_auc       0.914532   88.868159                0.213597          10.416236            2      False        219
# 123           RandomForest_r15_BAG_L1   0.962776     roc_auc       0.068820    0.752482                0.068820           0.752482            1       True         81
# 124         NeuralNetTorch_r87_BAG_L2   0.962597     roc_auc       0.890978   87.199869                0.190042           8.747946            2      False        181
# 125           RandomForest_r15_BAG_L2   0.962380     roc_auc       0.784040   79.271674                0.083105           0.819752            2      False        190
# 126          RandomForest_r195_BAG_L2   0.962367     roc_auc       0.784565   79.236260                0.083629           0.784337            2      False        135
# 127          RandomForest_r195_BAG_L1   0.962189     roc_auc       0.078898    0.773873                0.078898           0.773873            1       True         26
# 128        NeuralNetTorch_r121_BAG_L2   0.962150     roc_auc       0.900093   89.992525                0.199157          11.540602            2      False        201
# 129          RandomForest_r127_BAG_L1   0.961984     roc_auc       0.082595    0.824748                0.082595           0.824748            1       True         58
# 130       NeuralNetFastAI_r111_BAG_L2   0.961946     roc_auc       0.830434   87.414845                0.129498           8.962922            2      False        173
# 131        NeuralNetTorch_r143_BAG_L2   0.961448     roc_auc       0.921111   87.582849                0.220176           9.130926            2      False        171
# 132           RandomForest_r39_BAG_L2   0.961282     roc_auc       0.779906   79.150923                0.078970           0.699000            2      False        154
# 133               LightGBM_r96_BAG_L1   0.961269     roc_auc       0.061551    6.328336                0.061551           6.328336            1      False         19
# 134           RandomForestEntr_BAG_L1   0.961257     roc_auc       0.085001    0.609435                0.085001           0.609435            1       True          6
# 135         NeuralNetTorch_r14_BAG_L2   0.960274     roc_auc       0.895922   85.937343                0.194987           7.485420            2      False        148
# 136         NeuralNetTorch_r22_BAG_L2   0.960044     roc_auc       0.885120   87.808717                0.184184           9.356794            2      False        129
# 137       NeuralNetFastAI_r138_BAG_L2   0.959635     roc_auc       0.790778   86.657283                0.089842           8.205360            2      False        195
# 138       NeuralNetFastAI_r191_BAG_L2   0.959559     roc_auc       0.803740   85.922950                0.102804           7.471027            2      False        126
# 139        NeuralNetFastAI_r11_BAG_L2   0.959393     roc_auc       0.797614   86.478457                0.096678           8.026534            2      False        143
# 140         NeuralNetTorch_r71_BAG_L2   0.959150     roc_auc       0.906199   86.005996                0.205263           7.554074            2      False        182
# 141        NeuralNetTorch_r185_BAG_L2   0.958895     roc_auc       0.891617   89.231531                0.190681          10.779608            2      False        187
# 142       NeuralNetFastAI_r127_BAG_L2   0.958742     roc_auc       0.793153   87.496311                0.092217           9.044388            2      False        202
# 143        NeuralNetTorch_r135_BAG_L2   0.958435     roc_auc       0.889197   88.007834                0.188261           9.555911            2      False        206
# 144           RandomForestGini_BAG_L1   0.958167     roc_auc       0.085140    1.069384                0.085140           1.069384            1       True          5
# 145        NeuralNetTorch_r197_BAG_L2   0.957925     roc_auc       0.904108   86.385517                0.203172           7.933594            2      False        163
# 146              LightGBMLarge_BAG_L1   0.957899     roc_auc       0.053650    3.520194                0.053650           3.520194            1      False         13
# 147          RandomForest_r166_BAG_L1   0.957478     roc_auc       0.077850    0.802219                0.077850           0.802219            1       True         76
# 148       NeuralNetFastAI_r145_BAG_L2   0.957184     roc_auc       0.796641   85.610588                0.095705           7.158665            2      False        137
# 149             NeuralNetTorch_BAG_L2   0.956827     roc_auc       0.869873   86.969779                0.168937           8.517856            2      False        121
# 150          NeuralNetTorch_r1_BAG_L2   0.956189     roc_auc       0.892403   88.309340                0.191468           9.857417            2      False        218
# 151           RandomForest_r16_BAG_L2   0.956010     roc_auc       0.780721   79.664179                0.079785           1.212256            2      False        203
# 152              LightGBMLarge_BAG_L2   0.955014     roc_auc       0.759080   81.815124                0.058145           3.363201            2      False        122
# 153            ExtraTrees_r172_BAG_L1   0.953610     roc_auc       0.067080    0.563273                0.067080           0.563273            1       True         36
# 154       NeuralNetFastAI_r160_BAG_L2   0.953482     roc_auc       0.790174   85.861626                0.089238           7.409703            2      False        188
# 155            ExtraTrees_r197_BAG_L1   0.953240     roc_auc       0.083669    0.857150                0.083669           0.857150            1       True         91
# 156       NeuralNetFastAI_r102_BAG_L2   0.952640     roc_auc       0.800211   87.529310                0.099275           9.077388            2      False        133
# 157         NeuralNetFastAI_r4_BAG_L2   0.952206     roc_auc       0.757819   85.713735                0.056883           7.261812            2      False        207
# 158        NeuralNetFastAI_r69_BAG_L2   0.952002     roc_auc       0.783693   85.895602                0.082757           7.443679            2      False        193
# 159            ExtraTrees_r178_BAG_L1   0.950802     roc_auc       0.084051    0.665406                0.084051           0.665406            1       True         75
# 160       NeuralNetFastAI_r194_BAG_L2   0.950214     roc_auc       0.786350   85.447325                0.085415           6.995402            2      False        204
# 161            NeuralNetFastAI_BAG_L2   0.950138     roc_auc       0.768272   85.302712                0.067336           6.850789            2      False        119
# 162             ExtraTrees_r42_BAG_L1   0.949397     roc_auc       0.083201    0.571893                0.083201           0.571893            1       True         22
# 163           RandomForest_r34_BAG_L1   0.947815     roc_auc       0.077773    0.557285                0.077773           0.557285            1       True         60
# 164         NeuralNetTorch_r86_BAG_L2   0.947508     roc_auc       0.875472   88.051171                0.174536           9.599248            2      False        141
# 165        NeuralNetFastAI_r95_BAG_L2   0.947304     roc_auc       0.854491   88.313390                0.153555           9.861467            2      False        156
# 166       NeuralNetFastAI_r103_BAG_L2   0.945644     roc_auc       0.750400   85.582525                0.049464           7.130603            2      False        147
# 167         NeuralNetTorch_r41_BAG_L2   0.945389     roc_auc       0.944288   88.575282                0.243352          10.123359            2      False        157
# 168         NeuralNetTorch_r31_BAG_L2   0.941534     roc_auc       0.893861   86.799986                0.192925           8.348063            2      False        174
# 169         NeuralNetTorch_r87_BAG_L1   0.940257     roc_auc       0.163236    9.559488                0.163236           9.559488            1      False         72
# 170             ExtraTreesEntr_BAG_L1   0.940002     roc_auc       0.085691    0.531893                0.085691           0.531893            1       True          9
# 171         NeuralNetTorch_r89_BAG_L1   0.939772     roc_auc       0.209518    9.773530                0.209518           9.773530            1      False        110
# 172        NeuralNetTorch_r158_BAG_L1   0.938445     roc_auc       0.211348   10.570350                0.211348          10.570350            1      False         51
# 173         NeuralNetTorch_r79_BAG_L1   0.938368     roc_auc       0.166214   13.468095                0.166214          13.468095            1      False         15
# 174         NeuralNetTorch_r14_BAG_L1   0.938164     roc_auc       0.183304    7.433479                0.183304           7.433479            1      False         39
# 175             ExtraTrees_r49_BAG_L1   0.937691     roc_auc       0.070322    0.657699                0.070322           0.657699            1       True         56
# 176             ExtraTreesGini_BAG_L1   0.937691     roc_auc       0.088371    0.549313                0.088371           0.549313            1       True          8
# 177            ExtraTrees_r126_BAG_L1   0.933007     roc_auc       0.113291    0.906916                0.113291           0.906916            1       True         99
# 178         NeuralNetTorch_r30_BAG_L1   0.932419     roc_auc       0.163216   11.075543                0.163216          11.075543            1      False         30
# 179         NeuralNetTorch_r36_BAG_L1   0.932138     roc_auc       0.209447    8.563167                0.209447           8.563167            1      False        100
# 180         NeuralNetTorch_r19_BAG_L1   0.927594     roc_auc       0.149421    8.538274                0.149421           8.538274            1      False        105
# 181         NeuralNetTorch_r41_BAG_L1   0.927083     roc_auc       0.215618   10.822922                0.215618          10.822922            1      False         48
# 182              ExtraTrees_r4_BAG_L1   0.925960     roc_auc       0.084565    0.782544                0.084565           0.782544            1       True         66
# 183        NeuralNetTorch_r121_BAG_L1   0.924837     roc_auc       0.192666   11.429879                0.192666          11.429879            1      False         92
# 184        NeuralNetTorch_r197_BAG_L1   0.924632     roc_auc       0.140966    7.403792                0.140966           7.403792            1      False         54
# 185        NeuralNetTorch_r143_BAG_L1   0.924505     roc_auc       0.176611   17.436112                0.176611          17.436112            1      False         62
# 186        NeuralNetFastAI_r37_BAG_L1   0.923381     roc_auc       0.114325   11.232059                0.114325          11.232059            1      False         53
# 187        NeuralNetTorch_r185_BAG_L1   0.922360     roc_auc       0.181684   10.026591                0.181684          10.026591            1      False         78
# 188         NeuralNetTorch_r31_BAG_L1   0.920752     roc_auc       0.168228    7.773695                0.168228           7.773695            1      False         65
# 189         NeuralNetTorch_r22_BAG_L1   0.919935     roc_auc       0.163977   10.559794                0.163977          10.559794            1      False         20
# 190       NeuralNetFastAI_r111_BAG_L1   0.919616     roc_auc       0.103871    8.544235                0.103871           8.544235            1      False         64
# 191         NeuralNetTorch_r76_BAG_L1   0.918760     roc_auc       0.175590    7.810217                0.175590           7.810217            1      False         90
# 192         NeuralNetTorch_r71_BAG_L1   0.915875     roc_auc       0.180626    7.545124                0.180626           7.545124            1      False         73
# 193        NeuralNetTorch_r135_BAG_L1   0.912071     roc_auc       0.188686    9.380055                0.188686           9.380055            1      False         97
# 194             NeuralNetTorch_BAG_L1   0.912046     roc_auc       0.183613   16.819630                0.183613          16.819630            1      False         12
# 195         NeuralNetTorch_r86_BAG_L1   0.911663     roc_auc       0.147514   10.291985                0.147514          10.291985            1      False         32
# 196       NeuralNetFastAI_r143_BAG_L1   0.911650     roc_auc       0.119441    9.972594                0.119441           9.972594            1      False         41
# 197          NeuralNetTorch_r1_BAG_L1   0.909722     roc_auc       0.195339   10.582092                0.195339          10.582092            1      False        109
# 198        NeuralNetFastAI_r65_BAG_L1   0.909263     roc_auc       0.099365    9.891391                0.099365           9.891391            1      False         67
# 199       NeuralNetFastAI_r127_BAG_L1   0.909109     roc_auc       0.092551    8.581836                0.092551           8.581836            1      False         93
# 200       NeuralNetFastAI_r138_BAG_L1   0.907718     roc_auc       0.108685    8.121625                0.108685           8.121625            1      False         86
# 201       NeuralNetFastAI_r134_BAG_L1   0.906314     roc_auc       0.124884   12.268429                0.124884          12.268429            1      False         59
# 202         NeuralNetFastAI_r4_BAG_L1   0.905050     roc_auc       0.082668    6.957836                0.082668           6.957836            1      False         98
# 203       NeuralNetFastAI_r102_BAG_L1   0.904003     roc_auc       0.116869    8.547288                0.116869           8.547288            1      False         24
# 204       NeuralNetFastAI_r100_BAG_L1   0.903876     roc_auc       0.090472   12.333522                0.090472          12.333522            1      False        101
# 205        NeuralNetFastAI_r11_BAG_L1   0.902459     roc_auc       0.065399    7.742379                0.065399           7.742379            1      False         34
# 206       NeuralNetFastAI_r156_BAG_L1   0.900837     roc_auc       0.106736    8.443280                0.106736           8.443280            1      False         43
# 207            NeuralNetFastAI_BAG_L1   0.900812     roc_auc       0.076577    7.263170                0.076577           7.263170            1      False         10
# 208       NeuralNetFastAI_r103_BAG_L1   0.900135     roc_auc       0.052634    6.549849                0.052634           6.549849            1      False         38
# 209       NeuralNetFastAI_r160_BAG_L1   0.898872     roc_auc       0.086927    7.035961                0.086927           7.035961            1      False         79
# 210       NeuralNetFastAI_r191_BAG_L1   0.896165     roc_auc       0.077950    7.324245                0.077950           7.324245            1      False         17
# 211       NeuralNetFastAI_r172_BAG_L1   0.895808     roc_auc       0.061542    9.544864                0.061542           9.544864            1      False         88
# 212       NeuralNetFastAI_r187_BAG_L1   0.895591     roc_auc       0.098270    8.730529                0.098270           8.730529            1      False        104
# 213        NeuralNetFastAI_r88_BAG_L1   0.891353     roc_auc       0.130359   10.006867                0.130359          10.006867            1      False         68
# 214       NeuralNetFastAI_r194_BAG_L1   0.890523     roc_auc       0.090118    6.974678                0.090118           6.974678            1      False         95
# 215        NeuralNetFastAI_r69_BAG_L1   0.888327     roc_auc       0.094489    6.914051                0.094489           6.914051            1      False         84
# 216       NeuralNetFastAI_r145_BAG_L1   0.886132     roc_auc       0.088876    7.041463                0.088876           7.041463            1      False         28
# 217        NeuralNetFastAI_r95_BAG_L1   0.885187     roc_auc       0.079492    8.048275                0.079492           8.048275            1      False         47
# 218             KNeighborsDist_BAG_L1   0.554049     roc_auc       0.008461    0.005376                0.008461           0.005376            1       True          2
# 219             KNeighborsUnif_BAG_L1   0.531441     roc_auc       1.547925    0.013365                1.547925           0.013365            1       True          1
# 220        KNeighborsDist_BAG_L1_FULL        NaN     roc_auc       0.008461    0.005376                0.008461           0.005376            1       True        222
# 221       ExtraTrees_r172_BAG_L1_FULL        NaN     roc_auc       0.067080    0.563273                0.067080           0.563273            1       True        256
# 222      RandomForest_r15_BAG_L1_FULL        NaN     roc_auc       0.068820    0.752482                0.068820           0.752482            1       True        301
# 223        ExtraTrees_r49_BAG_L1_FULL        NaN     roc_auc       0.070322    0.657699                0.070322           0.657699            1       True        276
# 224      RandomForest_r34_BAG_L1_FULL        NaN     roc_auc       0.077773    0.557285                0.077773           0.557285            1       True        280
# 225     RandomForest_r166_BAG_L1_FULL        NaN     roc_auc       0.077850    0.802219                0.077850           0.802219            1       True        296
# 226      RandomForest_r39_BAG_L1_FULL        NaN     roc_auc       0.078501    0.664582                0.078501           0.664582            1       True        265
# 227     RandomForest_r195_BAG_L1_FULL        NaN     roc_auc       0.078898    0.773873                0.078898           0.773873            1       True        246
# 228     RandomForest_r127_BAG_L1_FULL        NaN     roc_auc       0.082595    0.824748                0.082595           0.824748            1       True        278
# 229        ExtraTrees_r42_BAG_L1_FULL        NaN     roc_auc       0.083201    0.571893                0.083201           0.571893            1       True        242
# 230      RandomForest_r16_BAG_L1_FULL        NaN     roc_auc       0.083400    1.186044                0.083400           1.186044            1       True        314
# 231       ExtraTrees_r197_BAG_L1_FULL        NaN     roc_auc       0.083669    0.857150                0.083669           0.857150            1       True        311
# 232       ExtraTrees_r178_BAG_L1_FULL        NaN     roc_auc       0.084051    0.665406                0.084051           0.665406            1       True        295
# 233         ExtraTrees_r4_BAG_L1_FULL        NaN     roc_auc       0.084565    0.782544                0.084565           0.782544            1       True        286
# 234      RandomForestEntr_BAG_L1_FULL        NaN     roc_auc       0.085001    0.609435                0.085001           0.609435            1       True        226
# 235      RandomForestGini_BAG_L1_FULL        NaN     roc_auc       0.085140    1.069384                0.085140           1.069384            1       True        225
# 236        ExtraTreesEntr_BAG_L1_FULL        NaN     roc_auc       0.085691    0.531893                0.085691           0.531893            1       True        229
# 237        ExtraTreesGini_BAG_L1_FULL        NaN     roc_auc       0.088371    0.549313                0.088371           0.549313            1       True        228
# 238       ExtraTrees_r126_BAG_L1_FULL        NaN     roc_auc       0.113291    0.906916                0.113291           0.906916            1       True        319
# 239        KNeighborsUnif_BAG_L1_FULL        NaN     roc_auc       1.547925    0.013365                1.547925           0.013365            1       True        221
# 240           XGBoost_r98_BAG_L2_FULL        NaN     roc_auc            NaN    7.627759                     NaN           0.629638            2       True        378
# 241           XGBoost_r98_BAG_L1_FULL        NaN     roc_auc            NaN    0.907917                     NaN           0.907917            1       True        269
# 242           XGBoost_r95_BAG_L2_FULL        NaN     roc_auc            NaN    7.090283                     NaN           0.092162            2       True        435
# 243           XGBoost_r95_BAG_L1_FULL        NaN     roc_auc            NaN    0.131332                     NaN           0.131332            1       True        326
# 244           XGBoost_r89_BAG_L2_FULL        NaN     roc_auc            NaN    7.097759                     NaN           0.099639            2       True        358
# 245           XGBoost_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.122459                     NaN           0.122459            1       True        249
# 246           XGBoost_r49_BAG_L2_FULL        NaN     roc_auc            NaN    7.151173                     NaN           0.153053            2       True        399
# 247           XGBoost_r49_BAG_L1_FULL        NaN     roc_auc            NaN    0.370584                     NaN           0.370584            1       True        290
# 248           XGBoost_r34_BAG_L2_FULL        NaN     roc_auc            NaN    7.151911                     NaN           0.153790            2       True        436
# 249           XGBoost_r34_BAG_L1_FULL        NaN     roc_auc            NaN    0.387107                     NaN           0.387107            1       True        327
# 250           XGBoost_r33_BAG_L2_FULL        NaN     roc_auc            NaN    7.272457                     NaN           0.274337            2       True        350
# 251           XGBoost_r33_BAG_L1_FULL        NaN     roc_auc            NaN    0.748181                     NaN           0.748181            1       True        241
# 252           XGBoost_r31_BAG_L2_FULL        NaN     roc_auc            NaN    7.285980                     NaN           0.287860            2       True        406
# 253           XGBoost_r31_BAG_L1_FULL        NaN     roc_auc            NaN    0.470501                     NaN           0.470501            1       True        297
# 254           XGBoost_r22_BAG_L2_FULL        NaN     roc_auc            NaN    7.090563                     NaN           0.092443            2       True        412
# 255           XGBoost_r22_BAG_L1_FULL        NaN     roc_auc            NaN    0.163695                     NaN           0.163695            1       True        303
# 256          XGBoost_r194_BAG_L2_FULL        NaN     roc_auc            NaN    7.109549                     NaN           0.111428            2       True        364
# 257          XGBoost_r194_BAG_L1_FULL        NaN     roc_auc            NaN    0.203613                     NaN           0.203613            1       True        255
# 258               XGBoost_BAG_L2_FULL        NaN     roc_auc            NaN    7.079447                     NaN           0.081327            2       True        340
# 259               XGBoost_BAG_L1_FULL        NaN     roc_auc            NaN    0.311219                     NaN           0.311219            1       True        231
# 260          WeightedEnsemble_L3_FULL        NaN     roc_auc            NaN    9.313996                     NaN           0.051333            3       True        440
# 261          WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN    5.571733                     NaN           0.050179            2       True        331
# 262      RandomForest_r39_BAG_L2_FULL        NaN     roc_auc            NaN    7.697120                0.078970           0.699000            2       True        374
# 263      RandomForest_r34_BAG_L2_FULL        NaN     roc_auc            NaN    7.691917                0.086313           0.693797            2       True        389
# 264     RandomForest_r195_BAG_L2_FULL        NaN     roc_auc            NaN    7.782458                0.083629           0.784337            2       True        355
# 265      RandomForest_r16_BAG_L2_FULL        NaN     roc_auc            NaN    8.210376                0.079785           1.212256            2       True        423
# 266     RandomForest_r166_BAG_L2_FULL        NaN     roc_auc            NaN    7.808142                0.081399           0.810021            2       True        405
# 267      RandomForest_r15_BAG_L2_FULL        NaN     roc_auc            NaN    7.817872                0.083105           0.819752            2       True        410
# 268     RandomForest_r127_BAG_L2_FULL        NaN     roc_auc            NaN    7.939447                0.082726           0.941327            2       True        387
# 269      RandomForestGini_BAG_L2_FULL        NaN     roc_auc            NaN    7.696283                0.075908           0.698162            2       True        334
# 270      RandomForestEntr_BAG_L2_FULL        NaN     roc_auc            NaN    7.526095                0.092756           0.527974            2       True        335
# 271    NeuralNetTorch_r89_BAG_L2_FULL        NaN     roc_auc            NaN    7.408526                     NaN           0.410406            2       True        439
# 272    NeuralNetTorch_r89_BAG_L1_FULL        NaN     roc_auc            NaN    0.487235                     NaN           0.487235            1       True        330
# 273    NeuralNetTorch_r87_BAG_L2_FULL        NaN     roc_auc            NaN    7.208973                     NaN           0.210853            2       True        401
# 274    NeuralNetTorch_r87_BAG_L1_FULL        NaN     roc_auc            NaN    0.610624                     NaN           0.610624            1       True        292
# 275    NeuralNetTorch_r86_BAG_L2_FULL        NaN     roc_auc            NaN    7.460418                     NaN           0.462298            2       True        361
# 276    NeuralNetTorch_r86_BAG_L1_FULL        NaN     roc_auc            NaN    0.553313                     NaN           0.553313            1       True        252
# 277    NeuralNetTorch_r79_BAG_L2_FULL        NaN     roc_auc            NaN    7.475981                     NaN           0.477861            2       True        344
# 278    NeuralNetTorch_r79_BAG_L1_FULL        NaN     roc_auc            NaN    1.149809                     NaN           1.149809            1       True        235
# 279    NeuralNetTorch_r76_BAG_L2_FULL        NaN     roc_auc            NaN    7.314647                     NaN           0.316527            2       True        419
# 280    NeuralNetTorch_r76_BAG_L1_FULL        NaN     roc_auc            NaN    0.289553                     NaN           0.289553            1       True        310
# 281    NeuralNetTorch_r71_BAG_L2_FULL        NaN     roc_auc            NaN    7.137788                     NaN           0.139668            2       True        402
# 282    NeuralNetTorch_r71_BAG_L1_FULL        NaN     roc_auc            NaN    0.150465                     NaN           0.150465            1       True        293
# 283    NeuralNetTorch_r41_BAG_L2_FULL        NaN     roc_auc            NaN    7.289068                     NaN           0.290947            2       True        377
# 284    NeuralNetTorch_r41_BAG_L1_FULL        NaN     roc_auc            NaN    0.701702                     NaN           0.701702            1       True        268
# 285    NeuralNetTorch_r36_BAG_L2_FULL        NaN     roc_auc            NaN    7.261757                     NaN           0.263637            2       True        429
# 286    NeuralNetTorch_r36_BAG_L1_FULL        NaN     roc_auc            NaN    0.449929                     NaN           0.449929            1       True        320
# ...
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r103_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r156_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r95_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r37_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r134_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r34_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r111_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r65_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r88_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r30_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r160_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r69_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r138_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r172_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r127_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_r194_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r12_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r4_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r100_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r187_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L2_FULL': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3_FULL': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L3   0.978733     roc_auc       1.179322
#  1          WeightedEnsemble_L2   0.978222     roc_auc       0.417389
#  2          CatBoost_r49_BAG_L2   0.976920     roc_auc       0.776401
#  3         LightGBM_r188_BAG_L1   0.976869     roc_auc       0.031758
#  4           CatBoost_r5_BAG_L2   0.976205     roc_auc       0.759235
#  ..                         ...        ...         ...            ...
#  435   CatBoost_r12_BAG_L1_FULL        NaN     roc_auc            NaN
#  436  CatBoost_r128_BAG_L2_FULL        NaN     roc_auc            NaN
#  437  CatBoost_r128_BAG_L1_FULL        NaN     roc_auc            NaN
#  438       CatBoost_BAG_L2_FULL        NaN     roc_auc            NaN
#  439       CatBoost_BAG_L1_FULL        NaN     roc_auc            NaN
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0    106.422245                0.001034           0.051333            3
#  1     70.324866                0.000000           0.050179            2
#  2     85.434185                0.075465           6.982262            2
#  3      2.765587                0.031758           2.765587            1
#  4     86.394897                0.058299           7.942975            2
#  ..          ...                     ...                ...          ...
#  435    1.806742                     NaN           1.806742            1
#  436    8.406259                     NaN           1.408139            2
#  437    2.729391                     NaN           2.729391            1
#  438    9.258652                     NaN           2.260532            2
#  439    5.119596                     NaN           5.119596            1
#
#       can_infer  fit_order
#  0        False        220
#  1        False        111
#  2        False        164
#  3        False         27
#  4        False        180
#  ..         ...        ...
#  435       True        316
#  436       True        392
#  437       True        283
#  438       True        336
#  439       True        227
#
#  [440 rows x 10 columns]}

# %%
auxiliary_metrics = ['accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9857954545454546
# Evaluations on test data:
# {
#     "roc_auc": 0.9857954545454546,
#     "accuracy": 0.92,
#     "balanced_accuracy": 0.9188311688311688,
#     "mcc": 0.8376623376623377,
#     "f1": 0.9285714285714286,
#     "precision": 0.9285714285714286,
#     "recall": 0.9285714285714286
# }
# {'roc_auc': 0.9857954545454546,
#  'accuracy': 0.92,
#  'balanced_accuracy': 0.9188311688311688,
#  'mcc': 0.8376623376623377,
#  'f1': 0.9285714285714286,
#  'precision': 0.9285714285714286,
#  'recall': 0.9285714285714286}

# %%
predictor.model_best
# Out:
# 'WeightedEnsemble_L3_FULL'

# %%
predictors = predictor.leaderboard(
    df_test,
    extra_metrics = auxiliary_metrics,
    extra_info=True,
    silent=True
)

# %%
predictors[['model', 'roc_auc', 'accuracy', 'balanced_accuracy', 'f1', 'precision', 'recall', 'num_features']]
# Out:
#                            model   roc_auc  accuracy  balanced_accuracy  \
# 0        XGBoost_r49_BAG_L1_FULL  0.991477      0.94           0.941558
# 1       CatBoost_r13_BAG_L1_FULL  0.991477      0.93           0.932630
# 2        XGBoost_r95_BAG_L1_FULL  0.991477      0.94           0.939123
# 3      LightGBM_r130_BAG_L1_FULL  0.991071      0.94           0.941558
# 4      LightGBM_r135_BAG_L1_FULL  0.991071      0.94           0.941558
# ..                           ...       ...       ...                ...
# 435   NeuralNetFastAI_r88_BAG_L1       NaN       NaN                NaN
# 436  NeuralNetFastAI_r194_BAG_L1       NaN       NaN                NaN
# 437   NeuralNetFastAI_r69_BAG_L1       NaN       NaN                NaN
# 438  NeuralNetFastAI_r145_BAG_L1       NaN       NaN                NaN
# 439   NeuralNetFastAI_r95_BAG_L1       NaN       NaN                NaN
#
#            f1  precision    recall  num_features
# 0    0.945455   0.962963  0.928571            82
# 1    0.935780   0.962264  0.910714            82
# 2    0.946429   0.946429  0.946429            82
# 3    0.945455   0.962963  0.928571            82
# 4    0.945455   0.962963  0.928571            82
# ..        ...        ...       ...           ...
# 435       NaN        NaN       NaN            82
# 436       NaN        NaN       NaN            82
# 437       NaN        NaN       NaN            82
# 438       NaN        NaN       NaN            82
# 439       NaN        NaN       NaN            82
#
# [440 rows x 8 columns]

# %%
predictors.to_excel(
    '../../data/tlp/predictors-ctgan.xlsx',
    index=False
)

# %%
predictor.feature_importance(data=df_train)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['clin-Covid_sintomaSarpullido']
# Computing feature importance via permutation shuffling for 75 features using 396 rows with 5 shuffle sets...
# 	206.88s	= Expected runtime (41.38s per shuffle set)
# 	30.63s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                importance        stddev  \
# eval-TLP-Stroop-color-PD                     7.148693e-04  5.188522e-04
# eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD    1.021242e-05  2.283566e-05
# clin-reservaCognitiva_ocupacion              2.220446e-17  4.965068e-17
# demo-fechaEvaluacion                         2.220446e-17  4.965068e-17
# eval-TLP-Tavec-1_RI_A1-PD                    0.000000e+00  0.000000e+00
# ...                                                   ...           ...
# ques-MMSE-Total-PD                           0.000000e+00  0.000000e+00
# ques-Sus-total-PD                            0.000000e+00  0.000000e+00
# ques-Sus-totalImpar-PD                       0.000000e+00  0.000000e+00
# ques-Sus-totalPar-PD                         0.000000e+00  0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.000000e+00  0.000000e+00
#
#                                               p_value  n      p99_high  \
# eval-TLP-Stroop-color-PD                     0.018451  5  1.783193e-03
# eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD    0.186950  5  5.723136e-05
# clin-reservaCognitiva_ocupacion              0.186950  5  1.244359e-16
# demo-fechaEvaluacion                         0.186950  5  1.244359e-16
# eval-TLP-Tavec-1_RI_A1-PD                    0.500000  5  0.000000e+00
# ...                                               ... ..           ...
# ques-MMSE-Total-PD                           0.500000  5  0.000000e+00
# ques-Sus-total-PD                            0.500000  5  0.000000e+00
# ques-Sus-totalImpar-PD                       0.500000  5  0.000000e+00
# ques-Sus-totalPar-PD                         0.500000  5  0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.500000  5  0.000000e+00
#
#                                                   p99_low
# eval-TLP-Stroop-color-PD                    -3.534545e-04
# eval-TLP-Tavec-29_RCl_Cp_frente_RCl_LP-PD   -3.680652e-05
# clin-reservaCognitiva_ocupacion             -8.002698e-17
# demo-fechaEvaluacion                        -8.002698e-17
# eval-TLP-Tavec-1_RI_A1-PD                    0.000000e+00
# ...                                                   ...
# ques-MMSE-Total-PD                           0.000000e+00
# ques-Sus-total-PD                            0.000000e+00
# ques-Sus-totalImpar-PD                       0.000000e+00
# ques-Sus-totalPar-PD                         0.000000e+00
# eval-TLP-Tavec-33_Recon_Ac_frente_RCl_LP-PD  0.000000e+00
#
# [75 rows x 6 columns]
