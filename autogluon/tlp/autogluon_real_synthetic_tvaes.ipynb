# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../data/real/synthetic-tvaes.csv')

# %%
drop_columns = [
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]
pz_columns = [column for column in df.columns if 'PZ' in column ]
pdc_columns = [column for column in df.columns if 'PDC' in column]
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD  TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                             33.333333
# 1                           12.500000                              0.000000
# 2                           75.000000                             25.000000
# 3                           16.666667                              0.000000
# 4                           66.666667                              0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD  TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                           -33.333333
# 1                            0.000000                             0.000000
# 2                          -20.000000                             0.000000
# 3                           50.000000                           -20.000000
# 4                          -33.333333                             0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 68 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((376, 68), (94, 68))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/synthetic/tvaes/v1'
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/synthetic/tvaes/v1"

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 300,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       5.66 GB / 15.71 GB (36.1%)
# Disk Space Avail:   668.76 GB / 933.46 GB (71.6%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-17 00:05:05,748	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# 		Context path: "AutogluonModels/synthetic/tvaes/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=6168) Running DyStack sub-fit ...
# (_dystack pid=6168) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=6168) Beginning AutoGluon training ... Time limit = 67s
# (_dystack pid=6168) AutoGluon will save models to "AutogluonModels/synthetic/tvaes/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=6168) Train Data Rows:    334
# (_dystack pid=6168) Train Data Columns: 67
# (_dystack pid=6168) Label Column:       ED_2Clases
# (_dystack pid=6168) Problem Type:       binary
# (_dystack pid=6168) Preprocessing data ...
# (_dystack pid=6168) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=6168) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=6168) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=6168) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=6168) Using Feature Generators to preprocess the data ...
# (_dystack pid=6168) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=6168) 	Available Memory:                    5222.63 MB
# (_dystack pid=6168) 	Train Data (Original)  Memory Usage: 0.17 MB (0.0% of available memory)
# (_dystack pid=6168) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=6168) 	Stage 1 Generators:
# (_dystack pid=6168) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=6168) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=6168) 	Stage 2 Generators:
# (_dystack pid=6168) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=6168) 	Stage 3 Generators:
# (_dystack pid=6168) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=6168) 	Stage 4 Generators:
# (_dystack pid=6168) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=6168) 	Stage 5 Generators:
# (_dystack pid=6168) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=6168) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=6168) 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=6168) 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=6168) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=6168) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=6168) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=6168) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=6168) 	0.1s = Fit runtime
# (_dystack pid=6168) 	67 features in original data used to generate 67 features in processed data.
# (_dystack pid=6168) 	Train Data (Processed) Memory Usage: 0.15 MB (0.0% of available memory)
# (_dystack pid=6168) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=6168) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=6168) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=6168) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=6168) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=6168) User-specified model hyperparameters to be fit:
# (_dystack pid=6168) {
# (_dystack pid=6168) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=6168) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=6168) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=6168) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=6168) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=6168) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=6168) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=6168) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=6168) }
# (_dystack pid=6168) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=6168) Fitting 110 L1 models ...
# (_dystack pid=6168) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 44.83s of the 67.25s of remaining time.
# (_dystack pid=6168) 	0.7931	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.03s	 = Training   runtime
# (_dystack pid=6168) 	0.13s	 = Validation runtime
# (_dystack pid=6168) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 41.99s of the 64.42s of remaining time.
# (_dystack pid=6168) 	0.796	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.01s	 = Training   runtime
# (_dystack pid=6168) 	0.02s	 = Validation runtime
# (_dystack pid=6168) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 41.93s of the 64.35s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.27%)
# (_ray_fit pid=21536) [1000]	valid_set's binary_logloss: 0.0866565
# (_dystack pid=6168) 	0.9621	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	1.88s	 = Training   runtime
# (_dystack pid=6168) 	0.02s	 = Validation runtime
# (_dystack pid=6168) Fitting model: LightGBM_BAG_L1 ... Training model for up to 36.47s of the 58.89s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.28%)
# (_dystack pid=6168) 	0.9655	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	1.05s	 = Training   runtime
# (_dystack pid=6168) 	0.04s	 = Validation runtime
# (_dystack pid=6168) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 31.84s of the 54.27s of remaining time.
# (_dystack pid=6168) 	0.9433	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.94s	 = Training   runtime
# (_dystack pid=6168) 	0.08s	 = Validation runtime
# (_dystack pid=6168) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 30.76s of the 53.19s of remaining time.
# (_dystack pid=6168) 	0.9432	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.69s	 = Training   runtime
# (_dystack pid=6168) 	0.07s	 = Validation runtime
# (_dystack pid=6168) Fitting model: CatBoost_BAG_L1 ... Training model for up to 29.95s of the 52.38s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.53%)
# (_dystack pid=6168) 	0.9562	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	9.62s	 = Training   runtime
# (_dystack pid=6168) 	0.04s	 = Validation runtime
# (_dystack pid=6168) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 16.76s of the 39.19s of remaining time.
# (_dystack pid=6168) 	0.9227	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.7s	 = Training   runtime
# (_dystack pid=6168) 	0.08s	 = Validation runtime
# (_dystack pid=6168) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 15.93s of the 38.36s of remaining time.
# (_dystack pid=6168) 	0.928	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.7s	 = Training   runtime
# (_dystack pid=6168) 	0.08s	 = Validation runtime
# (_dystack pid=6168) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 15.1s of the 37.52s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# (_dystack pid=6168) 	0.9485	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	7.49s	 = Training   runtime
# (_dystack pid=6168) 	0.11s	 = Validation runtime
# (_dystack pid=6168) Fitting model: XGBoost_BAG_L1 ... Training model for up to 4.05s of the 26.48s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.05%)
# (_dystack pid=6168) 	0.9604	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	2.7s	 = Training   runtime
# (_dystack pid=6168) 	0.03s	 = Validation runtime
# (_dystack pid=6168) Fitting model: WeightedEnsemble_L2 ... Training model for up to 67.26s of the 19.49s of remaining time.
# (_dystack pid=6168) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.286, 'XGBoost_BAG_L1': 0.286, 'LightGBM_BAG_L1': 0.214, 'NeuralNetFastAI_BAG_L1': 0.214}
# (_dystack pid=6168) 	0.9716	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.07s	 = Training   runtime
# (_dystack pid=6168) 	0.0s	 = Validation runtime
# (_dystack pid=6168) Fitting 108 L2 models ...
# (_dystack pid=6168) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 19.4s of the 19.31s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.29%)
# (_dystack pid=6168) 	0.9636	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.86s	 = Training   runtime
# (_dystack pid=6168) 	0.02s	 = Validation runtime
# (_dystack pid=6168) Fitting model: LightGBM_BAG_L2 ... Training model for up to 14.94s of the 14.86s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.36%)
# (_dystack pid=6168) 	0.9624	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.92s	 = Training   runtime
# (_dystack pid=6168) 	0.02s	 = Validation runtime
# (_dystack pid=6168) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 10.35s of the 10.27s of remaining time.
# (_dystack pid=6168) 	0.966	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.86s	 = Training   runtime
# (_dystack pid=6168) 	0.07s	 = Validation runtime
# (_dystack pid=6168) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 9.37s of the 9.28s of remaining time.
# (_dystack pid=6168) 	0.9625	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.7s	 = Training   runtime
# (_dystack pid=6168) 	0.07s	 = Validation runtime
# (_dystack pid=6168) Fitting model: CatBoost_BAG_L2 ... Training model for up to 8.55s of the 8.47s of remaining time.
# (_dystack pid=6168) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.57%)
# (_dystack pid=6168) 	0.9678	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	7.0s	 = Training   runtime
# (_dystack pid=6168) 	0.07s	 = Validation runtime
# (_dystack pid=6168) Fitting model: WeightedEnsemble_L3 ... Training model for up to 67.26s of the -2.54s of remaining time.
# (_dystack pid=6168) 	Ensemble Weights: {'CatBoost_BAG_L2': 0.471, 'LightGBM_BAG_L1': 0.294, 'LightGBMXT_BAG_L1': 0.176, 'NeuralNetFastAI_BAG_L1': 0.059}
# (_dystack pid=6168) 	0.9726	 = Validation score   (roc_auc)
# (_dystack pid=6168) 	0.07s	 = Training   runtime
# (_dystack pid=6168) 	0.0s	 = Validation runtime
# (_dystack pid=6168) AutoGluon training complete, total runtime = 69.99s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 113.0 rows/s (42 batch size)
# (_dystack pid=6168) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/tvaes/v1\ds_sub_fit\sub_fit_ho")
# (_dystack pid=6168) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestEntr_BAG_L1       0.933107   0.943183     roc_auc        0.161635       0.073175   0.691104                 0.161635                0.073175           0.691104            1       True          6
# 1   RandomForestGini_BAG_L1       0.927438   0.943255     roc_auc        0.129110       0.078761   0.944602                 0.129110                0.078761           0.944602            1       True          5
# 2   RandomForestGini_BAG_L2       0.922902   0.965989     roc_auc        5.333001       0.782752  26.675259                 0.119992                0.072657           0.861541            2       True         15
# 3       WeightedEnsemble_L3       0.920635   0.972569     roc_auc        5.447715       0.776806  32.889407                 0.018486                0.000000           0.073136            3       True         18
# 4         LightGBMXT_BAG_L1       0.918367   0.962134     roc_auc        0.566524       0.023410   1.880640                 0.566524                0.023410           1.880640            1       True          3
# 5    NeuralNetFastAI_BAG_L1       0.918367   0.948508     roc_auc        2.472939       0.114305   7.494720                 2.472939                0.114305           7.494720            1       True         10
# 6         LightGBMXT_BAG_L2       0.918367   0.963569     roc_auc        5.385771       0.727355  26.676081                 0.172761                0.017260           0.862362            2       True         13
# 7           CatBoost_BAG_L2       0.918367   0.967764     roc_auc        5.429228       0.776806  32.816271                 0.216218                0.066711           7.002552            2       True         17
# 8           CatBoost_BAG_L1       0.916100   0.956182     roc_auc        0.935317       0.041949   9.615902                 0.935317                0.041949           9.615902            1       True          7
# 9           LightGBM_BAG_L1       0.913832   0.965469     roc_auc        0.206913       0.036158   1.051308                 0.206913                0.036158           1.051308            1       True          4
# 10           XGBoost_BAG_L1       0.913832   0.960377     roc_auc        0.344378       0.030736   2.702730                 0.344378                0.030736           2.702730            1       True         11
# 11      WeightedEnsemble_L2       0.913832   0.971601     roc_auc        3.605269       0.204608  13.200954                 0.014515                0.000000           0.071556            2       True         12
# 12  RandomForestEntr_BAG_L2       0.912698   0.962529     roc_auc        5.355432       0.783204  26.516121                 0.142422                0.073108           0.702402            2       True         16
# 13    ExtraTreesEntr_BAG_L1       0.905896   0.928016     roc_auc        0.134815       0.080632   0.695951                 0.134815                0.080632           0.695951            1       True          9
# 14    ExtraTreesGini_BAG_L1       0.897959   0.922745     roc_auc        0.111392       0.079804   0.698236                 0.111392                0.079804           0.698236            1       True          8
# 15          LightGBM_BAG_L2       0.891156   0.962367     roc_auc        5.383418       0.726630  26.737831                 0.170408                0.016534           0.924112            2       True         14
# 16    KNeighborsDist_BAG_L1       0.786848   0.796005     roc_auc        0.047722       0.022673   0.011764                 0.047722                0.022673           0.011764            1       True          2
# 17    KNeighborsUnif_BAG_L1       0.780045   0.793083     roc_auc        0.102265       0.128492   0.026761                 0.102265                0.128492           0.026761            1       True          1
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	86s	 = DyStack   runtime |	214s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 214s
# AutoGluon will save models to "AutogluonModels/synthetic/tvaes/v1"
# Train Data Rows:    376
# Train Data Columns: 67
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5328.91 MB
# 	Train Data (Original)  Memory Usage: 0.19 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])   : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# 	0.1s = Fit runtime
# 	67 features in original data used to generate 67 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 142.32s of the 213.52s of remaining time.
# 	0.7901	 = Validation score   (roc_auc)
# 	0.0s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 138.85s of the 210.05s of remaining time.
# 	0.7949	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 138.76s of the 209.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.24%)
# 	0.9465	 = Validation score   (roc_auc)
# 	1.13s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 134.02s of the 205.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.31%)
# 	0.9428	 = Validation score   (roc_auc)
# 	2.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 129.27s of the 200.47s of remaining time.
# 	0.9384	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 128.21s of the 199.42s of remaining time.
# 	0.938	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 127.33s of the 198.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.49%)
# 	0.9505	 = Validation score   (roc_auc)
# 	8.25s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 116.32s of the 187.52s of remaining time.
# 	0.926	 = Validation score   (roc_auc)
# 	0.73s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 115.45s of the 186.66s of remaining time.
# 	0.9233	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 114.66s of the 185.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.9385	 = Validation score   (roc_auc)
# 	6.87s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 105.02s of the 176.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.03%)
# 	0.9503	 = Validation score   (roc_auc)
# 	2.79s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 99.13s of the 170.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	0.9276	 = Validation score   (roc_auc)
# 	24.57s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 71.8s of the 143.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.26%)
# 	0.9218	 = Validation score   (roc_auc)
# 	2.91s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 66.02s of the 137.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.57%)
# 	0.949	 = Validation score   (roc_auc)
# 	6.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 56.62s of the 127.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	0.929	 = Validation score   (roc_auc)
# 	20.84s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 33.07s of the 104.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.53%)
# 	0.9431	 = Validation score   (roc_auc)
# 	2.89s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 27.21s of the 98.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.954	 = Validation score   (roc_auc)
# 	7.62s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 16.93s of the 88.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=4.32%)
# 	0.9389	 = Validation score   (roc_auc)
# 	14.62s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 213.53s of the 70.04s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.292, 'NeuralNetFastAI_r191_BAG_L1': 0.25, 'CatBoost_BAG_L1': 0.167, 'NeuralNetTorch_r79_BAG_L1': 0.167, 'LightGBMXT_BAG_L1': 0.042, 'NeuralNetFastAI_BAG_L1': 0.042, 'NeuralNetTorch_BAG_L1': 0.042}
# 	0.9658	 = Validation score   (roc_auc)
# 	0.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 69.92s of the 69.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.31%)
# 	0.9642	 = Validation score   (roc_auc)
# 	2.09s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 65.13s of the 65.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.38%)
# 	0.969	 = Validation score   (roc_auc)
# 	2.15s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 60.28s of the 60.2s of remaining time.
# 	0.9603	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 59.35s of the 59.27s of remaining time.
# 	0.9586	 = Validation score   (roc_auc)
# 	0.69s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 58.54s of the 58.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.62%)
# 	0.9651	 = Validation score   (roc_auc)
# 	13.35s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 42.56s of the 42.48s of remaining time.
# 	0.9612	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 41.69s of the 41.62s of remaining time.
# 	0.9571	 = Validation score   (roc_auc)
# 	0.67s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 40.89s of the 40.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.9507	 = Validation score   (roc_auc)
# 	6.95s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 31.21s of the 31.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.31%)
# 	0.9691	 = Validation score   (roc_auc)
# 	3.04s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 25.11s of the 25.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.03%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L2.
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 6.75s of the 6.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.67%)
# 	0.9603	 = Validation score   (roc_auc)
# 	3.65s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 213.53s of the -0.43s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L2': 0.5, 'LightGBM_BAG_L2': 0.188, 'LightGBMLarge_BAG_L2': 0.125, 'XGBoost_BAG_L1': 0.062, 'CatBoost_r177_BAG_L1': 0.062, 'NeuralNetFastAI_r191_BAG_L1': 0.062}
# 	0.9722	 = Validation score   (roc_auc)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 214.29s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 41.0 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/synthetic/tvaes/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L3   0.972159     roc_auc       1.734096  113.265240                0.000000           0.128968            3       True         30
# 1                XGBoost_BAG_L2   0.969103     roc_auc       1.656154  107.341305                0.036416           3.043483            2       True         28
# 2               LightGBM_BAG_L2   0.969046     roc_auc       1.653506  106.447157                0.033767           2.149335            2       True         21
# 3           WeightedEnsemble_L2   0.965821     roc_auc       0.757226   72.148252                0.000000           0.087811            2       True         19
# 4               CatBoost_BAG_L2   0.965113     roc_auc       1.675113  117.645760                0.055374          13.347938            2       True         24
# 5             LightGBMXT_BAG_L2   0.964236     roc_auc       1.641642  106.386161                0.021903           2.088340            2       True         20
# 6         ExtraTreesGini_BAG_L2   0.961152     roc_auc       1.699535  105.039675                0.079796           0.741853            2       True         25
# 7       RandomForestGini_BAG_L2   0.960317     roc_auc       1.691503  105.083103                0.071764           0.785281            2       True         22
# 8          LightGBMLarge_BAG_L2   0.960303     roc_auc       1.663913  107.943454                0.044174           3.645632            2       True         29
# 9       RandomForestEntr_BAG_L2   0.958563     roc_auc       1.695566  104.983585                0.075827           0.685763            2       True         23
# 10        ExtraTreesEntr_BAG_L2   0.957078     roc_auc       1.699639  104.970072                0.079900           0.672250            2       True         26
# 11  NeuralNetFastAI_r191_BAG_L1   0.954022     roc_auc       0.120235    7.621633                0.120235           7.621633            1       True         17
# 12       NeuralNetFastAI_BAG_L2   0.950712     roc_auc       1.731141  111.248862                0.111402           6.951040            2       True         27
# 13              CatBoost_BAG_L1   0.950542     roc_auc       0.074645    8.247495                0.074645           8.247495            1       True          7
# 14               XGBoost_BAG_L1   0.950344     roc_auc       0.035481    2.786930                0.035481           2.786930            1       True         11
# 15         CatBoost_r177_BAG_L1   0.948957     roc_auc       0.030988    6.752247                0.030988           6.752247            1       True         14
# 16            LightGBMXT_BAG_L1   0.946524     roc_auc       0.025137    1.129392                0.025137           1.129392            1       True          3
# 17         LightGBM_r131_BAG_L1   0.943100     roc_auc       0.024550    2.888549                0.024550           2.888549            1       True         16
# 18              LightGBM_BAG_L1   0.942818     roc_auc       0.026630    2.003049                0.026630           2.003049            1       True          4
# 19           CatBoost_r9_BAG_L1   0.938856     roc_auc       0.089932   14.619207                0.089932          14.619207            1       True         18
# 20       NeuralNetFastAI_BAG_L1   0.938517     roc_auc       0.101497    6.866154                0.101497           6.866154            1       True         10
# 21      RandomForestGini_BAG_L1   0.938361     roc_auc       0.085975    0.908376                0.085975           0.908376            1       True          5
# 22      RandomForestEntr_BAG_L1   0.937979     roc_auc       0.082094    0.741915                0.082094           0.741915            1       True          6
# 23    NeuralNetTorch_r79_BAG_L1   0.928953     roc_auc       0.207831   20.838110                0.207831          20.838110            1       True         15
# 24        NeuralNetTorch_BAG_L1   0.927624     roc_auc       0.192401   24.570727                0.192401          24.570727            1       True         12
# 25        ExtraTreesGini_BAG_L1   0.926011     roc_auc       0.082721    0.732270                0.082721           0.732270            1       True          8
# 26        ExtraTreesEntr_BAG_L1   0.923266     roc_auc       0.076215    0.666256                0.076215           0.666256            1       True          9
# 27         LightGBMLarge_BAG_L1   0.921767     roc_auc       0.018958    2.913490                0.018958           2.913490            1       True         13
# 28        KNeighborsDist_BAG_L1   0.794924     roc_auc       0.029042    0.012021                0.029042           0.012021            1       True          2
# 29        KNeighborsUnif_BAG_L1   0.790114     roc_auc       0.315408    0.000000                0.315408           0.000000            1       True          1
# Number of models trained: 30
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.790114025408143,
#   'KNeighborsDist_BAG_L1': 0.794924030218148,
#   'LightGBMXT_BAG_L1': 0.9465240641711229,
#   'LightGBM_BAG_L1': 0.9428175310528252,
#   'RandomForestGini_BAG_L1': 0.9383612030670854,
#   'RandomForestEntr_BAG_L1': 0.9379792320968791,
#   'CatBoost_BAG_L1': 0.9505418328947741,
#   'ExtraTreesGini_BAG_L1': 0.9260108083637496,
#   'ExtraTreesEntr_BAG_L1': 0.9232662762074527,
#   'NeuralNetFastAI_BAG_L1': 0.9385168208697621,
#   'XGBoost_BAG_L1': 0.9503437738731855,
#   'NeuralNetTorch_BAG_L1': 0.9276235746823982,
#   'LightGBMLarge_BAG_L1': 0.9217666864725689,
#   'CatBoost_r177_BAG_L1': 0.9489573607220665,
#   'NeuralNetTorch_r79_BAG_L1': 0.9289533995416349,
#   'LightGBM_r131_BAG_L1': 0.9431004725122373,
#   'NeuralNetFastAI_r191_BAG_L1': 0.9540220128455422,
#   'CatBoost_r9_BAG_L1': 0.9388563506210564,
#   'WeightedEnsemble_L2': 0.9658206717030248,
#   'LightGBMXT_BAG_L2': 0.9642361995303173,
#   'LightGBM_BAG_L2': 0.969046204340322,
#   'RandomForestGini_BAG_L2': 0.9603174603174605,
#   'RandomForestEntr_BAG_L2': 0.9585632232691057,
#   'CatBoost_BAG_L2': 0.9651133180544945,
#   'ExtraTreesGini_BAG_L2': 0.9611521376227258,
#   'ExtraTreesEntr_BAG_L2': 0.9570777806071924,
#   'NeuralNetFastAI_BAG_L2': 0.9507115977704212,
#   'XGBoost_BAG_L2': 0.9691027926322043,
#   'LightGBMLarge_BAG_L2': 0.9603033132444897,
#   'WeightedEnsemble_L3': 0.9721585603938545},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.01202082633972168,
#   'LightGBMXT_BAG_L1': 1.1293919086456299,
#   'LightGBM_BAG_L1': 2.003048896789551,
#   'RandomForestGini_BAG_L1': 0.9083759784698486,
#   'RandomForestEntr_BAG_L1': 0.741915225982666,
#   'CatBoost_BAG_L1': 8.247495412826538,
#   'ExtraTreesGini_BAG_L1': 0.7322704792022705,
#   'ExtraTreesEntr_BAG_L1': 0.6662564277648926,
#   'NeuralNetFastAI_BAG_L1': 6.866153717041016,
#   'XGBoost_BAG_L1': 2.7869298458099365,
#   'NeuralNetTorch_BAG_L1': 24.570727348327637,
#   'LightGBMLarge_BAG_L1': 2.913490056991577,
#   'CatBoost_r177_BAG_L1': 6.752246618270874,
#   'NeuralNetTorch_r79_BAG_L1': 20.83811044692993,
#   'LightGBM_r131_BAG_L1': 2.8885486125946045,
#   'NeuralNetFastAI_r191_BAG_L1': 7.621633052825928,
#   'CatBoost_r9_BAG_L1': 14.61920690536499,
#   'WeightedEnsemble_L2': 0.08781051635742188,
#   'LightGBMXT_BAG_L2': 2.0883395671844482,
#   'LightGBM_BAG_L2': 2.1493351459503174,
#   'RandomForestGini_BAG_L2': 0.7852811813354492,
#   'RandomForestEntr_BAG_L2': 0.6857633590698242,
#   'CatBoost_BAG_L2': 13.347938060760498,
#   'ExtraTreesGini_BAG_L2': 0.7418532371520996,
#   'ExtraTreesEntr_BAG_L2': 0.6722502708435059,
#   'NeuralNetFastAI_BAG_L2': 6.951039791107178,
#   'XGBoost_BAG_L2': 3.0434834957122803,
#   'LightGBMLarge_BAG_L2': 3.645631790161133,
#   'WeightedEnsemble_L3': 0.1289677619934082},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.31540822982788086,
#   'KNeighborsDist_BAG_L1': 0.029041767120361328,
#   'LightGBMXT_BAG_L1': 0.025136947631835938,
#   'LightGBM_BAG_L1': 0.026629924774169922,
#   'RandomForestGini_BAG_L1': 0.08597469329833984,
#   'RandomForestEntr_BAG_L1': 0.08209443092346191,
#   'CatBoost_BAG_L1': 0.07464456558227539,
#   'ExtraTreesGini_BAG_L1': 0.08272123336791992,
#   'ExtraTreesEntr_BAG_L1': 0.07621455192565918,
#   'NeuralNetFastAI_BAG_L1': 0.10149741172790527,
#   'XGBoost_BAG_L1': 0.03548073768615723,
#   'NeuralNetTorch_BAG_L1': 0.19240093231201172,
#   'LightGBMLarge_BAG_L1': 0.018957853317260742,
#   'CatBoost_r177_BAG_L1': 0.03098773956298828,
#   'NeuralNetTorch_r79_BAG_L1': 0.20783066749572754,
#   'LightGBM_r131_BAG_L1': 0.02454996109008789,
#   'NeuralNetFastAI_r191_BAG_L1': 0.12023496627807617,
#   'CatBoost_r9_BAG_L1': 0.08993220329284668,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.021902799606323242,
#   'LightGBM_BAG_L2': 0.033766984939575195,
#   'RandomForestGini_BAG_L2': 0.07176446914672852,
#   'RandomForestEntr_BAG_L2': 0.07582736015319824,
#   'CatBoost_BAG_L2': 0.0553743839263916,
#   'ExtraTreesGini_BAG_L2': 0.07979607582092285,
#   'ExtraTreesEntr_BAG_L2': 0.07990026473999023,
#   'NeuralNetFastAI_BAG_L2': 0.11140203475952148,
#   'XGBoost_BAG_L2': 0.03641557693481445,
#   'LightGBMLarge_BAG_L2': 0.0441744327545166,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L3   0.972159     roc_auc       1.734096
#  1                XGBoost_BAG_L2   0.969103     roc_auc       1.656154
#  2               LightGBM_BAG_L2   0.969046     roc_auc       1.653506
#  3           WeightedEnsemble_L2   0.965821     roc_auc       0.757226
#  4               CatBoost_BAG_L2   0.965113     roc_auc       1.675113
#  5             LightGBMXT_BAG_L2   0.964236     roc_auc       1.641642
#  6         ExtraTreesGini_BAG_L2   0.961152     roc_auc       1.699535
#  7       RandomForestGini_BAG_L2   0.960317     roc_auc       1.691503
#  8          LightGBMLarge_BAG_L2   0.960303     roc_auc       1.663913
#  9       RandomForestEntr_BAG_L2   0.958563     roc_auc       1.695566
#  10        ExtraTreesEntr_BAG_L2   0.957078     roc_auc       1.699639
#  11  NeuralNetFastAI_r191_BAG_L1   0.954022     roc_auc       0.120235
#  12       NeuralNetFastAI_BAG_L2   0.950712     roc_auc       1.731141
#  13              CatBoost_BAG_L1   0.950542     roc_auc       0.074645
#  14               XGBoost_BAG_L1   0.950344     roc_auc       0.035481
#  15         CatBoost_r177_BAG_L1   0.948957     roc_auc       0.030988
#  16            LightGBMXT_BAG_L1   0.946524     roc_auc       0.025137
#  17         LightGBM_r131_BAG_L1   0.943100     roc_auc       0.024550
#  18              LightGBM_BAG_L1   0.942818     roc_auc       0.026630
#  19           CatBoost_r9_BAG_L1   0.938856     roc_auc       0.089932
#  20       NeuralNetFastAI_BAG_L1   0.938517     roc_auc       0.101497
#  21      RandomForestGini_BAG_L1   0.938361     roc_auc       0.085975
#  22      RandomForestEntr_BAG_L1   0.937979     roc_auc       0.082094
#  23    NeuralNetTorch_r79_BAG_L1   0.928953     roc_auc       0.207831
#  24        NeuralNetTorch_BAG_L1   0.927624     roc_auc       0.192401
#  25        ExtraTreesGini_BAG_L1   0.926011     roc_auc       0.082721
#  26        ExtraTreesEntr_BAG_L1   0.923266     roc_auc       0.076215
#  27         LightGBMLarge_BAG_L1   0.921767     roc_auc       0.018958
#  28        KNeighborsDist_BAG_L1   0.794924     roc_auc       0.029042
#  29        KNeighborsUnif_BAG_L1   0.790114     roc_auc       0.315408
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   113.265240                0.000000           0.128968            3
#  1   107.341305                0.036416           3.043483            2
#  2   106.447157                0.033767           2.149335            2
#  3    72.148252                0.000000           0.087811            2
#  4   117.645760                0.055374          13.347938            2
#  5   106.386161                0.021903           2.088340            2
#  6   105.039675                0.079796           0.741853            2
#  7   105.083103                0.071764           0.785281            2
#  8   107.943454                0.044174           3.645632            2
#  9   104.983585                0.075827           0.685763            2
#  10  104.970072                0.079900           0.672250            2
#  11    7.621633                0.120235           7.621633            1
#  12  111.248862                0.111402           6.951040            2
#  13    8.247495                0.074645           8.247495            1
#  14    2.786930                0.035481           2.786930            1
#  15    6.752247                0.030988           6.752247            1
#  16    1.129392                0.025137           1.129392            1
#  17    2.888549                0.024550           2.888549            1
#  18    2.003049                0.026630           2.003049            1
#  19   14.619207                0.089932          14.619207            1
#  20    6.866154                0.101497           6.866154            1
#  21    0.908376                0.085975           0.908376            1
#  22    0.741915                0.082094           0.741915            1
#  23   20.838110                0.207831          20.838110            1
#  24   24.570727                0.192401          24.570727            1
#  25    0.732270                0.082721           0.732270            1
#  26    0.666256                0.076215           0.666256            1
#  27    2.913490                0.018958           2.913490            1
#  28    0.012021                0.029042           0.012021            1
#  29    0.000000                0.315408           0.000000            1
#
#      can_infer  fit_order
#  0        True         30
#  1        True         28
#  2        True         21
#  3        True         19
#  4        True         24
#  5        True         20
#  6        True         25
#  7        True         22
#  8        True         29
#  9        True         23
#  10       True         26
#  11       True         17
#  12       True         27
#  13       True          7
#  14       True         11
#  15       True         14
#  16       True          3
#  17       True         16
#  18       True          4
#  19       True         18
#  20       True         10
#  21       True          5
#  22       True          6
#  23       True         15
#  24       True         12
#  25       True          8
#  26       True          9
#  27       True         13
#  28       True          2
#  29       True          1  }

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.9678442028985508
# Evaluations on test data:
# {
#     "roc_auc": 0.9678442028985508,
#     "accuracy": 0.925531914893617,
#     "balanced_accuracy": 0.926177536231884,
#     "mcc": 0.8529347087582083,
#     "f1": 0.9247311827956989,
#     "precision": 0.9555555555555556,
#     "recall": 0.8958333333333334
# }
# {'roc_auc': 0.9678442028985508,
#  'accuracy': 0.925531914893617,
#  'balanced_accuracy': 0.926177536231884,
#  'mcc': 0.8529347087582083,
#  'f1': 0.9247311827956989,
#  'precision': 0.9555555555555556,
#  'recall': 0.8958333333333334}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                           model  score_test  balanced_accuracy        f1  \
# 0               LightGBM_BAG_L1    1.000000           1.000000  1.000000
# 1             LightGBMXT_BAG_L1    1.000000           1.000000  1.000000
# 2         KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 3          LightGBMLarge_BAG_L1    1.000000           1.000000  1.000000
# 4          CatBoost_r177_BAG_L1    1.000000           1.000000  1.000000
# 5               CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 6            CatBoost_r9_BAG_L1    1.000000           1.000000  1.000000
# 7       RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 8          LightGBM_r131_BAG_L1    1.000000           1.000000  1.000000
# 9       RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# 10               XGBoost_BAG_L1    1.000000           1.000000  1.000000
# 11        ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 12       NeuralNetFastAI_BAG_L1    1.000000           1.000000  1.000000
# 13        ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 14  NeuralNetFastAI_r191_BAG_L1    1.000000           0.997326  0.997319
# 15          WeightedEnsemble_L2    1.000000           1.000000  1.000000
# 16              LightGBM_BAG_L2    1.000000           1.000000  1.000000
# 17         LightGBMLarge_BAG_L2    1.000000           1.000000  1.000000
# 18               XGBoost_BAG_L2    1.000000           1.000000  1.000000
# 19      RandomForestEntr_BAG_L2    1.000000           1.000000  1.000000
# 20        ExtraTreesEntr_BAG_L2    1.000000           1.000000  1.000000
# 21      RandomForestGini_BAG_L2    1.000000           1.000000  1.000000
# 22          WeightedEnsemble_L3    1.000000           1.000000  1.000000
# 23            LightGBMXT_BAG_L2    1.000000           1.000000  1.000000
# 24        ExtraTreesGini_BAG_L2    1.000000           1.000000  1.000000
# 25              CatBoost_BAG_L2    1.000000           1.000000  1.000000
# 26       NeuralNetFastAI_BAG_L2    1.000000           1.000000  1.000000
# 27        NeuralNetTorch_BAG_L1    0.999462           0.986688  0.986595
# 28    NeuralNetTorch_r79_BAG_L1    0.997821           0.981397  0.981333
# 29        KNeighborsUnif_BAG_L1    0.905993           0.830179  0.840796
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 3   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 5   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 6   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 7   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 8   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 9   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 10  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 11  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 12  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 13  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 14  0.997340  0.997340  1.000000           1.000000   1.000000  0.994652  ...
# 15  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 16  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 17  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 18  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 19  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 20  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 21  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 22  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 23  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 24  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 25  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 26  1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 27  0.986701  0.986702  0.999462           0.999465   0.989247  0.983957  ...
# 28  0.981383  0.981383  0.997821           0.997914   0.978723  0.983957  ...
# 29  0.828969  0.829787  0.905993           0.877706   0.786047  0.903743  ...
#
#     eval_metric  pred_time_test  pred_time_val    fit_time  \
# 0       roc_auc        0.028361       0.026630    2.003049
# 1       roc_auc        0.039565       0.025137    1.129392
# 2       roc_auc        0.044432       0.029042    0.012021
# 3       roc_auc        0.051270       0.018958    2.913490
# 4       roc_auc        0.055422       0.030988    6.752247
# 5       roc_auc        0.063430       0.074645    8.247495
# 6       roc_auc        0.071735       0.089932   14.619207
# 7       roc_auc        0.079579       0.082094    0.741915
# 8       roc_auc        0.082900       0.024550    2.888549
# 9       roc_auc        0.112995       0.085975    0.908376
# 10      roc_auc        0.142248       0.035481    2.786930
# 11      roc_auc        0.158735       0.076215    0.666256
# 12      roc_auc        0.160847       0.101497    6.866154
# 13      roc_auc        0.201105       0.082721    0.732270
# 14      roc_auc        0.232507       0.120235    7.621633
# 15      roc_auc        1.312698       0.757226   72.148252
# 16      roc_auc        2.257938       1.653506  106.447157
# 17      roc_auc        2.271146       1.663913  107.943454
# 18      roc_auc        2.341508       1.656154  107.341305
# 19      roc_auc        2.349812       1.695566  104.983585
# 20      roc_auc        2.350631       1.699639  104.970072
# 21      roc_auc        2.350976       1.691503  105.083103
# 22      roc_auc        2.423204       1.734096  113.265240
# 23      roc_auc        2.426385       1.641642  106.386161
# 24      roc_auc        2.511096       1.699535  105.039675
# 25      roc_auc        2.573457       1.675113  117.645760
# 26      roc_auc        2.617986       1.731141  111.248862
# 27      roc_auc        0.316267       0.192401   24.570727
# 28      roc_auc        0.351820       0.207831   20.838110
# 29      roc_auc        0.030477       0.315408    0.000000
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.028361                0.026630           2.003049
# 1                  0.039565                0.025137           1.129392
# 2                  0.044432                0.029042           0.012021
# 3                  0.051270                0.018958           2.913490
# 4                  0.055422                0.030988           6.752247
# 5                  0.063430                0.074645           8.247495
# 6                  0.071735                0.089932          14.619207
# 7                  0.079579                0.082094           0.741915
# 8                  0.082900                0.024550           2.888549
# 9                  0.112995                0.085975           0.908376
# 10                 0.142248                0.035481           2.786930
# 11                 0.158735                0.076215           0.666256
# 12                 0.160847                0.101497           6.866154
# 13                 0.201105                0.082721           0.732270
# 14                 0.232507                0.120235           7.621633
# 15                 0.006014                0.000000           0.087811
# 16                 0.034244                0.033767           2.149335
# 17                 0.047452                0.044174           3.645632
# 18                 0.117814                0.036416           3.043483
# 19                 0.126117                0.075827           0.685763
# 20                 0.126936                0.079900           0.672250
# 21                 0.127282                0.071764           0.785281
# 22                 0.000000                0.000000           0.128968
# 23                 0.202691                0.021903           2.088340
# 24                 0.287402                0.079796           0.741853
# 25                 0.349763                0.055374          13.347938
# 26                 0.394292                0.111402           6.951040
# 27                 0.316267                0.192401          24.570727
# 28                 0.351820                0.207831          20.838110
# 29                 0.030477                0.315408           0.000000
#
#     stack_level  can_infer  fit_order
# 0             1       True          4
# 1             1       True          3
# 2             1       True          2
# 3             1       True         13
# 4             1       True         14
# 5             1       True          7
# 6             1       True         18
# 7             1       True          6
# 8             1       True         16
# 9             1       True          5
# 10            1       True         11
# 11            1       True          9
# 12            1       True         10
# 13            1       True          8
# 14            1       True         17
# 15            2       True         19
# 16            2       True         21
# 17            2       True         29
# 18            2       True         28
# 19            2       True         23
# 20            2       True         26
# 21            2       True         22
# 22            3       True         30
# 23            2       True         20
# 24            2       True         25
# 25            2       True         24
# 26            2       True         27
# 27            1       True         12
# 28            1       True         15
# 29            1       True          1
#
# [30 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 67 features using 376 rows with 5 shuffle sets...
# 	829.94s	= Expected runtime (165.99s per shuffle set)
# 	122.09s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.Stroop.color.PD                       0.015466  0.001541  0.000012  5
# ISC.FPacientes.Edad                       0.000526  0.000244  0.004246  5
# TLP.FigRey.Copia.PD                       0.000334  0.000451  0.086641  5
# TLP.CubCorsi.Directos.PD                  0.000124  0.000099  0.024273  5
# TLP.Stroop.palabras.PD                    0.000034  0.000076  0.186950  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Memoria.PD                       0.000000  0.000000  0.500000  5
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.Stroop.color.PD                     0.018639  0.012293
# ISC.FPacientes.Edad                     0.001028  0.000024
# TLP.FigRey.Copia.PD                     0.001263 -0.000595
# TLP.CubCorsi.Directos.PD                0.000329 -0.000080
# TLP.Stroop.palabras.PD                  0.000190 -0.000122
# ...                                          ...       ...
# TLP.MMSE.Memoria.PD                     0.000000  0.000000
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [67 rows x 6 columns]
# 2025-01-17 00:30:27,314	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:30:27,317	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-01-17 00:30:27,321	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
