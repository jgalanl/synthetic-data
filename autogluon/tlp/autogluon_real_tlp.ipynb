# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('../../data/real/TLP_Identia.xlsx')

# %%
drop_columns = [
    'ISC.FPacientes.IDUsuario',
    'ISC.FPacientes.etiquetaDiagnosticaExpTLP',
    'ISC.FPacientes.etiquetaDiagnostica',
    'ED_MMSE_2Clases',
    'ISC.resultadosCovid.numDosis',
    'ISC.resultadosCovid.numVecesCovid',
    'ISC.resultadosCovid.numVecesCovid_mode',
    'ISC.resultadosCovid.pasadoCovid',
    'ISC.resultadosCovid.sentimientoAislado',
    'ISC.resultadosCovid.sentimientoAislado_mediaFiltro',
    'ISC.resultadosCovid.sentimientoAislado_mode',
    'ISC.resultadosCovid.sintomaCansancio',
    'ISC.resultadosCovid.sintomaDiarrea',
    'ISC.resultadosCovid.sintomaDifRespirar',
    'ISC.resultadosCovid.sintomaDolCabeza',
    'ISC.resultadosCovid.sintomaDolGarganta',
    'ISC.resultadosCovid.sintomaDolMuscular',
    'ISC.resultadosCovid.sintomaEscalofrios',
    'ISC.resultadosCovid.sintomaFiebre',
    'ISC.resultadosCovid.sintomaOtro',
    'ISC.resultadosCovid.sintomaOtroString',
    'ISC.resultadosCovid.sintomaPerGusto',
    'ISC.resultadosCovid.sintomaPerOlfato',
    'ISC.resultadosCovid.vacunado',
    'ISC.resultadosObservacion.añosSinFumar',
    'ISC.resultadosObservacion.añosSinFumar_Rangos',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_knn',
    'ISC.resultadosObservacion.consumoAlcohol_UBEsemanal_mode&rangoEdad',
    'ISC.resultadosObservacion.enfermedadesAltTiroides',
    'ISC.resultadosObservacion.enfermedadesAntecedentesCardiacos',
    'ISC.resultadosObservacion.enfermedadesCardiopatiaIsquemica',
    'ISC.resultadosObservacion.enfermedadesHepatica',
    'ISC.resultadosObservacion.enfermedadesNinguna',
    'ISC.resultadosObservacion.enfermedadesOtros',
    'ISC.resultadosObservacion.enfermedadesRenal',
    'ISC.resultadosObservacion.entorno',
    'ISC.resultadosObservacion.familiaresAlzheimer',
    'ISC.resultadosObservacion.familiaresOtraDemencia',
    'ISC.resultadosObservacion.fumador',
    'ISC.resultadosObservacion.numCigarros',
    'ISC.resultadosObservacion.numCigarrosDia_knn',
    'ISC.resultadosObservacion.numCigarrosDia_mode&rangoEdad',
    'ISC.resultadosObservacion.tratCronico',
    'ISC.resultadosObservacion.tratPsicologic',
    'ISC.resultadosObservacion.tratPsiquiatrico',
    'ISC.resultadosOtros.frecOlvidos',
    'ISC.resultadosOtros.frecUsoEmail',
    'ISC.resultadosOtros.frecUsoMovil',
    'ISC.resultadosOtros.frecUsoOrdenador',
    'ISC.resultadosOtros.frecUsoRSociales',
    'ISC.resultadosOtros.frecUsoTele',
    'ISC.resultadosOtros.nivelActFisica',
    'ISC.resultadosOtros.nivelSociabilidad',
    'ISC.resultadosReservaCognitiva.actividadLectora',
    'ISC.resultadosReservaCognitiva.cursos',
    'ISC.resultadosReservaCognitiva.escolaridadPadres',
    'ISC.resultadosReservaCognitiva.formacionMusical',
    'ISC.resultadosReservaCognitiva.juegos',
    'ISC.resultadosWFQ.DE_array'
]

# %%
pt_columns = [column for column in df.columns if 'PT' in column ]

# %%
pz_columns = [column for column in df.columns if 'PZ' in column ]

# %%
pdc_columns = [column for column in df.columns if 'PDC' in column]

# %%
drop_columns.extend(pt_columns)
drop_columns.extend(pz_columns)
drop_columns.extend(pdc_columns)

# %%
df.drop(columns=drop_columns, inplace=True)
df.replace([np.inf, -np.inf], 0, inplace=True)
df.head()
# Out:
#   ED_2Clases  ISC.FPacientes.genero  ISC.FPacientes.Edad  \
# 0          D                      2                   82
# 1          D                      2                   75
# 2          H                      2                   72
# 3          D                      2                   60
# 4          D                      2                   64
#
#    ISC.resultadosCribaje.Total.PD  ISC.resultadosObservacion.alcohol  \
# 0                              16                                  0
# 1                              16                                  0
# 2                              14                                  0
# 3                              11                                  0
# 4                              14                                  0
#
#    ISC.resultadosObservacion.ansiedad  ISC.resultadosObservacion.depresion  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    ISC.resultadosObservacion.enfermedadesDiabetes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    ISC.resultadosObservacion.enfermedadesHipercolesterolemia  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ISC.resultadosObservacion.enfermedadesHipertension  ...  \
# 0                                                  0   ...
# 1                                                  0   ...
# 2                                                  0   ...
# 3                                                  0   ...
# 4                                                  0   ...
#
#    TLP.Tavec.23_FP.PD  TLP.Tavec.24_Discriminabilidad.PD  \
# 0                   4                          84.090909
# 1                   3                          79.545455
# 2                   1                          88.636364
# 3                   4                          90.909091
# 4                   0                          86.363636
#
#    TLP.Tavec.25_Sesgo.PD  TLP.Tavec.26_RI-B_frente_RI-A1.PD  \
# 0               0.142857                         -20.000000
# 1              -0.333333                         -71.428571
# 2              -0.600000                         -14.285714
# 3               0.600000                          60.000000
# 4              -0.714286                           0.000000
#
#    TLP.Tavec.27_RL-CP_frente_RI-A5.PD TLP.Tavec.28_RCl-Cp_frente_RCl-LP.PD  \
# 0                            0.000000                            33.333333
# 1                           12.500000                             0.000000
# 2                           75.000000                            25.000000
# 3                           16.666667                             0.000000
# 4                           66.666667                             0.000000
#
#    TLP.Tavec.29_RL-LP_frente_RL-CP.PD TLP.Tavec.30_RCl-LP_frente_RL-LP.PD  \
# 0                           37.500000                          -33.333333
# 1                            0.000000                            0.000000
# 2                          -20.000000                            0.000000
# 3                           50.000000                          -20.000000
# 4                          -33.333333                            0.000000
#
#    TLP.Tavec.31_Recon-Ac_frente_RL-LP.PD  \
# 0                             -38.461538
# 1                             -20.000000
# 2                             -16.666667
# 3                             -50.000000
# 4                             -10.000000
#
#    TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD
# 0                               -7.692308
# 1                              -20.000000
# 2                              -16.666667
# 3                              -37.500000
# 4                              -10.000000
#
# [5 rows x 70 columns]

# %%
df_train, df_test=train_test_split(df, test_size=0.2, random_state=42)
df_train.shape, df_test.shape
# Out:
# ((247, 70), (62, 70))

# %%
predictor= TabularPredictor(
    label='ED_2Clases',
    problem_type='binary',
    eval_metric='roc_auc',
    sample_weight='balance_weight',
    path='AutogluonModels/real/tlp/v1'
    )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/real/tlp/v1"

# %%
predictor.fit(
    train_data = df_train,
    presets = ['best_quality'],
    time_limit = 300,
    auto_stack = True,
    verbosity = 2
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          20
# Memory Avail:       8.68 GB / 15.71 GB (55.2%)
# Disk Space Avail:   668.11 GB / 933.46 GB (71.6%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-01-16 00:18:00,305	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/real/tlp/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=2408) Running DyStack sub-fit ...
# (_dystack pid=2408) Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# (_dystack pid=2408) Beginning AutoGluon training ... Time limit = 57s
# (_dystack pid=2408) AutoGluon will save models to "AutogluonModels/real/tlp/v1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=2408) Train Data Rows:    219
# (_dystack pid=2408) Train Data Columns: 69
# (_dystack pid=2408) Label Column:       ED_2Clases
# (_dystack pid=2408) Problem Type:       binary
# (_dystack pid=2408) Preprocessing data ...
# (_dystack pid=2408) Selected class <--> label mapping:  class 1 = H, class 0 = D
# (_dystack pid=2408) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# (_dystack pid=2408) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=2408) Assigning sample weights to balance differences in frequency of classes.
# (_dystack pid=2408) Using Feature Generators to preprocess the data ...
# (_dystack pid=2408) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=2408) 	Available Memory:                    8216.27 MB
# (_dystack pid=2408) 	Train Data (Original)  Memory Usage: 0.14 MB (0.0% of available memory)
# (_dystack pid=2408) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=2408) 	Stage 1 Generators:
# (_dystack pid=2408) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=2408) 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=2408) 	Stage 2 Generators:
# (_dystack pid=2408) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=2408) 	Stage 3 Generators:
# (_dystack pid=2408) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=2408) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=2408) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=2408) 	Stage 4 Generators:
# (_dystack pid=2408) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=2408) 	Stage 5 Generators:
# (_dystack pid=2408) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=2408) 	Unused Original Features (Count: 1): ['ISC.resultadosWFQ.NO_array']
# (_dystack pid=2408) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=2408) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=2408) 		These features do not need to be present at inference time.
# (_dystack pid=2408) 		('object', []) : 1 | ['ISC.resultadosWFQ.NO_array']
# (_dystack pid=2408) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=2408) 		('float', [])  : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=2408) 		('int', [])    : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# (_dystack pid=2408) 		('object', []) :  1 | ['ISC.resultadosWFQ.SA_array']
# (_dystack pid=2408) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=2408) 		('category', [])  :  1 | ['ISC.resultadosWFQ.SA_array']
# (_dystack pid=2408) 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# (_dystack pid=2408) 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# (_dystack pid=2408) 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# (_dystack pid=2408) 	0.1s = Fit runtime
# (_dystack pid=2408) 	68 features in original data used to generate 68 features in processed data.
# (_dystack pid=2408) 	Train Data (Processed) Memory Usage: 0.10 MB (0.0% of available memory)
# (_dystack pid=2408) Data preprocessing and feature engineering runtime = 0.13s ...
# (_dystack pid=2408) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=2408) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=2408) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=2408) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=2408) User-specified model hyperparameters to be fit:
# (_dystack pid=2408) {
# (_dystack pid=2408) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=2408) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=2408) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=2408) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=2408) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=2408) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=2408) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=2408) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=2408) }
# (_dystack pid=2408) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=2408) Fitting 110 L1 models ...
# (_dystack pid=2408) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 37.73s of the 56.6s of remaining time.
# (_dystack pid=2408) 	0.7209	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	0.01s	 = Training   runtime
# (_dystack pid=2408) 	0.15s	 = Validation runtime
# (_dystack pid=2408) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 34.66s of the 53.53s of remaining time.
# (_dystack pid=2408) 	0.7187	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	0.02s	 = Training   runtime
# (_dystack pid=2408) 	0.03s	 = Validation runtime
# (_dystack pid=2408) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 34.58s of the 53.45s of remaining time.
# (_dystack pid=2408) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# (_dystack pid=2408) 	0.9294	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	4.34s	 = Training   runtime
# (_dystack pid=2408) 	0.1s	 = Validation runtime
# (_dystack pid=2408) Fitting model: LightGBM_BAG_L1 ... Training model for up to 18.73s of the 37.6s of remaining time.
# (_dystack pid=2408) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# (_dystack pid=2408) 	0.92	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	3.43s	 = Training   runtime
# (_dystack pid=2408) 	0.12s	 = Validation runtime
# (_dystack pid=2408) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 3.6s of the 22.47s of remaining time.
# (_dystack pid=2408) 	0.9003	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	2.01s	 = Training   runtime
# (_dystack pid=2408) 	0.09s	 = Validation runtime
# (_dystack pid=2408) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1.39s of the 20.26s of remaining time.
# (_dystack pid=2408) 	0.8976	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	0.83s	 = Training   runtime
# (_dystack pid=2408) 	0.1s	 = Validation runtime
# (_dystack pid=2408) Fitting model: CatBoost_BAG_L1 ... Training model for up to 0.39s of the 19.26s of remaining time.
# (_dystack pid=2408) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.34%)
# (_dystack pid=2408) 	Time limit exceeded... Skipping CatBoost_BAG_L1.
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=22240, ip=127.0.0.1)
# (_dystack pid=2408)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=2408)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=2408)     out = self._fit(**kwargs)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\catboost\catboost_model.py", line 197, in _fit
# (_dystack pid=2408)     raise TimeLimitExceeded
# (_dystack pid=2408) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=12800, ip=127.0.0.1)
# (_dystack pid=2408)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=2408)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=2408)     out = self._fit(**kwargs)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\catboost\catboost_model.py", line 197, in _fit
# (_dystack pid=2408)     raise TimeLimitExceeded
# (_dystack pid=2408) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=2408) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=23072, ip=127.0.0.1)
# (_dystack pid=2408)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=2408)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=2408)     out = self._fit(**kwargs)
# (_dystack pid=2408)   File "c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\tabular\models\catboost\catboost_model.py", line 197, in _fit
# (_dystack pid=2408)     raise TimeLimitExceeded
# (_dystack pid=2408) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=2408) Fitting model: WeightedEnsemble_L2 ... Training model for up to 56.61s of the 4.19s of remaining time.
# (_dystack pid=2408) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.5, 'LightGBM_BAG_L1': 0.3, 'RandomForestGini_BAG_L1': 0.2}
# (_dystack pid=2408) 	0.9353	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	0.04s	 = Training   runtime
# (_dystack pid=2408) 	0.0s	 = Validation runtime
# (_dystack pid=2408) Fitting 108 L2 models ...
# (_dystack pid=2408) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4.11s of the 4.08s of remaining time.
# (_dystack pid=2408) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.18%)
# (_dystack pid=2408) 	0.9303	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	3.77s	 = Training   runtime
# (_dystack pid=2408) 	0.1s	 = Validation runtime
# (_dystack pid=2408) Fitting model: WeightedEnsemble_L3 ... Training model for up to 56.61s of the -12.3s of remaining time.
# (_dystack pid=2408) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.5, 'LightGBMXT_BAG_L1': 0.273, 'RandomForestGini_BAG_L1': 0.136, 'LightGBM_BAG_L1': 0.091}
# (_dystack pid=2408) 	0.9377	 = Validation score   (roc_auc)
# (_dystack pid=2408) 	0.07s	 = Training   runtime
# (_dystack pid=2408) 	0.0s	 = Validation runtime
# (_dystack pid=2408) AutoGluon training complete, total runtime = 69.12s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 75.1 rows/s (28 batch size)
# (_dystack pid=2408) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/real/tlp/v1\ds_sub_fit\sub_fit_ho")
# (_dystack pid=2408) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          LightGBM_BAG_L1       0.972789   0.919956     roc_auc        0.403317       0.121933   3.433002                 0.403317                0.121933           3.433002            1       True          4
# 1        LightGBMXT_BAG_L1       0.959184   0.929379     roc_auc        0.687193       0.104702   4.339213                 0.687193                0.104702           4.339213            1       True          3
# 2      WeightedEnsemble_L2       0.959184   0.935255     roc_auc        1.503170       0.317164   9.824942                 0.031560                0.000000           0.044935            2       True          7
# 3        LightGBMXT_BAG_L2       0.959184   0.930266     roc_auc        2.188631       0.693945  14.415862                 0.374378                0.099278           3.770693            2       True          8
# 4      WeightedEnsemble_L3       0.945578   0.937694     roc_auc        2.223484       0.693945  14.487522                 0.034853                0.000000           0.071661            3       True          9
# 5  RandomForestEntr_BAG_L1       0.931973   0.897616     roc_auc        0.190554       0.104149   0.834460                 0.190554                0.104149           0.834460            1       True          6
# 6  RandomForestGini_BAG_L1       0.931973   0.900277     roc_auc        0.381100       0.090529   2.007792                 0.381100                0.090529           2.007792            1       True          5
# 7    KNeighborsUnif_BAG_L1       0.738095   0.720898     roc_auc        0.063877       0.146563   0.009752                 0.063877                0.146563           0.009752            1       True          1
# 8    KNeighborsDist_BAG_L1       0.727891   0.718736     roc_auc        0.088212       0.026791   0.020949                 0.088212                0.026791           0.020949            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	94s	 = DyStack   runtime |	206s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Using predefined sample weighting strategy: balance_weight. Evaluation metrics will ignore sample weights, specify weight_evaluation=True to instead report weighted metrics.
# Beginning AutoGluon training ... Time limit = 206s
# AutoGluon will save models to "AutogluonModels/real/tlp/v1"
# Train Data Rows:    247
# Train Data Columns: 69
# Label Column:       ED_2Clases
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = H, class 0 = D
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (H) vs negative (D) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Assigning sample weights to balance differences in frequency of classes.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7912.98 MB
# 	Train Data (Original)  Memory Usage: 0.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])    : 52 | ['ISC.FPacientes.genero', 'ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', ...]
# 		('object', []) :  2 | ['ISC.resultadosWFQ.NO_array', 'ISC.resultadosWFQ.SA_array']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  :  2 | ['ISC.resultadosWFQ.NO_array', 'ISC.resultadosWFQ.SA_array']
# 		('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# 		('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# 		('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# 	0.4s = Fit runtime
# 	69 features in original data used to generate 69 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.11 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.48s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 205.85s of the 205.81s of remaining time.
# 	0.7163	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 201.92s of the 201.88s of remaining time.
# 	0.7133	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 201.84s of the 201.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# 	0.9476	 = Validation score   (roc_auc)
# 	5.49s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 184.87s of the 184.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.17%)
# 	0.9373	 = Validation score   (roc_auc)
# 	6.49s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 169.35s of the 169.31s of remaining time.
# 	0.9075	 = Validation score   (roc_auc)
# 	1.71s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 167.45s of the 167.41s of remaining time.
# 	0.8991	 = Validation score   (roc_auc)
# 	0.89s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 166.43s of the 166.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.34%)
# 	0.9466	 = Validation score   (roc_auc)
# 	133.13s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 24.1s of the 24.07s of remaining time.
# 	0.8659	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 23.07s of the 23.03s of remaining time.
# 	0.8573	 = Validation score   (roc_auc)
# 	1.06s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 21.72s of the 21.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.02%)
# 	0.8905	 = Validation score   (roc_auc)
# 	28.06s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 205.85s of the -17.04s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.44, 'LightGBMXT_BAG_L1': 0.2, 'NeuralNetFastAI_BAG_L1': 0.2, 'LightGBM_BAG_L1': 0.16}
# 	0.9549	 = Validation score   (roc_auc)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 223.71s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 31.9 rows/s (31 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/real/tlp/v1")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L2   0.954926     roc_auc       0.975175  173.401439                0.004218           0.233840            2       True         11
# 1         LightGBMXT_BAG_L1   0.947602     roc_auc       0.096243    5.490738                0.096243           5.490738            1       True          3
# 2           CatBoost_BAG_L1   0.946556     roc_auc       0.201414  133.125659                0.201414         133.125659            1       True          7
# 3           LightGBM_BAG_L1   0.937315     roc_auc       0.166824    6.490392                0.166824           6.490392            1       True          4
# 4   RandomForestGini_BAG_L1   0.907454     roc_auc       0.116992    1.708302                0.116992           1.708302            1       True          5
# 5   RandomForestEntr_BAG_L1   0.899085     roc_auc       0.095015    0.886536                0.095015           0.886536            1       True          6
# 6    NeuralNetFastAI_BAG_L1   0.890497     roc_auc       0.506476   28.060809                0.506476          28.060809            1       True         10
# 7     ExtraTreesGini_BAG_L1   0.865867     roc_auc       0.119799    0.872991                0.119799           0.872991            1       True          8
# 8     ExtraTreesEntr_BAG_L1   0.857280     roc_auc       0.199095    1.057578                0.199095           1.057578            1       True          9
# 9     KNeighborsUnif_BAG_L1   0.716260     roc_auc       0.222902    0.012249                0.222902           0.012249            1       True          1
# 10    KNeighborsDist_BAG_L1   0.713252     roc_auc       0.018187    0.015328                0.018187           0.015328            1       True          2
# Number of models trained: 11
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  :  2 | ['ISC.resultadosWFQ.NO_array', 'ISC.resultadosWFQ.SA_array']
# ('float', [])     : 15 | ['TLP.FigRey.Copia.PD', 'TLP.FigRey.Memoria.PD', 'TLP.Stroop.interferencia.PD', 'TLP.Tavec.04_Rg-Pr.PD', 'TLP.Tavec.05_Rg-Md.PD', ...]
# ('int', [])       : 44 | ['ISC.FPacientes.Edad', 'ISC.resultadosCribaje.Total.PD', 'ISC.resultadosReservaCognitiva.Total.PD', 'ISC.resultadosReservaCognitiva.escolaridad', 'ISC.resultadosReservaCognitiva.idiomas', ...]
# ('int', ['bool']) :  8 | ['ISC.FPacientes.genero', 'ISC.resultadosObservacion.alcohol', 'ISC.resultadosObservacion.ansiedad', 'ISC.resultadosObservacion.depresion', 'ISC.resultadosObservacion.enfermedadesDiabetes', ...]
# *** End of fit() summary ***
# c:\Users\jgala\Documents\uned\tfm\synthetic-data\.venv\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.716259808195292,
#   'KNeighborsDist_BAG_L1': 0.7132519616390585,
#   'LightGBMXT_BAG_L1': 0.9476024411508283,
#   'LightGBM_BAG_L1': 0.9373147340889276,
#   'RandomForestGini_BAG_L1': 0.9074542284219703,
#   'RandomForestEntr_BAG_L1': 0.8990845684394072,
#   'CatBoost_BAG_L1': 0.9465562336530078,
#   'ExtraTreesGini_BAG_L1': 0.8658674803836094,
#   'ExtraTreesEntr_BAG_L1': 0.8572798605056668,
#   'NeuralNetFastAI_BAG_L1': 0.8904969485614647,
#   'WeightedEnsemble_L2': 0.9549258936355711},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.012249469757080078,
#   'KNeighborsDist_BAG_L1': 0.015327692031860352,
#   'LightGBMXT_BAG_L1': 5.490738391876221,
#   'LightGBM_BAG_L1': 6.490392446517944,
#   'RandomForestGini_BAG_L1': 1.7083015441894531,
#   'RandomForestEntr_BAG_L1': 0.8865358829498291,
#   'CatBoost_BAG_L1': 133.12565922737122,
#   'ExtraTreesGini_BAG_L1': 0.872990608215332,
#   'ExtraTreesEntr_BAG_L1': 1.0575780868530273,
#   'NeuralNetFastAI_BAG_L1': 28.06080913543701,
#   'WeightedEnsemble_L2': 0.233839750289917},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.2229022979736328,
#   'KNeighborsDist_BAG_L1': 0.018187284469604492,
#   'LightGBMXT_BAG_L1': 0.09624290466308594,
#   'LightGBM_BAG_L1': 0.1668243408203125,
#   'RandomForestGini_BAG_L1': 0.11699223518371582,
#   'RandomForestEntr_BAG_L1': 0.09501504898071289,
#   'CatBoost_BAG_L1': 0.2014141082763672,
#   'ExtraTreesGini_BAG_L1': 0.11979937553405762,
#   'ExtraTreesEntr_BAG_L1': 0.1990952491760254,
#   'NeuralNetFastAI_BAG_L1': 0.5064756870269775,
#   'WeightedEnsemble_L2': 0.004218339920043945},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val eval_metric  pred_time_val    fit_time  \
#  0       WeightedEnsemble_L2   0.954926     roc_auc       0.975175  173.401439
#  1         LightGBMXT_BAG_L1   0.947602     roc_auc       0.096243    5.490738
#  2           CatBoost_BAG_L1   0.946556     roc_auc       0.201414  133.125659
#  3           LightGBM_BAG_L1   0.937315     roc_auc       0.166824    6.490392
#  4   RandomForestGini_BAG_L1   0.907454     roc_auc       0.116992    1.708302
#  5   RandomForestEntr_BAG_L1   0.899085     roc_auc       0.095015    0.886536
#  6    NeuralNetFastAI_BAG_L1   0.890497     roc_auc       0.506476   28.060809
#  7     ExtraTreesGini_BAG_L1   0.865867     roc_auc       0.119799    0.872991
#  8     ExtraTreesEntr_BAG_L1   0.857280     roc_auc       0.199095    1.057578
#  9     KNeighborsUnif_BAG_L1   0.716260     roc_auc       0.222902    0.012249
#  10    KNeighborsDist_BAG_L1   0.713252     roc_auc       0.018187    0.015328
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.004218           0.233840            2       True
#  1                 0.096243           5.490738            1       True
#  2                 0.201414         133.125659            1       True
#  3                 0.166824           6.490392            1       True
#  4                 0.116992           1.708302            1       True
#  5                 0.095015           0.886536            1       True
#  6                 0.506476          28.060809            1       True
#  7                 0.119799           0.872991            1       True
#  8                 0.199095           1.057578            1       True
#  9                 0.222902           0.012249            1       True
#  10                0.018187           0.015328            1       True
#
#      fit_order
#  0          11
#  1           3
#  2           7
#  3           4
#  4           5
#  5           6
#  6          10
#  7           8
#  8           9
#  9           1
#  10          2  }

# %%
auxiliary_metrics = ['balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'roc_auc', 'average_precision', 'precision', 'recall', 'log_loss', 'pac_score']

# %%
predictor.evaluate(
    df_test,
    silent = False,
    auxiliary_metrics = auxiliary_metrics
    )
# Out:
# Evaluation: roc_auc on test data: 0.885
# Evaluations on test data:
# {
#     "roc_auc": 0.885,
#     "accuracy": 0.8387096774193549,
#     "balanced_accuracy": 0.8049999999999999,
#     "mcc": 0.5507652778673942,
#     "f1": 0.6428571428571429,
#     "precision": 0.5625,
#     "recall": 0.75
# }
# {'roc_auc': 0.885,
#  'accuracy': 0.8387096774193549,
#  'balanced_accuracy': 0.8049999999999999,
#  'mcc': 0.5507652778673942,
#  'f1': 0.6428571428571429,
#  'precision': 0.5625,
#  'recall': 0.75}

# %%
predictor.leaderboard(
    df_train,
    extra_metrics = auxiliary_metrics,
    silent=True
)
# Out:
#                       model  score_test  balanced_accuracy        f1  \
# 0           CatBoost_BAG_L1    1.000000           1.000000  1.000000
# 1     KNeighborsDist_BAG_L1    1.000000           1.000000  1.000000
# 2           LightGBM_BAG_L1    1.000000           0.997297  0.992000
# 3         LightGBMXT_BAG_L1    1.000000           0.991892  0.976378
# 4     ExtraTreesEntr_BAG_L1    1.000000           1.000000  1.000000
# 5     ExtraTreesGini_BAG_L1    1.000000           1.000000  1.000000
# 6   RandomForestEntr_BAG_L1    1.000000           1.000000  1.000000
# 7   RandomForestGini_BAG_L1    1.000000           1.000000  1.000000
# 8    NeuralNetFastAI_BAG_L1    1.000000           1.000000  1.000000
# 9       WeightedEnsemble_L2    1.000000           1.000000  1.000000
# 10    KNeighborsUnif_BAG_L1    0.874237           0.798126  0.699187
#
#     f1_macro  f1_micro   roc_auc  average_precision  precision    recall  ...  \
# 0   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 1   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 2   0.994645  0.995951  1.000000           1.000000   0.984127  1.000000  ...
# 3   0.984102  0.987854  1.000000           1.000000   0.953846  1.000000  ...
# 4   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 5   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 6   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 7   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 8   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 9   1.000000  1.000000  1.000000           1.000000   1.000000  1.000000  ...
# 10  0.799728  0.850202  0.874237           0.648725   0.704918  0.693548  ...
#
#     eval_metric  pred_time_test  pred_time_val    fit_time  \
# 0       roc_auc        0.079048       0.201414  133.125659
# 1       roc_auc        0.097116       0.018187    0.015328
# 2       roc_auc        0.112543       0.166824    6.490392
# 3       roc_auc        0.148039       0.096243    5.490738
# 4       roc_auc        0.150516       0.199095    1.057578
# 5       roc_auc        0.175745       0.119799    0.872991
# 6       roc_auc        0.207177       0.095015    0.886536
# 7       roc_auc        0.302136       0.116992    1.708302
# 8       roc_auc        0.722668       0.506476   28.060809
# 9       roc_auc        1.071923       0.975175  173.401439
# 10      roc_auc        0.081151       0.222902    0.012249
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.079048                0.201414         133.125659
# 1                  0.097116                0.018187           0.015328
# 2                  0.112543                0.166824           6.490392
# 3                  0.148039                0.096243           5.490738
# 4                  0.150516                0.199095           1.057578
# 5                  0.175745                0.119799           0.872991
# 6                  0.207177                0.095015           0.886536
# 7                  0.302136                0.116992           1.708302
# 8                  0.722668                0.506476          28.060809
# 9                  0.009625                0.004218           0.233840
# 10                 0.081151                0.222902           0.012249
#
#     stack_level  can_infer  fit_order
# 0             1       True          7
# 1             1       True          2
# 2             1       True          4
# 3             1       True          3
# 4             1       True          9
# 5             1       True          8
# 6             1       True          6
# 7             1       True          5
# 8             1       True         10
# 9             2       True         11
# 10            1       True          1
#
# [11 rows x 23 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 69 features using 247 rows with 5 shuffle sets...
# 	441.29s	= Expected runtime (88.26s per shuffle set)
# 	252.68s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                         importance    stddev   p_value  n  \
# TLP.Stroop.color.PD                       0.065702  0.008305  0.000030  5
# TLP.CubCorsi.Directos.PD                  0.004882  0.001450  0.000833  5
# TLP.FigRey.Memoria.PD                     0.000401  0.000335  0.027796  5
# ISC.FPacientes.Edad                       0.000384  0.000306  0.024273  5
# TLP.Stroop.palabras.PD                    0.000070  0.000073  0.049650  5
# ...                                            ...       ...       ... ..
# TLP.MMSE.Memoria.PD                       0.000000  0.000000  0.500000  5
# TLP.MMSE.Orientacion.PD                   0.000000  0.000000  0.500000  5
# TLP.MMSE.Total.PD                         0.000000  0.000000  0.500000  5
# TLP.Stroop.interferencia.PD               0.000000  0.000000  0.500000  5
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD    0.000000  0.000000  0.500000  5
#
#                                         p99_high   p99_low
# TLP.Stroop.color.PD                     0.082801  0.048603
# TLP.CubCorsi.Directos.PD                0.007867  0.001897
# TLP.FigRey.Memoria.PD                   0.001092 -0.000290
# ISC.FPacientes.Edad                     0.001013 -0.000246
# TLP.Stroop.palabras.PD                  0.000220 -0.000080
# ...                                          ...       ...
# TLP.MMSE.Memoria.PD                     0.000000  0.000000
# TLP.MMSE.Orientacion.PD                 0.000000  0.000000
# TLP.MMSE.Total.PD                       0.000000  0.000000
# TLP.Stroop.interferencia.PD             0.000000  0.000000
# TLP.Tavec.32_Recon-Ac_frente_RCl-LP.PD  0.000000  0.000000
#
# [69 rows x 6 columns]
