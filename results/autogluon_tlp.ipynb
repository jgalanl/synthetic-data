# %%
import pandas as pd
import numpy as np

from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/tlp/predictors.csv')

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [model, score_test, balanced_accuracy, f1, f1_macro, f1_micro, roc_auc, average_precision, precision, recall, log_loss, pac, score_val, eval_metric, pred_time_test, pred_time_val, fit_time, pred_time_test_marginal, pred_time_val_marginal, fit_time_marginal, stack_level, can_infer, fit_order, num_features, num_models, num_models_w_ancestors, memory_size, memory_size_w_ancestors, memory_size_min, memory_size_min_w_ancestors, num_ancestors, num_descendants, model_type, child_model_type, stopping_metric, hyperparameters, hyperparameters_fit, ag_args_fit, features, compile_time, child_hyperparameters, child_hyperparameters_fit, child_ag_args_fit, ancestors, descendants]
# Index: []
#
# [0 rows x 45 columns]

# %%
df[df['score_test'].notna()].sort_values(by='roc_auc', ascending=False)
# Out:
#                                model  score_test  balanced_accuracy        f1  \
# 0               LightGBM_BAG_L1_FULL    1.000000           0.984043  0.954545
# 1             LightGBMXT_BAG_L1_FULL    1.000000           1.000000  1.000000
# 26         LightGBM_r188_BAG_L1_FULL    1.000000           1.000000  1.000000
# 27          CatBoost_r12_BAG_L1_FULL    1.000000           1.000000  1.000000
# 28           XGBoost_r49_BAG_L1_FULL    1.000000           1.000000  1.000000
# ..                               ...         ...                ...       ...
# 65  NeuralNetFastAI_r143_BAG_L1_FULL    0.970787           0.912530  0.854962
# 66  NeuralNetFastAI_r172_BAG_L1_FULL    0.968170           0.896614  0.827068
# 67  NeuralNetFastAI_r102_BAG_L1_FULL    0.955843           0.788332  0.725490
# 68  NeuralNetFastAI_r160_BAG_L1_FULL    0.945120           0.856552  0.719512
# 69   NeuralNetFastAI_r11_BAG_L1_FULL    0.595069           0.530648  0.350877
#
# ...
